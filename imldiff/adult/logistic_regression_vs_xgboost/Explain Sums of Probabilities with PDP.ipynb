# %% [markdown]
# # Explain Sums of Probabilities with PDP
# [SHAP docs:](https://shap.readthedocs.io/en/latest/example_notebooks/overviews/An%20introduction%20to%20explainable%20AI%20with%20Shapley%20values.html)
# > Note that explaining the probability of a linear logistic regression model is not linear in the inputs.

# %%
from imldiff.adult.loader import load_data
from imldiff.adult.models import LogisticRegressionModel, XGBoostModel
from imldiff.comparers import SumComparer
from imldiff.util import printmd
import shap
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X, y, display_data = load_data()
feature_names = list(X.columns)
linear_model = LogisticRegressionModel()
linear_model.load_or_train(X, y)
tree_based_model = XGBoostModel()
tree_based_model.load_or_train(X, y)
# Out:
# Loaded model: models/Logistic.model
# Loaded model: models/XGBoost.model

# %%
comparer = SumComparer(linear_model, tree_based_model)

# %%
def partial_dependence_plot(feature_name):
    printmd(f'### {feature_name}')
    shap.partial_dependence_plot(
        feature_name, comparer.predict_proba, X, model_expected_value=True,
        feature_expected_value=True, show=False, ice=False)
    plt.show()

# %%
partial_dependence_plot('Age')
# Out:
# ### Age

# %%
partial_dependence_plot('Workclass')
# Out:
# ### Workclass

# %%
partial_dependence_plot('Education-Num')
# Out:
# ### Education-Num

# %%
partial_dependence_plot('Marital Status')
# Out:
# ### Marital Status

# %%
partial_dependence_plot('Occupation')
# Out:
# ### Occupation

# %%
partial_dependence_plot('Relationship')
# Out:
# ### Relationship

# %%
partial_dependence_plot('Race')
# Out:
# ### Race

# %%
partial_dependence_plot('Sex')
# Out:
# ### Sex

# %%
partial_dependence_plot('Capital Gain')
# Out:
# ### Capital Gain

# %%
partial_dependence_plot('Capital Loss')
# Out:
# ### Capital Loss

# %%
partial_dependence_plot('Hours per week')
# Out:
# ### Hours per week

# %%
partial_dependence_plot('Country')
# Out:
# ### Country
