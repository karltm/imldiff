# %%
import plot
from shap.maskers import Independent
from sklearn.utils import resample
import shap
from matplotlib import pyplot as plt
from sklearn.utils import resample, shuffle
import numpy as np
import pandas as pd
import pickle
# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open('classifiers.pickle', 'rb') as f:
    clf_a, clf_b = pickle.load(f)
with open('predictions.pickle', 'rb') as f:
    X, display_data, feature_names, n_features, n_samples, indices, pred_a, pred_b, proba_a, proba_b, log_proba_a, log_proba_b, log_odds_a, log_odds_b = pickle.load(f)
with open('subsets.pickle', 'rb') as f:
    is_pred_diff, is_pred_diff_a_pos, is_pred_diff_b_pos, proba_diff_a_pos, proba_diff_b_pos, proba_diff, log_odds_diff_a_pos, log_odds_diff_b_pos, log_odds_diff = pickle.load(f)

idx_sample_pred_equal = indices[~is_pred_diff]
idx_sample_pred_diff = indices[is_pred_diff]
if idx_sample_pred_equal.shape[0] > 500:
    idx_sample_pred_equal = shuffle(idx_sample_pred_equal, random_state=42, n_samples=500)
if idx_sample_pred_diff.shape[0] > 500:
    idx_sample_pred_diff = shuffle(idx_sample_pred_diff, random_state=42, n_samples=500)
idx_sample = np.union1d(idx_sample_pred_equal, idx_sample_pred_diff)

X = X.iloc[idx_sample, :]
display_data = display_data[idx_sample]
pred_a = pred_a[idx_sample]
pred_b = pred_b[idx_sample]
proba_a = proba_a[idx_sample]
proba_b = proba_b[idx_sample]
log_proba_a  =  log_proba_a[idx_sample]
log_proba_b  = log_proba_b[idx_sample]
log_odds_a = log_odds_a[idx_sample]
log_odds_b = log_odds_b[idx_sample]
is_pred_diff = is_pred_diff[idx_sample]
is_pred_diff_a_pos = is_pred_diff_a_pos[idx_sample]
is_pred_diff_b_pos = is_pred_diff_b_pos[idx_sample]
proba_diff_a_pos = proba_diff_a_pos[idx_sample]
proba_diff_b_pos = proba_diff_b_pos[idx_sample]
proba_diff = proba_diff[idx_sample]
log_odds_diff_a_pos = log_odds_diff_a_pos[idx_sample]
log_odds_diff_b_pos = log_odds_diff_b_pos[idx_sample]
log_odds_diff = log_odds_diff[idx_sample]

n_samples = X.shape[0]
indices = np.array(range(n_samples))

# %%
try:
    with open('shapvalues.pred.pickle', 'rb') as f:
        shap_values_diff, shap_values_diff_a_pos, shap_values_diff_b_pos, overall_importance, feature_order, shap_values_diff_a_vs_b_pos = pickle.load(f)
        print('Loaded cached shap values')
except FileNotFoundError:
    print('No cached shap values found')
# Out:
# Loaded cached shap values

# %% [markdown]
# ## Generate Explanations

# %% [markdown]
# Now we define the difference functions to be explained:

# %%
merge_pred_diff_c1_pos = lambda l1, l2: l1 & (~l2)
predict_pred_diff_a_pos = lambda X: merge_pred_diff_c1_pos(clf_a.predict(X), clf_b.predict(X))
predict_pred_diff_b_pos = lambda X: merge_pred_diff_c1_pos(clf_b.predict(X), clf_a.predict(X))

# %%
merge_pred_diff = lambda l1, l2: merge_pred_diff_c1_pos(l1, l2) + merge_pred_diff_c1_pos(l2, l1)
predict_pred_diff = lambda X: merge_pred_diff(clf_a.predict(X), clf_b.predict(X))

# %% [markdown]
# And now we calculate SHAP values for each merge function:

# %%
# %%time

background_data = X
def explain(predict):
    masker = Independent(data=background_data, max_samples=100)
    explainer = shap.Explainer(predict, masker, feature_names=feature_names)
    shap_values = explainer(X)
    shap_values.display_data = display_data
    return shap_values

shap_values_diff_a_pos = explain(predict_pred_diff_a_pos)
shap_values_diff_b_pos = explain(predict_pred_diff_b_pos)

shap_values_diff = shap_values_diff_a_pos + shap_values_diff_b_pos
shap_values_diff.data = shap_values_diff_a_pos.data
shap_values_diff.display_data = shap_values_diff_a_pos.display_data

overall_importance = shap_values_diff.abs.mean(axis=0)
feature_order = np.flip(overall_importance.values.argsort())

shap_values_diff_a_vs_b_pos = shap_values_diff_b_pos - shap_values_diff_a_pos
shap_values_diff_a_vs_b_pos.data = shap_values_diff_a_pos.data
shap_values_diff_a_vs_b_pos.display_data = shap_values_diff_a_pos.display_data

with open(f'shapvalues.pred.pickle', 'wb') as f:
    pickle.dump((shap_values_diff, shap_values_diff_a_pos, shap_values_diff_b_pos, overall_importance, feature_order, shap_values_diff_a_vs_b_pos), f, pickle.HIGHEST_PROTOCOL)
# Out:
# Permutation explainer: 697it [00:35, 15.27it/s]
# Permutation explainer: 697it [00:30, 14.96it/s]
# CPU times: user 1min 50s, sys: 9.6 s, total: 2min
# Wall time: 1min 6s

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# We estimate it with the mean absolute SHAP value (which is the default for this plot) and will also sort features subsequently in this order

# %%
shap.plots.bar(overall_importance, max_display=n_features)

# %% [markdown]
# We see, that compared to the overall importance in the lower segment both Relationship and Education-Num are more important while in the higher difference probability segment these probabilities decrease and decrease even further for the actual different subset

# %% [markdown]
# There is actually a significant difference in the two error classes: Capital Gain is more important for B to predict the positive label than for A to predict the positive label

# %% [markdown]
# But we cannot confirm this completely by looking at the importance differences of the separate difference models

# %%
x = np.arange(n_features)
width = 0.2
fig, ax = plt.subplots(figsize=(14, 7))
rects1 = ax.bar(x - width/2, shap_values_diff_a_pos.abs.mean(0)[feature_order].values, width, label='Different, A=positive', color='green')
rects2 = ax.bar(x + width/2, shap_values_diff_b_pos.abs.mean(0)[feature_order].values, width, label='Different, B=positive', color='orange')
ax.set_ylabel('mean(|SHAP value|)')
ax.set_title('A=positive vs. B=positive')
ax.set_xticks(x)
ax.set_xticklabels(feature_names[feature_order])
ax.legend()
plt.show()

# %% [markdown]
# ### SHAP Value Distribution

# %% [markdown]
# Next, we will try to understand the importances using the whole distribution of values, not only the aggregated mean.

# %% [markdown]
# TODO: build own plots, where all sets of instances are in one plot, with different colors per set and a color range from low to high feature value as well

# %%
plot.shap_beeswarm(shap_values_diff, 'P(different)', order=feature_order, max_display=n_features)

# %%
for feature in feature_names[feature_order]:
    a_feature = shap_values_diff_a_pos[:, feature]
    b_feature = shap_values_diff_b_pos[:, feature]
    values = np.array([a_feature.values, b_feature.values]).T
    data = np.array([a_feature.data, b_feature.data]).T
    display_data = np.array([a_feature.display_data, b_feature.display_data]).T
    explanation = shap.Explanation(values, data=data, display_data=display_data, feature_names=['P(different, A=pos)', 'P(different, B=pos)'])
    plot.shap_beeswarm(explanation, 'Feature ' + feature)

# %%
plot.shap_beeswarm(shap_values_diff_a_vs_b_pos, 'P(different, B=pos) - P(different, A=pos)', order=feature_order, max_display=n_features)

# %% [markdown]
# ### Features' Partial Dependence Plots

# %%
n_columns = 3
n_rows = n_features
fig = plt.figure(figsize=(9*n_columns, 7*n_rows))
i = 1
for feature in feature_names[feature_order]:
    ax1 = fig.add_subplot(n_rows, n_columns, i)
    ax2 = fig.add_subplot(n_rows, n_columns, i+1, sharey=ax1)
    ax3 = fig.add_subplot(n_rows, n_columns, i+2, sharey=ax1)
    shap.plots.scatter(shap_values_diff[:, feature], title='Different', ax=ax1, color=proba_diff, show=False)
    shap.plots.scatter(shap_values_diff_a_pos[:, feature], title='Different, A=pos', ax=ax2, color=proba_diff, show=False)
    shap.plots.scatter(shap_values_diff_b_pos[:, feature], title='Different, B=pos', ax=ax3, color=proba_diff, show=False)
    i += n_columns
plt.show()
# Out:
# Passing the fontdict parameter of _set_ticklabels() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %%
idx_diff = indices[pred_a != pred_b]
idx_equal = indices[pred_a == pred_b]
if len(idx_diff) > 500:
    idx_diff = shuffle(idx_diff, random_state=0, n_samples=500)
if len(idx_equal) > 500:
    idx_equal = shuffle(idx_equal, random_state=0, n_samples=500)

# %%
order = plot.shap_force(shap_values_diff[idx_diff], 'Different')
plot.shap_force(shap_values_diff_a_pos[idx_diff], 'Different, A=pos', ordering=order)
plot.shap_force(shap_values_diff_b_pos[idx_diff], 'Different, B=pos', ordering=order);
# Out:
# <div id='iW4OKKKBDADYLAA8AAO2C'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Different"], "baseValue": 0.24, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 1.0, "simIndex": 195.0, "features": {"0": {"effect": -0.05000000000000001, "value": 37.0}, "1": {"effect": 0.031111111111111114, "value": " Private"}, "2": {"effect": 0.07777777777777778, "value": 10.0}, "3": {"effect": 0.10999999999999997, "value": " Married-civ-spouse"}, "4": {"effect": 0.007777777777777778, "value": " Exec-managerial"}, "5": {"effect": 0.049999999999999996, "value": " Husband"}, "6": {"effect": 0.3033333333333333, "value": " Black"}, "7": {"effect": 0.07777777777777778, "value": " Male"}, "8": {"effect": 0.005555555555555545, "value": 0.0}, "9": {"effect": 0.0011111111111111198, "value": 0.0}, "10": {"effect": 0.13, "value": 80.0}, "11": {"effect": 0.015555555555555564, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 24.0, "features": {"0": {"effect": 0.1922222222222222, "value": 24.0}, "1": {"effect": 0.007777777777777792, "value": " Private"}, "2": {"effect": 0.24000000000000002, "value": 13.0}, "3": {"effect": 0.07222222222222224, "value": " Married-civ-spouse"}, "4": {"effect": 0.09555555555555555, "value": " Tech-support"}, "5": {"effect": 0.019999999999999993, "value": " Husband"}, "6": {"effect": -0.002222222222222221, "value": " White"}, "7": {"effect": 0.02444444444444445, "value": " Male"}, "8": {"effect": 0.05111111111111109, "value": 0.0}, "9": {"effect": 0.013333333333333348, "value": 0.0}, "10": {"effect": 0.008888888888888884, "value": 50.0}, "11": {"effect": 0.036666666666666674, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 19.0, "features": {"0": {"effect": 0.32333333333333336, "value": 49.0}, "1": {"effect": 0.01666666666666667, "value": " Private"}, "2": {"effect": 0.1544444444444444, "value": 13.0}, "3": {"effect": 0.04111111111111111, "value": " Married-civ-spouse"}, "4": {"effect": 0.14999999999999994, "value": " Sales"}, "5": {"effect": 0.04777777777777778, "value": " Husband"}, "6": {"effect": 0.002222222222222218, "value": " White"}, "7": {"effect": 0.03000000000000001, "value": " Male"}, "8": {"effect": -0.004444444444444445, "value": 0.0}, "9": {"effect": -0.0011111111111111087, "value": 0.0}, "10": {"effect": -0.007777777777777788, "value": 26.0}, "11": {"effect": 0.0077777777777777645, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 186.0, "features": {"0": {"effect": 0.13555555555555554, "value": 34.0}, "1": {"effect": -0.009999999999999997, "value": " Private"}, "2": {"effect": 0.06555555555555553, "value": 13.0}, "3": {"effect": 0.05444444444444444, "value": " Married-civ-spouse"}, "4": {"effect": 0.31222222222222223, "value": " Exec-managerial"}, "5": {"effect": 0.05000000000000001, "value": " Husband"}, "6": {"effect": 0.013333333333333332, "value": " White"}, "7": {"effect": 0.024444444444444442, "value": " Male"}, "8": {"effect": -0.0066666666666666645, "value": 0.0}, "9": {"effect": 0.007777777777777794, "value": 0.0}, "10": {"effect": 0.11666666666666667, "value": 45.0}, "11": {"effect": -0.003333333333333325, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 184.0, "features": {"0": {"effect": 0.1733333333333333, "value": 47.0}, "1": {"effect": 0.011111111111111106, "value": " Self-emp-not-inc"}, "2": {"effect": 0.007777777777777778, "value": 9.0}, "3": {"effect": 0.02999999999999999, "value": " Married-civ-spouse"}, "4": {"effect": 0.30444444444444446, "value": " Other-service"}, "5": {"effect": -0.045555555555555544, "value": " Wife"}, "6": {"effect": 0.0077777777777777845, "value": " White"}, "7": {"effect": 0.14555555555555555, "value": " Female"}, "8": {"effect": -0.0011111111111111137, "value": 0.0}, "9": {"effect": 0.018888888888888906, "value": 0.0}, "10": {"effect": 0.0955555555 ...
# <div id='iWY6Y1XZPUTYUR7PYSFPV'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Different, A=pos"], "baseValue": 0.24, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 1.0, "simIndex": 195.0, "features": {"0": {"effect": -0.05000000000000001, "value": 37.0}, "1": {"effect": 0.031111111111111114, "value": " Private"}, "2": {"effect": 0.07777777777777778, "value": 10.0}, "3": {"effect": 0.10999999999999997, "value": " Married-civ-spouse"}, "4": {"effect": 0.007777777777777778, "value": " Exec-managerial"}, "5": {"effect": 0.049999999999999996, "value": " Husband"}, "6": {"effect": 0.3033333333333333, "value": " Black"}, "7": {"effect": 0.07777777777777778, "value": " Male"}, "8": {"effect": 0.005555555555555545, "value": 0.0}, "9": {"effect": 0.0011111111111111198, "value": 0.0}, "10": {"effect": 0.13, "value": 80.0}, "11": {"effect": 0.015555555555555564, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 24.0, "features": {"0": {"effect": 0.1922222222222222, "value": 24.0}, "1": {"effect": 0.007777777777777792, "value": " Private"}, "2": {"effect": 0.24000000000000002, "value": 13.0}, "3": {"effect": 0.07222222222222224, "value": " Married-civ-spouse"}, "4": {"effect": 0.09555555555555555, "value": " Tech-support"}, "5": {"effect": 0.019999999999999993, "value": " Husband"}, "6": {"effect": -0.002222222222222221, "value": " White"}, "7": {"effect": 0.02444444444444445, "value": " Male"}, "8": {"effect": 0.05111111111111109, "value": 0.0}, "9": {"effect": 0.013333333333333348, "value": 0.0}, "10": {"effect": 0.008888888888888884, "value": 50.0}, "11": {"effect": 0.036666666666666674, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 19.0, "features": {"0": {"effect": 0.32333333333333336, "value": 49.0}, "1": {"effect": 0.01666666666666667, "value": " Private"}, "2": {"effect": 0.1544444444444444, "value": 13.0}, "3": {"effect": 0.04111111111111111, "value": " Married-civ-spouse"}, "4": {"effect": 0.14999999999999994, "value": " Sales"}, "5": {"effect": 0.04777777777777778, "value": " Husband"}, "6": {"effect": 0.002222222222222218, "value": " White"}, "7": {"effect": 0.03000000000000001, "value": " Male"}, "8": {"effect": -0.004444444444444445, "value": 0.0}, "9": {"effect": -0.0011111111111111087, "value": 0.0}, "10": {"effect": -0.007777777777777788, "value": 26.0}, "11": {"effect": 0.0077777777777777645, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 186.0, "features": {"0": {"effect": 0.13555555555555554, "value": 34.0}, "1": {"effect": -0.009999999999999997, "value": " Private"}, "2": {"effect": 0.06555555555555553, "value": 13.0}, "3": {"effect": 0.05444444444444444, "value": " Married-civ-spouse"}, "4": {"effect": 0.31222222222222223, "value": " Exec-managerial"}, "5": {"effect": 0.05000000000000001, "value": " Husband"}, "6": {"effect": 0.013333333333333332, "value": " White"}, "7": {"effect": 0.024444444444444442, "value": " Male"}, "8": {"effect": -0.0066666666666666645, "value": 0.0}, "9": {"effect": 0.007777777777777794, "value": 0.0}, "10": {"effect": 0.11666666666666667, "value": 45.0}, "11": {"effect": -0.003333333333333325, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 184.0, "features": {"0": {"effect": 0.1733333333333333, "value": 47.0}, "1": {"effect": 0.011111111111111106, "value": " Self-emp-not-inc"}, "2": {"effect": 0.007777777777777778, "value": 9.0}, "3": {"effect": 0.02999999999999999, "value": " Married-civ-spouse"}, "4": {"effect": 0.30444444444444446, "value": " Other-service"}, "5": {"effect": -0.045555555555555544, "value": " Wife"}, "6": {"effect": 0.0077777777777777845, "value": " White"}, "7": {"effect": 0.14555555555555555, "value": " Female"}, "8": {"effect": -0.0011111111111111137, "value": 0.0}, "9": {"effect": 0.018888888888888906, "value": 0.0}, "10": {"effect": 0.095 ...
# <div id='iKQ6JYU9Q9ZBQNHL3VZXD'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Different, B=pos"], "baseValue": 0.0, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.0, "simIndex": 98.0, "features": {"0": {"effect": 0.0, "value": 37.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": 0.0, "value": 10.0}, "3": {"effect": 0.0, "value": " Married-civ-spouse"}, "4": {"effect": 0.0, "value": " Exec-managerial"}, "5": {"effect": 0.0, "value": " Husband"}, "6": {"effect": 0.0, "value": " Black"}, "7": {"effect": 0.0, "value": " Male"}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": 0.0, "value": 80.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 99.0, "features": {"0": {"effect": 0.0, "value": 24.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": 0.0, "value": 13.0}, "3": {"effect": 0.0, "value": " Married-civ-spouse"}, "4": {"effect": 0.0, "value": " Tech-support"}, "5": {"effect": 0.0, "value": " Husband"}, "6": {"effect": 0.0, "value": " White"}, "7": {"effect": 0.0, "value": " Male"}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": 0.0, "value": 50.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 100.0, "features": {"0": {"effect": 0.0, "value": 49.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": 0.0, "value": 13.0}, "3": {"effect": 0.0, "value": " Married-civ-spouse"}, "4": {"effect": 0.0, "value": " Sales"}, "5": {"effect": 0.0, "value": " Husband"}, "6": {"effect": 0.0, "value": " White"}, "7": {"effect": 0.0, "value": " Male"}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": 0.0, "value": 26.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 97.0, "features": {"0": {"effect": 0.0, "value": 34.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": 0.0, "value": 13.0}, "3": {"effect": 0.0, "value": " Married-civ-spouse"}, "4": {"effect": 0.0, "value": " Exec-managerial"}, "5": {"effect": 0.0, "value": " Husband"}, "6": {"effect": 0.0, "value": " White"}, "7": {"effect": 0.0, "value": " Male"}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": 0.0, "value": 45.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 101.0, "features": {"0": {"effect": 0.0, "value": 47.0}, "1": {"effect": 0.0, "value": " Self-emp-not-inc"}, "2": {"effect": 0.0, "value": 9.0}, "3": {"effect": 0.0, "value": " Married-civ-spouse"}, "4": {"effect": 0.0, "value": " Other-service"}, "5": {"effect": 0.0, "value": " Wife"}, "6": {"effect": 0.0, "value": " White"}, "7": {"effect": 0.0, "value": " Female"}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": 0.0, "value": 75.0}, "11": {"effect": 0.0, "value": " Italy"}}}, {"outValue": 0.0, "simIndex": 96.0, "features": {"0": {"effect": 0.0, "value": 39.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": 0.0, "value": 13.0}, "3": {"effect": 0.0, "value": " Married-civ-spouse"}, "4": {"effect": 0.0, "value": " Craft-repair"}, "5": {"effect": 0.0, "value": " Husband"}, "6": {"effect": 0.0, "value": " White"}, "7": {"effect": 0.0, "value": " Male"}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": 0.0, "value": 40.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 102.0, "features": {"0": {"effect": 0.0, "value": 48.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": 0.0, "value": 13.0}, "3": {"effect": 0.0, "value": " Married-civ-spouse"}, "4": {"effect": 0.0, "value": " Exec-managerial"}, "5": {"effect": 0.0, "value": " Husband"}, "6": {"effect": 0.0, "value ...

# %%
order = plot.shap_force(shap_values_diff[idx_equal], 'Different')
plot.shap_force(shap_values_diff_a_pos[idx_equal], 'Different, A=pos', ordering=order)
plot.shap_force(shap_values_diff_b_pos[idx_equal], 'Different, B=pos', ordering=order);
# Out:
# <div id='iWYSU0P26ST0Q0L97ZOB7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Different"], "baseValue": 0.24, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 2.7755575615628914e-17, "simIndex": 482.0, "features": {"0": {"effect": 0.0, "value": 53.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": -0.06666666666666667, "value": 9.0}, "3": {"effect": 0.0033333333333333335, "value": " Divorced"}, "4": {"effect": -0.0011111111111111111, "value": " Sales"}, "5": {"effect": -0.0022222222222222222, "value": " Own-child"}, "6": {"effect": -0.005555555555555553, "value": " White"}, "7": {"effect": -0.10222222222222221, "value": " Female"}, "8": {"effect": -0.007777777777777777, "value": 0.0}, "9": {"effect": -0.001111111111111109, "value": 0.0}, "10": {"effect": -0.04444444444444444, "value": 35.0}, "11": {"effect": -0.012222222222222221, "value": " United-States"}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 358.0, "features": {"0": {"effect": -0.05666666666666666, "value": 35.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": -0.04333333333333334, "value": 14.0}, "3": {"effect": -0.004444444444444446, "value": " Married-civ-spouse"}, "4": {"effect": -0.011111111111111108, "value": " Prof-specialty"}, "5": {"effect": -0.07, "value": " Other-relative"}, "6": {"effect": -0.016666666666666663, "value": " White"}, "7": {"effect": -0.0022222222222222205, "value": " Male"}, "8": {"effect": 0.0022222222222222222, "value": 7298.0}, "9": {"effect": -0.0011111111111111122, "value": 0.0}, "10": {"effect": -0.024444444444444446, "value": 40.0}, "11": {"effect": -0.012222222222222223, "value": " United-States"}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 395.0, "features": {"0": {"effect": -0.006666666666666667, "value": 45.0}, "1": {"effect": -0.029999999999999995, "value": " Private"}, "2": {"effect": -0.007777777777777778, "value": 13.0}, "3": {"effect": -0.0011111111111111111, "value": " Married-civ-spouse"}, "4": {"effect": -0.05444444444444444, "value": " Prof-specialty"}, "5": {"effect": -0.008888888888888887, "value": " Husband"}, "6": {"effect": -0.007777777777777777, "value": " White"}, "7": {"effect": -0.0011111111111111085, "value": " Male"}, "8": {"effect": -0.0055555555555555575, "value": 0.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": -0.10444444444444446, "value": 55.0}, "11": {"effect": -0.012222222222222221, "value": " United-States"}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 295.0, "features": {"0": {"effect": -0.026666666666666665, "value": 53.0}, "1": {"effect": -0.026666666666666665, "value": " Local-gov"}, "2": {"effect": -0.013333333333333332, "value": 1.0}, "3": {"effect": -0.05666666666666667, "value": " Never-married"}, "4": {"effect": -0.015555555555555553, "value": " Machine-op-inspct"}, "5": {"effect": -0.02888888888888889, "value": " Not-in-family"}, "6": {"effect": -0.0066666666666666645, "value": " White"}, "7": {"effect": -0.017777777777777774, "value": " Female"}, "8": {"effect": -0.012222222222222221, "value": 0.0}, "9": {"effect": -0.001111111111111109, "value": 0.0}, "10": {"effect": -0.023333333333333334, "value": 35.0}, "11": {"effect": -0.011111111111111108, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 250.0, "features": {"0": {"effect": -0.08000000000000002, "value": 30.0}, "1": {"effect": -0.02, "value": " ?"}, "2": {"effect": -0.02, "value": 11.0}, "3": {"effect": -0.04888888888888889, "value": " Divorced"}, "4": {"effect": -0.024444444444444442, "value": " ?"}, "5": {"effect": -0.0011111111111111111, "value": " Unmarried"}, "6": {"effect": 0.003333333333333333, "value": " White"}, "7": {"effect": -0.026666666666666665, "value": " Female"}, "8": {"effect": -0.0033333333333333335, "value": 0.0}, "9": {"effect": -0.001111111111111111, "value": 0.0}, " ...
# <div id='iT2SVUG3TIL31KSKS2EMY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Different, A=pos"], "baseValue": 0.24, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 2.7755575615628914e-17, "simIndex": 482.0, "features": {"0": {"effect": 0.0, "value": 53.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": -0.06666666666666667, "value": 9.0}, "3": {"effect": 0.0033333333333333335, "value": " Divorced"}, "4": {"effect": -0.0011111111111111111, "value": " Sales"}, "5": {"effect": -0.0022222222222222222, "value": " Own-child"}, "6": {"effect": -0.005555555555555553, "value": " White"}, "7": {"effect": -0.10222222222222221, "value": " Female"}, "8": {"effect": -0.007777777777777777, "value": 0.0}, "9": {"effect": -0.001111111111111109, "value": 0.0}, "10": {"effect": -0.04444444444444444, "value": 35.0}, "11": {"effect": -0.012222222222222221, "value": " United-States"}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 358.0, "features": {"0": {"effect": -0.05666666666666666, "value": 35.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": -0.04333333333333334, "value": 14.0}, "3": {"effect": -0.004444444444444446, "value": " Married-civ-spouse"}, "4": {"effect": -0.011111111111111108, "value": " Prof-specialty"}, "5": {"effect": -0.07, "value": " Other-relative"}, "6": {"effect": -0.016666666666666663, "value": " White"}, "7": {"effect": -0.0022222222222222205, "value": " Male"}, "8": {"effect": 0.0022222222222222222, "value": 7298.0}, "9": {"effect": -0.0011111111111111122, "value": 0.0}, "10": {"effect": -0.024444444444444446, "value": 40.0}, "11": {"effect": -0.012222222222222223, "value": " United-States"}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 395.0, "features": {"0": {"effect": -0.006666666666666667, "value": 45.0}, "1": {"effect": -0.029999999999999995, "value": " Private"}, "2": {"effect": -0.007777777777777778, "value": 13.0}, "3": {"effect": -0.0011111111111111111, "value": " Married-civ-spouse"}, "4": {"effect": -0.05444444444444444, "value": " Prof-specialty"}, "5": {"effect": -0.008888888888888887, "value": " Husband"}, "6": {"effect": -0.007777777777777777, "value": " White"}, "7": {"effect": -0.0011111111111111085, "value": " Male"}, "8": {"effect": -0.0055555555555555575, "value": 0.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": -0.10444444444444446, "value": 55.0}, "11": {"effect": -0.012222222222222221, "value": " United-States"}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 295.0, "features": {"0": {"effect": -0.026666666666666665, "value": 53.0}, "1": {"effect": -0.026666666666666665, "value": " Local-gov"}, "2": {"effect": -0.013333333333333332, "value": 1.0}, "3": {"effect": -0.05666666666666667, "value": " Never-married"}, "4": {"effect": -0.015555555555555553, "value": " Machine-op-inspct"}, "5": {"effect": -0.02888888888888889, "value": " Not-in-family"}, "6": {"effect": -0.0066666666666666645, "value": " White"}, "7": {"effect": -0.017777777777777774, "value": " Female"}, "8": {"effect": -0.012222222222222221, "value": 0.0}, "9": {"effect": -0.001111111111111109, "value": 0.0}, "10": {"effect": -0.023333333333333334, "value": 35.0}, "11": {"effect": -0.011111111111111108, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 250.0, "features": {"0": {"effect": -0.08000000000000002, "value": 30.0}, "1": {"effect": -0.02, "value": " ?"}, "2": {"effect": -0.02, "value": 11.0}, "3": {"effect": -0.04888888888888889, "value": " Divorced"}, "4": {"effect": -0.024444444444444442, "value": " ?"}, "5": {"effect": -0.0011111111111111111, "value": " Unmarried"}, "6": {"effect": 0.003333333333333333, "value": " White"}, "7": {"effect": -0.026666666666666665, "value": " Female"}, "8": {"effect": -0.0033333333333333335, "value": 0.0}, "9": {"effect": -0.001111111111111111, "value":  ...
# <div id='iMHZUYYOCRH46IY07YKV9'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Different, B=pos"], "baseValue": 0.0, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.0, "simIndex": 250.0, "features": {"0": {"effect": 0.0, "value": 53.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": 0.0, "value": 9.0}, "3": {"effect": 0.0, "value": " Divorced"}, "4": {"effect": 0.0, "value": " Sales"}, "5": {"effect": 0.0, "value": " Own-child"}, "6": {"effect": 0.0, "value": " White"}, "7": {"effect": 0.0, "value": " Female"}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": 0.0, "value": 35.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 251.0, "features": {"0": {"effect": 0.0, "value": 35.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": 0.0, "value": 14.0}, "3": {"effect": 0.0, "value": " Married-civ-spouse"}, "4": {"effect": 0.0, "value": " Prof-specialty"}, "5": {"effect": 0.0, "value": " Other-relative"}, "6": {"effect": 0.0, "value": " White"}, "7": {"effect": 0.0, "value": " Male"}, "8": {"effect": 0.0, "value": 7298.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": 0.0, "value": 40.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 252.0, "features": {"0": {"effect": 0.0, "value": 45.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": 0.0, "value": 13.0}, "3": {"effect": 0.0, "value": " Married-civ-spouse"}, "4": {"effect": 0.0, "value": " Prof-specialty"}, "5": {"effect": 0.0, "value": " Husband"}, "6": {"effect": 0.0, "value": " White"}, "7": {"effect": 0.0, "value": " Male"}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": 0.0, "value": 55.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 249.0, "features": {"0": {"effect": 0.0, "value": 53.0}, "1": {"effect": 0.0, "value": " Local-gov"}, "2": {"effect": 0.0, "value": 1.0}, "3": {"effect": 0.0, "value": " Never-married"}, "4": {"effect": 0.0, "value": " Machine-op-inspct"}, "5": {"effect": 0.0, "value": " Not-in-family"}, "6": {"effect": 0.0, "value": " White"}, "7": {"effect": 0.0, "value": " Female"}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": 0.0, "value": 35.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 253.0, "features": {"0": {"effect": 0.0, "value": 30.0}, "1": {"effect": 0.0, "value": " ?"}, "2": {"effect": 0.0, "value": 11.0}, "3": {"effect": 0.0, "value": " Divorced"}, "4": {"effect": 0.0, "value": " ?"}, "5": {"effect": 0.0, "value": " Unmarried"}, "6": {"effect": 0.0, "value": " White"}, "7": {"effect": 0.0, "value": " Female"}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": 0.0, "value": 40.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 248.0, "features": {"0": {"effect": 0.0, "value": 17.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": 0.0, "value": 7.0}, "3": {"effect": 0.0, "value": " Never-married"}, "4": {"effect": 0.0, "value": " Other-service"}, "5": {"effect": 0.0, "value": " Own-child"}, "6": {"effect": 0.0, "value": " White"}, "7": {"effect": 0.0, "value": " Male"}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 0.0}, "10": {"effect": 0.0, "value": 10.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 254.0, "features": {"0": {"effect": 0.0, "value": 41.0}, "1": {"effect": 0.0, "value": " Local-gov"}, "2": {"effect": 0.0, "value": 10.0}, "3": {"effect": 0.0, "value": " Divorced"}, "4": {"effect": 0.0, "value": " Other-service"}, "5": {"effect": 0.0, "value": " Not-in-family"}, "6": {"effect": 0.0, "value": " Black"}, "7 ...

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %%
plot.shap_heatmap(shap_values_diff[idx_diff], 'Different', feature_order)

# %%
plot.shap_heatmap(shap_values_diff[idx_equal], 'Different', feature_order)

# %%
plot.shap_heatmap(shap_values_diff_a_pos[idx_diff], 'Different, A=pos', feature_order)

# %%
plot.shap_heatmap(shap_values_diff_a_pos[idx_equal], 'Different, A=pos', feature_order)

# %%
plot.shap_heatmap(shap_values_diff_b_pos[idx_diff], 'Different, B=pos', feature_order)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %%
plot.shap_heatmap(shap_values_diff_b_pos[idx_equal], 'Different, B=pos', feature_order)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %%
plot.shap_heatmap(shap_values_diff_a_vs_b_pos[idx_diff], 'Different, A vs. B pos', feature_order)

# %%
plot.shap_heatmap(shap_values_diff_a_vs_b_pos[idx_equal], 'Different, A vs. B pos', feature_order)
