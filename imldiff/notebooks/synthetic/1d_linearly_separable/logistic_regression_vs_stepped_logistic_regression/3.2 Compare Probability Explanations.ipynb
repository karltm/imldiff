# %%
from util import get_force_plot_ordering
from shap.maskers import Independent
from sklearn.utils import resample, shuffle
import shap
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open('classifiers.pickle', 'rb') as f:
    clf_a, clf_b = pickle.load(f)
with open('dataset.pickle', 'rb') as f:
    X, y, feature_names, n_features, n_samples = pickle.load(f)

# %%
try:
    with open(f'shapvalues.soa.proba.pickle', 'rb') as f:
        shap_values_a, shap_values_b = pickle.load(f)
        print('Loaded cached shap values')
except FileNotFoundError:
    print('No cached shap values found')
# Out:
# Loaded cached shap values

# %% [markdown]
# ## Generate Explanations

# %% [markdown]
# Now we define the functions to be explained:

# %%
predict_proba_a = lambda X: clf_a.predict_proba(X)[:, 1]
predict_proba_b = lambda X: clf_b.predict_proba(X)[:, 1]

# %% [markdown]
# And now we calculate SHAP values for each function:

# %%
# %%time

background_data = X
def explain(predict):
    masker = Independent(data=background_data, max_samples=100)
    explainer = shap.Explainer(predict, masker, feature_names=feature_names)
    shap_values = explainer(X)
    return shap_values

shap_values_a = explain(predict_proba_a)
shap_values_b = explain(predict_proba_b)

with open(f'shapvalues.soa.proba.pickle', 'wb') as f:
    pickle.dump((shap_values_a, shap_values_b), f, pickle.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 5.3 s, sys: 122 ms, total: 5.42 s
# Wall time: 6.01 s

# %% [markdown]
# ## Analyze

# %%
shap_values_a_vs_b = shap_values_b - shap_values_a
shap_values_a_vs_b.data = shap_values_a.data
feature_order = np.flip(shap_values_a_vs_b.abs.mean(axis=0).values.argsort())

# %%
indices = np.indices(y.shape).ravel()
pred_a = clf_a.predict(X)
pred_b = clf_b.predict(X)
is_pred_equal = pred_a == pred_b
is_pred_diff = ~is_pred_equal

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# #### Bar Plots

# %% [markdown]
# Per default, the bar plot draws the mean absolute SHAP value per feature as an estimate for the feature importance.

# %%
shap.plots.bar(shap_values_a, order=feature_order, max_display=n_features, show=False)
plt.title('Classifier A')
plt.show()
shap.plots.bar(shap_values_b, order=feature_order, max_display=n_features, show=False)
plt.title('Classifier B')
plt.show()
shap.plots.bar(shap_values_a_vs_b, order=feature_order, max_display=n_features, show=False)
plt.title('Differences between A and B')
plt.show()

# %% [markdown]
# #### SHAP Value Distribution

# %% [markdown]
# Next, we will try to understand the importances using the whole distribution of values, not only the aggregated mean.

# %%
shap.plots.beeswarm(shap_values_a, order=feature_order, plot_size=(14, 7), show=False)
plt.title('SHAP values of A')
plt.show()
shap.plots.beeswarm(shap_values_b, order=feature_order, plot_size=(14, 7), show=False)
plt.title('SHAP values of B')
plt.show()
shap.plots.beeswarm(shap_values_a_vs_b, order=feature_order, plot_size=(14, 7), show=False)
plt.title('Differences between SHAP values of A and B')
plt.show()

# %% [markdown]
# ### Feature Effects

# %% [markdown]
# #### Partial Dependence Plots

# %% [markdown]
# Here we investigate he effect a feature has no the model output. Plot in blue are the instances where A and B predict the same label, plot over in red are instances where they differ. The last column shows the difference between the two classifiers' SHAP values.

# %%
n_columns = 3
n_rows = n_features
fig = plt.figure(figsize=(9*n_columns, 7*n_rows))
i = 1
for feature in feature_names:
    ax1 = fig.add_subplot(n_rows, n_columns, i)
    ax2 = fig.add_subplot(n_rows, n_columns, i+1, sharey=ax1)
    ax3 = fig.add_subplot(n_rows, n_columns, i+2, sharey=None)
    shap.plots.scatter(shap_values_a[:, feature], ax=ax1, color='blue', show=False)
    shap.plots.scatter(shap_values_a[is_pred_diff, feature], title='Classifier A', ax=ax1, color='red',  hist=False, show=False)
    shap.plots.scatter(shap_values_b[:, feature], ax=ax2, color='blue', dot_size=16, show=False)
    shap.plots.scatter(shap_values_b[is_pred_diff, feature], title='Classifier B', ax=ax2, color='red', hist=False, show=False)
    shap.plots.scatter(shap_values_a_vs_b[:, feature], ax=ax3, color='blue', show=False)
    shap.plots.scatter(shap_values_a_vs_b[is_pred_diff, feature], title='Differences between A and B', ax=ax3, color='red', hist=False, show=False)
    i += n_columns
plt.show()

# %% [markdown]
# ### Cluster

# %% [markdown]
# #### Force plots

# %% [markdown]
# Visualize the SHAP values with their positive and negative forces on the prediction for a sample of the instances, ordered by similarity.

# %%
idx_diff = indices[is_pred_diff]
idx_equal = indices[is_pred_equal]
if len(idx_diff) > 500:
    idx_diff = shuffle(idx_diff, random_state=0, n_samples=500)
if len(idx_equal) > 500:
    idx_equal = shuffle(idx_equal, random_state=0, n_samples=500)

# %% [markdown]
# First, only instances which have a differing prediction:

# %%
ordering = None
for name, shap_values in zip(('A', 'B', 'A vs. B'), (shap_values_a, shap_values_b, shap_values_a_vs_b)):
    shap_values = shap_values[idx_diff]
    plot = shap.plots.force(base_value=shap_values.base_values[0], shap_values=shap_values.values, features=shap_values.display_data, feature_names=shap_values.feature_names, out_names=name, ordering_keys=ordering)
    display(plot)
    if not ordering:
        ordering = get_force_plot_ordering(plot)
# Out:
# <div id='iJPHWTWWEEJSIEN0MFWBL'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0.5375786987834565, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": 0.5071918068212042, "simIndex": 31.0, "features": {"0": {"effect": -0.030386891962252305, "value": ""}}}, {"outValue": 0.6621456281290802, "simIndex": 7.0, "features": {"0": {"effect": 0.12456692934562363, "value": ""}}}, {"outValue": 0.5835258962138511, "simIndex": 20.0, "features": {"0": {"effect": 0.04594719743039455, "value": ""}}}, {"outValue": 0.5711643154832566, "simIndex": 23.0, "features": {"0": {"effect": 0.03358561669980009, "value": ""}}}, {"outValue": 0.5955273299480961, "simIndex": 17.0, "features": {"0": {"effect": 0.05794863116463955, "value": ""}}}, {"outValue": 0.5216932425766317, "simIndex": 29.0, "features": {"0": {"effect": -0.0158854562068248, "value": ""}}}, {"outValue": 0.6294388230517218, "simIndex": 13.0, "features": {"0": {"effect": 0.09186012426826529, "value": ""}}}, {"outValue": 0.6023017297009545, "simIndex": 15.0, "features": {"0": {"effect": 0.06472303091749798, "value": ""}}}, {"outValue": 0.7307072117912757, "simIndex": 1.0, "features": {"0": {"effect": 0.1931285130078192, "value": ""}}}, {"outValue": 0.5887841061747419, "simIndex": 19.0, "features": {"0": {"effect": 0.05120540739128532, "value": ""}}}, {"outValue": 0.500586085616945, "simIndex": 34.0, "features": {"0": {"effect": -0.03699261316651159, "value": ""}}}, {"outValue": 0.7255354729097958, "simIndex": 2.0, "features": {"0": {"effect": 0.18795677412633927, "value": ""}}}, {"outValue": 0.6517901803659781, "simIndex": 10.0, "features": {"0": {"effect": 0.11421148158252159, "value": ""}}}, {"outValue": 0.5691359838776013, "simIndex": 24.0, "features": {"0": {"effect": 0.031557285094144794, "value": ""}}}, {"outValue": 0.5996070813024518, "simIndex": 16.0, "features": {"0": {"effect": 0.06202838251899523, "value": ""}}}, {"outValue": 0.5659788761724939, "simIndex": 25.0, "features": {"0": {"effect": 0.02840017738903733, "value": ""}}}, {"outValue": 0.6680181345900356, "simIndex": 6.0, "features": {"0": {"effect": 0.13043943580657902, "value": ""}}}, {"outValue": 0.7166023929364149, "simIndex": 3.0, "features": {"0": {"effect": 0.17902369415295838, "value": ""}}}, {"outValue": 0.5257848862124134, "simIndex": 28.0, "features": {"0": {"effect": -0.011793812571043172, "value": ""}}}, {"outValue": 0.5942458622158124, "simIndex": 18.0, "features": {"0": {"effect": 0.056667163432355894, "value": ""}}}, {"outValue": 0.6971757999586085, "simIndex": 5.0, "features": {"0": {"effect": 0.1595971011751519, "value": ""}}}, {"outValue": 0.507157474947663, "simIndex": 32.0, "features": {"0": {"effect": -0.030421223835793598, "value": ""}}}, {"outValue": 0.508772017120345, "simIndex": 30.0, "features": {"0": {"effect": -0.02880668166311151, "value": ""}}}, {"outValue": 0.5765687835932453, "simIndex": 21.0, "features": {"0": {"effect": 0.038990084809788716, "value": ""}}}, {"outValue": 0.5752452615024377, "simIndex": 22.0, "features": {"0": {"effect": 0.03766656271898117, "value": ""}}}, {"outValue": 0.5023266813528147, "simIndex": 33.0, "features": {"0": {"effect": -0.03525201743064188, "value": ""}}}, {"outValue": 0.5485157179873638, "simIndex": 26.0, "features": {"0": {"effect": 0.010937019203907217, "value": ""}}}, {"outValue": 0.6350966525082611, "simIndex": 12.0, "features": {"0": {"effect": 0.09751795372480454, "value": ""}}}, {"outValue": 0.6445182946112169, "simIndex": 11.0, "features": {"0": {"effect": 0.10693959582776036, "value": ""}}}, {"outValue": 0.5424858207394274, "simIndex": 27.0, "features": {"0": {"effect": 0.004907121955970872, "value": ""}}}, {"outValue": 0.6612591457088345, "simIndex": 8.0, "features": {"0": {"effect": 0.12368044692537794, "value": ""}}}, {"outValue": 0.6577784541029462, "simIndex": 9.0, "features": {"0": {"effect": 0.12019975531948968, "value": ""}}}, {"outValue": 0.6078570945726084, "simIndex": 14.0, "features": {"0": {"effect ...
#     document.getElementById('iJPHWTWWEEJSIEN0MFWBL')
#   );
# </script>
# <div id='i6L8T8QSECN8T1HD8COXG'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": 0.5376328610107666, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": 0.5, "simIndex": 17.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 18.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 19.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 16.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 20.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 15.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 21.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 14.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 22.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 13.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 23.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 12.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 24.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 11.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 25.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 10.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 26.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 9.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 27.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 8.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 28.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 7.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 29.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 6.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 30.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 5.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 31.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 4.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 32.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 3.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 33.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 2.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 34.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}, {"outValue": 0.5, "simIndex": 1.0, "features": {"0": {"effect": -0.03763286101076657, "value": ""}}}], "plot_cmap": "RdBu", "ordering_keys": [31, 7, 20, 23, 17, 29, 13, 15, 1, 19, 34, 2, 10, 24, 16, 25, 6, 3, 28, 18, 5, 32, 30, 21, 22, 33, 26, 12, 11, 27, 8, 9, 14, 4], "ordering_keys_time_format": null}),
#     document.getElementById('i6L8T8QSECN8T1HD8COXG')
#   );
# </script>
# <div id='iL2BCWEC37VMOXE82IVLR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": 5.41622273100284e-05, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": -0.0071918068212042385, "simIndex": 31.0, "features": {"0": {"effect": -0.007245969048514267, "value": ""}}}, {"outValue": -0.16214562812908018, "simIndex": 7.0, "features": {"0": {"effect": -0.1621997903563902, "value": ""}}}, {"outValue": -0.08352589621385109, "simIndex": 20.0, "features": {"0": {"effect": -0.08358005844116112, "value": ""}}}, {"outValue": -0.07116431548325663, "simIndex": 23.0, "features": {"0": {"effect": -0.07121847771056666, "value": ""}}}, {"outValue": -0.0955273299480961, "simIndex": 17.0, "features": {"0": {"effect": -0.09558149217540612, "value": ""}}}, {"outValue": -0.021693242576631744, "simIndex": 29.0, "features": {"0": {"effect": -0.021747404803941772, "value": ""}}}, {"outValue": -0.12943882305172183, "simIndex": 13.0, "features": {"0": {"effect": -0.12949298527903186, "value": ""}}}, {"outValue": -0.10230172970095452, "simIndex": 15.0, "features": {"0": {"effect": -0.10235589192826455, "value": ""}}}, {"outValue": -0.23070721179127573, "simIndex": 1.0, "features": {"0": {"effect": -0.23076137401858576, "value": ""}}}, {"outValue": -0.08878410617474186, "simIndex": 19.0, "features": {"0": {"effect": -0.08883826840205189, "value": ""}}}, {"outValue": -0.0005860856169449535, "simIndex": 34.0, "features": {"0": {"effect": -0.0006402478442549819, "value": ""}}}, {"outValue": -0.2255354729097958, "simIndex": 2.0, "features": {"0": {"effect": -0.22558963513710584, "value": ""}}}, {"outValue": -0.15179018036597813, "simIndex": 10.0, "features": {"0": {"effect": -0.15184434259328816, "value": ""}}}, {"outValue": -0.06913598387760134, "simIndex": 24.0, "features": {"0": {"effect": -0.06919014610491137, "value": ""}}}, {"outValue": -0.09960708130245177, "simIndex": 16.0, "features": {"0": {"effect": -0.0996612435297618, "value": ""}}}, {"outValue": -0.06597887617249387, "simIndex": 25.0, "features": {"0": {"effect": -0.0660330383998039, "value": ""}}}, {"outValue": -0.16801813459003556, "simIndex": 6.0, "features": {"0": {"effect": -0.1680722968173456, "value": ""}}}, {"outValue": -0.21660239293641492, "simIndex": 3.0, "features": {"0": {"effect": -0.21665655516372495, "value": ""}}}, {"outValue": -0.02578488621241337, "simIndex": 28.0, "features": {"0": {"effect": -0.0258390484397234, "value": ""}}}, {"outValue": -0.09424586221581244, "simIndex": 18.0, "features": {"0": {"effect": -0.09430002444312247, "value": ""}}}, {"outValue": -0.19717579995860846, "simIndex": 5.0, "features": {"0": {"effect": -0.19722996218591848, "value": ""}}}, {"outValue": -0.007157474947662945, "simIndex": 32.0, "features": {"0": {"effect": -0.0072116371749729735, "value": ""}}}, {"outValue": -0.008772017120345033, "simIndex": 30.0, "features": {"0": {"effect": -0.008826179347655061, "value": ""}}}, {"outValue": -0.07656878359324526, "simIndex": 21.0, "features": {"0": {"effect": -0.07662294582055529, "value": ""}}}, {"outValue": -0.07524526150243771, "simIndex": 22.0, "features": {"0": {"effect": -0.07529942372974774, "value": ""}}}, {"outValue": -0.0023266813528146635, "simIndex": 33.0, "features": {"0": {"effect": -0.002380843580124692, "value": ""}}}, {"outValue": -0.04851571798736376, "simIndex": 26.0, "features": {"0": {"effect": -0.04856988021467379, "value": ""}}}, {"outValue": -0.13509665250826108, "simIndex": 12.0, "features": {"0": {"effect": -0.1351508147355711, "value": ""}}}, {"outValue": -0.1445182946112169, "simIndex": 11.0, "features": {"0": {"effect": -0.14457245683852693, "value": ""}}}, {"outValue": -0.042485820739427416, "simIndex": 27.0, "features": {"0": {"effect": -0.042539982966737444, "value": ""}}}, {"outValue": -0.16125914570883448, "simIndex": 8.0, "features": {"0": {"effect": -0.1613133079361445, "value": ""}}}, {"outValue": -0.15777845410294622, "simIndex": 9.0, "features": {"0": {"effect": -0.15783261 ...
#     document.getElementById('iL2BCWEC37VMOXE82IVLR')
#   );
# </script>

# %% [markdown]
# And for instances, which have an equal prediction:

# %%
ordering = None
for name, shap_values in zip(('A', 'B', 'A vs. B'), (shap_values_a, shap_values_b, shap_values_a_vs_b)):
    shap_values = shap_values[idx_equal]
    plot = shap.plots.force(base_value=shap_values.base_values[0], shap_values=shap_values.values, features=shap_values.display_data, feature_names=shap_values.feature_names, out_names=name, ordering_keys=ordering)
    display(plot)
    if not ordering:
        ordering = get_force_plot_ordering(plot)
# Out:
# <div id='iQIM4XM0WBHF390JLSE25'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0
Index": 166.0, "features": {"0": {"effect": 0.0007993961467001043, "value": ""}}}, {"outValue": -4.080846771614688e-12, "simIndex": 336.0, "features": {"0": {"effect": -5.416223139087517e-05, "value": ""}}}, {"outValue": 0.000249466691274014, "simIndex": 190.0, "features": {"0": {"effect": 0.0001953044639639856, "value": ""}}}, {"outValue": -7.794886425216419e-08, "simIndex": 385.0, "features": {"0": {"effect": -5.424017617428056e-05, "value": ""}}}, {"outValue": 4.822145984184623e-06, "simIndex": 251.0, "features": {"0": {"effect": -4.9340081325843776e-05, "value": ""}}}, {"outValue": 0.003602864451943799, "simIndex": 123.0, "features": {"0": {"effect": 0.0035487022246337707, "value": ""}}}, {"outValue": 0.06637517266746334, "simIndex": 21.0, "features": {"0": {"effect": 0.06632101044015332, "value": ""}}}, {"outValue": 0.0, "simIndex": 290.0, "features": {"0": {"effect": -5.41622273100284e-05, "value": ""}}}, {"outValue": -0.00018097252529958308, "simIndex": 439.0, "features": {"0": {"effect": -0.00023513475260961147, "value": ""}}}, {"outValue": -2.102319429653221e-10, "simIndex": 350.0, "features": {"0": {"effect": -5.4162437541971364e-05, "value": ""}}}, {"outValue": -0.0679151491748693, "simIndex": 497.0, "features": {"0": {"effect": -0.06796931140217932, "value": ""}}}, {"outValue": 2.5102899781082044e-07, "simIndex": 268.0, "features": {"0": {"effect": -5.391119831221758e-05, "value": ""}}}, {"outValue": 0.0, "simIndex": 291.0, "features": {"0": {"effect": -5.41622273100284e-05, "value": ""}}}, {"outValue": -0.0003033042071083347, "simIndex": 441.0, "features": {"0": {"effect": -0.0003574664344183631, "value": ""}}}, {"outValue": 0.00013664305823790635, "simIndex": 207.0, "features": {"0": {"effect": 8.248083092787795e-05, "value": ""}}}, {"outValue": 8.632512928263836e-06, "simIndex": 246.0, "features": {"0": {"effect": -4.552971438176456e-05, "value": ""}}}, {"outValue": -1.1220721014559842e-06, "simIndex": 399.0, "features": {"0": {"effect": -5.528429941148438e-05, "value": ""}}}, {"outValue": 0.00020343380085752205, "simIndex": 192.0, "features": {"0": {"effect": 0.00014927157354749365, "value": ""}}}, {"outValue": 8.899102394355207e-05, "simIndex": 215.0, "features": {"0": {"effect": 3.482879663352367e-05, "value": ""}}}, {"outValue": -4.4033754420 ...

# %% [markdown]
# #### Heatmaps

# %% [markdown]
# SHAP heatmaps provide a way to cluster instances, using the hclust algorithm.

# %% [markdown]
# Classifier A:

# %%
shap.plots.heatmap(shap_values_a, max_display=n_features, feature_order=feature_order)

# %% [markdown]
# Classifier B:

# %%
shap.plots.heatmap(shap_values_b, max_display=n_features, feature_order=feature_order)

# %% [markdown]
# Differences between A and B:

# %%
shap.plots.heatmap(shap_values_a_vs_b, max_display=n_features, feature_order=feature_order)

# %% [markdown]
# #### Decision plots

# %%
shap.plots.decision(shap_values_a.base_values[0], shap_values_a.values, feature_names=feature_names, xlim=(-1, 1))

# %%
shap.plots.decision(shap_values_b.base_values[0], shap_values_b.values, feature_names=feature_names, xlim=(-1, 1))

# %%
shap.plots.decision(shap_values_a_vs_b.base_values[0], shap_values_a_vs_b.values, feature_names=feature_names, xlim=(-1, 1))
