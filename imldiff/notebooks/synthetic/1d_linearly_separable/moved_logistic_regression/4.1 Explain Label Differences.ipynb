# %%
from difference_models import BinaryDifferenceClassifier, MulticlassDifferenceClassifier
import util
from shap.maskers import Independent
from sklearn.utils import resample, shuffle
import shap
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open('classifiers.pickle', 'rb') as f:
    clf_a, clf_b = pickle.load(f)
with open('dataset.pickle', 'rb') as f:
    X, y, feature_names, n_features, n_samples = pickle.load(f)

# %%
try:
    with open('shapvalues.multiclassdiff.pred.pickle', 'rb') as f:
        shap_values = pickle.load(f)
        print('Loaded cached shap values')
except FileNotFoundError:
    print('No cached shap values found')
# Out:
# Loaded cached shap values

# %% [markdown]
# ## Generate Explanations

# %%
diff_clf = MulticlassDifferenceClassifier(clf_a, clf_b)
diff_clf.fit(X, y)
proba_equal = diff_clf.predict_proba(X)

# %% [markdown]
# Now we generate SHAP values for the difference classifier:

# %%
# %%time
predict = util.make_predict_one_hot_encoded_labels(n_classes=len(diff_clf.classes_),
                                                   predict=diff_clf.predict)
background_data = X
masker = Independent(data=background_data, max_samples=100)
explainer = shap.Explainer(predict, masker, feature_names=feature_names)
shap_values = explainer(X)
with open(f'shapvalues.multiclassdiff.pred.pickle', 'wb') as f:
    pickle.dump(shap_values, f, pickle.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 4.85 s, sys: 75.4 ms, total: 4.93 s
# Wall time: 5.11 s

# %% [markdown]
# ## Analyze

# %% [markdown]
# Preparations:

# %%
indices = np.indices(y.shape).ravel()
binary_diff_clf = BinaryDifferenceClassifier(clf_a, clf_b)
binary_diff_clf.fit(X, y)
is_pred_equal = binary_diff_clf.predict(X)
is_pred_diff = ~is_pred_equal

# %%
shap_values_equality = util.reduce_multiclass_proba_diff_shap_values(shap_values)
overall_importance = shap_values_equality.abs.mean(axis=0)
feature_order = np.flip(overall_importance.values.argsort())

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# #### Bar Plots

# %%
shap.plots.bar(overall_importance, max_display=n_features)

# %%
bar_width = 0.25
importances = shap_values.abs.mean(0).values.T
rects = [i * bar_width + np.arange(importances.shape[1]) for i in range(importances.shape[0])]
for class_idx, rect, importance in zip(diff_clf.classes_, rects, importances):
    plt.bar(rect, importance, width=bar_width, edgecolor='white', label=str(diff_clf.class_tuples[class_idx]))
plt.xlabel('feature')
plt.ylabel('mean(|SHAP value|)')
plt.xticks([r + bar_width for r in range(importances.shape[1])], feature_names)
plt.legend()
plt.show()

# %% [markdown]
# #### SHAP Value Distribution

# %%
shap.plots.beeswarm(shap_values_equality, order=feature_order, plot_size=(14, 7))

# %%
for idx_feature, feature in enumerate(feature_names):
    values = shap_values.values[:, idx_feature, :]
    data = np.reshape(np.repeat(shap_values.data[:, idx_feature], len(diff_clf.classes_)), (X.shape[0], len(diff_clf.classes_)))
    base_values = shap_values.base_values[:, idx_feature]
    class_names = [str(class_tuple) for class_tuple in diff_clf.class_tuples]
    shap_values_ = shap.Explanation(values, base_values, data, feature_names=class_names)
    shap.plots.beeswarm(shap_values_, plot_size=(14, 7), show=False)
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### Feature Effects

# %% [markdown]
# #### Partial Dependence Plots

# %% [markdown]
# Plot in blue are the instances where A and B predict the same label, plot over in red are instances where they differ.

# %%
for feature in feature_names:
    shap.plots.scatter(shap_values_equality[:, feature], color=is_pred_diff)

# %%
n_columns = len(diff_clf.classes_)
n_rows = n_features
fig = plt.figure(figsize=(9 * n_columns, 7 * n_rows))
plot_idx = 1
for feature in feature_names:
    ax_ref = None
    for class_idx, class_tuple in enumerate(diff_clf.class_tuples):
        ax = fig.add_subplot(n_rows, n_columns, plot_idx, sharey=ax_ref)
        if not ax_ref:
            ax_ref = ax
        shap.plots.scatter(shap_values[:, feature, class_idx], title=str(class_tuple), ax=ax, color=is_pred_diff, show=False)
        plot_idx += 1
plt.show()

# %% [markdown]
# ### Cluster

# %% [markdown]
# #### Force plots

# %%
shap.plots.force(
    base_value=shap_values_equality.base_values[0],
    shap_values=shap_values_equality.values,
    features=shap_values_equality.data,
    feature_names=feature_names)
# Out:
# <div id='iL3BIMM8CTW7VS15XH886'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.79, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": 1.0, "simIndex": 867.0, "features": {"0": {"effect": 0.2099999999999999, "value": 7.222998187783595}}}, {"outValue": 0.0, "simIndex": 103.0, "features": {"0": {"effect": -0.79, "value": 1.8683709996683522}}}, {"outValue": 1.0, "simIndex": 868.0, "features": {"0": {"effect": 0.2099999999999999, "value": 3.7882574891853755}}}, {"outValue": 1.0, "simIndex": 869.0, "features": {"0": {"effect": 0.2099999999999999, "value": 8.994987005635817}}}, {"outValue": 1.0, "simIndex": 866.0, "features": {"0": {"effect": 0.2099999999999999, "value": 7.53864795813709}}}, {"outValue": 1.0, "simIndex": 472.0, "features": {"0": {"effect": 0.21000000000000002, "value": -0.9168338958650811}}}, {"outValue": 1.0, "simIndex": 870.0, "features": {"0": {"effect": 0.2099999999999999, "value": 3.9625857456924747}}}, {"outValue": 1.0, "simIndex": 471.0, "features": {"0": {"effect": 0.21000000000000002, "value": -0.6967804974127687}}}, {"outValue": 1.0, "simIndex": 470.0, "features": {"0": {"effect": 0.21000000000000002, "value": -0.11801607283782962}}}, {"outValue": 0.0, "simIndex": 104.0, "features": {"0": {"effect": -0.79, "value": 1.7141040881275187}}}, {"outValue": 0.0, "simIndex": 105.0, "features": {"0": {"effect": -0.79, "value": 0.27607517995740033}}}, {"outValue": 1.0, "simIndex": 865.0, "features": {"0": {"effect": 0.2099999999999999, "value": 6.319289739955114}}}, {"outValue": 1.0, "simIndex": 871.0, "features": {"0": {"effect": 0.2099999999999999, "value": 3.0926186807594243}}}, {"outValue": 0.0, "simIndex": 102.0, "features": {"0": {"effect": -0.79, "value": 0.9557214894799925}}}, {"outValue": 0.0, "simIndex": 106.0, "features": {"0": {"effect": -0.79, "value": 1.5382960244317796}}}, {"outValue": 0.0, "simIndex": 101.0, "features": {"0": {"effect": -0.79, "value": 1.0625072730394693}}}, {"outValue": 1.0, "simIndex": 864.0, "features": {"0": {"effect": 0.2099999999999999, "value": 6.043591958920129}}}, {"outValue": 1.0, "simIndex": 473.0, "features": {"0": {"effect": 0.21000000000000002, "value": -0.7087647726143977}}}, {"outValue": 0.0, "simIndex": 107.0, "features": {"0": {"effect": -0.79, "value": 1.3167604837914335}}}, {"outValue": 1.0, "simIndex": 469.0, "features": {"0": {"effect": 0.21000000000000002, "value": -0.8249299697008494}}}, {"outValue": 1.0, "simIndex": 474.0, "features": {"0": {"effect": 0.21000000000000002, "value": -2.248290231371448}}}, {"outValue": 1.0, "simIndex": 872.0, "features": {"0": {"effect": 0.2099999999999999, "value": 2.8247867841109717}}}, {"outValue": 1.0, "simIndex": 863.0, "features": {"0": {"effect": 0.2099999999999999, "value": 3.332501590472513}}}, {"outValue": 1.0, "simIndex": 468.0, "features": {"0": {"effect": 0.21000000000000002, "value": -1.0714140168375152}}}, {"outValue": 1.0, "simIndex": 873.0, "features": {"0": {"effect": 0.2099999999999999, "value": 9.592710062353419}}}, {"outValue": 1.0, "simIndex": 475.0, "features": {"0": {"effect": 0.21000000000000002, "value": -1.6920001807683098}}}, {"outValue": 1.0, "simIndex": 467.0, "features": {"0": {"effect": 0.21000000000000002, "value": -0.13062329791505548}}}, {"outValue": 1.0, "simIndex": 476.0, "features": {"0": {"effect": 0.21000000000000002, "value": -0.5126406678642672}}}, {"outValue": 1.0, "simIndex": 862.0, "features": {"0": {"effect": 0.2099999999999999, "value": 6.46630845209483}}}, {"outValue": 1.0, "simIndex": 874.0, "features": {"0": {"effect": 0.2099999999999999, "value": 5.721765018273684}}}, {"outValue": 0.0, "simIndex": 100.0, "features": {"0": {"effect": -0.79, "value": 0.39367836293348496}}}, {"outValue": 0.0, "simIndex": 108.0, "features": {"0": {"effect": -0.79, "value": 1.5539570261796984}}}, {"outValue": 1.0, "simIndex": 466.0, "features": {"0": {"effect": 0.21000000000000002, "value": -0.9498691607973001}}}, {"outValue": 1.0, "simIndex": 477.0, "feat ...

# %%
for class_idx, class_tuple in enumerate(diff_clf.class_tuples):
    shap_values_ = shap_values[:, :, class_idx]
    plot = shap.plots.force(
        base_value=shap_values_.base_values[0],
        shap_values=shap_values_.values,
        features=shap_values_.data,
        feature_names=feature_names,
        out_names=str(class_tuple))
    display(plot)
# Out:
# <div id='iQQT3BHLQHP6OMP9JCO3F'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(False, False)"], "baseValue": 0.46, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": 0.0, "simIndex": 237.0, "features": {"0": {"effect": -0.46, "value": 7.222998187783595}}}, {"outValue": 0.0, "simIndex": 236.0, "features": {"0": {"effect": -0.46, "value": 1.8683709996683522}}}, {"outValue": 0.0, "simIndex": 235.0, "features": {"0": {"effect": -0.46, "value": 3.7882574891853755}}}, {"outValue": 0.0, "simIndex": 238.0, "features": {"0": {"effect": -0.46, "value": 8.994987005635817}}}, {"outValue": 0.0, "simIndex": 234.0, "features": {"0": {"effect": -0.46, "value": 7.53864795813709}}}, {"outValue": 1.0, "simIndex": 735.0, "features": {"0": {"effect": 0.54, "value": -0.9168338958650811}}}, {"outValue": 0.0, "simIndex": 239.0, "features": {"0": {"effect": -0.46, "value": 3.9625857456924747}}}, {"outValue": 1.0, "simIndex": 736.0, "features": {"0": {"effect": 0.54, "value": -0.6967804974127687}}}, {"outValue": 1.0, "simIndex": 737.0, "features": {"0": {"effect": 0.54, "value": -0.11801607283782962}}}, {"outValue": 0.0, "simIndex": 233.0, "features": {"0": {"effect": -0.46, "value": 1.7141040881275187}}}, {"outValue": 0.0, "simIndex": 240.0, "features": {"0": {"effect": -0.46, "value": 0.27607517995740033}}}, {"outValue": 0.0, "simIndex": 232.0, "features": {"0": {"effect": -0.46, "value": 6.319289739955114}}}, {"outValue": 0.0, "simIndex": 241.0, "features": {"0": {"effect": -0.46, "value": 3.0926186807594243}}}, {"outValue": 0.0, "simIndex": 231.0, "features": {"0": {"effect": -0.46, "value": 0.9557214894799925}}}, {"outValue": 0.0, "simIndex": 242.0, "features": {"0": {"effect": -0.46, "value": 1.5382960244317796}}}, {"outValue": 0.0, "simIndex": 230.0, "features": {"0": {"effect": -0.46, "value": 1.0625072730394693}}}, {"outValue": 0.0, "simIndex": 243.0, "features": {"0": {"effect": -0.46, "value": 6.043591958920129}}}, {"outValue": 1.0, "simIndex": 734.0, "features": {"0": {"effect": 0.54, "value": -0.7087647726143977}}}, {"outValue": 0.0, "simIndex": 229.0, "features": {"0": {"effect": -0.46, "value": 1.3167604837914335}}}, {"outValue": 1.0, "simIndex": 738.0, "features": {"0": {"effect": 0.54, "value": -0.8249299697008494}}}, {"outValue": 1.0, "simIndex": 733.0, "features": {"0": {"effect": 0.54, "value": -2.248290231371448}}}, {"outValue": 0.0, "simIndex": 244.0, "features": {"0": {"effect": -0.46, "value": 2.8247867841109717}}}, {"outValue": 0.0, "simIndex": 228.0, "features": {"0": {"effect": -0.46, "value": 3.332501590472513}}}, {"outValue": 1.0, "simIndex": 739.0, "features": {"0": {"effect": 0.54, "value": -1.0714140168375152}}}, {"outValue": 0.0, "simIndex": 245.0, "features": {"0": {"effect": -0.46, "value": 9.592710062353419}}}, {"outValue": 1.0, "simIndex": 732.0, "features": {"0": {"effect": 0.54, "value": -1.6920001807683098}}}, {"outValue": 1.0, "simIndex": 740.0, "features": {"0": {"effect": 0.54, "value": -0.13062329791505548}}}, {"outValue": 1.0, "simIndex": 731.0, "features": {"0": {"effect": 0.54, "value": -0.5126406678642672}}}, {"outValue": 0.0, "simIndex": 227.0, "features": {"0": {"effect": -0.46, "value": 6.46630845209483}}}, {"outValue": 0.0, "simIndex": 246.0, "features": {"0": {"effect": -0.46, "value": 5.721765018273684}}}, {"outValue": 0.0, "simIndex": 226.0, "features": {"0": {"effect": -0.46, "value": 0.39367836293348496}}}, {"outValue": 0.0, "simIndex": 247.0, "features": {"0": {"effect": -0.46, "value": 1.5539570261796984}}}, {"outValue": 1.0, "simIndex": 741.0, "features": {"0": {"effect": 0.54, "value": -0.9498691607973001}}}, {"outValue": 1.0, "simIndex": 730.0, "features": {"0": {"effect": 0.54, "value": -2.184225106459801}}}, {"outValue": 1.0, "simIndex": 742.0, "features": {"0": {"effect": 0.54, "value": -0.12171470923260874}}}, {"outValue": 0.0, "simIndex": 225.0, "features": {"0": {"effect": -0.46, "value": 0.9449905240453187}}}, {"outValue": 0.0, "simIndex": 248.0, "features": {" ...
# <div id='iX86H71HY289E30YUIF2P'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(False, True)"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": 0.0, "simIndex": 500.0, "features": {"0": {"effect": 0.0, "value": 7.222998187783595}}}, {"outValue": 0.0, "simIndex": 501.0, "features": {"0": {"effect": 0.0, "value": 1.8683709996683522}}}, {"outValue": 0.0, "simIndex": 502.0, "features": {"0": {"effect": 0.0, "value": 3.7882574891853755}}}, {"outValue": 0.0, "simIndex": 499.0, "features": {"0": {"effect": 0.0, "value": 8.994987005635817}}}, {"outValue": 0.0, "simIndex": 503.0, "features": {"0": {"effect": 0.0, "value": 7.53864795813709}}}, {"outValue": 0.0, "simIndex": 498.0, "features": {"0": {"effect": 0.0, "value": -0.9168338958650811}}}, {"outValue": 0.0, "simIndex": 504.0, "features": {"0": {"effect": 0.0, "value": 3.9625857456924747}}}, {"outValue": 0.0, "simIndex": 497.0, "features": {"0": {"effect": 0.0, "value": -0.6967804974127687}}}, {"outValue": 0.0, "simIndex": 505.0, "features": {"0": {"effect": 0.0, "value": -0.11801607283782962}}}, {"outValue": 0.0, "simIndex": 496.0, "features": {"0": {"effect": 0.0, "value": 1.7141040881275187}}}, {"outValue": 0.0, "simIndex": 506.0, "features": {"0": {"effect": 0.0, "value": 0.27607517995740033}}}, {"outValue": 0.0, "simIndex": 495.0, "features": {"0": {"effect": 0.0, "value": 6.319289739955114}}}, {"outValue": 0.0, "simIndex": 507.0, "features": {"0": {"effect": 0.0, "value": 3.0926186807594243}}}, {"outValue": 0.0, "simIndex": 494.0, "features": {"0": {"effect": 0.0, "value": 0.9557214894799925}}}, {"outValue": 0.0, "simIndex": 508.0, "features": {"0": {"effect": 0.0, "value": 1.5382960244317796}}}, {"outValue": 0.0, "simIndex": 493.0, "features": {"0": {"effect": 0.0, "value": 1.0625072730394693}}}, {"outValue": 0.0, "simIndex": 509.0, "features": {"0": {"effect": 0.0, "value": 6.043591958920129}}}, {"outValue": 0.0, "simIndex": 492.0, "features": {"0": {"effect": 0.0, "value": -0.7087647726143977}}}, {"outValue": 0.0, "simIndex": 510.0, "features": {"0": {"effect": 0.0, "value": 1.3167604837914335}}}, {"outValue": 0.0, "simIndex": 491.0, "features": {"0": {"effect": 0.0, "value": -0.8249299697008494}}}, {"outValue": 0.0, "simIndex": 511.0, "features": {"0": {"effect": 0.0, "value": -2.248290231371448}}}, {"outValue": 0.0, "simIndex": 490.0, "features": {"0": {"effect": 0.0, "value": 2.8247867841109717}}}, {"outValue": 0.0, "simIndex": 512.0, "features": {"0": {"effect": 0.0, "value": 3.332501590472513}}}, {"outValue": 0.0, "simIndex": 489.0, "features": {"0": {"effect": 0.0, "value": -1.0714140168375152}}}, {"outValue": 0.0, "simIndex": 513.0, "features": {"0": {"effect": 0.0, "value": 9.592710062353419}}}, {"outValue": 0.0, "simIndex": 488.0, "features": {"0": {"effect": 0.0, "value": -1.6920001807683098}}}, {"outValue": 0.0, "simIndex": 514.0, "features": {"0": {"effect": 0.0, "value": -0.13062329791505548}}}, {"outValue": 0.0, "simIndex": 487.0, "features": {"0": {"effect": 0.0, "value": -0.5126406678642672}}}, {"outValue": 0.0, "simIndex": 515.0, "features": {"0": {"effect": 0.0, "value": 6.46630845209483}}}, {"outValue": 0.0, "simIndex": 486.0, "features": {"0": {"effect": 0.0, "value": 5.721765018273684}}}, {"outValue": 0.0, "simIndex": 516.0, "features": {"0": {"effect": 0.0, "value": 0.39367836293348496}}}, {"outValue": 0.0, "simIndex": 485.0, "features": {"0": {"effect": 0.0, "value": 1.5539570261796984}}}, {"outValue": 0.0, "simIndex": 517.0, "features": {"0": {"effect": 0.0, "value": -0.9498691607973001}}}, {"outValue": 0.0, "simIndex": 484.0, "features": {"0": {"effect": 0.0, "value": -2.184225106459801}}}, {"outValue": 0.0, "simIndex": 518.0, "features": {"0": {"effect": 0.0, "value": -0.12171470923260874}}}, {"outValue": 0.0, "simIndex": 483.0, "features": {"0": {"effect": 0.0, "value": 0.9449905240453187}}}, {"outValue": 0.0, "simIndex": 519.0, "features": {"0": {"effect": 0.0, "value": 5.216757975592843}}}, {"outValue ...
# <div id='iYZJ1MQZ8804HVKIHT1QR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(True, False)"], "baseValue": 0.21, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": 0.0, "simIndex": 604.0, "features": {"0": {"effect": -0.21, "value": 7.222998187783595}}}, {"outValue": 1.0, "simIndex": 103.0, "features": {"0": {"effect": 0.79, "value": 1.8683709996683522}}}, {"outValue": 0.0, "simIndex": 603.0, "features": {"0": {"effect": -0.21, "value": 3.7882574891853755}}}, {"outValue": 0.0, "simIndex": 602.0, "features": {"0": {"effect": -0.21, "value": 8.994987005635817}}}, {"outValue": 0.0, "simIndex": 605.0, "features": {"0": {"effect": -0.21, "value": 7.53864795813709}}}, {"outValue": 0.0, "simIndex": 601.0, "features": {"0": {"effect": -0.21, "value": -0.9168338958650811}}}, {"outValue": 0.0, "simIndex": 606.0, "features": {"0": {"effect": -0.21, "value": 3.9625857456924747}}}, {"outValue": 0.0, "simIndex": 600.0, "features": {"0": {"effect": -0.21, "value": -0.6967804974127687}}}, {"outValue": 0.0, "simIndex": 607.0, "features": {"0": {"effect": -0.21, "value": -0.11801607283782962}}}, {"outValue": 1.0, "simIndex": 104.0, "features": {"0": {"effect": 0.79, "value": 1.7141040881275187}}}, {"outValue": 1.0, "simIndex": 105.0, "features": {"0": {"effect": 0.79, "value": 0.27607517995740033}}}, {"outValue": 0.0, "simIndex": 599.0, "features": {"0": {"effect": -0.21, "value": 6.319289739955114}}}, {"outValue": 0.0, "simIndex": 608.0, "features": {"0": {"effect": -0.21, "value": 3.0926186807594243}}}, {"outValue": 1.0, "simIndex": 102.0, "features": {"0": {"effect": 0.79, "value": 0.9557214894799925}}}, {"outValue": 1.0, "simIndex": 106.0, "features": {"0": {"effect": 0.79, "value": 1.5382960244317796}}}, {"outValue": 1.0, "simIndex": 101.0, "features": {"0": {"effect": 0.79, "value": 1.0625072730394693}}}, {"outValue": 0.0, "simIndex": 598.0, "features": {"0": {"effect": -0.21, "value": 6.043591958920129}}}, {"outValue": 0.0, "simIndex": 609.0, "features": {"0": {"effect": -0.21, "value": -0.7087647726143977}}}, {"outValue": 1.0, "simIndex": 107.0, "features": {"0": {"effect": 0.79, "value": 1.3167604837914335}}}, {"outValue": 0.0, "simIndex": 597.0, "features": {"0": {"effect": -0.21, "value": -0.8249299697008494}}}, {"outValue": 0.0, "simIndex": 610.0, "features": {"0": {"effect": -0.21, "value": -2.248290231371448}}}, {"outValue": 0.0, "simIndex": 596.0, "features": {"0": {"effect": -0.21, "value": 2.8247867841109717}}}, {"outValue": 0.0, "simIndex": 611.0, "features": {"0": {"effect": -0.21, "value": 3.332501590472513}}}, {"outValue": 0.0, "simIndex": 595.0, "features": {"0": {"effect": -0.21, "value": -1.0714140168375152}}}, {"outValue": 0.0, "simIndex": 612.0, "features": {"0": {"effect": -0.21, "value": 9.592710062353419}}}, {"outValue": 0.0, "simIndex": 594.0, "features": {"0": {"effect": -0.21, "value": -1.6920001807683098}}}, {"outValue": 0.0, "simIndex": 613.0, "features": {"0": {"effect": -0.21, "value": -0.13062329791505548}}}, {"outValue": 0.0, "simIndex": 593.0, "features": {"0": {"effect": -0.21, "value": -0.5126406678642672}}}, {"outValue": 0.0, "simIndex": 614.0, "features": {"0": {"effect": -0.21, "value": 6.46630845209483}}}, {"outValue": 0.0, "simIndex": 592.0, "features": {"0": {"effect": -0.21, "value": 5.721765018273684}}}, {"outValue": 1.0, "simIndex": 100.0, "features": {"0": {"effect": 0.79, "value": 0.39367836293348496}}}, {"outValue": 1.0, "simIndex": 108.0, "features": {"0": {"effect": 0.79, "value": 1.5539570261796984}}}, {"outValue": 0.0, "simIndex": 615.0, "features": {"0": {"effect": -0.21, "value": -0.9498691607973001}}}, {"outValue": 0.0, "simIndex": 591.0, "features": {"0": {"effect": -0.21, "value": -2.184225106459801}}}, {"outValue": 0.0, "simIndex": 616.0, "features": {"0": {"effect": -0.21, "value": -0.12171470923260874}}}, {"outValue": 1.0, "simIndex": 99.0, "features": {"0": {"effect": 0.79, "value": 0.9449905240453187}}}, {"outValue": 0.0, "simIndex": 590.0, "features": { ...
# <div id='iEF1AFA4GM6FRXQ12EFW4'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(True, True)"], "baseValue": 0.33, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": 1.0, "simIndex": 134.0, "features": {"0": {"effect": 0.6699999999999999, "value": 7.222998187783595}}}, {"outValue": 0.0, "simIndex": 632.0, "features": {"0": {"effect": -0.33, "value": 1.8683709996683522}}}, {"outValue": 1.0, "simIndex": 133.0, "features": {"0": {"effect": 0.6699999999999999, "value": 3.7882574891853755}}}, {"outValue": 1.0, "simIndex": 132.0, "features": {"0": {"effect": 0.6699999999999999, "value": 8.994987005635817}}}, {"outValue": 1.0, "simIndex": 135.0, "features": {"0": {"effect": 0.6699999999999999, "value": 7.53864795813709}}}, {"outValue": 0.0, "simIndex": 633.0, "features": {"0": {"effect": -0.33, "value": -0.9168338958650811}}}, {"outValue": 1.0, "simIndex": 131.0, "features": {"0": {"effect": 0.6699999999999999, "value": 3.9625857456924747}}}, {"outValue": 0.0, "simIndex": 634.0, "features": {"0": {"effect": -0.33, "value": -0.6967804974127687}}}, {"outValue": 0.0, "simIndex": 631.0, "features": {"0": {"effect": -0.33, "value": -0.11801607283782962}}}, {"outValue": 0.0, "simIndex": 635.0, "features": {"0": {"effect": -0.33, "value": 1.7141040881275187}}}, {"outValue": 0.0, "simIndex": 630.0, "features": {"0": {"effect": -0.33, "value": 0.27607517995740033}}}, {"outValue": 1.0, "simIndex": 136.0, "features": {"0": {"effect": 0.6699999999999999, "value": 6.319289739955114}}}, {"outValue": 1.0, "simIndex": 130.0, "features": {"0": {"effect": 0.6699999999999999, "value": 3.0926186807594243}}}, {"outValue": 0.0, "simIndex": 636.0, "features": {"0": {"effect": -0.33, "value": 0.9557214894799925}}}, {"outValue": 0.0, "simIndex": 629.0, "features": {"0": {"effect": -0.33, "value": 1.5382960244317796}}}, {"outValue": 0.0, "simIndex": 637.0, "features": {"0": {"effect": -0.33, "value": 1.0625072730394693}}}, {"outValue": 1.0, "simIndex": 137.0, "features": {"0": {"effect": 0.6699999999999999, "value": 6.043591958920129}}}, {"outValue": 0.0, "simIndex": 628.0, "features": {"0": {"effect": -0.33, "value": -0.7087647726143977}}}, {"outValue": 0.0, "simIndex": 638.0, "features": {"0": {"effect": -0.33, "value": 1.3167604837914335}}}, {"outValue": 0.0, "simIndex": 627.0, "features": {"0": {"effect": -0.33, "value": -0.8249299697008494}}}, {"outValue": 0.0, "simIndex": 639.0, "features": {"0": {"effect": -0.33, "value": -2.248290231371448}}}, {"outValue": 1.0, "simIndex": 129.0, "features": {"0": {"effect": 0.6699999999999999, "value": 2.8247867841109717}}}, {"outValue": 1.0, "simIndex": 138.0, "features": {"0": {"effect": 0.6699999999999999, "value": 3.332501590472513}}}, {"outValue": 0.0, "simIndex": 626.0, "features": {"0": {"effect": -0.33, "value": -1.0714140168375152}}}, {"outValue": 1.0, "simIndex": 128.0, "features": {"0": {"effect": 0.6699999999999999, "value": 9.592710062353419}}}, {"outValue": 0.0, "simIndex": 640.0, "features": {"0": {"effect": -0.33, "value": -1.6920001807683098}}}, {"outValue": 0.0, "simIndex": 625.0, "features": {"0": {"effect": -0.33, "value": -0.13062329791505548}}}, {"outValue": 0.0, "simIndex": 641.0, "features": {"0": {"effect": -0.33, "value": -0.5126406678642672}}}, {"outValue": 1.0, "simIndex": 139.0, "features": {"0": {"effect": 0.6699999999999999, "value": 6.46630845209483}}}, {"outValue": 1.0, "simIndex": 127.0, "features": {"0": {"effect": 0.6699999999999999, "value": 5.721765018273684}}}, {"outValue": 0.0, "simIndex": 624.0, "features": {"0": {"effect": -0.33, "value": 0.39367836293348496}}}, {"outValue": 0.0, "simIndex": 642.0, "features": {"0": {"effect": -0.33, "value": 1.5539570261796984}}}, {"outValue": 0.0, "simIndex": 623.0, "features": {"0": {"effect": -0.33, "value": -0.9498691607973001}}}, {"outValue": 0.0, "simIndex": 643.0, "features": {"0": {"effect": -0.33, "value": -2.184225106459801}}}, {"outValue": 0.0, "simIndex": 622.0, "features": {"0": {"effect": -0.33, "value": - ...

# %% [markdown]
# #### Heatmaps

# %%
shap.plots.heatmap(shap_values_equality, max_display=n_features, feature_order=feature_order)

# %%
for class_idx, class_tuple in enumerate(diff_clf.class_tuples):
    shap_values_ = shap_values[:, :, class_idx]
    shap.plots.heatmap(shap_values_, max_display=n_features, show=False)
    plt.title(str(class_tuple))
    plt.show()
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %% [markdown]
# #### Decision plots

# %%
shap.plots.decision(shap_values_equality.base_values[0], shap_values_equality.values, feature_names=feature_names)

# %% [markdown]
# We can also visualize the shap values for a single instance with all predicted probabilities for the difference classes:

# %%
def class_labels(row_index):
    return [f'{diff_clf.class_tuples[i]} ({proba_equal[row_index, i].round(2):.2f})' for i in range(len(diff_clf.classes_))]

# %%
def plot_multioutput_decision(row_index):
    shap.multioutput_decision_plot(shap_values.base_values[0, :].tolist(),
                                   [a.T for a in list(shap_values.values.T)],
                                   row_index=row_index,
                                   feature_names=feature_names, 
                                   highlight=[np.argmax(is_pred_equal[row_index])],
                                   legend_labels=class_labels(row_index),
                                   legend_location='lower right')

# %% [markdown]
# The instance with the highest predicted equality probability

# %%
idx_max = np.argmax(shap_values_equality.values[:, 0])
plot_multioutput_decision(idx_max)

# %% [markdown]
# The instance with the lowest predicted equality probability

# %%
idx_min = np.argmin(shap_values_equality.values[:, 0])
plot_multioutput_decision(idx_min)
