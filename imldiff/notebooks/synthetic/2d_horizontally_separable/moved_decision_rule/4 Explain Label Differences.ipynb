# %%
from difference_models import BinaryDifferenceClassifier, MulticlassDifferenceClassifier
from util import get_force_plot_ordering, reduce_multiclass_proba_diff_shap_values
from shap.maskers import Independent
from sklearn.utils import resample, shuffle
import shap
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open('classifiers.pickle', 'rb') as f:
    clf_a, clf_b = pickle.load(f)
with open('dataset.pickle', 'rb') as f:
    X, y, feature_names, n_features, n_samples = pickle.load(f)

# %%
try:
    with open(f'shapvalues.multiclassdiff.pred.pickle', 'rb') as f:
        shap_values = pickle.load(f)
        print('Loaded cached shap values')
except FileNotFoundError:
    print('No cached shap values found')
# Out:
# Loaded cached shap values

# %% [markdown]
# ## Generate Explanations

# %%
diff_clf = MulticlassDifferenceClassifier(clf_a, clf_b)
diff_clf.fit(X, y)
proba_equal = diff_clf.predict_proba(X)

# %% [markdown]
# Now we generate SHAP values for the difference classifier:

# %%
# %%time
background_data = X
masker = Independent(data=background_data, max_samples=100)
explainer = shap.Explainer(diff_clf.predict_proba, masker, feature_names=feature_names)
shap_values = explainer(X)
with open(f'shapvalues.multiclassdiff.pred.pickle', 'wb') as f:
    pickle.dump(shap_values, f, pickle.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 8.45 s, sys: 111 ms, total: 8.56 s
# Wall time: 8.88 s

# %% [markdown]
# ## Analyze

# %% [markdown]
# Preparations:

# %%
indices = np.indices(y.shape).ravel()
binary_diff_clf = BinaryDifferenceClassifier(clf_a, clf_b)
binary_diff_clf.fit(X, y)
is_pred_equal = binary_diff_clf.predict(X)
is_pred_diff = ~is_pred_equal

# %%
shap_values_equality = reduce_multiclass_proba_diff_shap_values(shap_values)
overall_importance = shap_values_equality.abs.mean(axis=0)
feature_order = np.flip(overall_importance.values.argsort())

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# #### Bar Plots

# %%
shap.plots.bar(overall_importance, max_display=n_features)

# %%
bar_width = 0.25
importances = shap_values.abs.mean(0).values.T
rects = [i * bar_width + np.arange(importances.shape[1]) for i in range(importances.shape[0])]
for class_idx, rect, importance in zip(diff_clf.classes_, rects, importances):
    plt.bar(rect, importance, width=bar_width, edgecolor='white', label=str(diff_clf.class_tuples[class_idx]))
plt.xlabel('feature')
plt.ylabel('mean(|SHAP value|)')
plt.xticks([r + bar_width for r in range(importances.shape[1])], feature_names)
plt.legend()
plt.show()

# %% [markdown]
# #### SHAP Value Distribution

# %%
shap.plots.beeswarm(shap_values_equality, order=feature_order, plot_size=(14, 7))

# %%
for idx_feature, feature in enumerate(feature_names):
    values = shap_values.values[:, idx_feature, :]
    data = np.reshape(np.repeat(shap_values.data[:, idx_feature], len(diff_clf.classes_)), (X.shape[0], len(diff_clf.classes_)))
    base_values = shap_values.base_values[:, idx_feature]
    class_names = [str(class_tuple) for class_tuple in diff_clf.class_tuples]
    shap_values_ = shap.Explanation(values, base_values, data, feature_names=class_names)
    shap.plots.beeswarm(shap_values_, plot_size=(14, 7), show=False)
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### Feature Effects

# %% [markdown]
# #### Partial Dependence Plots

# %% [markdown]
# Plot in blue are the instances where A and B predict the same label, plot over in red are instances where they differ.

# %%
for feature in feature_names:
    shap.plots.scatter(shap_values_equality[:, feature], color=is_pred_diff)

# %%
n_columns = len(diff_clf.classes_)
n_rows = n_features
fig = plt.figure(figsize=(9 * n_columns, 7 * n_rows))
plot_idx = 1
for feature in feature_names:
    ax_ref = None
    for class_idx, class_tuple in enumerate(diff_clf.class_tuples):
        ax = fig.add_subplot(n_rows, n_columns, plot_idx, sharey=ax_ref)
        if not ax_ref:
            ax_ref = ax
        shap.plots.scatter(shap_values[:, feature, class_idx], title=str(class_tuple), ax=ax, color=is_pred_diff, show=False)
        plot_idx += 1
plt.show()

# %% [markdown]
# ### Cluster

# %% [markdown]
# #### Force plots

# %%
shap.plots.force(
    base_value=shap_values_equality.base_values[0],
    shap_values=shap_values_equality.values,
    features=shap_values_equality.data,
    feature_names=feature_names)
# Out:
# <div id='iY54QJ4OWBH10SHV4KKBL'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.92, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 1.0, "simIndex": 496.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -1.0}}}, {"outValue": 1.0, "simIndex": 495.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.9310344827586207}}}, {"outValue": 1.0, "simIndex": 494.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.8620689655172413}}}, {"outValue": 1.0, "simIndex": 497.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.7931034482758621}}}, {"outValue": 1.0, "simIndex": 493.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.7241379310344828}}}, {"outValue": 1.0, "simIndex": 498.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.6551724137931034}}}, {"outValue": 1.0, "simIndex": 492.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.5862068965517242}}}, {"outValue": 1.0, "simIndex": 499.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.5172413793103449}}}, {"outValue": 1.0, "simIndex": 491.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.4482758620689655}}}, {"outValue": 1.0, "simIndex": 500.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.3793103448275862}}}, {"outValue": 1.0, "simIndex": 490.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.31034482758620685}}}, {"outValue": 1.0, "simIndex": 501.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.24137931034482762}}}, {"outValue": 1.0, "simIndex": 489.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.1724137931034483}}}, {"outValue": 1.0, "simIndex": 502.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.10344827586206895}}}, {"outValue": 1.0, "simIndex": 488.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": -0.034482758620689724}}}, {"outValue": 1.0, "simIndex": 503.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": 0.034482758620689724}}}, {"outValue": 1.0, "simIndex": 487.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": 0.10344827586206895}}}, {"outValue": 1.0, "simIndex": 504.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": 0.17241379310344818}}}, {"outValue": 1.0, "simIndex": 486.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": 0.24137931034482762}}}, {"outValue": 1.0, "simIndex": 505.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": 0.31034482758620685}}}, {"outValue": 1.0, "simIndex": 485.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": 0.3793103448275863}}}, {"outValue": 1.0, "simIndex": 506.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": 0.4482758620689655}}}, {"outValue": 1.0, "simIndex": 484.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": 0.5172413793103448}}}, {"outValue": 1.0, "simIndex": 507.0, "features": {"0": {"effect": 0.07999999999999996, "value": -1.0}, "1": {"effect": 0.0, "value": 0.5862068965517242}}}, {"outValue": 1.0, "simIndex": 483.0, "features": {"0": {"effect": 0.0799 ...

# %%
for class_idx, class_tuple in enumerate(diff_clf.class_tuples):
    shap_values_ = shap_values[:, :, class_idx]
    plot = shap.plots.force(
        base_value=shap_values_.base_values[0],
        shap_values=shap_values_.values,
        features=shap_values_.data,
        feature_names=feature_names,
        out_names=str(class_tuple))
    display(plot)
# Out:
# <div id='i9SON92Y7VDHM7O571GE3'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(False, False)"], "baseValue": 0.53, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 1.0, "simIndex": 691.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -1.0}}}, {"outValue": 1.0, "simIndex": 690.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.9310344827586207}}}, {"outValue": 1.0, "simIndex": 689.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.8620689655172413}}}, {"outValue": 1.0, "simIndex": 692.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.7931034482758621}}}, {"outValue": 1.0, "simIndex": 688.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.7241379310344828}}}, {"outValue": 1.0, "simIndex": 693.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.6551724137931034}}}, {"outValue": 1.0, "simIndex": 687.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.5862068965517242}}}, {"outValue": 1.0, "simIndex": 694.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.5172413793103449}}}, {"outValue": 1.0, "simIndex": 686.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.4482758620689655}}}, {"outValue": 1.0, "simIndex": 695.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.3793103448275862}}}, {"outValue": 1.0, "simIndex": 685.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.31034482758620685}}}, {"outValue": 1.0, "simIndex": 696.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.24137931034482762}}}, {"outValue": 1.0, "simIndex": 684.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.1724137931034483}}}, {"outValue": 1.0, "simIndex": 697.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.10344827586206895}}}, {"outValue": 1.0, "simIndex": 683.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": -0.034482758620689724}}}, {"outValue": 1.0, "simIndex": 698.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": 0.034482758620689724}}}, {"outValue": 1.0, "simIndex": 682.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": 0.10344827586206895}}}, {"outValue": 1.0, "simIndex": 699.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": 0.17241379310344818}}}, {"outValue": 1.0, "simIndex": 681.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": 0.24137931034482762}}}, {"outValue": 1.0, "simIndex": 700.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": 0.31034482758620685}}}, {"outValue": 1.0, "simIndex": 680.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": 0.3793103448275863}}}, {"outValue": 1.0, "simIndex": 701.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": 0.4482758620689655}}}, {"outValue": 1.0, "simIndex": 679.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": 0.5172413793103448}}}, {"outValue": 1.0, "simIndex": 702.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": 0.5862068965517242}}}, {"outValue": 1.0, "simIndex": 678.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": 0.6551724137931034}}}, {"outValue": 1.0, "simIndex": 703.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": 0.7241379310344827}}}, {"outValue": 1.0, "simIndex": 677.0, "features": {"0": {"effect": 0.47, "value": -1.0}, "1": {"effect": 0.0, "value": 0.7931034482758621}}}, ...
# <div id='iTKQX6BTVPD6X2YCV25G7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(False, True)"], "baseValue": 0.04, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 481.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -1.0}}}, {"outValue": 0.0, "simIndex": 480.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.9310344827586207}}}, {"outValue": 0.0, "simIndex": 479.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.8620689655172413}}}, {"outValue": 0.0, "simIndex": 482.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.7931034482758621}}}, {"outValue": 0.0, "simIndex": 478.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.7241379310344828}}}, {"outValue": 0.0, "simIndex": 483.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.6551724137931034}}}, {"outValue": 0.0, "simIndex": 477.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.5862068965517242}}}, {"outValue": 0.0, "simIndex": 484.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.5172413793103449}}}, {"outValue": 0.0, "simIndex": 476.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.4482758620689655}}}, {"outValue": 0.0, "simIndex": 485.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.3793103448275862}}}, {"outValue": 0.0, "simIndex": 475.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.31034482758620685}}}, {"outValue": 0.0, "simIndex": 486.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.24137931034482762}}}, {"outValue": 0.0, "simIndex": 474.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.1724137931034483}}}, {"outValue": 0.0, "simIndex": 487.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.10344827586206895}}}, {"outValue": 0.0, "simIndex": 473.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.034482758620689724}}}, {"outValue": 0.0, "simIndex": 488.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.034482758620689724}}}, {"outValue": 0.0, "simIndex": 472.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.10344827586206895}}}, {"outValue": 0.0, "simIndex": 489.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.17241379310344818}}}, {"outValue": 0.0, "simIndex": 471.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.24137931034482762}}}, {"outValue": 0.0, "simIndex": 490.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.31034482758620685}}}, {"outValue": 0.0, "simIndex": 470.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.3793103448275863}}}, {"outValue": 0.0, "simIndex": 491.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.4482758620689655}}}, {"outValue": 0.0, "simIndex": 469.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.5172413793103448}}}, {"outValue": 0.0, "simIndex": 492.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.5862068965517242}}}, {"outValue": 0.0, "simIndex": 468.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.6551724137931034}}}, {"outValue": 0.0, "simIndex": 493.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.7241379310344827}}}, {"outValue": 0.0, "simIndex": 467.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "valu ...
# <div id='iMFB3GSQKTYXLQGX1QHJ9'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(True, False)"], "baseValue": 0.04, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 466.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -1.0}}}, {"outValue": 0.0, "simIndex": 465.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.9310344827586207}}}, {"outValue": 0.0, "simIndex": 464.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.8620689655172413}}}, {"outValue": 0.0, "simIndex": 467.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.7931034482758621}}}, {"outValue": 0.0, "simIndex": 463.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.7241379310344828}}}, {"outValue": 0.0, "simIndex": 468.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.6551724137931034}}}, {"outValue": 0.0, "simIndex": 462.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.5862068965517242}}}, {"outValue": 0.0, "simIndex": 469.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.5172413793103449}}}, {"outValue": 0.0, "simIndex": 461.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.4482758620689655}}}, {"outValue": 0.0, "simIndex": 470.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.3793103448275862}}}, {"outValue": 0.0, "simIndex": 460.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.31034482758620685}}}, {"outValue": 0.0, "simIndex": 471.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.24137931034482762}}}, {"outValue": 0.0, "simIndex": 459.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.1724137931034483}}}, {"outValue": 0.0, "simIndex": 472.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.10344827586206895}}}, {"outValue": 0.0, "simIndex": 458.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": -0.034482758620689724}}}, {"outValue": 0.0, "simIndex": 473.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.034482758620689724}}}, {"outValue": 0.0, "simIndex": 457.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.10344827586206895}}}, {"outValue": 0.0, "simIndex": 474.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.17241379310344818}}}, {"outValue": 0.0, "simIndex": 456.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.24137931034482762}}}, {"outValue": 0.0, "simIndex": 475.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.31034482758620685}}}, {"outValue": 0.0, "simIndex": 455.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.3793103448275863}}}, {"outValue": 0.0, "simIndex": 476.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.4482758620689655}}}, {"outValue": 0.0, "simIndex": 454.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.5172413793103448}}}, {"outValue": 0.0, "simIndex": 477.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.5862068965517242}}}, {"outValue": 0.0, "simIndex": 453.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.6551724137931034}}}, {"outValue": 0.0, "simIndex": 478.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "value": 0.7241379310344827}}}, {"outValue": 0.0, "simIndex": 452.0, "features": {"0": {"effect": -0.04, "value": -1.0}, "1": {"effect": 0.0, "valu ...
# <div id='i1GUPMLSZMRBHXYTUK4TM'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(True, True)"], "baseValue": 0.39, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 646.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -1.0}}}, {"outValue": 0.0, "simIndex": 645.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.9310344827586207}}}, {"outValue": 0.0, "simIndex": 644.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.8620689655172413}}}, {"outValue": 0.0, "simIndex": 647.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.7931034482758621}}}, {"outValue": 0.0, "simIndex": 643.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.7241379310344828}}}, {"outValue": 0.0, "simIndex": 648.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.6551724137931034}}}, {"outValue": 0.0, "simIndex": 642.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.5862068965517242}}}, {"outValue": 0.0, "simIndex": 649.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.5172413793103449}}}, {"outValue": 0.0, "simIndex": 641.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.4482758620689655}}}, {"outValue": 0.0, "simIndex": 650.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.3793103448275862}}}, {"outValue": 0.0, "simIndex": 640.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.31034482758620685}}}, {"outValue": 0.0, "simIndex": 651.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.24137931034482762}}}, {"outValue": 0.0, "simIndex": 639.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.1724137931034483}}}, {"outValue": 0.0, "simIndex": 652.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.10344827586206895}}}, {"outValue": 0.0, "simIndex": 638.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": -0.034482758620689724}}}, {"outValue": 0.0, "simIndex": 653.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": 0.034482758620689724}}}, {"outValue": 0.0, "simIndex": 637.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": 0.10344827586206895}}}, {"outValue": 0.0, "simIndex": 654.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": 0.17241379310344818}}}, {"outValue": 0.0, "simIndex": 636.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": 0.24137931034482762}}}, {"outValue": 0.0, "simIndex": 655.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": 0.31034482758620685}}}, {"outValue": 0.0, "simIndex": 635.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": 0.3793103448275863}}}, {"outValue": 0.0, "simIndex": 656.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": 0.4482758620689655}}}, {"outValue": 0.0, "simIndex": 634.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": 0.5172413793103448}}}, {"outValue": 0.0, "simIndex": 657.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": 0.5862068965517242}}}, {"outValue": 0.0, "simIndex": 633.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": 0.6551724137931034}}}, {"outValue": 0.0, "simIndex": 658.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value": 0.7241379310344827}}}, {"outValue": 0.0, "simIndex": 632.0, "features": {"0": {"effect": -0.39, "value": -1.0}, "1": {"effect": 0.0, "value ...

# %% [markdown]
# #### Heatmaps

# %%
shap.plots.heatmap(shap_values_equality, max_display=n_features, feature_order=feature_order)

# %%
for class_idx, class_tuple in enumerate(diff_clf.class_tuples):
    shap_values_ = shap_values[:, :, class_idx]
    shap.plots.heatmap(shap_values_, max_display=n_features, show=False)
    plt.title(str(class_tuple))
    plt.show()

# %% [markdown]
# #### Decision plots

# %%
shap.plots.decision(shap_values_equality.base_values[0], shap_values_equality.values, feature_names=feature_names)

# %% [markdown]
# We can also visualize the individual shap values per difference class for a single instance, and we select the instance with the highest shap value

# %%
def class_labels(row_index):
    return [f'{diff_clf.class_tuples[i]} ({proba_equal[row_index, i].round(2):.2f})' for i in range(len(diff_clf.classes_))]

# %%
def plot_multioutput_decision(row_index):
    shap.multioutput_decision_plot(shap_values.base_values[0, :].tolist(),
                                   [a.T for a in list(shap_values.values.T)],
                                   row_index=row_index,
                                   feature_names=feature_names, 
                                   highlight=[np.argmax(is_pred_equal[row_index])],
                                   legend_labels=class_labels(row_index),
                                   legend_location='lower right')

# %%
for class_idx in diff_clf.classes_:
    idx_max = np.argmax(shap_values.values[:, 0, class_idx])
    plot_multioutput_decision(idx_max)
