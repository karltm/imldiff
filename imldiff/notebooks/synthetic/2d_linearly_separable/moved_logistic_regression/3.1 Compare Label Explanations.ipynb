# %%
import plot
from scipy.special import logit
from shap.maskers import Independent
from sklearn.utils import resample, shuffle
import shap
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open('classifiers.pickle', 'rb') as f:
    clf_a, clf_b = pickle.load(f)
with open('predictions.pickle', 'rb') as f:
    X, feature_names, n_features, n_samples, indices, pred_a, pred_b, proba_a, proba_b, log_proba_a, log_proba_b, log_odds_a, log_odds_b = pickle.load(f)

# %%
try:
    with open(f'shapvalues.soa.pred.pickle', 'rb') as f:
        shap_values_a, shap_values_b, shap_values_a_vs_b, feature_order = pickle.load(f)
        print('Loaded cached shap values')
except FileNotFoundError:
    print('No cached shap values found')
# Out:
# No cached shap values found

# %% [markdown]
# ## Generate Explanations

# %% [markdown]
# Now we define the functions to be explained:

# %%
predict_pred_a = lambda X: clf_a.predict(X)
predict_pred_b = lambda X: clf_b.predict(X)

# %% [markdown]
# And now we calculate SHAP values for each function:

# %%
# %%time

background_data = X
def explain(predict):
    masker = Independent(data=background_data, max_samples=100)
    explainer = shap.Explainer(predict, masker, feature_names=feature_names)
    shap_values = explainer(X)
    return shap_values

shap_values_a = explain(predict_pred_a)
shap_values_b = explain(predict_pred_b)

shap_values_a_vs_b = shap_values_b - shap_values_a
shap_values_a_vs_b.data = shap_values_a.data

feature_order = np.flip(shap_values_a_vs_b.abs.mean(axis=0).values.argsort())

with open(f'shapvalues.soa.pred.pickle', 'wb') as f:
    pickle.dump((shap_values_a, shap_values_b, shap_values_a_vs_b, feature_order), f, pickle.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 5.24 s, sys: 76.1 ms, total: 5.32 s
# Wall time: 5.5 s

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# We estimate it with the mean absolute SHAP value (which is the default for this plot) and will also sort features subsequently in this order

# %%
shap.plots.bar(shap_values_a, order=feature_order, max_display=n_features)
shap.plots.bar(shap_values_b, order=feature_order, max_display=n_features)
shap.plots.bar(shap_values_a_vs_b, order=feature_order, max_display=n_features)

# %% [markdown]
# ### SHAP Value Distribution

# %%
plot.shap_beeswarm(shap_values_a, 'A', order=feature_order, max_display=n_features)

# %%
plot.shap_beeswarm(shap_values_b, 'B', order=feature_order, max_display=n_features)

# %%
plot.shap_beeswarm(shap_values_a_vs_b, 'A vs. B', order=feature_order, max_display=n_features)

# %% [markdown]
# ### Features' Partial Dependence Plots

# %%
n_columns = 3
n_rows = n_features
fig = plt.figure(figsize=(9*n_columns, 7*n_rows))
i = 1
for feature in feature_names:
    ax1 = fig.add_subplot(n_rows, n_columns, i)
    ax2 = fig.add_subplot(n_rows, n_columns, i+1, sharey=ax1)
    ax3 = fig.add_subplot(n_rows, n_columns, i+2, sharey=None)
    shap.plots.scatter(shap_values_a[:, feature], title='A', ax=ax1, color='blue', show=False)
    shap.plots.scatter(shap_values_a[pred_a != pred_b, feature], title='A', ax=ax1, color='red',  hist=False, show=False)
    shap.plots.scatter(shap_values_b[:, feature], title='B', ax=ax2, color='blue', dot_size=16, show=False)
    shap.plots.scatter(shap_values_b[pred_a != pred_b, feature], title='B', ax=ax2, color='red', hist=False, show=False)
    shap.plots.scatter(shap_values_a_vs_b[:, feature], title='B - A', ax=ax3, color='blue', show=False)
    shap.plots.scatter(shap_values_a_vs_b[pred_a != pred_b, feature], title='B - A', ax=ax3, color='red', hist=False, show=False)
    i += n_columns
plt.show()

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %%
idx_diff = indices[pred_a != pred_b]
idx_equal = indices[pred_a == pred_b]
if len(idx_diff) > 500:
    idx_diff = shuffle(idx_diff, random_state=0, n_samples=500)
if len(idx_equal) > 500:
    idx_equal = shuffle(idx_equal, random_state=0, n_samples=500)

# %%
order = plot.shap_force(shap_values_a_vs_b[idx_diff], 'A vs. B')
plot.shap_force(shap_values_a[idx_diff], 'A', ordering=order)
plot.shap_force(shap_values_b[idx_diff], 'B', ordering=order);
# Out:
# <div id='iAHYTTPLNCWH2P6OFCGDH'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": 0.14000000000000007, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -1.0, "simIndex": 125.0, "features": {"0": {"effect": -0.5750000000000001, "value": ""}, "1": {"effect": -0.5650000000000001, "value": ""}}}, {"outValue": -1.0, "simIndex": 56.0, "features": {"0": {"effect": -0.5450000000000002, "value": ""}, "1": {"effect": -0.595, "value": ""}}}, {"outValue": -1.0, "simIndex": 6.0, "features": {"0": {"effect": -0.485, "value": ""}, "1": {"effect": -0.655, "value": ""}}}, {"outValue": 1.0, "simIndex": 250.0, "features": {"0": {"effect": 0.45999999999999996, "value": ""}, "1": {"effect": 0.39999999999999997, "value": ""}}}, {"outValue": 1.0, "simIndex": 320.0, "features": {"0": {"effect": 0.495, "value": ""}, "1": {"effect": 0.365, "value": ""}}}, {"outValue": 1.0, "simIndex": 252.0, "features": {"0": {"effect": 0.45999999999999996, "value": ""}, "1": {"effect": 0.3999999999999999, "value": ""}}}, {"outValue": -1.0, "simIndex": 50.0, "features": {"0": {"effect": -0.54, "value": ""}, "1": {"effect": -0.6000000000000001, "value": ""}}}, {"outValue": -1.0, "simIndex": 139.0, "features": {"0": {"effect": -0.5800000000000001, "value": ""}, "1": {"effect": -0.56, "value": ""}}}, {"outValue": -1.0, "simIndex": 175.0, "features": {"0": {"effect": -0.6, "value": ""}, "1": {"effect": -0.54, "value": ""}}}, {"outValue": -1.0, "simIndex": 117.0, "features": {"0": {"effect": -0.57, "value": ""}, "1": {"effect": -0.5700000000000001, "value": ""}}}, {"outValue": -1.0, "simIndex": 169.0, "features": {"0": {"effect": -0.6000000000000001, "value": ""}, "1": {"effect": -0.54, "value": ""}}}, {"outValue": 1.0, "simIndex": 362.0, "features": {"0": {"effect": 0.5399999999999999, "value": ""}, "1": {"effect": 0.31999999999999995, "value": ""}}}, {"outValue": -1.0, "simIndex": 111.0, "features": {"0": {"effect": -0.5700000000000001, "value": ""}, "1": {"effect": -0.5700000000000001, "value": ""}}}, {"outValue": -1.0, "simIndex": 152.0, "features": {"0": {"effect": -0.5900000000000001, "value": ""}, "1": {"effect": -0.55, "value": ""}}}, {"outValue": -1.0, "simIndex": 180.0, "features": {"0": {"effect": -0.6150000000000001, "value": ""}, "1": {"effect": -0.525, "value": ""}}}, {"outValue": -1.0, "simIndex": 126.0, "features": {"0": {"effect": -0.5750000000000001, "value": ""}, "1": {"effect": -0.5650000000000001, "value": ""}}}, {"outValue": -1.0, "simIndex": 159.0, "features": {"0": {"effect": -0.5950000000000001, "value": ""}, "1": {"effect": -0.545, "value": ""}}}, {"outValue": 1.0, "simIndex": 321.0, "features": {"0": {"effect": 0.495, "value": ""}, "1": {"effect": 0.365, "value": ""}}}, {"outValue": -1.0, "simIndex": 83.0, "features": {"0": {"effect": -0.555, "value": ""}, "1": {"effect": -0.5850000000000001, "value": ""}}}, {"outValue": 1.0, "simIndex": 348.0, "features": {"0": {"effect": 0.5149999999999999, "value": ""}, "1": {"effect": 0.3449999999999999, "value": ""}}}, {"outValue": 1.0, "simIndex": 278.0, "features": {"0": {"effect": 0.48, "value": ""}, "1": {"effect": 0.3799999999999999, "value": ""}}}, {"outValue": 1.0000000000000002, "simIndex": 370.0, "features": {"0": {"effect": 0.555, "value": ""}, "1": {"effect": 0.305, "value": ""}}}, {"outValue": 1.0, "simIndex": 314.0, "features": {"0": {"effect": 0.48999999999999994, "value": ""}, "1": {"effect": 0.37, "value": ""}}}, {"outValue": -1.0, "simIndex": 74.0, "features": {"0": {"effect": -0.5550000000000002, "value": ""}, "1": {"effect": -0.585, "value": ""}}}, {"outValue": 1.0, "simIndex": 342.0, "features": {"0": {"effect": 0.51, "value": ""}, "1": {"effect": 0.35, "value": ""}}}, {"outValue": 1.0, "simIndex": 214.0, "features": {"0": {"effect": 0.4149999999999999, "value": ""}, "1": {"effect": 0.44499999999999995, "value": ""}}}, {"outValue": -1.0, "simIndex": 151.0, "features": {"0": {"effect": -0.5900000000000001, "value": ""}, "1": {"effect": -0. ...
# <div id='i8J6TBIQ9MZMB3HQ5K3Q9'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0.41, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 1.0, "simIndex": 119.0, "features": {"0": {"effect": -0.04499999999999996, "value": ""}, "1": {"effect": 0.635, "value": ""}}}, {"outValue": 1.0, "simIndex": 152.0, "features": {"0": {"effect": -0.03499999999999995, "value": ""}, "1": {"effect": 0.625, "value": ""}}}, {"outValue": 1.0, "simIndex": 142.0, "features": {"0": {"effect": -0.03999999999999995, "value": ""}, "1": {"effect": 0.63, "value": ""}}}, {"outValue": 0.0, "simIndex": 224.0, "features": {"0": {"effect": -0.03999999999999998, "value": ""}, "1": {"effect": -0.37, "value": ""}}}, {"outValue": -5.551115123125783e-17, "simIndex": 294.0, "features": {"0": {"effect": -0.004999999999999977, "value": ""}, "1": {"effect": -0.405, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 345.0, "features": {"0": {"effect": 0.035, "value": ""}, "1": {"effect": -0.44499999999999995, "value": ""}}}, {"outValue": 1.0, "simIndex": 9.0, "features": {"0": {"effect": -0.10499999999999995, "value": ""}, "1": {"effect": 0.6950000000000001, "value": ""}}}, {"outValue": 1.0, "simIndex": 52.0, "features": {"0": {"effect": -0.06999999999999995, "value": ""}, "1": {"effect": 0.66, "value": ""}}}, {"outValue": 1.0, "simIndex": 20.0, "features": {"0": {"effect": -0.08999999999999996, "value": ""}, "1": {"effect": 0.68, "value": ""}}}, {"outValue": 1.0, "simIndex": 167.0, "features": {"0": {"effect": -0.005000000000000032, "value": ""}, "1": {"effect": 0.595, "value": ""}}}, {"outValue": 1.0, "simIndex": 118.0, "features": {"0": {"effect": -0.04499999999999996, "value": ""}, "1": {"effect": 0.635, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 213.0, "features": {"0": {"effect": -0.07499999999999998, "value": ""}, "1": {"effect": -0.33499999999999996, "value": ""}}}, {"outValue": 1.0, "simIndex": 12.0, "features": {"0": {"effect": -0.09499999999999996, "value": ""}, "1": {"effect": 0.685, "value": ""}}}, {"outValue": 1.0, "simIndex": 94.0, "features": {"0": {"effect": -0.04999999999999996, "value": ""}, "1": {"effect": 0.64, "value": ""}}}, {"outValue": 1.0, "simIndex": 78.0, "features": {"0": {"effect": -0.05999999999999997, "value": ""}, "1": {"effect": 0.65, "value": ""}}}, {"outValue": 1.0, "simIndex": 65.0, "features": {"0": {"effect": -0.06499999999999995, "value": ""}, "1": {"effect": 0.655, "value": ""}}}, {"outValue": 1.0, "simIndex": 77.0, "features": {"0": {"effect": -0.05999999999999997, "value": ""}, "1": {"effect": 0.65, "value": ""}}}, {"outValue": -5.551115123125783e-17, "simIndex": 236.0, "features": {"0": {"effect": -0.03, "value": ""}, "1": {"effect": -0.38, "value": ""}}}, {"outValue": 1.0, "simIndex": 21.0, "features": {"0": {"effect": -0.08999999999999996, "value": ""}, "1": {"effect": 0.68, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 337.0, "features": {"0": {"effect": 0.03, "value": ""}, "1": {"effect": -0.43999999999999995, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 349.0, "features": {"0": {"effect": 0.04000000000000001, "value": ""}, "1": {"effect": -0.44999999999999996, "value": ""}}}, {"outValue": -5.551115123125783e-17, "simIndex": 275.0, "features": {"0": {"effect": -0.014999999999999986, "value": ""}, "1": {"effect": -0.395, "value": ""}}}, {"outValue": 0.0, "simIndex": 205.0, "features": {"0": {"effect": -0.10499999999999998, "value": ""}, "1": {"effect": -0.305, "value": ""}}}, {"outValue": 1.0, "simIndex": 151.0, "features": {"0": {"effect": -0.03499999999999995, "value": ""}, "1": {"effect": 0.625, "value": ""}}}, {"outValue": -5.551115123125783e-17, "simIndex": 276.0, "features": {"0": {"effect": -0.014999999999999986, "value": ""}, "1": {"effect": -0.395, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 363.0, "features": {"0": {"effect": 0.06500000000000003, "value": ""}, "1": {"effect": -0.47 ...
# <div id='iYZOZWA93L8OAHIWPQVU7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": 0.55, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 94.0, "features": {"0": {"effect": -0.62, "value": ""}, "1": {"effect": 0.06999999999999998, "value": ""}}}, {"outValue": 0.0, "simIndex": 145.0, "features": {"0": {"effect": -0.5800000000000001, "value": ""}, "1": {"effect": 0.029999999999999978, "value": ""}}}, {"outValue": 1.1102230246251565e-16, "simIndex": 171.0, "features": {"0": {"effect": -0.5249999999999999, "value": ""}, "1": {"effect": -0.025000000000000022, "value": ""}}}, {"outValue": 1.0, "simIndex": 216.0, "features": {"0": {"effect": 0.42, "value": ""}, "1": {"effect": 0.02999999999999997, "value": ""}}}, {"outValue": 1.0, "simIndex": 328.0, "features": {"0": {"effect": 0.49, "value": ""}, "1": {"effect": -0.040000000000000036, "value": ""}}}, {"outValue": 1.0, "simIndex": 341.0, "features": {"0": {"effect": 0.495, "value": ""}, "1": {"effect": -0.04500000000000004, "value": ""}}}, {"outValue": 0.0, "simIndex": 43.0, "features": {"0": {"effect": -0.645, "value": ""}, "1": {"effect": 0.09499999999999997, "value": ""}}}, {"outValue": 0.0, "simIndex": 32.0, "features": {"0": {"effect": -0.65, "value": ""}, "1": {"effect": 0.09999999999999998, "value": ""}}}, {"outValue": 0.0, "simIndex": 5.0, "features": {"0": {"effect": -0.69, "value": ""}, "1": {"effect": 0.13999999999999996, "value": ""}}}, {"outValue": 0.0, "simIndex": 150.0, "features": {"0": {"effect": -0.575, "value": ""}, "1": {"effect": 0.024999999999999967, "value": ""}}}, {"outValue": 0.0, "simIndex": 44.0, "features": {"0": {"effect": -0.645, "value": ""}, "1": {"effect": 0.09499999999999997, "value": ""}}}, {"outValue": 1.0, "simIndex": 253.0, "features": {"0": {"effect": 0.46499999999999997, "value": ""}, "1": {"effect": -0.015000000000000013, "value": ""}}}, {"outValue": 0.0, "simIndex": 17.0, "features": {"0": {"effect": -0.665, "value": ""}, "1": {"effect": 0.11499999999999999, "value": ""}}}, {"outValue": 0.0, "simIndex": 63.0, "features": {"0": {"effect": -0.64, "value": ""}, "1": {"effect": 0.08999999999999997, "value": ""}}}, {"outValue": 0.0, "simIndex": 8.0, "features": {"0": {"effect": -0.675, "value": ""}, "1": {"effect": 0.125, "value": ""}}}, {"outValue": 0.0, "simIndex": 64.0, "features": {"0": {"effect": -0.64, "value": ""}, "1": {"effect": 0.08999999999999997, "value": ""}}}, {"outValue": 0.0, "simIndex": 29.0, "features": {"0": {"effect": -0.655, "value": ""}, "1": {"effect": 0.10499999999999998, "value": ""}}}, {"outValue": 1.0, "simIndex": 252.0, "features": {"0": {"effect": 0.46499999999999997, "value": ""}, "1": {"effect": -0.015000000000000013, "value": ""}}}, {"outValue": 0.0, "simIndex": 45.0, "features": {"0": {"effect": -0.645, "value": ""}, "1": {"effect": 0.09499999999999997, "value": ""}}}, {"outValue": 1.0, "simIndex": 377.0, "features": {"0": {"effect": 0.5449999999999999, "value": ""}, "1": {"effect": -0.09500000000000003, "value": ""}}}, {"outValue": 1.0, "simIndex": 365.0, "features": {"0": {"effect": 0.52, "value": ""}, "1": {"effect": -0.07000000000000006, "value": ""}}}, {"outValue": 1.0, "simIndex": 374.0, "features": {"0": {"effect": 0.54, "value": ""}, "1": {"effect": -0.09000000000000002, "value": ""}}}, {"outValue": 1.0, "simIndex": 206.0, "features": {"0": {"effect": 0.38499999999999995, "value": ""}, "1": {"effect": 0.065, "value": ""}}}, {"outValue": 0.0, "simIndex": 128.0, "features": {"0": {"effect": -0.5900000000000001, "value": ""}, "1": {"effect": 0.03999999999999998, "value": ""}}}, {"outValue": 1.0, "simIndex": 342.0, "features": {"0": {"effect": 0.495, "value": ""}, "1": {"effect": -0.04500000000000004, "value": ""}}}, {"outValue": 1.0, "simIndex": 313.0, "features": {"0": {"effect": 0.48, "value": ""}, "1": {"effect": -0.030000000000000027, "value": ""}}}, {"outValue": 0.0, "simIndex": 77.0, "features": {"0": {"effect": -0.635, "value": ""}, "1": {"ef ...

# %%
order = plot.shap_force(shap_values_a_vs_b[idx_equal], 'A vs. B')
plot.shap_force(shap_values_a[idx_equal], 'A', ordering=order)
plot.shap_force(shap_values_b[idx_equal], 'B', ordering=order);
# Out:
# <div id='iRT8FQKJVY8Y2483Z3BU8'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": 0.14000000000000007, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 16.0, "features": {"0": {"effect": -0.455, "value": ""}, "1": {"effect": 0.31499999999999995, "value": ""}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 245.0, "features": {"0": {"effect": -0.08000000000000007, "value": ""}, "1": {"effect": -0.060000000000000026, "value": ""}}}, {"outValue": 0.0, "simIndex": 181.0, "features": {"0": {"effect": -0.31500000000000006, "value": ""}, "1": {"effect": 0.175, "value": ""}}}, {"outValue": 0.0, "simIndex": 127.0, "features": {"0": {"effect": -0.385, "value": ""}, "1": {"effect": 0.24499999999999994, "value": ""}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 116.0, "features": {"0": {"effect": -0.39, "value": ""}, "1": {"effect": 0.24999999999999997, "value": ""}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 117.0, "features": {"0": {"effect": -0.39, "value": ""}, "1": {"effect": 0.24999999999999997, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 394.0, "features": {"0": {"effect": 0.30999999999999994, "value": ""}, "1": {"effect": -0.44999999999999996, "value": ""}}}, {"outValue": 0.0, "simIndex": 278.0, "features": {"0": {"effect": 0.024999999999999967, "value": ""}, "1": {"effect": -0.16500000000000004, "value": ""}}}, {"outValue": -8.326672684688674e-17, "simIndex": 253.0, "features": {"0": {"effect": -0.04000000000000006, "value": ""}, "1": {"effect": -0.10000000000000009, "value": ""}}}, {"outValue": -5.551115123125783e-17, "simIndex": 234.0, "features": {"0": {"effect": -0.1250000000000001, "value": ""}, "1": {"effect": -0.015000000000000013, "value": ""}}}, {"outValue": 8.326672684688674e-17, "simIndex": 298.0, "features": {"0": {"effect": 0.07000000000000009, "value": ""}, "1": {"effect": -0.21000000000000008, "value": ""}}}, {"outValue": 0.0, "simIndex": 178.0, "features": {"0": {"effect": -0.32000000000000006, "value": ""}, "1": {"effect": 0.18, "value": ""}}}, {"outValue": -5.551115123125783e-17, "simIndex": 6.0, "features": {"0": {"effect": -0.4650000000000001, "value": ""}, "1": {"effect": 0.32499999999999996, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 413.0, "features": {"0": {"effect": 0.33000000000000007, "value": ""}, "1": {"effect": -0.4700000000000001, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 136.0, "features": {"0": {"effect": -0.375, "value": ""}, "1": {"effect": 0.235, "value": ""}}}, {"outValue": 1.1102230246251565e-16, "simIndex": 302.0, "features": {"0": {"effect": 0.07999999999999996, "value": ""}, "1": {"effect": -0.21999999999999992, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 433.0, "features": {"0": {"effect": 0.3550000000000001, "value": ""}, "1": {"effect": -0.4950000000000001, "value": ""}}}, {"outValue": -1.1102230246251565e-16, "simIndex": 395.0, "features": {"0": {"effect": 0.3149999999999999, "value": ""}, "1": {"effect": -0.45500000000000007, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 366.0, "features": {"0": {"effect": 0.25, "value": ""}, "1": {"effect": -0.39, "value": ""}}}, {"outValue": 0.0, "simIndex": 97.0, "features": {"0": {"effect": -0.4, "value": ""}, "1": {"effect": 0.25999999999999995, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 196.0, "features": {"0": {"effect": -0.275, "value": ""}, "1": {"effect": 0.135, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 324.0, "features": {"0": {"effect": 0.135, "value": ""}, "1": {"effect": -0.275, "value": ""}}}, {"outValue": -1.1102230246251565e-16, "simIndex": 485.0, "features": {"0": {"effect": 0.39499999999999996, "value": ""}, "1": {"effect": -0.5350000000000001, "value": ""}}}, {"outValue": 0.0, "simIndex": 471.0, "features": {"0": {"effect": 0.37999999999999995, "value": ""}, "1": {"effect": -0.52, "value": ""}}}, {"outVal ...
# <div id='iURD7HBRX0LX6R9F7CXBN'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0.41, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 79.0, "features": {"0": {"effect": -0.044999999999999984, "value": ""}, "1": {"effect": -0.365, "value": ""}}}, {"outValue": -5.551115123125783e-17, "simIndex": 238.0, "features": {"0": {"effect": -0.48, "value": ""}, "1": {"effect": 0.06999999999999998, "value": ""}}}, {"outValue": -5.551115123125783e-17, "simIndex": 211.0, "features": {"0": {"effect": -0.155, "value": ""}, "1": {"effect": -0.255, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 146.0, "features": {"0": {"effect": -0.06999999999999998, "value": ""}, "1": {"effect": -0.33999999999999997, "value": ""}}}, {"outValue": 0.0, "simIndex": 184.0, "features": {"0": {"effect": -0.08999999999999998, "value": ""}, "1": {"effect": -0.32, "value": ""}}}, {"outValue": 0.0, "simIndex": 185.0, "features": {"0": {"effect": -0.08999999999999998, "value": ""}, "1": {"effect": -0.32, "value": ""}}}, {"outValue": 1.0, "simIndex": 422.0, "features": {"0": {"effect": 0.12, "value": ""}, "1": {"effect": 0.47, "value": ""}}}, {"outValue": 1.0, "simIndex": 483.0, "features": {"0": {"effect": 0.435, "value": ""}, "1": {"effect": 0.15500000000000003, "value": ""}}}, {"outValue": 1.0, "simIndex": 248.0, "features": {"0": {"effect": -0.03499999999999995, "value": ""}, "1": {"effect": 0.625, "value": ""}}}, {"outValue": 1.0, "simIndex": 497.0, "features": {"0": {"effect": 0.5900000000000001, "value": ""}, "1": {"effect": 0.0, "value": ""}}}, {"outValue": 0.9999999999999998, "simIndex": 344.0, "features": {"0": {"effect": 0.014999999999999958, "value": ""}, "1": {"effect": 0.575, "value": ""}}}, {"outValue": -5.551115123125783e-17, "simIndex": 222.0, "features": {"0": {"effect": -0.22, "value": ""}, "1": {"effect": -0.19, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 145.0, "features": {"0": {"effect": -0.06999999999999998, "value": ""}, "1": {"effect": -0.33999999999999997, "value": ""}}}, {"outValue": 1.0, "simIndex": 413.0, "features": {"0": {"effect": 0.10499999999999998, "value": ""}, "1": {"effect": 0.485, "value": ""}}}, {"outValue": -5.551115123125783e-17, "simIndex": 39.0, "features": {"0": {"effect": -0.03, "value": ""}, "1": {"effect": -0.38, "value": ""}}}, {"outValue": 0.9999999999999998, "simIndex": 369.0, "features": {"0": {"effect": 0.034999999999999976, "value": ""}, "1": {"effect": 0.5549999999999999, "value": ""}}}, {"outValue": 1.0, "simIndex": 400.0, "features": {"0": {"effect": 0.07999999999999999, "value": ""}, "1": {"effect": 0.51, "value": ""}}}, {"outValue": 1.0, "simIndex": 313.0, "features": {"0": {"effect": -0.009999999999999953, "value": ""}, "1": {"effect": 0.6000000000000001, "value": ""}}}, {"outValue": 1.0, "simIndex": 450.0, "features": {"0": {"effect": 0.19999999999999996, "value": ""}, "1": {"effect": 0.39, "value": ""}}}, {"outValue": 5.551115123125783e-17, "simIndex": 135.0, "features": {"0": {"effect": -0.06499999999999997, "value": ""}, "1": {"effect": -0.345, "value": ""}}}, {"outValue": -5.551115123125783e-17, "simIndex": 19.0, "features": {"0": {"effect": -0.024999999999999994, "value": ""}, "1": {"effect": -0.385, "value": ""}}}, {"outValue": 1.0, "simIndex": 439.0, "features": {"0": {"effect": 0.15499999999999997, "value": ""}, "1": {"effect": 0.435, "value": ""}}}, {"outValue": 1.0, "simIndex": 349.0, "features": {"0": {"effect": 0.020000000000000073, "value": ""}, "1": {"effect": 0.5700000000000001, "value": ""}}}, {"outValue": 1.0, "simIndex": 304.0, "features": {"0": {"effect": -0.014999999999999958, "value": ""}, "1": {"effect": 0.605, "value": ""}}}, {"outValue": 0.0, "simIndex": 98.0, "features": {"0": {"effect": -0.04999999999999999, "value": ""}, "1": {"effect": -0.36, "value": ""}}}, {"outValue": -5.551115123125783e-17, "simIndex": 20.0, "features": {"0": {"effect": -0.024999999999999994, "value": ""}, "1":  ...
# <div id='iCV1JED6YO8639A41F6G7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": 0.55, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 67.0, "features": {"0": {"effect": -0.5, "value": ""}, "1": {"effect": -0.05000000000000004, "value": ""}}}, {"outValue": 0.0, "simIndex": 3.0, "features": {"0": {"effect": -0.56, "value": ""}, "1": {"effect": 0.009999999999999953, "value": ""}}}, {"outValue": 0.0, "simIndex": 104.0, "features": {"0": {"effect": -0.47000000000000003, "value": ""}, "1": {"effect": -0.08000000000000002, "value": ""}}}, {"outValue": 0.0, "simIndex": 130.0, "features": {"0": {"effect": -0.455, "value": ""}, "1": {"effect": -0.09500000000000003, "value": ""}}}, {"outValue": 0.0, "simIndex": 89.0, "features": {"0": {"effect": -0.48, "value": ""}, "1": {"effect": -0.07000000000000003, "value": ""}}}, {"outValue": 0.0, "simIndex": 88.0, "features": {"0": {"effect": -0.48, "value": ""}, "1": {"effect": -0.07000000000000003, "value": ""}}}, {"outValue": 1.0, "simIndex": 318.0, "features": {"0": {"effect": 0.42999999999999994, "value": ""}, "1": {"effect": 0.020000000000000018, "value": ""}}}, {"outValue": 1.0, "simIndex": 264.0, "features": {"0": {"effect": 0.45999999999999996, "value": ""}, "1": {"effect": -0.010000000000000009, "value": ""}}}, {"outValue": 1.0, "simIndex": 495.0, "features": {"0": {"effect": -0.07500000000000001, "value": ""}, "1": {"effect": 0.5249999999999999, "value": ""}}}, {"outValue": 1.0, "simIndex": 245.0, "features": {"0": {"effect": 0.46499999999999997, "value": ""}, "1": {"effect": -0.015000000000000013, "value": ""}}}, {"outValue": 1.0, "simIndex": 460.0, "features": {"0": {"effect": 0.08500000000000005, "value": ""}, "1": {"effect": 0.3649999999999999, "value": ""}}}, {"outValue": 0.0, "simIndex": 8.0, "features": {"0": {"effect": -0.54, "value": ""}, "1": {"effect": -0.010000000000000009, "value": ""}}}, {"outValue": 0.0, "simIndex": 18.0, "features": {"0": {"effect": -0.535, "value": ""}, "1": {"effect": -0.015000000000000013, "value": ""}}}, {"outValue": 1.0, "simIndex": 310.0, "features": {"0": {"effect": 0.43500000000000005, "value": ""}, "1": {"effect": 0.014999999999999902, "value": ""}}}, {"outValue": 0.0, "simIndex": 175.0, "features": {"0": {"effect": -0.405, "value": ""}, "1": {"effect": -0.14500000000000002, "value": ""}}}, {"outValue": 1.0, "simIndex": 454.0, "features": {"0": {"effect": 0.11499999999999994, "value": ""}, "1": {"effect": 0.335, "value": ""}}}, {"outValue": 1.0, "simIndex": 309.0, "features": {"0": {"effect": 0.43500000000000005, "value": ""}, "1": {"effect": 0.014999999999999902, "value": ""}}}, {"outValue": 1.0, "simIndex": 426.0, "features": {"0": {"effect": 0.30499999999999994, "value": ""}, "1": {"effect": 0.14500000000000002, "value": ""}}}, {"outValue": 1.0, "simIndex": 283.0, "features": {"0": {"effect": 0.44999999999999996, "value": ""}, "1": {"effect": 0.0, "value": ""}}}, {"outValue": 0.0, "simIndex": 115.0, "features": {"0": {"effect": -0.465, "value": ""}, "1": {"effect": -0.08500000000000002, "value": ""}}}, {"outValue": 0.0, "simIndex": 219.0, "features": {"0": {"effect": -0.3, "value": ""}, "1": {"effect": -0.25, "value": ""}}}, {"outValue": 1.0, "simIndex": 429.0, "features": {"0": {"effect": 0.29, "value": ""}, "1": {"effect": 0.15999999999999998, "value": ""}}}, {"outValue": 1.0, "simIndex": 333.0, "features": {"0": {"effect": 0.41500000000000004, "value": ""}, "1": {"effect": 0.03499999999999992, "value": ""}}}, {"outValue": 1.0, "simIndex": 391.0, "features": {"0": {"effect": 0.365, "value": ""}, "1": {"effect": 0.08499999999999996, "value": ""}}}, {"outValue": 0.0, "simIndex": 87.0, "features": {"0": {"effect": -0.48, "value": ""}, "1": {"effect": -0.07000000000000003, "value": ""}}}, {"outValue": 0.0, "simIndex": 229.0, "features": {"0": {"effect": -0.195, "value": ""}, "1": {"effect": -0.35500000000000004, "value": ""}}}, {"outValue": 0.0, "simIndex": 238.0, "features": {"0 ...

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %%
plot.shap_heatmap(shap_values_a[idx_equal], 'A', feature_order)
plot.shap_heatmap(shap_values_b[idx_equal], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[idx_equal], 'A vs. B', feature_order)

# %%
plot.shap_heatmap(shap_values_a[idx_diff], 'A', feature_order)
plot.shap_heatmap(shap_values_b[idx_diff], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[idx_diff], 'A vs. B', feature_order)
