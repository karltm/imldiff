# %%
import plot
from scipy.special import logit
from shap.maskers import Independent
from sklearn.utils import resample, shuffle
import shap
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open('classifiers.pickle', 'rb') as f:
    clf_a, clf_b = pickle.load(f)
with open('predictions.pickle', 'rb') as f:
    X, display_data, feature_names, n_features, n_samples, indices, pred_a, pred_b, proba_a, proba_b, log_proba_a, log_proba_b, log_odds_a, log_odds_b = pickle.load(f)

# Sample
X, display_data, pred_a, pred_b, proba_a, proba_b, log_proba_a, log_proba_b, log_odds_a, log_odds_b = \
    shuffle(X, display_data, pred_a, pred_b, proba_a, proba_b, log_proba_a, log_proba_b, log_odds_a, log_odds_b, random_state=42, n_samples=500)
n_samples = X.shape[0]
indices = np.array(range(n_samples))

# %%
np.sum(pred_a != pred_b)
# Out:
# 37

# %%
try:
    with open(f'shapvalues.soa.proba.pickle', 'rb') as f:
        shap_values_a, shap_values_b, shap_values_a_vs_b, feature_order = pickle.load(f)
        print('Loaded cached shap values')
except FileNotFoundError:
    print('No cached shap values found')
# Out:
# Loaded cached shap values

# %% [markdown]
# ## Generate Explanations

# %% [markdown]
# Now we define the functions to be explained:

# %%
predict_proba_a = lambda X: clf_a.predict_proba(X)[:, 1]
predict_proba_b = lambda X: clf_b.predict_proba(X)[:, 1]

# %% [markdown]
# And now we calculate SHAP values for each function:

# %%
# %%time

background_data = X
def explain(predict):
    masker = Independent(data=background_data, max_samples=100)
    explainer = shap.Explainer(predict, masker, feature_names=feature_names)
    shap_values = explainer(X)
    shap_values.display_data = display_data
    return shap_values

shap_values_a = explain(predict_proba_a)
shap_values_b = explain(predict_proba_b)

shap_values_a_vs_b = shap_values_b - shap_values_a
shap_values_a_vs_b.data = shap_values_a.data
shap_values_a_vs_b.display_data = shap_values_a.display_data

feature_order = np.flip(shap_values_a_vs_b.abs.mean(axis=0).values.argsort())

with open(f'shapvalues.soa.proba.pickle', 'wb') as f:
    pickle.dump((shap_values_a, shap_values_b, shap_values_a_vs_b, feature_order), f, pickle.HIGHEST_PROTOCOL)
# Out:
# Permutation explainer: 501it [00:22, 12.43it/s]
# Permutation explainer: 501it [00:23, 12.48it/s]
# CPU times: user 58.8 s, sys: 5.07 s, total: 1min 3s
# Wall time: 45.8 s

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# We estimate it with the mean absolute SHAP value (which is the default for this plot) and will also sort features subsequently in this order

# %%
shap.plots.bar(shap_values_a, order=feature_order, max_display=n_features)
shap.plots.bar(shap_values_b, max_display=n_features)
shap.plots.bar(shap_values_a_vs_b, order=feature_order, max_display=n_features)

# %% [markdown]
# ### SHAP Value Distribution

# %%
shap.plots.beeswarm(shap_values_a, order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_a[pred_a != pred_b], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %%
shap.plots.beeswarm(shap_values_b, order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_b[pred_a != pred_b], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %%
shap.plots.beeswarm(shap_values_a_vs_b, order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_a_vs_b[pred_a != pred_b], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %% [markdown]
# ### Features' Partial Dependence Plots

# %%
n_columns = 3
n_rows = n_features
fig = plt.figure(figsize=(9*n_columns, 7*n_rows))
i = 1
for feature in feature_names[feature_order]:
    ax1 = fig.add_subplot(n_rows, n_columns, i)
    ax2 = fig.add_subplot(n_rows, n_columns, i+1, sharey=ax1)
    ax3 = fig.add_subplot(n_rows, n_columns, i+2, sharey=None)
    shap.plots.scatter(shap_values_a[:, feature], title='A', ax=ax1, color='blue', show=False)
    shap.plots.scatter(shap_values_a[pred_a != pred_b, feature], title='A', ax=ax1, color='red', hist=False, show=False)
    shap.plots.scatter(shap_values_b[:, feature], title='B', ax=ax2, color='blue', show=False)
    shap.plots.scatter(shap_values_b[pred_a != pred_b, feature], title='B', ax=ax2, color='red', hist=False, show=False)
    shap.plots.scatter(shap_values_a_vs_b[:, feature], title='B - A', ax=ax3, color='blue', show=False)
    shap.plots.scatter(shap_values_a_vs_b[pred_a != pred_b, feature], title='B - A', ax=ax3, color='red', hist=False, show=False)
    i += n_columns
plt.show()
# Out:
# Passing the fontdict parameter of _set_ticklabels() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %%
mask = pred_a != pred_b
order = plot.shap_force(shap_values_a_vs_b[mask], 'A vs. B')
plot.shap_force(shap_values_a[mask], 'A', ordering=order)
plot.shap_force(shap_values_b[mask], 'B', ordering=order);
# Out:
# <div id='iHVAI7SSA9CR5RNYATBHT'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": 0.019579723760457413, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.19819963286213543, "simIndex": 26.0, "features": {"0": {"effect": 0.049325498235595844, "value": 50.0}, "1": {"effect": 0.002138090932312758, "value": " Private"}, "2": {"effect": 0.025423229503696562, "value": 9.0}, "3": {"effect": 0.01136538269723069, "value": " Married-civ-spouse"}, "4": {"effect": -0.0006508973511853249, "value": " Craft-repair"}, "5": {"effect": -0.009170402741789013, "value": " Husband"}, "6": {"effect": -0.00239886603707129, "value": " White"}, "7": {"effect": 0.005946665846600804, "value": " Male"}, "8": {"effect": 0.07899533355527133, "value": 3103.0}, "9": {"effect": 0.0066350563378301565, "value": 0.0}, "10": {"effect": 0.010907942652187221, "value": 40.0}, "11": {"effect": 0.00010287547099830746, "value": " United-States"}}}, {"outValue": 0.6168832964309185, "simIndex": 37.0, "features": {"0": {"effect": 0.021551613328688504, "value": 53.0}, "1": {"effect": -0.007105981268937588, "value": " Private"}, "2": {"effect": 0.194163896201102, "value": 3.0}, "3": {"effect": 0.023081298830521874, "value": " Married-civ-spouse"}, "4": {"effect": 0.004728423566083297, "value": " Craft-repair"}, "5": {"effect": 0.11659892815363988, "value": " Husband"}, "6": {"effect": -0.004034479205770719, "value": " Other"}, "7": {"effect": 0.003443665105479214, "value": " Male"}, "8": {"effect": 0.23198200073386868, "value": 5178.0}, "9": {"effect": 0.003979846498378547, "value": 0.0}, "10": {"effect": 0.022428102016956983, "value": 40.0}, "11": {"effect": -0.013513741289549666, "value": " Puerto-Rico"}}}, {"outValue": -0.6549074412428177, "simIndex": 1.0, "features": {"0": {"effect": -0.004117738701722468, "value": 46.0}, "1": {"effect": 0.002493546249187673, "value": " Private"}, "2": {"effect": 0.006693226530569748, "value": 10.0}, "3": {"effect": -0.08020683464349637, "value": " Divorced"}, "4": {"effect": -0.048597074532574044, "value": " Transport-moving"}, "5": {"effect": -0.12965439914422494, "value": " Own-child"}, "6": {"effect": -0.004405346042169267, "value": " White"}, "7": {"effect": -0.021865350424046578, "value": " Male"}, "8": {"effect": -0.3512371103398112, "value": 3325.0}, "9": {"effect": 0.005364291304947708, "value": 0.0}, "10": {"effect": -0.04862895799480002, "value": 55.0}, "11": {"effect": -0.00032541726513535913, "value": " United-States"}}}, {"outValue": 0.13178053912259682, "simIndex": 27.0, "features": {"0": {"effect": 0.07612163613758752, "value": 37.0}, "1": {"effect": 0.0008610212370855014, "value": " Private"}, "2": {"effect": -0.023061741482439266, "value": 13.0}, "3": {"effect": 0.005902683354225205, "value": " Married-civ-spouse"}, "4": {"effect": -0.006759569551687683, "value": " Craft-repair"}, "5": {"effect": 0.018923356337989528, "value": " Husband"}, "6": {"effect": 0.015691070831721797, "value": " Asian-Pac-Islander"}, "7": {"effect": -0.006061278819777947, "value": " Male"}, "8": {"effect": 0.019884476226116048, "value": 0.0}, "9": {"effect": 0.004765136864043926, "value": 0.0}, "10": {"effect": -0.0009748187614484916, "value": 40.0}, "11": {"effect": 0.006908842988723275, "value": " Cambodia"}}}, {"outValue": -0.40193331845912716, "simIndex": 9.0, "features": {"0": {"effect": -0.02655351028780601, "value": 51.0}, "1": {"effect": -0.023342599935121458, "value": " Self-emp-not-inc"}, "2": {"effect": 0.008663592133182161, "value": 10.0}, "3": {"effect": -0.0007182751869437183, "value": " Married-civ-spouse"}, "4": {"effect": -0.11051557308757536, "value": " Farming-fishing"}, "5": {"effect": -0.039132335272020397, "value": " Husband"}, "6": {"effect": -0.003710422277254636, "value": " White"}, "7": {"effect": -0.015415049404862855,  ...
# <div id='iMLRYAIZM1K0I3SE7MBGY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0.2705533692666495, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.48991959979243604, "simIndex": 3.0, "features": {"0": {"effect": 0.06385553207624581, "value": 50.0}, "1": {"effect": -0.001969830518262889, "value": " Private"}, "2": {"effect": -0.09733200558289762, "value": 9.0}, "3": {"effect": 0.00610096785811808, "value": " Married-civ-spouse"}, "4": {"effect": -0.010187865147081358, "value": " Craft-repair"}, "5": {"effect": 0.11726612835586853, "value": " Husband"}, "6": {"effect": 0.004497297799495586, "value": " White"}, "7": {"effect": 0.027281607139997523, "value": " Male"}, "8": {"effect": 0.13374352048177673, "value": 3103.0}, "9": {"effect": -0.013778366886360848, "value": 0.0}, "10": {"effect": -0.010512447176606932, "value": 40.0}, "11": {"effect": 0.00040169212549394834, "value": " United-States"}}}, {"outValue": 0.18522189193883257, "simIndex": 1.0, "features": {"0": {"effect": 0.04922080843663057, "value": 53.0}, "1": {"effect": -0.0014075868957784661, "value": " Private"}, "2": {"effect": -0.3485190999350577, "value": 3.0}, "3": {"effect": 0.004399955465460914, "value": " Married-civ-spouse"}, "4": {"effect": -0.006855281083184502, "value": " Craft-repair"}, "5": {"effect": 0.06855246317775111, "value": " Husband"}, "6": {"effect": -0.007878613304046824, "value": " Other"}, "7": {"effect": 0.016420956638753252, "value": " Male"}, "8": {"effect": 0.15911095436080938, "value": 5178.0}, "9": {"effect": -0.010327071132105356, "value": 0.0}, "10": {"effect": -0.007194930611492258, "value": 40.0}, "11": {"effect": -0.0008540324455570511, "value": " Puerto-Rico"}}}, {"outValue": 0.6779660885326899, "simIndex": 5.0, "features": {"0": {"effect": 0.037427267822901844, "value": 46.0}, "1": {"effect": -0.0018101957606441548, "value": " Private"}, "2": {"effect": -0.02210405641550119, "value": 10.0}, "3": {"effect": 0.08245311488305263, "value": " Divorced"}, "4": {"effect": 0.023195004680843814, "value": " Transport-moving"}, "5": {"effect": 0.03463642614855561, "value": " Own-child"}, "6": {"effect": 0.004642237324361291, "value": " White"}, "7": {"effect": 0.02762878869878124, "value": " Male"}, "8": {"effect": 0.14608433779656266, "value": 3325.0}, "9": {"effect": -0.013199581458562057, "value": 0.0}, "10": {"effect": 0.08797151696306978, "value": 55.0}, "11": {"effect": 0.00048785858261892373, "value": " United-States"}}}, {"outValue": 0.41014691773317713, "simIndex": 29.0, "features": {"0": {"effect": -0.013664354067568754, "value": 37.0}, "1": {"effect": -0.0020227832751372682, "value": " Private"}, "2": {"effect": 0.1416601102258609, "value": 13.0}, "3": {"effect": 0.005720029244409798, "value": " Married-civ-spouse"}, "4": {"effect": -0.008764545767475616, "value": " Craft-repair"}, "5": {"effect": 0.10638264521005786, "value": " Husband"}, "6": {"effect": -0.03734978821938809, "value": " Asian-Pac-Islander"}, "7": {"effect": 0.0285114471755923, "value": " Male"}, "8": {"effect": -0.04588364927016204, "value": 0.0}, "9": {"effect": -0.01436250313827493, "value": 0.0}, "10": {"effect": -0.011658291715474426, "value": 40.0}, "11": {"effect": -0.008974767935912155, "value": " Cambodia"}}}, {"outValue": 0.5995126129022577, "simIndex": 6.0, "features": {"0": {"effect": 0.07572997396336191, "value": 51.0}, "1": {"effect": -0.01970440177357846, "value": " Self-emp-not-inc"}, "2": {"effect": -0.030860338955062842, "value": 10.0}, "3": {"effect": 0.008530205783856258, "value": " Married-civ-spouse"}, "4": {"effect": -0.003529266435772483, "value": " Farming-fishing"}, "5": {"effect": 0.11680287849410059, "value": " Husband"}, "6": {"effect": 0.004258877388303235, "value": " White"}, "7": {"effect": 0.030094791187788166, "value": " Male"}, "8":  ...
# <div id='iHDYBAE2OB9EE5OB8VB1D'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": 0.29013309302710694, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.6881192326545715, "simIndex": 36.0, "features": {"0": {"effect": 0.11318103031184165, "value": 50.0}, "1": {"effect": 0.0001682604140498688, "value": " Private"}, "2": {"effect": -0.07190877607920106, "value": 9.0}, "3": {"effect": 0.01746635055534877, "value": " Married-civ-spouse"}, "4": {"effect": -0.010838762498266683, "value": " Craft-repair"}, "5": {"effect": 0.10809572561407951, "value": " Husband"}, "6": {"effect": 0.002098431762424296, "value": " White"}, "7": {"effect": 0.03322827298659833, "value": " Male"}, "8": {"effect": 0.21273885403704806, "value": 3103.0}, "9": {"effect": -0.007143310548530691, "value": 0.0}, "10": {"effect": 0.00039549547558029, "value": 40.0}, "11": {"effect": 0.0005045675964922558, "value": " United-States"}}}, {"outValue": 0.802105188369751, "simIndex": 35.0, "features": {"0": {"effect": 0.07077242176531907, "value": 53.0}, "1": {"effect": -0.008513568164716054, "value": " Private"}, "2": {"effect": -0.1543552037339557, "value": 3.0}, "3": {"effect": 0.027481254295982787, "value": " Married-civ-spouse"}, "4": {"effect": -0.002126857517101205, "value": " Craft-repair"}, "5": {"effect": 0.185151391331391, "value": " Husband"}, "6": {"effect": -0.011913092509817542, "value": " Other"}, "7": {"effect": 0.019864621744232466, "value": " Male"}, "8": {"effect": 0.39109295509467806, "value": 5178.0}, "9": {"effect": -0.006347224633726809, "value": 0.0}, "10": {"effect": 0.015233171405464723, "value": 40.0}, "11": {"effect": -0.014367773735106717, "value": " Puerto-Rico"}}}, {"outValue": 0.02305864728987217, "simIndex": 3.0, "features": {"0": {"effect": 0.033309529121179376, "value": 46.0}, "1": {"effect": 0.0006833504885435181, "value": " Private"}, "2": {"effect": -0.015410829884931442, "value": 10.0}, "3": {"effect": 0.0022462802395562505, "value": " Divorced"}, "4": {"effect": -0.025402069851730227, "value": " Transport-moving"}, "5": {"effect": -0.09501797299566934, "value": " Own-child"}, "6": {"effect": 0.00023689128219202328, "value": " White"}, "7": {"effect": 0.0057634382747346604, "value": " Male"}, "8": {"effect": -0.20515277254324854, "value": 3325.0}, "9": {"effect": -0.007835290153614349, "value": 0.0}, "10": {"effect": 0.039342558968269756, "value": 55.0}, "11": {"effect": 0.00016244131748356457, "value": " United-States"}}}, {"outValue": 0.5419274568557739, "simIndex": 25.0, "features": {"0": {"effect": 0.06245728207001876, "value": 37.0}, "1": {"effect": -0.0011617620380517668, "value": " Private"}, "2": {"effect": 0.11859836874342163, "value": 13.0}, "3": {"effect": 0.011622712598635003, "value": " Married-civ-spouse"}, "4": {"effect": -0.0155241153191633, "value": " Craft-repair"}, "5": {"effect": 0.12530600154804739, "value": " Husband"}, "6": {"effect": -0.021658717387666296, "value": " Asian-Pac-Islander"}, "7": {"effect": 0.022450168355814353, "value": " Male"}, "8": {"effect": -0.02599917304404599, "value": 0.0}, "9": {"effect": -0.009597366274231004, "value": 0.0}, "10": {"effect": -0.012633110476922917, "value": 40.0}, "11": {"effect": -0.0020659249471888796, "value": " Cambodia"}}}, {"outValue": 0.1975792944431305, "simIndex": 8.0, "features": {"0": {"effect": 0.0491764636755559, "value": 51.0}, "1": {"effect": -0.04304700170869992, "value": " Self-emp-not-inc"}, "2": {"effect": -0.02219674682188068, "value": 10.0}, "3": {"effect": 0.00781193059691254, "value": " Married-civ-spouse"}, "4": {"effect": -0.11404483952334783, "value": " Farming-fishing"}, "5": {"effect": 0.0776705432220802, "value": " Husband"}, "6": {"effect": 0.0005484551110485995, "value": " White"}, "7": {"effect": 0.014679741782925311, "value": " Male"}, "8": { ...

# %%
idx_pred_eq = resample(indices[pred_a == pred_b], n_samples=100, replace=False, random_state=2)
order = plot.shap_force(shap_values_a_vs_b[idx_pred_eq], 'A vs. B')
plot.shap_force(shap_values_a[idx_pred_eq], 'A', ordering=order)
plot.shap_force(shap_values_b[idx_pred_eq], 'B', ordering=order);
# Out:
# <div id='iJPF7X2IJBEGQCPE8UF8D'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": 0.019579723760457413, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.028425609061444326, "simIndex": 66.0, "features": {"0": {"effect": 0.008123620515372508, "value": 33.0}, "1": {"effect": 0.0003007429701624285, "value": " Private"}, "2": {"effect": -0.0014338124760873705, "value": 7.0}, "3": {"effect": 0.012712385265864058, "value": " Never-married"}, "4": {"effect": -0.0020739062282010175, "value": " Craft-repair"}, "5": {"effect": 0.03456828690715395, "value": " Not-in-family"}, "6": {"effect": -0.0015626056800508313, "value": " White"}, "7": {"effect": -0.0029280582805134223, "value": " Male"}, "8": {"effect": -0.02000247622075467, "value": 0.0}, "9": {"effect": 0.0007337866416040287, "value": 0.0}, "10": {"effect": -0.019623351378154734, "value": 65.0}, "11": {"effect": 3.127326459197937e-05, "value": " United-States"}}}, {"outValue": 0.022186718379886446, "simIndex": 57.0, "features": {"0": {"effect": 0.013138474327427858, "value": 36.0}, "1": {"effect": 0.001043931875099918, "value": " Private"}, "2": {"effect": -0.001052875291580855, "value": 10.0}, "3": {"effect": -0.032593232566699284, "value": " Divorced"}, "4": {"effect": 0.009495796792800115, "value": " Prof-specialty"}, "5": {"effect": 0.02903238255176241, "value": " Not-in-family"}, "6": {"effect": -0.001489031848036587, "value": " White"}, "7": {"effect": -0.0014518071804069579, "value": " Male"}, "8": {"effect": -0.0068936519718982014, "value": 0.0}, "9": {"effect": 0.0009023140430874932, "value": 0.0}, "10": {"effect": -0.007648961084912162, "value": 40.0}, "11": {"effect": 0.00012365497278528522, "value": " United-States"}}}, {"outValue": -0.02431810569390254, "simIndex": 54.0, "features": {"0": {"effect": 0.011702093415296582, "value": 36.0}, "1": {"effect": -0.006618205783806222, "value": " Local-gov"}, "2": {"effect": 0.011433402609136698, "value": 10.0}, "3": {"effect": -0.03663688042024696, "value": " Divorced"}, "4": {"effect": -0.0021620981580845293, "value": " Adm-clerical"}, "5": {"effect": -0.018691698616684557, "value": " Unmarried"}, "6": {"effect": -0.00125755404041212, "value": " White"}, "7": {"effect": 0.008083186641606243, "value": " Female"}, "8": {"effect": -0.014059387140656555, "value": 0.0}, "9": {"effect": 0.0016906071053053098, "value": 0.0}, "10": {"effect": 0.0026825973316548235, "value": 35.0}, "11": {"effect": -6.389239746866698e-05, "value": " United-States"}}}, {"outValue": 0.16417356190426607, "simIndex": 99.0, "features": {"0": {"effect": -0.021991862358427233, "value": 29.0}, "1": {"effect": 0.0005553560856081216, "value": " Private"}, "2": {"effect": 0.025794022020056873, "value": 9.0}, "3": {"effect": 0.008228792118106835, "value": " Married-civ-spouse"}, "4": {"effect": -0.06978309042173748, "value": " Machine-op-inspct"}, "5": {"effect": 0.023262557567870254, "value": " Husband"}, "6": {"effect": -0.002745255348805197, "value": " White"}, "7": {"effect": -0.0028938812927663815, "value": " Male"}, "8": {"effect": 0.0038684810160759045, "value": 0.0}, "9": {"effect": 0.21039311321653953, "value": 1887.0}, "10": {"effect": -0.030161688735340468, "value": 30.0}, "11": {"effect": 6.729427662792057e-05, "value": " United-States"}}}, {"outValue": -0.0514004632703422, "simIndex": 16.0, "features": {"0": {"effect": -0.08791505568335045, "value": 21.0}, "1": {"effect": 0.005032046593531946, "value": " ?"}, "2": {"effect": 0.026618911524326633, "value": 10.0}, "3": {"effect": 0.022009111053997738, "value": " Never-married"}, "4": {"effect": -0.013018920403360819, "value": " ?"}, "5": {"effect": -0.04088881722364136, "value": " Own-child"}, "6": {"effect": -0.002490342254581409, "value": " White"}, "7": {"effect": 0.017063400933358036, "value": " Fema ...
# <div id='iMORTRJDY9YWYTZH9MCXI'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0.2705533692666495, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.01755350332525929, "simIndex": 24.0, "features": {"0": {"effect": -0.0220664572114023, "value": 33.0}, "1": {"effect": -0.0004241577337223181, "value": " Private"}, "2": {"effect": -0.10819191872800572, "value": 7.0}, "3": {"effect": -0.026770662555790446, "value": " Never-married"}, "4": {"effect": -0.004629766057521038, "value": " Craft-repair"}, "5": {"effect": -0.1133075590320382, "value": " Not-in-family"}, "6": {"effect": 0.0018126337443959478, "value": " White"}, "7": {"effect": 0.010248598050359343, "value": " Male"}, "8": {"effect": -0.03542546045269426, "value": 0.0}, "9": {"effect": -0.008758591399046353, "value": 0.0}, "10": {"effect": 0.05439925953626374, "value": 65.0}, "11": {"effect": 0.00011421589781127833, "value": " United-States"}}}, {"outValue": 0.05720385959204882, "simIndex": 31.0, "features": {"0": {"effect": -0.016247609424126543, "value": 36.0}, "1": {"effect": -0.0008367006236934307, "value": " Private"}, "2": {"effect": -0.024843273884501527, "value": 10.0}, "3": {"effect": 0.03427671897604234, "value": " Divorced"}, "4": {"effect": 0.0055166259582078575, "value": " Prof-specialty"}, "5": {"effect": -0.16680235939454224, "value": " Not-in-family"}, "6": {"effect": 0.0025661599388094158, "value": " White"}, "7": {"effect": 0.012580564329905453, "value": " Male"}, "8": {"effect": -0.03886232896348932, "value": 0.0}, "9": {"effect": -0.010043163401282727, "value": 0.0}, "10": {"effect": -0.010813689490762902, "value": 40.0}, "11": {"effect": 0.00015954630483290853, "value": " United-States"}}}, {"outValue": 0.04923245046659905, "simIndex": 33.0, "features": {"0": {"effect": -0.016544268569518954, "value": 36.0}, "1": {"effect": 0.007135941018979368, "value": " Local-gov"}, "2": {"effect": -0.03175555069081507, "value": 10.0}, "3": {"effect": 0.03836525519396103, "value": " Divorced"}, "4": {"effect": -0.008655188646744834, "value": " Adm-clerical"}, "5": {"effect": -0.10352516725615685, "value": " Unmarried"}, "6": {"effect": 0.0018299953258235357, "value": " White"}, "7": {"effect": -0.03267730003354672, "value": " Female"}, "8": {"effect": -0.03981071539874329, "value": 0.0}, "9": {"effect": -0.010526792217900871, "value": 0.0}, "10": {"effect": -0.025327993308605287, "value": 35.0}, "11": {"effect": 0.00017086578321743226, "value": " United-States"}}}, {"outValue": 0.3342920953299259, "simIndex": 75.0, "features": {"0": {"effect": -0.05376677722102405, "value": 29.0}, "1": {"effect": -0.001737445349647053, "value": " Private"}, "2": {"effect": -0.0852787679417921, "value": 9.0}, "3": {"effect": 0.005755279499942654, "value": " Married-civ-spouse"}, "4": {"effect": 0.0012928382370106086, "value": " Machine-op-inspct"}, "5": {"effect": 0.10573982327890942, "value": " Husband"}, "6": {"effect": 0.004416001549380905, "value": " White"}, "7": {"effect": 0.021677365633489362, "value": " Male"}, "8": {"effect": -0.04376885916321606, "value": 0.0}, "9": {"effect": 0.167472121702534, "value": 1887.0}, "10": {"effect": -0.05832268038221273, "value": 30.0}, "11": {"effect": 0.00025982621990133483, "value": " United-States"}}}, {"outValue": 0.052306429249087544, "simIndex": 17.0, "features": {"0": {"effect": -0.06231016188036087, "value": 21.0}, "1": {"effect": 0.015060198703127267, "value": " ?"}, "2": {"effect": -0.03150262440299728, "value": 10.0}, "3": {"effect": -0.03372780360151655, "value": " Never-married"}, "4": {"effect": -0.010002861901514145, "value": " ?"}, "5": {"effect": -0.002832131318414578, "value": " Own-child"}, "6": {"effect": 0.0025334729445287587, "value": " White"}, "7": {"effect": -0.03447089181099314, "value": " Female"}, "8": {"effect": -0.040 ...
# <div id='i0KWVUJU1W74ACPCYQGWY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": 0.29013309302710694, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.04597911238670355, "simIndex": 20.0, "features": {"0": {"effect": -0.013942836696029791, "value": 33.0}, "1": {"effect": -0.00012341476355988963, "value": " Private"}, "2": {"effect": -0.1096257312040931, "value": 7.0}, "3": {"effect": -0.014058277289926388, "value": " Never-married"}, "4": {"effect": -0.006703672285722055, "value": " Craft-repair"}, "5": {"effect": -0.07873927212488424, "value": " Not-in-family"}, "6": {"effect": 0.00025002806434511654, "value": " White"}, "7": {"effect": 0.0073205397698459206, "value": " Male"}, "8": {"effect": -0.05542793667344893, "value": 0.0}, "9": {"effect": -0.008024804757442324, "value": 0.0}, "10": {"effect": 0.034775908158109006, "value": 65.0}, "11": {"effect": 0.0001454891624032577, "value": " United-States"}}}, {"outValue": 0.07939057797193527, "simIndex": 32.0, "features": {"0": {"effect": -0.003109135096698685, "value": 36.0}, "1": {"effect": 0.0002072312514064873, "value": " Private"}, "2": {"effect": -0.02589614917608238, "value": 10.0}, "3": {"effect": 0.001683486409343059, "value": " Divorced"}, "4": {"effect": 0.015012422751007972, "value": " Prof-specialty"}, "5": {"effect": -0.13776997684277983, "value": " Not-in-family"}, "6": {"effect": 0.0010771280907728288, "value": " White"}, "7": {"effect": 0.011128757149498495, "value": " Male"}, "8": {"effect": -0.04575598093538752, "value": 0.0}, "9": {"effect": -0.009140849358195233, "value": 0.0}, "10": {"effect": -0.018462650575675064, "value": 40.0}, "11": {"effect": 0.00028320127761819375, "value": " United-States"}}}, {"outValue": 0.024914344772696495, "simIndex": 23.0, "features": {"0": {"effect": -0.004842175154222372, "value": 36.0}, "1": {"effect": 0.0005177352351731462, "value": " Local-gov"}, "2": {"effect": -0.020322148081678374, "value": 10.0}, "3": {"effect": 0.0017283747737140683, "value": " Divorced"}, "4": {"effect": -0.010817286804829363, "value": " Adm-clerical"}, "5": {"effect": -0.1222168658728414, "value": " Unmarried"}, "6": {"effect": 0.0005724412854114159, "value": " White"}, "7": {"effect": -0.024594113391940477, "value": " Female"}, "8": {"effect": -0.05387010253939985, "value": 0.0}, "9": {"effect": -0.008836185112595561, "value": 0.0}, "10": {"effect": -0.022645395976950464, "value": 35.0}, "11": {"effect": 0.00010697338574876528, "value": " United-States"}}}, {"outValue": 0.4984656572341919, "simIndex": 100.0, "features": {"0": {"effect": -0.07575863957945128, "value": 29.0}, "1": {"effect": -0.0011820892640389314, "value": " Private"}, "2": {"effect": -0.05948474592173522, "value": 9.0}, "3": {"effect": 0.01398407161804949, "value": " Married-civ-spouse"}, "4": {"effect": -0.06849025218472687, "value": " Machine-op-inspct"}, "5": {"effect": 0.12900238084677967, "value": " Husband"}, "6": {"effect": 0.001670746200575708, "value": " White"}, "7": {"effect": 0.01878348434072298, "value": " Male"}, "8": {"effect": -0.039900378147140154, "value": 0.0}, "9": {"effect": 0.37786523491907353, "value": 1887.0}, "10": {"effect": -0.0884843691175532, "value": 30.0}, "11": {"effect": 0.0003271204965292554, "value": " United-States"}}}, {"outValue": 0.0009059659787453156, "simIndex": 40.0, "features": {"0": {"effect": -0.15022521756371132, "value": 21.0}, "1": {"effect": 0.020092245296659213, "value": " ?"}, "2": {"effect": -0.0048837128786706485, "value": 10.0}, "3": {"effect": -0.011718692547518814, "value": " Never-married"}, "4": {"effect": -0.023021782304874963, "value": " ?"}, "5": {"effect": -0.043720948542055944, "value": " Own-child"}, "6": {"effect": 4.313068994734978e-05, "value": " White"}, "7": {"effect": -0.0174074908776351, "value": " Female"}, "8": {"ef ...

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %%
mask = pred_a != pred_b
plot.shap_heatmap(shap_values_a[mask], 'A', feature_order)
plot.shap_heatmap(shap_values_b[mask], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[mask], 'A vs. B', feature_order)

# %%
idx = indices[pred_a == pred_b] #shuffle(indices[pred_a == pred_b], random_state=0, n_samples=500)
plot.shap_heatmap(shap_values_a[idx], 'A', feature_order)
plot.shap_heatmap(shap_values_b[idx], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[idx], 'A vs. B', feature_order)
