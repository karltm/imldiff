# %%
import plot
from scipy.special import logit
from shap.maskers import Independent
from sklearn.utils import resample, shuffle
import shap
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open('classifiers.pickle', 'rb') as f:
    clf_a, clf_b = pickle.load(f)
with open('predictions.pickle', 'rb') as f:
    X, display_data, feature_names, n_features, n_samples, indices, pred_a, pred_b, proba_a, proba_b, log_proba_a, log_proba_b, log_odds_a, log_odds_b = pickle.load(f)

# %%
try:
    with open(f'shapvalues.soa.proba.pickle', 'rb') as f:
        shap_values_a, shap_values_b, shap_values_a_vs_b, feature_order = pickle.load(f)
        print('Loaded cached shap values')
except FileNotFoundError:
    print('No cached shap values found')
# Out:
# Loaded cached shap values

# %% [markdown]
# ## Generate Explanations

# %% [markdown]
# Now we define the functions to be explained:

# %%
predict_proba_a = lambda X: clf_a.predict_proba(X)[:, 1]
predict_proba_b = lambda X: clf_b.predict_proba(X)[:, 1]

# %% [markdown]
# And now we calculate SHAP values for each function:

# %%
# %%time

background_data = X
def explain(predict):
    masker = Independent(data=background_data, max_samples=100)
    explainer = shap.Explainer(predict, masker, feature_names=feature_names)
    shap_values = explainer(X)
    shap_values.display_data = display_data
    return shap_values

shap_values_a = explain(predict_proba_a)
shap_values_b = explain(predict_proba_b)

shap_values_a_vs_b = shap_values_b - shap_values_a
shap_values_a_vs_b.data = shap_values_a.data
shap_values_a_vs_b.display_data = shap_values_a.display_data

feature_order = np.flip(shap_values_a_vs_b.abs.mean(axis=0).values.argsort())

with open(f'shapvalues.soa.proba.pickle', 'wb') as f:
    pickle.dump((shap_values_a, shap_values_b, shap_values_a_vs_b, feature_order), f, pickle.HIGHEST_PROTOCOL)
# Out:
# Permutation explainer: 32562it [16:58, 31.74it/s]
# Permutation explainer: 32562it [18:25, 29.11it/s]
# CPU times: user 54min 53s, sys: 5min 5s, total: 59min 58s
# Wall time: 35min 29s

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# We estimate it with the mean absolute SHAP value (which is the default for this plot) and will also sort features subsequently in this order

# %%
shap.plots.bar(shap_values_a, order=feature_order, max_display=n_features)
shap.plots.bar(shap_values_b, max_display=n_features)
shap.plots.bar(shap_values_a_vs_b, order=feature_order, max_display=n_features)

# %% [markdown]
# ### SHAP Value Distribution

# %%
shap.plots.beeswarm(shap_values_a, order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_a[pred_a != pred_b], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %%
shap.plots.beeswarm(shap_values_b, order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_b[pred_a != pred_b], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %%
shap.plots.beeswarm(shap_values_a_vs_b, order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_a_vs_b[pred_a != pred_b], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %% [markdown]
# ### Features' Partial Dependence Plots

# %%
n_columns = 3
n_rows = n_features
fig = plt.figure(figsize=(9*n_columns, 7*n_rows))
i = 1
for feature in feature_names[feature_order]:
    ax1 = fig.add_subplot(n_rows, n_columns, i)
    ax2 = fig.add_subplot(n_rows, n_columns, i+1, sharey=ax1)
    ax3 = fig.add_subplot(n_rows, n_columns, i+2, sharey=None)
    shap.plots.scatter(shap_values_a[:, feature], title='A', ax=ax1, color='blue', dot_size=1, show=False)
    shap.plots.scatter(shap_values_a[pred_a != pred_b, feature], title='A', ax=ax1, color='red', dot_size=8, alpha=0.8, hist=False, show=False)
    shap.plots.scatter(shap_values_b[:, feature], title='B', ax=ax2, color='blue', dot_size=1, show=False)
    shap.plots.scatter(shap_values_b[pred_a != pred_b, feature], title='B', ax=ax2, color='red', dot_size=8, alpha=0.8, hist=False, show=False)
    shap.plots.scatter(shap_values_a_vs_b[:, feature], title='B - A', ax=ax3, color='blue', dot_size=1, show=False)
    shap.plots.scatter(shap_values_a_vs_b[pred_a != pred_b, feature], title='B - A', ax=ax3, color='red', dot_size=8, alpha=0.8, hist=False, show=False)
    i += n_columns
plt.show()

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %%
idx_diff = indices[pred_a != pred_b]
idx_equal = indices[pred_a == pred_b]
if len(idx_diff) > 500:
    idx_diff = shuffle(idx_diff, random_state=0, n_samples=500)
if len(idx_equal) > 500:
    idx_equal = shuffle(idx_equal, random_state=0, n_samples=500)

# %%
order = plot.shap_force(shap_values_a_vs_b[idx_diff], 'A vs. B')
plot.shap_force(shap_values_a[idx_diff], 'A', ordering=order)
plot.shap_force(shap_values_b[idx_diff], 'B', ordering=order);
# Out:
# <div id='i28FG7EGSVPL8LLHW2FFL'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": -0.004398703658193476, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": -0.009249463866642785, "simIndex": 48.0, "features": {"0": {"effect": -0.000546940776941925, "value": 37.0}, "1": {"effect": 0.0003618708917336455, "value": " Private"}, "2": {"effect": -0.01132873520009366, "value": 10.0}, "3": {"effect": -0.005261624444052225, "value": " Married-civ-spouse"}, "4": {"effect": 0.0017071685899334044, "value": " Exec-managerial"}, "5": {"effect": 0.026685985908844315, "value": " Husband"}, "6": {"effect": 0.0023186757158303976, "value": " Black"}, "7": {"effect": -0.007527648313014071, "value": " Male"}, "8": {"effect": -0.004470845052605699, "value": 0.0}, "9": {"effect": -0.0021591784584795368, "value": 0.0}, "10": {"effect": -0.004714027241449759, "value": 80.0}, "11": {"effect": 8.453817184580744e-05, "value": " United-States"}}}, {"outValue": -0.005999860678622277, "simIndex": 138.0, "features": {"0": {"effect": 0.0065789674122757325, "value": 24.0}, "1": {"effect": 0.0005124202315232463, "value": " Private"}, "2": {"effect": 0.013343291313918065, "value": 13.0}, "3": {"effect": -0.012844705967386613, "value": " Married-civ-spouse"}, "4": {"effect": 0.002712943553391982, "value": " Tech-support"}, "5": {"effect": -0.011026556247863, "value": " Husband"}, "6": {"effect": -0.00046920374384153054, "value": " White"}, "7": {"effect": -0.00034132962043289736, "value": " Male"}, "8": {"effect": 0.0034908252574178157, "value": 0.0}, "9": {"effect": -0.0005884668844098676, "value": 0.0}, "10": {"effect": -0.00297592526784881, "value": 50.0}, "11": {"effect": 6.582942827074536e-06, "value": " United-States"}}}, {"outValue": -0.012249168090213312, "simIndex": 145.0, "features": {"0": {"effect": 0.003437282208116836, "value": 49.0}, "1": {"effect": -0.0006263660813913153, "value": " Private"}, "2": {"effect": -0.0031786153328969835, "value": 13.0}, "3": {"effect": -0.004218526054188579, "value": " Married-civ-spouse"}, "4": {"effect": 0.0004957199164667848, "value": " Sales"}, "5": {"effect": 0.004690080311631678, "value": " Husband"}, "6": {"effect": 0.0006729260107960211, "value": " White"}, "7": {"effect": -0.0034755830897243503, "value": " Male"}, "8": {"effect": -0.0007173174038452891, "value": 0.0}, "9": {"effect": -0.0013836823289929759, "value": 0.0}, "10": {"effect": -0.003481273718317246, "value": 26.0}, "11": {"effect": -6.51088696744178e-05, "value": " United-States"}}}, {"outValue": -0.008499621176881425, "simIndex": 57.0, "features": {"0": {"effect": 0.002338495518080845, "value": 34.0}, "1": {"effect": -0.00017079958865352319, "value": " Private"}, "2": {"effect": -0.03454946570949036, "value": 13.0}, "3": {"effect": -0.0035849324465828357, "value": " Married-civ-spouse"}, "4": {"effect": 0.0005851492588866882, "value": " Exec-managerial"}, "5": {"effect": 0.023909904354026026, "value": " Husband"}, "6": {"effect": 0.0013576512046346236, "value": " White"}, "7": {"effect": 0.0026093792008584395, "value": " Male"}, "8": {"effect": 0.0003027479489290802, "value": 0.0}, "9": {"effect": -7.690516244614198e-06, "value": 0.0}, "10": {"effect": 0.003143429581297326, "value": 45.0}, "11": {"effect": -3.478632442964946e-05, "value": " United-States"}}}, {"outValue": -0.01174847920646401, "simIndex": 171.0, "features": {"0": {"effect": -0.004642468943460452, "value": 47.0}, "1": {"effect": 0.003825598164017556, "value": " Self-emp-not-inc"}, "2": {"effect": -0.0035993585364954145, "value": 9.0}, "3": {"effect": -0.004404256690362179, "value": " Married-civ-spouse"}, "4": {"effect": -0.00014507459892703582, "value": " Other-service"}, "5": {"effect": -0.026863731909260696, "value": " Wife"}, "6": {"effect": -0.001064053809364588, "value": " White"}, ...
# <div id='i5X2B51NY9VX65G3YG8SD'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0.24758416281439902, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.5019118540026638, "simIndex": 125.0, "features": {"0": {"effect": -0.015580890461898549, "value": 37.0}, "1": {"effect": -0.0018556262957435368, "value": " Private"}, "2": {"effect": 0.013685414653641363, "value": 10.0}, "3": {"effect": 0.026775513596186712, "value": " Married-civ-spouse"}, "4": {"effect": -0.008603310466093207, "value": " Exec-managerial"}, "5": {"effect": 0.08565494681696711, "value": " Husband"}, "6": {"effect": -0.026462358543134796, "value": " Black"}, "7": {"effect": 0.031075155040177525, "value": " Male"}, "8": {"effect": -0.02632547542771453, "value": 0.0}, "9": {"effect": -0.021969642724161062, "value": 0.0}, "10": {"effect": 0.19738112004590122, "value": 80.0}, "11": {"effect": 0.0005528449541365196, "value": " United-States"}}}, {"outValue": 0.5013251069734673, "simIndex": 93.0, "features": {"0": {"effect": -0.08134941880539767, "value": 24.0}, "1": {"effect": -0.0023577300491332185, "value": " Private"}, "2": {"effect": 0.15971617087284729, "value": 13.0}, "3": {"effect": 0.024701484510873, "value": " Married-civ-spouse"}, "4": {"effect": 0.012764977575807655, "value": " Tech-support"}, "5": {"effect": 0.10611523183386816, "value": " Husband"}, "6": {"effect": 0.0051787138104579895, "value": " White"}, "7": {"effect": 0.028840398158095287, "value": " Male"}, "8": {"effect": -0.03037503146233653, "value": 0.0}, "9": {"effect": -0.023889014130839117, "value": 0.0}, "10": {"effect": 0.05382140350185251, "value": 50.0}, "11": {"effect": 0.0005737583429730402, "value": " United-States"}}}, {"outValue": 0.5082394943435554, "simIndex": 16.0, "features": {"0": {"effect": 0.0451120804319525, "value": 49.0}, "1": {"effect": -0.0017944319127623787, "value": " Private"}, "2": {"effect": 0.17828119520782248, "value": 13.0}, "3": {"effect": 0.016023336134043237, "value": " Married-civ-spouse"}, "4": {"effect": 0.012794680908126434, "value": " Sales"}, "5": {"effect": 0.10260740626393978, "value": " Husband"}, "6": {"effect": 0.003954121016230019, "value": " White"}, "7": {"effect": 0.031070007804981297, "value": " Male"}, "8": {"effect": -0.02707617673216665, "value": 0.0}, "9": {"effect": -0.021358423347921474, "value": 0.0}, "10": {"effect": -0.07958177531449137, "value": 26.0}, "11": {"effect": 0.0006233110694026039, "value": " United-States"}}}, {"outValue": 0.506512762293854, "simIndex": 68.0, "features": {"0": {"effect": -0.034944822485548914, "value": 34.0}, "1": {"effect": -0.0018475143495549936, "value": " Private"}, "2": {"effect": 0.20578452197319594, "value": 13.0}, "3": {"effect": 0.02065039983510719, "value": " Married-civ-spouse"}, "4": {"effect": -0.006508500286337914, "value": " Exec-managerial"}, "5": {"effect": 0.0861660744841549, "value": " Husband"}, "6": {"effect": 0.003533792915600711, "value": " White"}, "7": {"effect": 0.021949400025795263, "value": " Male"}, "8": {"effect": -0.027227545293217956, "value": 0.0}, "9": {"effect": -0.022808382986293327, "value": 0.0}, "10": {"effect": 0.013604919914695375, "value": 45.0}, "11": {"effect": 0.0005762557318587658, "value": " United-States"}}}, {"outValue": 0.5013079700854227, "simIndex": 138.0, "features": {"0": {"effect": 0.041895777132480244, "value": 47.0}, "1": {"effect": -0.015352312108539138, "value": " Self-emp-not-inc"}, "2": {"effect": -0.05203673635505754, "value": 9.0}, "3": {"effect": 0.02248280527730291, "value": " Married-civ-spouse"}, "4": {"effect": 0.0034948794525977095, "value": " Other-service"}, "5": {"effect": 0.19778483500133728, "value": " Wife"}, "6": {"effect": 0.005193221308542023, "value": " White"}, "7": {"effect": -0.053446974487747524, "value": " Female"}, "8": {"effect": ...
# <div id='iJGJCWRTV41WL245ZE4XI'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": 0.24318545915620554, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.492662390136021, "simIndex": 143.0, "features": {"0": {"effect": -0.016127831238840474, "value": 37.0}, "1": {"effect": -0.0014937554040098913, "value": " Private"}, "2": {"effect": 0.002356679453547703, "value": 10.0}, "3": {"effect": 0.021513889152134487, "value": " Married-civ-spouse"}, "4": {"effect": -0.006896141876159802, "value": " Exec-managerial"}, "5": {"effect": 0.11234093272581143, "value": " Husband"}, "6": {"effect": -0.024143682827304398, "value": " Black"}, "7": {"effect": 0.023547506727163454, "value": " Male"}, "8": {"effect": -0.03079632048032023, "value": 0.0}, "9": {"effect": -0.0241288211826406, "value": 0.0}, "10": {"effect": 0.19266709280445146, "value": 80.0}, "11": {"effect": 0.000637383125982327, "value": " United-States"}}}, {"outValue": 0.4953252462948451, "simIndex": 85.0, "features": {"0": {"effect": -0.07477045139312194, "value": 24.0}, "1": {"effect": -0.0018453098176099722, "value": " Private"}, "2": {"effect": 0.17305946218676535, "value": 13.0}, "3": {"effect": 0.011856778543486386, "value": " Married-civ-spouse"}, "4": {"effect": 0.015477921129199637, "value": " Tech-support"}, "5": {"effect": 0.09508867558600516, "value": " Husband"}, "6": {"effect": 0.004709510066616459, "value": " White"}, "7": {"effect": 0.02849906853766239, "value": " Male"}, "8": {"effect": -0.026884206204918715, "value": 0.0}, "9": {"effect": -0.024477481015248985, "value": 0.0}, "10": {"effect": 0.0508454782340037, "value": 50.0}, "11": {"effect": 0.0005803412858001148, "value": " United-States"}}}, {"outValue": 0.49599032625334216, "simIndex": 99.0, "features": {"0": {"effect": 0.048549362640069336, "value": 49.0}, "1": {"effect": -0.002420797994153694, "value": " Private"}, "2": {"effect": 0.1751025798749255, "value": 13.0}, "3": {"effect": 0.011804810079854658, "value": " Married-civ-spouse"}, "4": {"effect": 0.01329040082459322, "value": " Sales"}, "5": {"effect": 0.10729748657557146, "value": " Husband"}, "6": {"effect": 0.00462704702702604, "value": " White"}, "7": {"effect": 0.027594424715256947, "value": " Male"}, "8": {"effect": -0.02779349413601194, "value": 0.0}, "9": {"effect": -0.02274210567691445, "value": 0.0}, "10": {"effect": -0.08306304903280862, "value": 26.0}, "11": {"effect": 0.0005582021997281861, "value": " United-States"}}}, {"outValue": 0.49801314111697265, "simIndex": 37.0, "features": {"0": {"effect": -0.03260632696746807, "value": 34.0}, "1": {"effect": -0.002018313938208517, "value": " Private"}, "2": {"effect": 0.17123505626370558, "value": 13.0}, "3": {"effect": 0.017065467388524356, "value": " Married-civ-spouse"}, "4": {"effect": -0.005923351027451226, "value": " Exec-managerial"}, "5": {"effect": 0.11007597883818093, "value": " Husband"}, "6": {"effect": 0.004891444120235335, "value": " White"}, "7": {"effect": 0.024558779226653702, "value": " Male"}, "8": {"effect": -0.026924797344288876, "value": 0.0}, "9": {"effect": -0.02281607350253794, "value": 0.0}, "10": {"effect": 0.0167483494959927, "value": 45.0}, "11": {"effect": 0.0005414694074291163, "value": " United-States"}}}, {"outValue": 0.4895594908789588, "simIndex": 138.0, "features": {"0": {"effect": 0.03725330818901979, "value": 47.0}, "1": {"effect": -0.011526713944521582, "value": " Self-emp-not-inc"}, "2": {"effect": -0.055636094891552954, "value": 9.0}, "3": {"effect": 0.018078548586940732, "value": " Married-civ-spouse"}, "4": {"effect": 0.0033498048536706737, "value": " Other-service"}, "5": {"effect": 0.1709211030920766, "value": " Wife"}, "6": {"effect": 0.004129167499177435, "value": " White"}, "7": {"effect": -0.04908736819248305, "value": " Female"}, "8": {"effect": -0.026 ...

# %%
order = plot.shap_force(shap_values_a_vs_b[idx_equal], 'A vs. B')
plot.shap_force(shap_values_a[idx_equal], 'A', ordering=order)
plot.shap_force(shap_values_b[idx_equal], 'B', ordering=order);
# Out:
# <div id='iEBK6F6BKIEG8MC5S0BFO'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": -0.004398703658193476, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": -0.0003272563526822113, "simIndex": 308.0, "features": {"0": {"effect": -0.006500646859272305, "value": 18.0}, "1": {"effect": -0.00012134840774311235, "value": " Private"}, "2": {"effect": -0.003345235856971787, "value": 7.0}, "3": {"effect": 0.004997642319363203, "value": " Never-married"}, "4": {"effect": 3.911953256898067e-05, "value": " Handlers-cleaners"}, "5": {"effect": -0.0006941515392783221, "value": " Own-child"}, "6": {"effect": -0.00015340600508065142, "value": " White"}, "7": {"effect": -0.0017163826960868269, "value": " Male"}, "8": {"effect": 0.0006864353876979944, "value": 0.0}, "9": {"effect": 0.005812695375003705, "value": 0.0}, "10": {"effect": 0.005033074567090217, "value": 30.0}, "11": {"effect": 3.365148822017023e-05, "value": " United-States"}}}, {"outValue": -0.0017618076286178138, "simIndex": 103.0, "features": {"0": {"effect": -0.0031770699165989402, "value": 30.0}, "1": {"effect": -0.00022722498746271993, "value": " Private"}, "2": {"effect": 0.01249301547324387, "value": 13.0}, "3": {"effect": -0.006007193228855373, "value": " Never-married"}, "4": {"effect": 0.0006208820978181838, "value": " Prof-specialty"}, "5": {"effect": -0.0041767561173177425, "value": " Not-in-family"}, "6": {"effect": 0.00042791228451795034, "value": " White"}, "7": {"effect": 0.0009627876371202538, "value": " Male"}, "8": {"effect": -0.0019609752973638005, "value": 0.0}, "9": {"effect": 0.002309862631190219, "value": 0.0}, "10": {"effect": 0.0013051402530950165, "value": 40.0}, "11": {"effect": 6.651520018874368e-05, "value": " United-States"}}}, {"outValue": -0.012749268028984477, "simIndex": 40.0, "features": {"0": {"effect": -0.001961842929088492, "value": 53.0}, "1": {"effect": 0.008242161448186971, "value": " State-gov"}, "2": {"effect": -0.010690549164056488, "value": 10.0}, "3": {"effect": -0.002951382545166272, "value": " Married-civ-spouse"}, "4": {"effect": 0.0011402193613440732, "value": " Farming-fishing"}, "5": {"effect": 0.011138525993746429, "value": " Husband"}, "6": {"effect": -0.00019392968711527507, "value": " White"}, "7": {"effect": -0.014872430700759925, "value": " Male"}, "8": {"effect": -0.002999372106743805, "value": 0.0}, "9": {"effect": -0.001354175632566828, "value": 0.0}, "10": {"effect": 0.006224894288272706, "value": 50.0}, "11": {"effect": -7.268269684409764e-05, "value": " United-States"}}}, {"outValue": -0.008939172902731461, "simIndex": 75.0, "features": {"0": {"effect": 0.0007796718640389194, "value": 36.0}, "1": {"effect": 0.003015652207791337, "value": " Self-emp-not-inc"}, "2": {"effect": -0.0014890056728710105, "value": 9.0}, "3": {"effect": -0.002457381963910602, "value": " Married-civ-spouse"}, "4": {"effect": 0.001513095086378082, "value": " Farming-fishing"}, "5": {"effect": -0.0031744564318673257, "value": " Husband"}, "6": {"effect": -0.001990812919492241, "value": " White"}, "7": {"effect": -0.0012259430589537101, "value": " Male"}, "8": {"effect": -0.005089888224911746, "value": 0.0}, "9": {"effect": -0.003189703125806992, "value": 0.0}, "10": {"effect": 0.008840448923875505, "value": 84.0}, "11": {"effect": -7.214592880820192e-05, "value": " United-States"}}}, {"outValue": -0.0005806703866682306, "simIndex": 35.0, "features": {"0": {"effect": 0.004397543424864949, "value": 32.0}, "1": {"effect": -0.0026372650703348818, "value": " Self-emp-not-inc"}, "2": {"effect": -0.005499708137736106, "value": 9.0}, "3": {"effect": -0.002124488517322276, "value": " Separated"}, "4": {"effect": -2.1918420635194322e-05, "value": " Sales"}, "5": {"effect": 0.018084199094550654, "value": " Not-in-family"}, "6": {"effect": 8.771902839740833e-05, ...
# <div id='iUH0H61SYRBQG55IYYAA5'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0.24758416281439902, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.018688159008947186, "simIndex": 285.0, "features": {"0": {"effect": -0.05087184617622345, "value": 18.0}, "1": {"effect": -0.0007634965167197569, "value": " Private"}, "2": {"effect": -0.08570880797906812, "value": 7.0}, "3": {"effect": -0.02536905891326907, "value": " Never-married"}, "4": {"effect": -0.0007387690988157814, "value": " Handlers-cleaners"}, "5": {"effect": -0.007704835470454389, "value": " Own-child"}, "6": {"effect": 0.0015668226110193953, "value": " White"}, "7": {"effect": 0.009443806517872182, "value": " Male"}, "8": {"effect": -0.02391867506588103, "value": 0.0}, "9": {"effect": -0.017723899246589275, "value": 0.0}, "10": {"effect": -0.02740055648541709, "value": 30.0}, "11": {"effect": 0.00029331201809453325, "value": " United-States"}}}, {"outValue": 0.06353727394805297, "simIndex": 30.0, "features": {"0": {"effect": -0.03566904400458945, "value": 30.0}, "1": {"effect": -0.0007662387338494489, "value": " Private"}, "2": {"effect": 0.07425849214777347, "value": 13.0}, "3": {"effect": -0.027895303400531195, "value": " Never-married"}, "4": {"effect": 0.003925518710681576, "value": " Prof-specialty"}, "5": {"effect": -0.16120968184922538, "value": " Not-in-family"}, "6": {"effect": 0.0019910129907040074, "value": " White"}, "7": {"effect": 0.009449182774707124, "value": " Male"}, "8": {"effect": -0.025679523227524963, "value": 0.0}, "9": {"effect": -0.017701284382865255, "value": 0.0}, "10": {"effect": -0.005124899565999956, "value": 40.0}, "11": {"effect": 0.0003748796743733774, "value": " United-States"}}}, {"outValue": 0.409255622663793, "simIndex": 427.0, "features": {"0": {"effect": 0.06403350934459258, "value": 53.0}, "1": {"effect": -0.025566573597951853, "value": " State-gov"}, "2": {"effect": -0.002307428861959954, "value": 10.0}, "3": {"effect": 0.017361286863761424, "value": " Married-civ-spouse"}, "4": {"effect": -0.0047361795634253846, "value": " Farming-fishing"}, "5": {"effect": 0.08447520217394154, "value": " Husband"}, "6": {"effect": 0.004475587478671649, "value": " White"}, "7": {"effect": 0.03471537118137391, "value": " Male"}, "8": {"effect": -0.02838326977739544, "value": 0.0}, "9": {"effect": -0.02444343129308731, "value": 0.0}, "10": {"effect": 0.041428760935236494, "value": 50.0}, "11": {"effect": 0.000618624965636336, "value": " United-States"}}}, {"outValue": 0.46344761850350896, "simIndex": 401.0, "features": {"0": {"effect": -0.021716719945879703, "value": 36.0}, "1": {"effect": -0.01687392384499627, "value": " Self-emp-not-inc"}, "2": {"effect": -0.05590051998285079, "value": 9.0}, "3": {"effect": 0.020407249360856295, "value": " Married-civ-spouse"}, "4": {"effect": -0.005156594547485303, "value": " Farming-fishing"}, "5": {"effect": 0.1050638907687364, "value": " Husband"}, "6": {"effect": 0.006041770080033444, "value": " White"}, "7": {"effect": 0.027008548733648136, "value": " Male"}, "8": {"effect": -0.02780819498040973, "value": 0.0}, "9": {"effect": -0.020882364492321028, "value": 0.0}, "10": {"effect": 0.2050889676160129, "value": 84.0}, "11": {"effect": 0.0005913469237655998, "value": " United-States"}}}, {"outValue": 0.018779601893229803, "simIndex": 347.0, "features": {"0": {"effect": -0.023164046052877356, "value": 32.0}, "1": {"effect": -0.004947235604795292, "value": " Self-emp-not-inc"}, "2": {"effect": -0.03940388522249884, "value": 9.0}, "3": {"effect": -0.02880611403193995, "value": " Separated"}, "4": {"effect": 0.006859074009863398, "value": " Sales"}, "5": {"effect": -0.12727953895881988, "value": " Not-in-family"}, "6": {"effect": 0.0012045897367343602, "value": " White"}, "7": {"effect": 0.00667586286233678, "val ...
# <div id='i6CJP81FIT8AUQ87QTPWU'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": 0.24318545915620554, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.018360902656264944, "simIndex": 281.0, "features": {"0": {"effect": -0.057372493035495756, "value": 18.0}, "1": {"effect": -0.0008848449244628693, "value": " Private"}, "2": {"effect": -0.0890540438360399, "value": 7.0}, "3": {"effect": -0.02037141659390587, "value": " Never-married"}, "4": {"effect": -0.0006996495662468007, "value": " Handlers-cleaners"}, "5": {"effect": -0.008398987009732711, "value": " Own-child"}, "6": {"effect": 0.0014134166059387439, "value": " White"}, "7": {"effect": 0.007727423821785355, "value": " Male"}, "8": {"effect": -0.023232239678183036, "value": 0.0}, "9": {"effect": -0.01191120387158557, "value": 0.0}, "10": {"effect": -0.022367481918326874, "value": 30.0}, "11": {"effect": 0.0003269635063147035, "value": " United-States"}}}, {"outValue": 0.061775466319435146, "simIndex": 124.0, "features": {"0": {"effect": -0.03884611392118839, "value": 30.0}, "1": {"effect": -0.0009934637213121688, "value": " Private"}, "2": {"effect": 0.08675150762101734, "value": 13.0}, "3": {"effect": -0.03390249662938657, "value": " Never-married"}, "4": {"effect": 0.00454640080849976, "value": " Prof-specialty"}, "5": {"effect": -0.16538643796654312, "value": " Not-in-family"}, "6": {"effect": 0.002418925275221958, "value": " White"}, "7": {"effect": 0.010411970411827377, "value": " Male"}, "8": {"effect": -0.027640498524888764, "value": 0.0}, "9": {"effect": -0.015391421751675035, "value": 0.0}, "10": {"effect": -0.003819759312904939, "value": 40.0}, "11": {"effect": 0.0004413948745621211, "value": " United-States"}}}, {"outValue": 0.39650635463480854, "simIndex": 371.0, "features": {"0": {"effect": 0.06207166641550409, "value": 53.0}, "1": {"effect": -0.017324412149764882, "value": " State-gov"}, "2": {"effect": -0.012997978026016441, "value": 10.0}, "3": {"effect": 0.014409904318595151, "value": " Married-civ-spouse"}, "4": {"effect": -0.0035959602020813114, "value": " Farming-fishing"}, "5": {"effect": 0.09561372816768797, "value": " Husband"}, "6": {"effect": 0.004281657791556374, "value": " White"}, "7": {"effect": 0.019842940480613986, "value": " Male"}, "8": {"effect": -0.031382641884139244, "value": 0.0}, "9": {"effect": -0.025797606925654137, "value": 0.0}, "10": {"effect": 0.0476536552235092, "value": 50.0}, "11": {"effect": 0.0005459422687922384, "value": " United-States"}}}, {"outValue": 0.4545084456007775, "simIndex": 351.0, "features": {"0": {"effect": -0.020937048081840784, "value": 36.0}, "1": {"effect": -0.013858271637204933, "value": " Self-emp-not-inc"}, "2": {"effect": -0.0573895256557218, "value": 9.0}, "3": {"effect": 0.017949867396945693, "value": " Married-civ-spouse"}, "4": {"effect": -0.003643499461107221, "value": " Farming-fishing"}, "5": {"effect": 0.10188943433686908, "value": " Husband"}, "6": {"effect": 0.004050957160541204, "value": " White"}, "7": {"effect": 0.025782605674694425, "value": " Male"}, "8": {"effect": -0.03289808320532148, "value": 0.0}, "9": {"effect": -0.02407206761812802, "value": 0.0}, "10": {"effect": 0.2139294165398884, "value": 84.0}, "11": {"effect": 0.0005192009949573979, "value": " United-States"}}}, {"outValue": 0.018198931506561628, "simIndex": 247.0, "features": {"0": {"effect": -0.018766502628012407, "value": 32.0}, "1": {"effect": -0.007584500675130174, "value": " Self-emp-not-inc"}, "2": {"effect": -0.044903593360234945, "value": 9.0}, "3": {"effect": -0.030930602549262227, "value": " Separated"}, "4": {"effect": 0.006837155589228204, "value": " Sales"}, "5": {"effect": -0.10919533986426923, "value": " Not-in-family"}, "6": {"effect": 0.0012923087651317685, "value": " White"}, "7": {"effect": 0.004997702681783994, ...

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %%
plot.shap_heatmap(shap_values_a[idx_equal], 'A', feature_order)
plot.shap_heatmap(shap_values_b[idx_equal], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[idx_equal], 'A vs. B', feature_order)

# %%
plot.shap_heatmap(shap_values_a[idx_diff], 'A', feature_order)
plot.shap_heatmap(shap_values_b[idx_diff], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[idx_diff], 'A vs. B', feature_order)
