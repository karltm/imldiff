# %%
import plot
from scipy.special import logit
from shap.maskers import Independent
from sklearn.utils import resample, shuffle
import shap
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open('classifiers.pickle', 'rb') as f:
    clf_a, clf_b = pickle.load(f)
with open('predictions.pickle', 'rb') as f:
    X, display_data, feature_names, n_features, n_samples, indices, pred_a, pred_b, proba_a, proba_b, log_proba_a, log_proba_b, log_odds_a, log_odds_b = pickle.load(f)
with open('subsets.pickle', 'rb') as f:
    is_pred_diff, is_pred_diff_a_pos, is_pred_diff_b_pos, proba_diff_a_pos, proba_diff_b_pos, proba_diff, log_odds_diff_a_pos, log_odds_diff_b_pos, log_odds_diff = pickle.load(f)
    
idx_sample_pred_equal = indices[~is_pred_diff]
idx_sample_pred_diff = indices[is_pred_diff]
if idx_sample_pred_equal.shape[0] > 500:
    idx_sample_pred_equal = shuffle(idx_sample_pred_equal, random_state=42, n_samples=500)
if idx_sample_pred_diff.shape[0] > 500:
    idx_sample_pred_diff = shuffle(idx_sample_pred_diff, random_state=42, n_samples=500)
idx_sample = np.union1d(idx_sample_pred_equal, idx_sample_pred_diff)

X = X.iloc[idx_sample, :]
display_data = display_data[idx_sample]
pred_a = pred_a[idx_sample]
pred_b = pred_b[idx_sample]
proba_a = proba_a[idx_sample]
proba_b = proba_b[idx_sample]
log_proba_a  =  log_proba_a[idx_sample]
log_proba_b  = log_proba_b[idx_sample]
log_odds_a = log_odds_a[idx_sample]
log_odds_b = log_odds_b[idx_sample]
is_pred_diff = is_pred_diff[idx_sample]
is_pred_diff_a_pos = is_pred_diff_a_pos[idx_sample]
is_pred_diff_b_pos = is_pred_diff_b_pos[idx_sample]
proba_diff_a_pos = proba_diff_a_pos[idx_sample]
proba_diff_b_pos = proba_diff_b_pos[idx_sample]
proba_diff = proba_diff[idx_sample]
log_odds_diff_a_pos = log_odds_diff_a_pos[idx_sample]
log_odds_diff_b_pos = log_odds_diff_b_pos[idx_sample]
log_odds_diff = log_odds_diff[idx_sample]

n_samples = X.shape[0]
indices = np.array(range(n_samples))

# %%
try:
    with open(f'shapvalues.soa.pred.pickle', 'rb') as f:
        shap_values_a, shap_values_b, shap_values_a_vs_b, feature_order = pickle.load(f)
        print('Loaded cached shap values')
except FileNotFoundError:
    print('No cached shap values found')
# Out:
# Loaded cached shap values

# %% [markdown]
# ## Generate Explanations

# %% [markdown]
# Now we define the functions to be explained:

# %%
predict_pred_a = lambda X: clf_a.predict(X)
predict_pred_b = lambda X: clf_b.predict(X)

# %% [markdown]
# And now we calculate SHAP values for each function:

# %%
# %%time

background_data = X
def explain(predict):
    masker = Independent(data=background_data, max_samples=100)
    explainer = shap.Explainer(predict, masker, feature_names=feature_names)
    shap_values = explainer(X)
    shap_values.display_data = display_data
    return shap_values

shap_values_a = explain(predict_pred_a)
shap_values_b = explain(predict_pred_b)

shap_values_a_vs_b = shap_values_b - shap_values_a
shap_values_a_vs_b.data = shap_values_a.data
shap_values_a_vs_b.display_data = shap_values_a.display_data

feature_order = np.flip(shap_values_a_vs_b.abs.mean(axis=0).values.argsort())

with open(f'shapvalues.soa.pred.pickle', 'wb') as f:
    pickle.dump((shap_values_a, shap_values_b, shap_values_a_vs_b, feature_order), f, pickle.HIGHEST_PROTOCOL)
# Out:
# Permutation explainer: 697it [00:20, 18.09it/s]
# Permutation explainer: 697it [00:18, 16.76it/s]
# CPU times: user 1min 4s, sys: 5.9 s, total: 1min 10s
# Wall time: 38.9 s

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# We estimate it with the mean absolute SHAP value (which is the default for this plot) and will also sort features subsequently in this order

# %%
shap.plots.bar(shap_values_a, order=feature_order, max_display=n_features)
shap.plots.bar(shap_values_b, order=feature_order, max_display=n_features)
shap.plots.bar(shap_values_a_vs_b, order=feature_order, max_display=n_features)

# %% [markdown]
# ### SHAP Value Distribution

# %%
shap.plots.beeswarm(shap_values_a, order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_a[pred_a != pred_b], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %%
shap.plots.beeswarm(shap_values_b, order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_b[pred_a != pred_b], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %%
shap.plots.beeswarm(shap_values_a_vs_b, order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_a_vs_b[pred_a != pred_b], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %% [markdown]
# ### Features' Partial Dependence Plots

# %%
n_columns = 3
n_rows = n_features
fig = plt.figure(figsize=(9*n_columns, 7*n_rows))
i = 1
for feature in feature_names[feature_order]:
    ax1 = fig.add_subplot(n_rows, n_columns, i)
    ax2 = fig.add_subplot(n_rows, n_columns, i+1, sharey=ax1)
    ax3 = fig.add_subplot(n_rows, n_columns, i+2, sharey=None)
    shap.plots.scatter(shap_values_a[:, feature], title='A', ax=ax1, color='blue', show=False)
    shap.plots.scatter(shap_values_a[pred_a != pred_b, feature], title='A', ax=ax1, color='red', hist=False, show=False)
    shap.plots.scatter(shap_values_b[:, feature], title='B', ax=ax2, color='blue', show=False)
    shap.plots.scatter(shap_values_b[pred_a != pred_b, feature], title='B', ax=ax2, color='red', hist=False, show=False)
    shap.plots.scatter(shap_values_a_vs_b[:, feature], title='B - A', ax=ax3, color='blue', show=False)
    shap.plots.scatter(shap_values_a_vs_b[pred_a != pred_b, feature], title='B - A', ax=ax3, color='red', hist=False, show=False)
    i += n_columns
plt.show()
# Out:
# Passing the fontdict parameter of _set_ticklabels() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %%
idx_diff = indices[pred_a != pred_b]
idx_equal = indices[pred_a == pred_b]
if len(idx_diff) > 500:
    idx_diff = shuffle(idx_diff, random_state=0, n_samples=500)
if len(idx_equal) > 500:
    idx_equal = shuffle(idx_equal, random_state=0, n_samples=500)

# %%
order = plot.shap_force(shap_values_a_vs_b[idx_diff], 'A vs. B')
plot.shap_force(shap_values_a[idx_diff], 'A', ordering=order)
plot.shap_force(shap_values_b[idx_diff], 'B', ordering=order);
# Out:
# <div id='iSZPYY0N5MATGJGM913NG'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": -0.24, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": -1.0, "simIndex": 82.0, "features": {"0": {"effect": -0.0288888888888889, "value": 37.0}, "1": {"effect": -0.049999999999999996, "value": " Private"}, "2": {"effect": -0.24555555555555555, "value": 10.0}, "3": {"effect": -0.01111111111111112, "value": " Married-civ-spouse"}, "4": {"effect": -0.14333333333333337, "value": " Exec-managerial"}, "5": {"effect": -0.07999999999999999, "value": " Husband"}, "6": {"effect": -0.03333333333333334, "value": " Black"}, "7": {"effect": -0.027777777777777776, "value": " Male"}, "8": {"effect": -0.020000000000000004, "value": 0.0}, "9": {"effect": 6.938893903907228e-18, "value": 0.0}, "10": {"effect": -0.11111111111111105, "value": 80.0}, "11": {"effect": -0.008888888888888887, "value": " United-States"}}}, {"outValue": -1.0, "simIndex": 157.0, "features": {"0": {"effect": -0.1133333333333334, "value": 24.0}, "1": {"effect": -0.04888888888888887, "value": " Private"}, "2": {"effect": -0.13555555555555554, "value": 13.0}, "3": {"effect": -0.03333333333333333, "value": " Married-civ-spouse"}, "4": {"effect": -0.08333333333333334, "value": " Tech-support"}, "5": {"effect": -0.04999999999999999, "value": " Husband"}, "6": {"effect": 0.0022222222222222227, "value": " White"}, "7": {"effect": -0.03111111111111111, "value": " Male"}, "8": {"effect": 0.004444444444444452, "value": 0.0}, "9": {"effect": -1.3877787807814457e-17, "value": 0.0}, "10": {"effect": -0.2511111111111111, "value": 50.0}, "11": {"effect": -0.01999999999999999, "value": " United-States"}}}, {"outValue": -1.0, "simIndex": 33.0, "features": {"0": {"effect": -0.18000000000000008, "value": 49.0}, "1": {"effect": -0.05555555555555555, "value": " Private"}, "2": {"effect": -0.2633333333333334, "value": 13.0}, "3": {"effect": -0.02222222222222222, "value": " Married-civ-spouse"}, "4": {"effect": -0.13444444444444448, "value": " Sales"}, "5": {"effect": -0.06555555555555556, "value": " Husband"}, "6": {"effect": 3.469446951953614e-18, "value": " White"}, "7": {"effect": 0.01444444444444444, "value": " Male"}, "8": {"effect": -0.005555555555555522, "value": 0.0}, "9": {"effect": -0.01888888888888888, "value": 0.0}, "10": {"effect": -0.0333333333333333, "value": 26.0}, "11": {"effect": 0.004444444444444446, "value": " United-States"}}}, {"outValue": -1.0, "simIndex": 172.0, "features": {"0": {"effect": -0.14666666666666667, "value": 34.0}, "1": {"effect": -0.01333333333333333, "value": " Private"}, "2": {"effect": -0.031111111111111145, "value": 13.0}, "3": {"effect": -0.027777777777777776, "value": " Married-civ-spouse"}, "4": {"effect": -0.18000000000000005, "value": " Exec-managerial"}, "5": {"effect": -0.060000000000000026, "value": " Husband"}, "6": {"effect": -0.022222222222222233, "value": " White"}, "7": {"effect": 0.0011111111111111252, "value": " Male"}, "8": {"effect": -0.013333333333333357, "value": 0.0}, "9": {"effect": -0.014444444444444454, "value": 0.0}, "10": {"effect": -0.25555555555555554, "value": 45.0}, "11": {"effect": 0.003333333333333334, "value": " United-States"}}}, {"outValue": -1.0000000000000002, "simIndex": 146.0, "features": {"0": {"effect": -0.2055555555555556, "value": 47.0}, "1": {"effect": -0.08999999999999998, "value": " Self-emp-not-inc"}, "2": {"effect": -0.12888888888888891, "value": 9.0}, "3": {"effect": -0.01333333333333332, "value": " Married-civ-spouse"}, "4": {"effect": -0.18777777777777774, "value": " Other-service"}, "5": {"effect": -0.043333333333333335, "value": " Wife"}, "6": {"effect": -0.04666666666666668, "value": " White"}, "7": {"effect": 0.11333333333333329, "value": " Female"}, "8": {"effect": -0.006666666666666654, "value": 0.0}, "9": {"effect": -0. ...
# <div id='iMZBRG6XNH8NR4P9T6DV4'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0.37, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 1.0, "simIndex": 53.0, "features": {"0": {"effect": -0.007777777777777774, "value": 37.0}, "1": {"effect": 0.026666666666666665, "value": " Private"}, "2": {"effect": 0.09222222222222223, "value": 10.0}, "3": {"effect": 0.00555555555555556, "value": " Married-civ-spouse"}, "4": {"effect": -0.05, "value": " Exec-managerial"}, "5": {"effect": 0.12222222222222223, "value": " Husband"}, "6": {"effect": -0.021111111111111098, "value": " Black"}, "7": {"effect": 0.06333333333333334, "value": " Male"}, "8": {"effect": -0.03333333333333334, "value": 0.0}, "9": {"effect": -0.014444444444444454, "value": 0.0}, "10": {"effect": 0.43, "value": 80.0}, "11": {"effect": 0.01666666666666667, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 65.0, "features": {"0": {"effect": -0.22666666666666663, "value": 24.0}, "1": {"effect": 0.00666666666666666, "value": " Private"}, "2": {"effect": 0.2711111111111111, "value": 13.0}, "3": {"effect": 0.0022222222222222274, "value": " Married-civ-spouse"}, "4": {"effect": 0.13, "value": " Tech-support"}, "5": {"effect": 0.10777777777777778, "value": " Husband"}, "6": {"effect": 0.008888888888888884, "value": " White"}, "7": {"effect": 0.042222222222222223, "value": " Male"}, "8": {"effect": -0.05222222222222223, "value": 0.0}, "9": {"effect": -0.021111111111111098, "value": 0.0}, "10": {"effect": 0.32555555555555554, "value": 50.0}, "11": {"effect": 0.03555555555555555, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 22.0, "features": {"0": {"effect": 0.23777777777777784, "value": 49.0}, "1": {"effect": 0.026666666666666665, "value": " Private"}, "2": {"effect": 0.3911111111111112, "value": 13.0}, "3": {"effect": -0.0011111111111111137, "value": " Married-civ-spouse"}, "4": {"effect": 0.12888888888888891, "value": " Sales"}, "5": {"effect": 0.09666666666666668, "value": " Husband"}, "6": {"effect": 0.008888888888888884, "value": " White"}, "7": {"effect": 0.02444444444444445, "value": " Male"}, "8": {"effect": -0.05333333333333337, "value": 0.0}, "9": {"effect": -0.008888888888888894, "value": 0.0}, "10": {"effect": -0.2288888888888889, "value": 26.0}, "11": {"effect": 0.007777777777777778, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 58.0, "features": {"0": {"effect": -0.051111111111111135, "value": 34.0}, "1": {"effect": -0.003333333333333339, "value": " Private"}, "2": {"effect": 0.29, "value": 13.0}, "3": {"effect": 0.005555555555555564, "value": " Married-civ-spouse"}, "4": {"effect": -0.012222222222222221, "value": " Exec-managerial"}, "5": {"effect": 0.11555555555555558, "value": " Husband"}, "6": {"effect": 0.02777777777777779, "value": " White"}, "7": {"effect": 0.03777777777777777, "value": " Male"}, "8": {"effect": -0.03555555555555555, "value": 0.0}, "9": {"effect": -0.012222222222222218, "value": 0.0}, "10": {"effect": 0.25, "value": 45.0}, "11": {"effect": 0.017777777777777778, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 168.0, "features": {"0": {"effect": 0.19444444444444448, "value": 47.0}, "1": {"effect": -0.10333333333333335, "value": " Self-emp-not-inc"}, "2": {"effect": -0.08111111111111113, "value": 9.0}, "3": {"effect": 0.009999999999999997, "value": " Married-civ-spouse"}, "4": {"effect": 0.14666666666666664, "value": " Other-service"}, "5": {"effect": 0.30666666666666664, "value": " Wife"}, "6": {"effect": 0.06000000000000002, "value": " White"}, "7": {"effect": -0.21333333333333332, "value": " Female"}, "8": {"effect": -0.05000000000000002, "value": 0.0}, "9": {"effect": -0.017777777777777785, "value": 0.0}, "10": {"effect": 0.3700000000000001, "value": 75.0}, "11": {"effect": 0.007777777777777766, "value ...
# <div id='iYA6EMAXETKRPZ7BI0LYM'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": 0.13, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 1.1102230246251565e-16, "simIndex": 107.0, "features": {"0": {"effect": -0.036666666666666674, "value": 37.0}, "1": {"effect": -0.02333333333333333, "value": " Private"}, "2": {"effect": -0.15333333333333332, "value": 10.0}, "3": {"effect": -0.00555555555555556, "value": " Married-civ-spouse"}, "4": {"effect": -0.19333333333333336, "value": " Exec-managerial"}, "5": {"effect": 0.04222222222222224, "value": " Husband"}, "6": {"effect": -0.05444444444444444, "value": " Black"}, "7": {"effect": 0.03555555555555556, "value": " Male"}, "8": {"effect": -0.053333333333333344, "value": 0.0}, "9": {"effect": -0.014444444444444447, "value": 0.0}, "10": {"effect": 0.31888888888888894, "value": 80.0}, "11": {"effect": 0.007777777777777782, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 39.0, "features": {"0": {"effect": -0.34, "value": 24.0}, "1": {"effect": -0.04222222222222221, "value": " Private"}, "2": {"effect": 0.13555555555555554, "value": 13.0}, "3": {"effect": -0.031111111111111103, "value": " Married-civ-spouse"}, "4": {"effect": 0.04666666666666666, "value": " Tech-support"}, "5": {"effect": 0.05777777777777779, "value": " Husband"}, "6": {"effect": 0.011111111111111106, "value": " White"}, "7": {"effect": 0.011111111111111113, "value": " Male"}, "8": {"effect": -0.04777777777777778, "value": 0.0}, "9": {"effect": -0.021111111111111112, "value": 0.0}, "10": {"effect": 0.07444444444444444, "value": 50.0}, "11": {"effect": 0.015555555555555557, "value": " United-States"}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 57.0, "features": {"0": {"effect": 0.05777777777777777, "value": 49.0}, "1": {"effect": -0.02888888888888889, "value": " Private"}, "2": {"effect": 0.1277777777777778, "value": 13.0}, "3": {"effect": -0.023333333333333334, "value": " Married-civ-spouse"}, "4": {"effect": -0.005555555555555559, "value": " Sales"}, "5": {"effect": 0.031111111111111114, "value": " Husband"}, "6": {"effect": 0.008888888888888887, "value": " White"}, "7": {"effect": 0.03888888888888889, "value": " Male"}, "8": {"effect": -0.05888888888888889, "value": 0.0}, "9": {"effect": -0.027777777777777773, "value": 0.0}, "10": {"effect": -0.2622222222222222, "value": 26.0}, "11": {"effect": 0.012222222222222225, "value": " United-States"}}}, {"outValue": -1.1102230246251565e-16, "simIndex": 15.0, "features": {"0": {"effect": -0.1977777777777778, "value": 34.0}, "1": {"effect": -0.01666666666666667, "value": " Private"}, "2": {"effect": 0.25888888888888884, "value": 13.0}, "3": {"effect": -0.022222222222222213, "value": " Married-civ-spouse"}, "4": {"effect": -0.19222222222222227, "value": " Exec-managerial"}, "5": {"effect": 0.05555555555555555, "value": " Husband"}, "6": {"effect": 0.0055555555555555575, "value": " White"}, "7": {"effect": 0.038888888888888896, "value": " Male"}, "8": {"effect": -0.048888888888888905, "value": 0.0}, "9": {"effect": -0.026666666666666672, "value": 0.0}, "10": {"effect": -0.005555555555555554, "value": 45.0}, "11": {"effect": 0.021111111111111112, "value": " United-States"}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 127.0, "features": {"0": {"effect": -0.01111111111111112, "value": 47.0}, "1": {"effect": -0.19333333333333333, "value": " Self-emp-not-inc"}, "2": {"effect": -0.21000000000000005, "value": 9.0}, "3": {"effect": -0.003333333333333324, "value": " Married-civ-spouse"}, "4": {"effect": -0.0411111111111111, "value": " Other-service"}, "5": {"effect": 0.2633333333333333, "value": " Wife"}, "6": {"effect": 0.013333333333333336, "value": " White"}, "7": {"effect": -0.10000000000000003, "value": " Female"}, "8": {"effect": -0.05666666666666667, "value": 0.0},  ...

# %%
order = plot.shap_force(shap_values_a_vs_b[idx_equal], 'A vs. B')
plot.shap_force(shap_values_a[idx_equal], 'A', ordering=order)
plot.shap_force(shap_values_b[idx_equal], 'B', ordering=order);
# Out:
# <div id='iQ4SC98S206F6HZJMZEFZ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": -0.24, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.0, "simIndex": 96.0, "features": {"0": {"effect": 0.033333333333333326, "value": 53.0}, "1": {"effect": 0.008888888888888887, "value": " Private"}, "2": {"effect": 0.04222222222222222, "value": 9.0}, "3": {"effect": 0.023333333333333338, "value": " Divorced"}, "4": {"effect": 0.03222222222222222, "value": " Sales"}, "5": {"effect": -0.0022222222222222227, "value": " Own-child"}, "6": {"effect": -0.004444444444444445, "value": " White"}, "7": {"effect": 0.06222222222222223, "value": " Female"}, "8": {"effect": -0.0055555555555555705, "value": 0.0}, "9": {"effect": -0.0011111111111111079, "value": 0.0}, "10": {"effect": 0.044444444444444446, "value": 35.0}, "11": {"effect": 0.006666666666666666, "value": " United-States"}}}, {"outValue": 1.1102230246251565e-16, "simIndex": 36.0, "features": {"0": {"effect": 0.03111111111111111, "value": 35.0}, "1": {"effect": 0.01444444444444445, "value": " Private"}, "2": {"effect": 0.11333333333333329, "value": 14.0}, "3": {"effect": -0.0011111111111111118, "value": " Married-civ-spouse"}, "4": {"effect": 0.035555555555555556, "value": " Prof-specialty"}, "5": {"effect": -0.09222222222222222, "value": " Other-relative"}, "6": {"effect": 0.010000000000000002, "value": " White"}, "7": {"effect": -0.007777777777777762, "value": " Male"}, "8": {"effect": 0.06222222222222229, "value": 7298.0}, "9": {"effect": 0.0011111111111111087, "value": 0.0}, "10": {"effect": 0.05444444444444447, "value": 40.0}, "11": {"effect": 0.018888888888888886, "value": " United-States"}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 61.0, "features": {"0": {"effect": 0.0, "value": 45.0}, "1": {"effect": 0.01555555555555556, "value": " Private"}, "2": {"effect": 0.03222222222222221, "value": 13.0}, "3": {"effect": -0.017777777777777788, "value": " Married-civ-spouse"}, "4": {"effect": 0.07444444444444445, "value": " Prof-specialty"}, "5": {"effect": -0.045555555555555516, "value": " Husband"}, "6": {"effect": 0.016666666666666666, "value": " White"}, "7": {"effect": 0.04444444444444445, "value": " Male"}, "8": {"effect": 0.033333333333333354, "value": 0.0}, "9": {"effect": 0.003333333333333313, "value": 0.0}, "10": {"effect": 0.0744444444444444, "value": 55.0}, "11": {"effect": 0.00888888888888889, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 273.0, "features": {"0": {"effect": 0.025555555555555554, "value": 53.0}, "1": {"effect": -0.013333333333333329, "value": " Local-gov"}, "2": {"effect": -0.00555555555555555, "value": 1.0}, "3": {"effect": 0.039999999999999994, "value": " Never-married"}, "4": {"effect": 0.054444444444444434, "value": " Machine-op-inspct"}, "5": {"effect": 0.03333333333333333, "value": " Not-in-family"}, "6": {"effect": 0.00888888888888889, "value": " White"}, "7": {"effect": -0.005555555555555557, "value": " Female"}, "8": {"effect": 0.011111111111111106, "value": 0.0}, "9": {"effect": 0.0022222222222222214, "value": 0.0}, "10": {"effect": 0.07888888888888891, "value": 35.0}, "11": {"effect": 0.01, "value": " United-States"}}}, {"outValue": 5.551115123125783e-17, "simIndex": 382.0, "features": {"0": {"effect": 0.042222222222222223, "value": 30.0}, "1": {"effect": 0.03777777777777777, "value": " ?"}, "2": {"effect": 0.03, "value": 11.0}, "3": {"effect": 0.07333333333333333, "value": " Divorced"}, "4": {"effect": 0.011111111111111106, "value": " ?"}, "5": {"effect": 0.02444444444444449, "value": " Unmarried"}, "6": {"effect": -0.002222222222222221, "value": " White"}, "7": {"effect": 0.012222222222222221, "value": " Female"}, "8": {"effect": 0.004444444444444445, "value": 0.0}, "9": {"effect": 0.0022222222222222253, "value": 0.0}, "10": {"effect" ...
# <div id='i97KQ523K5J5FMCOT82PW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0.37, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.0, "simIndex": 140.0, "features": {"0": {"effect": 0.025555555555555567, "value": 53.0}, "1": {"effect": 0.0, "value": " Private"}, "2": {"effect": -0.20111111111111107, "value": 9.0}, "3": {"effect": 0.05222222222222223, "value": " Divorced"}, "4": {"effect": 0.007777777777777776, "value": " Sales"}, "5": {"effect": -0.048888888888888885, "value": " Own-child"}, "6": {"effect": 0.0055555555555555575, "value": " White"}, "7": {"effect": -0.09666666666666668, "value": " Female"}, "8": {"effect": -0.0488888888888889, "value": 0.0}, "9": {"effect": -0.008888888888888894, "value": 0.0}, "10": {"effect": -0.05666666666666667, "value": 35.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": 0.9999999999999999, "simIndex": 473.0, "features": {"0": {"effect": -0.04222222222222222, "value": 35.0}, "1": {"effect": -0.0011111111111111122, "value": " Private"}, "2": {"effect": 0.3044444444444444, "value": 14.0}, "3": {"effect": -0.00333333333333333, "value": " Married-civ-spouse"}, "4": {"effect": -0.02333333333333333, "value": " Prof-specialty"}, "5": {"effect": -0.037777777777777785, "value": " Other-relative"}, "6": {"effect": 0.0, "value": " White"}, "7": {"effect": 0.018888888888888882, "value": " Male"}, "8": {"effect": 0.4422222222222222, "value": 7298.0}, "9": {"effect": -0.006666666666666666, "value": 0.0}, "10": {"effect": -0.02333333333333334, "value": 40.0}, "11": {"effect": 0.0022222222222222244, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 365.0, "features": {"0": {"effect": 0.06222222222222223, "value": 45.0}, "1": {"effect": -0.007777777777777778, "value": " Private"}, "2": {"effect": 0.38555555555555554, "value": 13.0}, "3": {"effect": 0.0022222222222222244, "value": " Married-civ-spouse"}, "4": {"effect": -0.014444444444444446, "value": " Prof-specialty"}, "5": {"effect": 0.13555555555555554, "value": " Husband"}, "6": {"effect": 0.001111111111111109, "value": " White"}, "7": {"effect": 0.003333333333333336, "value": " Male"}, "8": {"effect": -0.05666666666666668, "value": 0.0}, "9": {"effect": -0.019999999999999993, "value": 0.0}, "10": {"effect": 0.13888888888888892, "value": 55.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": 0.0, "simIndex": 188.0, "features": {"0": {"effect": 0.03333333333333334, "value": 53.0}, "1": {"effect": 0.018888888888888886, "value": " Local-gov"}, "2": {"effect": -0.04888888888888889, "value": 1.0}, "3": {"effect": -0.048888888888888885, "value": " Never-married"}, "4": {"effect": -0.04666666666666666, "value": " Machine-op-inspct"}, "5": {"effect": -0.09555555555555556, "value": " Not-in-family"}, "6": {"effect": 0.0, "value": " White"}, "7": {"effect": -0.05666666666666667, "value": " Female"}, "8": {"effect": -0.037777777777777785, "value": 0.0}, "9": {"effect": -0.0055555555555555575, "value": 0.0}, "10": {"effect": -0.08222222222222224, "value": 35.0}, "11": {"effect": 0.0, "value": " United-States"}}}, {"outValue": -5.551115123125783e-17, "simIndex": 148.0, "features": {"0": {"effect": -0.05888888888888889, "value": 30.0}, "1": {"effect": 0.032222222222222235, "value": " ?"}, "2": {"effect": -0.04555555555555555, "value": 11.0}, "3": {"effect": 0.01444444444444445, "value": " Divorced"}, "4": {"effect": -0.027777777777777776, "value": " ?"}, "5": {"effect": -0.20333333333333337, "value": " Unmarried"}, "6": {"effect": 0.004444444444444442, "value": " White"}, "7": {"effect": -0.02, "value": " Female"}, "8": {"effect": -0.04666666666666668, "value": 0.0}, "9": {"effect": -0.010000000000000002, "value": 0.0}, "10": {"effect": -0.008888888888888894, "value": 40.0}, "11": {"effect": 0.0, "value": " United-State ...
# <div id='iCKVLVEOKTK2RF8E7BO64'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": 0.13, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 2.7755575615628914e-17, "simIndex": 234.0, "features": {"0": {"effect": 0.05888888888888889, "value": 53.0}, "1": {"effect": 0.008888888888888887, "value": " Private"}, "2": {"effect": -0.15888888888888886, "value": 9.0}, "3": {"effect": 0.07555555555555557, "value": " Divorced"}, "4": {"effect": 0.04, "value": " Sales"}, "5": {"effect": -0.05111111111111111, "value": " Own-child"}, "6": {"effect": 0.0011111111111111122, "value": " White"}, "7": {"effect": -0.03444444444444445, "value": " Female"}, "8": {"effect": -0.05444444444444447, "value": 0.0}, "9": {"effect": -0.010000000000000002, "value": 0.0}, "10": {"effect": -0.012222222222222225, "value": 35.0}, "11": {"effect": 0.006666666666666666, "value": " United-States"}}}, {"outValue": 0.9999999999999999, "simIndex": 135.0, "features": {"0": {"effect": -0.011111111111111106, "value": 35.0}, "1": {"effect": 0.01333333333333334, "value": " Private"}, "2": {"effect": 0.4177777777777777, "value": 14.0}, "3": {"effect": -0.004444444444444442, "value": " Married-civ-spouse"}, "4": {"effect": 0.012222222222222225, "value": " Prof-specialty"}, "5": {"effect": -0.13, "value": " Other-relative"}, "6": {"effect": 0.010000000000000002, "value": " White"}, "7": {"effect": 0.01111111111111112, "value": " Male"}, "8": {"effect": 0.5044444444444445, "value": 7298.0}, "9": {"effect": -0.0055555555555555575, "value": 0.0}, "10": {"effect": 0.031111111111111128, "value": 40.0}, "11": {"effect": 0.021111111111111112, "value": " United-States"}}}, {"outValue": 1.0, "simIndex": 184.0, "features": {"0": {"effect": 0.06222222222222223, "value": 45.0}, "1": {"effect": 0.007777777777777782, "value": " Private"}, "2": {"effect": 0.41777777777777775, "value": 13.0}, "3": {"effect": -0.015555555555555564, "value": " Married-civ-spouse"}, "4": {"effect": 0.060000000000000005, "value": " Prof-specialty"}, "5": {"effect": 0.09000000000000002, "value": " Husband"}, "6": {"effect": 0.017777777777777774, "value": " White"}, "7": {"effect": 0.04777777777777779, "value": " Male"}, "8": {"effect": -0.023333333333333324, "value": 0.0}, "9": {"effect": -0.01666666666666668, "value": 0.0}, "10": {"effect": 0.21333333333333332, "value": 55.0}, "11": {"effect": 0.00888888888888889, "value": " United-States"}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 283.0, "features": {"0": {"effect": 0.05888888888888889, "value": 53.0}, "1": {"effect": 0.0055555555555555575, "value": " Local-gov"}, "2": {"effect": -0.05444444444444444, "value": 1.0}, "3": {"effect": -0.008888888888888887, "value": " Never-married"}, "4": {"effect": 0.007777777777777776, "value": " Machine-op-inspct"}, "5": {"effect": -0.06222222222222223, "value": " Not-in-family"}, "6": {"effect": 0.00888888888888889, "value": " White"}, "7": {"effect": -0.06222222222222223, "value": " Female"}, "8": {"effect": -0.02666666666666668, "value": 0.0}, "9": {"effect": -0.003333333333333336, "value": 0.0}, "10": {"effect": -0.003333333333333333, "value": 35.0}, "11": {"effect": 0.01, "value": " United-States"}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 417.0, "features": {"0": {"effect": -0.01666666666666667, "value": 30.0}, "1": {"effect": 0.07, "value": " ?"}, "2": {"effect": -0.015555555555555552, "value": 11.0}, "3": {"effect": 0.08777777777777779, "value": " Divorced"}, "4": {"effect": -0.01666666666666667, "value": " ?"}, "5": {"effect": -0.17888888888888888, "value": " Unmarried"}, "6": {"effect": 0.002222222222222221, "value": " White"}, "7": {"effect": -0.007777777777777778, "value": " Female"}, "8": {"effect": -0.04222222222222224, "value": 0.0}, "9": {"effect": -0.007777777777777777, "value": 0.0}, "10": {"effect": ...

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %%
plot.shap_heatmap(shap_values_a[idx_equal], 'A', feature_order)
plot.shap_heatmap(shap_values_b[idx_equal], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[idx_equal], 'A vs. B', feature_order)

# %%
plot.shap_heatmap(shap_values_a[idx_diff], 'A', feature_order)
plot.shap_heatmap(shap_values_b[idx_diff], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[idx_diff], 'A vs. B', feature_order)
