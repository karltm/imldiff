# %%
import plot
from scipy.special import logit
from shap.maskers import Independent
from sklearn.utils import resample, shuffle
import shap
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open('classifiers.pickle', 'rb') as f:
    clf_a, clf_b = pickle.load(f)
with open('predictions.pickle', 'rb') as f:
    X, display_data, feature_names, n_features, n_samples, indices, pred_a, pred_b, proba_a, proba_b, log_proba_a, log_proba_b, log_odds_a, log_odds_b = pickle.load(f)
with open('subsets.pickle', 'rb') as f:
    is_pred_diff, is_pred_diff_a_pos, is_pred_diff_b_pos, proba_diff_a_pos, proba_diff_b_pos, proba_diff, log_odds_diff_a_pos, log_odds_diff_b_pos, log_odds_diff = pickle.load(f)

idx_sample_pred_equal = indices[~is_pred_diff]
idx_sample_pred_diff = indices[is_pred_diff]
if idx_sample_pred_equal.shape[0] > 500:
    idx_sample_pred_equal = shuffle(idx_sample_pred_equal, random_state=42, n_samples=500)
if idx_sample_pred_diff.shape[0] > 500:
    idx_sample_pred_diff = shuffle(idx_sample_pred_diff, random_state=42, n_samples=500)
idx_sample = np.union1d(idx_sample_pred_equal, idx_sample_pred_diff)

X = X.iloc[idx_sample, :]
display_data = display_data[idx_sample]
pred_a = pred_a[idx_sample]
pred_b = pred_b[idx_sample]
proba_a = proba_a[idx_sample]
proba_b = proba_b[idx_sample]
log_proba_a  =  log_proba_a[idx_sample]
log_proba_b  = log_proba_b[idx_sample]
log_odds_a = log_odds_a[idx_sample]
log_odds_b = log_odds_b[idx_sample]
is_pred_diff = is_pred_diff[idx_sample]
is_pred_diff_a_pos = is_pred_diff_a_pos[idx_sample]
is_pred_diff_b_pos = is_pred_diff_b_pos[idx_sample]
proba_diff_a_pos = proba_diff_a_pos[idx_sample]
proba_diff_b_pos = proba_diff_b_pos[idx_sample]
proba_diff = proba_diff[idx_sample]
log_odds_diff_a_pos = log_odds_diff_a_pos[idx_sample]
log_odds_diff_b_pos = log_odds_diff_b_pos[idx_sample]
log_odds_diff = log_odds_diff[idx_sample]

n_samples = X.shape[0]
indices = np.array(range(n_samples))

# %%
try:
    with open(f'shapvalues.soa.proba.pickle', 'rb') as f:
        shap_values_a, shap_values_b, shap_values_a_vs_b, feature_order = pickle.load(f)
        print('Loaded cached shap values')
except FileNotFoundError:
    print('No cached shap values found')
# Out:
# Loaded cached shap values

# %% [markdown]
# ## Generate Explanations

# %% [markdown]
# Now we define the functions to be explained:

# %%
predict_proba_a = lambda X: clf_a.predict_proba(X)[:, 1]
predict_proba_b = lambda X: clf_b.predict_proba(X)[:, 1]

# %% [markdown]
# And now we calculate SHAP values for each function:

# %%
# %%time

background_data = X
def explain(predict):
    masker = Independent(data=background_data, max_samples=100)
    explainer = shap.Explainer(predict, masker, feature_names=feature_names)
    shap_values = explainer(X)
    shap_values.display_data = display_data
    return shap_values

shap_values_a = explain(predict_proba_a)
shap_values_b = explain(predict_proba_b)

shap_values_a_vs_b = shap_values_b - shap_values_a
shap_values_a_vs_b.data = shap_values_a.data
shap_values_a_vs_b.display_data = shap_values_a.display_data

feature_order = np.flip(shap_values_a_vs_b.abs.mean(axis=0).values.argsort())

with open(f'shapvalues.soa.proba.pickle', 'wb') as f:
    pickle.dump((shap_values_a, shap_values_b, shap_values_a_vs_b, feature_order), f, pickle.HIGHEST_PROTOCOL)
# Out:
# Permutation explainer: 697it [00:27, 19.08it/s]
# Permutation explainer: 697it [00:20, 16.32it/s]
# CPU times: user 1min 11s, sys: 6.26 s, total: 1min 17s
# Wall time: 47.8 s

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# We estimate it with the mean absolute SHAP value (which is the default for this plot) and will also sort features subsequently in this order

# %%
shap.plots.bar(shap_values_a, order=feature_order, max_display=n_features)
shap.plots.bar(shap_values_b, order=feature_order, max_display=n_features)
shap.plots.bar(shap_values_a_vs_b, order=feature_order, max_display=n_features)

# %% [markdown]
# ### SHAP Value Distribution

# %%
shap.plots.beeswarm(shap_values_a, order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_a[pred_a != pred_b], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %%
shap.plots.beeswarm(shap_values_b, order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_b[pred_a != pred_b], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %%
shap.plots.beeswarm(shap_values_a_vs_b, order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_a_vs_b[pred_a != pred_b], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %% [markdown]
# ### Features' Partial Dependence Plots

# %%
n_columns = 3
n_rows = n_features
fig = plt.figure(figsize=(9*n_columns, 7*n_rows))
i = 1
for feature in feature_names[feature_order]:
    ax1 = fig.add_subplot(n_rows, n_columns, i)
    ax2 = fig.add_subplot(n_rows, n_columns, i+1, sharey=ax1)
    ax3 = fig.add_subplot(n_rows, n_columns, i+2, sharey=None)
    shap.plots.scatter(shap_values_a[:, feature], title='A', ax=ax1, color='blue', show=False)
    shap.plots.scatter(shap_values_a[pred_a != pred_b, feature], title='A', ax=ax1, color='red', hist=False, show=False)
    shap.plots.scatter(shap_values_b[:, feature], title='B', ax=ax2, color='blue', show=False)
    shap.plots.scatter(shap_values_b[pred_a != pred_b, feature], title='B', ax=ax2, color='red', hist=False, show=False)
    shap.plots.scatter(shap_values_a_vs_b[:, feature], title='B - A', ax=ax3, color='blue', show=False)
    shap.plots.scatter(shap_values_a_vs_b[pred_a != pred_b, feature], title='B - A', ax=ax3, color='red', hist=False, show=False)
    i += n_columns
plt.show()
# Out:
# Passing the fontdict parameter of _set_ticklabels() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %%
idx_diff = indices[pred_a != pred_b]
idx_equal = indices[pred_a == pred_b]
if len(idx_diff) > 500:
    idx_diff = shuffle(idx_diff, random_state=0, n_samples=500)
if len(idx_equal) > 500:
    idx_equal = shuffle(idx_equal, random_state=0, n_samples=500)

# %%
order = plot.shap_force(shap_values_a_vs_b[idx_diff], 'A vs. B')
plot.shap_force(shap_values_a[idx_diff], 'A', ordering=order)
plot.shap_force(shap_values_b[idx_diff], 'B', ordering=order);
# Out:
# <div id='iV6GAAHN96Y4NKGZVNFVE'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": -0.007616821338199409, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": -0.012498408270737544, "simIndex": 147.0, "features": {"0": {"effect": 0.0009604812171274159, "value": 37.0}, "1": {"effect": 0.0009235529514068795, "value": " Private"}, "2": {"effect": -0.009990483888199723, "value": 10.0}, "3": {"effect": -0.000148309987102709, "value": " Married-civ-spouse"}, "4": {"effect": -0.0010033710034107381, "value": " Exec-managerial"}, "5": {"effect": -0.014695749696463978, "value": " Husband"}, "6": {"effect": -0.00010896916336850665, "value": " Black"}, "7": {"effect": -0.0004879365098540492, "value": " Male"}, "8": {"effect": 0.003459272689605726, "value": 0.0}, "9": {"effect": 0.0016248299992583006, "value": 0.0}, "10": {"effect": 0.014643059611511633, "value": 80.0}, "11": {"effect": -5.79631530483861e-05, "value": " United-States"}}}, {"outValue": -0.012498136602999567, "simIndex": 15.0, "features": {"0": {"effect": 0.0049282323897909125, "value": 24.0}, "1": {"effect": 2.601752445815142e-05, "value": " Private"}, "2": {"effect": -0.008296078472396246, "value": 13.0}, "3": {"effect": -0.00048763230556469724, "value": " Married-civ-spouse"}, "4": {"effect": -0.001185556742997241, "value": " Tech-support"}, "5": {"effect": 0.008054113861986331, "value": " Husband"}, "6": {"effect": -2.1227199088236746e-05, "value": " White"}, "7": {"effect": 7.296523314832826e-05, "value": " Male"}, "8": {"effect": -0.0003754712607505692, "value": 0.0}, "9": {"effect": -0.00038788899170113904, "value": 0.0}, "10": {"effect": -0.007227408930096289, "value": 50.0}, "11": {"effect": 1.861962841053714e-05, "value": " United-States"}}}, {"outValue": -0.01249915098954737, "simIndex": 36.0, "features": {"0": {"effect": -0.005152816510644885, "value": 49.0}, "1": {"effect": -0.0006353121962576017, "value": " Private"}, "2": {"effect": 0.018493009154251006, "value": 13.0}, "3": {"effect": 0.00012280068170857864, "value": " Married-civ-spouse"}, "4": {"effect": -0.0006708500721032667, "value": " Sales"}, "5": {"effect": -0.01291952992025483, "value": " Husband"}, "6": {"effect": -0.000290611480556085, "value": " White"}, "7": {"effect": -0.0036472589520399334, "value": " Male"}, "8": {"effect": -0.000976539652161601, "value": 0.0}, "9": {"effect": 0.0004423929792773604, "value": 0.0}, "10": {"effect": 0.0002172536909659517, "value": 26.0}, "11": {"effect": 0.000135132626467348, "value": " United-States"}}}, {"outValue": -0.012499345537854782, "simIndex": 39.0, "features": {"0": {"effect": -0.002287626767162633, "value": 34.0}, "1": {"effect": -0.00046379989653679466, "value": " Private"}, "2": {"effect": 0.00961960207584181, "value": 13.0}, "3": {"effect": 0.002445710550428893, "value": " Married-civ-spouse"}, "4": {"effect": -0.0009347763934511692, "value": " Exec-managerial"}, "5": {"effect": -0.01832938355517788, "value": " Husband"}, "6": {"effect": 0.0008071058788987617, "value": " White"}, "7": {"effect": 0.0037895436090130442, "value": " Male"}, "8": {"effect": 0.0005887550619025558, "value": 0.0}, "9": {"effect": 0.000735633544449131, "value": 0.0}, "10": {"effect": -0.0008311853945895155, "value": 45.0}, "11": {"effect": -2.210291327157791e-05, "value": " United-States"}}}, {"outValue": -0.01249812815138693, "simIndex": 26.0, "features": {"0": {"effect": 0.0020724806022567287, "value": 47.0}, "1": {"effect": 0.0024286975601873397, "value": " Self-emp-not-inc"}, "2": {"effect": 0.005116830005743339, "value": 9.0}, "3": {"effect": -0.00018040095623008008, "value": " Married-civ-spouse"}, "4": {"effect": -0.0004573945258438191, "value": " Other-service"}, "5": {"effect": -0.0022551354017842085, "value": " Wife"}, "6": {"effect": 0.000488678011853292, "value": " Whit ...
# <div id='iWJLKW6B64EH0GVB6QP9Z'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0.31224637444466624, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.5019118540026638, "simIndex": 147.0, "features": {"0": {"effect": -0.030510955067869345, "value": 37.0}, "1": {"effect": -0.001331741306794834, "value": " Private"}, "2": {"effect": -0.03591587912073814, "value": 10.0}, "3": {"effect": 0.00030629244187840854, "value": " Married-civ-spouse"}, "4": {"effect": -0.00922847984455947, "value": " Exec-managerial"}, "5": {"effect": 0.09824817376293576, "value": " Husband"}, "6": {"effect": -0.027786312714739192, "value": " Black"}, "7": {"effect": 0.01762665805217004, "value": " Male"}, "8": {"effect": -0.03710306123935839, "value": 0.0}, "9": {"effect": -0.012115035613054437, "value": 0.0}, "10": {"effect": 0.2264787335472223, "value": 80.0}, "11": {"effect": 0.0009970866609048668, "value": " United-States"}}}, {"outValue": 0.5013251069734673, "simIndex": 124.0, "features": {"0": {"effect": -0.1083509697265402, "value": 24.0}, "1": {"effect": -0.0009310616651592286, "value": " Private"}, "2": {"effect": 0.1592922887138666, "value": 13.0}, "3": {"effect": 0.00035700527409261566, "value": " Married-civ-spouse"}, "4": {"effect": 0.017987485878901248, "value": " Tech-support"}, "5": {"effect": 0.08687154825503512, "value": " Husband"}, "6": {"effect": 0.004537362671999818, "value": " White"}, "7": {"effect": 0.018039576948039895, "value": " Male"}, "8": {"effect": -0.03545060035868866, "value": 0.0}, "9": {"effect": -0.011459588187549379, "value": 0.0}, "10": {"effect": 0.05723300010005507, "value": 50.0}, "11": {"effect": 0.0009526846247482038, "value": " United-States"}}}, {"outValue": 0.5082394943435554, "simIndex": 118.0, "features": {"0": {"effect": 0.043915947497308615, "value": 49.0}, "1": {"effect": -0.0005597566231501588, "value": " Private"}, "2": {"effect": 0.14216558095882567, "value": 13.0}, "3": {"effect": 0.0008766064952894657, "value": " Married-civ-spouse"}, "4": {"effect": 0.014848459021654749, "value": " Sales"}, "5": {"effect": 0.10061272373824412, "value": " Husband"}, "6": {"effect": 0.0050188738214894295, "value": " White"}, "7": {"effect": 0.021492010620177495, "value": " Male"}, "8": {"effect": -0.034007648374927237, "value": 0.0}, "9": {"effect": -0.011687718061288275, "value": 0.0}, "10": {"effect": -0.08761955117334491, "value": 26.0}, "11": {"effect": 0.0009375919786101867, "value": " United-States"}}}, {"outValue": 0.5065127622938541, "simIndex": 114.0, "features": {"0": {"effect": -0.04886095612579782, "value": 34.0}, "1": {"effect": -0.000728561940815843, "value": " Private"}, "2": {"effect": 0.14788252811764052, "value": 13.0}, "3": {"effect": -0.0006648176866287041, "value": " Married-civ-spouse"}, "4": {"effect": -0.00996675820960349, "value": " Exec-managerial"}, "5": {"effect": 0.10001148949121408, "value": " Husband"}, "6": {"effect": 0.004765289770717002, "value": " White"}, "7": {"effect": 0.02111192694000985, "value": " Male"}, "8": {"effect": -0.035123131719871574, "value": 0.0}, "9": {"effect": -0.011466684050064319, "value": 0.0}, "10": {"effect": 0.026299836199012154, "value": 45.0}, "11": {"effect": 0.0010062270633760344, "value": " United-States"}}}, {"outValue": 0.5013079700854227, "simIndex": 144.0, "features": {"0": {"effect": 0.029283244809374696, "value": 47.0}, "1": {"effect": -0.017450201125755127, "value": " Self-emp-not-inc"}, "2": {"effect": -0.10622108999075544, "value": 9.0}, "3": {"effect": 0.0008484546182463045, "value": " Married-civ-spouse"}, "4": {"effect": 0.002387315414147378, "value": " Other-service"}, "5": {"effect": 0.18801666932543143, "value": " Wife"}, "6": {"effect": 0.0035541544887559345, "value": " White"}, "7": {"effect": -0.07274452127461492, "value": " Female"}, "8":  ...
# <div id='iGETW8VWG8ASOXRNF6H1C'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": 0.30462955310646683, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.48941344573192624, "simIndex": 43.0, "features": {"0": {"effect": -0.02955047385074193, "value": 37.0}, "1": {"effect": -0.00040818835538795434, "value": " Private"}, "2": {"effect": -0.04590636300893786, "value": 10.0}, "3": {"effect": 0.00015798245477569953, "value": " Married-civ-spouse"}, "4": {"effect": -0.010231850847970209, "value": " Exec-managerial"}, "5": {"effect": 0.08355242406647179, "value": " Husband"}, "6": {"effect": -0.0278952818781077, "value": " Black"}, "7": {"effect": 0.01713872154231599, "value": " Male"}, "8": {"effect": -0.03364378854975266, "value": 0.0}, "9": {"effect": -0.010490205613796136, "value": 0.0}, "10": {"effect": 0.24112179315873394, "value": 80.0}, "11": {"effect": 0.0009391235078564807, "value": " United-States"}}}, {"outValue": 0.4888269703704678, "simIndex": 161.0, "features": {"0": {"effect": -0.10342273733674928, "value": 24.0}, "1": {"effect": -0.0009050441407010772, "value": " Private"}, "2": {"effect": 0.15099621024147036, "value": 13.0}, "3": {"effect": -0.00013062703147208155, "value": " Married-civ-spouse"}, "4": {"effect": 0.016801929135904007, "value": " Tech-support"}, "5": {"effect": 0.09492566211702146, "value": " Husband"}, "6": {"effect": 0.0045161354729115815, "value": " White"}, "7": {"effect": 0.018112542181188223, "value": " Male"}, "8": {"effect": -0.03582607161943923, "value": 0.0}, "9": {"effect": -0.011847477179250518, "value": 0.0}, "10": {"effect": 0.05000559116995878, "value": 50.0}, "11": {"effect": 0.0009713042531587409, "value": " United-States"}}}, {"outValue": 0.495740343354008, "simIndex": 180.0, "features": {"0": {"effect": 0.03876313098666373, "value": 49.0}, "1": {"effect": -0.0011950688194077605, "value": " Private"}, "2": {"effect": 0.16065859011307668, "value": 13.0}, "3": {"effect": 0.0009994071769980444, "value": " Married-civ-spouse"}, "4": {"effect": 0.014177608949551482, "value": " Sales"}, "5": {"effect": 0.08769319381798929, "value": " Husband"}, "6": {"effect": 0.0047282623409333445, "value": " White"}, "7": {"effect": 0.01784475166813756, "value": " Male"}, "8": {"effect": -0.03498418802708884, "value": 0.0}, "9": {"effect": -0.011245325082010914, "value": 0.0}, "10": {"effect": -0.08740229748237896, "value": 26.0}, "11": {"effect": 0.0010727246050775347, "value": " United-States"}}}, {"outValue": 0.49401341675599936, "simIndex": 101.0, "features": {"0": {"effect": -0.051148582892960454, "value": 34.0}, "1": {"effect": -0.0011923618373526376, "value": " Private"}, "2": {"effect": 0.15750213019348233, "value": 13.0}, "3": {"effect": 0.0017808928638001888, "value": " Married-civ-spouse"}, "4": {"effect": -0.01090153460305466, "value": " Exec-managerial"}, "5": {"effect": 0.0816821059360362, "value": " Husband"}, "6": {"effect": 0.005572395649615764, "value": " White"}, "7": {"effect": 0.024901470549022895, "value": " Male"}, "8": {"effect": -0.03453437665796902, "value": 0.0}, "9": {"effect": -0.010731050505615188, "value": 0.0}, "10": {"effect": 0.02546865080442264, "value": 45.0}, "11": {"effect": 0.0009841241501044565, "value": " United-States"}}}, {"outValue": 0.48880984193403576, "simIndex": 40.0, "features": {"0": {"effect": 0.031355725411631424, "value": 47.0}, "1": {"effect": -0.015021503565567787, "value": " Self-emp-not-inc"}, "2": {"effect": -0.1011042599850121, "value": 9.0}, "3": {"effect": 0.0006680536620162244, "value": " Married-civ-spouse"}, "4": {"effect": 0.0019299208883035589, "value": " Other-service"}, "5": {"effect": 0.18576153392364722, "value": " Wife"}, "6": {"effect": 0.0040428325006092265, "value": " White"}, "7": {"effect": -0.07090991804043964, "value": " Female"}, "8": ...

# %%
order = plot.shap_force(shap_values_a_vs_b[idx_equal], 'A vs. B')
plot.shap_force(shap_values_a[idx_equal], 'A', ordering=order)
plot.shap_force(shap_values_b[idx_equal], 'B', ordering=order);
# Out:
# <div id='iDLY6OTLVKOHCDECUIRXL'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": -0.007616821338199409, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": -0.006878428620529616, "simIndex": 136.0, "features": {"0": {"effect": -0.004796620759465103, "value": 53.0}, "1": {"effect": -6.587094805657963e-06, "value": " Private"}, "2": {"effect": 0.005508416120102236, "value": 9.0}, "3": {"effect": -0.0005345746321243974, "value": " Divorced"}, "4": {"effect": -0.0003779269755360727, "value": " Sales"}, "5": {"effect": -0.0018742485761186894, "value": " Own-child"}, "6": {"effect": -0.00021301843004762743, "value": " White"}, "7": {"effect": 0.001962417718219922, "value": " Female"}, "8": {"effect": -0.0010828239617274027, "value": 0.0}, "9": {"effect": -0.00010171776927718999, "value": 0.0}, "10": {"effect": 0.0023461603099681934, "value": 35.0}, "11": {"effect": -9.108323151841809e-05, "value": " United-States"}}}, {"outValue": -0.006968507200139363, "simIndex": 23.0, "features": {"0": {"effect": 0.0077896160378177065, "value": 35.0}, "1": {"effect": -0.0004913791073428061, "value": " Private"}, "2": {"effect": -0.02463700255642773, "value": 14.0}, "3": {"effect": 0.0018581881862756813, "value": " Married-civ-spouse"}, "4": {"effect": 0.00032118398499430493, "value": " Prof-specialty"}, "5": {"effect": 0.02128221409999595, "value": " Other-relative"}, "6": {"effect": -0.0002034530267173893, "value": " White"}, "7": {"effect": 0.001920752887981424, "value": " Male"}, "8": {"effect": -0.006775610118333775, "value": 7298.0}, "9": {"effect": 0.002331341272726041, "value": 0.0}, "10": {"effect": -0.002622958273915831, "value": 40.0}, "11": {"effect": -0.0001245792489935338, "value": " United-States"}}}, {"outValue": -0.010822579537144519, "simIndex": 68.0, "features": {"0": {"effect": 0.0005233934523057385, "value": 45.0}, "1": {"effect": 0.0004990510723432029, "value": " Private"}, "2": {"effect": -0.01564938887378106, "value": 13.0}, "3": {"effect": 0.0008943269877360111, "value": " Married-civ-spouse"}, "4": {"effect": -0.000575514959483079, "value": " Prof-specialty"}, "5": {"effect": 0.006075045768200185, "value": " Husband"}, "6": {"effect": -0.0003641642144417423, "value": " White"}, "7": {"effect": -0.0017024762590758385, "value": " Male"}, "8": {"effect": -0.0037324703448605168, "value": 0.0}, "9": {"effect": 0.0007414353108013347, "value": 0.0}, "10": {"effect": 0.010077130823492514, "value": 55.0}, "11": {"effect": 7.873037818141452e-06, "value": " United-States"}}}, {"outValue": -5.5439253057587914e-05, "simIndex": 433.0, "features": {"0": {"effect": 0.003379443338769883, "value": 53.0}, "1": {"effect": 0.002515261169017964, "value": " Local-gov"}, "2": {"effect": -0.0008030667677746961, "value": 1.0}, "3": {"effect": 0.0005871775975303493, "value": " Never-married"}, "4": {"effect": 2.2823782063606578e-05, "value": " Machine-op-inspct"}, "5": {"effect": 0.01462967891973789, "value": " Not-in-family"}, "6": {"effect": -0.0005935458346566817, "value": " White"}, "7": {"effect": 0.0024849593121807276, "value": " Female"}, "8": {"effect": -0.0043401403003944, "value": 0.0}, "9": {"effect": 0.0015248882387276117, "value": 0.0}, "10": {"effect": -0.012257701321722101, "value": 35.0}, "11": {"effect": 0.00041160395166166627, "value": " United-States"}}}, {"outValue": -0.0032132001165969155, "simIndex": 30.0, "features": {"0": {"effect": 0.0028946396390334764, "value": 30.0}, "1": {"effect": -0.0031913893967189626, "value": " ?"}, "2": {"effect": 0.004425815985669364, "value": 11.0}, "3": {"effect": 0.007121435554443223, "value": " Divorced"}, "4": {"effect": -0.00010060229917070555, "value": " ?"}, "5": {"effect": 0.011814024861434735, "value": " Unmarried"}, "6": {"effect": -0.0001496635164399537, "value": " White"}, "7": {"effect": ...
# <div id='iS3J69Q6UTF5MGD017BLE'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0.31224637444466624, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.16815635334159784, "simIndex": 447.0, "features": {"0": {"effect": 0.048657068972625624, "value": 53.0}, "1": {"effect": -0.00015475721143006708, "value": " Private"}, "2": {"effect": -0.10776442553126432, "value": 9.0}, "3": {"effect": 0.05579135435919796, "value": " Divorced"}, "4": {"effect": 0.01127189804747886, "value": " Sales"}, "5": {"effect": -0.018093173075155712, "value": " Own-child"}, "6": {"effect": 0.003333981758473167, "value": " White"}, "7": {"effect": -0.06023110451531929, "value": " Female"}, "8": {"effect": -0.03658687647199795, "value": 0.0}, "9": {"effect": -0.009829920070840133, "value": 0.0}, "10": {"effect": -0.03128441684785574, "value": 35.0}, "11": {"effect": 0.0008003494830192168, "value": " United-States"}}}, {"outValue": 0.8360695235437261, "simIndex": 19.0, "features": {"0": {"effect": -0.025679807744660617, "value": 35.0}, "1": {"effect": -0.0002655624775024019, "value": " Private"}, "2": {"effect": 0.21061660231955748, "value": 14.0}, "3": {"effect": -0.0002460831100651533, "value": " Married-civ-spouse"}, "4": {"effect": 0.0063835571048055, "value": " Prof-specialty"}, "5": {"effect": -0.06980778642004043, "value": " Other-relative"}, "6": {"effect": 0.00407087210009282, "value": " White"}, "7": {"effect": 0.015291888334350289, "value": " Male"}, "8": {"effect": 0.39132512570800077, "value": 7298.0}, "9": {"effect": -0.01006982972750067, "value": 0.0}, "10": {"effect": 0.0014318859959082356, "value": 40.0}, "11": {"effect": 0.0007722870161141081, "value": " United-States"}}}, {"outValue": 0.6885303742776423, "simIndex": 250.0, "features": {"0": {"effect": 0.021380396618706665, "value": 45.0}, "1": {"effect": -0.0012245101588509938, "value": " Private"}, "2": {"effect": 0.17584252675965317, "value": 13.0}, "3": {"effect": -0.0004326980526640181, "value": " Married-civ-spouse"}, "4": {"effect": 0.008742368686489286, "value": " Prof-specialty"}, "5": {"effect": 0.0986410380596794, "value": " Husband"}, "6": {"effect": 0.004410542747464694, "value": " White"}, "7": {"effect": 0.021586634329209986, "value": " Male"}, "8": {"effect": -0.03073138457848275, "value": 0.0}, "9": {"effect": -0.010905716065426452, "value": 0.0}, "10": {"effect": 0.08802033636945053, "value": 55.0}, "11": {"effect": 0.000954465117746433, "value": " United-States"}}}, {"outValue": 0.0011379675570332703, "simIndex": 144.0, "features": {"0": {"effect": 0.006060069527146609, "value": 53.0}, "1": {"effect": 0.005190796971432573, "value": " Local-gov"}, "2": {"effect": -0.15855323301883326, "value": 1.0}, "3": {"effect": -0.01709465995346731, "value": " Never-married"}, "4": {"effect": -0.0004675393173167455, "value": " Machine-op-inspct"}, "5": {"effect": -0.09144589297011911, "value": " Not-in-family"}, "6": {"effect": 0.0015330638236523955, "value": " White"}, "7": {"effect": -0.024089169755525552, "value": " Female"}, "8": {"effect": -0.018758232813276186, "value": 0.0}, "9": {"effect": -0.00562890384061717, "value": 0.0}, "10": {"effect": -0.008043933351192972, "value": 35.0}, "11": {"effect": 0.0001892278104837553, "value": " United-States"}}}, {"outValue": 0.07064814375908149, "simIndex": 207.0, "features": {"0": {"effect": -0.0503246825197112, "value": 30.0}, "1": {"effect": 0.01819892005961746, "value": " ?"}, "2": {"effect": -0.0002644573022808041, "value": 11.0}, "3": {"effect": 0.03828859238369087, "value": " Divorced"}, "4": {"effect": -0.012961061680933432, "value": " ?"}, "5": {"effect": -0.15863964050156235, "value": " Unmarried"}, "6": {"effect": 0.0025591833565176206, "value": " White"}, "7": {"effect": -0.030148703020261482, "value": " Female"}, "8": {"effect": -0.0 ...
# <div id='i67HOC94DX69EUUML0ZTQ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": 0.30462955310646683, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.16127792472106825, "simIndex": 175.0, "features": {"0": {"effect": 0.04386044821316052, "value": 53.0}, "1": {"effect": -0.00016134430623572504, "value": " Private"}, "2": {"effect": -0.10225600941116209, "value": 9.0}, "3": {"effect": 0.05525677972707356, "value": " Divorced"}, "4": {"effect": 0.010893971071942787, "value": " Sales"}, "5": {"effect": -0.0199674216512744, "value": " Own-child"}, "6": {"effect": 0.0031209633284255394, "value": " White"}, "7": {"effect": -0.058268686797099366, "value": " Female"}, "8": {"effect": -0.037669700433725355, "value": 0.0}, "9": {"effect": -0.009931637840117323, "value": 0.0}, "10": {"effect": -0.028938256537887546, "value": 35.0}, "11": {"effect": 0.0007092662515007987, "value": " United-States"}}}, {"outValue": 0.8291010163435868, "simIndex": 322.0, "features": {"0": {"effect": -0.01789019170684291, "value": 35.0}, "1": {"effect": -0.000756941584845208, "value": " Private"}, "2": {"effect": 0.18597959976312975, "value": 14.0}, "3": {"effect": 0.001612105076210528, "value": " Married-civ-spouse"}, "4": {"effect": 0.006704741089799805, "value": " Prof-specialty"}, "5": {"effect": -0.04852557232004448, "value": " Other-relative"}, "6": {"effect": 0.0038674190733754307, "value": " White"}, "7": {"effect": 0.017212641222331713, "value": " Male"}, "8": {"effect": 0.384549515589667, "value": 7298.0}, "9": {"effect": -0.0077384884547746285, "value": 0.0}, "10": {"effect": -0.001191072278007595, "value": 40.0}, "11": {"effect": 0.0006477077671205743, "value": " United-States"}}}, {"outValue": 0.6777077947404977, "simIndex": 280.0, "features": {"0": {"effect": 0.021903790071012404, "value": 45.0}, "1": {"effect": -0.000725459086507791, "value": " Private"}, "2": {"effect": 0.1601931378858721, "value": 13.0}, "3": {"effect": 0.00046162893507199304, "value": " Married-civ-spouse"}, "4": {"effect": 0.008166853727006207, "value": " Prof-specialty"}, "5": {"effect": 0.10471608382787959, "value": " Husband"}, "6": {"effect": 0.004046378533022952, "value": " White"}, "7": {"effect": 0.019884158070134147, "value": " Male"}, "8": {"effect": -0.034463854923343265, "value": 0.0}, "9": {"effect": -0.010164280754625117, "value": 0.0}, "10": {"effect": 0.09809746719294304, "value": 55.0}, "11": {"effect": 0.0009623381555645744, "value": " United-States"}}}, {"outValue": 0.001082528303975705, "simIndex": 182.0, "features": {"0": {"effect": 0.009439512865916492, "value": 53.0}, "1": {"effect": 0.0077060581404505375, "value": " Local-gov"}, "2": {"effect": -0.15935629978660795, "value": 1.0}, "3": {"effect": -0.01650748235593696, "value": " Never-married"}, "4": {"effect": -0.00044471553525313894, "value": " Machine-op-inspct"}, "5": {"effect": -0.07681621405038122, "value": " Not-in-family"}, "6": {"effect": 0.0009395179889957138, "value": " White"}, "7": {"effect": -0.021604210443344825, "value": " Female"}, "8": {"effect": -0.023098373113670585, "value": 0.0}, "9": {"effect": -0.004104015601889558, "value": 0.0}, "10": {"effect": -0.020301634672915073, "value": 35.0}, "11": {"effect": 0.0006008317621454216, "value": " United-States"}}}, {"outValue": 0.06743494364248456, "simIndex": 191.0, "features": {"0": {"effect": -0.047430042880677724, "value": 30.0}, "1": {"effect": 0.015007530662898498, "value": " ?"}, "2": {"effect": 0.004161358683388561, "value": 11.0}, "3": {"effect": 0.04541002793813409, "value": " Divorced"}, "4": {"effect": -0.013061663980104138, "value": " ?"}, "5": {"effect": -0.1468256156401276, "value": " Unmarried"}, "6": {"effect": 0.002409519840077667, "value": " White"}, "7": {"effect": -0.049232403205037384, "value": " Female"}, "8": {"effect": ...

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %%
plot.shap_heatmap(shap_values_a[idx_equal], 'A', feature_order)
plot.shap_heatmap(shap_values_b[idx_equal], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[idx_equal], 'A vs. B', feature_order)

# %%
plot.shap_heatmap(shap_values_a[idx_diff], 'A', feature_order)
plot.shap_heatmap(shap_values_b[idx_diff], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[idx_diff], 'A vs. B', feature_order)
