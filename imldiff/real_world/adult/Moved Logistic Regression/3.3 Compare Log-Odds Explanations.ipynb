# %%
import plot
from shap.maskers import Independent
from sklearn.utils import resample, shuffle
import shap
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open('classifiers.pickle', 'rb') as f:
    clf_a, clf_b = pickle.load(f)
with open('predictions.pickle', 'rb') as f:
    X, display_data, feature_names, n_features, n_samples, indices, pred_a, pred_b, proba_a, proba_b, log_proba_a, log_proba_b, log_odds_a, log_odds_b = pickle.load(f)
with open('subsets.pickle', 'rb') as f:
    is_pred_diff, is_pred_diff_a_pos, is_pred_diff_b_pos, proba_diff_a_pos, proba_diff_b_pos, proba_diff, log_odds_diff_a_pos, log_odds_diff_b_pos, log_odds_diff = pickle.load(f)

idx_sample_pred_equal = indices[~is_pred_diff]
idx_sample_pred_diff = indices[is_pred_diff]
if idx_sample_pred_equal.shape[0] > 500:
    idx_sample_pred_equal = shuffle(idx_sample_pred_equal, random_state=42, n_samples=500)
if idx_sample_pred_diff.shape[0] > 500:
    idx_sample_pred_diff = shuffle(idx_sample_pred_diff, random_state=42, n_samples=500)
idx_sample = np.union1d(idx_sample_pred_equal, idx_sample_pred_diff)

X = X.iloc[idx_sample, :]
display_data = display_data[idx_sample]
pred_a = pred_a[idx_sample]
pred_b = pred_b[idx_sample]
proba_a = proba_a[idx_sample]
proba_b = proba_b[idx_sample]
log_proba_a  =  log_proba_a[idx_sample]
log_proba_b  = log_proba_b[idx_sample]
log_odds_a = log_odds_a[idx_sample]
log_odds_b = log_odds_b[idx_sample]
is_pred_diff = is_pred_diff[idx_sample]
is_pred_diff_a_pos = is_pred_diff_a_pos[idx_sample]
is_pred_diff_b_pos = is_pred_diff_b_pos[idx_sample]
proba_diff_a_pos = proba_diff_a_pos[idx_sample]
proba_diff_b_pos = proba_diff_b_pos[idx_sample]
proba_diff = proba_diff[idx_sample]
log_odds_diff_a_pos = log_odds_diff_a_pos[idx_sample]
log_odds_diff_b_pos = log_odds_diff_b_pos[idx_sample]
log_odds_diff = log_odds_diff[idx_sample]

n_samples = X.shape[0]
indices = np.array(range(n_samples))

# %%
try:
    with open(f'shapvalues.soa.log_odds.pickle', 'rb') as f:
        shap_values_a, shap_values_b, shap_values_a_vs_b, is_finite, is_outlier, is_normal, feature_order = pickle.load(f)
        print('Loaded cached shap values')
except FileNotFoundError:
    print('No cached shap values found')
# Out:
# Loaded cached shap values

# %% [markdown]
# ## Generate Explanations

# %% [markdown]
# Now we define the functions to be explained:

# %%
log_proba_to_log_odds = lambda log_proba: log_proba[:, 1] - log_proba[:, 0]
predict_log_odds_a = lambda X: log_proba_to_log_odds(clf_a.predict_log_proba(X))
predict_log_odds_b = lambda X: log_proba_to_log_odds(clf_b.predict_log_proba(X))

# %% [markdown]
# And now we calculate SHAP values for each function:

# %%
# %%time

background_data = X
def explain(predict):
    masker = Independent(data=background_data, max_samples=100)
    explainer = shap.Explainer(predict, masker, feature_names=feature_names)
    shap_values = explainer(X)
    shap_values.display_data = display_data
    return shap_values

shap_values_a = explain(predict_log_odds_a)
shap_values_b = explain(predict_log_odds_b)

shap_values_a_vs_b = shap_values_b - shap_values_a
shap_values_a_vs_b.data = shap_values_a.data
shap_values_a_vs_b.display_data = shap_values_a.display_data

is_finite = np.all(np.isfinite(shap_values_a.values), axis=1) & np.all(np.isfinite(shap_values_b.values), axis=1)
is_outlier = np.any(shap_values_a.abs.values > 12, axis=1) | np.any(shap_values_b.abs.values > 12, axis=1)
is_normal = is_finite & ~is_outlier
feature_order = np.flip(shap_values_a_vs_b[is_normal].abs.mean(axis=0).values.argsort())

with open(f'shapvalues.soa.log_odds.pickle', 'wb') as f:
    pickle.dump((shap_values_a, shap_values_b, shap_values_a_vs_b, is_finite, is_outlier, is_normal, feature_order), f, pickle.HIGHEST_PROTOCOL)
# Out:
# Permutation explainer: 697it [00:24, 20.32it/s]
# Permutation explainer: 697it [00:18, 16.32it/s]
# CPU times: user 1min 10s, sys: 6.16 s, total: 1min 16s
# Wall time: 43.4 s

# %% [markdown]
# ## Analyze

# %%
print(f'non-finite SHAP-values: {np.sum(~is_finite)}')
print(f'outlier SHAP-values: {np.sum(is_outlier)}')
print(f'total SHAP-values: {len(is_normal)}')
# Out:
# non-finite SHAP-values: 0
# outlier SHAP-values: 1
# total SHAP-values: 696

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# We estimate it with the mean absolute SHAP value (which is the default for this plot) and will also sort features subsequently in this order

# %%
shap.plots.bar(shap_values_a[is_normal], order=feature_order, max_display=n_features)
shap.plots.bar(shap_values_b[is_normal], order=feature_order, max_display=n_features)
shap.plots.bar(shap_values_a_vs_b[is_normal], order=feature_order, max_display=n_features)

# %% [markdown]
# ### SHAP Value Distribution

# %%
shap.plots.beeswarm(shap_values_a[is_normal], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_a[is_normal & (pred_a != pred_b)], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %%
shap.plots.beeswarm(shap_values_b[is_normal], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_b[is_normal & (pred_a != pred_b)], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %%
shap.plots.beeswarm(shap_values_a_vs_b[is_normal], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
xlim = plt.xlim()
plt.show()
shap.plots.beeswarm(shap_values_a_vs_b[is_normal & (pred_a != pred_b)], order=feature_order, max_display=n_features, plot_size=(14, 7), show=False)
plt.xlim(xlim)
plt.show()

# %% [markdown]
# ### Features' Partial Dependence Plots

# %%
n_columns = 3
n_rows = n_features
fig = plt.figure(figsize=(9*n_columns, 7*n_rows))
i = 1
for feature in feature_names[feature_order]:
    ax1 = fig.add_subplot(n_rows, n_columns, i)
    ax2 = fig.add_subplot(n_rows, n_columns, i+1, sharey=ax1)
    ax3 = fig.add_subplot(n_rows, n_columns, i+2, sharey=None)
    shap.plots.scatter(shap_values_a[:, feature], title='A', ax=ax1, color='blue', show=False)
    shap.plots.scatter(shap_values_b[:, feature], title='B', ax=ax2, color='blue', show=False)
    shap.plots.scatter(shap_values_a_vs_b[:, feature], title='B - A', ax=ax3, color='blue', show=False)
    if np.sum(pred_a != pred_b) > 0:
        shap.plots.scatter(shap_values_a[pred_a != pred_b, feature], title='A', ax=ax1, color='red', hist=False, show=False)
        shap.plots.scatter(shap_values_b[pred_a != pred_b, feature], title='B', ax=ax2, color='red', hist=False, show=False)
        shap.plots.scatter(shap_values_a_vs_b[pred_a != pred_b, feature], title='B - A', ax=ax3, color='red', hist=False, show=False)
    i += n_columns
plt.show()
# Out:
# Passing the fontdict parameter of _set_ticklabels() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %%
idx_diff = indices[is_normal & (pred_a != pred_b)]
idx_equal = indices[is_normal & (pred_a == pred_b)]
if len(idx_diff) > 500:
    idx_diff = shuffle(idx_diff, random_state=0, n_samples=500)
if len(idx_equal) > 500:
    idx_equal = shuffle(idx_equal, random_state=0, n_samples=500)

# %%
order = plot.shap_force(shap_values_a_vs_b[idx_diff], 'A vs. B')
plot.shap_force(shap_values_a[idx_diff], 'A', ordering=order)
plot.shap_force(shap_values_b[idx_diff], 'B', ordering=order);
# Out:
# <div id='iLPDIG52B3FJG01Z75DTY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": -0.0499999999999976, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": -0.05000000000000075, "simIndex": 68.0, "features": {"0": {"effect": 1.1657341758564144e-15, "value": 37.0}, "1": {"effect": 5.204170427930421e-17, "value": " Private"}, "2": {"effect": 5.273559366969494e-16, "value": 10.0}, "3": {"effect": 3.400058012914542e-16, "value": " Married-civ-spouse"}, "4": {"effect": -2.636779683484747e-16, "value": " Exec-managerial"}, "5": {"effect": 4.440892098500626e-16, "value": " Husband"}, "6": {"effect": -3.0531133177191805e-16, "value": " Black"}, "7": {"effect": -1.249000902703301e-16, "value": " Male"}, "8": {"effect": -3.774758283725532e-15, "value": 0.0}, "9": {"effect": 1.3877787807814457e-17, "value": 0.0}, "10": {"effect": -1.1102230246251565e-15, "value": 80.0}, "11": {"effect": -1.1709383462843448e-16, "value": " United-States"}}}, {"outValue": -0.05000000000000076, "simIndex": 189.0, "features": {"0": {"effect": -5.440092820663267e-15, "value": 24.0}, "1": {"effect": -1.734723475976807e-17, "value": " Private"}, "2": {"effect": -1.1102230246251565e-16, "value": 13.0}, "3": {"effect": 7.389922007661198e-16, "value": " Married-civ-spouse"}, "4": {"effect": -4.315992008230296e-15, "value": " Tech-support"}, "5": {"effect": 5.218048215738236e-15, "value": " Husband"}, "6": {"effect": -7.28583859910259e-17, "value": " White"}, "7": {"effect": -3.7470027081099033e-16, "value": " Male"}, "8": {"effect": 8.881784197001252e-16, "value": 0.0}, "9": {"effect": 1.8041124150158794e-16, "value": 0.0}, "10": {"effect": 0.0, "value": 50.0}, "11": {"effect": 1.48318857196017e-16, "value": " United-States"}}}, {"outValue": -0.05000000000000128, "simIndex": 125.0, "features": {"0": {"effect": -4.3576253716537394e-15, "value": 49.0}, "1": {"effect": 7.806255641895632e-17, "value": " Private"}, "2": {"effect": -5.551115123125783e-16, "value": 13.0}, "3": {"effect": 3.851086116668512e-15, "value": " Married-civ-spouse"}, "4": {"effect": -2.8171909249863347e-15, "value": " Sales"}, "5": {"effect": -2.55351295663786e-15, "value": " Husband"}, "6": {"effect": -1.0408340855860843e-17, "value": " White"}, "7": {"effect": -1.5265566588595902e-16, "value": " Male"}, "8": {"effect": 2.4980018054066022e-15, "value": 0.0}, "9": {"effect": -1.3877787807814457e-17, "value": 0.0}, "10": {"effect": 3.3306690738754696e-16, "value": 26.0}, "11": {"effect": 2.168404344971009e-17, "value": " United-States"}}}, {"outValue": -0.050000000000000974, "simIndex": 83.0, "features": {"0": {"effect": -3.747002708109903e-15, "value": 34.0}, "1": {"effect": 2.949029909160572e-17, "value": " Private"}, "2": {"effect": -3.3306690738754696e-16, "value": 13.0}, "3": {"effect": 3.712308238590367e-16, "value": " Married-civ-spouse"}, "4": {"effect": 1.249000902703301e-16, "value": " Exec-managerial"}, "5": {"effect": 5.10702591327572e-15, "value": " Husband"}, "6": {"effect": 8.326672684688674e-17, "value": " White"}, "7": {"effect": 2.7755575615628914e-17, "value": " Male"}, "8": {"effect": -1.5543122344752192e-15, "value": 0.0}, "9": {"effect": -9.71445146547012e-17, "value": 0.0}, "10": {"effect": -3.497202527569243e-15, "value": 45.0}, "11": {"effect": 1.1275702593849246e-16, "value": " United-States"}}}, {"outValue": -0.050000000000000995, "simIndex": 143.0, "features": {"0": {"effect": 1.6653345369377348e-15, "value": 47.0}, "1": {"effect": 1.609823385706477e-15, "value": " Self-emp-not-inc"}, "2": {"effect": -1.2212453270876722e-15, "value": 9.0}, "3": {"effect": -7.78023478975598e-15, "value": " Married-civ-spouse"}, "4": {"effect": -5.759281940243e-16, "value": " Other-service"}, "5": {"effect": -6.661338147750939e-16, "value": " Wife"}, "6": {"effect": -4.5102810375396984e-17, "va ...
# <div id='iU5333LYRC78XS3PL0FAH'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": -1.1226903235537928, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": 0.00764745328128158, "simIndex": 49.0, "features": {"0": {"effect": -0.14115183001880266, "value": 37.0}, "1": {"effect": -0.008206757041886071, "value": " Private"}, "2": {"effect": -0.19377155218942332, "value": 10.0}, "3": {"effect": 0.013157048746053253, "value": " Married-civ-spouse"}, "4": {"effect": -0.049322150728143596, "value": " Exec-managerial"}, "5": {"effect": 0.5907247156608584, "value": " Husband"}, "6": {"effect": -0.14331611480968437, "value": " Black"}, "7": {"effect": 0.11425574411506384, "value": " Male"}, "8": {"effect": -0.26272726823096526, "value": 0.0}, "9": {"effect": -0.06413094285872928, "value": 0.0}, "10": {"effect": 1.2699181026022344, "value": 80.0}, "11": {"effect": 0.004908781588499059, "value": " United-States"}}}, {"outValue": 0.005300440303340537, "simIndex": 99.0, "features": {"0": {"effect": -0.5600956177458372, "value": 24.0}, "1": {"effect": -0.00820675704188593, "value": " Private"}, "2": {"effect": 0.8631641870256106, "value": 13.0}, "3": {"effect": 0.01315704874605352, "value": " Married-civ-spouse"}, "4": {"effect": 0.09341076134687466, "value": " Tech-support"}, "5": {"effect": 0.590724715660853, "value": " Husband"}, "6": {"effect": 0.026288754787575246, "value": " White"}, "7": {"effect": 0.11425574411506391, "value": " Male"}, "8": {"effect": -0.2627272682309678, "value": 0.0}, "9": {"effect": -0.06413094285872926, "value": 0.0}, "10": {"effect": 0.31724135646402346, "value": 50.0}, "11": {"effect": 0.0049087815884989484, "value": " United-States"}}}, {"outValue": 0.03296096118429914, "simIndex": 154.0, "features": {"0": {"effect": 0.2455655124984689, "value": 49.0}, "1": {"effect": -0.008206757041886004, "value": " Private"}, "2": {"effect": 0.8631641870256112, "value": 13.0}, "3": {"effect": 0.013157048746049404, "value": " Married-civ-spouse"}, "4": {"effect": 0.07755154889409305, "value": " Sales"}, "5": {"effect": 0.5907247156608589, "value": " Husband"}, "6": {"effect": 0.02628875478757526, "value": " White"}, "7": {"effect": 0.11425574411506371, "value": " Male"}, "8": {"effect": -0.26272726823096904, "value": 0.0}, "9": {"effect": -0.06413094285872935, "value": 0.0}, "10": {"effect": -0.44490004044654285, "value": 26.0}, "11": {"effect": 0.0049087815884990005, "value": " United-States"}}}, {"outValue": 0.026052522636348385, "simIndex": 86.0, "features": {"0": {"effect": -0.2378311656481173, "value": 34.0}, "1": {"effect": -0.008206757041885952, "value": " Private"}, "2": {"effect": 0.8631641870256108, "value": 13.0}, "3": {"effect": 0.013157048746053859, "value": " Married-civ-spouse"}, "4": {"effect": -0.04932215072814339, "value": " Exec-managerial"}, "5": {"effect": 0.5907247156608522, "value": " Husband"}, "6": {"effect": 0.026288754787575155, "value": " White"}, "7": {"effect": 0.11425574411506373, "value": " Male"}, "8": {"effect": -0.2627272682309624, "value": 0.0}, "9": {"effect": -0.06413094285872915, "value": 0.0}, "10": {"effect": 0.1584618987743244, "value": 45.0}, "11": {"effect": 0.004908781588498939, "value": " United-States"}}}, {"outValue": 0.005231892275910921, "simIndex": 46.0, "features": {"0": {"effect": 0.18111262207891987, "value": 47.0}, "1": {"effect": -0.09027432746074532, "value": " Self-emp-not-inc"}, "2": {"effect": -0.5460834652611003, "value": 9.0}, "3": {"effect": 0.013157048746059203, "value": " Married-civ-spouse"}, "4": {"effect": 0.014114699082973883, "value": " Other-service"}, "5": {"effect": 1.1277471844434597, "value": " Wife"}, "6": {"effect": 0.026288754787575364, "value": " White"}, "7": {"effect": -0.3618098563643679, "value": " Female"}, "8": {"effect": -0.26272726823097264, "value": 0 ...
# <div id='iPYKJ1XS4OSVQAR19XYM7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": -1.1726903235537904, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": -0.04235254671871935, "simIndex": 49.0, "features": {"0": {"effect": -0.1411518300188015, "value": 37.0}, "1": {"effect": -0.00820675704188602, "value": " Private"}, "2": {"effect": -0.1937715521894228, "value": 10.0}, "3": {"effect": 0.013157048746053593, "value": " Married-civ-spouse"}, "4": {"effect": -0.04932215072814386, "value": " Exec-managerial"}, "5": {"effect": 0.5907247156608588, "value": " Husband"}, "6": {"effect": -0.14331611480968467, "value": " Black"}, "7": {"effect": 0.11425574411506371, "value": " Male"}, "8": {"effect": -0.26272726823096904, "value": 0.0}, "9": {"effect": -0.06413094285872926, "value": 0.0}, "10": {"effect": 1.2699181026022333, "value": 80.0}, "11": {"effect": 0.0049087815884989415, "value": " United-States"}}}, {"outValue": -0.044699559696660174, "simIndex": 99.0, "features": {"0": {"effect": -0.5600956177458426, "value": 24.0}, "1": {"effect": -0.008206757041885948, "value": " Private"}, "2": {"effect": 0.8631641870256105, "value": 13.0}, "3": {"effect": 0.01315704874605426, "value": " Married-civ-spouse"}, "4": {"effect": 0.09341076134687035, "value": " Tech-support"}, "5": {"effect": 0.5907247156608583, "value": " Husband"}, "6": {"effect": 0.026288754787575173, "value": " White"}, "7": {"effect": 0.11425574411506353, "value": " Male"}, "8": {"effect": -0.2627272682309669, "value": 0.0}, "9": {"effect": -0.06413094285872908, "value": 0.0}, "10": {"effect": 0.31724135646402346, "value": 50.0}, "11": {"effect": 0.004908781588499097, "value": " United-States"}}}, {"outValue": -0.01703903881570179, "simIndex": 154.0, "features": {"0": {"effect": 0.24556551249846453, "value": 49.0}, "1": {"effect": -0.008206757041885926, "value": " Private"}, "2": {"effect": 0.8631641870256106, "value": 13.0}, "3": {"effect": 0.013157048746053255, "value": " Married-civ-spouse"}, "4": {"effect": 0.07755154889409023, "value": " Sales"}, "5": {"effect": 0.5907247156608564, "value": " Husband"}, "6": {"effect": 0.02628875478757525, "value": " White"}, "7": {"effect": 0.11425574411506356, "value": " Male"}, "8": {"effect": -0.26272726823096654, "value": 0.0}, "9": {"effect": -0.06413094285872936, "value": 0.0}, "10": {"effect": -0.4449000404465425, "value": 26.0}, "11": {"effect": 0.004908781588499022, "value": " United-States"}}}, {"outValue": -0.02394747736365299, "simIndex": 86.0, "features": {"0": {"effect": -0.23783116564812104, "value": 34.0}, "1": {"effect": -0.008206757041885922, "value": " Private"}, "2": {"effect": 0.8631641870256105, "value": 13.0}, "3": {"effect": 0.01315704874605423, "value": " Married-civ-spouse"}, "4": {"effect": -0.04932215072814326, "value": " Exec-managerial"}, "5": {"effect": 0.5907247156608573, "value": " Husband"}, "6": {"effect": 0.02628875478757524, "value": " White"}, "7": {"effect": 0.11425574411506376, "value": " Male"}, "8": {"effect": -0.26272726823096393, "value": 0.0}, "9": {"effect": -0.06413094285872925, "value": 0.0}, "10": {"effect": 0.1584618987743209, "value": 45.0}, "11": {"effect": 0.004908781588499052, "value": " United-States"}}}, {"outValue": -0.044768107724090456, "simIndex": 46.0, "features": {"0": {"effect": 0.18111262207892154, "value": 47.0}, "1": {"effect": -0.09027432746074371, "value": " Self-emp-not-inc"}, "2": {"effect": -0.5460834652611015, "value": 9.0}, "3": {"effect": 0.013157048746051423, "value": " Married-civ-spouse"}, "4": {"effect": 0.014114699082973307, "value": " Other-service"}, "5": {"effect": 1.127747184443459, "value": " Wife"}, "6": {"effect": 0.02628875478757532, "value": " White"}, "7": {"effect": -0.3618098563643678, "value": " Female"}, "8": {"effect": -0.2627272682309684, "value": 0.0 ...

# %%
order = plot.shap_force(shap_values_a_vs_b[idx_equal], 'A vs. B')
plot.shap_force(shap_values_a[idx_equal], 'A', ordering=order)
plot.shap_force(shap_values_b[idx_equal], 'B', ordering=order);
# Out:
# <div id='iN7STEKDGVIWTJUZI9OZA'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": -0.0499999999999976, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": -0.05000000000000629, "simIndex": 23.0, "features": {"0": {"effect": 6.106226635438361e-16, "value": 53.0}, "1": {"effect": -7.511352650979575e-16, "value": " Private"}, "2": {"effect": -2.3314683517128287e-15, "value": 9.0}, "3": {"effect": -1.3877787807814457e-15, "value": " Divorced"}, "4": {"effect": -1.1518563880486e-15, "value": " Sales"}, "5": {"effect": -4.295175326518574e-15, "value": " Own-child"}, "6": {"effect": 6.938893903907228e-18, "value": " White"}, "7": {"effect": -2.886579864025407e-15, "value": " Female"}, "8": {"effect": 1.887379141862766e-15, "value": 0.0}, "9": {"effect": 6.938893903907228e-17, "value": 0.0}, "10": {"effect": 1.582067810090848e-15, "value": 35.0}, "11": {"effect": -3.642919299551295e-17, "value": " United-States"}}}, {"outValue": -0.05000000000000602, "simIndex": 377.0, "features": {"0": {"effect": -9.159339953157541e-16, "value": 35.0}, "1": {"effect": -1.1587952819525071e-15, "value": " Private"}, "2": {"effect": -2.220446049250313e-15, "value": 14.0}, "3": {"effect": -4.163336342344337e-17, "value": " Married-civ-spouse"}, "4": {"effect": -1.609823385706477e-15, "value": " Prof-specialty"}, "5": {"effect": 8.881784197001252e-16, "value": " Other-relative"}, "6": {"effect": 1.214306433183765e-16, "value": " White"}, "7": {"effect": -1.249000902703301e-16, "value": " Male"}, "8": {"effect": -1.3322676295501878e-15, "value": 7298.0}, "9": {"effect": -2.7755575615628914e-17, "value": 0.0}, "10": {"effect": -1.986041539558947e-15, "value": 40.0}, "11": {"effect": -7.806255641895632e-18, "value": " United-States"}}}, {"outValue": -0.050000000000002334, "simIndex": 15.0, "features": {"0": {"effect": 4.4825254619240695e-15, "value": 45.0}, "1": {"effect": -2.688821387764051e-16, "value": " Private"}, "2": {"effect": -3.3306690738754696e-16, "value": 13.0}, "3": {"effect": -4.336808689942018e-15, "value": " Married-civ-spouse"}, "4": {"effect": -4.0592529337857286e-15, "value": " Prof-specialty"}, "5": {"effect": -1.6653345369377348e-15, "value": " Husband"}, "6": {"effect": -1.3530843112619095e-16, "value": " White"}, "7": {"effect": 1.1102230246251565e-16, "value": " Male"}, "8": {"effect": -4.829470157119431e-15, "value": 0.0}, "9": {"effect": -1.6653345369377348e-16, "value": 0.0}, "10": {"effect": 6.5503158452884236e-15, "value": 55.0}, "11": {"effect": -8.500145032286355e-17, "value": " United-States"}}}, {"outValue": -0.04999999999999485, "simIndex": 150.0, "features": {"0": {"effect": 3.3306690738754696e-16, "value": 53.0}, "1": {"effect": -6.800116025829084e-16, "value": " Local-gov"}, "2": {"effect": 0.0, "value": 1.0}, "3": {"effect": -1.887379141862766e-15, "value": " Never-married"}, "4": {"effect": -7.153565934059358e-16, "value": " Machine-op-inspct"}, "5": {"effect": 6.661338147750939e-16, "value": " Not-in-family"}, "6": {"effect": 1.249000902703301e-16, "value": " White"}, "7": {"effect": -3.3306690738754696e-16, "value": " Female"}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 5.551115123125783e-17, "value": 0.0}, "10": {"effect": 4.9960036108132044e-15, "value": 35.0}, "11": {"effect": 1.97758476261356e-16, "value": " United-States"}}}, {"outValue": -0.05000000000000438, "simIndex": 343.0, "features": {"0": {"effect": -1.942890293094024e-15, "value": 30.0}, "1": {"effect": 1.0547118733938987e-15, "value": " ?"}, "2": {"effect": -3.3306690738754696e-16, "value": 11.0}, "3": {"effect": 3.3306690738754696e-16, "value": " Divorced"}, "4": {"effect": -2.1510571102112408e-15, "value": " ?"}, "5": {"effect": -2.886579864025407e-15, "value": " Unmarried"}, "6": {"effect": -1.97758476261356e-16, "value": " White"}, "7": {"effect" ...
# <div id='i7JQAC48F8SQZX8QIYLUN'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": -1.1226903235537928, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": -1.5987502772252384, "simIndex": 152.0, "features": {"0": {"effect": 0.3744712933375544, "value": 53.0}, "1": {"effect": -0.008206757041885622, "value": " Private"}, "2": {"effect": -0.5460834652610989, "value": 9.0}, "3": {"effect": 0.38907272720470437, "value": " Divorced"}, "4": {"effect": 0.07755154889409062, "value": " Sales"}, "5": {"effect": 0.05370224687825958, "value": " Own-child"}, "6": {"effect": 0.02628875478757519, "value": " White"}, "7": {"effect": -0.3618098563643664, "value": " Female"}, "8": {"effect": -0.2627272682309669, "value": 0.0}, "9": {"effect": -0.06413094285872926, "value": 0.0}, "10": {"effect": -0.15909701660508166, "value": 35.0}, "11": {"effect": 0.004908781588499019, "value": " United-States"}}}, {"outValue": 1.6292693578646678, "simIndex": 15.0, "features": {"0": {"effect": -0.20560472043834616, "value": 35.0}, "1": {"effect": -0.008206757041885492, "value": " Private"}, "2": {"effect": 1.2154761000972893, "value": 14.0}, "3": {"effect": 0.013157048746053364, "value": " Married-civ-spouse"}, "4": {"effect": 0.045833123988534515, "value": " Prof-specialty"}, "5": {"effect": -0.4833202219043398, "value": " Other-relative"}, "6": {"effect": 0.026288754787575256, "value": " White"}, "7": {"effect": 0.11425574411506384, "value": " Male"}, "8": {"effect": 2.0936203292541253, "value": 7298.0}, "9": {"effect": -0.06413094285872928, "value": 0.0}, "10": {"effect": -0.00031755891537858333, "value": 40.0}, "11": {"effect": 0.0049087815884989155, "value": " United-States"}}}, {"outValue": 0.7932576100399216, "simIndex": 238.0, "features": {"0": {"effect": 0.11665973165937499, "value": 45.0}, "1": {"effect": -0.008206757041885972, "value": " Private"}, "2": {"effect": 0.8631641870256112, "value": 13.0}, "3": {"effect": 0.013157048746053945, "value": " Married-civ-spouse"}, "4": {"effect": 0.04583312398853645, "value": " Prof-specialty"}, "5": {"effect": 0.5907247156608596, "value": " Husband"}, "6": {"effect": 0.02628875478757529, "value": " White"}, "7": {"effect": 0.1142557441150635, "value": " Male"}, "8": {"effect": -0.262727268230965, "value": 0.0}, "9": {"effect": -0.06413094285872914, "value": 0.0}, "10": {"effect": 0.47602081415372033, "value": 55.0}, "11": {"effect": 0.004908781588499064, "value": " United-States"}}}, {"outValue": -6.777372836908812, "simIndex": 462.0, "features": {"0": {"effect": 0.3744712933375517, "value": 53.0}, "1": {"effect": 0.07386081337697344, "value": " Local-gov"}, "2": {"effect": -3.364578769834525, "value": 1.0}, "3": {"effect": -0.3627586297125983, "value": " Never-married"}, "4": {"effect": -0.0017445133698056707, "value": " Machine-op-inspct"}, "5": {"effect": -1.5573651594695386, "value": " Not-in-family"}, "6": {"effect": 0.02628875478757522, "value": " White"}, "7": {"effect": -0.36180985636436763, "value": " Female"}, "8": {"effect": -0.2627272682309669, "value": 0.0}, "9": {"effect": -0.06413094285872911, "value": 0.0}, "10": {"effect": -0.1590970166050872, "value": 35.0}, "11": {"effect": 0.004908781588498797, "value": " United-States"}}}, {"outValue": -2.576775579377773, "simIndex": 397.0, "features": {"0": {"effect": -0.36673694648720656, "value": 30.0}, "1": {"effect": 0.15592838379583257, "value": " ?"}, "2": {"effect": 0.15854036088225504, "value": 11.0}, "3": {"effect": 0.3890727272047035, "value": " Divorced"}, "4": {"effect": -0.11275900053925926, "value": " ?"}, "5": {"effect": -1.0203426906869362, "value": " Unmarried"}, "6": {"effect": 0.026288754787575395, "value": " White"}, "7": {"effect": -0.3618098563643688, "value": " Female"}, "8": {"effect": -0.26272726823096637, "value": 0.0}, "9": {"effect": -0.06 ...
# <div id='iJ05LE9A87EQNHEVSPA2K'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": -1.1726903235537904, "link": "identity", "featureNames": ["Age", "Workclass", "Education-Num", "Marital Status", "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss", "Hours per week", "Country"], "explanations": [{"outValue": -1.6487502772252447, "simIndex": 152.0, "features": {"0": {"effect": 0.374471293337555, "value": 53.0}, "1": {"effect": -0.008206757041886373, "value": " Private"}, "2": {"effect": -0.5460834652611012, "value": 9.0}, "3": {"effect": 0.389072727204703, "value": " Divorced"}, "4": {"effect": 0.07755154889408947, "value": " Sales"}, "5": {"effect": 0.05370224687825528, "value": " Own-child"}, "6": {"effect": 0.026288754787575197, "value": " White"}, "7": {"effect": -0.3618098563643693, "value": " Female"}, "8": {"effect": -0.26272726823096504, "value": 0.0}, "9": {"effect": -0.0641309428587292, "value": 0.0}, "10": {"effect": -0.15909701660508008, "value": 35.0}, "11": {"effect": 0.004908781588498982, "value": " United-States"}}}, {"outValue": 1.5792693578646622, "simIndex": 15.0, "features": {"0": {"effect": -0.20560472043834707, "value": 35.0}, "1": {"effect": -0.00820675704188665, "value": " Private"}, "2": {"effect": 1.2154761000972871, "value": 14.0}, "3": {"effect": 0.013157048746053323, "value": " Married-civ-spouse"}, "4": {"effect": 0.045833123988532905, "value": " Prof-specialty"}, "5": {"effect": -0.48332022190433893, "value": " Other-relative"}, "6": {"effect": 0.026288754787575377, "value": " White"}, "7": {"effect": 0.11425574411506371, "value": " Male"}, "8": {"effect": 2.093620329254124, "value": 7298.0}, "9": {"effect": -0.0641309428587293, "value": 0.0}, "10": {"effect": -0.00031755891538056937, "value": 40.0}, "11": {"effect": 0.004908781588498908, "value": " United-States"}}}, {"outValue": 0.7432576100399189, "simIndex": 238.0, "features": {"0": {"effect": 0.11665973165937947, "value": 45.0}, "1": {"effect": -0.008206757041886241, "value": " Private"}, "2": {"effect": 0.8631641870256108, "value": 13.0}, "3": {"effect": 0.013157048746049609, "value": " Married-civ-spouse"}, "4": {"effect": 0.04583312398853239, "value": " Prof-specialty"}, "5": {"effect": 0.5907247156608579, "value": " Husband"}, "6": {"effect": 0.026288754787575155, "value": " White"}, "7": {"effect": 0.11425574411506362, "value": " Male"}, "8": {"effect": -0.2627272682309698, "value": 0.0}, "9": {"effect": -0.0641309428587293, "value": 0.0}, "10": {"effect": 0.4760208141537269, "value": 55.0}, "11": {"effect": 0.004908781588498979, "value": " United-States"}}}, {"outValue": -6.827372836908806, "simIndex": 462.0, "features": {"0": {"effect": 0.374471293337552, "value": 53.0}, "1": {"effect": 0.07386081337697276, "value": " Local-gov"}, "2": {"effect": -3.364578769834525, "value": 1.0}, "3": {"effect": -0.3627586297126002, "value": " Never-married"}, "4": {"effect": -0.001744513369806386, "value": " Machine-op-inspct"}, "5": {"effect": -1.557365159469538, "value": " Not-in-family"}, "6": {"effect": 0.026288754787575346, "value": " White"}, "7": {"effect": -0.36180985636436797, "value": " Female"}, "8": {"effect": -0.2627272682309669, "value": 0.0}, "9": {"effect": -0.06413094285872906, "value": 0.0}, "10": {"effect": -0.15909701660508221, "value": 35.0}, "11": {"effect": 0.004908781588498994, "value": " United-States"}}}, {"outValue": -2.626775579377777, "simIndex": 397.0, "features": {"0": {"effect": -0.3667369464872085, "value": 30.0}, "1": {"effect": 0.15592838379583362, "value": " ?"}, "2": {"effect": 0.1585403608822547, "value": 11.0}, "3": {"effect": 0.3890727272047038, "value": " Divorced"}, "4": {"effect": -0.11275900053926141, "value": " ?"}, "5": {"effect": -1.020342690686939, "value": " Unmarried"}, "6": {"effect": 0.026288754787575197, "value": " White"}, "7": {"effect": -0.3618098563643688, "value": " Female"}, "8": {"effect": -0.26272726823096704, "value": 0.0}, "9": {"effect": -0.0641309428 ...

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %%
plot.shap_heatmap(shap_values_a[idx_equal], 'A', feature_order)
plot.shap_heatmap(shap_values_b[idx_equal], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[idx_equal], 'A vs. B', feature_order)

# %%
plot.shap_heatmap(shap_values_a[idx_diff], 'A', feature_order)
plot.shap_heatmap(shap_values_b[idx_diff], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[idx_diff], 'A vs. B', feature_order)

# %% [markdown]
# ### Unusual instances

# %% [markdown]
# #### Outliers in SHAP-values

# %% [markdown]
# An unusually high capital gain leads to a very big SHAP value for the instance's feature.

# %%
idx_outliers = np.where(is_outlier & is_finite)[0]

# %%
pd.DataFrame(display_data[idx_outliers, :], index=idx_outliers, columns=feature_names)
# Out:
#       Age          Workclass Education-Num       Marital Status Occupation  \
# 371  57.0   Self-emp-not-inc          10.0   Married-civ-spouse      Sales
#
#     Relationship    Race    Sex Capital Gain Capital Loss Hours per week  \
# 371      Husband   White   Male      99999.0          0.0           45.0
#
#             Country
# 371   United-States

# %%
for idx in shuffle(idx_outliers, n_samples=3):
    plot.shap_force(shap_values_a[idx], f'A (#{idx})')
    plot.shap_force(shap_values_b[idx], f'B (#{idx})')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Users/karl/.pyenv/versions/3.9.0/lib/python3.9/site-packages/IPython/core/interactiveshell.py, in run_code:
# Line 3437:  exec(code_obj, self.user_global_ns, self.user_ns)
#
# In  [19]:
# Line 1:     for idx in shuffle(idx_outliers, n_samples=3):
#
# File /Users/karl/.pyenv/versions/3.9.0/lib/python3.9/site-packages/sklearn/utils/__init__.py, in shuffle:
# Line 631:   return resample(*arrays, replace=False, n_samples=n_samples,
#
# File /Users/karl/.pyenv/versions/3.9.0/lib/python3.9/site-packages/sklearn/utils/__init__.py, in resample:
# Line 514:   raise ValueError("Cannot sample %d out of arrays with dim %d "
#
# ValueError: Cannot sample 3 out of arrays with dim 1 when replace is False
# ---------------------------------------------------------------------------

# %% [markdown]
# #### Non-finite SHAP-values

# %%
idx_nonfinite = np.where(~is_finite)[0]

# %%
pd.DataFrame(display_data[idx_nonfinite, :], index=idx_nonfinite, columns=feature_names)

# %%
pd.DataFrame(shap_values_a[idx_nonfinite].values, index=idx_nonfinite, columns=feature_names)

# %%
pd.DataFrame(shap_values_b[idx_nonfinite].values, index=idx_nonfinite, columns=feature_names)
