# %%
import plot
from shap.maskers import Independent
import shap
from matplotlib import pyplot as plt
from sklearn.utils import resample, shuffle
import numpy as np
import pandas as pd
import pickle
# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open('classifiers.pickle', 'rb') as f:
    clf_a, clf_b = pickle.load(f)
with open('predictions.pickle', 'rb') as f:
    X, feature_names, n_features, n_samples, indices, pred_a, pred_b, proba_a, proba_b, log_proba_a, log_proba_b, log_odds_a, log_odds_b = pickle.load(f)
with open('subsets.pickle', 'rb') as f:
    is_pred_diff, is_pred_diff_a_pos, is_pred_diff_b_pos, proba_diff_a_pos, proba_diff_b_pos, proba_diff, log_odds_diff_a_pos, log_odds_diff_b_pos, log_odds_diff = pickle.load(f)

# %%
try:
    with open('shapvalues.log_odds.pickle', 'rb') as f:
        shap_values_diff, shap_values_diff_a_pos, shap_values_diff_b_pos, overall_importance, feature_order, shap_values_diff_a_vs_b_pos, is_finite, is_normal = pickle.load(f)
        print('Loaded cached shap values')
except FileNotFoundError:
    print('No cached shap values found')
# Out:
# No cached shap values found

# %% [markdown]
# ## Generate Explanations

# %% [markdown]
# Now we define the difference functions to be explained:

# %%
log_proba_add = lambda y1, y2: y1 + np.log1p(np.exp(y2 - y1))
log_proba_complement = lambda y: np.log1p(-np.exp(y))
log_proba_to_log_odds = lambda x: x - log_proba_complement(x)
merge_log_proba_diff_c1_pos = lambda y1, y2: y1[:, 1] + y2[:, 0]
predict_log_odds_diff_a_pos = lambda X: log_proba_to_log_odds(merge_log_proba_diff_c1_pos(clf_a.predict_log_proba(X), clf_b.predict_log_proba(X)))
predict_log_odds_diff_b_pos = lambda X: log_proba_to_log_odds(merge_log_proba_diff_c1_pos(clf_b.predict_log_proba(X), clf_a.predict_log_proba(X)))

# %%
merge_log_proba_diff = lambda y1, y2: log_proba_add(merge_log_proba_diff_c1_pos(y1, y2), merge_log_proba_diff_c1_pos(y2, y1))
predict_log_odds_diff = lambda X: log_proba_to_log_odds(merge_log_proba_diff(clf_a.predict_log_proba(X), clf_b.predict_log_proba(X)))

# %% [markdown]
# And now we calculate SHAP values for each merge function:

# %%
# %%time

background_data = X
def explain(predict):
    masker = Independent(data=background_data)
    explainer = shap.Explainer(predict, masker, feature_names=feature_names)
    shap_values = explainer(X)
    return shap_values

shap_values_diff = explain(predict_log_odds_diff)
shap_values_diff_a_pos = explain(predict_log_odds_diff_a_pos)
shap_values_diff_b_pos = explain(predict_log_odds_diff_b_pos)

shap_values_diff_a_vs_b_pos = shap_values_diff_b_pos - shap_values_diff_a_pos
shap_values_diff_a_vs_b_pos.data = shap_values_diff_a_pos.data
shap_values_diff_a_vs_b_pos.display_data = shap_values_diff_a_pos.display_data

is_finite = np.all(np.isfinite(shap_values_diff.values), axis=1)
is_outlier = np.any(shap_values_diff.abs.values > 8, axis=1)
is_normal = is_finite

overall_importance = shap_values_diff[is_normal].abs.mean(axis=0)
feature_order = np.flip(overall_importance.values.argsort())

with open(f'shapvalues.log_odds.pickle', 'wb') as f:
    pickle.dump((shap_values_diff, shap_values_diff_a_pos, shap_values_diff_b_pos, overall_importance, feature_order, shap_values_diff_a_vs_b_pos, is_finite, is_normal), f, pickle.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 4.1 s, sys: 22 ms, total: 4.12 s
# Wall time: 4.28 s

# %% [markdown]
# ## Analyze

# %%
print(f'non-finite SHAP-values: {np.sum(~is_finite)}')
print(f'outlier SHAP-values: {np.sum(is_outlier)}')
print(f'total SHAP-values: {len(is_normal)}')
# Out:
# non-finite SHAP-values: 0
# outlier SHAP-values: 0
# total SHAP-values: 1000

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# We estimate it with the mean absolute SHAP value (which is the default for this plot) and will also sort features subsequently in this order

# %%
shap.plots.bar(overall_importance, max_display=n_features)

# %%
x = np.arange(n_features)
width = 0.2
fig, ax = plt.subplots(figsize=(14, 7))
rects1 = ax.bar(x - width/2, shap_values_diff_a_pos.abs.mean(0)[feature_order].values, width, label='Different, A=positive', color='green')
rects2 = ax.bar(x + width/2, shap_values_diff_b_pos.abs.mean(0)[feature_order].values, width, label='Different, B=positive', color='orange')
ax.set_ylabel('mean(|SHAP value|)')
ax.set_title('A=positive vs. B=positive')
ax.set_xticks(x)
ax.set_xticklabels(feature_names)
ax.legend()
plt.show()

# %% [markdown]
# ### SHAP Value Distribution

# %% [markdown]
# Next, we will try to understand the importances using the whole distribution of values, not only the aggregated mean.

# %%
plot.shap_beeswarm(shap_values_diff[is_normal], 'P(different)', order=feature_order, max_display=n_features)

# %%
for feature in feature_names:
    a_feature = shap_values_diff_a_pos[:, feature]
    b_feature = shap_values_diff_b_pos[:, feature]
    values = np.array([a_feature.values, b_feature.values]).T
    data = np.array([a_feature.data, b_feature.data]).T
    display_data = np.array([a_feature.display_data, b_feature.display_data]).T
    explanation = shap.Explanation(values, data=data, display_data=display_data, feature_names=['P(different, A=pos)', 'P(different, B=pos)'])
    plot.shap_beeswarm(explanation, 'Feature ' + feature)

# %%
plot.shap_beeswarm(shap_values_diff_a_vs_b_pos, 'log(odds(different, B=pos)) - log(odds(different, A=pos))', order=feature_order, max_display=n_features)

# %% [markdown]
# ### Features' Partial Dependence Plots

# %%
n_columns = 3
n_rows = n_features
fig = plt.figure(figsize=(9*n_columns, 7*n_rows))
i = 1
for feature in feature_names:
    ax1 = fig.add_subplot(n_rows, n_columns, i)
    ax2 = fig.add_subplot(n_rows, n_columns, i+1, sharey=ax1)
    ax3 = fig.add_subplot(n_rows, n_columns, i+2, sharey=ax1)
    shap.plots.scatter(shap_values_diff[:, feature], title='Different', ax=ax1, color=proba_diff, show=False)
    shap.plots.scatter(shap_values_diff_a_pos[:, feature], title='Different, A=pos', ax=ax2, color=proba_diff, show=False)
    shap.plots.scatter(shap_values_diff_b_pos[:, feature], title='Different, B=pos', ax=ax3, color=proba_diff, show=False)
    i += n_columns
plt.show()

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %%
idx_diff = indices[pred_a != pred_b]
idx_equal = indices[pred_a == pred_b]
if len(idx_diff) > 500:
    idx_diff = shuffle(idx_diff, random_state=0, n_samples=500)
if len(idx_equal) > 500:
    idx_equal = shuffle(idx_equal, random_state=0, n_samples=500)

# %%
order = plot.shap_force(shap_values_diff[idx_diff], 'Different')
plot.shap_force(shap_values_diff_a_pos[idx_diff], 'Different, A=pos', ordering=order)
plot.shap_force(shap_values_diff_b_pos[idx_diff], 'Different, B=pos', ordering=order);
# Out:
# <div id='iGUIS7RJMV9DBEGVUO63Z'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Different"], "baseValue": -0.3424441103844444, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.10504769959962734, "simIndex": 90.0, "features": {"0": {"effect": 0.5263541737867448, "value": ""}, "1": {"effect": -0.07886236380267303, "value": ""}}}, {"outValue": 0.3381747512588786, "simIndex": 158.0, "features": {"0": {"effect": 0.3051689911359394, "value": ""}, "1": {"effect": 0.37544987050738354, "value": ""}}}, {"outValue": 0.16094740627407572, "simIndex": 105.0, "features": {"0": {"effect": 0.3249923564269648, "value": ""}, "1": {"effect": 0.17839916023155528, "value": ""}}}, {"outValue": 0.17843302553025692, "simIndex": 198.0, "features": {"0": {"effect": 0.2880351506393915, "value": ""}, "1": {"effect": 0.23284198527530983, "value": ""}}}, {"outValue": 0.49023980618638946, "simIndex": 295.0, "features": {"0": {"effect": 0.4850223316485074, "value": ""}, "1": {"effect": 0.34766158492232646, "value": ""}}}, {"outValue": 1.0212747553441843, "simIndex": 339.0, "features": {"0": {"effect": 0.6878160585915772, "value": ""}, "1": {"effect": 0.6759028071370514, "value": ""}}}, {"outValue": 2.4365039044933194, "simIndex": 22.0, "features": {"0": {"effect": 1.1860730310678969, "value": ""}, "1": {"effect": 1.592874983809867, "value": ""}}}, {"outValue": 1.4770818378431128, "simIndex": 65.0, "features": {"0": {"effect": 1.095240657149448, "value": ""}, "1": {"effect": 0.7242852910781092, "value": ""}}}, {"outValue": 2.2017817336707797, "simIndex": 19.0, "features": {"0": {"effect": 1.57347016184187, "value": ""}, "1": {"effect": 0.9707556822133536, "value": ""}}}, {"outValue": 0.21105203565542524, "simIndex": 243.0, "features": {"0": {"effect": 0.17074514963411247, "value": ""}, "1": {"effect": 0.38275099640575716, "value": ""}}}, {"outValue": 0.45866004127475374, "simIndex": 260.0, "features": {"0": {"effect": 0.6542471106583236, "value": ""}, "1": {"effect": 0.14685704100087454, "value": ""}}}, {"outValue": 0.027487355409136993, "simIndex": 126.0, "features": {"0": {"effect": 0.19182127351153408, "value": ""}, "1": {"effect": 0.17811019228204733, "value": ""}}}, {"outValue": 2.7555366263059327, "simIndex": 5.0, "features": {"0": {"effect": 1.5907762873184161, "value": ""}, "1": {"effect": 1.5072044493719605, "value": ""}}}, {"outValue": 0.9278797780098513, "simIndex": 346.0, "features": {"0": {"effect": 0.7903938982769458, "value": ""}, "1": {"effect": 0.47992999011735, "value": ""}}}, {"outValue": 0.7495594427832282, "simIndex": 85.0, "features": {"0": {"effect": 0.9913622507316271, "value": ""}, "1": {"effect": 0.10064130243604541, "value": ""}}}, {"outValue": 1.4405761634221792, "simIndex": 61.0, "features": {"0": {"effect": 0.963935250563702, "value": ""}, "1": {"effect": 0.8190850232429217, "value": ""}}}, {"outValue": 1.0226362231148005, "simIndex": 349.0, "features": {"0": {"effect": 0.942867609990307, "value": ""}, "1": {"effect": 0.422212723508938, "value": ""}}}, {"outValue": 0.21585383678667142, "simIndex": 195.0, "features": {"0": {"effect": 0.2959160980846731, "value": ""}, "1": {"effect": 0.26238184908644274, "value": ""}}}, {"outValue": 2.278309980484978, "simIndex": 20.0, "features": {"0": {"effect": 1.2534096398949577, "value": ""}, "1": {"effect": 1.367344450974464, "value": ""}}}, {"outValue": 1.3103822980428095, "simIndex": 59.0, "features": {"0": {"effect": 0.9642807129742618, "value": ""}, "1": {"effect": 0.6885456954529923, "value": ""}}}, {"outValue": 1.2373069757426942, "simIndex": 47.0, "features": {"0": {"effect": 0.814212518998411, "value": ""}, "1": {"effect": 0.7655385671287277, "value": ""}}}, {"outValue": 0.24191195410569305, "simIndex": 282.0, "features": {"0": {"effect": 0.4584717306885955, "value": ""}, "1": {"effect": 0.12588433380154196, "value": ""}}}, {"outValue": 0.09842560131455275, "simIndex": 117.0, "features": {"0": {"effect": 0.24170856184519038, "value": ""}, "1": {"effect": ...
# <div id='i3GZE1ML5UXLB6XWSXAA2'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Different, A=pos"], "baseValue": -2.1398548703396454, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.04128080785237298, "simIndex": 152.0, "features": {"0": {"effect": 1.0896824724001226, "value": ""}, "1": {"effect": 1.0914532057918955, "value": ""}}}, {"outValue": -0.013040373642242642, "simIndex": 153.0, "features": {"0": {"effect": 1.061549719605512, "value": ""}, "1": {"effect": 1.0652647770918906, "value": ""}}}, {"outValue": -0.1760881218300696, "simIndex": 162.0, "features": {"0": {"effect": 0.8857499637053321, "value": ""}, "1": {"effect": 1.0780167848042437, "value": ""}}}, {"outValue": -2.050755680041533, "simIndex": 331.0, "features": {"0": {"effect": 0.17467744215847536, "value": ""}, "1": {"effect": -0.08557825186036316, "value": ""}}}, {"outValue": -2.8831770906152405, "simIndex": 293.0, "features": {"0": {"effect": -0.103329940769878, "value": ""}, "1": {"effect": -0.6399922795057169, "value": ""}}}, {"outValue": -3.787352692474716, "simIndex": 251.0, "features": {"0": {"effect": -1.0104592900861342, "value": ""}, "1": {"effect": -0.6370385320489367, "value": ""}}}, {"outValue": 2.4247055447751453, "simIndex": 27.0, "features": {"0": {"effect": 2.135865727227587, "value": ""}, "1": {"effect": 2.4286946878872033, "value": ""}}}, {"outValue": 1.445340349170532, "simIndex": 38.0, "features": {"0": {"effect": 1.8929847709660854, "value": ""}, "1": {"effect": 1.6922104485440919, "value": ""}}}, {"outValue": 2.1948889148829878, "simIndex": 23.0, "features": {"0": {"effect": 2.4151656054643524, "value": ""}, "1": {"effect": 1.9195781797582812, "value": ""}}}, {"outValue": -0.13346826639186027, "simIndex": 134.0, "features": {"0": {"effect": 1.068093914517457, "value": ""}, "1": {"effect": 0.9382926894303281, "value": ""}}}, {"outValue": 0.3978453733281313, "simIndex": 107.0, "features": {"0": {"effect": 1.2955461173311142, "value": ""}, "1": {"effect": 1.2421541263366624, "value": ""}}}, {"outValue": -2.6927325802699906, "simIndex": 244.0, "features": {"0": {"effect": -0.7712752996516408, "value": ""}, "1": {"effect": 0.21839758972129575, "value": ""}}}, {"outValue": 2.7394639044358655, "simIndex": 5.0, "features": {"0": {"effect": 2.482084359794465, "value": ""}, "1": {"effect": 2.3972344149810456, "value": ""}}}, {"outValue": 0.8582313222297078, "simIndex": 67.0, "features": {"0": {"effect": 1.527280109514876, "value": ""}, "1": {"effect": 1.4708060830544771, "value": ""}}}, {"outValue": 0.7397520662501096, "simIndex": 55.0, "features": {"0": {"effect": 1.702543560361258, "value": ""}, "1": {"effect": 1.177063376228497, "value": ""}}}, {"outValue": 1.381158446462507, "simIndex": 41.0, "features": {"0": {"effect": 1.790094378864525, "value": ""}, "1": {"effect": 1.7309189379376273, "value": ""}}}, {"outValue": 0.991929187891718, "simIndex": 78.0, "features": {"0": {"effect": 1.6806980912023688, "value": ""}, "1": {"effect": 1.4510859670289948, "value": ""}}}, {"outValue": -2.619496535233994, "simIndex": 236.0, "features": {"0": {"effect": -0.5889837768592074, "value": ""}, "1": {"effect": 0.10934211196485877, "value": ""}}}, {"outValue": 2.25142788169404, "simIndex": 14.0, "features": {"0": {"effect": 2.1685531721195046, "value": ""}, "1": {"effect": 2.222729579914181, "value": ""}}}, {"outValue": -4.563387717258151, "simIndex": 360.0, "features": {"0": {"effect": -0.7898443984668215, "value": ""}, "1": {"effect": -1.6336884484516843, "value": ""}}}, {"outValue": -4.098778631130346, "simIndex": 268.0, "features": {"0": {"effect": -1.0521342949569645, "value": ""}, "1": {"effect": -0.9067894658337352, "value": ""}}}, {"outValue": -3.7157971049606013, "simIndex": 273.0, "features": {"0": {"effect": 0.021072054250711902, "value": ""}, "1": {"effect": -1.5970142888716676, "value": ""}}}, {"outValue": -1.7246045202089109, "simIndex": 347.0, "features": {"0": {"effect": 0.2282952000083731, "value": ""}, "1": {" ...
# <div id='i6OBRDZY584LPA8QA7LTA'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Different, B=pos"], "baseValue": -1.6204182714067783, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -4.124190710194241, "simIndex": 110.0, "features": {"0": {"effect": -0.17463157116888972, "value": ""}, "1": {"effect": -2.3291408676185728, "value": ""}}}, {"outValue": -2.3507380347270934, "simIndex": 166.0, "features": {"0": {"effect": -0.39006085886874886, "value": ""}, "1": {"effect": -0.34025890445156626, "value": ""}}}, {"outValue": -2.3884349605766966, "simIndex": 142.0, "features": {"0": {"effect": -0.037789293645966726, "value": ""}, "1": {"effect": -0.7302273955239513, "value": ""}}}, {"outValue": -0.2797534125737686, "simIndex": 203.0, "features": {"0": {"effect": 0.6320314486722698, "value": ""}, "1": {"effect": 0.7086334101607399, "value": ""}}}, {"outValue": 0.27031994894965283, "simIndex": 301.0, "features": {"0": {"effect": 0.9133716910158701, "value": ""}, "1": {"effect": 0.977366529340561, "value": ""}}}, {"outValue": 0.9103277906061034, "simIndex": 338.0, "features": {"0": {"effect": 1.3139837393415428, "value": ""}, "1": {"effect": 1.216762322671339, "value": ""}}}, {"outValue": -7.038171099098999, "simIndex": 21.0, "features": {"0": {"effect": -3.3605853335501323, "value": ""}, "1": {"effect": -2.057167494142088, "value": ""}}}, {"outValue": -5.323680312929282, "simIndex": 9.0, "features": {"0": {"effect": -1.1870534668153179, "value": ""}, "1": {"effect": -2.5162085747071856, "value": ""}}}, {"outValue": -7.385488575022688, "simIndex": 3.0, "features": {"0": {"effect": -1.887485162275544, "value": ""}, "1": {"effect": -3.8775851413403655, "value": ""}}}, {"outValue": -2.364938944059558, "simIndex": 183.0, "features": {"0": {"effect": -0.6510945853793908, "value": ""}, "1": {"effect": -0.09342608727338897, "value": ""}}}, {"outValue": -4.217156429593668, "simIndex": 106.0, "features": {"0": {"effect": -0.38140157568380295, "value": ""}, "1": {"effect": -2.2153365825030864, "value": ""}}}, {"outValue": -0.22709962554740937, "simIndex": 241.0, "features": {"0": {"effect": 0.9251411206078997, "value": ""}, "1": {"effect": 0.4681775252514694, "value": ""}}}, {"outValue": -7.001450681474159, "simIndex": 33.0, "features": {"0": {"effect": -2.5458371241302573, "value": ""}, "1": {"effect": -2.835195285937123, "value": ""}}}, {"outValue": -4.229272428182964, "simIndex": 92.0, "features": {"0": {"effect": -0.7074528742932911, "value": ""}, "1": {"effect": -1.9014012824828943, "value": ""}}}, {"outValue": -6.144311446268025, "simIndex": 17.0, "features": {"0": {"effect": -0.7598556383941857, "value": ""}, "1": {"effect": -3.764037536467061, "value": ""}}}, {"outValue": -4.661165225100137, "simIndex": 82.0, "features": {"0": {"effect": -1.2062964443726332, "value": ""}, "1": {"effect": -1.8344505093207257, "value": ""}}}, {"outValue": -5.107134491673154, "simIndex": 12.0, "features": {"0": {"effect": -0.8263077768147933, "value": ""}, "1": {"effect": -2.660408443451582, "value": ""}}}, {"outValue": -0.05657205651860764, "simIndex": 254.0, "features": {"0": {"effect": 0.9526917306509652, "value": ""}, "1": {"effect": 0.6111544842372054, "value": ""}}}, {"outValue": -6.076451849494118, "simIndex": 28.0, "features": {"0": {"effect": -2.381657547385678, "value": ""}, "1": {"effect": -2.0743760307016617, "value": ""}}}, {"outValue": 1.2497584127595078, "simIndex": 367.0, "features": {"0": {"effect": 1.4917626365097358, "value": ""}, "1": {"effect": 1.37841404765655, "value": ""}}}, {"outValue": 1.1459632118205003, "simIndex": 369.0, "features": {"0": {"effect": 1.4190659677929525, "value": ""}, "1": {"effect": 1.3473155154343264, "value": ""}}}, {"outValue": 0.14596622792047342, "simIndex": 307.0, "features": {"0": {"effect": 0.8138049347038545, "value": ""}, "1": {"effect": 0.9525795646233972, "value": ""}}}, {"outValue": -0.5180533752893963, "simIndex": 230.0, "features": {"0": {"effect": 0.5685072241502083, " ...

# %%
order = plot.shap_force(shap_values_diff[idx_equal], 'Different')
plot.shap_force(shap_values_diff_a_pos[idx_equal], 'Different, A=pos', ordering=order)
plot.shap_force(shap_values_diff_b_pos[idx_equal], 'Different, B=pos', ordering=order);
# Out:
# <div id='i208SVD6OX96C8TC5M1YX'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Different"], "baseValue": -0.3424441103844444, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -1.1747975065752636, "simIndex": 160.0, "features": {"0": {"effect": -0.5164976825875627, "value": ""}, "1": {"effect": -0.3158557136032566, "value": ""}}}, {"outValue": -0.3300460794785254, "simIndex": 238.0, "features": {"0": {"effect": -0.303032652467609, "value": ""}, "1": {"effect": 0.31543068337352803, "value": ""}}}, {"outValue": -0.25943138094028023, "simIndex": 260.0, "features": {"0": {"effect": -0.03312802894086933, "value": ""}, "1": {"effect": 0.11614075838503349, "value": ""}}}, {"outValue": -3.1865398000869662, "simIndex": 25.0, "features": {"0": {"effect": -1.5879590454181047, "value": ""}, "1": {"effect": -1.2561366442844173, "value": ""}}}, {"outValue": -3.51427855205975, "simIndex": 14.0, "features": {"0": {"effect": -2.054165039707901, "value": ""}, "1": {"effect": -1.1176694019674045, "value": ""}}}, {"outValue": -3.403081416473259, "simIndex": 17.0, "features": {"0": {"effect": -1.968029629927516, "value": ""}, "1": {"effect": -1.0926076761612986, "value": ""}}}, {"outValue": -1.3706377528837532, "simIndex": 484.0, "features": {"0": {"effect": -0.5705697060033976, "value": ""}, "1": {"effect": -0.4576239364959112, "value": ""}}}, {"outValue": -0.25354099149062415, "simIndex": 261.0, "features": {"0": {"effect": -0.03434414356059365, "value": ""}, "1": {"effect": 0.12324726245441389, "value": ""}}}, {"outValue": -0.3005871353981035, "simIndex": 392.0, "features": {"0": {"effect": 0.3593361230378195, "value": ""}, "1": {"effect": -0.3174791480514786, "value": ""}}}, {"outValue": -0.3454117290981632, "simIndex": 239.0, "features": {"0": {"effect": -0.3214950192856061, "value": ""}, "1": {"effect": 0.3185274005718873, "value": ""}}}, {"outValue": -0.031198256160186233, "simIndex": 332.0, "features": {"0": {"effect": 0.19802787884329529, "value": ""}, "1": {"effect": 0.11321797538096288, "value": ""}}}, {"outValue": -0.4261897846204217, "simIndex": 246.0, "features": {"0": {"effect": -0.20382019622288053, "value": ""}, "1": {"effect": 0.12007452198690322, "value": ""}}}, {"outValue": -1.115158902489454, "simIndex": 181.0, "features": {"0": {"effect": -0.5859766055262905, "value": ""}, "1": {"effect": -0.186738186578719, "value": ""}}}, {"outValue": -1.1372925430297727, "simIndex": 161.0, "features": {"0": {"effect": -0.40220563494052364, "value": ""}, "1": {"effect": -0.3926427977048047, "value": ""}}}, {"outValue": -0.5377175129079462, "simIndex": 198.0, "features": {"0": {"effect": -0.11911669368504499, "value": ""}, "1": {"effect": -0.07615670883845685, "value": ""}}}, {"outValue": -0.06316902149643394, "simIndex": 324.0, "features": {"0": {"effect": 0.1826776368668408, "value": ""}, "1": {"effect": 0.09659745202116962, "value": ""}}}, {"outValue": -0.8096036972170978, "simIndex": 217.0, "features": {"0": {"effect": -0.17180910913084058, "value": ""}, "1": {"effect": -0.29535047770181283, "value": ""}}}, {"outValue": -0.46140209452857295, "simIndex": 424.0, "features": {"0": {"effect": 0.0633009662912733, "value": ""}, "1": {"effect": -0.18225895043540183, "value": ""}}}, {"outValue": -0.6348385283075119, "simIndex": 203.0, "features": {"0": {"effect": -0.13992538226893436, "value": ""}, "1": {"effect": -0.1524690356541331, "value": ""}}}, {"outValue": -2.853954269699922, "simIndex": 21.0, "features": {"0": {"effect": -1.449766736072657, "value": ""}, "1": {"effect": -1.0617434232428207, "value": ""}}}, {"outValue": -0.4254600311872707, "simIndex": 431.0, "features": {"0": {"effect": 0.006011122298123228, "value": ""}, "1": {"effect": -0.08902704310094953, "value": ""}}}, {"outValue": -0.042636987383567304, "simIndex": 326.0, "features": {"0": {"effect": 0.18275791360288962, "value": ""}, "1": {"effect": 0.11704920939798746, "value": ""}}}, {"outValue": -0.8028905238339321, "simIndex": 230.0, "features":  ...
# <div id='iZDELM4U0L2FFTO5ZYDR5'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Different, A=pos"], "baseValue": -2.1398548703396454, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -2.322158486332546, "simIndex": 395.0, "features": {"0": {"effect": 0.6595358211852105, "value": ""}, "1": {"effect": -0.8418394371781113, "value": ""}}}, {"outValue": -0.4675046232992539, "simIndex": 262.0, "features": {"0": {"effect": 0.965742229061908, "value": ""}, "1": {"effect": 0.7066080179784835, "value": ""}}}, {"outValue": -1.2075024141033737, "simIndex": 302.0, "features": {"0": {"effect": 0.7230812604822274, "value": ""}, "1": {"effect": 0.20927119575404418, "value": ""}}}, {"outValue": -4.168632176433408, "simIndex": 471.0, "features": {"0": {"effect": 0.4315598948747009, "value": ""}, "1": {"effect": -2.4603372009684636, "value": ""}}}, {"outValue": -3.745998364200654, "simIndex": 418.0, "features": {"0": {"effect": 0.1682310431952626, "value": ""}, "1": {"effect": -1.774374537056271, "value": ""}}}, {"outValue": -3.671269539867917, "simIndex": 417.0, "features": {"0": {"effect": 0.22248440146430715, "value": ""}, "1": {"effect": -1.753899070992579, "value": ""}}}, {"outValue": -3.655458385129768, "simIndex": 39.0, "features": {"0": {"effect": -2.026219076179668, "value": ""}, "1": {"effect": 0.5106155613895456, "value": ""}}}, {"outValue": -3.466279584199051, "simIndex": 82.0, "features": {"0": {"effect": -1.5664374547020117, "value": ""}, "1": {"effect": 0.24001274084260604, "value": ""}}}, {"outValue": -0.3791257591808799, "simIndex": 245.0, "features": {"0": {"effect": 0.8153572923343908, "value": ""}, "1": {"effect": 0.9453718188243747, "value": ""}}}, {"outValue": -5.075979267024875, "simIndex": 14.0, "features": {"0": {"effect": -3.0201671469633156, "value": ""}, "1": {"effect": 0.08404275027808605, "value": ""}}}, {"outValue": -0.7415969441745682, "simIndex": 244.0, "features": {"0": {"effect": 0.5850683751549411, "value": ""}, "1": {"effect": 0.8131895510101359, "value": ""}}}, {"outValue": -0.9381438444501289, "simIndex": 274.0, "features": {"0": {"effect": 0.871318733387295, "value": ""}, "1": {"effect": 0.3303922925022215, "value": ""}}}, {"outValue": -1.710513580750663, "simIndex": 315.0, "features": {"0": {"effect": 0.7455979014816466, "value": ""}, "1": {"effect": -0.3162566118926643, "value": ""}}}, {"outValue": -3.1898385901133666, "simIndex": 65.0, "features": {"0": {"effect": -1.5750511397716904, "value": ""}, "1": {"effect": 0.5250674199979692, "value": ""}}}, {"outValue": -2.2078876648222012, "simIndex": 341.0, "features": {"0": {"effect": 0.5571516717475018, "value": ""}, "1": {"effect": -0.6251844662300576, "value": ""}}}, {"outValue": -0.8864114271762094, "simIndex": 222.0, "features": {"0": {"effect": 0.5010517129511984, "value": ""}, "1": {"effect": 0.7523917302122376, "value": ""}}}, {"outValue": -2.4354004502200457, "simIndex": 118.0, "features": {"0": {"effect": -0.864972339834672, "value": ""}, "1": {"effect": 0.5694267599542716, "value": ""}}}, {"outValue": -1.150224901523487, "simIndex": 176.0, "features": {"0": {"effect": 0.18148061372936586, "value": ""}, "1": {"effect": 0.8081493550867925, "value": ""}}}, {"outValue": -2.8315156300355975, "simIndex": 97.0, "features": {"0": {"effect": -1.1509336311073803, "value": ""}, "1": {"effect": 0.4592728714114285, "value": ""}}}, {"outValue": -3.713639000231632, "simIndex": 461.0, "features": {"0": {"effect": 0.4791232647900934, "value": ""}, "1": {"effect": -2.05290739468208, "value": ""}}}, {"outValue": -2.762986761940759, "simIndex": 368.0, "features": {"0": {"effect": 0.428097960939411, "value": ""}, "1": {"effect": -1.0512298525405246, "value": ""}}}, {"outValue": -1.2604219710246554, "simIndex": 199.0, "features": {"0": {"effect": 0.32832364573693207, "value": ""}, "1": {"effect": 0.551109253578058, "value": ""}}}, {"outValue": -1.843651717926661, "simIndex": 147.0, "features": {"0": {"effect": -0.3897327754259948, "value": ...
# <div id='i89S6FGBY6CUEF2LR36P5'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Different, B=pos"], "baseValue": -1.6204182714067783, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -1.7608449167828522, "simIndex": 132.0, "features": {"0": {"effect": -0.7536100727330525, "value": ""}, "1": {"effect": 0.6131834273569786, "value": ""}}}, {"outValue": -3.376989971180324, "simIndex": 64.0, "features": {"0": {"effect": -1.871578265722905, "value": ""}, "1": {"effect": 0.1150065659493591, "value": ""}}}, {"outValue": -1.3531232715815986, "simIndex": 154.0, "features": {"0": {"effect": -0.19115453211784472, "value": ""}, "1": {"effect": 0.4584495319430243, "value": ""}}}, {"outValue": -3.6868838397869026, "simIndex": 36.0, "features": {"0": {"effect": -2.3960064360150612, "value": ""}, "1": {"effect": 0.3295408676349372, "value": ""}}}, {"outValue": -5.136942476845252, "simIndex": 11.0, "features": {"0": {"effect": -3.893339243350932, "value": ""}, "1": {"effect": 0.37681503791245863, "value": ""}}}, {"outValue": -4.900688020042267, "simIndex": 16.0, "features": {"0": {"effect": -3.667544528399864, "value": ""}, "1": {"effect": 0.3872747797643745, "value": ""}}}, {"outValue": -1.5346212452466164, "simIndex": 399.0, "features": {"0": {"effect": 0.5916408834627969, "value": ""}, "1": {"effect": -0.5058438573026349, "value": ""}}}, {"outValue": -0.377769103154006, "simIndex": 250.0, "features": {"0": {"effect": 0.8669618385858129, "value": ""}, "1": {"effect": 0.3756873296669594, "value": ""}}}, {"outValue": -3.9400538985566596, "simIndex": 474.0, "features": {"0": {"effect": 0.038729465268025565, "value": ""}, "1": {"effect": -2.3583650924179067, "value": ""}}}, {"outValue": -0.37104186247889004, "simIndex": 241.0, "features": {"0": {"effect": 0.6387652561688231, "value": ""}, "1": {"effect": 0.6106111527590652, "value": ""}}}, {"outValue": -1.5888480231488042, "simIndex": 338.0, "features": {"0": {"effect": 0.2339170168867576, "value": ""}, "1": {"effect": -0.20234676862878342, "value": ""}}}, {"outValue": -2.052885797496821, "simIndex": 138.0, "features": {"0": {"effect": -0.789762644549268, "value": ""}, "1": {"effect": 0.35729511845922546, "value": ""}}}, {"outValue": -2.2679393381511948, "simIndex": 104.0, "features": {"0": {"effect": -1.1698656302028163, "value": ""}, "1": {"effect": 0.5223445634584, "value": ""}}}, {"outValue": -1.3659937367759014, "simIndex": 312.0, "features": {"0": {"effect": 0.6746798635479252, "value": ""}, "1": {"effect": -0.42025532891704837, "value": ""}}}, {"outValue": -0.9962756670805818, "simIndex": 189.0, "features": {"0": {"effect": -0.07589185808836796, "value": ""}, "1": {"effect": 0.7000344624145645, "value": ""}}}, {"outValue": -1.434734562803032, "simIndex": 339.0, "features": {"0": {"effect": 0.30726110487121305, "value": ""}, "1": {"effect": -0.12157739626746666, "value": ""}}}, {"outValue": -1.2226969301967925, "simIndex": 315.0, "features": {"0": {"effect": 0.7277819797245628, "value": ""}, "1": {"effect": -0.33006063851457706, "value": ""}}}, {"outValue": -1.7646793324870282, "simIndex": 406.0, "features": {"0": {"effect": 0.4643584348940074, "value": ""}, "1": {"effect": -0.6086194959742574, "value": ""}}}, {"outValue": -0.8916495922392755, "simIndex": 299.0, "features": {"0": {"effect": 0.7830192136299873, "value": ""}, "1": {"effect": -0.05425053446248446, "value": ""}}}, {"outValue": -3.4533434299168597, "simIndex": 46.0, "features": {"0": {"effect": -2.238949105252427, "value": ""}, "1": {"effect": 0.40602394674234543, "value": ""}}}, {"outValue": -0.6818273888196466, "simIndex": 221.0, "features": {"0": {"effect": 0.16704208943467813, "value": ""}, "1": {"effect": 0.7715487931524536, "value": ""}}}, {"outValue": -1.0025461787964502, "simIndex": 266.0, "features": {"0": {"effect": 0.4573280784524997, "value": ""}, "1": {"effect": 0.16054401415782837, "value": ""}}}, {"outValue": -1.5659986436066897, "simIndex": 396.0, "features": {"0": {"effect": 0.63850 ...

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %%
plot.shap_heatmap(shap_values_diff[idx_diff], 'Different', feature_order)

# %%
plot.shap_heatmap(shap_values_diff[idx_equal], 'Different', feature_order)

# %%
plot.shap_heatmap(shap_values_diff_a_pos[idx_diff], 'Different, A=pos', feature_order)

# %%
plot.shap_heatmap(shap_values_diff_a_pos[idx_equal], 'Different, A=pos', feature_order)

# %%
plot.shap_heatmap(shap_values_diff_b_pos[idx_diff], 'Different, B=pos', feature_order)

# %%
plot.shap_heatmap(shap_values_diff_b_pos[idx_equal], 'Different, B=pos', feature_order)

# %%
plot.shap_heatmap(shap_values_diff_a_vs_b_pos[idx_diff], 'Different, A vs. B pos', feature_order)

# %%
plot.shap_heatmap(shap_values_diff_a_vs_b_pos[idx_equal], 'Different, A vs. B pos', feature_order)

# %% [markdown]
# ### Unusual instances

# %% [markdown]
# #### Non-finite SHAP-values

# %%
idx_nonfinite = np.where(~is_finite)[0]

# %%
pd.DataFrame(X[idx_nonfinite, :], index=idx_nonfinite, columns=feature_names)
# Out:
# Empty DataFrame
# Columns: [x1, x2]
# Index: []

# %%
pd.DataFrame(shap_values_diff[idx_nonfinite].values, index=idx_nonfinite, columns=feature_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Users/karl/.pyenv/versions/3.9.0/lib/python3.9/site-packages/IPython/core/interactiveshell.py, in run_code:
# Line 3437:  exec(code_obj, self.user_global_ns, self.user_ns)
#
# In  [29]:
# Line 1:     pd.DataFrame(shap_values_diff[idx_nonfinite].values, index=idx_nonfinite, columns=feature_names)
#
# File /Users/karl/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/frame.py, in __init__:
# Line 558:   mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#
# File /Users/karl/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/internals/construction.py, in init_ndarray:
# Line 238:   return create_block_manager_from_blocks(block_values, [columns, index])
#
# File /Users/karl/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/internals/managers.py, in create_block_manager_from_blocks:
# Line 1687:  raise construction_error(tot_items, blocks[0].shape[1:], axes, e)
#
# ValueError: Empty data passed with indices specified.
# ---------------------------------------------------------------------------
