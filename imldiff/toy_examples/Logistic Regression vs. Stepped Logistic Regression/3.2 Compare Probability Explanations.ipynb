# %%
import plot
from scipy.special import logit
from shap.maskers import Independent
from sklearn.utils import resample, shuffle
import shap
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open('classifiers.pickle', 'rb') as f:
    clf_a, clf_b = pickle.load(f)
with open('predictions.pickle', 'rb') as f:
    X, feature_names, n_features, n_samples, indices, pred_a, pred_b, proba_a, proba_b, log_proba_a, log_proba_b, log_odds_a, log_odds_b = pickle.load(f)

# %%
try:
    with open(f'shapvalues.soa.proba.pickle', 'rb') as f:
        shap_values_a, shap_values_b, shap_values_a_vs_b, feature_order = pickle.load(f)
        print('Loaded cached shap values')
except FileNotFoundError:
    print('No cached shap values found')
# Out:
# Loaded cached shap values

# %% [markdown]
# ## Generate Explanations

# %% [markdown]
# Now we define the functions to be explained:

# %%
predict_proba_a = lambda X: clf_a.predict_proba(X)[:, 1]
predict_proba_b = lambda X: clf_b.predict_proba(X)[:, 1]

# %% [markdown]
# And now we calculate SHAP values for each function:

# %%
# %%time

background_data = X
def explain(predict):
    masker = Independent(data=background_data, max_samples=100)
    explainer = shap.Explainer(predict, masker, feature_names=feature_names)
    shap_values = explainer(X)
    return shap_values

shap_values_a = explain(predict_proba_a)
shap_values_b = explain(predict_proba_b)

shap_values_a_vs_b = shap_values_b - shap_values_a
shap_values_a_vs_b.data = shap_values_a.data

feature_order = np.flip(shap_values_a_vs_b.abs.mean(axis=0).values.argsort())

with open(f'shapvalues.soa.proba.pickle', 'wb') as f:
    pickle.dump((shap_values_a, shap_values_b, shap_values_a_vs_b, feature_order), f, pickle.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 5.55 s, sys: 105 ms, total: 5.65 s
# Wall time: 6.58 s

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# We estimate it with the mean absolute SHAP value (which is the default for this plot) and will also sort features subsequently in this order

# %%
shap.plots.bar(shap_values_a, order=feature_order, max_display=n_features)
shap.plots.bar(shap_values_b, max_display=n_features)
shap.plots.bar(shap_values_a_vs_b, order=feature_order, max_display=n_features)

# %% [markdown]
# ### SHAP Value Distribution

# %%
plot.shap_beeswarm(shap_values_a, 'A', order=feature_order, max_display=n_features)

# %%
plot.shap_beeswarm(shap_values_b, 'B', order=feature_order, max_display=n_features)

# %%
plot.shap_beeswarm(shap_values_a_vs_b, 'A vs. B', order=feature_order, max_display=n_features)

# %% [markdown]
# ### Features' Partial Dependence Plots

# %%
n_columns = 3
n_rows = n_features
fig = plt.figure(figsize=(9*n_columns, 7*n_rows))
i = 1
for feature in feature_names:
    ax1 = fig.add_subplot(n_rows, n_columns, i)
    ax2 = fig.add_subplot(n_rows, n_columns, i+1, sharey=ax1)
    ax3 = fig.add_subplot(n_rows, n_columns, i+2, sharey=None)
    shap.plots.scatter(shap_values_a[:, feature], title='A', ax=ax1, color='blue', show=False)
    shap.plots.scatter(shap_values_a[pred_a != pred_b, feature], title='A', ax=ax1, color='red',  hist=False, show=False)
    shap.plots.scatter(shap_values_b[:, feature], title='B', ax=ax2, color='blue', dot_size=16, show=False)
    shap.plots.scatter(shap_values_b[pred_a != pred_b, feature], title='B', ax=ax2, color='red', hist=False, show=False)
    shap.plots.scatter(shap_values_a_vs_b[:, feature], title='B - A', ax=ax3, color='blue', show=False)
    shap.plots.scatter(shap_values_a_vs_b[pred_a != pred_b, feature], title='B - A', ax=ax3, color='red', hist=False, show=False)
    i += n_columns
plt.show()

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %%
idx_diff = indices[pred_a != pred_b]
idx_equal = indices[pred_a == pred_b]
if len(idx_diff) > 500:
    idx_diff = shuffle(idx_diff, random_state=0, n_samples=500)
if len(idx_equal) > 500:
    idx_equal = shuffle(idx_equal, random_state=0, n_samples=500)

# %%
order = plot.shap_force(shap_values_a_vs_b[idx_diff], 'A vs. B')
plot.shap_force(shap_values_a[idx_diff], 'A', ordering=order)
plot.shap_force(shap_values_b[idx_diff], 'B', ordering=order);
# Out:
# <div id='iYTP2Z5O1HST920GUUO9V'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": 0.008324389885092653, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": -0.0071918068212042385, "simIndex": 31.0, "features": {"0": {"effect": -0.015516196706296892, "value": ""}}}, {"outValue": -0.16214562812908018, "simIndex": 7.0, "features": {"0": {"effect": -0.17047001801417283, "value": ""}}}, {"outValue": -0.08352589621385109, "simIndex": 20.0, "features": {"0": {"effect": -0.09185028609894375, "value": ""}}}, {"outValue": -0.07116431548325663, "simIndex": 23.0, "features": {"0": {"effect": -0.07948870536834929, "value": ""}}}, {"outValue": -0.0955273299480961, "simIndex": 17.0, "features": {"0": {"effect": -0.10385171983318875, "value": ""}}}, {"outValue": -0.021693242576631744, "simIndex": 29.0, "features": {"0": {"effect": -0.030017632461724397, "value": ""}}}, {"outValue": -0.12943882305172183, "simIndex": 13.0, "features": {"0": {"effect": -0.13776321293681448, "value": ""}}}, {"outValue": -0.10230172970095452, "simIndex": 15.0, "features": {"0": {"effect": -0.11062611958604718, "value": ""}}}, {"outValue": -0.23070721179127573, "simIndex": 1.0, "features": {"0": {"effect": -0.2390316016763684, "value": ""}}}, {"outValue": -0.08878410617474186, "simIndex": 19.0, "features": {"0": {"effect": -0.09710849605983451, "value": ""}}}, {"outValue": -0.0005860856169449535, "simIndex": 34.0, "features": {"0": {"effect": -0.008910475502037607, "value": ""}}}, {"outValue": -0.2255354729097958, "simIndex": 2.0, "features": {"0": {"effect": -0.23385986279488846, "value": ""}}}, {"outValue": -0.15179018036597813, "simIndex": 10.0, "features": {"0": {"effect": -0.1601145702510708, "value": ""}}}, {"outValue": -0.06913598387760134, "simIndex": 24.0, "features": {"0": {"effect": -0.07746037376269399, "value": ""}}}, {"outValue": -0.09960708130245177, "simIndex": 16.0, "features": {"0": {"effect": -0.10793147118754443, "value": ""}}}, {"outValue": -0.06597887617249387, "simIndex": 25.0, "features": {"0": {"effect": -0.07430326605758653, "value": ""}}}, {"outValue": -0.16801813459003556, "simIndex": 6.0, "features": {"0": {"effect": -0.17634252447512822, "value": ""}}}, {"outValue": -0.21660239293641492, "simIndex": 3.0, "features": {"0": {"effect": -0.22492678282150758, "value": ""}}}, {"outValue": -0.02578488621241337, "simIndex": 28.0, "features": {"0": {"effect": -0.034109276097506025, "value": ""}}}, {"outValue": -0.09424586221581244, "simIndex": 18.0, "features": {"0": {"effect": -0.10257025210090509, "value": ""}}}, {"outValue": -0.19717579995860846, "simIndex": 5.0, "features": {"0": {"effect": -0.2055001898437011, "value": ""}}}, {"outValue": -0.007157474947662945, "simIndex": 32.0, "features": {"0": {"effect": -0.015481864832755599, "value": ""}}}, {"outValue": -0.008772017120345033, "simIndex": 30.0, "features": {"0": {"effect": -0.017096407005437686, "value": ""}}}, {"outValue": -0.07656878359324526, "simIndex": 21.0, "features": {"0": {"effect": -0.08489317347833791, "value": ""}}}, {"outValue": -0.07524526150243771, "simIndex": 22.0, "features": {"0": {"effect": -0.08356965138753036, "value": ""}}}, {"outValue": -0.0023266813528146635, "simIndex": 33.0, "features": {"0": {"effect": -0.010651071237907317, "value": ""}}}, {"outValue": -0.04851571798736376, "simIndex": 26.0, "features": {"0": {"effect": -0.056840107872456413, "value": ""}}}, {"outValue": -0.13509665250826108, "simIndex": 12.0, "features": {"0": {"effect": -0.14342104239335374, "value": ""}}}, {"outValue": -0.1445182946112169, "simIndex": 11.0, "features": {"0": {"effect": -0.15284268449630956, "value": ""}}}, {"outValue": -0.042485820739427416, "simIndex": 27.0, "features": {"0": {"effect": -0.05081021062452007, "value": ""}}}, {"outValue": -0.16125914570883448, "simIndex": 8.0, "features": {"0": {"effect": -0.16958353559392714, "value": ""}}}, {"outValue": -0.15777845410294622, "simIndex": 9.0, "features": {"0": {"effect": -0.16610 ...
#     document.getElementById('iYTP2Z5O1HST920GUUO9V')
#   );
# </script>
# <div id='iL2IFZNQ4Z9NP7Y6KQLDJ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0.46103039947139296, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": 0.5071918068212042, "simIndex": 31.0, "features": {"0": {"effect": 0.04616140734981128, "value": ""}}}, {"outValue": 0.6621456281290802, "simIndex": 7.0, "features": {"0": {"effect": 0.20111522865768722, "value": ""}}}, {"outValue": 0.5835258962138511, "simIndex": 20.0, "features": {"0": {"effect": 0.12249549674245813, "value": ""}}}, {"outValue": 0.5711643154832566, "simIndex": 23.0, "features": {"0": {"effect": 0.11013391601186368, "value": ""}}}, {"outValue": 0.5955273299480961, "simIndex": 17.0, "features": {"0": {"effect": 0.13449693047670314, "value": ""}}}, {"outValue": 0.5216932425766317, "simIndex": 29.0, "features": {"0": {"effect": 0.060662843105238784, "value": ""}}}, {"outValue": 0.6294388230517218, "simIndex": 13.0, "features": {"0": {"effect": 0.16840842358032887, "value": ""}}}, {"outValue": 0.6023017297009545, "simIndex": 15.0, "features": {"0": {"effect": 0.14127133022956156, "value": ""}}}, {"outValue": 0.7307072117912757, "simIndex": 1.0, "features": {"0": {"effect": 0.2696768123198828, "value": ""}}}, {"outValue": 0.5887841061747419, "simIndex": 19.0, "features": {"0": {"effect": 0.1277537067033489, "value": ""}}}, {"outValue": 0.500586085616945, "simIndex": 34.0, "features": {"0": {"effect": 0.039555686145551994, "value": ""}}}, {"outValue": 0.7255354729097958, "simIndex": 2.0, "features": {"0": {"effect": 0.26450507343840285, "value": ""}}}, {"outValue": 0.6517901803659781, "simIndex": 10.0, "features": {"0": {"effect": 0.19075978089458517, "value": ""}}}, {"outValue": 0.5691359838776013, "simIndex": 24.0, "features": {"0": {"effect": 0.10810558440620838, "value": ""}}}, {"outValue": 0.5996070813024518, "simIndex": 16.0, "features": {"0": {"effect": 0.1385766818310588, "value": ""}}}, {"outValue": 0.5659788761724939, "simIndex": 25.0, "features": {"0": {"effect": 0.10494847670110091, "value": ""}}}, {"outValue": 0.6680181345900356, "simIndex": 6.0, "features": {"0": {"effect": 0.2069877351186426, "value": ""}}}, {"outValue": 0.7166023929364149, "simIndex": 3.0, "features": {"0": {"effect": 0.25557199346502196, "value": ""}}}, {"outValue": 0.5257848862124134, "simIndex": 28.0, "features": {"0": {"effect": 0.06475448674102041, "value": ""}}}, {"outValue": 0.5942458622158124, "simIndex": 18.0, "features": {"0": {"effect": 0.13321546274441948, "value": ""}}}, {"outValue": 0.6971757999586085, "simIndex": 5.0, "features": {"0": {"effect": 0.2361454004872155, "value": ""}}}, {"outValue": 0.507157474947663, "simIndex": 32.0, "features": {"0": {"effect": 0.046127075476269985, "value": ""}}}, {"outValue": 0.508772017120345, "simIndex": 30.0, "features": {"0": {"effect": 0.04774161764895207, "value": ""}}}, {"outValue": 0.5765687835932453, "simIndex": 21.0, "features": {"0": {"effect": 0.1155383841218523, "value": ""}}}, {"outValue": 0.5752452615024377, "simIndex": 22.0, "features": {"0": {"effect": 0.11421486203104475, "value": ""}}}, {"outValue": 0.5023266813528147, "simIndex": 33.0, "features": {"0": {"effect": 0.041296281881421704, "value": ""}}}, {"outValue": 0.5485157179873638, "simIndex": 26.0, "features": {"0": {"effect": 0.0874853185159708, "value": ""}}}, {"outValue": 0.6350966525082611, "simIndex": 12.0, "features": {"0": {"effect": 0.17406625303686812, "value": ""}}}, {"outValue": 0.6445182946112169, "simIndex": 11.0, "features": {"0": {"effect": 0.18348789513982394, "value": ""}}}, {"outValue": 0.5424858207394274, "simIndex": 27.0, "features": {"0": {"effect": 0.08145542126803446, "value": ""}}}, {"outValue": 0.6612591457088345, "simIndex": 8.0, "features": {"0": {"effect": 0.20022874623744152, "value": ""}}}, {"outValue": 0.6577784541029462, "simIndex": 9.0, "features": {"0": {"effect": 0.19674805463155326, "value": ""}}}, {"outValue": 0.6078570945726084, "simIndex": 14.0, "features": {"0": {"effect": 0.146826695 ...
#     document.getElementById('iL2IFZNQ4Z9NP7Y6KQLDJ')
#   );
# </script>
# <div id='i3E05G08AYFFOKGMVB85B'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": 0.4693547893564856, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": 0.5, "simIndex": 17.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 18.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 19.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 16.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 20.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 15.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 21.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 14.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 22.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 13.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 23.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 12.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 24.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 11.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 25.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 10.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 26.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 9.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 27.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 8.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 28.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 7.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 29.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 6.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 30.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 5.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 31.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 4.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 32.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 3.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 33.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 2.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 34.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}, {"outValue": 0.5, "simIndex": 1.0, "features": {"0": {"effect": 0.030645210643514387, "value": ""}}}], "plot_cmap": "RdBu", "ordering_keys": [31, 7, 20, 23, 17, 29, 13, 15, 1, 19, 34, 2, 10, 24, 16, 25, 6, 3, 28, 18, 5, 32, 30, 21, 22, 33, 26, 12, 11, 27, 8, 9, 14, 4], "ordering_keys_time_format": null}),
#     document.getElementById('i3E05G08AYFFOKGMVB85B')
#   );
# </script>

# %%
order = plot.shap_force(shap_values_a_vs_b[idx_equal], 'A vs. B')
plot.shap_force(shap_values_a[idx_equal], 'A', ordering=order)
plot.shap_force(shap_values_b[idx_equal], 'B', ordering=order);
# Out:
# <div id='iRR6PLV5C4KV2V3JVHCL1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A vs. B"], "baseValue": 0.008324389885092653, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": 0.0013899699582674008, "simIndex": 345.0, "features": {"0": {"effect": -0.006934419926825253, "value": ""}}}, {"outValue": 0.0001572228195249603, "simIndex": 300.0, "features": {"0": {"effect": -0.008167167065567693, "value": ""}}}, {"outValue": -2.0043988691043069e-10, "simIndex": 178.0, "features": {"0": {"effect": -0.00832439008553254, "value": ""}}}, {"outValue": -7.758733655549577e-10, "simIndex": 170.0, "features": {"0": {"effect": -0.008324390660966019, "value": ""}}}, {"outValue": -2.1021549967414899e-07, "simIndex": 136.0, "features": {"0": {"effect": -0.008324600100592328, "value": ""}}}, {"outValue": -8.082539655562826e-06, "simIndex": 113.0, "features": {"0": {"effect": -0.008332472424748216, "value": ""}}}, {"outValue": -0.015309282923008427, "simIndex": 33.0, "features": {"0": {"effect": -0.02363367280810108, "value": ""}}}, {"outValue": -0.0034514493575710237, "simIndex": 48.0, "features": {"0": {"effect": -0.011775839242663677, "value": ""}}}, {"outValue": -0.04253502817132382, "simIndex": 14.0, "features": {"0": {"effect": -0.05085941805641647, "value": ""}}}, {"outValue": -5.735412145213559e-13, "simIndex": 202.0, "features": {"0": {"effect": -0.008324389885666195, "value": ""}}}, {"outValue": -0.003480845587216841, "simIndex": 47.0, "features": {"0": {"effect": -0.011805235472309494, "value": ""}}}, {"outValue": 0.09340773862425578, "simIndex": 485.0, "features": {"0": {"effect": 0.08508334873916312, "value": ""}}}, {"outValue": 2.171847757193035e-09, "simIndex": 227.0, "features": {"0": {"effect": -0.008324387713244896, "value": ""}}}, {"outValue": 0.02152553415485403, "simIndex": 439.0, "features": {"0": {"effect": 0.013201144269761378, "value": ""}}}, {"outValue": 0.004339562823335585, "simIndex": 385.0, "features": {"0": {"effect": -0.003984827061757068, "value": ""}}}, {"outValue": -6.947621039143925e-06, "simIndex": 115.0, "features": {"0": {"effect": -0.008331337506131797, "value": ""}}}, {"outValue": 0.00019258066165173116, "simIndex": 307.0, "features": {"0": {"effect": -0.008131809223440922, "value": ""}}}, {"outValue": -3.808344214317749e-05, "simIndex": 102.0, "features": {"0": {"effect": -0.008362473327235831, "value": ""}}}, {"outValue": -0.008978547961202787, "simIndex": 39.0, "features": {"0": {"effect": -0.01730293784629544, "value": ""}}}, {"outValue": 0.04423362249213378, "simIndex": 466.0, "features": {"0": {"effect": 0.035909232607041125, "value": ""}}}, {"outValue": -6.987839605732127e-05, "simIndex": 95.0, "features": {"0": {"effect": -0.008394268281149975, "value": ""}}}, {"outValue": 0.00018985684028083316, "simIndex": 305.0, "features": {"0": {"effect": -0.00813453304481182, "value": ""}}}, {"outValue": 0.13007251693751654, "simIndex": 491.0, "features": {"0": {"effect": 0.12174812705242388, "value": ""}}}, {"outValue": 0.012265958792395504, "simIndex": 417.0, "features": {"0": {"effect": 0.00394156890730285, "value": ""}}}, {"outValue": -0.011684496027442093, "simIndex": 36.0, "features": {"0": {"effect": -0.020008885912534746, "value": ""}}}, {"outValue": 2.0491873091998958e-05, "simIndex": 265.0, "features": {"0": {"effect": -0.008303898012000654, "value": ""}}}, {"outValue": -0.0937681532708422, "simIndex": 4.0, "features": {"0": {"effect": -0.10209254315593486, "value": ""}}}, {"outValue": -2.3373439365759197e-05, "simIndex": 106.0, "features": {"0": {"effect": -0.008347763324458413, "value": ""}}}, {"outValue": 0.06639129042346781, "simIndex": 478.0, "features": {"0": {"effect": 0.058066900538375155, "value": ""}}}, {"outValue": 4.466101913846998e-07, "simIndex": 238.0, "features": {"0": {"effect": -0.008323943274901269, "value": ""}}}, {"outValue": 0.015244962224756076, "simIndex": 423.0, "features": {"0": {"effect": 0.006920572339663422, "value": ""}}}, {"outValue": -0.0207831011 ...
# <div id='iCQDTVYC8OHPNLUWSKGHW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A"], "baseValue": 0.46103039947139296, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": 0.001082653198367367, "simIndex": 408.0, "features": {"0": {"effect": -0.4599477462730256, "value": ""}}}, {"outValue": 0.00017812731094152268, "simIndex": 439.0, "features": {"0": {"effect": -0.46085227216045144, "value": ""}}}, {"outValue": 0.9999999994421815, "simIndex": 51.0, "features": {"0": {"effect": 0.5389695999707886, "value": ""}}}, {"outValue": 0.9999999987147179, "simIndex": 57.0, "features": {"0": {"effect": 0.538969599243325, "value": ""}}}, {"outValue": 0.9999993786874726, "simIndex": 93.0, "features": {"0": {"effect": 0.5389689792160797, "value": ""}}}, {"outValue": 0.9999913811178092, "simIndex": 108.0, "features": {"0": {"effect": 0.5389609816464163, "value": ""}}}, {"outValue": 0.9678834097454396, "simIndex": 199.0, "features": {"0": {"effect": 0.5068530102740467, "value": ""}}}, {"outValue": 0.9967585984332885, "simIndex": 170.0, "features": {"0": {"effect": 0.5357281989618956, "value": ""}}}, {"outValue": 0.9233321061492074, "simIndex": 212.0, "features": {"0": {"effect": 0.4623017066778144, "value": ""}}}, {"outValue": 0.9999999999954621, "simIndex": 28.0, "features": {"0": {"effect": 0.5389696005240692, "value": ""}}}, {"outValue": 0.9967879946629343, "simIndex": 169.0, "features": {"0": {"effect": 0.5357575951915414, "value": ""}}}, {"outValue": 0.17553368274573905, "simIndex": 250.0, "features": {"0": {"effect": -0.2854967167256539, "value": ""}}}, {"outValue": 3.9227527726115596e-08, "simIndex": 498.0, "features": {"0": {"effect": -0.46103036024386523, "value": ""}}}, {"outValue": 0.02590033902271277, "simIndex": 308.0, "features": {"0": {"effect": -0.4351300604486802, "value": ""}}}, {"outValue": 0.013646647138755963, "simIndex": 329.0, "features": {"0": {"effect": -0.447383752332637, "value": ""}}}, {"outValue": 0.9999902461991927, "simIndex": 110.0, "features": {"0": {"effect": 0.5389598467277998, "value": ""}}}, {"outValue": 0.00014276946881475183, "simIndex": 444.0, "features": {"0": {"effect": -0.4608876300025782, "value": ""}}}, {"outValue": 0.9999146888661592, "simIndex": 125.0, "features": {"0": {"effect": 0.5388842893947663, "value": ""}}}, {"outValue": 0.9909923379991126, "simIndex": 179.0, "features": {"0": {"effect": 0.5299619385277197, "value": ""}}}, {"outValue": 0.22470779887786105, "simIndex": 243.0, "features": {"0": {"effect": -0.2363226005935319, "value": ""}}}, {"outValue": 0.9997345282655905, "simIndex": 137.0, "features": {"0": {"effect": 0.5387041287941976, "value": ""}}}, {"outValue": 0.0022827663163539347, "simIndex": 394.0, "features": {"0": {"effect": -0.458747633155039, "value": ""}}}, {"outValue": 0.1388689044324783, "simIndex": 253.0, "features": {"0": {"effect": -0.32216149503891467, "value": ""}}}, {"outValue": 0.0351599143851713, "simIndex": 292.0, "features": {"0": {"effect": -0.42587048508622166, "value": ""}}}, {"outValue": 0.9642586228498733, "simIndex": 201.0, "features": {"0": {"effect": 0.5032282233784804, "value": ""}}}, {"outValue": 2.490599561044693e-05, "simIndex": 471.0, "features": {"0": {"effect": -0.4610054934757825, "value": ""}}}, {"outValue": 0.8248267319008464, "simIndex": 219.0, "features": {"0": {"effect": 0.3637963324294535, "value": ""}}}, {"outValue": 0.9999779755706626, "simIndex": 115.0, "features": {"0": {"effect": 0.5389475760992697, "value": ""}}}, {"outValue": 0.20255013094652702, "simIndex": 247.0, "features": {"0": {"effect": -0.25848026852486594, "value": ""}}}, {"outValue": 3.849178362713701e-07, "simIndex": 493.0, "features": {"0": {"effect": -0.4610300145535567, "value": ""}}}, {"outValue": 0.032180910952810726, "simIndex": 296.0, "features": {"0": {"effect": -0.42884948851858223, "value": ""}}}, {"outValue": 0.9733572279913001, "simIndex": 195.0, "features": {"0": {"effect": 0.5123268285199072, "value": ""}}}, {"outValue": 0.7685080845273217, ...
# <div id='i5IUJUU5QC3O5K7TNZUJ6'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B"], "baseValue": 0.4693547893564856, "link": "identity", "featureNames": ["x1"], "explanations": [{"outValue": 0.002472623156634768, "simIndex": 102.0, "features": {"0": {"effect": -0.46688216619985085, "value": ""}}}, {"outValue": 0.000335350130466483, "simIndex": 61.0, "features": {"0": {"effect": -0.46901943922601913, "value": ""}}}, {"outValue": 0.9999999992417417, "simIndex": 452.0, "features": {"0": {"effect": 0.5306452098852561, "value": ""}}}, {"outValue": 0.9999999979388445, "simIndex": 444.0, "features": {"0": {"effect": 0.530645208582359, "value": ""}}}, {"outValue": 0.9999991684719729, "simIndex": 409.0, "features": {"0": {"effect": 0.5306443791154873, "value": ""}}}, {"outValue": 0.9999832985781536, "simIndex": 392.0, "features": {"0": {"effect": 0.530628509221668, "value": ""}}}, {"outValue": 0.9525741268224313, "simIndex": 305.0, "features": {"0": {"effect": 0.48321933746594564, "value": ""}}}, {"outValue": 0.9933071490757175, "simIndex": 329.0, "features": {"0": {"effect": 0.5239523597192319, "value": ""}}}, {"outValue": 0.8807970779778835, "simIndex": 290.0, "features": {"0": {"effect": 0.4114422886213979, "value": ""}}}, {"outValue": 0.9999999999948885, "simIndex": 475.0, "features": {"0": {"effect": 0.530645210638403, "value": ""}}}, {"outValue": 0.9933071490757175, "simIndex": 330.0, "features": {"0": {"effect": 0.5239523597192319, "value": ""}}}, {"outValue": 0.2689414213699948, "simIndex": 252.0, "features": {"0": {"effect": -0.2004133679864908, "value": ""}}}, {"outValue": 4.139937548330863e-08, "simIndex": 3.0, "features": {"0": {"effect": -0.46935474795711013, "value": ""}}}, {"outValue": 0.0474258731775668, "simIndex": 197.0, "features": {"0": {"effect": -0.4219289161789188, "value": ""}}}, {"outValue": 0.01798620996209155, "simIndex": 163.0, "features": {"0": {"effect": -0.45136857939439406, "value": ""}}}, {"outValue": 0.9999832985781536, "simIndex": 391.0, "features": {"0": {"effect": 0.530628509221668, "value": ""}}}, {"outValue": 0.000335350130466483, "simIndex": 62.0, "features": {"0": {"effect": -0.46901943922601913, "value": ""}}}, {"outValue": 0.999876605424016, "simIndex": 378.0, "features": {"0": {"effect": 0.5305218160675305, "value": ""}}}, {"outValue": 0.9820137900379098, "simIndex": 319.0, "features": {"0": {"effect": 0.5126590006814242, "value": ""}}}, {"outValue": 0.2689414213699948, "simIndex": 253.0, "features": {"0": {"effect": -0.2004133679864908, "value": ""}}}, {"outValue": 0.9996646498695332, "simIndex": 366.0, "features": {"0": {"effect": 0.5303098605130476, "value": ""}}}, {"outValue": 0.002472623156634768, "simIndex": 101.0, "features": {"0": {"effect": -0.46688216619985085, "value": ""}}}, {"outValue": 0.2689414213699948, "simIndex": 254.0, "features": {"0": {"effect": -0.2004133679864908, "value": ""}}}, {"outValue": 0.0474258731775668, "simIndex": 198.0, "features": {"0": {"effect": -0.4219289161789188, "value": ""}}}, {"outValue": 0.9525741268224313, "simIndex": 306.0, "features": {"0": {"effect": 0.48321933746594564, "value": ""}}}, {"outValue": 4.539786870244589e-05, "simIndex": 30.0, "features": {"0": {"effect": -0.46930939148778317, "value": ""}}}, {"outValue": 0.7310585786300042, "simIndex": 279.0, "features": {"0": {"effect": 0.2617037892735186, "value": ""}}}, {"outValue": 0.9999546021312968, "simIndex": 384.0, "features": {"0": {"effect": 0.5305998127748113, "value": ""}}}, {"outValue": 0.2689414213699948, "simIndex": 251.0, "features": {"0": {"effect": -0.2004133679864908, "value": ""}}}, {"outValue": 8.315280276560699e-07, "simIndex": 10.0, "features": {"0": {"effect": -0.46935395782845796, "value": ""}}}, {"outValue": 0.0474258731775668, "simIndex": 199.0, "features": {"0": {"effect": -0.4219289161789188, "value": ""}}}, {"outValue": 0.9525741268224313, "simIndex": 307.0, "features": {"0": {"effect": 0.48321933746594564, "value": ""}}}, {"outValue": 0.7310585786300042, "simIndex":  ...

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %%
plot.shap_heatmap(shap_values_a[idx_equal], 'A', feature_order)
plot.shap_heatmap(shap_values_b[idx_equal], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[idx_equal], 'A vs. B', feature_order)

# %%
plot.shap_heatmap(shap_values_a[idx_diff], 'A', feature_order)
plot.shap_heatmap(shap_values_b[idx_diff], 'B', feature_order)
plot.shap_heatmap(shap_values_a_vs_b[idx_diff], 'A vs. B', feature_order)
