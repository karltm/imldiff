# %%
from scipy.special import logit
from shap.maskers import Independent
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from plots import plot_shap_value_distribution, plot_shap_partial_dependence, plot_shap_values_stacked, \
    plot_shap_values_hierarchically_clustered, plot_decision_boundary
import shap
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
shap.initjs()
np.seterr(divide='ignore');
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# # Decision Tree vs. Naive Bayes
# Based on ["Classifier comparison"](https://scikit-learn.org/0.24/auto_examples/classification/plot_classifier_comparison.html) example of scikit-learn docs.

# %% [markdown]
# ## Create Models

# %%
feature_names = ['x1', 'x2']
X, y = make_circles(n_samples=500, noise=0.2, factor=0.5, random_state=1)
X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.8, random_state=42)

# %%
m1 = DecisionTreeClassifier(max_depth=5)
m1.fit(X_train, y_train)
logit_from_log_proba = lambda Y: Y[:,1] - Y[:,0]
f1 = lambda X: logit_from_log_proba(m1.predict_log_proba(X))
c1 = lambda X: m1.predict_proba(X)[:,1]

# %%
m2 = GaussianNB()
m2.fit(X_train, y_train)
f2 = lambda X: logit_from_log_proba(m2.predict_log_proba(X))
c2 = lambda X: m2.predict_proba(X)[:,1]

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_decision_boundary(f1, X, 'Classifier 1 in margin space', feature_names, (-8, 8), fig, axs[0,0], logit(y))
plot_decision_boundary(f2, X, 'Classifier 2 in margin space', feature_names, (-8, 8), fig, axs[1,0], logit(y))
plot_decision_boundary(c1, X, 'Classifier 1 in probability space', feature_names, (0, 1), fig, axs[0,1], y)
plot_decision_boundary(c2, X, 'Classifier 2 in probability space', feature_names, (0, 1), fig, axs[1,1], y)
plt.show()
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %%
complement = lambda p: 1 - p
c1_positive_and_c2_negative = lambda p1, p2: p1 * complement(p2)
c1_negative_and_c2_positive = lambda p1, p2: complement(p1) * p2
c1_and_c2_different = lambda p1, p2: c1_positive_and_c2_negative(p1, p2) + c1_negative_and_c2_positive(p1, p2)
odds = lambda p: p / complement(p)
log_odds_ratio_from_proba = lambda p1, p2: np.log(odds(p1) / odds(p2))

c_c1_positive_and_c2_negative = lambda X: c1_positive_and_c2_negative(c1(X), c2(X))
c_c1_negative_and_c2_positive = lambda X: c1_negative_and_c2_positive(c1(X), c2(X))
c_c1_and_c2_different = lambda X: c1_and_c2_different(c1(X), c2(X))
f_log_odds_ratio_from_proba = lambda X: log_odds_ratio_from_proba(c1(X), c2(X))

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_decision_boundary(c_c1_positive_and_c2_negative, X, 'Probability: C1 predicts positive and C2 negative', feature_names, (0, 1), fig, axs[0,0], y)
plot_decision_boundary(c_c1_negative_and_c2_positive, X, 'Probability: C1 predicts negative and C2 positive', feature_names, (0, 1), fig, axs[0,1], y)
plot_decision_boundary(c_c1_and_c2_different, X, 'Probability: C1 and C2 predict different labels', feature_names, (0, 1), fig, axs[1,0], y)
plot_decision_boundary(f_log_odds_ratio_from_proba, X, 'Log odds ratio of C1 and C2, calculated from probabilities', feature_names, (-8, 8), fig, axs[1,1], logit(y))
plt.show()
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %%
log_odds_ratio = lambda y1, y2: y1 - y2
f_log_odds_ratio = lambda X: log_odds_ratio(f1(X), f2(X))
plot_decision_boundary(f_log_odds_ratio, X, 'Log odds ratio of C1 and C2', feature_names, (-8, 8), z=logit(y))
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %% [markdown]
# ## Generate Explanations

# %%
def make_shap_values(model, background_data, feature_names):
    masker = Independent(background_data)
    explainer = shap.Explainer(model, masker, feature_names=feature_names)
    shap_values = explainer(X)
    return shap_values

shap_values_f1 = make_shap_values(f1, X, feature_names)
shap_values_f2 = make_shap_values(f2, X, feature_names)
shap_values_c1 = make_shap_values(c1, X, feature_names)
shap_values_c2 = make_shap_values(c2, X, feature_names)

# %%
shap_values_c_c1_positive_and_c2_negative = make_shap_values(c_c1_positive_and_c2_negative, X, feature_names)
shap_values_c_c1_negative_and_c2_positive = make_shap_values(c_c1_negative_and_c2_positive, X, feature_names)
shap_values_c_c1_and_c2_different = make_shap_values(c_c1_and_c2_different, X, feature_names)
shap_values_f_log_odds_ratio = make_shap_values(f_log_odds_ratio, X, feature_names)

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### SHAP Value Distribution

# %%
plot_shap_value_distribution(shap_values_f1, 'Classifier 1 in margin space')
plot_shap_value_distribution(shap_values_f2, 'Classifier 2 in margin space')

# %%
plot_shap_value_distribution(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_value_distribution(shap_values_c2, 'Classifier 2 in probability space')

# %%
plot_shap_value_distribution(shap_values_c_c1_positive_and_c2_negative, 'Probability: C1 predicts positive and C2 negative')
plot_shap_value_distribution(shap_values_c_c1_negative_and_c2_positive, 'Probability: C1 predicts negative and C2 positive')
plot_shap_value_distribution(shap_values_c_c1_and_c2_different, 'Probability: C1 and C2 predict different labels')
plot_shap_value_distribution(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2')

# %% [markdown]
# ### Features' Partial Dependence Plots

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_f1, feature_names[0], 'Classifier 1 in margin space', (-8, 8), axs[0])
plot_shap_partial_dependence(shap_values_f2, feature_names[0], 'Classifier 2 in margin space', (-8, 8), axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_c1, feature_names[0], 'Classifier 1 in probability space', (-1, 1), axs[0])
plot_shap_partial_dependence(shap_values_c2, feature_names[0], 'Classifier 2 in probability space', (-1, 1), axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_c_c1_positive_and_c2_negative, feature_names[0], 'Probability: C1 predicts positive and C2 negative', (-1, 1), axs[0])
plot_shap_partial_dependence(shap_values_c_c1_negative_and_c2_positive, feature_names[0], 'Probability: C1 predicts negative and C2 positive', (-1, 1), axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_c_c1_and_c2_different, feature_names[0], 'Probability: C1 and C2 predict different labels', (-1, 1), axs[0])
plot_shap_partial_dependence(shap_values_f_log_odds_ratio, feature_names[0], 'Log odds ratio of C1 and C2', (-6, 6), axs[1])
plt.show()

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %%
# ordering = plot_shap_values_stacked(shap_values_f1, 'Classifier 1 in margin space')
plot_shap_values_stacked(shap_values_f2, 'Classifier 2 in margin space');
# Out:
# <div id='iLD2SCMBQJ431E2EDR931'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 2 in margin space"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.4994131161803651, "simIndex": 105.0, "features": {"0": {"effect": 0.680162482272858, "value": ""}, "1": {"effect": -0.18074936609249292, "value": ""}}}, {"outValue": 1.316597417840792, "simIndex": 259.0, "features": {"0": {"effect": 0.7353519583439924, "value": ""}, "1": {"effect": 0.5812454594967996, "value": ""}}}, {"outValue": -0.6557656802586556, "simIndex": 45.0, "features": {"0": {"effect": 0.47397168666945366, "value": ""}, "1": {"effect": -1.1297373669281092, "value": ""}}}, {"outValue": -0.17761414101833528, "simIndex": 89.0, "features": {"0": {"effect": 0.3430802710510271, "value": ""}, "1": {"effect": -0.5206944120693624, "value": ""}}}, {"outValue": 0.5625608910833864, "simIndex": 139.0, "features": {"0": {"effect": 0.27805602874220225, "value": ""}, "1": {"effect": 0.2845048623411841, "value": ""}}}, {"outValue": 1.122718671304956, "simIndex": 227.0, "features": {"0": {"effect": 0.45140267081285923, "value": ""}, "1": {"effect": 0.6713160004920968, "value": ""}}}, {"outValue": 0.8145643409485767, "simIndex": 118.0, "features": {"0": {"effect": 0.6915067866989663, "value": ""}, "1": {"effect": 0.12305755424961042, "value": ""}}}, {"outValue": -0.6239304464739548, "simIndex": 335.0, "features": {"0": {"effect": -0.3270869859816359, "value": ""}, "1": {"effect": -0.2968434604923189, "value": ""}}}, {"outValue": -1.311846998208031, "simIndex": 454.0, "features": {"0": {"effect": -1.6688259363779179, "value": ""}, "1": {"effect": 0.356978938169887, "value": ""}}}, {"outValue": -0.6588232459611478, "simIndex": 377.0, "features": {"0": {"effect": -0.1782539115000138, "value": ""}, "1": {"effect": -0.48056933446113403, "value": ""}}}, {"outValue": 0.712556920059746, "simIndex": 110.0, "features": {"0": {"effect": 0.7567319638844087, "value": ""}, "1": {"effect": -0.04417504382466263, "value": ""}}}, {"outValue": -0.4319939553632126, "simIndex": 60.0, "features": {"0": {"effect": 0.4441557449478012, "value": ""}, "1": {"effect": -0.8761497003110138, "value": ""}}}, {"outValue": 0.36981845426094295, "simIndex": 325.0, "features": {"0": {"effect": -0.047957946441208765, "value": ""}, "1": {"effect": 0.4177764007021517, "value": ""}}}, {"outValue": -1.1916244837133902, "simIndex": 21.0, "features": {"0": {"effect": 0.6282466580874609, "value": ""}, "1": {"effect": -1.819871141800851, "value": ""}}}, {"outValue": 0.6096022116733062, "simIndex": 107.0, "features": {"0": {"effect": 0.7031210103056976, "value": ""}, "1": {"effect": -0.0935187986323914, "value": ""}}}, {"outValue": -3.9550453541390347, "simIndex": 1.0, "features": {"0": {"effect": 0.33636422870511784, "value": ""}, "1": {"effect": -4.291409582844152, "value": ""}}}, {"outValue": 1.3207511576245257, "simIndex": 260.0, "features": {"0": {"effect": 0.7301398647803053, "value": ""}, "1": {"effect": 0.5906112928442203, "value": ""}}}, {"outValue": 1.4019619722621817, "simIndex": 268.0, "features": {"0": {"effect": 0.7058136386543493, "value": ""}, "1": {"effect": 0.6961483336078323, "value": ""}}}, {"outValue": -2.280913601592618, "simIndex": 485.0, "features": {"0": {"effect": -2.3885269087842076, "value": ""}, "1": {"effect": 0.10761330719158968, "value": ""}}}, {"outValue": -0.4836369873848483, "simIndex": 449.0, "features": {"0": {"effect": -0.79749951161031, "value": ""}, "1": {"effect": 0.3138625242254617, "value": ""}}}, {"outValue": 1.0480657237788589, "simIndex": 168.0, "features": {"0": {"effect": 0.6802842861774003, "value": ""}, "1": {"effect": 0.3677814376014586, "value": ""}}}, {"outValue": 0.8970227910258731, "simIndex": 159.0, "features": {"0": {"effect": 0.6180588943563584, "value": ""}, "1": {"effect": 0.2789638966695147, "value": ""}}}, {"outValue": 1.4059480335292918, "simIndex": 270.0, "features": {"0": {"effect": 0.731254881812839, "value": ...

# %%
ordering = plot_shap_values_stacked(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_values_stacked(shap_values_c2, 'Classifier 2 in probability space', ordering=ordering);
# Out:
# <div id='iVUQG8HRSI2IOL8C35U4B'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 1 in probability space"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.4730894308943082, "simIndex": 184.0, "features": {"0": {"effect": 0.2997696476964765, "value": ""}, "1": {"effect": 0.1733197831978317, "value": ""}}}, {"outValue": 0.4730894308943082, "simIndex": 183.0, "features": {"0": {"effect": 0.2997696476964765, "value": ""}, "1": {"effect": 0.1733197831978317, "value": ""}}}, {"outValue": -0.4537398373983742, "simIndex": 3.0, "features": {"0": {"effect": 0.19422764227642253, "value": ""}, "1": {"effect": -0.6479674796747967, "value": ""}}}, {"outValue": 0.4730894308943082, "simIndex": 182.0, "features": {"0": {"effect": 0.2997696476964765, "value": ""}, "1": {"effect": 0.1733197831978317, "value": ""}}}, {"outValue": -0.00929539295393067, "simIndex": 335.0, "features": {"0": {"effect": -0.07696476964769772, "value": ""}, "1": {"effect": 0.06766937669376705, "value": ""}}}, {"outValue": -0.00929539295393067, "simIndex": 334.0, "features": {"0": {"effect": -0.07696476964769772, "value": ""}, "1": {"effect": 0.06766937669376705, "value": ""}}}, {"outValue": 0.4730894308943082, "simIndex": 185.0, "features": {"0": {"effect": 0.2997696476964765, "value": ""}, "1": {"effect": 0.1733197831978317, "value": ""}}}, {"outValue": -0.4537398373983742, "simIndex": 431.0, "features": {"0": {"effect": -0.5197425474254747, "value": ""}, "1": {"effect": 0.06600271002710047, "value": ""}}}, {"outValue": -0.4537398373983742, "simIndex": 432.0, "features": {"0": {"effect": -0.5197425474254747, "value": ""}, "1": {"effect": 0.06600271002710047, "value": ""}}}, {"outValue": 0.4730894308943082, "simIndex": 181.0, "features": {"0": {"effect": 0.2997696476964765, "value": ""}, "1": {"effect": 0.1733197831978317, "value": ""}}}, {"outValue": 0.4730894308943082, "simIndex": 186.0, "features": {"0": {"effect": 0.2997696476964765, "value": ""}, "1": {"effect": 0.1733197831978317, "value": ""}}}, {"outValue": -0.4537398373983742, "simIndex": 55.0, "features": {"0": {"effect": 0.049227642276422845, "value": ""}, "1": {"effect": -0.502967479674797, "value": ""}}}, {"outValue": 0.4730894308943082, "simIndex": 180.0, "features": {"0": {"effect": 0.2997696476964765, "value": ""}, "1": {"effect": 0.1733197831978317, "value": ""}}}, {"outValue": -0.45373983739837415, "simIndex": 17.0, "features": {"0": {"effect": 0.13922764227642287, "value": ""}, "1": {"effect": -0.592967479674797, "value": ""}}}, {"outValue": 0.4730894308943082, "simIndex": 187.0, "features": {"0": {"effect": 0.2997696476964765, "value": ""}, "1": {"effect": 0.1733197831978317, "value": ""}}}, {"outValue": -0.4537398373983742, "simIndex": 56.0, "features": {"0": {"effect": 0.049227642276422845, "value": ""}, "1": {"effect": -0.502967479674797, "value": ""}}}, {"outValue": 0.4730894308943082, "simIndex": 179.0, "features": {"0": {"effect": 0.2997696476964765, "value": ""}, "1": {"effect": 0.1733197831978317, "value": ""}}}, {"outValue": 0.4730894308943082, "simIndex": 188.0, "features": {"0": {"effect": 0.2997696476964765, "value": ""}, "1": {"effect": 0.1733197831978317, "value": ""}}}, {"outValue": -0.4537398373983742, "simIndex": 393.0, "features": {"0": {"effect": -0.46474254742547466, "value": ""}, "1": {"effect": 0.01100271002710046, "value": ""}}}, {"outValue": -0.4537398373983742, "simIndex": 480.0, "features": {"0": {"effect": -0.5297425474254747, "value": ""}, "1": {"effect": 0.07600271002710046, "value": ""}}}, {"outValue": 0.4730894308943082, "simIndex": 178.0, "features": {"0": {"effect": 0.2997696476964765, "value": ""}, "1": {"effect": 0.1733197831978317, "value": ""}}}, {"outValue": 0.4730894308943082, "simIndex": 189.0, "features": {"0": {"effect": 0.2997696476964765, "value": ""}, "1": {"effect": 0.1733197831978317, "value": ""}}}, {"outValue": 0.4730894308943082, "simIndex": 177.0, "features": {"0": {"effect": 0.299769647696 ...
# <div id='iWUVTMNHWG23E2VRWWQXK'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 2 in probability space"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.08768797225164654, "simIndex": 362.0, "features": {"0": {"effect": 0.1354975998110277, "value": ""}, "1": {"effect": -0.047809627559381174, "value": ""}}}, {"outValue": 0.282192236978163, "simIndex": 282.0, "features": {"0": {"effect": 0.15649983227164743, "value": ""}, "1": {"effect": 0.12569240470651555, "value": ""}}}, {"outValue": -0.17113236031385384, "simIndex": 462.0, "features": {"0": {"effect": 0.06904642842395145, "value": ""}, "1": {"effect": -0.2401787887378053, "value": ""}}}, {"outValue": -0.07473585805330235, "simIndex": 411.0, "features": {"0": {"effect": 0.051080032258151414, "value": ""}, "1": {"effect": -0.12581589031145377, "value": ""}}}, {"outValue": 0.10347336095642623, "simIndex": 191.0, "features": {"0": {"effect": 0.04889306861852197, "value": ""}, "1": {"effect": 0.05458029233790426, "value": ""}}}, {"outValue": 0.23917908331635546, "simIndex": 250.0, "features": {"0": {"effect": 0.09412623140328497, "value": ""}, "1": {"effect": 0.1450528519130705, "value": ""}}}, {"outValue": 0.16596415567302608, "simIndex": 348.0, "features": {"0": {"effect": 0.14346015961644926, "value": ""}, "1": {"effect": 0.022503996056576825, "value": ""}}}, {"outValue": -0.1653567563826474, "simIndex": 400.0, "features": {"0": {"effect": -0.08864005914230527, "value": ""}, "1": {"effect": -0.07671669724034212, "value": ""}}}, {"outValue": -0.26873681463499083, "simIndex": 80.0, "features": {"0": {"effect": -0.3136010938979065, "value": ""}, "1": {"effect": 0.04486427926291569, "value": ""}}}, {"outValue": -0.1716819954636477, "simIndex": 393.0, "features": {"0": {"effect": -0.05817241637103826, "value": ""}, "1": {"effect": -0.11350957909260946, "value": ""}}}, {"outValue": 0.14083254206939094, "simIndex": 353.0, "features": {"0": {"effect": 0.15597028845696687, "value": ""}, "1": {"effect": -0.015137746387575923, "value": ""}}}, {"outValue": -0.12852762615546087, "simIndex": 424.0, "features": {"0": {"effect": 0.0672317894945896, "value": ""}, "1": {"effect": -0.19575941565005048, "value": ""}}}, {"outValue": 0.05536392392523509, "simIndex": 131.0, "features": {"0": {"effect": -0.02551093437893992, "value": ""}, "1": {"effect": 0.08087485830417501, "value": ""}}}, {"outValue": -0.25383518520289766, "simIndex": 481.0, "features": {"0": {"effect": 0.08587488497742124, "value": ""}, "1": {"effect": -0.3397100701803189, "value": ""}}}, {"outValue": 0.11522150707886897, "simIndex": 357.0, "features": {"0": {"effect": 0.14259796998578111, "value": ""}, "1": {"effect": -0.027376462906912147, "value": ""}}}, {"outValue": -0.39515674714472954, "simIndex": 491.0, "features": {"0": {"effect": 0.03173469771237847, "value": ""}, "1": {"effect": -0.426891444857108, "value": ""}}}, {"outValue": 0.28308226329664526, "simIndex": 283.0, "features": {"0": {"effect": 0.15537254468265915, "value": ""}, "1": {"effect": 0.1277097186139861, "value": ""}}}, {"outValue": 0.30019697937120543, "simIndex": 291.0, "features": {"0": {"effect": 0.15000911247553111, "value": ""}, "1": {"effect": 0.15018786689567432, "value": ""}}}, {"outValue": -0.34927727741818493, "simIndex": 25.0, "features": {"0": {"effect": -0.3549253572119121, "value": ""}, "1": {"effect": 0.005648079793727161, "value": ""}}}, {"outValue": -0.13877012070662792, "simIndex": 58.0, "features": {"0": {"effect": -0.18466558461523794, "value": ""}, "1": {"effect": 0.04589546390861002, "value": ""}}}, {"outValue": 0.2219180717214087, "simIndex": 308.0, "features": {"0": {"effect": 0.14354114771633208, "value": ""}, "1": {"effect": 0.07837692400507662, "value": ""}}}, {"outValue": 0.18601618244745427, "simIndex": 325.0, "features": {"0": {"effect": 0.1284732827038172, "value": ""}, "1": {"effect": 0.05754289974363708, "value": ""}}}, {"outValue": 0.3010227066782054, "simIndex": 2 ...

# %%
plot_shap_values_stacked(shap_values_c_c1_positive_and_c2_negative, 'Probability: C1 predicts positive and C2 negative');
# Out:
# <div id='i4F4FYJA3L9R1SGOBBB78'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Probability: C1 predicts positive and C2 negative"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.2772786312203984, "simIndex": 204.0, "features": {"0": {"effect": 0.11044282055143426, "value": ""}, "1": {"effect": 0.16683581066896414, "value": ""}}}, {"outValue": 0.09700638586411445, "simIndex": 140.0, "features": {"0": {"effect": 0.07123440813764315, "value": ""}, "1": {"effect": 0.0257719777264713, "value": ""}}}, {"outValue": -0.19163082467825537, "simIndex": 496.0, "features": {"0": {"effect": 0.10020522657957269, "value": ""}, "1": {"effect": -0.2918360512578281, "value": ""}}}, {"outValue": 0.4278177910152289, "simIndex": 215.0, "features": {"0": {"effect": 0.19041664525781926, "value": ""}, "1": {"effect": 0.23740114575740962, "value": ""}}}, {"outValue": 0.026210612994997662, "simIndex": 236.0, "features": {"0": {"effect": 0.005943108670618091, "value": ""}, "1": {"effect": 0.02026750432437957, "value": ""}}}, {"outValue": -0.03410304138719329, "simIndex": 256.0, "features": {"0": {"effect": -0.0060282106156409054, "value": ""}, "1": {"effect": -0.028074830771552386, "value": ""}}}, {"outValue": 0.20472997341521768, "simIndex": 91.0, "features": {"0": {"effect": 0.09572683905154891, "value": ""}, "1": {"effect": 0.10900313436366876, "value": ""}}}, {"outValue": -0.19163082467825543, "simIndex": 409.0, "features": {"0": {"effect": -0.2655350059042531, "value": ""}, "1": {"effect": 0.07390418122599766, "value": ""}}}, {"outValue": -0.19163082467825543, "simIndex": 362.0, "features": {"0": {"effect": -0.21460751985813264, "value": ""}, "1": {"effect": 0.02297669517987723, "value": ""}}}, {"outValue": 0.5176703086150611, "simIndex": 40.0, "features": {"0": {"effect": 0.2842474916256929, "value": ""}, "1": {"effect": 0.2334228169893683, "value": ""}}}, {"outValue": 0.22802268846248905, "simIndex": 98.0, "features": {"0": {"effect": 0.08956533251763649, "value": ""}, "1": {"effect": 0.13845735594485256, "value": ""}}}, {"outValue": -0.19163082467825537, "simIndex": 452.0, "features": {"0": {"effect": -0.010213699686776823, "value": ""}, "1": {"effect": -0.18141712499147855, "value": ""}}}, {"outValue": 0.30723750527902505, "simIndex": 26.0, "features": {"0": {"effect": 0.23325931461076196, "value": ""}, "1": {"effect": 0.07397819066826306, "value": ""}}}, {"outValue": -0.19163082467825543, "simIndex": 478.0, "features": {"0": {"effect": 0.046971612273113375, "value": ""}, "1": {"effect": -0.2386024369513688, "value": ""}}}, {"outValue": 0.2517597452829711, "simIndex": 203.0, "features": {"0": {"effect": 0.10220758240478062, "value": ""}, "1": {"effect": 0.1495521628781905, "value": ""}}}, {"outValue": -0.1916308246782554, "simIndex": 447.0, "features": {"0": {"effect": -0.016950068820573733, "value": ""}, "1": {"effect": -0.17468075585768167, "value": ""}}}, {"outValue": 0.09618148342259417, "simIndex": 141.0, "features": {"0": {"effect": 0.07189735596253274, "value": ""}, "1": {"effect": 0.024284127460061422, "value": ""}}}, {"outValue": 0.08031906364617283, "simIndex": 152.0, "features": {"0": {"effect": 0.07313520966884163, "value": ""}, "1": {"effect": 0.007183853977331206, "value": ""}}}, {"outValue": -0.19163082467825543, "simIndex": 315.0, "features": {"0": {"effect": -0.17777401171500978, "value": ""}, "1": {"effect": -0.013856812963245632, "value": ""}}}, {"outValue": -0.19163082467825543, "simIndex": 378.0, "features": {"0": {"effect": -0.22590042313853131, "value": ""}, "1": {"effect": 0.0342695984602759, "value": ""}}}, {"outValue": 0.15287024634598395, "simIndex": 121.0, "features": {"0": {"effect": 0.08866298813371834, "value": ""}, "1": {"effect": 0.06420725821226561, "value": ""}}}, {"outValue": 0.18614516811208923, "simIndex": 109.0, "features": {"0": {"effect": 0.10409396620578212, "value": ""}, "1": {"effect": 0.0820512019063071, "value": ""}}}, {"outValue": 0.0795537554104 ...

# %%
plot_shap_values_stacked(shap_values_c_c1_negative_and_c2_positive, 'Probability: C1 predicts negative and C2 positive');
# Out:
# <div id='iKCU6P5ENP7R40CYN512Q'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Probability: C1 predicts negative and C2 positive"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.10812282742226365, "simIndex": 118.0, "features": {"0": {"effect": -0.05382922733401471, "value": ""}, "1": {"effect": -0.05429360008824893, "value": ""}}}, {"outValue": -0.09389080805203077, "simIndex": 224.0, "features": {"0": {"effect": -0.07203540728718588, "value": ""}, "1": {"effect": -0.021855400764844893, "value": ""}}}, {"outValue": 0.09097665240626529, "simIndex": 34.0, "features": {"0": {"effect": -0.024975987272898355, "value": ""}, "1": {"effect": 0.11595263967916364, "value": ""}}}, {"outValue": -0.12000749793238191, "simIndex": 110.0, "features": {"0": {"effect": -0.05827297018050599, "value": ""}, "1": {"effect": -0.06173452775187593, "value": ""}}}, {"outValue": 0.1389793669053545, "simIndex": 426.0, "features": {"0": {"effect": 0.1318009469368371, "value": ""}, "1": {"effect": 0.007178419968517397, "value": ""}}}, {"outValue": 0.2143714348830934, "simIndex": 461.0, "features": {"0": {"effect": 0.16506279043534117, "value": ""}, "1": {"effect": 0.04930864444775224, "value": ""}}}, {"outValue": -0.10239530180606522, "simIndex": 186.0, "features": {"0": {"effect": -0.06058264902847872, "value": ""}, "1": {"effect": -0.0418126527775865, "value": ""}}}, {"outValue": 0.09675225633747178, "simIndex": 472.0, "features": {"0": {"effect": 0.16556748237891622, "value": ""}, "1": {"effect": -0.06881522604144444, "value": ""}}}, {"outValue": -0.006627801914871639, "simIndex": 409.0, "features": {"0": {"effect": -0.008466066330564612, "value": ""}, "1": {"effect": 0.0018382644156929723, "value": ""}}}, {"outValue": -0.12710111774289495, "simIndex": 105.0, "features": {"0": {"effect": -0.07369457244182218, "value": ""}, "1": {"effect": -0.053406545301072764, "value": ""}}}, {"outValue": -0.10423420036242868, "simIndex": 122.0, "features": {"0": {"effect": -0.05423402672187348, "value": ""}, "1": {"effect": -0.0500001736405552, "value": ""}}}, {"outValue": 0.1335813865646583, "simIndex": 31.0, "features": {"0": {"effect": 0.00779044753139032, "value": ""}, "1": {"effect": 0.12579093903326796, "value": ""}}}, {"outValue": -0.11048800169004991, "simIndex": 275.0, "features": {"0": {"effect": -0.09202126746465551, "value": ""}, "1": {"effect": -0.018466734225394393, "value": ""}}}, {"outValue": 0.00827382751722152, "simIndex": 80.0, "features": {"0": {"effect": -0.00638114502588772, "value": ""}, "1": {"effect": 0.01465497254310924, "value": ""}}}, {"outValue": -0.10610817853246679, "simIndex": 124.0, "features": {"0": {"effect": -0.054964095305914305, "value": ""}, "1": {"effect": -0.05114408322655249, "value": ""}}}, {"outValue": -0.13304773442461035, "simIndex": 347.0, "features": {"0": {"effect": -0.03444301338461768, "value": ""}, "1": {"effect": -0.09860472103999267, "value": ""}}}, {"outValue": -0.09382568417506854, "simIndex": 220.0, "features": {"0": {"effect": -0.07249974705128476, "value": ""}, "1": {"effect": -0.021325937123783778, "value": ""}}}, {"outValue": -0.09257338787693015, "simIndex": 254.0, "features": {"0": {"effect": -0.07662532555210382, "value": ""}, "1": {"effect": -0.015948062324826328, "value": ""}}}, {"outValue": -0.08716826469806578, "simIndex": 227.0, "features": {"0": {"effect": -0.06795682150144725, "value": ""}, "1": {"effect": -0.019211443196618532, "value": ""}}}, {"outValue": 0.12333889201349119, "simIndex": 424.0, "features": {"0": {"effect": 0.11917653967170533, "value": ""}, "1": {"effect": 0.004162352341785858, "value": ""}}}, {"outValue": -0.0983011128269152, "simIndex": 161.0, "features": {"0": {"effect": -0.0675655118464259, "value": ""}, "1": {"effect": -0.0307356009804893, "value": ""}}}, {"outValue": -0.10092808033476576, "simIndex": 155.0, "features": {"0": {"effect": -0.06720239878687767, "value": ""}, "1": {"effect": -0.03372568154788809, "value": " ...

# %%
plot_shap_values_stacked(shap_values_c_c1_and_c2_different, 'Probability: C1 and C2 predict different labels');
# Out:
# <div id='iOBUYU2FORKRCX5A3BN1V'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Probability: C1 and C2 predict different labels"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.16915580379813372, "simIndex": 200.0, "features": {"0": {"effect": 0.05661359321741896, "value": ""}, "1": {"effect": 0.11254221058071476, "value": ""}}}, {"outValue": 0.003115577812084047, "simIndex": 403.0, "features": {"0": {"effect": -0.0008009991495425417, "value": ""}, "1": {"effect": 0.003916576961626589, "value": ""}}}, {"outValue": -0.1006541722719903, "simIndex": 485.0, "features": {"0": {"effect": 0.07522923930667424, "value": ""}, "1": {"effect": -0.17588341157866455, "value": ""}}}, {"outValue": 0.30781029308284497, "simIndex": 19.0, "features": {"0": {"effect": 0.1321436750773123, "value": ""}, "1": {"effect": 0.17566661800553265, "value": ""}}}, {"outValue": 0.1651899799003526, "simIndex": 86.0, "features": {"0": {"effect": 0.13774405560745542, "value": ""}, "1": {"effect": 0.02744592429289719, "value": ""}}}, {"outValue": 0.1802683934958993, "simIndex": 53.0, "features": {"0": {"effect": 0.15903457981969993, "value": ""}, "1": {"effect": 0.021233813676199365, "value": ""}}}, {"outValue": 0.10233467160915247, "simIndex": 171.0, "features": {"0": {"effect": 0.035144190023070176, "value": ""}, "1": {"effect": 0.06719048158608229, "value": ""}}}, {"outValue": -0.09487856834078384, "simIndex": 291.0, "features": {"0": {"effect": -0.09996752352533719, "value": ""}, "1": {"effect": 0.005088955184553351, "value": ""}}}, {"outValue": -0.19825862659312724, "simIndex": 265.0, "features": {"0": {"effect": -0.22307358618869738, "value": ""}, "1": {"effect": 0.024814959595570146, "value": ""}}}, {"outValue": 0.3905691908721665, "simIndex": 17.0, "features": {"0": {"effect": 0.21055291918387067, "value": ""}, "1": {"effect": 0.18001627168829584, "value": ""}}}, {"outValue": 0.12378848810005946, "simIndex": 181.0, "features": {"0": {"effect": 0.035331305795762546, "value": ""}, "1": {"effect": 0.08845718230429692, "value": ""}}}, {"outValue": -0.05804943811359731, "simIndex": 442.0, "features": {"0": {"effect": -0.002423252155386607, "value": ""}, "1": {"effect": -0.0556261859582107, "value": ""}}}, {"outValue": 0.19674950358897375, "simIndex": 79.0, "features": {"0": {"effect": 0.14123804714610597, "value": ""}, "1": {"effect": 0.055511456442867785, "value": ""}}}, {"outValue": -0.18335699716103407, "simIndex": 476.0, "features": {"0": {"effect": 0.040590467247225676, "value": ""}, "1": {"effect": -0.22394746440825974, "value": ""}}}, {"outValue": 0.14565156675050514, "simIndex": 188.0, "features": {"0": {"effect": 0.04724348709886658, "value": ""}, "1": {"effect": 0.09840807965163856, "value": ""}}}, {"outValue": -0.32467855910286597, "simIndex": 472.0, "features": {"0": {"effect": -0.051393082205191565, "value": ""}, "1": {"effect": -0.2732854768976744, "value": ""}}}, {"outValue": 0.0023557992475255474, "simIndex": 402.0, "features": {"0": {"effect": -0.0006023910887519579, "value": ""}, "1": {"effect": 0.0029581903362775053, "value": ""}}}, {"outValue": -0.012254324230758118, "simIndex": 428.0, "features": {"0": {"effect": -0.00349011588326259, "value": ""}, "1": {"effect": -0.008764208347495528, "value": ""}}}, {"outValue": -0.2787990893763214, "simIndex": 218.0, "features": {"0": {"effect": -0.24573083321645733, "value": ""}, "1": {"effect": -0.03306825615986407, "value": ""}}}, {"outValue": -0.06829193266476441, "simIndex": 286.0, "features": {"0": {"effect": -0.1067238834668261, "value": ""}, "1": {"effect": 0.03843195080206169, "value": ""}}}, {"outValue": 0.05456913351906789, "simIndex": 372.0, "features": {"0": {"effect": 0.021097476287292027, "value": ""}, "1": {"effect": 0.033471657231775864, "value": ""}}}, {"outValue": 0.08521708777732362, "simIndex": 151.0, "features": {"0": {"effect": 0.03689156741890448, "value": ""}, "1": {"effect": 0.04832552035841914, "value": ""}}}, {"outValue": ...

# %%
# plot_shap_values_stacked(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2');

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %%
#plot_shap_values_hierarchically_clustered(shap_values_f1, 'Classifier 1 in margin space')
plot_shap_values_hierarchically_clustered(shap_values_f2, 'Classifier 2 in margin space')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_values_hierarchically_clustered(shap_values_c2, 'Classifier 2 in probability space')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_positive_and_c2_negative, 'Probability: C1 predicts positive and C2 negative')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_negative_and_c2_positive, 'Probability: C1 predicts negative and C2 positive')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_and_c2_different, 'Probability: C1 and C2 predict different labels')

# %%
#plot_shap_values_hierarchically_clustered(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2')
