# %%
from scipy.special import logit
from shap.maskers import Independent
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from plots import plot_shap_value_distribution, plot_shap_partial_dependence, plot_shap_values_stacked, \
    plot_shap_values_hierarchically_clustered, plot_decision_boundary
import shap
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
shap.initjs()
np.seterr(all='ignore');
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# # Decision Tree vs. Naive Bayes
# Based on ["Classifier comparison"](https://scikit-learn.org/0.24/auto_examples/classification/plot_classifier_comparison.html) example of scikit-learn docs.

# %% [markdown]
# ## Create Models

# %%
feature_names = ['x1', 'x2']
X, y = make_circles(n_samples=500, noise=0.2, factor=0.5, random_state=1)
X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.8, random_state=42)

# %%
m1 = DecisionTreeClassifier(max_depth=5)
m1.fit(X_train, y_train)
logit_from_log_proba = lambda Y: Y[:,1] - Y[:,0]
f1 = lambda X: logit_from_log_proba(m1.predict_log_proba(X))
c1 = lambda X: m1.predict_proba(X)[:,1]

# %%
m2 = GaussianNB()
m2.fit(X_train, y_train)
f2 = lambda X: logit_from_log_proba(m2.predict_log_proba(X))
c2 = lambda X: m2.predict_proba(X)[:,1]

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_decision_boundary(c1, X, 'Classifier 1 in probability space', feature_names, (0, 1), fig, axs[0,0], y)
plot_decision_boundary(c2, X, 'Classifier 2 in probability space', feature_names, (0, 1), fig, axs[1,0], y)
plot_decision_boundary(f1, X, 'Classifier 1 in margin space', feature_names, (-8, 8), fig, axs[0,1], logit(y))
plot_decision_boundary(f2, X, 'Classifier 2 in margin space', feature_names, (-8, 8), fig, axs[1,1], logit(y))
plt.show()
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %%
complement = lambda p: 1 - p
c1_positive_and_c2_negative = lambda p1, p2: p1 * complement(p2)
c1_negative_and_c2_positive = lambda p1, p2: complement(p1) * p2
c1_and_c2_different = lambda p1, p2: c1_positive_and_c2_negative(p1, p2) + c1_negative_and_c2_positive(p1, p2)

c_c1_positive_and_c2_negative = lambda X: c1_positive_and_c2_negative(c1(X), c2(X))
c_c1_negative_and_c2_positive = lambda X: c1_negative_and_c2_positive(c1(X), c2(X))
c_c1_and_c2_different = lambda X: c1_and_c2_different(c1(X), c2(X))

# %%
odds = lambda p: p / complement(p)
log_odds_ratio_from_proba = lambda p1, p2: np.log(odds(p1) / odds(p2))
log_odds_ratio = lambda y1, y2: y1 - y2

f_c1_positive_and_c2_negative = lambda X: logit(c_c1_positive_and_c2_negative(X))
f_c1_negative_and_c2_positive = lambda X: logit(c_c1_negative_and_c2_positive(X))
f_c1_and_c2_different = lambda X: logit(c_c1_and_c2_different(X))
f_log_odds_ratio = lambda X: log_odds_ratio(f1(X), f2(X))

# %%
fig, axs = plt.subplots(3, 2, figsize=(18, 21))
plot_decision_boundary(c_c1_positive_and_c2_negative, X, 'Probability: C1 predicts positive and C2 negative', feature_names, (0, 1), fig, axs[0,0], y)
plot_decision_boundary(c_c1_negative_and_c2_positive, X, 'Probability: C1 predicts negative and C2 positive', feature_names, (0, 1), fig, axs[1,0], y)
plot_decision_boundary(c_c1_and_c2_different, X, 'Probability: C1 and C2 predict different labels', feature_names, (0, 1), fig, axs[2,0], y)
plot_decision_boundary(f_c1_positive_and_c2_negative, X, 'Margin: C1 predicts positive and C2 negative', feature_names, (-8, 8), fig, axs[0,1], logit(y))
plot_decision_boundary(f_c1_negative_and_c2_positive, X, 'Margin: C1 predicts negative and C2 positive', feature_names, (-8, 8), fig, axs[1,1], logit(y))
plot_decision_boundary(f_c1_and_c2_different, X, 'Margin: C1 and C2 predict different labels', feature_names, (-8, 8), fig, axs[2,1], logit(y))
plt.show()
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %%
plot_decision_boundary(f_log_odds_ratio, X, 'Log odds ratio of C1 and C2', feature_names, (-8, 8), z=logit(y))
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %% [markdown]
# ## Generate Explanations

# %%
def make_shap_values(model, background_data, feature_names):
    masker = Independent(background_data)
    explainer = shap.Explainer(model, masker, feature_names=feature_names)
    shap_values = explainer(X)
    return shap_values

shap_values_c1 = make_shap_values(c1, X, feature_names)
shap_values_c2 = make_shap_values(c2, X, feature_names)
shap_values_f1 = make_shap_values(f1, X, feature_names)
shap_values_f2 = make_shap_values(f2, X, feature_names)

# %%
shap_values_c_c1_positive_and_c2_negative = make_shap_values(c_c1_positive_and_c2_negative, X, feature_names)
shap_values_c_c1_negative_and_c2_positive = make_shap_values(c_c1_negative_and_c2_positive, X, feature_names)
shap_values_c_c1_and_c2_different = make_shap_values(c_c1_and_c2_different, X, feature_names)
shap_values_f_c1_positive_and_c2_negative = make_shap_values(f_c1_positive_and_c2_negative, X, feature_names)
shap_values_f_c1_negative_and_c2_positive = make_shap_values(f_c1_negative_and_c2_positive, X, feature_names)
shap_values_f_c1_and_c2_different = make_shap_values(f_c1_and_c2_different, X, feature_names)
shap_values_f_log_odds_ratio = make_shap_values(f_log_odds_ratio, X, feature_names)

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### SHAP Value Distribution

# %% [markdown]
# #### Probability Space

# %%
plot_shap_value_distribution(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_value_distribution(shap_values_c2, 'Classifier 2 in probability space')

# %%
plot_shap_value_distribution(shap_values_c_c1_positive_and_c2_negative, 'C1 predicts positive and C2 negative')
plot_shap_value_distribution(shap_values_c_c1_negative_and_c2_positive, 'C1 predicts negative and C2 positive')
plot_shap_value_distribution(shap_values_c_c1_and_c2_different, 'C1 and C2 predict different labels')

# %% [markdown]
# #### Margin Space

# %%
plot_shap_value_distribution(shap_values_f1, 'Classifier 1 in margin space')
plot_shap_value_distribution(shap_values_f2, 'Classifier 2 in margin space')

# %%
plot_shap_value_distribution(shap_values_f_c1_positive_and_c2_negative, 'C1 predicts positive and C2 negative')
plot_shap_value_distribution(shap_values_f_c1_negative_and_c2_positive, 'C1 predicts negative and C2 positive')
plot_shap_value_distribution(shap_values_f_c1_and_c2_different, 'C1 and C2 predict different labels')

# %%
plot_shap_value_distribution(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2')

# %% [markdown]
# ### Features' Partial Dependence Plots

# %% [markdown]
# #### Probability Space

# %%
ylim = None
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_shap_partial_dependence(shap_values_c1, feature_names[0], 'Classifier 1', ylim, axs[0,0])
plot_shap_partial_dependence(shap_values_c1, feature_names[1], 'Classifier 1', ylim, axs[0,1])
plot_shap_partial_dependence(shap_values_c2, feature_names[0], 'Classifier 2', ylim, axs[1,0])
plot_shap_partial_dependence(shap_values_c2, feature_names[1], 'Classifier 2', ylim, axs[1,1])
plt.show()

# %%
ylim = None
fig, axs = plt.subplots(3, 2, figsize=(18, 21))
plot_shap_partial_dependence(shap_values_c_c1_positive_and_c2_negative, feature_names[0], 'C1 predicts positive and C2 negative', ylim, axs[0,0])
plot_shap_partial_dependence(shap_values_c_c1_positive_and_c2_negative, feature_names[1], 'C1 predicts positive and C2 negative', ylim, axs[0,1])
plot_shap_partial_dependence(shap_values_c_c1_negative_and_c2_positive, feature_names[0], 'C1 predicts negative and C2 positive', ylim, axs[1,0])
plot_shap_partial_dependence(shap_values_c_c1_negative_and_c2_positive, feature_names[1], 'C1 predicts negative and C2 positive', ylim, axs[1,1])
plot_shap_partial_dependence(shap_values_c_c1_and_c2_different, feature_names[0], 'C1 and C2 predict different labels', ylim, axs[2,0])
plot_shap_partial_dependence(shap_values_c_c1_and_c2_different, feature_names[1], 'C1 and C2 predict different labels', ylim, axs[2,1])
plt.show()

# %% [markdown]
# #### Margin Space

# %%
ylim = None
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_shap_partial_dependence(shap_values_f1, feature_names[0], 'Classifier 1', ylim, axs[0,0])
plot_shap_partial_dependence(shap_values_f1, feature_names[1], 'Classifier 1', ylim, axs[0,1])
plot_shap_partial_dependence(shap_values_f2, feature_names[0], 'Classifier 2', ylim, axs[1,0])
plot_shap_partial_dependence(shap_values_f2, feature_names[1], 'Classifier 2', ylim, axs[1,1])
plt.show()

# %%
ylim = None
fig, axs = plt.subplots(3, 2, figsize=(18, 21))
plot_shap_partial_dependence(shap_values_f_c1_positive_and_c2_negative, feature_names[0], 'C1 predicts positive and C2 negative', ylim, axs[0,0])
plot_shap_partial_dependence(shap_values_f_c1_positive_and_c2_negative, feature_names[1], 'C1 predicts positive and C2 negative', ylim, axs[0,1])
plot_shap_partial_dependence(shap_values_f_c1_negative_and_c2_positive, feature_names[0], 'C1 predicts negative and C2 positive', ylim, axs[1,0])
plot_shap_partial_dependence(shap_values_f_c1_negative_and_c2_positive, feature_names[1], 'C1 predicts negative and C2 positive', ylim, axs[1,1])
plot_shap_partial_dependence(shap_values_f_c1_and_c2_different, feature_names[0], 'C1 and C2 predict different labels', ylim, axs[2,0])
plot_shap_partial_dependence(shap_values_f_c1_and_c2_different, feature_names[1], 'C1 and C2 predict different labels', ylim, axs[2,1])
plt.show()

# %%
ylim = None
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_f_log_odds_ratio, feature_names[0], 'Log odds ratio of C1 and C2', ylim, axs[0])
plot_shap_partial_dependence(shap_values_f_log_odds_ratio, feature_names[1], 'Log odds ratio of C1 and C2', ylim, axs[1])
plt.show()

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %% [markdown]
# #### Probability Space

# %%
ordering = plot_shap_values_stacked(shap_values_c1, 'Classifier 1')
plot_shap_values_stacked(shap_values_c2, 'Classifier 2', ordering);
# Out:
# <div id='iETXRM7VSMWI2GDFASW6Z'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 1"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.4630894308943082, "simIndex": 287.0, "features": {"0": {"effect": 0.2947696476964765, "value": ""}, "1": {"effect": 0.1683197831978317, "value": ""}}}, {"outValue": 0.4630894308943082, "simIndex": 286.0, "features": {"0": {"effect": 0.2947696476964765, "value": ""}, "1": {"effect": 0.1683197831978317, "value": ""}}}, {"outValue": -0.4637398373983742, "simIndex": 498.0, "features": {"0": {"effect": 0.18922764227642253, "value": ""}, "1": {"effect": -0.6529674796747967, "value": ""}}}, {"outValue": 0.4630894308943082, "simIndex": 285.0, "features": {"0": {"effect": 0.2947696476964765, "value": ""}, "1": {"effect": 0.1683197831978317, "value": ""}}}, {"outValue": -0.01929539295393068, "simIndex": 150.0, "features": {"0": {"effect": -0.10696476964769774, "value": ""}, "1": {"effect": 0.08766937669376706, "value": ""}}}, {"outValue": -0.01929539295393068, "simIndex": 167.0, "features": {"0": {"effect": -0.08196476964769772, "value": ""}, "1": {"effect": 0.06266937669376704, "value": ""}}}, {"outValue": 0.4630894308943082, "simIndex": 288.0, "features": {"0": {"effect": 0.2947696476964765, "value": ""}, "1": {"effect": 0.1683197831978317, "value": ""}}}, {"outValue": -0.4637398373983742, "simIndex": 87.0, "features": {"0": {"effect": -0.5247425474254747, "value": ""}, "1": {"effect": 0.061002710027100455, "value": ""}}}, {"outValue": -0.4637398373983742, "simIndex": 26.0, "features": {"0": {"effect": -0.5497425474254747, "value": ""}, "1": {"effect": 0.08600271002710048, "value": ""}}}, {"outValue": 0.4630894308943082, "simIndex": 284.0, "features": {"0": {"effect": 0.2947696476964765, "value": ""}, "1": {"effect": 0.1683197831978317, "value": ""}}}, {"outValue": 0.4630894308943082, "simIndex": 289.0, "features": {"0": {"effect": 0.2947696476964765, "value": ""}, "1": {"effect": 0.1683197831978317, "value": ""}}}, {"outValue": -0.4637398373983742, "simIndex": 446.0, "features": {"0": {"effect": 0.049227642276422845, "value": ""}, "1": {"effect": -0.5129674796747971, "value": ""}}}, {"outValue": 0.4630894308943082, "simIndex": 283.0, "features": {"0": {"effect": 0.2947696476964765, "value": ""}, "1": {"effect": 0.1683197831978317, "value": ""}}}, {"outValue": -0.46373983739837427, "simIndex": 484.0, "features": {"0": {"effect": 0.13422764227642286, "value": ""}, "1": {"effect": -0.5979674796747971, "value": ""}}}, {"outValue": 0.4630894308943082, "simIndex": 290.0, "features": {"0": {"effect": 0.2947696476964765, "value": ""}, "1": {"effect": 0.1683197831978317, "value": ""}}}, {"outValue": -0.4637398373983742, "simIndex": 445.0, "features": {"0": {"effect": 0.049227642276422845, "value": ""}, "1": {"effect": -0.5129674796747971, "value": ""}}}, {"outValue": 0.4630894308943082, "simIndex": 380.0, "features": {"0": {"effect": 0.2697696476964765, "value": ""}, "1": {"effect": 0.19331978319783172, "value": ""}}}, {"outValue": 0.4630894308943082, "simIndex": 282.0, "features": {"0": {"effect": 0.2947696476964765, "value": ""}, "1": {"effect": 0.1683197831978317, "value": ""}}}, {"outValue": 0.5362601626016258, "simIndex": 183.0, "features": {"0": {"effect": 0.1202574525745253, "value": ""}, "1": {"effect": 0.4160027100271005, "value": ""}}}, {"outValue": -0.4637398373983742, "simIndex": 10.0, "features": {"0": {"effect": -0.5597425474254747, "value": ""}, "1": {"effect": 0.09600271002710048, "value": ""}}}, {"outValue": 0.4630894308943082, "simIndex": 291.0, "features": {"0": {"effect": 0.2947696476964765, "value": ""}, "1": {"effect": 0.1683197831978317, "value": ""}}}, {"outValue": 0.4630894308943082, "simIndex": 281.0, "features": {"0": {"effect": 0.2947696476964765, "value": ""}, "1": {"effect": 0.1683197831978317, "value": ""}}}, {"outValue": 0.4630894308943082, "simIndex": 292.0, "features": {"0": {"effect": 0.2947696476964765, "value": ""} ...
# <div id='iJJ1KW6VZQ8IDKJ18LRPD'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 2"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.08768797225164654, "simIndex": 362.0, "features": {"0": {"effect": 0.1354975998110277, "value": ""}, "1": {"effect": -0.047809627559381174, "value": ""}}}, {"outValue": 0.282192236978163, "simIndex": 282.0, "features": {"0": {"effect": 0.15649983227164743, "value": ""}, "1": {"effect": 0.12569240470651555, "value": ""}}}, {"outValue": -0.17113236031385384, "simIndex": 462.0, "features": {"0": {"effect": 0.06904642842395145, "value": ""}, "1": {"effect": -0.2401787887378053, "value": ""}}}, {"outValue": -0.07473585805330235, "simIndex": 411.0, "features": {"0": {"effect": 0.051080032258151414, "value": ""}, "1": {"effect": -0.12581589031145377, "value": ""}}}, {"outValue": 0.10347336095642623, "simIndex": 191.0, "features": {"0": {"effect": 0.04889306861852197, "value": ""}, "1": {"effect": 0.05458029233790426, "value": ""}}}, {"outValue": 0.23917908331635546, "simIndex": 250.0, "features": {"0": {"effect": 0.09412623140328497, "value": ""}, "1": {"effect": 0.1450528519130705, "value": ""}}}, {"outValue": 0.16596415567302608, "simIndex": 348.0, "features": {"0": {"effect": 0.14346015961644926, "value": ""}, "1": {"effect": 0.022503996056576825, "value": ""}}}, {"outValue": -0.1653567563826474, "simIndex": 400.0, "features": {"0": {"effect": -0.08864005914230527, "value": ""}, "1": {"effect": -0.07671669724034212, "value": ""}}}, {"outValue": -0.26873681463499083, "simIndex": 80.0, "features": {"0": {"effect": -0.3136010938979065, "value": ""}, "1": {"effect": 0.04486427926291569, "value": ""}}}, {"outValue": -0.1716819954636477, "simIndex": 393.0, "features": {"0": {"effect": -0.05817241637103826, "value": ""}, "1": {"effect": -0.11350957909260946, "value": ""}}}, {"outValue": 0.14083254206939094, "simIndex": 353.0, "features": {"0": {"effect": 0.15597028845696687, "value": ""}, "1": {"effect": -0.015137746387575923, "value": ""}}}, {"outValue": -0.12852762615546087, "simIndex": 424.0, "features": {"0": {"effect": 0.0672317894945896, "value": ""}, "1": {"effect": -0.19575941565005048, "value": ""}}}, {"outValue": 0.05536392392523509, "simIndex": 131.0, "features": {"0": {"effect": -0.02551093437893992, "value": ""}, "1": {"effect": 0.08087485830417501, "value": ""}}}, {"outValue": -0.25383518520289766, "simIndex": 481.0, "features": {"0": {"effect": 0.08587488497742124, "value": ""}, "1": {"effect": -0.3397100701803189, "value": ""}}}, {"outValue": 0.11522150707886897, "simIndex": 357.0, "features": {"0": {"effect": 0.14259796998578111, "value": ""}, "1": {"effect": -0.027376462906912147, "value": ""}}}, {"outValue": -0.39515674714472954, "simIndex": 491.0, "features": {"0": {"effect": 0.03173469771237847, "value": ""}, "1": {"effect": -0.426891444857108, "value": ""}}}, {"outValue": 0.28308226329664526, "simIndex": 283.0, "features": {"0": {"effect": 0.15537254468265915, "value": ""}, "1": {"effect": 0.1277097186139861, "value": ""}}}, {"outValue": 0.30019697937120543, "simIndex": 291.0, "features": {"0": {"effect": 0.15000911247553111, "value": ""}, "1": {"effect": 0.15018786689567432, "value": ""}}}, {"outValue": -0.34927727741818493, "simIndex": 25.0, "features": {"0": {"effect": -0.3549253572119121, "value": ""}, "1": {"effect": 0.005648079793727161, "value": ""}}}, {"outValue": -0.13877012070662792, "simIndex": 58.0, "features": {"0": {"effect": -0.18466558461523794, "value": ""}, "1": {"effect": 0.04589546390861002, "value": ""}}}, {"outValue": 0.2219180717214087, "simIndex": 308.0, "features": {"0": {"effect": 0.14354114771633208, "value": ""}, "1": {"effect": 0.07837692400507662, "value": ""}}}, {"outValue": 0.18601618244745427, "simIndex": 325.0, "features": {"0": {"effect": 0.1284732827038172, "value": ""}, "1": {"effect": 0.05754289974363708, "value": ""}}}, {"outValue": 0.3010227066782054, "simIndex": 293.0, "features": {"0 ...

# %%
plot_shap_values_stacked(shap_values_c_c1_positive_and_c2_negative, 'C1 predicts positive and C2 negative')
plot_shap_values_stacked(shap_values_c_c1_negative_and_c2_positive, 'C1 predicts negative and C2 positive')
plot_shap_values_stacked(shap_values_c_c1_and_c2_different, 'C1 and C2 predict different labels');
# Out:
# <div id='iKYKT1PTYF65VWYHU9NY0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["C1 predicts positive and C2 negative"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.2679623948701163, "simIndex": 38.0, "features": {"0": {"effect": 0.10578470237629325, "value": ""}, "1": {"effect": 0.16217769249382308, "value": ""}}}, {"outValue": 0.08769014951383239, "simIndex": 204.0, "features": {"0": {"effect": 0.06657628996250212, "value": ""}, "1": {"effect": 0.021113859551330272, "value": ""}}}, {"outValue": -0.2009470610285375, "simIndex": 370.0, "features": {"0": {"effect": 0.09554710840443165, "value": ""}, "1": {"effect": -0.29649416943296913, "value": ""}}}, {"outValue": 0.4185015546649468, "simIndex": 45.0, "features": {"0": {"effect": 0.1857585270826782, "value": ""}, "1": {"effect": 0.2327430275822686, "value": ""}}}, {"outValue": 0.01689437664471552, "simIndex": 253.0, "features": {"0": {"effect": -0.02217750090495657, "value": ""}, "1": {"effect": 0.03907187754967209, "value": ""}}}, {"outValue": -0.04341927773747535, "simIndex": 262.0, "features": {"0": {"effect": -0.010686328790781921, "value": ""}, "1": {"effect": -0.03273294894669343, "value": ""}}}, {"outValue": 0.1954137370649356, "simIndex": 172.0, "features": {"0": {"effect": 0.09106872087640788, "value": ""}, "1": {"effect": 0.1043450161885277, "value": ""}}}, {"outValue": -0.20094706102853754, "simIndex": 492.0, "features": {"0": {"effect": -0.27019312407939416, "value": ""}, "1": {"effect": 0.06924606305085662, "value": ""}}}, {"outValue": -0.20094706102853752, "simIndex": 464.0, "features": {"0": {"effect": -0.24262076620594036, "value": ""}, "1": {"effect": 0.04167370517740285, "value": ""}}}, {"outValue": 0.508354072264779, "simIndex": 22.0, "features": {"0": {"effect": 0.27958937345055185, "value": ""}, "1": {"effect": 0.22876469881422723, "value": ""}}}, {"outValue": 0.21870645211220693, "simIndex": 179.0, "features": {"0": {"effect": 0.08490721434249543, "value": ""}, "1": {"effect": 0.1337992377697115, "value": ""}}}, {"outValue": -0.2009470610285375, "simIndex": 325.0, "features": {"0": {"effect": -0.0100464706194473, "value": ""}, "1": {"effect": -0.1909005904090902, "value": ""}}}, {"outValue": 0.29792126892874293, "simIndex": 59.0, "features": {"0": {"effect": 0.2286011964356209, "value": ""}, "1": {"effect": 0.069320072493122, "value": ""}}}, {"outValue": -0.2009470610285375, "simIndex": 351.0, "features": {"0": {"effect": 0.04231349409797233, "value": ""}, "1": {"effect": -0.24326055512650982, "value": ""}}}, {"outValue": 0.242443508932689, "simIndex": 175.0, "features": {"0": {"effect": 0.09754946422963956, "value": ""}, "1": {"effect": 0.14489404470304945, "value": ""}}}, {"outValue": -0.20094706102853746, "simIndex": 322.0, "features": {"0": {"effect": -0.016614128166107495, "value": ""}, "1": {"effect": -0.18433293286242997, "value": ""}}}, {"outValue": 0.08686524707231208, "simIndex": 224.0, "features": {"0": {"effect": 0.04427896578298818, "value": ""}, "1": {"effect": 0.0425862812893239, "value": ""}}}, {"outValue": 0.07100282729589075, "simIndex": 199.0, "features": {"0": {"effect": 0.0684770914937006, "value": ""}, "1": {"effect": 0.002525735802190149, "value": ""}}}, {"outValue": 0.7419468121108924, "simIndex": 3.0, "features": {"0": {"effect": 0.37172844578632913, "value": ""}, "1": {"effect": 0.3702183663245633, "value": ""}}}, {"outValue": -0.20094706102853746, "simIndex": 476.0, "features": {"0": {"effect": -0.2539783503735923, "value": ""}, "1": {"effect": 0.05303128934505483, "value": ""}}}, {"outValue": 0.14355400999570184, "simIndex": 210.0, "features": {"0": {"effect": 0.08400486995857728, "value": ""}, "1": {"effect": 0.059549140037124554, "value": ""}}}, {"outValue": 0.17682893176180714, "simIndex": 157.0, "features": {"0": {"effect": 0.0994358480306411, "value": ""}, "1": {"effect": 0.07739308373116605, "value": ""}}}, {"outValue": 0.0702375190601345, "simIndex": 200.0, "features" ...
# <div id='iGZX95AZD2SMNLBXF41S9'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["C1 predicts negative and C2 positive"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.10743906377254578, "simIndex": 340.0, "features": {"0": {"effect": -0.05348734550915578, "value": ""}, "1": {"effect": -0.05395171826339, "value": ""}}}, {"outValue": -0.0932070444023129, "simIndex": 303.0, "features": {"0": {"effect": -0.07169352546232693, "value": ""}, "1": {"effect": -0.02151351893998596, "value": ""}}}, {"outValue": 0.09166041605598316, "simIndex": 417.0, "features": {"0": {"effect": -0.024634105448039408, "value": ""}, "1": {"effect": 0.11629452150402256, "value": ""}}}, {"outValue": -0.11932373428266405, "simIndex": 336.0, "features": {"0": {"effect": -0.05793108835564706, "value": ""}, "1": {"effect": -0.061392645927016994, "value": ""}}}, {"outValue": 0.13966313055507235, "simIndex": 74.0, "features": {"0": {"effect": 0.13368033736126247, "value": ""}, "1": {"effect": 0.005982793193809871, "value": ""}}}, {"outValue": 0.21505519853281127, "simIndex": 63.0, "features": {"0": {"effect": 0.16540467226020011, "value": ""}, "1": {"effect": 0.049650526272611156, "value": ""}}}, {"outValue": -0.10171153815634737, "simIndex": 364.0, "features": {"0": {"effect": -0.0602407672036198, "value": ""}, "1": {"effect": -0.04147077095272757, "value": ""}}}, {"outValue": 0.09743601998718968, "simIndex": 25.0, "features": {"0": {"effect": 0.16590936420377517, "value": ""}, "1": {"effect": -0.06847334421658549, "value": ""}}}, {"outValue": -0.0059440382651537865, "simIndex": 376.0, "features": {"0": {"effect": -0.006479312678372359, "value": ""}, "1": {"effect": 0.0005352744132185727, "value": ""}}}, {"outValue": -0.1264173540931771, "simIndex": 327.0, "features": {"0": {"effect": -0.07335269061696326, "value": ""}, "1": {"effect": -0.05306466347621383, "value": ""}}}, {"outValue": -0.10355043671271083, "simIndex": 345.0, "features": {"0": {"effect": -0.05389214489701456, "value": ""}, "1": {"effect": -0.04965829181569627, "value": ""}}}, {"outValue": 0.13426515021437616, "simIndex": 420.0, "features": {"0": {"effect": 0.007957676598719841, "value": ""}, "1": {"effect": 0.1263074736156563, "value": ""}}}, {"outValue": -0.10980423804033206, "simIndex": 181.0, "features": {"0": {"effect": -0.09167938563979659, "value": ""}, "1": {"effect": -0.01812485240053546, "value": ""}}}, {"outValue": 0.0089575911669394, "simIndex": 446.0, "features": {"0": {"effect": -0.006039263201028773, "value": ""}, "1": {"effect": 0.014996854367968174, "value": ""}}}, {"outValue": -0.10542441488274892, "simIndex": 343.0, "features": {"0": {"effect": -0.05462221348105537, "value": ""}, "1": {"effect": -0.05080220140169356, "value": ""}}}, {"outValue": -0.13236397077489248, "simIndex": 124.0, "features": {"0": {"effect": -0.03410707273015147, "value": ""}, "1": {"effect": -0.09825689804474101, "value": ""}}}, {"outValue": -0.09314192052535067, "simIndex": 307.0, "features": {"0": {"effect": -0.0701181372308293, "value": ""}, "1": {"effect": -0.02302378329452137, "value": ""}}}, {"outValue": -0.0918896242272123, "simIndex": 211.0, "features": {"0": {"effect": -0.0762834437272449, "value": ""}, "1": {"effect": -0.015606180499967395, "value": ""}}}, {"outValue": -0.14359062790891655, "simIndex": 172.0, "features": {"0": {"effect": -0.10345436400010763, "value": ""}, "1": {"effect": -0.040136263908808915, "value": ""}}}, {"outValue": 0.12402265566320905, "simIndex": 72.0, "features": {"0": {"effect": 0.12109861243664427, "value": ""}, "1": {"effect": 0.002924043226564782, "value": ""}}}, {"outValue": -0.09761734917719732, "simIndex": 281.0, "features": {"0": {"effect": -0.06722363002156695, "value": ""}, "1": {"effect": -0.030393719155630366, "value": ""}}}, {"outValue": -0.10024431668504788, "simIndex": 262.0, "features": {"0": {"effect": -0.06686051696201872, "value": ""}, "1": {"effect": -0.033383799723029156, "value": ""}}}, {"outVa ...
# <div id='i14XIZ39BG75B5QMIKRXT'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["C1 and C2 predict different labels"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.1605233310975694, "simIndex": 97.0, "features": {"0": {"effect": 0.05229735686713685, "value": ""}, "1": {"effect": 0.10822597423043254, "value": ""}}}, {"outValue": -0.005516894888480284, "simIndex": 378.0, "features": {"0": {"effect": -0.005117235499824707, "value": ""}, "1": {"effect": -0.0003996593886555766, "value": ""}}}, {"outValue": -0.10928664497255464, "simIndex": 485.0, "features": {"0": {"effect": 0.07091300295639208, "value": ""}, "1": {"effect": -0.18019964792894672, "value": ""}}}, {"outValue": 0.29917782038228063, "simIndex": 23.0, "features": {"0": {"effect": 0.1278274387270302, "value": ""}, "1": {"effect": 0.17135038165525043, "value": ""}}}, {"outValue": 0.15655750719978828, "simIndex": 174.0, "features": {"0": {"effect": 0.11150283645630601, "value": ""}, "1": {"effect": 0.04505467074348227, "value": ""}}}, {"outValue": 0.17163592079533507, "simIndex": 41.0, "features": {"0": {"effect": 0.15471834346941782, "value": ""}, "1": {"effect": 0.016917577325917255, "value": ""}}}, {"outValue": 0.09370219890858819, "simIndex": 126.0, "features": {"0": {"effect": 0.030827953672788067, "value": ""}, "1": {"effect": 0.06287424523580012, "value": ""}}}, {"outValue": -0.10351104104134817, "simIndex": 275.0, "features": {"0": {"effect": -0.10428375987561936, "value": ""}, "1": {"effect": 0.0007727188342711855, "value": ""}}}, {"outValue": -0.2068910992936916, "simIndex": 207.0, "features": {"0": {"effect": -0.2491000788843129, "value": ""}, "1": {"effect": 0.04220897959062131, "value": ""}}}, {"outValue": 0.3819367181716022, "simIndex": 24.0, "features": {"0": {"effect": 0.2062366828335885, "value": ""}, "1": {"effect": 0.17570003533801368, "value": ""}}}, {"outValue": 0.11515601539949519, "simIndex": 121.0, "features": {"0": {"effect": 0.031015069445480437, "value": ""}, "1": {"effect": 0.08414094595401475, "value": ""}}}, {"outValue": -0.06668191081416167, "simIndex": 398.0, "features": {"0": {"effect": -0.0020887940207276745, "value": ""}, "1": {"effect": -0.06459311679343399, "value": ""}}}, {"outValue": 0.18811703088840942, "simIndex": 71.0, "features": {"0": {"effect": 0.1369218107958238, "value": ""}, "1": {"effect": 0.05119522009258562, "value": ""}}}, {"outValue": -0.1919894698615984, "simIndex": 476.0, "features": {"0": {"effect": 0.03627423089694351, "value": ""}, "1": {"effect": -0.2282637007585419, "value": ""}}}, {"outValue": 0.13701909404994086, "simIndex": 105.0, "features": {"0": {"effect": 0.04292725074858447, "value": ""}, "1": {"effect": 0.09409184330135639, "value": ""}}}, {"outValue": -0.3333110318034303, "simIndex": 472.0, "features": {"0": {"effect": -0.050721200896259144, "value": ""}, "1": {"effect": -0.28258983090717116, "value": ""}}}, {"outValue": -0.0062766734530387835, "simIndex": 291.0, "features": {"0": {"effect": -0.025839171447841175, "value": ""}, "1": {"effect": 0.01956249799480239, "value": ""}}}, {"outValue": -0.02088679693132245, "simIndex": 370.0, "features": {"0": {"effect": -0.0078063522335447555, "value": ""}, "1": {"effect": -0.013080444697777693, "value": ""}}}, {"outValue": 0.5983561842019757, "simIndex": 4.0, "features": {"0": {"effect": 0.26827408178622136, "value": ""}, "1": {"effect": 0.3300821024157543, "value": ""}}}, {"outValue": -0.07692440536532877, "simIndex": 248.0, "features": {"0": {"effect": -0.13287973793694827, "value": ""}, "1": {"effect": 0.0559553325716195, "value": ""}}}, {"outValue": 0.04593666081850356, "simIndex": 327.0, "features": {"0": {"effect": 0.016781239937009862, "value": ""}, "1": {"effect": 0.0291554208814937, "value": ""}}}, {"outValue": 0.07658461507675929, "simIndex": 343.0, "features": {"0": {"effect": 0.032575331068622315, "value": ""}, "1": {"effect": 0.04400928400813697, "value": ""}}}, {"outValue": -0.021591686095834922, ...

# %% [markdown]
# #### Margin Space

# %%
ordering = plot_shap_values_stacked(shap_values_f1, 'Classifier 1')
plot_shap_values_stacked(shap_values_f2, 'Classifier 2', ordering);
# Out:
# Omitting plot because of ValueError: The condensed distance matrix must contain only finite values.
# <div id='iO8SBNTL7DX4TPFXPFIN5'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 2"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.4994131161803651, "simIndex": 105.0, "features": {"0": {"effect": 0.680162482272858, "value": ""}, "1": {"effect": -0.18074936609249292, "value": ""}}}, {"outValue": 1.316597417840792, "simIndex": 259.0, "features": {"0": {"effect": 0.7353519583439924, "value": ""}, "1": {"effect": 0.5812454594967996, "value": ""}}}, {"outValue": -0.6557656802586556, "simIndex": 45.0, "features": {"0": {"effect": 0.47397168666945366, "value": ""}, "1": {"effect": -1.1297373669281092, "value": ""}}}, {"outValue": -0.17761414101833528, "simIndex": 89.0, "features": {"0": {"effect": 0.3430802710510271, "value": ""}, "1": {"effect": -0.5206944120693624, "value": ""}}}, {"outValue": 0.5625608910833864, "simIndex": 139.0, "features": {"0": {"effect": 0.27805602874220225, "value": ""}, "1": {"effect": 0.2845048623411841, "value": ""}}}, {"outValue": 1.122718671304956, "simIndex": 227.0, "features": {"0": {"effect": 0.45140267081285923, "value": ""}, "1": {"effect": 0.6713160004920968, "value": ""}}}, {"outValue": 0.8145643409485767, "simIndex": 118.0, "features": {"0": {"effect": 0.6915067866989663, "value": ""}, "1": {"effect": 0.12305755424961042, "value": ""}}}, {"outValue": -0.6239304464739548, "simIndex": 335.0, "features": {"0": {"effect": -0.3270869859816359, "value": ""}, "1": {"effect": -0.2968434604923189, "value": ""}}}, {"outValue": -1.311846998208031, "simIndex": 454.0, "features": {"0": {"effect": -1.6688259363779179, "value": ""}, "1": {"effect": 0.356978938169887, "value": ""}}}, {"outValue": -0.6588232459611478, "simIndex": 377.0, "features": {"0": {"effect": -0.1782539115000138, "value": ""}, "1": {"effect": -0.48056933446113403, "value": ""}}}, {"outValue": 0.712556920059746, "simIndex": 110.0, "features": {"0": {"effect": 0.7567319638844087, "value": ""}, "1": {"effect": -0.04417504382466263, "value": ""}}}, {"outValue": -0.4319939553632126, "simIndex": 60.0, "features": {"0": {"effect": 0.4441557449478012, "value": ""}, "1": {"effect": -0.8761497003110138, "value": ""}}}, {"outValue": 0.36981845426094295, "simIndex": 325.0, "features": {"0": {"effect": -0.047957946441208765, "value": ""}, "1": {"effect": 0.4177764007021517, "value": ""}}}, {"outValue": -1.1916244837133902, "simIndex": 21.0, "features": {"0": {"effect": 0.6282466580874609, "value": ""}, "1": {"effect": -1.819871141800851, "value": ""}}}, {"outValue": 0.6096022116733062, "simIndex": 107.0, "features": {"0": {"effect": 0.7031210103056976, "value": ""}, "1": {"effect": -0.0935187986323914, "value": ""}}}, {"outValue": -3.9550453541390347, "simIndex": 1.0, "features": {"0": {"effect": 0.33636422870511784, "value": ""}, "1": {"effect": -4.291409582844152, "value": ""}}}, {"outValue": 1.3207511576245257, "simIndex": 260.0, "features": {"0": {"effect": 0.7301398647803053, "value": ""}, "1": {"effect": 0.5906112928442203, "value": ""}}}, {"outValue": 1.4019619722621817, "simIndex": 268.0, "features": {"0": {"effect": 0.7058136386543493, "value": ""}, "1": {"effect": 0.6961483336078323, "value": ""}}}, {"outValue": -2.280913601592618, "simIndex": 485.0, "features": {"0": {"effect": -2.3885269087842076, "value": ""}, "1": {"effect": 0.10761330719158968, "value": ""}}}, {"outValue": -0.4836369873848483, "simIndex": 449.0, "features": {"0": {"effect": -0.79749951161031, "value": ""}, "1": {"effect": 0.3138625242254617, "value": ""}}}, {"outValue": 1.0480657237788589, "simIndex": 168.0, "features": {"0": {"effect": 0.6802842861774003, "value": ""}, "1": {"effect": 0.3677814376014586, "value": ""}}}, {"outValue": 0.8970227910258731, "simIndex": 159.0, "features": {"0": {"effect": 0.6180588943563584, "value": ""}, "1": {"effect": 0.2789638966695147, "value": ""}}}, {"outValue": 1.4059480335292918, "simIndex": 270.0, "features": {"0": {"effect": 0.731254881812839, "value": ""}, "1": {"eff ...

# %%
plot_shap_values_stacked(shap_values_f_c1_positive_and_c2_negative, 'C1 predicts positive and C2 negative')
plot_shap_values_stacked(shap_values_f_c1_negative_and_c2_positive, 'C1 predicts negative and C2 positive')
plot_shap_values_stacked(shap_values_f_c1_and_c2_different, 'C1 and C2 predict different labels');
# Out:
# Omitting plot because of ValueError: The condensed distance matrix must contain only finite values.
# Omitting plot because of ValueError: The condensed distance matrix must contain only finite values.
# <div id='iQG5XZYCNFPE6LIHSDIIN'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["C1 and C2 predict different labels"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.7809131290326323, "simIndex": 204.0, "features": {"0": {"effect": 0.32527407968101635, "value": ""}, "1": {"effect": 0.45563904935161603, "value": ""}}}, {"outValue": 0.09300742146663926, "simIndex": 281.0, "features": {"0": {"effect": 0.047358294635254705, "value": ""}, "1": {"effect": 0.04564912683138456, "value": ""}}}, {"outValue": -0.41822604430917654, "simIndex": 473.0, "features": {"0": {"effect": 0.48367378602369737, "value": ""}, "1": {"effect": -0.9018998303328739, "value": ""}}}, {"outValue": 1.3521956874220216, "simIndex": 40.0, "features": {"0": {"effect": 0.6526948869606308, "value": ""}, "1": {"effect": 0.6995008004613907, "value": ""}}}, {"outValue": 0.7650491490313232, "simIndex": 69.0, "features": {"0": {"effect": 0.4928290118465826, "value": ""}, "1": {"effect": 0.27222013718474053, "value": ""}}}, {"outValue": 0.825385374766573, "simIndex": 103.0, "features": {"0": {"effect": 0.7063821353844394, "value": ""}, "1": {"effect": 0.11900323938213361, "value": ""}}}, {"outValue": 0.5123598950044018, "simIndex": 175.0, "features": {"0": {"effect": 0.22008613214200018, "value": ""}, "1": {"effect": 0.29227376286240164, "value": ""}}}, {"outValue": -0.3863908105244759, "simIndex": 353.0, "features": {"0": {"effect": -0.4004750727270095, "value": ""}, "1": {"effect": 0.014084262202533615, "value": ""}}}, {"outValue": -1.0743073622585517, "simIndex": 398.0, "features": {"0": {"effect": -1.4552174862876222, "value": ""}, "1": {"effect": 0.3809101240290703, "value": ""}}}, {"outValue": 1.7374764192579044, "simIndex": 38.0, "features": {"0": {"effect": 0.9686235115576787, "value": ""}, "1": {"effect": 0.7688529077002257, "value": ""}}}, {"outValue": 0.5990925720950335, "simIndex": 183.0, "features": {"0": {"effect": 0.23151751497258483, "value": ""}, "1": {"effect": 0.36757505712244876, "value": ""}}}, {"outValue": -0.19445431941373398, "simIndex": 252.0, "features": {"0": {"effect": 0.04884566300371809, "value": ""}, "1": {"effect": -0.24329998241745207, "value": ""}}}, {"outValue": 0.8914734240678629, "simIndex": 81.0, "features": {"0": {"effect": 0.6085515728909264, "value": ""}, "1": {"effect": 0.28292185117693647, "value": ""}}}, {"outValue": -0.954084847763911, "simIndex": 487.0, "features": {"0": {"effect": 0.41415677637311793, "value": ""}, "1": {"effect": -1.368241624137029, "value": ""}}}, {"outValue": 0.6868620034083166, "simIndex": 190.0, "features": {"0": {"effect": 0.2821822518516272, "value": ""}, "1": {"effect": 0.40467975155668945, "value": ""}}}, {"outValue": -3.717505718189556, "simIndex": 500.0, "features": {"0": {"effect": -0.5610247621918272, "value": ""}, "1": {"effect": -3.1564809559977287, "value": ""}}}, {"outValue": 0.0896149951222612, "simIndex": 324.0, "features": {"0": {"effect": -0.07508132485078522, "value": ""}, "1": {"effect": 0.16469631997304643, "value": ""}}}, {"outValue": 0.0236244238651086, "simIndex": 268.0, "features": {"0": {"effect": 0.030438439005219642, "value": ""}, "1": {"effect": -0.0068140151401110405, "value": ""}}}, {"outValue": 3.5647106805956668, "simIndex": 2.0, "features": {"0": {"effect": 1.5037959041079505, "value": ""}, "1": {"effect": 2.0609147764877163, "value": ""}}}, {"outValue": -0.24609735143536937, "simIndex": 344.0, "features": {"0": {"effect": -0.6419062812485412, "value": ""}, "1": {"effect": 0.39580892981317184, "value": ""}}}, {"outValue": 0.3153496068430993, "simIndex": 149.0, "features": {"0": {"effect": 0.14934971138878494, "value": ""}, "1": {"effect": 0.1659998954543144, "value": ""}}}, {"outValue": 0.4425004352416139, "simIndex": 170.0, "features": {"0": {"effect": 0.21776930650634874, "value": ""}, "1": {"effect": 0.22473112873526518, "value": ""}}}, {"outValue": 0.020402463661352288, "simIndex": 266.0, "features": {"0": {"effect":  ...

# %%
plot_shap_values_stacked(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2');
# Out:
# Omitting plot because of ValueError: The condensed distance matrix must contain only finite values.

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %% [markdown]
# #### Probability Space

# %%
plot_shap_values_hierarchically_clustered(shap_values_c1, 'Classifier 1')
plot_shap_values_hierarchically_clustered(shap_values_c2, 'Classifier 2')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_positive_and_c2_negative, 'C1 predicts positive and C2 negative')
plot_shap_values_hierarchically_clustered(shap_values_c_c1_negative_and_c2_positive, 'C1 predicts negative and C2 positive')
plot_shap_values_hierarchically_clustered(shap_values_c_c1_and_c2_different, 'C1 and C2 predict different labels')

# %% [markdown]
# #### Margin Space

# %%
plot_shap_values_hierarchically_clustered(shap_values_f1, 'Classifier 1')
plot_shap_values_hierarchically_clustered(shap_values_f2, 'Classifier 2')
# Out:
# Omitting plot because of ValueError: The condensed distance matrix must contain only finite values.

# %%
plot_shap_values_hierarchically_clustered(shap_values_f_c1_positive_and_c2_negative, 'C1 predicts positive and C2 negative')
plot_shap_values_hierarchically_clustered(shap_values_f_c1_negative_and_c2_positive, 'C1 predicts negative and C2 positive')
plot_shap_values_hierarchically_clustered(shap_values_f_c1_and_c2_different, 'C1 and C2 predict different labels')
# Out:
# Omitting plot because of ValueError: The condensed distance matrix must contain only finite values.
# Omitting plot because of ValueError: The condensed distance matrix must contain only finite values.

# %%
plot_shap_values_hierarchically_clustered(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2')
# Out:
# Omitting plot because of ValueError: The condensed distance matrix must contain only finite values.
