# %%
from scipy.special import logit
from shap.maskers import Independent
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from imldiff.plots import plot_shap_value_distribution, \
    plot_shap_partial_dependence, plot_shap_values_stacked, plot_shap_values_hierarchically_clustered, \
    plot_decision_boundary
import shap
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
shap.initjs()
np.seterr(all='ignore');
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# # Decision Tree vs. KNN
# Based on ["Classifier comparison"](https://scikit-learn.org/0.24/auto_examples/classification/plot_classifier_comparison.html) example of scikit-learn docs.

# %% [markdown]
# ## Create Models

# %%
feature_names = ['x1', 'x2']
X, y = make_classification(n_features=2, n_redundant=0, n_informative=2,
                           random_state=1, n_clusters_per_class=1)
rng = np.random.RandomState(2)
X += 2 * rng.uniform(size=X.shape)
X = StandardScaler().fit_transform(X)

# %%
m1 = DecisionTreeClassifier(max_depth=5)
m1.fit(X, y)
logit_from_log_proba = lambda Y: Y[:,1] - Y[:,0]
f1 = lambda X: logit_from_log_proba(m1.predict_log_proba(X))
c1 = lambda X: m1.predict_proba(X)[:,1]

# %%
m2 = KNeighborsClassifier(3)
m2.fit(X, y)
f2 = lambda X: logit(m2.predict_proba(X)[:,1])
c2 = lambda X: m2.predict_proba(X)[:,1]

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_decision_boundary(f1, X, 'Classifier 1 in margin space', feature_names, (-25, 25), fig, axs[0,0])
plot_decision_boundary(f2, X, 'Classifier 2 in margin space', feature_names, (-25, 25), fig, axs[1,0])
plot_decision_boundary(c1, X, 'Classifier 1 in probability space', feature_names, (0, 1), fig, axs[0,1])
plot_decision_boundary(c2, X, 'Classifier 2 in probability space', feature_names, (0, 1), fig, axs[1,1])
plt.show()
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %%
complement = lambda p: 1 - p
c1_positive_and_c2_negative = lambda p1, p2: p1 * complement(p2)
c1_negative_and_c2_positive = lambda p1, p2: complement(p1) * p2
c1_and_c2_different = lambda p1, p2: c1_positive_and_c2_negative(p1, p2) + c1_negative_and_c2_positive(p1, p2)
odds = lambda p: p / complement(p)
log_odds_ratio_from_proba = lambda p1, p2: np.log(odds(p1) / odds(p2))

c_c1_positive_and_c2_negative = lambda X: c1_positive_and_c2_negative(c1(X), c2(X))
c_c1_negative_and_c2_positive = lambda X: c1_negative_and_c2_positive(c1(X), c2(X))
c_c1_and_c2_different = lambda X: c1_and_c2_different(c1(X), c2(X))
f_log_odds_ratio_from_proba = lambda X: log_odds_ratio_from_proba(c1(X), c2(X))

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_decision_boundary(c_c1_positive_and_c2_negative, X, 'Probability: C1 predicts positive and C2 negative', feature_names, (0, 1), fig, axs[0,0])
plot_decision_boundary(c_c1_negative_and_c2_positive, X, 'Probability: C1 predicts negative and C2 positive', feature_names, (0, 1), fig, axs[0,1])
plot_decision_boundary(c_c1_and_c2_different, X, 'Probability: C1 and C2 predict different labels', feature_names, (0, 1), fig, axs[1,0])
plot_decision_boundary(f_log_odds_ratio_from_proba, X, 'Log odds ratio of C1 and C2, calculated from probabilities', feature_names, (-11, 11), fig, axs[1,1])
plt.show()
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %%
log_odds_ratio = lambda y1, y2: y1 - y2
f_log_odds_ratio = lambda X: log_odds_ratio(f1(X), f2(X))
plot_decision_boundary(f_log_odds_ratio, X, 'Log odds ratio of C1 and C2', feature_names, (-11, 11))

# %% [markdown]
# ## Generate Explanations

# %%
def make_shap_values(model, background_data, feature_names):
    masker = Independent(background_data)
    explainer = shap.Explainer(model, masker, feature_names=feature_names)
    shap_values = explainer(X)
    return shap_values

shap_values_f1 = make_shap_values(f1, X, feature_names)
shap_values_f2 = make_shap_values(f2, X, feature_names)
shap_values_c1 = make_shap_values(c1, X, feature_names)
shap_values_c2 = make_shap_values(c2, X, feature_names)

# %%
shap_values_c_c1_positive_and_c2_negative = make_shap_values(c_c1_positive_and_c2_negative, X, feature_names)
shap_values_c_c1_negative_and_c2_positive = make_shap_values(c_c1_negative_and_c2_positive, X, feature_names)
shap_values_c_c1_and_c2_different = make_shap_values(c_c1_and_c2_different, X, feature_names)
shap_values_f_log_odds_ratio = make_shap_values(f_log_odds_ratio, X, feature_names)

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### SHAP Value Distribution

# %%
plot_shap_value_distribution(shap_values_f1, 'Classifier 1 in margin space')
plot_shap_value_distribution(shap_values_f2, 'Classifier 2 in margin space')

# %%
plot_shap_value_distribution(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_value_distribution(shap_values_c2, 'Classifier 2 in probability space')

# %%
plot_shap_value_distribution(shap_values_c_c1_positive_and_c2_negative, 'Probability: C1 predicts positive and C2 negative')
plot_shap_value_distribution(shap_values_c_c1_negative_and_c2_positive, 'Probability: C1 predicts negative and C2 positive')
plot_shap_value_distribution(shap_values_c_c1_and_c2_different, 'Probability: C1 and C2 predict different labels')
plot_shap_value_distribution(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2')

# %% [markdown]
# ### Features' Partial Dependence Plots

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_f1, feature_names[0], 'Classifier 1 in margin space', (-8, 8), axs[0])
plot_shap_partial_dependence(shap_values_f2, feature_names[0], 'Classifier 2 in margin space', (-8, 8), axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_c1, feature_names[0], 'Classifier 1 in probability space', (-1, 1), axs[0])
plot_shap_partial_dependence(shap_values_c2, feature_names[0], 'Classifier 2 in probability space', (-1, 1), axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_c_c1_positive_and_c2_negative, feature_names[0], 'Probability: C1 predicts positive and C2 negative', (-1, 1), axs[0])
plot_shap_partial_dependence(shap_values_c_c1_negative_and_c2_positive, feature_names[0], 'Probability: C1 predicts negative and C2 positive', (-1, 1), axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_c_c1_and_c2_different, feature_names[0], 'Probability: C1 and C2 predict different labels', (-1, 1), axs[0])
plot_shap_partial_dependence(shap_values_f_log_odds_ratio, feature_names[0], 'Log odds ratio of C1 and C2', (-6, 6), axs[1])
plt.show()

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %%
# ordering = plot_shap_values_stacked(shap_values_f1, 'Classifier 1 in margin space')
# plot_shap_values_stacked(shap_values_f2, 'Classifier 2 in margin space');

# %%
ordering = plot_shap_values_stacked(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_values_stacked(shap_values_c2, 'Classifier 2 in probability space', ordering=ordering);
# Out:
# <div id='iPXLDISJ0LXT23FY9T7K7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 1 in probability space"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.5, "simIndex": 88.0, "features": {"0": {"effect": 0.51875, "value": ""}, "1": {"effect": -0.01874999999999999, "value": ""}}}, {"outValue": -0.5, "simIndex": 16.0, "features": {"0": {"effect": -0.49624999999999997, "value": ""}, "1": {"effect": -0.0037500000000000033, "value": ""}}}, {"outValue": -0.5, "simIndex": 31.0, "features": {"0": {"effect": -0.48125, "value": ""}, "1": {"effect": -0.01874999999999999, "value": ""}}}, {"outValue": 0.5, "simIndex": 68.0, "features": {"0": {"effect": 0.50375, "value": ""}, "1": {"effect": -0.003750000000000031, "value": ""}}}, {"outValue": 0.5, "simIndex": 89.0, "features": {"0": {"effect": 0.51875, "value": ""}, "1": {"effect": -0.01874999999999999, "value": ""}}}, {"outValue": 0.5, "simIndex": 69.0, "features": {"0": {"effect": 0.50375, "value": ""}, "1": {"effect": -0.003750000000000031, "value": ""}}}, {"outValue": -0.24999999999999997, "simIndex": 48.0, "features": {"0": {"effect": -0.18249999999999997, "value": ""}, "1": {"effect": -0.0675, "value": ""}}}, {"outValue": 0.5, "simIndex": 70.0, "features": {"0": {"effect": 0.50375, "value": ""}, "1": {"effect": -0.003750000000000031, "value": ""}}}, {"outValue": -0.5, "simIndex": 32.0, "features": {"0": {"effect": -0.48125, "value": ""}, "1": {"effect": -0.01874999999999999, "value": ""}}}, {"outValue": -0.24999999999999997, "simIndex": 49.0, "features": {"0": {"effect": -0.18249999999999997, "value": ""}, "1": {"effect": -0.0675, "value": ""}}}, {"outValue": -0.5, "simIndex": 33.0, "features": {"0": {"effect": -0.48125, "value": ""}, "1": {"effect": -0.01874999999999999, "value": ""}}}, {"outValue": -0.5, "simIndex": 30.0, "features": {"0": {"effect": -0.48125, "value": ""}, "1": {"effect": -0.01874999999999999, "value": ""}}}, {"outValue": -0.24999999999999997, "simIndex": 50.0, "features": {"0": {"effect": -0.18249999999999997, "value": ""}, "1": {"effect": -0.0675, "value": ""}}}, {"outValue": -0.5, "simIndex": 44.0, "features": {"0": {"effect": -0.39625, "value": ""}, "1": {"effect": -0.10375, "value": ""}}}, {"outValue": -0.49999999999999994, "simIndex": 42.0, "features": {"0": {"effect": -0.41124999999999995, "value": ""}, "1": {"effect": -0.08875000000000001, "value": ""}}}, {"outValue": -0.5, "simIndex": 34.0, "features": {"0": {"effect": -0.48125, "value": ""}, "1": {"effect": -0.01874999999999999, "value": ""}}}, {"outValue": 0.5, "simIndex": 67.0, "features": {"0": {"effect": 0.50375, "value": ""}, "1": {"effect": -0.003750000000000031, "value": ""}}}, {"outValue": 0.5, "simIndex": 90.0, "features": {"0": {"effect": 0.51875, "value": ""}, "1": {"effect": -0.01874999999999999, "value": ""}}}, {"outValue": 0.5, "simIndex": 54.0, "features": {"0": {"effect": 0.2250000000000001, "value": ""}, "1": {"effect": 0.2749999999999999, "value": ""}}}, {"outValue": 0.5, "simIndex": 71.0, "features": {"0": {"effect": 0.50375, "value": ""}, "1": {"effect": -0.003750000000000031, "value": ""}}}, {"outValue": 0.5, "simIndex": 55.0, "features": {"0": {"effect": 0.27375000000000005, "value": ""}, "1": {"effect": 0.22624999999999995, "value": ""}}}, {"outValue": -0.5, "simIndex": 17.0, "features": {"0": {"effect": -0.49624999999999997, "value": ""}, "1": {"effect": -0.0037500000000000033, "value": ""}}}, {"outValue": 0.5, "simIndex": 87.0, "features": {"0": {"effect": 0.51875, "value": ""}, "1": {"effect": -0.01874999999999999, "value": ""}}}, {"outValue": -0.49999999999999994, "simIndex": 5.0, "features": {"0": {"effect": -0.5449999999999999, "value": ""}, "1": {"effect": 0.044999999999999984, "value": ""}}}, {"outValue": -0.49999999999999994, "simIndex": 6.0, "features": {"0": {"effect": -0.5449999999999999, "value": ""}, "1": {"effect": 0.044999999999999984, "value": ""}}}, {"outValue": 0.5, "simIndex": 91.0, "features": {"0": { ...
# <div id='iXLN5S6M44JWEIJ2XEFSY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 2 in probability space"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.5033333333333334, "simIndex": 79.0, "features": {"0": {"effect": 0.5083333333333333, "value": ""}, "1": {"effect": -0.004999999999999949, "value": ""}}}, {"outValue": -0.4966666666666666, "simIndex": 9.0, "features": {"0": {"effect": -0.5016666666666666, "value": ""}, "1": {"effect": 0.005000000000000015, "value": ""}}}, {"outValue": -0.49666666666666665, "simIndex": 15.0, "features": {"0": {"effect": -0.48666666666666664, "value": ""}, "1": {"effect": -0.010000000000000021, "value": ""}}}, {"outValue": 0.5033333333333333, "simIndex": 85.0, "features": {"0": {"effect": 0.52, "value": ""}, "1": {"effect": -0.01666666666666672, "value": ""}}}, {"outValue": 0.5033333333333334, "simIndex": 83.0, "features": {"0": {"effect": 0.5150000000000001, "value": ""}, "1": {"effect": -0.011666666666666714, "value": ""}}}, {"outValue": 0.5033333333333333, "simIndex": 58.0, "features": {"0": {"effect": 0.4466666666666668, "value": ""}, "1": {"effect": 0.056666666666666476, "value": ""}}}, {"outValue": -0.4966666666666667, "simIndex": 40.0, "features": {"0": {"effect": -0.30333333333333345, "value": ""}, "1": {"effect": -0.19333333333333322, "value": ""}}}, {"outValue": 0.5033333333333333, "simIndex": 86.0, "features": {"0": {"effect": 0.52, "value": ""}, "1": {"effect": -0.01666666666666672, "value": ""}}}, {"outValue": -0.49666666666666665, "simIndex": 29.0, "features": {"0": {"effect": -0.4633333333333333, "value": ""}, "1": {"effect": -0.033333333333333326, "value": ""}}}, {"outValue": -0.16333333333333366, "simIndex": 47.0, "features": {"0": {"effect": -0.2233333333333335, "value": ""}, "1": {"effect": 0.05999999999999982, "value": ""}}}, {"outValue": -0.4966666666666667, "simIndex": 6.0, "features": {"0": {"effect": -0.5166666666666667, "value": ""}, "1": {"effect": 0.020000000000000046, "value": ""}}}, {"outValue": -0.49666666666666665, "simIndex": 35.0, "features": {"0": {"effect": -0.4533333333333333, "value": ""}, "1": {"effect": -0.043333333333333335, "value": ""}}}, {"outValue": -0.4966666666666666, "simIndex": 41.0, "features": {"0": {"effect": -0.3433333333333333, "value": ""}, "1": {"effect": -0.1533333333333333, "value": ""}}}, {"outValue": -0.16333333333333375, "simIndex": 51.0, "features": {"0": {"effect": -0.27166666666666694, "value": ""}, "1": {"effect": 0.1083333333333332, "value": ""}}}, {"outValue": -0.1633333333333337, "simIndex": 48.0, "features": {"0": {"effect": -0.24833333333333352, "value": ""}, "1": {"effect": 0.08499999999999983, "value": ""}}}, {"outValue": -0.49666666666666665, "simIndex": 28.0, "features": {"0": {"effect": -0.4666666666666667, "value": ""}, "1": {"effect": -0.02999999999999999, "value": ""}}}, {"outValue": 0.5033333333333334, "simIndex": 78.0, "features": {"0": {"effect": 0.5083333333333333, "value": ""}, "1": {"effect": -0.004999999999999949, "value": ""}}}, {"outValue": 0.5033333333333334, "simIndex": 75.0, "features": {"0": {"effect": 0.5016666666666667, "value": ""}, "1": {"effect": 0.0016666666666666496, "value": ""}}}, {"outValue": 0.5033333333333334, "simIndex": 54.0, "features": {"0": {"effect": 0.2733333333333334, "value": ""}, "1": {"effect": 0.23000000000000004, "value": ""}}}, {"outValue": 0.5033333333333334, "simIndex": 77.0, "features": {"0": {"effect": 0.5066666666666667, "value": ""}, "1": {"effect": -0.0033333333333332993, "value": ""}}}, {"outValue": 0.5033333333333334, "simIndex": 55.0, "features": {"0": {"effect": 0.37500000000000006, "value": ""}, "1": {"effect": 0.12833333333333335, "value": ""}}}, {"outValue": -0.49666666666666665, "simIndex": 19.0, "features": {"0": {"effect": -0.4816666666666667, "value": ""}, "1": {"effect": -0.014999999999999958, "value": ""}}}, {"outValue": 0.5033333333333334, "simIndex": 71.0, "features": {"0": {"effect": 0.496666666666 ...

# %%
plot_shap_values_stacked(shap_values_c_c1_positive_and_c2_negative, 'Probability: C1 predicts positive and C2 negative');
# Out:
# <div id='iBR951HJ9U6UF7XGQXVNH'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Probability: C1 predicts positive and C2 negative"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.022500000000000006, "simIndex": 37.0, "features": {"0": {"effect": -0.020000000000000004, "value": ""}, "1": {"effect": -0.002500000000000002, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 44.0, "features": {"0": {"effect": -0.02166666666666667, "value": ""}, "1": {"effect": -0.0008333333333333352, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 65.0, "features": {"0": {"effect": -0.02541666666666667, "value": ""}, "1": {"effect": 0.0029166666666666646, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 70.0, "features": {"0": {"effect": -0.027083333333333338, "value": ""}, "1": {"effect": 0.004583333333333332, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 71.0, "features": {"0": {"effect": -0.028750000000000005, "value": ""}, "1": {"effect": 0.006249999999999999, "value": ""}}}, {"outValue": -0.022500000000000013, "simIndex": 13.0, "features": {"0": {"effect": 0.04375000000000003, "value": ""}, "1": {"effect": -0.06625000000000004, "value": ""}}}, {"outValue": 0.22749999999999998, "simIndex": 4.0, "features": {"0": {"effect": 0.20249999999999999, "value": ""}, "1": {"effect": 0.024999999999999994, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 69.0, "features": {"0": {"effect": -0.027083333333333338, "value": ""}, "1": {"effect": 0.004583333333333332, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 91.0, "features": {"0": {"effect": -0.03416666666666667, "value": ""}, "1": {"effect": 0.011666666666666665, "value": ""}}}, {"outValue": 0.14416666666666644, "simIndex": 7.0, "features": {"0": {"effect": 0.18583333333333324, "value": ""}, "1": {"effect": -0.04166666666666678, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 33.0, "features": {"0": {"effect": -0.018750000000000003, "value": ""}, "1": {"effect": -0.0037500000000000016, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 78.0, "features": {"0": {"effect": -0.03125000000000001, "value": ""}, "1": {"effect": 0.00875, "value": ""}}}, {"outValue": 0.22749999999999998, "simIndex": 5.0, "features": {"0": {"effect": 0.21375000000000005, "value": ""}, "1": {"effect": 0.013749999999999943, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 17.0, "features": {"0": {"effect": 0.017499999999999988, "value": ""}, "1": {"effect": -0.039999999999999994, "value": ""}}}, {"outValue": -0.02250000000000001, "simIndex": 15.0, "features": {"0": {"effect": 0.026249999999999992, "value": ""}, "1": {"effect": -0.04875, "value": ""}}}, {"outValue": -0.02250000000000001, "simIndex": 83.0, "features": {"0": {"effect": -0.031666666666666676, "value": ""}, "1": {"effect": 0.009166666666666667, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 23.0, "features": {"0": {"effect": -0.01416666666666667, "value": ""}, "1": {"effect": -0.008333333333333337, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 42.0, "features": {"0": {"effect": -0.02041666666666667, "value": ""}, "1": {"effect": -0.0020833333333333355, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 12.0, "features": {"0": {"effect": 0.043750000000000025, "value": ""}, "1": {"effect": -0.06625000000000003, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 45.0, "features": {"0": {"effect": -0.02166666666666667, "value": ""}, "1": {"effect": -0.0008333333333333352, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 21.0, "features": {"0": {"effect": 0.006249999999999992, "value": ""}, "1": {"effect": -0.028749999999999998, "value": ""}}}, {"outValue": -0.022500000000000006, "simIndex": 62.0, "features": {"0": {"effect": -0.02416666666666667, "value": ""}, "1": {"effect": 0.0016666666666666635, "value": ""}} ...

# %%
plot_shap_values_stacked(shap_values_c_c1_negative_and_c2_positive, 'Probability: C1 predicts negative and C2 positive');
# Out:
# <div id='iJV9EOLRQE8IFXLPKKVNB'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Probability: C1 predicts negative and C2 positive"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.019166666666666665, "simIndex": 22.0, "features": {"0": {"effect": -0.03041666666666666, "value": ""}, "1": {"effect": 0.011249999999999996, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 32.0, "features": {"0": {"effect": -0.027083333333333334, "value": ""}, "1": {"effect": 0.007916666666666669, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 20.0, "features": {"0": {"effect": -0.03083333333333333, "value": ""}, "1": {"effect": 0.011666666666666667, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 74.0, "features": {"0": {"effect": -0.010833333333333332, "value": ""}, "1": {"effect": -0.008333333333333333, "value": ""}}}, {"outValue": -0.01916666666666667, "simIndex": 18.0, "features": {"0": {"effect": -0.0325, "value": ""}, "1": {"effect": 0.013333333333333332, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 68.0, "features": {"0": {"effect": -0.013333333333333332, "value": ""}, "1": {"effect": -0.005833333333333333, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 98.0, "features": {"0": {"effect": 0.08166666666666667, "value": ""}, "1": {"effect": -0.10083333333333333, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 73.0, "features": {"0": {"effect": -0.010833333333333332, "value": ""}, "1": {"effect": -0.008333333333333333, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 60.0, "features": {"0": {"effect": -0.01625, "value": ""}, "1": {"effect": -0.0029166666666666664, "value": ""}}}, {"outValue": 0.23083333333333333, "simIndex": 5.0, "features": {"0": {"effect": 0.14500000000000002, "value": ""}, "1": {"effect": 0.08583333333333333, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 6.0, "features": {"0": {"effect": -0.054166666666666655, "value": ""}, "1": {"effect": 0.03499999999999999, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 86.0, "features": {"0": {"effect": -0.0033333333333333305, "value": ""}, "1": {"effect": -0.015833333333333335, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 97.0, "features": {"0": {"effect": 0.05291666666666667, "value": ""}, "1": {"effect": -0.07208333333333333, "value": ""}}}, {"outValue": 0.31416666666666626, "simIndex": 2.0, "features": {"0": {"effect": 0.14208333333333312, "value": ""}, "1": {"effect": 0.17208333333333314, "value": ""}}}, {"outValue": 0.31416666666666626, "simIndex": 4.0, "features": {"0": {"effect": 0.18916666666666648, "value": ""}, "1": {"effect": 0.12499999999999979, "value": ""}}}, {"outValue": -0.01916666666666666, "simIndex": 54.0, "features": {"0": {"effect": -0.01708333333333333, "value": ""}, "1": {"effect": -0.002083333333333334, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 78.0, "features": {"0": {"effect": -0.009583333333333333, "value": ""}, "1": {"effect": -0.009583333333333333, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 15.0, "features": {"0": {"effect": -0.0375, "value": ""}, "1": {"effect": 0.018333333333333333, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 99.0, "features": {"0": {"effect": 0.0920833333333333, "value": ""}, "1": {"effect": -0.11124999999999996, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 46.0, "features": {"0": {"effect": -0.01875, "value": ""}, "1": {"effect": -0.0004166666666666659, "value": ""}}}, {"outValue": -0.01916666666666668, "simIndex": 100.0, "features": {"0": {"effect": 0.10750000000000003, "value": ""}, "1": {"effect": -0.1266666666666667, "value": ""}}}, {"outValue": -0.019166666666666665, "simIndex": 79.0, "features": {"0": {"effect": -0.009583333333333333, "value": ""}, "1": {"effect": -0.009583333333333333, "value": ""}}}, {"outValue": -0.0191666666666666 ...

# %%
plot_shap_values_stacked(shap_values_c_c1_and_c2_different, 'Probability: C1 and C2 predict different labels');
# Out:
# <div id='i8IMQJPP56GAE9C54ZDWU'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Probability: C1 and C2 predict different labels"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.04166666666666667, "simIndex": 71.0, "features": {"0": {"effect": -0.050416666666666665, "value": ""}, "1": {"effect": 0.008749999999999994, "value": ""}}}, {"outValue": -0.04166666666666667, "simIndex": 61.0, "features": {"0": {"effect": -0.04875, "value": ""}, "1": {"effect": 0.007083333333333327, "value": ""}}}, {"outValue": -0.04166666666666668, "simIndex": 82.0, "features": {"0": {"effect": -0.05625000000000001, "value": ""}, "1": {"effect": 0.014583333333333332, "value": ""}}}, {"outValue": -0.04166666666666667, "simIndex": 40.0, "features": {"0": {"effect": -0.03791666666666667, "value": ""}, "1": {"effect": -0.00375, "value": ""}}}, {"outValue": -0.041666666666666685, "simIndex": 92.0, "features": {"0": {"effect": -0.06125000000000001, "value": ""}, "1": {"effect": 0.01958333333333333, "value": ""}}}, {"outValue": -0.04166666666666667, "simIndex": 21.0, "features": {"0": {"effect": 0.030416666666666703, "value": ""}, "1": {"effect": -0.07208333333333337, "value": ""}}}, {"outValue": 0.20833333333333331, "simIndex": 11.0, "features": {"0": {"effect": 0.2841666666666667, "value": ""}, "1": {"effect": -0.07583333333333335, "value": ""}}}, {"outValue": -0.04166666666666667, "simIndex": 39.0, "features": {"0": {"effect": -0.03791666666666667, "value": ""}, "1": {"effect": -0.00375, "value": ""}}}, {"outValue": -0.04166666666666667, "simIndex": 72.0, "features": {"0": {"effect": -0.050416666666666665, "value": ""}, "1": {"effect": 0.008749999999999994, "value": ""}}}, {"outValue": 0.3749999999999999, "simIndex": 8.0, "features": {"0": {"effect": 0.3308333333333333, "value": ""}, "1": {"effect": 0.04416666666666655, "value": ""}}}, {"outValue": -0.04166666666666668, "simIndex": 96.0, "features": {"0": {"effect": -0.07291666666666669, "value": ""}, "1": {"effect": 0.03125000000000001, "value": ""}}}, {"outValue": -0.04166666666666668, "simIndex": 33.0, "features": {"0": {"effect": -0.03458333333333334, "value": ""}, "1": {"effect": -0.007083333333333337, "value": ""}}}, {"outValue": 0.20833333333333331, "simIndex": 10.0, "features": {"0": {"effect": 0.2666666666666667, "value": ""}, "1": {"effect": -0.058333333333333404, "value": ""}}}, {"outValue": 0.29166666666666624, "simIndex": 3.0, "features": {"0": {"effect": 0.15958333333333308, "value": ""}, "1": {"effect": 0.13208333333333316, "value": ""}}}, {"outValue": 0.2916666666666663, "simIndex": 6.0, "features": {"0": {"effect": 0.21541666666666648, "value": ""}, "1": {"effect": 0.0762499999999998, "value": ""}}}, {"outValue": -0.04166666666666667, "simIndex": 62.0, "features": {"0": {"effect": -0.04875, "value": ""}, "1": {"effect": 0.007083333333333327, "value": ""}}}, {"outValue": -0.04166666666666667, "simIndex": 25.0, "features": {"0": {"effect": -0.02375, "value": ""}, "1": {"effect": -0.01791666666666667, "value": ""}}}, {"outValue": -0.041666666666666685, "simIndex": 87.0, "features": {"0": {"effect": -0.05791666666666668, "value": ""}, "1": {"effect": 0.016249999999999997, "value": ""}}}, {"outValue": -0.04166666666666666, "simIndex": 12.0, "features": {"0": {"effect": 0.1358333333333334, "value": ""}, "1": {"effect": -0.17750000000000005, "value": ""}}}, {"outValue": -0.04166666666666667, "simIndex": 42.0, "features": {"0": {"effect": -0.04041666666666667, "value": ""}, "1": {"effect": -0.0012500000000000046, "value": ""}}}, {"outValue": -0.04166666666666666, "simIndex": 14.0, "features": {"0": {"effect": 0.11374999999999993, "value": ""}, "1": {"effect": -0.1554166666666666, "value": ""}}}, {"outValue": -0.04166666666666667, "simIndex": 30.0, "features": {"0": {"effect": -0.03375, "value": ""}, "1": {"effect": -0.007916666666666669, "value": ""}}}, {"outValue": -0.04166666666666667, "simIndex": 84.0, "features": {"0": {"effect": -0.05625,  ...

# %%
# plot_shap_values_stacked(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2');

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %%
# plot_shap_values_hierarchically_clustered(shap_values_f1, 'Classifier 1 in margin space')
# plot_shap_values_hierarchically_clustered(shap_values_f2, 'Classifier 2 in margin space')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_values_hierarchically_clustered(shap_values_c2, 'Classifier 2 in probability space')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_positive_and_c2_negative, 'Probability: C1 predicts positive and C2 negative')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_negative_and_c2_positive, 'Probability: C1 predicts negative and C2 positive')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_and_c2_different, 'Probability: C1 and C2 predict different labels')

# %%
# plot_shap_values_hierarchically_clustered(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2')
