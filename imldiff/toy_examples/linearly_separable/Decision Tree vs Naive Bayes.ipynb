# %%
from scipy.special import logit
from shap.maskers import Independent
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from plots import plot_shap_value_distribution, plot_shap_partial_dependence, plot_shap_values_stacked, \
    plot_shap_values_hierarchically_clustered, plot_decision_boundary
import shap
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
shap.initjs()
np.seterr(divide='ignore');
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# # Decision Tree vs. Naive Bayes
# Based on ["Classifier comparison"](https://scikit-learn.org/0.24/auto_examples/classification/plot_classifier_comparison.html) example of scikit-learn docs.

# %% [markdown]
# ## Create Models

# %%
feature_names = ['x1', 'x2']
X, y = make_classification(n_samples=500, n_features=2, n_redundant=0, n_informative=2,
                           random_state=1, n_clusters_per_class=1)
rng = np.random.RandomState(2)
X += 2 * rng.uniform(size=X.shape)
X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.8, random_state=42)

# %%
m1 = DecisionTreeClassifier(max_depth=5)
m1.fit(X_train, y_train)
logit_from_log_proba = lambda Y: Y[:,1] - Y[:,0]
f1 = lambda X: logit_from_log_proba(m1.predict_log_proba(X))
c1 = lambda X: m1.predict_proba(X)[:,1]

# %%
m2 = GaussianNB()
m2.fit(X_train, y_train)
f2 = lambda X: logit_from_log_proba(m2.predict_log_proba(X))
c2 = lambda X: m2.predict_proba(X)[:,1]

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_decision_boundary(f1, X, 'Classifier 1 in margin space', feature_names, (-8, 8), fig, axs[0,0], logit(y))
plot_decision_boundary(f2, X, 'Classifier 2 in margin space', feature_names, (-8, 8), fig, axs[1,0], logit(y))
plot_decision_boundary(c1, X, 'Classifier 1 in probability space', feature_names, (0, 1), fig, axs[0,1], y)
plot_decision_boundary(c2, X, 'Classifier 2 in probability space', feature_names, (0, 1), fig, axs[1,1], y)
plt.show()
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %%
complement = lambda p: 1 - p
c1_positive_and_c2_negative = lambda p1, p2: p1 * complement(p2)
c1_negative_and_c2_positive = lambda p1, p2: complement(p1) * p2
c1_and_c2_different = lambda p1, p2: c1_positive_and_c2_negative(p1, p2) + c1_negative_and_c2_positive(p1, p2)
odds = lambda p: p / complement(p)
log_odds_ratio_from_proba = lambda p1, p2: np.log(odds(p1) / odds(p2))

c_c1_positive_and_c2_negative = lambda X: c1_positive_and_c2_negative(c1(X), c2(X))
c_c1_negative_and_c2_positive = lambda X: c1_negative_and_c2_positive(c1(X), c2(X))
c_c1_and_c2_different = lambda X: c1_and_c2_different(c1(X), c2(X))
f_log_odds_ratio_from_proba = lambda X: log_odds_ratio_from_proba(c1(X), c2(X))

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_decision_boundary(c_c1_positive_and_c2_negative, X, 'Probability: C1 predicts positive and C2 negative', feature_names, (0, 1), fig, axs[0,0], y)
plot_decision_boundary(c_c1_negative_and_c2_positive, X, 'Probability: C1 predicts negative and C2 positive', feature_names, (0, 1), fig, axs[0,1], y)
plot_decision_boundary(c_c1_and_c2_different, X, 'Probability: C1 and C2 predict different labels', feature_names, (0, 1), fig, axs[1,0], y)
plot_decision_boundary(f_log_odds_ratio_from_proba, X, 'Log odds ratio of C1 and C2, calculated from probabilities', feature_names, (-8, 8), fig, axs[1,1], logit(y))
plt.show()
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %%
log_odds_ratio = lambda y1, y2: y1 - y2
f_log_odds_ratio = lambda X: log_odds_ratio(f1(X), f2(X))
plot_decision_boundary(f_log_odds_ratio, X, 'Log odds ratio of C1 and C2', feature_names, (-8, 8), z=logit(y))
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %% [markdown]
# ## Generate Explanations

# %%
def make_shap_values(model, background_data, feature_names):
    masker = Independent(background_data)
    explainer = shap.Explainer(model, masker, feature_names=feature_names)
    shap_values = explainer(X)
    return shap_values

shap_values_f1 = make_shap_values(f1, X, feature_names)
shap_values_f2 = make_shap_values(f2, X, feature_names)
shap_values_c1 = make_shap_values(c1, X, feature_names)
shap_values_c2 = make_shap_values(c2, X, feature_names)

# %%
shap_values_c_c1_positive_and_c2_negative = make_shap_values(c_c1_positive_and_c2_negative, X, feature_names)
shap_values_c_c1_negative_and_c2_positive = make_shap_values(c_c1_negative_and_c2_positive, X, feature_names)
shap_values_c_c1_and_c2_different = make_shap_values(c_c1_and_c2_different, X, feature_names)
shap_values_f_log_odds_ratio = make_shap_values(f_log_odds_ratio, X, feature_names)

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### SHAP Value Distribution

# %%
plot_shap_value_distribution(shap_values_f1, 'Classifier 1 in margin space')
plot_shap_value_distribution(shap_values_f2, 'Classifier 2 in margin space')

# %%
plot_shap_value_distribution(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_value_distribution(shap_values_c2, 'Classifier 2 in probability space')

# %%
plot_shap_value_distribution(shap_values_c_c1_positive_and_c2_negative, 'Probability: C1 predicts positive and C2 negative')
plot_shap_value_distribution(shap_values_c_c1_negative_and_c2_positive, 'Probability: C1 predicts negative and C2 positive')
plot_shap_value_distribution(shap_values_c_c1_and_c2_different, 'Probability: C1 and C2 predict different labels')
plot_shap_value_distribution(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2')

# %% [markdown]
# ### Features' Partial Dependence Plots

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_f1, feature_names[0], 'Classifier 1 in margin space', (-8, 8), axs[0])
plot_shap_partial_dependence(shap_values_f2, feature_names[0], 'Classifier 2 in margin space', (-8, 8), axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_c1, feature_names[0], 'Classifier 1 in probability space', (-1, 1), axs[0])
plot_shap_partial_dependence(shap_values_c2, feature_names[0], 'Classifier 2 in probability space', (-1, 1), axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_c_c1_positive_and_c2_negative, feature_names[0], 'Probability: C1 predicts positive and C2 negative', (-1, 1), axs[0])
plot_shap_partial_dependence(shap_values_c_c1_negative_and_c2_positive, feature_names[0], 'Probability: C1 predicts negative and C2 positive', (-1, 1), axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_c_c1_and_c2_different, feature_names[0], 'Probability: C1 and C2 predict different labels', (-1, 1), axs[0])
plot_shap_partial_dependence(shap_values_f_log_odds_ratio, feature_names[0], 'Log odds ratio of C1 and C2', (-6, 6), axs[1])
plt.show()

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %%
# ordering = plot_shap_values_stacked(shap_values_f1, 'Classifier 1 in margin space')
plot_shap_values_stacked(shap_values_f2, 'Classifier 2 in margin space');
# Out:
# <div id='i0NXS5OEEE2LYLLIL90JW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 2 in margin space"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 8.364510627926133, "simIndex": 2.0, "features": {"0": {"effect": 0.1981113097118676, "value": ""}, "1": {"effect": 8.166399318214266, "value": ""}}}, {"outValue": -2.316851807335241, "simIndex": 378.0, "features": {"0": {"effect": -0.1169177548542808, "value": ""}, "1": {"effect": -2.1999340524809603, "value": ""}}}, {"outValue": 0.7472662707370497, "simIndex": 191.0, "features": {"0": {"effect": -0.17952363156440443, "value": ""}, "1": {"effect": 0.9267899023014541, "value": ""}}}, {"outValue": 1.2335485120725749, "simIndex": 176.0, "features": {"0": {"effect": -0.1447810314934619, "value": ""}, "1": {"effect": 1.3783295435660368, "value": ""}}}, {"outValue": -2.1927883683948464, "simIndex": 367.0, "features": {"0": {"effect": -0.08942446409702087, "value": ""}, "1": {"effect": -2.1033639042978254, "value": ""}}}, {"outValue": -2.3813412725462824, "simIndex": 370.0, "features": {"0": {"effect": -0.2058019972795649, "value": ""}, "1": {"effect": -2.1755392752667175, "value": ""}}}, {"outValue": 2.743077116090067, "simIndex": 105.0, "features": {"0": {"effect": -0.08452133140989623, "value": ""}, "1": {"effect": 2.827598447499963, "value": ""}}}, {"outValue": -0.6091318813924677, "simIndex": 251.0, "features": {"0": {"effect": -0.1566522307683139, "value": ""}, "1": {"effect": -0.45247965062415374, "value": ""}}}, {"outValue": -1.174246618514703, "simIndex": 317.0, "features": {"0": {"effect": 0.11887755914874676, "value": ""}, "1": {"effect": -1.2931241776634497, "value": ""}}}, {"outValue": 7.266813466799788, "simIndex": 5.0, "features": {"0": {"effect": 0.29240342307620837, "value": ""}, "1": {"effect": 6.97441004372358, "value": ""}}}, {"outValue": 3.1399919037065236, "simIndex": 83.0, "features": {"0": {"effect": -0.07183840715992768, "value": ""}, "1": {"effect": 3.211830310866451, "value": ""}}}, {"outValue": 2.619378218702928, "simIndex": 93.0, "features": {"0": {"effect": -0.07614558399316303, "value": ""}, "1": {"effect": 2.695523802696091, "value": ""}}}, {"outValue": -2.7501945631258633, "simIndex": 398.0, "features": {"0": {"effect": -0.11186264271339792, "value": ""}, "1": {"effect": -2.6383319204124653, "value": ""}}}, {"outValue": 3.412418349063374, "simIndex": 69.0, "features": {"0": {"effect": -0.11627057161315874, "value": ""}, "1": {"effect": 3.5286889206765326, "value": ""}}}, {"outValue": -2.336231271457735, "simIndex": 374.0, "features": {"0": {"effect": -0.0646766731246273, "value": ""}, "1": {"effect": -2.271554598333108, "value": ""}}}, {"outValue": -3.322695066053664, "simIndex": 414.0, "features": {"0": {"effect": -0.07527767030138616, "value": ""}, "1": {"effect": -3.2474173957522776, "value": ""}}}, {"outValue": -0.5426969596367209, "simIndex": 253.0, "features": {"0": {"effect": -0.1553846841391887, "value": ""}, "1": {"effect": -0.3873122754975322, "value": ""}}}, {"outValue": -6.222106923555046, "simIndex": 487.0, "features": {"0": {"effect": -0.13862483253385935, "value": ""}, "1": {"effect": -6.083482091021186, "value": ""}}}, {"outValue": -1.2273897699346743, "simIndex": 293.0, "features": {"0": {"effect": -0.09936085114958695, "value": ""}, "1": {"effect": -1.1280289187850874, "value": ""}}}, {"outValue": 0.7006815507369133, "simIndex": 208.0, "features": {"0": {"effect": -0.02134288731102693, "value": ""}, "1": {"effect": 0.7220244380479403, "value": ""}}}, {"outValue": -3.8074933893947533, "simIndex": 439.0, "features": {"0": {"effect": 0.14371684230919538, "value": ""}, "1": {"effect": -3.9512102317039486, "value": ""}}}, {"outValue": -3.838745980969775, "simIndex": 438.0, "features": {"0": {"effect": 0.0654099867030401, "value": ""}, "1": {"effect": -3.904155967672815, "value": ""}}}, {"outValue": 5.446696603746737, "simIndex": 34.0, "features": {"0": {"effect": 0.19925215406839214, ...

# %%
ordering = plot_shap_values_stacked(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_values_stacked(shap_values_c2, 'Classifier 2 in probability space', ordering=ordering);
# Out:
# <div id='iMXUN9076XTK014FI91JE'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 1 in probability space"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.49666666666666653, "simIndex": 52.0, "features": {"0": {"effect": -0.07666666666666672, "value": ""}, "1": {"effect": 0.5733333333333333, "value": ""}}}, {"outValue": -0.3033333333333339, "simIndex": 404.0, "features": {"0": {"effect": 0.09533333333333316, "value": ""}, "1": {"effect": -0.39866666666666706, "value": ""}}}, {"outValue": 0.4966666666666665, "simIndex": 181.0, "features": {"0": {"effect": 0.4033333333333332, "value": ""}, "1": {"effect": 0.09333333333333327, "value": ""}}}, {"outValue": 0.4966666666666665, "simIndex": 204.0, "features": {"0": {"effect": 0.34333333333333327, "value": ""}, "1": {"effect": 0.1533333333333332, "value": ""}}}, {"outValue": -0.3033333333333339, "simIndex": 310.0, "features": {"0": {"effect": -0.039666666666666905, "value": ""}, "1": {"effect": -0.263666666666667, "value": ""}}}, {"outValue": 0.4966666666666664, "simIndex": 163.0, "features": {"0": {"effect": 0.5553333333333332, "value": ""}, "1": {"effect": -0.05866666666666681, "value": ""}}}, {"outValue": 0.49666666666666665, "simIndex": 107.0, "features": {"0": {"effect": -0.0616666666666667, "value": ""}, "1": {"effect": 0.5583333333333333, "value": ""}}}, {"outValue": 0.4966666666666665, "simIndex": 205.0, "features": {"0": {"effect": 0.34333333333333327, "value": ""}, "1": {"effect": 0.1533333333333332, "value": ""}}}, {"outValue": -0.5033333333333335, "simIndex": 328.0, "features": {"0": {"effect": -0.15466666666666673, "value": ""}, "1": {"effect": -0.3486666666666668, "value": ""}}}, {"outValue": 0.49666666666666653, "simIndex": 53.0, "features": {"0": {"effect": -0.07666666666666672, "value": ""}, "1": {"effect": 0.5733333333333333, "value": ""}}}, {"outValue": 0.4966666666666666, "simIndex": 123.0, "features": {"0": {"effect": 0.05083333333333345, "value": ""}, "1": {"effect": 0.44583333333333314, "value": ""}}}, {"outValue": 0.4966666666666666, "simIndex": 124.0, "features": {"0": {"effect": 0.05083333333333345, "value": ""}, "1": {"effect": 0.44583333333333314, "value": ""}}}, {"outValue": -0.5033333333333336, "simIndex": 460.0, "features": {"0": {"effect": 0.0733333333333333, "value": ""}, "1": {"effect": -0.5766666666666669, "value": ""}}}, {"outValue": 0.4966666666666666, "simIndex": 143.0, "features": {"0": {"effect": 0.07333333333333336, "value": ""}, "1": {"effect": 0.42333333333333323, "value": ""}}}, {"outValue": 0.4966666666666666, "simIndex": 125.0, "features": {"0": {"effect": 0.05083333333333345, "value": ""}, "1": {"effect": 0.44583333333333314, "value": ""}}}, {"outValue": -0.5033333333333335, "simIndex": 430.0, "features": {"0": {"effect": 0.0508333333333334, "value": ""}, "1": {"effect": -0.5541666666666669, "value": ""}}}, {"outValue": 0.4966666666666665, "simIndex": 206.0, "features": {"0": {"effect": 0.34333333333333327, "value": ""}, "1": {"effect": 0.1533333333333332, "value": ""}}}, {"outValue": -0.5033333333333336, "simIndex": 461.0, "features": {"0": {"effect": 0.0733333333333333, "value": ""}, "1": {"effect": -0.5766666666666669, "value": ""}}}, {"outValue": -0.3033333333333339, "simIndex": 403.0, "features": {"0": {"effect": 0.09533333333333316, "value": ""}, "1": {"effect": -0.39866666666666706, "value": ""}}}, {"outValue": 0.3299999999999995, "simIndex": 232.0, "features": {"0": {"effect": 0.23749999999999988, "value": ""}, "1": {"effect": 0.09249999999999964, "value": ""}}}, {"outValue": -0.5033333333333335, "simIndex": 358.0, "features": {"0": {"effect": -0.07666666666666677, "value": ""}, "1": {"effect": -0.42666666666666675, "value": ""}}}, {"outValue": -0.5033333333333335, "simIndex": 359.0, "features": {"0": {"effect": -0.07666666666666677, "value": ""}, "1": {"effect": -0.42666666666666675, "value": ""}}}, {"outValue": 0.49666666666666653, "simIndex": 54.0, "features": {"0": { ...
# <div id='i8WZ600A5ZX7NHV9YFD14'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 2 in probability space"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.471834007358592, "simIndex": 468.0, "features": {"0": {"effect": 0.011289271982461824, "value": ""}, "1": {"effect": 0.46054473537613017, "value": ""}}}, {"outValue": -0.4203128012811659, "simIndex": 130.0, "features": {"0": {"effect": -0.01132893925926648, "value": ""}, "1": {"effect": -0.4089838620218994, "value": ""}}}, {"outValue": 0.19299443504862923, "simIndex": 304.0, "features": {"0": {"effect": -0.025374766210362887, "value": ""}, "1": {"effect": 0.21836920125899212, "value": ""}}}, {"outValue": 0.27979063696461837, "simIndex": 326.0, "features": {"0": {"effect": -0.016980311315768992, "value": ""}, "1": {"effect": 0.29677094828038736, "value": ""}}}, {"outValue": -0.4078008620935534, "simIndex": 134.0, "features": {"0": {"effect": -0.008914103279785701, "value": ""}, "1": {"effect": -0.3988867588137677, "value": ""}}}, {"outValue": -0.42635347293483256, "simIndex": 131.0, "features": {"0": {"effect": -0.02031152725499802, "value": ""}, "1": {"effect": -0.40604194567983454, "value": ""}}}, {"outValue": 0.4220552361842027, "simIndex": 430.0, "features": {"0": {"effect": -0.005218834750267409, "value": ""}, "1": {"effect": 0.4272740709344701, "value": ""}}}, {"outValue": -0.12837263837380417, "simIndex": 250.0, "features": {"0": {"effect": -0.0263721968693299, "value": ""}, "1": {"effect": -0.10200044150447427, "value": ""}}}, {"outValue": -0.25354025557987375, "simIndex": 207.0, "features": {"0": {"effect": 0.018318142685526395, "value": ""}, "1": {"effect": -0.27185839826540015, "value": ""}}}, {"outValue": 0.47145407208298806, "simIndex": 482.0, "features": {"0": {"effect": 0.016233300925426575, "value": ""}, "1": {"effect": 0.4552207711575615, "value": ""}}}, {"outValue": 0.43786637314641735, "simIndex": 423.0, "features": {"0": {"effect": -0.0038118085805390334, "value": ""}, "1": {"effect": 0.4416781817269564, "value": ""}}}, {"outValue": 0.4158451915499027, "simIndex": 393.0, "features": {"0": {"effect": -0.004784008480524959, "value": ""}, "1": {"effect": 0.42062920003042764, "value": ""}}}, {"outValue": -0.4554269509790263, "simIndex": 103.0, "features": {"0": {"effect": -0.009064083289617386, "value": ""}, "1": {"effect": -0.4463628676894089, "value": ""}}}, {"outValue": 0.4457984159015364, "simIndex": 435.0, "features": {"0": {"effect": -0.006423868135456978, "value": ""}, "1": {"effect": 0.4522222840369934, "value": ""}}}, {"outValue": -0.4221605102264484, "simIndex": 126.0, "features": {"0": {"effect": -0.0058435799157252055, "value": ""}, "1": {"effect": -0.4163169303107232, "value": ""}}}, {"outValue": -0.48571352371674203, "simIndex": 91.0, "features": {"0": {"effect": -0.004689263133409505, "value": ""}, "1": {"effect": -0.48102426058333253, "value": ""}}}, {"outValue": -0.11233245560690408, "simIndex": 247.0, "features": {"0": {"effect": -0.02630461457222033, "value": ""}, "1": {"effect": -0.08602784103468375, "value": ""}}}, {"outValue": -0.5255521033740409, "simIndex": 25.0, "features": {"0": {"effect": -0.006462765686520433, "value": ""}, "1": {"effect": -0.5190893376875205, "value": ""}}}, {"outValue": -0.26399437633383527, "simIndex": 193.0, "features": {"0": {"effect": -0.014423549414536385, "value": ""}, "1": {"effect": -0.2495708269192989, "value": ""}}}, {"outValue": 0.18352714088298266, "simIndex": 299.0, "features": {"0": {"effect": -0.0019722480696376388, "value": ""}, "1": {"effect": 0.1854993889526203, "value": ""}}}, {"outValue": -0.5015201947752156, "simIndex": 18.0, "features": {"0": {"effect": 0.010094789570085916, "value": ""}, "1": {"effect": -0.5116149843453015, "value": ""}}}, {"outValue": -0.5023133206466275, "simIndex": 73.0, "features": {"0": {"effect": 0.005087319659543232, "value": ""}, "1": {"effect": -0.5074006403061707, "value": ""}}}, {"outValue": 0.4685146451 ...

# %%
plot_shap_values_stacked(shap_values_c_c1_positive_and_c2_negative, 'Probability: C1 predicts positive and C2 negative');
# Out:
# <div id='iO42I3AG6VX9YQIFN3WWU'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Probability: C1 predicts positive and C2 negative"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.09435255622770278, "simIndex": 254.0, "features": {"0": {"effect": -0.03968647120145156, "value": ""}, "1": {"effect": -0.05466608502625122, "value": ""}}}, {"outValue": 0.08392453575015296, "simIndex": 123.0, "features": {"0": {"effect": 0.05231428278143502, "value": ""}, "1": {"effect": 0.031610252968717945, "value": ""}}}, {"outValue": 0.1844870160822592, "simIndex": 53.0, "features": {"0": {"effect": 0.1641682837000739, "value": ""}, "1": {"effect": 0.02031873238218529, "value": ""}}}, {"outValue": 0.09769081416626815, "simIndex": 84.0, "features": {"0": {"effect": 0.08746521165359203, "value": ""}, "1": {"effect": 0.010225602512676124, "value": ""}}}, {"outValue": 0.08142214791263003, "simIndex": 163.0, "features": {"0": {"effect": -0.0060057635172197366, "value": ""}, "1": {"effect": 0.08742791142984976, "value": ""}}}, {"outValue": 0.8038349240657214, "simIndex": 5.0, "features": {"0": {"effect": 0.4660886087571999, "value": ""}, "1": {"effect": 0.33774631530852156, "value": ""}}}, {"outValue": -0.04457378505331266, "simIndex": 177.0, "features": {"0": {"effect": -0.023365813714109736, "value": ""}, "1": {"effect": -0.021207971339202922, "value": ""}}}, {"outValue": 0.5058540895046928, "simIndex": 36.0, "features": {"0": {"effect": 0.19985881628579066, "value": ""}, "1": {"effect": 0.30599527321890213, "value": ""}}}, {"outValue": -0.09454289341532261, "simIndex": 444.0, "features": {"0": {"effect": -0.09922180847877814, "value": ""}, "1": {"effect": 0.004678915063455521, "value": ""}}}, {"outValue": -0.09397262095209924, "simIndex": 234.0, "features": {"0": {"effect": -0.04041003967706301, "value": ""}, "1": {"effect": -0.05356258127503623, "value": ""}}}, {"outValue": -0.06038492201552946, "simIndex": 361.0, "features": {"0": {"effect": 0.022571719253023717, "value": ""}, "1": {"effect": -0.08295664126855318, "value": ""}}}, {"outValue": -0.038363740419014275, "simIndex": 378.0, "features": {"0": {"effect": 0.023471401680044066, "value": ""}, "1": {"effect": -0.06183514209905834, "value": ""}}}, {"outValue": -0.09454289341532264, "simIndex": 314.0, "features": {"0": {"effect": 0.03251996676868567, "value": ""}, "1": {"effect": -0.1270628601840083, "value": ""}}}, {"outValue": -0.06831696477064969, "simIndex": 355.0, "features": {"0": {"effect": 0.034022919760056135, "value": ""}, "1": {"effect": -0.10233988453070583, "value": ""}}}, {"outValue": 0.7996419613573371, "simIndex": 4.0, "features": {"0": {"effect": 0.024724378009744405, "value": ""}, "1": {"effect": 0.7749175833475928, "value": ""}}}, {"outValue": -0.09454289341532263, "simIndex": 350.0, "features": {"0": {"effect": 0.02165649673886859, "value": ""}, "1": {"effect": -0.11619939015419121, "value": ""}}}, {"outValue": 0.48981390673779257, "simIndex": 37.0, "features": {"0": {"effect": 0.19544046283395575, "value": ""}, "1": {"effect": 0.2943734439038368, "value": ""}}}, {"outValue": -0.09454289341532263, "simIndex": 302.0, "features": {"0": {"effect": 0.03361255031345747, "value": ""}, "1": {"effect": -0.1281554437287801, "value": ""}}}, {"outValue": 0.052660850760686384, "simIndex": 93.0, "features": {"0": {"effect": 0.047843570179959174, "value": ""}, "1": {"effect": 0.0048172805807272095, "value": ""}}}, {"outValue": 0.14587144297070168, "simIndex": 76.0, "features": {"0": {"effect": 0.07002014478648072, "value": ""}, "1": {"effect": 0.07585129818422096, "value": ""}}}, {"outValue": -0.09454289341532263, "simIndex": 258.0, "features": {"0": {"effect": -0.039267235996361956, "value": ""}, "1": {"effect": -0.05527565741896067, "value": ""}}}, {"outValue": -0.09454289341532263, "simIndex": 269.0, "features": {"0": {"effect": -0.03866091058165575, "value": ""}, "1": {"effect": -0.055881982833666875, "value": ""}}}, {"outValue": -0 ...

# %%
plot_shap_values_stacked(shap_values_c_c1_negative_and_c2_positive, 'Probability: C1 predicts negative and C2 positive');
# Out:
# <div id='i5KD7R3G65NGP1UVMA4WM'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Probability: C1 predicts negative and C2 positive"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.1191852155357792, "simIndex": 85.0, "features": {"0": {"effect": 0.04826946744767603, "value": ""}, "1": {"effect": -0.16745468298345523, "value": ""}}}, {"outValue": -0.03305493219767997, "simIndex": 403.0, "features": {"0": {"effect": -0.05434798981116492, "value": ""}, "1": {"effect": 0.021293057613484948, "value": ""}}}, {"outValue": -0.11918521553577918, "simIndex": 477.0, "features": {"0": {"effect": -0.26453981584362285, "value": ""}, "1": {"effect": 0.14535460030784367, "value": ""}}}, {"outValue": -0.11918521553577915, "simIndex": 473.0, "features": {"0": {"effect": -0.2728484329955097, "value": ""}, "1": {"effect": 0.15366321745973055, "value": ""}}}, {"outValue": -0.023045380847590245, "simIndex": 192.0, "features": {"0": {"effect": 0.024746799869661176, "value": ""}, "1": {"effect": -0.04779218071725142, "value": ""}}}, {"outValue": -0.11918521553577918, "simIndex": 422.0, "features": {"0": {"effect": -0.10955625183113217, "value": ""}, "1": {"effect": -0.009628963704647015, "value": ""}}}, {"outValue": -0.11918521553577918, "simIndex": 175.0, "features": {"0": {"effect": 0.033082018202288066, "value": ""}, "1": {"effect": -0.15226723373806725, "value": ""}}}, {"outValue": -0.1191852155357792, "simIndex": 426.0, "features": {"0": {"effect": -0.16984671391687325, "value": ""}, "1": {"effect": 0.05066149838109406, "value": ""}}}, {"outValue": 0.15525018433813662, "simIndex": 355.0, "features": {"0": {"effect": 0.07376300087341484, "value": ""}, "1": {"effect": 0.08148718346472178, "value": ""}}}, {"outValue": -0.11918521553577918, "simIndex": 65.0, "features": {"0": {"effect": 0.052489927915029655, "value": ""}, "1": {"effect": -0.17167514345080884, "value": ""}}}, {"outValue": -0.11918521553577918, "simIndex": 317.0, "features": {"0": {"effect": -0.03207342266084871, "value": ""}, "1": {"effect": -0.08711179287493047, "value": ""}}}, {"outValue": -0.11918521553577918, "simIndex": 316.0, "features": {"0": {"effect": -0.03214594013381467, "value": ""}, "1": {"effect": -0.08703927540196452, "value": ""}}}, {"outValue": -0.04663651106101595, "simIndex": 213.0, "features": {"0": {"effect": -0.04987744985426533, "value": ""}, "1": {"effect": 0.003240938793249378, "value": ""}}}, {"outValue": -0.11918521553577918, "simIndex": 291.0, "features": {"0": {"effect": -0.0457342817087337, "value": ""}, "1": {"effect": -0.07345093382704548, "value": ""}}}, {"outValue": -0.11918521553577918, "simIndex": 323.0, "features": {"0": {"effect": -0.031952535239314905, "value": ""}, "1": {"effect": -0.08723268029646428, "value": ""}}}, {"outValue": -0.07692308379873164, "simIndex": 243.0, "features": {"0": {"effect": -0.03386609972787451, "value": ""}, "1": {"effect": -0.04305698407085713, "value": ""}}}, {"outValue": -0.11918521553577918, "simIndex": 423.0, "features": {"0": {"effect": -0.17419748507159852, "value": ""}, "1": {"effect": 0.055012269535819336, "value": ""}}}, {"outValue": -0.11676166345603062, "simIndex": 277.0, "features": {"0": {"effect": -0.04618354870639652, "value": ""}, "1": {"effect": -0.0705781147496341, "value": ""}}}, {"outValue": 0.0919998077601852, "simIndex": 375.0, "features": {"0": {"effect": -0.061913312567910175, "value": ""}, "1": {"effect": 0.15391312032809537, "value": ""}}}, {"outValue": -0.0006014161463173684, "simIndex": 490.0, "features": {"0": {"effect": -0.16945210328315774, "value": ""}, "1": {"effect": 0.16885068713684037, "value": ""}}}, {"outValue": -0.09272975485720522, "simIndex": 168.0, "features": {"0": {"effect": 0.04749422024039061, "value": ""}, "1": {"effect": -0.14022397509759582, "value": ""}}}, {"outValue": -0.09352288072861709, "simIndex": 170.0, "features": {"0": {"effect": 0.043093075744553976, "value": ""}, "1": {"effect": -0.13661595647317107, "value ...

# %%
plot_shap_values_stacked(shap_values_c_c1_and_c2_different, 'Probability: C1 and C2 predict different labels');
# Out:
# <div id='i0AQSR46PTTO6LI6DO8C0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Probability: C1 and C2 predict different labels"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.21353777176348204, "simIndex": 447.0, "features": {"0": {"effect": 0.008582996246224397, "value": ""}, "1": {"effect": -0.22212076800970643, "value": ""}}}, {"outValue": 0.05086960355247197, "simIndex": 183.0, "features": {"0": {"effect": -0.002033707029730422, "value": ""}, "1": {"effect": 0.05290331058220239, "value": ""}}}, {"outValue": 0.06530180054647997, "simIndex": 122.0, "features": {"0": {"effect": -0.10037153214354896, "value": ""}, "1": {"effect": 0.16567333269002893, "value": ""}}}, {"outValue": -0.02149440136951114, "simIndex": 112.0, "features": {"0": {"effect": -0.18538322134191787, "value": ""}, "1": {"effect": 0.16388881997240673, "value": ""}}}, {"outValue": 0.05837676706503925, "simIndex": 212.0, "features": {"0": {"effect": 0.01874103635244115, "value": ""}, "1": {"effect": 0.0396357307125981, "value": ""}}}, {"outValue": 0.6846497085299422, "simIndex": 57.0, "features": {"0": {"effect": 0.35653235692606766, "value": ""}, "1": {"effect": 0.32811735160387456, "value": ""}}}, {"outValue": -0.16375900058909193, "simIndex": 324.0, "features": {"0": {"effect": 0.009716204488178296, "value": ""}, "1": {"effect": -0.1734752050772702, "value": ""}}}, {"outValue": 0.38666887396891353, "simIndex": 73.0, "features": {"0": {"effect": 0.030012102368917368, "value": ""}, "1": {"effect": 0.35665677159999615, "value": ""}}}, {"outValue": 0.060707290922813906, "simIndex": 202.0, "features": {"0": {"effect": -0.02545880760536337, "value": ""}, "1": {"effect": 0.08616609852817728, "value": ""}}}, {"outValue": -0.2131578364878785, "simIndex": 441.0, "features": {"0": {"effect": 0.012079888237966574, "value": ""}, "1": {"effect": -0.22523772472584508, "value": ""}}}, {"outValue": -0.17957013755130868, "simIndex": 424.0, "features": {"0": {"effect": -0.009501703407825038, "value": ""}, "1": {"effect": -0.17006843414348366, "value": ""}}}, {"outValue": -0.15754895595479354, "simIndex": 281.0, "features": {"0": {"effect": -0.008674538453770586, "value": ""}, "1": {"effect": -0.14887441750102295, "value": ""}}}, {"outValue": -0.14117940447633864, "simIndex": 258.0, "features": {"0": {"effect": -0.01735748308557969, "value": ""}, "1": {"effect": -0.12382192139075895, "value": ""}}}, {"outValue": -0.18750218030642896, "simIndex": 413.0, "features": {"0": {"effect": -0.011711361948677598, "value": ""}, "1": {"effect": -0.17579081835775134, "value": ""}}}, {"outValue": 0.6804567458215579, "simIndex": 2.0, "features": {"0": {"effect": -0.007228157229570639, "value": ""}, "1": {"effect": 0.6876849030511285, "value": ""}}}, {"outValue": -0.17146597721405432, "simIndex": 290.0, "features": {"0": {"effect": -0.012209602989005919, "value": ""}, "1": {"effect": -0.1592563742250484, "value": ""}}}, {"outValue": 0.37062869120201336, "simIndex": 70.0, "features": {"0": {"effect": 0.0212429777623572, "value": ""}, "1": {"effect": 0.3493857134396562, "value": ""}}}, {"outValue": -0.21130455687135336, "simIndex": 377.0, "features": {"0": {"effect": -0.012570998392939056, "value": ""}, "1": {"effect": -0.19873355847841429, "value": ""}}}, {"outValue": 0.14466065852087068, "simIndex": 134.0, "features": {"0": {"effect": -0.01406974238795139, "value": ""}, "1": {"effect": 0.15873040090882207, "value": ""}}}, {"outValue": 0.1452700268243846, "simIndex": 156.0, "features": {"0": {"effect": -0.099431958496677, "value": ""}, "1": {"effect": 0.24470198532106163, "value": ""}}}, {"outValue": -0.18727264827252793, "simIndex": 361.0, "features": {"0": {"effect": 0.008226984244028582, "value": ""}, "1": {"effect": -0.1954996325165565, "value": ""}}}, {"outValue": -0.1880657741439398, "simIndex": 342.0, "features": {"0": {"effect": 0.004432165162898211, "value": ""}, "1": {"effect": -0.192497939306838, "value": ""}}}, {"outValue": -0. ...

# %%
# plot_shap_values_stacked(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2');

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %%
#plot_shap_values_hierarchically_clustered(shap_values_f1, 'Classifier 1 in margin space')
plot_shap_values_hierarchically_clustered(shap_values_f2, 'Classifier 2 in margin space')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_values_hierarchically_clustered(shap_values_c2, 'Classifier 2 in probability space')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_positive_and_c2_negative, 'Probability: C1 predicts positive and C2 negative')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_negative_and_c2_positive, 'Probability: C1 predicts negative and C2 positive')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_and_c2_different, 'Probability: C1 and C2 predict different labels')

# %%
#plot_shap_values_hierarchically_clustered(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2')
