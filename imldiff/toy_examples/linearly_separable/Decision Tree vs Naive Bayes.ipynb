# %%
from scipy.special import expit
from shap.maskers import Independent
from sklearn.datasets import make_classification
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from imldiff.plots import plot_shap_value_distribution, \
    plot_shap_partial_dependence, plot_shap_values_stacked, plot_shap_values_hierarchically_clustered, \
    plot_decision_boundary
from imldiff.util import printmd
import shap
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
shap.initjs()
np.seterr(divide='ignore');
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %% [markdown]
# # Decision Tree vs. Naive Bayes
# Based on ["Classifier comparison"](https://scikit-learn.org/0.24/auto_examples/classification/plot_classifier_comparison.html) example of scikit-learn docs.

# %%
## Create Models

# %%
feature_names = ['x1', 'x2']
X, y = make_classification(n_features=2, n_redundant=0, n_informative=2,
                           random_state=1, n_clusters_per_class=1)
rng = np.random.RandomState(2)
X += 2 * rng.uniform(size=X.shape)
X = StandardScaler().fit_transform(X)

# %%
m1 = DecisionTreeClassifier(max_depth=5)
m1.fit(X, y)
logit_from_log_proba = lambda Y: Y[:,1] - Y[:,0]
f1 = lambda X: logit_from_log_proba(m1.predict_log_proba(X))
c1 = lambda X: m1.predict_proba(X)[:,1]

# %%
m2 = GaussianNB()
m2.fit(X, y)
f2 = lambda X: logit_from_log_proba(m2.predict_log_proba(X))
c2 = lambda X: m2.predict_proba(X)[:,1]

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_decision_boundary(f1, X, 'Classifier 1 in margin space', feature_names, (-25, 25), fig, axs[0,0])
plot_decision_boundary(f2, X, 'Classifier 2 in margin space', feature_names, (-25, 25), fig, axs[1,0])
plot_decision_boundary(c1, X, 'Classifier 1 in probability space', feature_names, (-0.1, 1.1), fig, axs[0,1])
plot_decision_boundary(c2, X, 'Classifier 2 in probability space', feature_names, (-0.1, 1.1), fig, axs[1,1])
plt.show()
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %%
complement = lambda p: 1 - p
c1_positive_and_c2_negative = lambda p1, p2: p1 * complement(p2)
c1_negative_and_c2_positive = lambda p1, p2: complement(p1) * p2
c1_and_c2_different = lambda p1, p2: c1_positive_and_c2_negative(p1, p2) + c1_negative_and_c2_positive(p1, p2)
odds = lambda p: p / complement(p)
log_odds_ratio_from_proba = lambda p1, p2: np.log(odds(p1) / odds(p2))

c_c1_positive_and_c2_negative = lambda X: c1_positive_and_c2_negative(c1(X), c2(X))
c_c1_negative_and_c2_positive = lambda X: c1_negative_and_c2_positive(c1(X), c2(X))
c_c1_and_c2_different = lambda X: c1_and_c2_different(c1(X), c2(X))
f_log_odds_ratio_from_proba = lambda X: log_odds_ratio_from_proba(c1(X), c2(X))

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_decision_boundary(c_c1_positive_and_c2_negative, X, 'Probability: C1 predicts positive and C2 negative', feature_names, (0, 1), fig, axs[0,0])
plot_decision_boundary(c_c1_negative_and_c2_positive, X, 'Probability: C1 predicts negative and C2 positive', feature_names, (0, 1), fig, axs[0,1])
plot_decision_boundary(c_c1_and_c2_different, X, 'Probability: C1 and C2 predict different labels', feature_names, (0, 1), fig, axs[1,0])
plot_decision_boundary(f_log_odds_ratio_from_proba, X, 'Log odds ratio of C1 and C2, calculated from probabilities', feature_names, (-11, 11), fig, axs[1,1])
plt.show()
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %%
log_odds_ratio = lambda y1, y2: y1 - y2
f_log_odds_ratio = lambda X: log_odds_ratio(f1(X), f2(X))
plot_decision_boundary(f_log_odds_ratio, X, 'Log odds ratio of C1 and C2', feature_names, (-11, 11))
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %% [markdown]
# ## Generate Explanations

# %%
def make_shap_values(model, background_data, feature_names):
    masker = Independent(background_data)
    explainer = shap.Explainer(model, masker, feature_names=feature_names)
    shap_values = explainer(X)
    return shap_values

shap_values_f1 = make_shap_values(f1, X, feature_names)
shap_values_f2 = make_shap_values(f2, X, feature_names)
shap_values_c1 = make_shap_values(c1, X, feature_names)
shap_values_c2 = make_shap_values(c2, X, feature_names)

# %%
shap_values_c_c1_positive_and_c2_negative = make_shap_values(c_c1_positive_and_c2_negative, X, feature_names)
shap_values_c_c1_negative_and_c2_positive = make_shap_values(c_c1_negative_and_c2_positive, X, feature_names)
shap_values_c_c1_and_c2_different = make_shap_values(c_c1_and_c2_different, X, feature_names)
shap_values_f_log_odds_ratio = make_shap_values(f_log_odds_ratio, X, feature_names)

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### SHAP Value Distribution

# %%
plot_shap_value_distribution(shap_values_f1, 'Classifier 1 in margin space')
plot_shap_value_distribution(shap_values_f2, 'Classifier 2 in margin space')

# %%
plot_shap_value_distribution(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_value_distribution(shap_values_c2, 'Classifier 2 in probability space')

# %%
plot_shap_value_distribution(shap_values_c_c1_positive_and_c2_negative, 'Probability: C1 predicts positive and C2 negative')
plot_shap_value_distribution(shap_values_c_c1_negative_and_c2_positive, 'Probability: C1 predicts negative and C2 positive')
plot_shap_value_distribution(shap_values_c_c1_and_c2_different, 'Probability: C1 and C2 predict different labels')
plot_shap_value_distribution(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2')

# %% [markdown]
# ### Features' Partial Dependence Plots

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_f1, feature_names[0], 'Classifier 1 in margin space', (-8, 8), axs[0])
plot_shap_partial_dependence(shap_values_f2, feature_names[0], 'Classifier 2 in margin space', (-8, 8), axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_c1, feature_names[0], 'Classifier 1 in probability space', (-1, 1), axs[0])
plot_shap_partial_dependence(shap_values_c2, feature_names[0], 'Classifier 2 in probability space', (-1, 1), axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_c_c1_positive_and_c2_negative, feature_names[0], 'Probability: C1 predicts positive and C2 negative', (-1, 1), axs[0])
plot_shap_partial_dependence(shap_values_c_c1_negative_and_c2_positive, feature_names[0], 'Probability: C1 predicts negative and C2 positive', (-1, 1), axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_c_c1_and_c2_different, feature_names[0], 'Probability: C1 and C2 predict different labels', (-1, 1), axs[0])
plot_shap_partial_dependence(shap_values_f_log_odds_ratio, feature_names[0], 'Log odds ratio of C1 and C2', (-6, 6), axs[1])
plt.show()

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %%
# ordering = plot_shap_values_stacked(shap_values_f1, 'Classifier 1 in margin space')
plot_shap_values_stacked(shap_values_f2, 'Classifier 2 in margin space');
# Out:
# <div id='i4LG784EKCTIU6YOGUKMK'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 2 in margin space"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 5.665738493446926, "simIndex": 76.0, "features": {"0": {"effect": 5.577263251792058, "value": ""}, "1": {"effect": 0.08847524165486842, "value": ""}}}, {"outValue": -5.5178360384079035, "simIndex": 19.0, "features": {"0": {"effect": -5.831353273318459, "value": ""}, "1": {"effect": 0.31351723491055594, "value": ""}}}, {"outValue": -4.833529950181866, "simIndex": 31.0, "features": {"0": {"effect": -5.158481207000088, "value": ""}, "1": {"effect": 0.324951256818222, "value": ""}}}, {"outValue": 9.942120585036431, "simIndex": 90.0, "features": {"0": {"effect": 9.956464402510353, "value": ""}, "1": {"effect": -0.014343817473922549, "value": ""}}}, {"outValue": 6.827555350967449, "simIndex": 79.0, "features": {"0": {"effect": 6.494665017171711, "value": ""}, "1": {"effect": 0.3328903337957385, "value": ""}}}, {"outValue": 0.47816892797868626, "simIndex": 59.0, "features": {"0": {"effect": 0.5635314443764274, "value": ""}, "1": {"effect": -0.08536251639774117, "value": ""}}}, {"outValue": -1.8903607151527906, "simIndex": 53.0, "features": {"0": {"effect": -1.9917681452034355, "value": ""}, "1": {"effect": 0.10140743005064497, "value": ""}}}, {"outValue": 10.447258116857512, "simIndex": 94.0, "features": {"0": {"effect": 10.461177583810489, "value": ""}, "1": {"effect": -0.0139194669529763, "value": ""}}}, {"outValue": -7.179075463089777, "simIndex": 11.0, "features": {"0": {"effect": -7.476618907646246, "value": ""}, "1": {"effect": 0.2975434445564695, "value": ""}}}, {"outValue": -2.226371063862108, "simIndex": 50.0, "features": {"0": {"effect": -2.524934819868484, "value": ""}, "1": {"effect": 0.29856375600637597, "value": ""}}}, {"outValue": -6.557313723196735, "simIndex": 22.0, "features": {"0": {"effect": -6.558221246534623, "value": ""}, "1": {"effect": 0.0009075233378879055, "value": ""}}}, {"outValue": -4.529084343807603, "simIndex": 28.0, "features": {"0": {"effect": -4.693514756142089, "value": ""}, "1": {"effect": 0.16443041233448596, "value": ""}}}, {"outValue": -2.070206971536543, "simIndex": 52.0, "features": {"0": {"effect": -2.266025261929597, "value": ""}, "1": {"effect": 0.1958182903930543, "value": ""}}}, {"outValue": -3.523767110780345, "simIndex": 46.0, "features": {"0": {"effect": -3.2647031125584527, "value": ""}, "1": {"effect": -0.25906399822189263, "value": ""}}}, {"outValue": -3.0998311113855737, "simIndex": 41.0, "features": {"0": {"effect": -3.3986032395527666, "value": ""}, "1": {"effect": 0.2987721281671928, "value": ""}}}, {"outValue": -5.176241963490162, "simIndex": 36.0, "features": {"0": {"effect": -5.419251602582175, "value": ""}, "1": {"effect": 0.24300963909201267, "value": ""}}}, {"outValue": 2.4446159794251177, "simIndex": 66.0, "features": {"0": {"effect": 2.3651857616491463, "value": ""}, "1": {"effect": 0.07943021777597137, "value": ""}}}, {"outValue": 5.246169133553903, "simIndex": 73.0, "features": {"0": {"effect": 4.9212603647064, "value": ""}, "1": {"effect": 0.32490876884750275, "value": ""}}}, {"outValue": -1.3052872044571866, "simIndex": 54.0, "features": {"0": {"effect": -1.0341938838317741, "value": ""}, "1": {"effect": -0.27109332062541236, "value": ""}}}, {"outValue": 7.643594553936553, "simIndex": 83.0, "features": {"0": {"effect": 7.418442045246252, "value": ""}, "1": {"effect": 0.225152508690301, "value": ""}}}, {"outValue": -0.39300958570236877, "simIndex": 55.0, "features": {"0": {"effect": -0.5498850117863258, "value": ""}, "1": {"effect": 0.156875426083957, "value": ""}}}, {"outValue": -8.935909341883553, "simIndex": 5.0, "features": {"0": {"effect": -8.99840267787353, "value": ""}, "1": {"effect": 0.062493335989977083, "value": ""}}}, {"outValue": 6.447332476554545, "simIndex": 77.0, "features": {"0": {"effect": 6.12416470870863, "value": ""}, "1": {"effect": 0.32316 ...

# %%
ordering = plot_shap_values_stacked(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_values_stacked(shap_values_c2, 'Classifier 2 in probability space', ordering=ordering);
# Out:
# <div id='i2HMU4IIP25JCSXS8UJBF'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 1 in probability space"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.5, "simIndex": 80.0, "features": {"0": {"effect": 0.50875, "value": ""}, "1": {"effect": -0.008750000000000036, "value": ""}}}, {"outValue": -0.5, "simIndex": 27.0, "features": {"0": {"effect": -0.49124999999999996, "value": ""}, "1": {"effect": -0.008750000000000008, "value": ""}}}, {"outValue": -0.5, "simIndex": 26.0, "features": {"0": {"effect": -0.49124999999999996, "value": ""}, "1": {"effect": -0.008750000000000008, "value": ""}}}, {"outValue": 0.5, "simIndex": 79.0, "features": {"0": {"effect": 0.50875, "value": ""}, "1": {"effect": -0.008750000000000036, "value": ""}}}, {"outValue": 0.5, "simIndex": 78.0, "features": {"0": {"effect": 0.50875, "value": ""}, "1": {"effect": -0.008750000000000036, "value": ""}}}, {"outValue": 0.5, "simIndex": 81.0, "features": {"0": {"effect": 0.50875, "value": ""}, "1": {"effect": -0.008750000000000036, "value": ""}}}, {"outValue": -0.24999999999999997, "simIndex": 50.0, "features": {"0": {"effect": -0.17749999999999996, "value": ""}, "1": {"effect": -0.07250000000000001, "value": ""}}}, {"outValue": 0.5, "simIndex": 77.0, "features": {"0": {"effect": 0.50875, "value": ""}, "1": {"effect": -0.008750000000000036, "value": ""}}}, {"outValue": -0.5, "simIndex": 25.0, "features": {"0": {"effect": -0.49124999999999996, "value": ""}, "1": {"effect": -0.008750000000000008, "value": ""}}}, {"outValue": -0.24999999999999997, "simIndex": 49.0, "features": {"0": {"effect": -0.17749999999999996, "value": ""}, "1": {"effect": -0.07250000000000001, "value": ""}}}, {"outValue": -0.5, "simIndex": 28.0, "features": {"0": {"effect": -0.49124999999999996, "value": ""}, "1": {"effect": -0.008750000000000008, "value": ""}}}, {"outValue": -0.5, "simIndex": 24.0, "features": {"0": {"effect": -0.49124999999999996, "value": ""}, "1": {"effect": -0.008750000000000008, "value": ""}}}, {"outValue": -0.24999999999999997, "simIndex": 48.0, "features": {"0": {"effect": -0.17749999999999996, "value": ""}, "1": {"effect": -0.07250000000000001, "value": ""}}}, {"outValue": -0.49999999999999994, "simIndex": 44.0, "features": {"0": {"effect": -0.40624999999999994, "value": ""}, "1": {"effect": -0.09375000000000001, "value": ""}}}, {"outValue": -0.49999999999999994, "simIndex": 45.0, "features": {"0": {"effect": -0.40624999999999994, "value": ""}, "1": {"effect": -0.09375000000000001, "value": ""}}}, {"outValue": -0.5, "simIndex": 29.0, "features": {"0": {"effect": -0.49124999999999996, "value": ""}, "1": {"effect": -0.008750000000000008, "value": ""}}}, {"outValue": 0.5, "simIndex": 82.0, "features": {"0": {"effect": 0.50875, "value": ""}, "1": {"effect": -0.008750000000000036, "value": ""}}}, {"outValue": 0.5, "simIndex": 76.0, "features": {"0": {"effect": 0.50875, "value": ""}, "1": {"effect": -0.008750000000000036, "value": ""}}}, {"outValue": 0.5, "simIndex": 57.0, "features": {"0": {"effect": 0.45999999999999996, "value": ""}, "1": {"effect": 0.040000000000000036, "value": ""}}}, {"outValue": 0.5, "simIndex": 83.0, "features": {"0": {"effect": 0.50875, "value": ""}, "1": {"effect": -0.008750000000000036, "value": ""}}}, {"outValue": 0.5, "simIndex": 75.0, "features": {"0": {"effect": 0.50875, "value": ""}, "1": {"effect": -0.008750000000000036, "value": ""}}}, {"outValue": -0.5, "simIndex": 23.0, "features": {"0": {"effect": -0.49124999999999996, "value": ""}, "1": {"effect": -0.008750000000000008, "value": ""}}}, {"outValue": 0.5, "simIndex": 84.0, "features": {"0": {"effect": 0.50875, "value": ""}, "1": {"effect": -0.008750000000000036, "value": ""}}}, {"outValue": -0.5, "simIndex": 5.0, "features": {"0": {"effect": -0.54, "value": ""}, "1": {"effect": 0.03999999999999998, "value": ""}}}, {"outValue": -0.5, "simIndex": 6.0, "features": {"0": {"effect": -0.54, "value": ""}, "1": {"effect": 0.0399999999999 ...
# <div id='iALV89RXWW11FLIPEEFHI'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 2 in probability space"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.5038112831899151, "simIndex": 6.0, "features": {"0": {"effect": 0.5025615814300339, "value": ""}, "1": {"effect": 0.0012497017598810944, "value": ""}}}, {"outValue": -0.47457078627205895, "simIndex": 88.0, "features": {"0": {"effect": -0.48272043511518403, "value": ""}, "1": {"effect": 0.008149648843125063, "value": ""}}}, {"outValue": -0.4548096435785488, "simIndex": 72.0, "features": {"0": {"effect": -0.4652975722548184, "value": ""}, "1": {"effect": 0.0104879286762696, "value": ""}}}, {"outValue": 0.5044508487580815, "simIndex": 10.0, "features": {"0": {"effect": 0.505524538719645, "value": ""}, "1": {"effect": -0.0010736899615634288, "value": ""}}}, {"outValue": 0.5042568222686419, "simIndex": 30.0, "features": {"0": {"effect": 0.4976429530898286, "value": ""}, "1": {"effect": 0.0066138691788133475, "value": ""}}}, {"outValue": 0.4003623805039318, "simIndex": 42.0, "features": {"0": {"effect": 0.40105284750942877, "value": ""}, "1": {"effect": -0.0006904670054969642, "value": ""}}}, {"outValue": -0.049337545118899484, "simIndex": 48.0, "features": {"0": {"effect": -0.058330207771930154, "value": ""}, "1": {"effect": 0.00899266265303067, "value": ""}}}, {"outValue": 0.5044544244426692, "simIndex": 9.0, "features": {"0": {"effect": 0.5055196779518827, "value": ""}, "1": {"effect": -0.001065253509213493, "value": ""}}}, {"outValue": -0.4914891683576485, "simIndex": 95.0, "features": {"0": {"effect": -0.497593217128459, "value": ""}, "1": {"effect": 0.006104048770810473, "value": ""}}}, {"outValue": -0.13014801001476403, "simIndex": 50.0, "features": {"0": {"effect": -0.1627991403842, "value": ""}, "1": {"effect": 0.032651130369435954, "value": ""}}}, {"outValue": -0.4880226580542318, "simIndex": 86.0, "features": {"0": {"effect": -0.48691595787164443, "value": ""}, "1": {"effect": -0.0011067001825873593, "value": ""}}}, {"outValue": -0.4411038055120643, "simIndex": 69.0, "features": {"0": {"effect": -0.4457807242958455, "value": ""}, "1": {"effect": 0.004676918783781202, "value": ""}}}, {"outValue": -0.09323562102335603, "simIndex": 49.0, "features": {"0": {"effect": -0.11396602280342771, "value": ""}, "1": {"effect": 0.020730401780071683, "value": ""}}}, {"outValue": -0.3596005630059538, "simIndex": 57.0, "features": {"0": {"effect": -0.33145548398570274, "value": ""}, "1": {"effect": -0.028145079020251026, "value": ""}}}, {"outValue": -0.30173874327281536, "simIndex": 60.0, "features": {"0": {"effect": -0.3237041813741722, "value": ""}, "1": {"effect": 0.021965438101356843, "value": ""}}}, {"outValue": -0.46628211807379755, "simIndex": 73.0, "features": {"0": {"effect": -0.47280953853952984, "value": ""}, "1": {"effect": 0.006527420465732283, "value": ""}}}, {"outValue": 0.4884585059494691, "simIndex": 35.0, "features": {"0": {"effect": 0.48477085290496197, "value": ""}, "1": {"effect": 0.003687653044507133, "value": ""}}}, {"outValue": 0.5034735068304541, "simIndex": 31.0, "features": {"0": {"effect": 0.4967342177999901, "value": ""}, "1": {"effect": 0.006739289030464057, "value": ""}}}, {"outValue": 0.09568870517141154, "simIndex": 47.0, "features": {"0": {"effect": 0.1327355307361614, "value": ""}, "1": {"effect": -0.03704682556474986, "value": ""}}}, {"outValue": 0.504370073574532, "simIndex": 16.0, "features": {"0": {"effect": 0.5002362954499466, "value": ""}, "1": {"effect": 0.004133778124585374, "value": ""}}}, {"outValue": 0.2871351492731299, "simIndex": 46.0, "features": {"0": {"effect": 0.2666931219916137, "value": ""}, "1": {"effect": 0.020442027281516173, "value": ""}}}, {"outValue": -0.4948386254138754, "simIndex": 91.0, "features": {"0": {"effect": -0.49538479014149467, "value": ""}, "1": {"effect": 0.0005461647276192357, "value": ""}}}, {"outValue": 0.5041629203776314, "simIndex": 29.0, "features" ...

# %%
plot_shap_values_stacked(shap_values_c_c1_positive_and_c2_negative, 'Probability: C1 predicts positive and C2 negative');
# Out:
# <div id='iPS2V04CGJKYJKOQE8NGW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Probability: C1 predicts positive and C2 negative"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.04351313205258203, "simIndex": 24.0, "features": {"0": {"effect": -0.03574406804319372, "value": ""}, "1": {"effect": -0.007769064009388309, "value": ""}}}, {"outValue": -0.044161714029304494, "simIndex": 56.0, "features": {"0": {"effect": -0.03495573181085525, "value": ""}, "1": {"effect": -0.009205982218449248, "value": ""}}}, {"outValue": -0.044161714029304494, "simIndex": 63.0, "features": {"0": {"effect": -0.034879337823113955, "value": ""}, "1": {"effect": -0.009282376206190537, "value": ""}}}, {"outValue": -0.04415269762075194, "simIndex": 17.0, "features": {"0": {"effect": -0.037280433294748415, "value": ""}, "1": {"effect": -0.006872264326003529, "value": ""}}}, {"outValue": -0.043958671131311494, "simIndex": 69.0, "features": {"0": {"effect": -0.034541187832847924, "value": ""}, "1": {"effect": -0.009417483298463569, "value": ""}}}, {"outValue": 0.0599357706334013, "simIndex": 84.0, "features": {"0": {"effect": 0.06813101890465625, "value": ""}, "1": {"effect": -0.008195248271254951, "value": ""}}}, {"outValue": 0.09428763854207914, "simIndex": 92.0, "features": {"0": {"effect": 0.1519489575496812, "value": ""}, "1": {"effect": -0.057661319007602074, "value": ""}}}, {"outValue": -0.04415627330534003, "simIndex": 18.0, "features": {"0": {"effect": -0.037281298706134, "value": ""}, "1": {"effect": -0.006874974599206022, "value": ""}}}, {"outValue": -0.044161714029304494, "simIndex": 52.0, "features": {"0": {"effect": -0.03506300509623492, "value": ""}, "1": {"effect": -0.00909870893306958, "value": ""}}}, {"outValue": 0.11449025476604567, "simIndex": 94.0, "features": {"0": {"effect": 0.18357060505692008, "value": ""}, "1": {"effect": -0.0690803502908744, "value": ""}}}, {"outValue": -0.044161714029304494, "simIndex": 19.0, "features": {"0": {"effect": -0.037175666022883455, "value": ""}, "1": {"effect": -0.006986048006421037, "value": ""}}}, {"outValue": -0.044161714029304494, "simIndex": 29.0, "features": {"0": {"effect": -0.03598224413365958, "value": ""}, "1": {"effect": -0.008179469895644918, "value": ""}}}, {"outValue": 0.10526215751819334, "simIndex": 93.0, "features": {"0": {"effect": 0.16888010284462887, "value": ""}, "1": {"effect": -0.06361794532643553, "value": ""}}}, {"outValue": -0.044161714029304494, "simIndex": 87.0, "features": {"0": {"effect": 0.038307699447132526, "value": ""}, "1": {"effect": -0.08246941347643702, "value": ""}}}, {"outValue": -0.044161714029304494, "simIndex": 91.0, "features": {"0": {"effect": 0.04332691999461524, "value": ""}, "1": {"effect": -0.08748863402391974, "value": ""}}}, {"outValue": -0.044161714029304494, "simIndex": 44.0, "features": {"0": {"effect": -0.03543408912407221, "value": ""}, "1": {"effect": -0.008727624905232281, "value": ""}}}, {"outValue": -0.028160354812140104, "simIndex": 79.0, "features": {"0": {"effect": -0.017824661342825582, "value": ""}, "1": {"effect": -0.010335693469314521, "value": ""}}}, {"outValue": -0.04317535569312305, "simIndex": 72.0, "features": {"0": {"effect": -0.03350372491537179, "value": ""}, "1": {"effect": -0.009671630777751261, "value": ""}}}, {"outValue": 0.3646094459659185, "simIndex": 97.0, "features": {"0": {"effect": 0.29986919599852824, "value": ""}, "1": {"effect": 0.06474024996739028, "value": ""}}}, {"outValue": -0.044071922437199845, "simIndex": 43.0, "features": {"0": {"effect": -0.03543934491003518, "value": ""}, "1": {"effect": -0.008632577527164672, "value": ""}}}, {"outValue": 0.17316300186419994, "simIndex": 96.0, "features": {"0": {"effect": 0.1991311564658011, "value": ""}, "1": {"effect": -0.02596815460160115, "value": ""}}}, {"outValue": -0.044161714029304494, "simIndex": 21.0, "features": {"0": {"effect": -0.03671766501015, "value": ""}, "1": {"effect": -0.007444049019154492, "value" ...

# %%
plot_shap_values_stacked(shap_values_c_c1_negative_and_c2_positive, 'Probability: C1 predicts negative and C2 positive');
# Out:
# <div id='i08D2AINUOJIQYMPAFXRJ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Probability: C1 predicts negative and C2 positive"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.039701848862669184, "simIndex": 98.0, "features": {"0": {"effect": -0.041932486613160846, "value": ""}, "1": {"effect": 0.002230637750491659, "value": ""}}}, {"outValue": -0.018732500301363614, "simIndex": 44.0, "features": {"0": {"effect": -0.026426166926039413, "value": ""}, "1": {"effect": 0.007693666624675797, "value": ""}}}, {"outValue": 0.0010286423921465823, "simIndex": 24.0, "features": {"0": {"effect": -0.008926910077932431, "value": ""}, "1": {"effect": 0.009955552470079013, "value": ""}}}, {"outValue": -0.039701848862669184, "simIndex": 51.0, "features": {"0": {"effect": -0.04050589457510251, "value": ""}, "1": {"effect": 0.0008040457124333239, "value": ""}}}, {"outValue": -0.039701848862669184, "simIndex": 60.0, "features": {"0": {"effect": -0.04564823474301917, "value": ""}, "1": {"effect": 0.005946385880349986, "value": ""}}}, {"outValue": -0.039701848862669184, "simIndex": 50.0, "features": {"0": {"effect": -0.039566133585916305, "value": ""}, "1": {"effect": -0.00013571527675288256, "value": ""}}}, {"outValue": 0.2949500934231795, "simIndex": 2.0, "features": {"0": {"effect": 0.27111874977775097, "value": ""}, "1": {"effect": 0.02383134364542855, "value": ""}}}, {"outValue": -0.039701848862669184, "simIndex": 52.0, "features": {"0": {"effect": -0.0405116207542505, "value": ""}, "1": {"effect": 0.0008097718915813165, "value": ""}}}, {"outValue": -0.035650882386953214, "simIndex": 57.0, "features": {"0": {"effect": -0.04140622222469413, "value": ""}, "1": {"effect": 0.005755339837740917, "value": ""}}}, {"outValue": 0.2343422447512804, "simIndex": 5.0, "features": {"0": {"effect": 0.1982714646727194, "value": ""}, "1": {"effect": 0.03607078007856103, "value": ""}}}, {"outValue": -0.03218437208353645, "simIndex": 46.0, "features": {"0": {"effect": -0.032841623894527966, "value": ""}, "1": {"effect": 0.0006572518109915163, "value": ""}}}, {"outValue": 0.014734480458631072, "simIndex": 18.0, "features": {"0": {"effect": 0.009487031570494887, "value": ""}, "1": {"effect": 0.005247448888136184, "value": ""}}}, {"outValue": 0.26202653649483715, "simIndex": 4.0, "features": {"0": {"effect": 0.23241408004120104, "value": ""}, "1": {"effect": 0.02961245645363611, "value": ""}}}, {"outValue": 0.09623772296474163, "simIndex": 10.0, "features": {"0": {"effect": 0.11310221546142966, "value": ""}, "1": {"effect": -0.016864492496688033, "value": ""}}}, {"outValue": 0.15409954269788007, "simIndex": 13.0, "features": {"0": {"effect": 0.12587273862044301, "value": ""}, "1": {"effect": 0.028226804077437065, "value": ""}}}, {"outValue": -0.010443832103102084, "simIndex": 29.0, "features": {"0": {"effect": -0.016993627663602004, "value": ""}, "1": {"effect": 0.00654979556049992, "value": ""}}}, {"outValue": -0.039701848862669184, "simIndex": 99.0, "features": {"0": {"effect": -0.041803808437862675, "value": ""}, "1": {"effect": 0.002101959575193487, "value": ""}}}, {"outValue": -0.039701848862669184, "simIndex": 62.0, "features": {"0": {"effect": -0.045519507115381865, "value": ""}, "1": {"effect": 0.0058176582527126805, "value": ""}}}, {"outValue": -0.039701848862669184, "simIndex": 42.0, "features": {"0": {"effect": -0.02739527326531003, "value": ""}, "1": {"effect": -0.012306575597359155, "value": ""}}}, {"outValue": -0.039701848862669184, "simIndex": 78.0, "features": {"0": {"effect": -0.04395304946008925, "value": ""}, "1": {"effect": 0.004251200597420065, "value": ""}}}, {"outValue": -0.039701848862669184, "simIndex": 93.0, "features": {"0": {"effect": -0.0429257215425847, "value": ""}, "1": {"effect": 0.003223872679915519, "value": ""}}}, {"outValue": -0.03900033944318007, "simIndex": 54.0, "features": {"0": {"effect": -0.04085245515164484, "value": ""}, "1": {"effect": 0.001852115708464766, "value ...

# %%
plot_shap_values_stacked(shap_values_c_c1_and_c2_different, 'Probability: C1 and C2 predict different labels');
# Out:
# <div id='iX1SQER3QOMHPKN4ZZ04A'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Probability: C1 and C2 predict different labels"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.08321498091525122, "simIndex": 44.0, "features": {"0": {"effect": -0.07767655465635455, "value": ""}, "1": {"effect": -0.005538426258896662, "value": ""}}}, {"outValue": -0.06289421433066811, "simIndex": 61.0, "features": {"0": {"effect": -0.061381898736894654, "value": ""}, "1": {"effect": -0.001512315593773456, "value": ""}}}, {"outValue": -0.04313307163715792, "simIndex": 70.0, "features": {"0": {"effect": -0.04380624790104639, "value": ""}, "1": {"effect": 0.0006731762638884746, "value": ""}}}, {"outValue": -0.08385454648342112, "simIndex": 46.0, "features": {"0": {"effect": -0.07778632786985093, "value": ""}, "1": {"effect": -0.006068218613570191, "value": ""}}}, {"outValue": -0.08366051999398068, "simIndex": 17.0, "features": {"0": {"effect": -0.08018942257586709, "value": ""}, "1": {"effect": -0.003471097418113597, "value": ""}}}, {"outValue": 0.02023392177073212, "simIndex": 82.0, "features": {"0": {"effect": 0.028564885318739963, "value": ""}, "1": {"effect": -0.008330963548007844, "value": ""}}}, {"outValue": 0.38923773196525824, "simIndex": 96.0, "features": {"0": {"effect": 0.4230677073274318, "value": ""}, "1": {"effect": -0.03382997536217358, "value": ""}}}, {"outValue": -0.08385812216800921, "simIndex": 47.0, "features": {"0": {"effect": -0.07779291946038451, "value": ""}, "1": {"effect": -0.006065202707624699, "value": ""}}}, {"outValue": -0.07981259641625772, "simIndex": 51.0, "features": {"0": {"effect": -0.07646922732092906, "value": ""}, "1": {"effect": -0.0033433690953286596, "value": ""}}}, {"outValue": 0.348832499517326, "simIndex": 94.0, "features": {"0": {"effect": 0.3818420697296393, "value": ""}, "1": {"effect": -0.03300957021231335, "value": ""}}}, {"outValue": -0.07634608611284094, "simIndex": 57.0, "features": {"0": {"effect": -0.07001728991741142, "value": ""}, "1": {"effect": -0.006328796195429519, "value": ""}}}, {"outValue": -0.029427233570673422, "simIndex": 73.0, "features": {"0": {"effect": -0.026495212563164706, "value": ""}, "1": {"effect": -0.002932021007508716, "value": ""}}}, {"outValue": 0.36728869401303066, "simIndex": 95.0, "features": {"0": {"effect": 0.4012941828858301, "value": ""}, "1": {"effect": -0.034005488872799444, "value": ""}}}, {"outValue": 0.052076008935437124, "simIndex": 90.0, "features": {"0": {"effect": 0.1514099149085622, "value": ""}, "1": {"effect": -0.09933390597312508, "value": ""}}}, {"outValue": 0.1099378286685756, "simIndex": 87.0, "features": {"0": {"effect": 0.16919965861505826, "value": ""}, "1": {"effect": -0.05926182994648266, "value": ""}}}, {"outValue": -0.05460554613240658, "simIndex": 68.0, "features": {"0": {"effect": -0.052427716787674224, "value": ""}, "1": {"effect": -0.002177829344732353, "value": ""}}}, {"outValue": -0.06786220367480929, "simIndex": 63.0, "features": {"0": {"effect": -0.05962846978068827, "value": ""}, "1": {"effect": -0.008233733894121024, "value": ""}}}, {"outValue": -0.08287720455579224, "simIndex": 38.0, "features": {"0": {"effect": -0.07902323203075365, "value": ""}, "1": {"effect": -0.0038539725250385922, "value": ""}}}, {"outValue": 0.32490759710324923, "simIndex": 91.0, "features": {"0": {"effect": 0.27247392273321813, "value": ""}, "1": {"effect": 0.05243367437003113, "value": ""}}}, {"outValue": -0.08377377129986904, "simIndex": 34.0, "features": {"0": {"effect": -0.07939239437012445, "value": ""}, "1": {"effect": -0.004381376929744593, "value": ""}}}, {"outValue": 0.13346115300153075, "simIndex": 86.0, "features": {"0": {"effect": 0.15620543492321637, "value": ""}, "1": {"effect": -0.022744281921685622, "value": ""}}}, {"outValue": -0.08316205347248458, "simIndex": 45.0, "features": {"0": {"effect": -0.07757012016179485, "value": ""}, "1": {"effect": -0.005591933310689726, "value": ""}}},  ...

# %%
# plot_shap_values_stacked(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2');

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %%
#plot_shap_values_hierarchically_clustered(shap_values_f1, 'Classifier 1 in margin space')
plot_shap_values_hierarchically_clustered(shap_values_f2, 'Classifier 2 in margin space')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_values_hierarchically_clustered(shap_values_c2, 'Classifier 2 in probability space')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_positive_and_c2_negative, 'Probability: C1 predicts positive and C2 negative')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_negative_and_c2_positive, 'Probability: C1 predicts negative and C2 positive')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_and_c2_different, 'Probability: C1 and C2 predict different labels')

# %%
#plot_shap_values_hierarchically_clustered(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2')
