# %%
from scipy.special import logit
from shap.maskers import Independent
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from plots import plot_shap_value_distribution, plot_shap_partial_dependence, plot_shap_values_stacked, \
    plot_shap_values_hierarchically_clustered, plot_decision_boundary
import shap
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# # MLP vs. Naive Bayes
# Based on ["Classifier comparison"](https://scikit-learn.org/0.24/auto_examples/classification/plot_classifier_comparison.html) example of scikit-learn docs.

# %% [markdown]
# ## Create Models

# %%
feature_names = ['x1', 'x2']
X, y = make_classification(n_samples=500, n_features=2, n_redundant=0, n_informative=2,
                           random_state=1, n_clusters_per_class=1)
rng = np.random.RandomState(2)
X += 2 * rng.uniform(size=X.shape)
X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.8, random_state=42)

# %%
m1 = MLPClassifier(alpha=1, max_iter=1000)
m1.fit(X_train, y_train)
logit_from_log_proba = lambda Y: Y[:,1] - Y[:,0]
f1 = lambda X: logit_from_log_proba(m1.predict_log_proba(X))
c1 = lambda X: m1.predict_proba(X)[:,1]

# %%
m2 = GaussianNB()
m2.fit(X_train, y_train)
f2 = lambda X: logit_from_log_proba(m2.predict_log_proba(X))
c2 = lambda X: m2.predict_proba(X)[:,1]

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_decision_boundary(c1, X, 'Classifier 1 in probability space', feature_names, (0, 1), fig, axs[0,0], y)
plot_decision_boundary(c2, X, 'Classifier 2 in probability space', feature_names, (0, 1), fig, axs[1,0], y)
plot_decision_boundary(f1, X, 'Classifier 1 in margin space', feature_names, (-8, 8), fig, axs[0,1], logit(y))
plot_decision_boundary(f2, X, 'Classifier 2 in margin space', feature_names, (-8, 8), fig, axs[1,1], logit(y))
plt.show()
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %%
complement = lambda p: 1 - p
c1_positive_and_c2_negative = lambda p1, p2: p1 * complement(p2)
c1_negative_and_c2_positive = lambda p1, p2: complement(p1) * p2
c1_and_c2_different = lambda p1, p2: c1_positive_and_c2_negative(p1, p2) + c1_negative_and_c2_positive(p1, p2)

c_c1_positive_and_c2_negative = lambda X: c1_positive_and_c2_negative(c1(X), c2(X))
c_c1_negative_and_c2_positive = lambda X: c1_negative_and_c2_positive(c1(X), c2(X))
c_c1_and_c2_different = lambda X: c1_and_c2_different(c1(X), c2(X))

# %%
odds = lambda p: p / complement(p)
log_odds_ratio_from_proba = lambda p1, p2: np.log(odds(p1) / odds(p2))
log_odds_ratio = lambda y1, y2: y1 - y2

f_c1_positive_and_c2_negative = lambda X: logit(c_c1_positive_and_c2_negative(X))
f_c1_negative_and_c2_positive = lambda X: logit(c_c1_negative_and_c2_positive(X))
f_c1_and_c2_different = lambda X: logit(c_c1_and_c2_different(X))
f_log_odds_ratio = lambda X: log_odds_ratio(f1(X), f2(X))

# %%
fig, axs = plt.subplots(3, 2, figsize=(18, 21))
plot_decision_boundary(c_c1_positive_and_c2_negative, X, 'Probability: C1 predicts positive and C2 negative', feature_names, (0, 1), fig, axs[0,0], y)
plot_decision_boundary(c_c1_negative_and_c2_positive, X, 'Probability: C1 predicts negative and C2 positive', feature_names, (0, 1), fig, axs[1,0], y)
plot_decision_boundary(c_c1_and_c2_different, X, 'Probability: C1 and C2 predict different labels', feature_names, (0, 1), fig, axs[2,0], y)
plot_decision_boundary(f_c1_positive_and_c2_negative, X, 'Margin: C1 predicts positive and C2 negative', feature_names, (-8, 8), fig, axs[0,1], logit(y))
plot_decision_boundary(f_c1_negative_and_c2_positive, X, 'Margin: C1 predicts negative and C2 positive', feature_names, (-8, 8), fig, axs[1,1], logit(y))
plot_decision_boundary(f_c1_and_c2_different, X, 'Margin: C1 and C2 predict different labels', feature_names, (-8, 8), fig, axs[2,1], logit(y))
plt.show()
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %%
plot_decision_boundary(f_log_odds_ratio, X, 'Log odds ratio of C1 and C2', feature_names, (-8, 8), z=logit(y))
# Out:
# Warning: converting a masked element to nan.
# Warning: converting a masked element to nan.

# %% [markdown]
# ## Generate Explanations

# %%
def make_shap_values(model, background_data, feature_names):
    masker = Independent(background_data)
    explainer = shap.Explainer(model, masker, feature_names=feature_names)
    shap_values = explainer(X)
    return shap_values

shap_values_c1 = make_shap_values(c1, X, feature_names)
shap_values_c2 = make_shap_values(c2, X, feature_names)
shap_values_f1 = make_shap_values(f1, X, feature_names)
shap_values_f2 = make_shap_values(f2, X, feature_names)

# %%
shap_values_c_c1_positive_and_c2_negative = make_shap_values(c_c1_positive_and_c2_negative, X, feature_names)
shap_values_c_c1_negative_and_c2_positive = make_shap_values(c_c1_negative_and_c2_positive, X, feature_names)
shap_values_c_c1_and_c2_different = make_shap_values(c_c1_and_c2_different, X, feature_names)
shap_values_f_c1_positive_and_c2_negative = make_shap_values(f_c1_positive_and_c2_negative, X, feature_names)
shap_values_f_c1_negative_and_c2_positive = make_shap_values(f_c1_negative_and_c2_positive, X, feature_names)
shap_values_f_c1_and_c2_different = make_shap_values(f_c1_and_c2_different, X, feature_names)
shap_values_f_log_odds_ratio = make_shap_values(f_log_odds_ratio, X, feature_names)

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### SHAP Value Distribution

# %% [markdown]
# #### Probability Space

# %%
plot_shap_value_distribution(shap_values_c1, 'Classifier 1 in probability space')
plot_shap_value_distribution(shap_values_c2, 'Classifier 2 in probability space')

# %%
plot_shap_value_distribution(shap_values_c_c1_positive_and_c2_negative, 'C1 predicts positive and C2 negative')
plot_shap_value_distribution(shap_values_c_c1_negative_and_c2_positive, 'C1 predicts negative and C2 positive')
plot_shap_value_distribution(shap_values_c_c1_and_c2_different, 'C1 and C2 predict different labels')

# %% [markdown]
# #### Margin Space

# %%
plot_shap_value_distribution(shap_values_f1, 'Classifier 1 in margin space')
plot_shap_value_distribution(shap_values_f2, 'Classifier 2 in margin space')

# %%
plot_shap_value_distribution(shap_values_f_c1_positive_and_c2_negative, 'C1 predicts positive and C2 negative')
plot_shap_value_distribution(shap_values_f_c1_negative_and_c2_positive, 'C1 predicts negative and C2 positive')
plot_shap_value_distribution(shap_values_f_c1_and_c2_different, 'C1 and C2 predict different labels')

# %%
plot_shap_value_distribution(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2')

# %% [markdown]
# ### Features' Partial Dependence Plots

# %% [markdown]
# #### Probability Space

# %%
ylim = None
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_shap_partial_dependence(shap_values_c1, feature_names[0], 'Classifier 1', ylim, axs[0,0])
plot_shap_partial_dependence(shap_values_c1, feature_names[1], 'Classifier 1', ylim, axs[0,1])
plot_shap_partial_dependence(shap_values_c2, feature_names[0], 'Classifier 2', ylim, axs[1,0])
plot_shap_partial_dependence(shap_values_c2, feature_names[1], 'Classifier 2', ylim, axs[1,1])
plt.show()

# %%
ylim = None
fig, axs = plt.subplots(3, 2, figsize=(18, 21))
plot_shap_partial_dependence(shap_values_c_c1_positive_and_c2_negative, feature_names[0], 'C1 predicts positive and C2 negative', ylim, axs[0,0])
plot_shap_partial_dependence(shap_values_c_c1_positive_and_c2_negative, feature_names[1], 'C1 predicts positive and C2 negative', ylim, axs[0,1])
plot_shap_partial_dependence(shap_values_c_c1_negative_and_c2_positive, feature_names[0], 'C1 predicts negative and C2 positive', ylim, axs[1,0])
plot_shap_partial_dependence(shap_values_c_c1_negative_and_c2_positive, feature_names[1], 'C1 predicts negative and C2 positive', ylim, axs[1,1])
plot_shap_partial_dependence(shap_values_c_c1_and_c2_different, feature_names[0], 'C1 and C2 predict different labels', ylim, axs[2,0])
plot_shap_partial_dependence(shap_values_c_c1_and_c2_different, feature_names[1], 'C1 and C2 predict different labels', ylim, axs[2,1])
plt.show()

# %% [markdown]
# #### Margin Space

# %%
ylim = None
fig, axs = plt.subplots(2, 2, figsize=(18, 14))
plot_shap_partial_dependence(shap_values_f1, feature_names[0], 'Classifier 1', ylim, axs[0,0])
plot_shap_partial_dependence(shap_values_f1, feature_names[1], 'Classifier 1', ylim, axs[0,1])
plot_shap_partial_dependence(shap_values_f2, feature_names[0], 'Classifier 2', ylim, axs[1,0])
plot_shap_partial_dependence(shap_values_f2, feature_names[1], 'Classifier 2', ylim, axs[1,1])
plt.show()

# %%
ylim = None
fig, axs = plt.subplots(3, 2, figsize=(18, 21))
plot_shap_partial_dependence(shap_values_f_c1_positive_and_c2_negative, feature_names[0], 'C1 predicts positive and C2 negative', ylim, axs[0,0])
plot_shap_partial_dependence(shap_values_f_c1_positive_and_c2_negative, feature_names[1], 'C1 predicts positive and C2 negative', ylim, axs[0,1])
plot_shap_partial_dependence(shap_values_f_c1_negative_and_c2_positive, feature_names[0], 'C1 predicts negative and C2 positive', ylim, axs[1,0])
plot_shap_partial_dependence(shap_values_f_c1_negative_and_c2_positive, feature_names[1], 'C1 predicts negative and C2 positive', ylim, axs[1,1])
plot_shap_partial_dependence(shap_values_f_c1_and_c2_different, feature_names[0], 'C1 and C2 predict different labels', ylim, axs[2,0])
plot_shap_partial_dependence(shap_values_f_c1_and_c2_different, feature_names[1], 'C1 and C2 predict different labels', ylim, axs[2,1])
plt.show()

# %%
ylim = None
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
plot_shap_partial_dependence(shap_values_f_log_odds_ratio, feature_names[0], 'Log odds ratio of C1 and C2', ylim, axs[0])
plot_shap_partial_dependence(shap_values_f_log_odds_ratio, feature_names[1], 'Log odds ratio of C1 and C2', ylim, axs[1])
plt.show()

# %% [markdown]
# ### Stacked SHAP Explanations, Clustered by Similarity

# %% [markdown]
# #### Probability Space

# %%
ordering = plot_shap_values_stacked(shap_values_c1, 'Classifier 1')
plot_shap_values_stacked(shap_values_c2, 'Classifier 2', ordering);
# Out:
# <div id='iFPR1FTBUDDV5X9R5C6XK'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 1"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.4783540402340802, "simIndex": 32.0, "features": {"0": {"effect": -0.0782345725578329, "value": ""}, "1": {"effect": 0.5565886127919131, "value": ""}}}, {"outValue": -0.3309905357106961, "simIndex": 329.0, "features": {"0": {"effect": 0.07636131422264758, "value": ""}, "1": {"effect": -0.40735184993334367, "value": ""}}}, {"outValue": 0.40784551698837207, "simIndex": 138.0, "features": {"0": {"effect": 0.17933340289149402, "value": ""}, "1": {"effect": 0.22851211409687805, "value": ""}}}, {"outValue": 0.41451210365335356, "simIndex": 144.0, "features": {"0": {"effect": 0.12591683499359935, "value": ""}, "1": {"effect": 0.2885952686597542, "value": ""}}}, {"outValue": -0.35047301042573153, "simIndex": 326.0, "features": {"0": {"effect": 0.050104063737754057, "value": ""}, "1": {"effect": -0.4005770741634856, "value": ""}}}, {"outValue": -0.13917734795591144, "simIndex": 491.0, "features": {"0": {"effect": 0.21310516830392376, "value": ""}, "1": {"effect": -0.3522825162598352, "value": ""}}}, {"outValue": 0.45054032186722165, "simIndex": 53.0, "features": {"0": {"effect": 0.043807764717789965, "value": ""}, "1": {"effect": 0.4067325571494317, "value": ""}}}, {"outValue": 0.18704833952896316, "simIndex": 217.0, "features": {"0": {"effect": 0.21119991171905206, "value": ""}, "1": {"effect": -0.0241515721900889, "value": ""}}}, {"outValue": -0.43022947156516966, "simIndex": 296.0, "features": {"0": {"effect": -0.12452395581277567, "value": ""}, "1": {"effect": -0.30570551575239396, "value": ""}}}, {"outValue": 0.4713309957896513, "simIndex": 10.0, "features": {"0": {"effect": -0.10967470397140575, "value": ""}, "1": {"effect": 0.5810056997610571, "value": ""}}}, {"outValue": 0.45629304972052365, "simIndex": 58.0, "features": {"0": {"effect": 0.032508232536609394, "value": ""}, "1": {"effect": 0.42378481718391425, "value": ""}}}, {"outValue": 0.4456580923953329, "simIndex": 52.0, "features": {"0": {"effect": 0.04179877594311232, "value": ""}, "1": {"effect": 0.40385931645222056, "value": ""}}}, {"outValue": -0.3968601561771883, "simIndex": 387.0, "features": {"0": {"effect": 0.059586883866847934, "value": ""}, "1": {"effect": -0.45644704004403625, "value": ""}}}, {"outValue": 0.46494671390832154, "simIndex": 56.0, "features": {"0": {"effect": 0.05011300562591148, "value": ""}, "1": {"effect": 0.41483370828241006, "value": ""}}}, {"outValue": -0.3986910931200099, "simIndex": 333.0, "features": {"0": {"effect": 0.024260899489177923, "value": ""}, "1": {"effect": -0.4229519926091878, "value": ""}}}, {"outValue": -0.4660011233636147, "simIndex": 416.0, "features": {"0": {"effect": 0.026202155601122656, "value": ""}, "1": {"effect": -0.49220327896473737, "value": ""}}}, {"outValue": 0.19955669111776697, "simIndex": 216.0, "features": {"0": {"effect": 0.20972774407252653, "value": ""}, "1": {"effect": -0.010171052954759563, "value": ""}}}, {"outValue": -0.5107243642876667, "simIndex": 393.0, "features": {"0": {"effect": 0.0508862366588852, "value": ""}, "1": {"effect": -0.5616106009465518, "value": ""}}}, {"outValue": -0.13116901371147716, "simIndex": 465.0, "features": {"0": {"effect": 0.09423441854186043, "value": ""}, "1": {"effect": -0.2254034322533376, "value": ""}}}, {"outValue": 0.19880522220246444, "simIndex": 193.0, "features": {"0": {"effect": 0.028203090882001902, "value": ""}, "1": {"effect": 0.17060213132046254, "value": ""}}}, {"outValue": -0.5085400337502964, "simIndex": 348.0, "features": {"0": {"effect": -0.06656325201862831, "value": ""}, "1": {"effect": -0.4419767817316681, "value": ""}}}, {"outValue": -0.5049823104057538, "simIndex": 357.0, "features": {"0": {"effect": -0.03776507071379198, "value": ""}, "1": {"effect": -0.4672172396919618, "value": ""}}}, {"outValue": 0.45981589643590703, "simIndex": 34.0, "features": {"0": {"e ...
# <div id='iVDBRSAFC05W4O179VSFO'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 2"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.471834007358592, "simIndex": 468.0, "features": {"0": {"effect": 0.011289271982461824, "value": ""}, "1": {"effect": 0.46054473537613017, "value": ""}}}, {"outValue": -0.4203128012811659, "simIndex": 130.0, "features": {"0": {"effect": -0.01132893925926648, "value": ""}, "1": {"effect": -0.4089838620218994, "value": ""}}}, {"outValue": 0.19299443504862923, "simIndex": 304.0, "features": {"0": {"effect": -0.025374766210362887, "value": ""}, "1": {"effect": 0.21836920125899212, "value": ""}}}, {"outValue": 0.27979063696461837, "simIndex": 326.0, "features": {"0": {"effect": -0.016980311315768992, "value": ""}, "1": {"effect": 0.29677094828038736, "value": ""}}}, {"outValue": -0.4078008620935534, "simIndex": 134.0, "features": {"0": {"effect": -0.008914103279785701, "value": ""}, "1": {"effect": -0.3988867588137677, "value": ""}}}, {"outValue": -0.42635347293483256, "simIndex": 131.0, "features": {"0": {"effect": -0.02031152725499802, "value": ""}, "1": {"effect": -0.40604194567983454, "value": ""}}}, {"outValue": 0.4220552361842027, "simIndex": 430.0, "features": {"0": {"effect": -0.005218834750267409, "value": ""}, "1": {"effect": 0.4272740709344701, "value": ""}}}, {"outValue": -0.12837263837380417, "simIndex": 250.0, "features": {"0": {"effect": -0.0263721968693299, "value": ""}, "1": {"effect": -0.10200044150447427, "value": ""}}}, {"outValue": -0.25354025557987375, "simIndex": 207.0, "features": {"0": {"effect": 0.018318142685526395, "value": ""}, "1": {"effect": -0.27185839826540015, "value": ""}}}, {"outValue": 0.47145407208298806, "simIndex": 482.0, "features": {"0": {"effect": 0.016233300925426575, "value": ""}, "1": {"effect": 0.4552207711575615, "value": ""}}}, {"outValue": 0.43786637314641735, "simIndex": 423.0, "features": {"0": {"effect": -0.0038118085805390334, "value": ""}, "1": {"effect": 0.4416781817269564, "value": ""}}}, {"outValue": 0.4158451915499027, "simIndex": 393.0, "features": {"0": {"effect": -0.004784008480524959, "value": ""}, "1": {"effect": 0.42062920003042764, "value": ""}}}, {"outValue": -0.4554269509790263, "simIndex": 103.0, "features": {"0": {"effect": -0.009064083289617386, "value": ""}, "1": {"effect": -0.4463628676894089, "value": ""}}}, {"outValue": 0.4457984159015364, "simIndex": 435.0, "features": {"0": {"effect": -0.006423868135456978, "value": ""}, "1": {"effect": 0.4522222840369934, "value": ""}}}, {"outValue": -0.4221605102264484, "simIndex": 126.0, "features": {"0": {"effect": -0.0058435799157252055, "value": ""}, "1": {"effect": -0.4163169303107232, "value": ""}}}, {"outValue": -0.48571352371674203, "simIndex": 91.0, "features": {"0": {"effect": -0.004689263133409505, "value": ""}, "1": {"effect": -0.48102426058333253, "value": ""}}}, {"outValue": -0.11233245560690408, "simIndex": 247.0, "features": {"0": {"effect": -0.02630461457222033, "value": ""}, "1": {"effect": -0.08602784103468375, "value": ""}}}, {"outValue": -0.5255521033740409, "simIndex": 25.0, "features": {"0": {"effect": -0.006462765686520433, "value": ""}, "1": {"effect": -0.5190893376875205, "value": ""}}}, {"outValue": -0.26399437633383527, "simIndex": 193.0, "features": {"0": {"effect": -0.014423549414536385, "value": ""}, "1": {"effect": -0.2495708269192989, "value": ""}}}, {"outValue": 0.18352714088298266, "simIndex": 299.0, "features": {"0": {"effect": -0.0019722480696376388, "value": ""}, "1": {"effect": 0.1854993889526203, "value": ""}}}, {"outValue": -0.5015201947752156, "simIndex": 18.0, "features": {"0": {"effect": 0.010094789570085916, "value": ""}, "1": {"effect": -0.5116149843453015, "value": ""}}}, {"outValue": -0.5023133206466275, "simIndex": 73.0, "features": {"0": {"effect": 0.005087319659543232, "value": ""}, "1": {"effect": -0.5074006403061707, "value": ""}}}, {"outValue": 0.46851464512575786, "simIndex":  ...

# %%
plot_shap_values_stacked(shap_values_c_c1_positive_and_c2_negative, 'C1 predicts positive and C2 negative')
plot_shap_values_stacked(shap_values_c_c1_negative_and_c2_positive, 'C1 predicts negative and C2 positive')
plot_shap_values_stacked(shap_values_c_c1_and_c2_different, 'C1 and C2 predict different labels');
# Out:
# <div id='iDVUNYZUPIRUTFT4LHR7H'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["C1 predicts positive and C2 negative"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.10954556818815216, "simIndex": 125.0, "features": {"0": {"effect": -0.03654560241965388, "value": ""}, "1": {"effect": -0.07299996576849828, "value": ""}}}, {"outValue": 0.05664844870251223, "simIndex": 371.0, "features": {"0": {"effect": 0.0507906178020574, "value": ""}, "1": {"effect": 0.00585783090045483, "value": ""}}}, {"outValue": 0.14844965797092183, "simIndex": 448.0, "features": {"0": {"effect": 0.08011995084970518, "value": ""}, "1": {"effect": 0.06832970712121665, "value": ""}}}, {"outValue": 0.06941917607299097, "simIndex": 368.0, "features": {"0": {"effect": 0.04788062981569344, "value": ""}, "1": {"effect": 0.021538546257297536, "value": ""}}}, {"outValue": 0.037174323021021485, "simIndex": 373.0, "features": {"0": {"effect": 0.02949647653637584, "value": ""}, "1": {"effect": 0.007677846484645645, "value": ""}}}, {"outValue": 0.23009549429060108, "simIndex": 490.0, "features": {"0": {"effect": 0.16866365811115647, "value": ""}, "1": {"effect": 0.061431836179444615, "value": ""}}}, {"outValue": -0.06136555764952306, "simIndex": 69.0, "features": {"0": {"effect": 0.01140701629958256, "value": ""}, "1": {"effect": -0.07277257394910562, "value": ""}}}, {"outValue": 0.3132427966136536, "simIndex": 466.0, "features": {"0": {"effect": 0.12784134895896615, "value": ""}, "1": {"effect": 0.18540144765468747, "value": ""}}}, {"outValue": -0.04645191452391205, "simIndex": 310.0, "features": {"0": {"effect": -0.08653358236656132, "value": ""}, "1": {"effect": 0.04008166784264927, "value": ""}}}, {"outValue": -0.10917123264459704, "simIndex": 192.0, "features": {"0": {"effect": -0.042684732864270505, "value": ""}, "1": {"effect": -0.06648649978032653, "value": ""}}}, {"outValue": -0.0764740632990141, "simIndex": 117.0, "features": {"0": {"effect": 0.00702231269856754, "value": ""}, "1": {"effect": -0.08349637599758164, "value": ""}}}, {"outValue": -0.05562858207171673, "simIndex": 67.0, "features": {"0": {"effect": 0.009348787513913291, "value": ""}, "1": {"effect": -0.06497736958563002, "value": ""}}}, {"outValue": 0.0021049041143756594, "simIndex": 52.0, "features": {"0": {"effect": 0.03687933758272372, "value": ""}, "1": {"effect": -0.03477443346834806, "value": ""}}}, {"outValue": -0.08397087419116224, "simIndex": 82.0, "features": {"0": {"effect": 0.01944518051252471, "value": ""}, "1": {"effect": -0.10341605470368695, "value": ""}}}, {"outValue": -0.0035438439557511844, "simIndex": 284.0, "features": {"0": {"effect": 0.009160604744948807, "value": ""}, "1": {"effect": -0.012704448700699991, "value": ""}}}, {"outValue": -0.060461804397488966, "simIndex": 68.0, "features": {"0": {"effect": 0.010019832084126726, "value": ""}, "1": {"effect": -0.07048163648161569, "value": ""}}}, {"outValue": 0.30925187548786076, "simIndex": 467.0, "features": {"0": {"effect": 0.12462471088981962, "value": ""}, "1": {"effect": 0.18462716459804113, "value": ""}}}, {"outValue": -0.10302705743405674, "simIndex": 33.0, "features": {"0": {"effect": 0.026236030507985862, "value": ""}, "1": {"effect": -0.1292630879420426, "value": ""}}}, {"outValue": 0.17457398158348283, "simIndex": 420.0, "features": {"0": {"effect": 0.059285774903616875, "value": ""}, "1": {"effect": 0.11528820667986596, "value": ""}}}, {"outValue": 0.09690215011024046, "simIndex": 406.0, "features": {"0": {"effect": 0.0003827003929227357, "value": ""}, "1": {"effect": 0.09651944971731773, "value": ""}}}, {"outValue": -0.10106211323221459, "simIndex": 181.0, "features": {"0": {"effect": -0.038680853409228395, "value": ""}, "1": {"effect": -0.062381259822986194, "value": ""}}}, {"outValue": -0.09758862367356697, "simIndex": 172.0, "features": {"0": {"effect": -0.027773962551538092, "value": ""}, "1": {"effect": -0.06981466112202887, "value": ""}}}, {"outValue": -0. ...
# <div id='iTPQMN6U1NISJYL4UWEOC'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["C1 predicts negative and C2 positive"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.11606560106364439, "simIndex": 36.0, "features": {"0": {"effect": 0.05297824212063882, "value": ""}, "1": {"effect": -0.1690438431842832, "value": ""}}}, {"outValue": -0.03267381686795874, "simIndex": 426.0, "features": {"0": {"effect": -0.03689963567985722, "value": ""}, "1": {"effect": 0.004225818811898478, "value": ""}}}, {"outValue": -0.06640142396882168, "simIndex": 362.0, "features": {"0": {"effect": -0.12458821825215219, "value": ""}, "1": {"effect": 0.058186794283330505, "value": ""}}}, {"outValue": -0.06530229061574463, "simIndex": 377.0, "features": {"0": {"effect": -0.09501651649367485, "value": ""}, "1": {"effect": 0.029714225877930215, "value": ""}}}, {"outValue": -0.020153528646801637, "simIndex": 422.0, "features": {"0": {"effect": -0.029521690481164424, "value": ""}, "1": {"effect": 0.009368161834362787, "value": ""}}}, {"outValue": -0.0570806306883213, "simIndex": 391.0, "features": {"0": {"effect": -0.06475303744776595, "value": ""}, "1": {"effect": 0.007672406759444646, "value": ""}}}, {"outValue": -0.08985064333254572, "simIndex": 446.0, "features": {"0": {"effect": -0.03761958316847703, "value": ""}, "1": {"effect": -0.052231060164068685, "value": ""}}}, {"outValue": -0.002178181289114123, "simIndex": 347.0, "features": {"0": {"effect": -0.10973075962941613, "value": ""}, "1": {"effect": 0.107552578340302, "value": ""}}}, {"outValue": 0.13023730146138326, "simIndex": 245.0, "features": {"0": {"effect": 0.056308516131740496, "value": ""}, "1": {"effect": 0.07392878532964277, "value": ""}}}, {"outValue": -0.10904815635126043, "simIndex": 10.0, "features": {"0": {"effect": 0.08322327203256176, "value": ""}, "1": {"effect": -0.1922714283838222, "value": ""}}}, {"outValue": -0.09490073987312046, "simIndex": 100.0, "features": {"0": {"effect": -0.02929772841858065, "value": ""}, "1": {"effect": -0.06560301145453981, "value": ""}}}, {"outValue": -0.08544148291714962, "simIndex": 447.0, "features": {"0": {"effect": -0.03723399690972505, "value": ""}, "1": {"effect": -0.04820748600742456, "value": ""}}}, {"outValue": -0.05646189068746315, "simIndex": 462.0, "features": {"0": {"effect": -0.03177162957374213, "value": ""}, "1": {"effect": -0.024690261113721017, "value": ""}}}, {"outValue": -0.1031191721979483, "simIndex": 93.0, "features": {"0": {"effect": -0.037091693248843975, "value": ""}, "1": {"effect": -0.06602747894910432, "value": ""}}}, {"outValue": -0.02701326106219045, "simIndex": 419.0, "features": {"0": {"effect": -0.020943874659955, "value": ""}, "1": {"effect": -0.006069386402235449, "value": ""}}}, {"outValue": -0.08017420475061683, "simIndex": 76.0, "features": {"0": {"effect": -0.02087158665040576, "value": ""}, "1": {"effect": -0.05930261810021107, "value": ""}}}, {"outValue": -0.002637271236811345, "simIndex": 346.0, "features": {"0": {"effect": -0.11140764775492806, "value": ""}, "1": {"effect": 0.10877037651811672, "value": ""}}}, {"outValue": -0.11785479652043174, "simIndex": 123.0, "features": {"0": {"effect": -0.031112971837420116, "value": ""}, "1": {"effect": -0.08674182468301161, "value": ""}}}, {"outValue": 0.04174861896112474, "simIndex": 298.0, "features": {"0": {"effect": -0.04937219305277994, "value": ""}, "1": {"effect": 0.09112081201390468, "value": ""}}}, {"outValue": 0.08162406879075768, "simIndex": 312.0, "features": {"0": {"effect": -0.02979263855871741, "value": ""}, "1": {"effect": 0.11141670734947509, "value": ""}}}, {"outValue": -0.09404227425713439, "simIndex": 23.0, "features": {"0": {"effect": 0.03797718817948566, "value": ""}, "1": {"effect": -0.13201946243662005, "value": ""}}}, {"outValue": -0.09491963391444125, "simIndex": 190.0, "features": {"0": {"effect": 0.015078427821796775, "value": ""}, "1": {"effect": -0.10999806173623802, "value": ""}}}, {"out ...
# <div id='iW6S7WNP1NISIRST7OS89'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["C1 and C2 predict different labels"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -0.22561116925179647, "simIndex": 22.0, "features": {"0": {"effect": 0.016432639700984922, "value": ""}, "1": {"effect": -0.24204380895278138, "value": ""}}}, {"outValue": 0.023974631834553797, "simIndex": 330.0, "features": {"0": {"effect": 0.013890982122200371, "value": ""}, "1": {"effect": 0.010083649712353426, "value": ""}}}, {"outValue": 0.08204823400210012, "simIndex": 363.0, "features": {"0": {"effect": -0.044468267402446915, "value": ""}, "1": {"effect": 0.12651650140454704, "value": ""}}}, {"outValue": 0.004116885457246394, "simIndex": 252.0, "features": {"0": {"effect": -0.04713588667798142, "value": ""}, "1": {"effect": 0.05125277213522782, "value": ""}}}, {"outValue": 0.017020794374219633, "simIndex": 305.0, "features": {"0": {"effect": -2.521394478870176e-05, "value": ""}, "1": {"effect": 0.017046008319008335, "value": ""}}}, {"outValue": 0.1730148636022797, "simIndex": 228.0, "features": {"0": {"effect": 0.10391062066339042, "value": ""}, "1": {"effect": 0.06910424293888927, "value": ""}}}, {"outValue": -0.15121620098206867, "simIndex": 183.0, "features": {"0": {"effect": -0.026212566868894394, "value": ""}, "1": {"effect": -0.12500363411317428, "value": ""}}}, {"outValue": 0.31106461532453844, "simIndex": 482.0, "features": {"0": {"effect": 0.018110589329549343, "value": ""}, "1": {"effect": 0.2929540259949891, "value": ""}}}, {"outValue": 0.08378538693747056, "simIndex": 369.0, "features": {"0": {"effect": -0.030225066234821102, "value": ""}, "1": {"effect": 0.11401045317229166, "value": ""}}}, {"outValue": -0.21821938899585736, "simIndex": 12.0, "features": {"0": {"effect": 0.040538539168291254, "value": ""}, "1": {"effect": -0.2587579281641486, "value": ""}}}, {"outValue": -0.17137480317213455, "simIndex": 150.0, "features": {"0": {"effect": -0.02227541572001314, "value": ""}, "1": {"effect": -0.14909938745212142, "value": ""}}}, {"outValue": -0.14107006498886637, "simIndex": 197.0, "features": {"0": {"effect": -0.027885209395811822, "value": ""}, "1": {"effect": -0.11318485559305455, "value": ""}}}, {"outValue": -0.05435698657308774, "simIndex": 281.0, "features": {"0": {"effect": 0.005107708008981485, "value": ""}, "1": {"effect": -0.059464694582069225, "value": ""}}}, {"outValue": -0.18709004638911042, "simIndex": 62.0, "features": {"0": {"effect": -0.01764651273631923, "value": ""}, "1": {"effect": -0.1694435336527912, "value": ""}}}, {"outValue": -0.030557105017941233, "simIndex": 322.0, "features": {"0": {"effect": -0.011783269915005987, "value": ""}, "1": {"effect": -0.018773835102935246, "value": ""}}}, {"outValue": -0.1406360091481058, "simIndex": 175.0, "features": {"0": {"effect": -0.010851754566279057, "value": ""}, "1": {"effect": -0.12978425458182674, "value": ""}}}, {"outValue": 0.30661460425104936, "simIndex": 481.0, "features": {"0": {"effect": 0.013217063134891627, "value": ""}, "1": {"effect": 0.29339754111615773, "value": ""}}}, {"outValue": -0.22088185395448842, "simIndex": 99.0, "features": {"0": {"effect": -0.004876941329434226, "value": ""}, "1": {"effect": -0.2160049126250542, "value": ""}}}, {"outValue": 0.21632260054460828, "simIndex": 400.0, "features": {"0": {"effect": 0.009913581850837391, "value": ""}, "1": {"effect": 0.20640901869377087, "value": ""}}}, {"outValue": 0.17852621890099768, "simIndex": 430.0, "features": {"0": {"effect": -0.02940993816579475, "value": ""}, "1": {"effect": 0.20793615706679242, "value": ""}}}, {"outValue": -0.19510438748934888, "simIndex": 127.0, "features": {"0": {"effect": -0.0007036652297426754, "value": ""}, "1": {"effect": -0.1944007222596062, "value": ""}}}, {"outValue": -0.19250825758800805, "simIndex": 48.0, "features": {"0": {"effect": -0.01269553472974129, "value": ""}, "1": {"effect": -0.17981272285826674, "value": ""}}}, {"outV ...

# %% [markdown]
# #### Margin Space

# %%
ordering = plot_shap_values_stacked(shap_values_f1, 'Classifier 1')
plot_shap_values_stacked(shap_values_f2, 'Classifier 2', ordering);
# Out:
# <div id='iE1TPPQLV6MQOY8ARLXRB'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 1"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 5.469861289244657, "simIndex": 1.0, "features": {"0": {"effect": -1.0131096510344557, "value": ""}, "1": {"effect": 6.482970940279113, "value": ""}}}, {"outValue": -1.4724488384534637, "simIndex": 339.0, "features": {"0": {"effect": 0.7842974356634935, "value": ""}, "1": {"effect": -2.2567462741169573, "value": ""}}}, {"outValue": 2.517295953504131, "simIndex": 217.0, "features": {"0": {"effect": 1.3771875361809416, "value": ""}, "1": {"effect": 1.1401084173231895, "value": ""}}}, {"outValue": 2.6179485146568973, "simIndex": 90.0, "features": {"0": {"effect": 1.0329487971241813, "value": ""}, "1": {"effect": 1.584999717532716, "value": ""}}}, {"outValue": -1.6064729695252336, "simIndex": 342.0, "features": {"0": {"effect": 0.5651701872923239, "value": ""}, "1": {"effect": -2.1716431568175576, "value": ""}}}, {"outValue": -0.4961503434056378, "simIndex": 323.0, "features": {"0": {"effect": 1.6424504198904333, "value": ""}, "1": {"effect": -2.138600763296071, "value": ""}}}, {"outValue": 3.4098837158609157, "simIndex": 102.0, "features": {"0": {"effect": 0.4968961242969895, "value": ""}, "1": {"effect": 2.912987591563926, "value": ""}}}, {"outValue": 0.8695468755910347, "simIndex": 241.0, "features": {"0": {"effect": 1.2212659305347722, "value": ""}, "1": {"effect": -0.3517190549437375, "value": ""}}}, {"outValue": -2.3473292363598164, "simIndex": 282.0, "features": {"0": {"effect": -0.901233526557389, "value": ""}, "1": {"effect": -1.4460957098024274, "value": ""}}}, {"outValue": 4.4794890063388495, "simIndex": 5.0, "features": {"0": {"effect": -1.4216908534890615, "value": ""}, "1": {"effect": 5.901179859827911, "value": ""}}}, {"outValue": 3.6139078380834015, "simIndex": 42.0, "features": {"0": {"effect": 0.3963100701621406, "value": ""}, "1": {"effect": 3.217597767921261, "value": ""}}}, {"outValue": 3.2628786812794335, "simIndex": 103.0, "features": {"0": {"effect": 0.4495871396224641, "value": ""}, "1": {"effect": 2.8132915416569695, "value": ""}}}, {"outValue": -1.9861269486159672, "simIndex": 396.0, "features": {"0": {"effect": 0.7232516418178649, "value": ""}, "1": {"effect": -2.709378590433832, "value": ""}}}, {"outValue": 4.022576586990125, "simIndex": 78.0, "features": {"0": {"effect": 0.6500898394331298, "value": ""}, "1": {"effect": 3.372486747556995, "value": ""}}}, {"outValue": -2.0035065733887536, "simIndex": 346.0, "features": {"0": {"effect": 0.3606995973767315, "value": ""}, "1": {"effect": -2.364206170765485, "value": ""}}}, {"outValue": -2.91363193690357, "simIndex": 407.0, "features": {"0": {"effect": 0.41229790766743457, "value": ""}, "1": {"effect": -3.3259298445710046, "value": ""}}}, {"outValue": 0.9303971150554629, "simIndex": 240.0, "features": {"0": {"effect": 1.211349967754201, "value": ""}, "1": {"effect": -0.28095285269873815, "value": ""}}}, {"outValue": -4.994532020164334, "simIndex": 453.0, "features": {"0": {"effect": 0.7903311670709618, "value": ""}, "1": {"effect": -5.784863187235295, "value": ""}}}, {"outValue": -0.46223603041013184, "simIndex": 383.0, "features": {"0": {"effect": 0.6813030880784035, "value": ""}, "1": {"effect": -1.1435391184885353, "value": ""}}}, {"outValue": 0.9266966010652624, "simIndex": 201.0, "features": {"0": {"effect": 0.09462823140712687, "value": ""}, "1": {"effect": 0.8320683696581356, "value": ""}}}, {"outValue": -4.711039452975292, "simIndex": 446.0, "features": {"0": {"effect": -0.8739587407011653, "value": ""}, "1": {"effect": -3.8370807122741266, "value": ""}}}, {"outValue": -4.371431964927787, "simIndex": 448.0, "features": {"0": {"effect": -0.48719940568159653, "value": ""}, "1": {"effect": -3.8842325592461906, "value": ""}}}, {"outValue": 3.761576112325308, "simIndex": 18.0, "features": {"0": {"effect": -1.0481499999528898, "value": ""}, "1": {"effect": 4.8097261 ...
# <div id='iUNAO237JJ6YUFSQAV1XH'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Classifier 2"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 8.364510627926133, "simIndex": 2.0, "features": {"0": {"effect": 0.1981113097118676, "value": ""}, "1": {"effect": 8.166399318214266, "value": ""}}}, {"outValue": -2.316851807335241, "simIndex": 378.0, "features": {"0": {"effect": -0.1169177548542808, "value": ""}, "1": {"effect": -2.1999340524809603, "value": ""}}}, {"outValue": 0.7472662707370497, "simIndex": 191.0, "features": {"0": {"effect": -0.17952363156440443, "value": ""}, "1": {"effect": 0.9267899023014541, "value": ""}}}, {"outValue": 1.2335485120725749, "simIndex": 176.0, "features": {"0": {"effect": -0.1447810314934619, "value": ""}, "1": {"effect": 1.3783295435660368, "value": ""}}}, {"outValue": -2.1927883683948464, "simIndex": 367.0, "features": {"0": {"effect": -0.08942446409702087, "value": ""}, "1": {"effect": -2.1033639042978254, "value": ""}}}, {"outValue": -2.3813412725462824, "simIndex": 370.0, "features": {"0": {"effect": -0.2058019972795649, "value": ""}, "1": {"effect": -2.1755392752667175, "value": ""}}}, {"outValue": 2.743077116090067, "simIndex": 105.0, "features": {"0": {"effect": -0.08452133140989623, "value": ""}, "1": {"effect": 2.827598447499963, "value": ""}}}, {"outValue": -0.6091318813924677, "simIndex": 251.0, "features": {"0": {"effect": -0.1566522307683139, "value": ""}, "1": {"effect": -0.45247965062415374, "value": ""}}}, {"outValue": -1.174246618514703, "simIndex": 317.0, "features": {"0": {"effect": 0.11887755914874676, "value": ""}, "1": {"effect": -1.2931241776634497, "value": ""}}}, {"outValue": 7.266813466799788, "simIndex": 5.0, "features": {"0": {"effect": 0.29240342307620837, "value": ""}, "1": {"effect": 6.97441004372358, "value": ""}}}, {"outValue": 3.1399919037065236, "simIndex": 83.0, "features": {"0": {"effect": -0.07183840715992768, "value": ""}, "1": {"effect": 3.211830310866451, "value": ""}}}, {"outValue": 2.619378218702928, "simIndex": 93.0, "features": {"0": {"effect": -0.07614558399316303, "value": ""}, "1": {"effect": 2.695523802696091, "value": ""}}}, {"outValue": -2.7501945631258633, "simIndex": 398.0, "features": {"0": {"effect": -0.11186264271339792, "value": ""}, "1": {"effect": -2.6383319204124653, "value": ""}}}, {"outValue": 3.412418349063374, "simIndex": 69.0, "features": {"0": {"effect": -0.11627057161315874, "value": ""}, "1": {"effect": 3.5286889206765326, "value": ""}}}, {"outValue": -2.336231271457735, "simIndex": 374.0, "features": {"0": {"effect": -0.0646766731246273, "value": ""}, "1": {"effect": -2.271554598333108, "value": ""}}}, {"outValue": -3.322695066053664, "simIndex": 414.0, "features": {"0": {"effect": -0.07527767030138616, "value": ""}, "1": {"effect": -3.2474173957522776, "value": ""}}}, {"outValue": -0.5426969596367209, "simIndex": 253.0, "features": {"0": {"effect": -0.1553846841391887, "value": ""}, "1": {"effect": -0.3873122754975322, "value": ""}}}, {"outValue": -6.222106923555046, "simIndex": 487.0, "features": {"0": {"effect": -0.13862483253385935, "value": ""}, "1": {"effect": -6.083482091021186, "value": ""}}}, {"outValue": -1.2273897699346743, "simIndex": 293.0, "features": {"0": {"effect": -0.09936085114958695, "value": ""}, "1": {"effect": -1.1280289187850874, "value": ""}}}, {"outValue": 0.7006815507369133, "simIndex": 208.0, "features": {"0": {"effect": -0.02134288731102693, "value": ""}, "1": {"effect": 0.7220244380479403, "value": ""}}}, {"outValue": -3.8074933893947533, "simIndex": 439.0, "features": {"0": {"effect": 0.14371684230919538, "value": ""}, "1": {"effect": -3.9512102317039486, "value": ""}}}, {"outValue": -3.838745980969775, "simIndex": 438.0, "features": {"0": {"effect": 0.0654099867030401, "value": ""}, "1": {"effect": -3.904155967672815, "value": ""}}}, {"outValue": 5.446696603746737, "simIndex": 34.0, "features": {"0": {"effect": 0.19925215406839214, "value": ""}, " ...

# %%
plot_shap_values_stacked(shap_values_f_c1_positive_and_c2_negative, 'C1 predicts positive and C2 negative')
plot_shap_values_stacked(shap_values_f_c1_negative_and_c2_positive, 'C1 predicts negative and C2 positive')
plot_shap_values_stacked(shap_values_f_c1_and_c2_different, 'C1 and C2 predict different labels');
# Out:
# <div id='i9O6V0R0WUA8GWPPMEE38'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["C1 predicts positive and C2 negative"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -5.799052881981045, "simIndex": 4.0, "features": {"0": {"effect": -0.5815980522956601, "value": ""}, "1": {"effect": -5.217454829685385, "value": ""}}}, {"outValue": 1.1601993297780753, "simIndex": 360.0, "features": {"0": {"effect": 0.6115402500460625, "value": ""}, "1": {"effect": 0.5486590797320128, "value": ""}}}, {"outValue": 1.7162522980012878, "simIndex": 159.0, "features": {"0": {"effect": 0.6285889488806544, "value": ""}, "1": {"effect": 1.0876633491206333, "value": ""}}}, {"outValue": 1.2495892083751947, "simIndex": 380.0, "features": {"0": {"effect": 0.4461202346826767, "value": ""}, "1": {"effect": 0.8034689736925181, "value": ""}}}, {"outValue": 1.0126275819950656, "simIndex": 349.0, "features": {"0": {"effect": 0.4330256626818101, "value": ""}, "1": {"effect": 0.5796019193132556, "value": ""}}}, {"outValue": 2.107627824403724, "simIndex": 129.0, "features": {"0": {"effect": 1.3003551862822453, "value": ""}, "1": {"effect": 0.8072726381214785, "value": ""}}}, {"outValue": -0.20762928693893556, "simIndex": 435.0, "features": {"0": {"effect": 0.18110015401416257, "value": ""}, "1": {"effect": -0.38872944095309814, "value": ""}}}, {"outValue": 2.4611164087254958, "simIndex": 176.0, "features": {"0": {"effect": 0.8313127298224803, "value": ""}, "1": {"effect": 1.6298036789030155, "value": ""}}}, {"outValue": 0.07691579163014983, "simIndex": 236.0, "features": {"0": {"effect": -0.7895222339353405, "value": ""}, "1": {"effect": 0.8664380255654903, "value": ""}}}, {"outValue": -4.708438957689188, "simIndex": 16.0, "features": {"0": {"effect": -0.8123173392239815, "value": ""}, "1": {"effect": -3.8961216184652057, "value": ""}}}, {"outValue": -0.5978646380731216, "simIndex": 413.0, "features": {"0": {"effect": 0.1379883178834982, "value": ""}, "1": {"effect": -0.7358529559566198, "value": ""}}}, {"outValue": -0.08949814839012138, "simIndex": 425.0, "features": {"0": {"effect": 0.15983519777444477, "value": ""}, "1": {"effect": -0.24933334616456615, "value": ""}}}, {"outValue": 0.6995945097844349, "simIndex": 444.0, "features": {"0": {"effect": 0.5584123089923265, "value": ""}, "1": {"effect": 0.14118220079210841, "value": ""}}}, {"outValue": -0.8609891193115569, "simIndex": 392.0, "features": {"0": {"effect": 0.2618251638315605, "value": ""}, "1": {"effect": -1.1228142831431174, "value": ""}}}, {"outValue": 0.6414270511246898, "simIndex": 343.0, "features": {"0": {"effect": 0.2616268090030085, "value": ""}, "1": {"effect": 0.3798002421216813, "value": ""}}}, {"outValue": -0.18816721127585434, "simIndex": 434.0, "features": {"0": {"effect": 0.2976558328324024, "value": ""}, "1": {"effect": -0.4858230441082567, "value": ""}}}, {"outValue": 2.4447437188639416, "simIndex": 175.0, "features": {"0": {"effect": 0.8130695533692964, "value": ""}, "1": {"effect": 1.6316741654946454, "value": ""}}}, {"outValue": -2.2260394423401877, "simIndex": 106.0, "features": {"0": {"effect": 0.58163843059658, "value": ""}, "1": {"effect": -2.8076778729367677, "value": ""}}}, {"outValue": 1.8484906296532966, "simIndex": 153.0, "features": {"0": {"effect": 0.5229999716519191, "value": ""}, "1": {"effect": 1.3254906580013774, "value": ""}}}, {"outValue": 1.426361355159995, "simIndex": 277.0, "features": {"0": {"effect": 0.06156665462505595, "value": ""}, "1": {"effect": 1.364794700534939, "value": ""}}}, {"outValue": -1.9671534513596862, "simIndex": 80.0, "features": {"0": {"effect": -0.7540267407089647, "value": ""}, "1": {"effect": -1.2131267106507215, "value": ""}}}, {"outValue": -1.626817746069082, "simIndex": 77.0, "features": {"0": {"effect": -0.44310925002420465, "value": ""}, "1": {"effect": -1.1837084960448774, "value": ""}}}, {"outValue": -2.900109875994126, "simIndex": 26.0, "features": {"0": {"effect": -0.5888740247963904, ...
# <div id='iJVJEDGA0CI3BKWJA83FT'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["C1 predicts negative and C2 positive"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -2.915171374073408, "simIndex": 463.0, "features": {"0": {"effect": 0.7450208467620086, "value": ""}, "1": {"effect": -3.660192220835417, "value": ""}}}, {"outValue": 0.21069481913760946, "simIndex": 171.0, "features": {"0": {"effect": -0.39314490478177966, "value": ""}, "1": {"effect": 0.6038397239193891, "value": ""}}}, {"outValue": -0.31185062244082706, "simIndex": 294.0, "features": {"0": {"effect": -1.1918410476392614, "value": ""}, "1": {"effect": 0.8799904251984343, "value": ""}}}, {"outValue": -0.2904866851103496, "simIndex": 142.0, "features": {"0": {"effect": -0.9115266171921237, "value": ""}, "1": {"effect": 0.6210399320817741, "value": ""}}}, {"outValue": 0.3581201739216717, "simIndex": 162.0, "features": {"0": {"effect": -0.29039312287440966, "value": ""}, "1": {"effect": 0.6485132967960814, "value": ""}}}, {"outValue": -0.14233983659309968, "simIndex": 139.0, "features": {"0": {"effect": -0.845131540355819, "value": ""}, "1": {"effect": 0.7027917037627194, "value": ""}}}, {"outValue": -0.9079145129775776, "simIndex": 115.0, "features": {"0": {"effect": -0.45918031560265526, "value": ""}, "1": {"effect": -0.4487341973749224, "value": ""}}}, {"outValue": 0.5434376984440732, "simIndex": 271.0, "features": {"0": {"effect": -0.8668054422963056, "value": ""}, "1": {"effect": 1.4102431407403788, "value": ""}}}, {"outValue": 1.4581886779197917, "simIndex": 337.0, "features": {"0": {"effect": 0.4078399826723098, "value": ""}, "1": {"effect": 1.0503486952474819, "value": ""}}}, {"outValue": -1.9251848399472782, "simIndex": 459.0, "features": {"0": {"effect": 1.0721178355508387, "value": ""}, "1": {"effect": -2.997302675498117, "value": ""}}}, {"outValue": -1.0947024460710217, "simIndex": 31.0, "features": {"0": {"effect": -0.3737959015529393, "value": ""}, "1": {"effect": -0.7209065445180824, "value": ""}}}, {"outValue": -0.7679662314393827, "simIndex": 117.0, "features": {"0": {"effect": -0.4219486068609726, "value": ""}, "1": {"effect": -0.3460176245784101, "value": ""}}}, {"outValue": -0.13193372155177152, "simIndex": 97.0, "features": {"0": {"effect": -0.35773703628303877, "value": ""}, "1": {"effect": 0.22580331473126725, "value": ""}}}, {"outValue": -1.494741335669283, "simIndex": 131.0, "features": {"0": {"effect": -0.5731122072881578, "value": ""}, "1": {"effect": -0.9216291283811251, "value": ""}}}, {"outValue": 0.27954249830662103, "simIndex": 167.0, "features": {"0": {"effect": -0.19874544171564157, "value": ""}, "1": {"effect": 0.4782879400222626, "value": ""}}}, {"outValue": -0.6216290310737032, "simIndex": 37.0, "features": {"0": {"effect": -0.22734086648658614, "value": ""}, "1": {"effect": -0.394288164587117, "value": ""}}}, {"outValue": 0.5390218675520102, "simIndex": 270.0, "features": {"0": {"effect": -0.8717726341864103, "value": ""}, "1": {"effect": 1.4107945017384205, "value": ""}}}, {"outValue": -3.472718392551208, "simIndex": 485.0, "features": {"0": {"effect": -0.41916915544078925, "value": ""}, "1": {"effect": -3.0535492371104187, "value": ""}}}, {"outValue": 0.9107963547834277, "simIndex": 240.0, "features": {"0": {"effect": -0.39147317275407967, "value": ""}, "1": {"effect": 1.3022695275375074, "value": ""}}}, {"outValue": 1.1795920053053661, "simIndex": 214.0, "features": {"0": {"effect": -0.10485541445733726, "value": ""}, "1": {"effect": 1.2844474197627034, "value": ""}}}, {"outValue": -1.060532120290151, "simIndex": 447.0, "features": {"0": {"effect": 0.35802308833579544, "value": ""}, "1": {"effect": -1.4185552086259463, "value": ""}}}, {"outValue": -1.0954671038523374, "simIndex": 77.0, "features": {"0": {"effect": 0.16027114290873778, "value": ""}, "1": {"effect": -1.2557382467610751, "value": ""}}}, {"outValue": -1.210292559880711, "simIndex": 435.0, "features": {"0": {"effe ...
# <div id='i7V0TGM84WGL224ZQ3P5V'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["C1 and C2 predict different labels"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -3.7348924628950937, "simIndex": 4.0, "features": {"0": {"effect": 0.3908403028905316, "value": ""}, "1": {"effect": -4.125732765785625, "value": ""}}}, {"outValue": 0.6125118157107338, "simIndex": 269.0, "features": {"0": {"effect": 0.06147087641342741, "value": ""}, "1": {"effect": 0.5510409392973064, "value": ""}}}, {"outValue": 0.899477838457554, "simIndex": 367.0, "features": {"0": {"effect": -0.21612156610883793, "value": ""}, "1": {"effect": 1.115599404566392, "value": ""}}}, {"outValue": 0.504827118288869, "simIndex": 330.0, "features": {"0": {"effect": -0.2554676490933675, "value": ""}, "1": {"effect": 0.7602947673822364, "value": ""}}}, {"outValue": 0.5754716625378623, "simIndex": 290.0, "features": {"0": {"effect": -0.019739922898921236, "value": ""}, "1": {"effect": 0.5952115854367835, "value": ""}}}, {"outValue": 1.2971214481904234, "simIndex": 317.0, "features": {"0": {"effect": 0.4921067372015183, "value": ""}, "1": {"effect": 0.8050147109889051, "value": ""}}}, {"outValue": -0.7689744985976679, "simIndex": 189.0, "features": {"0": {"effect": -0.2304557393513158, "value": ""}, "1": {"effect": -0.5385187592463521, "value": ""}}}, {"outValue": 1.8546698702016227, "simIndex": 483.0, "features": {"0": {"effect": 0.039206426669231687, "value": ""}, "1": {"effect": 1.815463443532391, "value": ""}}}, {"outValue": 0.9075576796183038, "simIndex": 363.0, "features": {"0": {"effect": -0.15360117260057327, "value": ""}, "1": {"effect": 1.061158852218877, "value": ""}}}, {"outValue": -2.7396417748898063, "simIndex": 8.0, "features": {"0": {"effect": 0.6381522301301158, "value": ""}, "1": {"effect": -3.377794005019922, "value": ""}}}, {"outValue": -1.0861762399436656, "simIndex": 203.0, "features": {"0": {"effect": -0.21617792272074787, "value": ""}, "1": {"effect": -0.8699983172229178, "value": ""}}}, {"outValue": -0.6367540341002031, "simIndex": 173.0, "features": {"0": {"effect": -0.22996245693046846, "value": ""}, "1": {"effect": -0.4067915771697347, "value": ""}}}, {"outValue": 0.14388233563935549, "simIndex": 255.0, "features": {"0": {"effect": 0.040597918177633585, "value": ""}, "1": {"effect": 0.1032844174617219, "value": ""}}}, {"outValue": -1.4148108262042594, "simIndex": 123.0, "features": {"0": {"effect": -0.22073820571121527, "value": ""}, "1": {"effect": -1.194072620493044, "value": ""}}}, {"outValue": 0.30025432177287914, "simIndex": 283.0, "features": {"0": {"effect": -0.08325823973421176, "value": ""}, "1": {"effect": 0.3835125615070909, "value": ""}}}, {"outValue": -0.6314083411089384, "simIndex": 179.0, "features": {"0": {"effect": -0.06401876444275356, "value": ""}, "1": {"effect": -0.5673895766661848, "value": ""}}}, {"outValue": 1.8367616614120825, "simIndex": 484.0, "features": {"0": {"effect": 0.01917491298661267, "value": ""}, "1": {"effect": 1.81758674842547, "value": ""}}}, {"outValue": -2.998591349324929, "simIndex": 13.0, "features": {"0": {"effect": 0.10241912066856351, "value": ""}, "1": {"effect": -3.1010104699934926, "value": ""}}}, {"outValue": 1.4745003368018548, "simIndex": 404.0, "features": {"0": {"effect": -0.004395729323347863, "value": ""}, "1": {"effect": 1.4788960661252026, "value": ""}}}, {"outValue": 1.3199790105167253, "simIndex": 424.0, "features": {"0": {"effect": -0.17056205140797676, "value": ""}, "1": {"effect": 1.4905410619247021, "value": ""}}}, {"outValue": -1.6299075146630972, "simIndex": 110.0, "features": {"0": {"effect": -0.11617176988691202, "value": ""}, "1": {"effect": -1.5137357447761852, "value": ""}}}, {"outValue": -1.5554486584559037, "simIndex": 114.0, "features": {"0": {"effect": -0.1750371748306342, "value": ""}, "1": {"effect": -1.3804114836252697, "value": ""}}}, {"outValue": -1.9298917218429932, "simIndex": 70.0, "features": {"0": {"effect": 0.3 ...

# %%
plot_shap_values_stacked(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2');
# Out:
# <div id='iTB2RE2U68UV3GGOM6FHX'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["Log odds ratio of C1 and C2"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -2.8946493386814725, "simIndex": 19.0, "features": {"0": {"effect": -1.2112209607463216, "value": ""}, "1": {"effect": -1.6834283779351509, "value": ""}}}, {"outValue": 0.8444029688817709, "simIndex": 378.0, "features": {"0": {"effect": 0.9012151905177714, "value": ""}, "1": {"effect": -0.05681222163600058, "value": ""}}}, {"outValue": 1.7700296827670856, "simIndex": 460.0, "features": {"0": {"effect": 1.5567111677453478, "value": ""}, "1": {"effect": 0.21331851502173793, "value": ""}}}, {"outValue": 1.384400002584325, "simIndex": 428.0, "features": {"0": {"effect": 1.177729828617644, "value": ""}, "1": {"effect": 0.20667017396668086, "value": ""}}}, {"outValue": 0.5863153988696133, "simIndex": 330.0, "features": {"0": {"effect": 0.6545946513893459, "value": ""}, "1": {"effect": -0.06827925251973266, "value": ""}}}, {"outValue": 1.8851909291406446, "simIndex": 479.0, "features": {"0": {"effect": 1.848252417169998, "value": ""}, "1": {"effect": 0.03693851197064657, "value": ""}}}, {"outValue": 0.6668065997708346, "simIndex": 358.0, "features": {"0": {"effect": 0.5814174557068784, "value": ""}, "1": {"effect": 0.08538914406395615, "value": ""}}}, {"outValue": 1.478678756983499, "simIndex": 421.0, "features": {"0": {"effect": 1.3779181613030844, "value": ""}, "1": {"effect": 0.10076059568041451, "value": ""}}}, {"outValue": -1.1730826178451128, "simIndex": 134.0, "features": {"0": {"effect": -1.0201110857061357, "value": ""}, "1": {"effect": -0.15297153213897718, "value": ""}}}, {"outValue": -2.7873244604609404, "simIndex": 15.0, "features": {"0": {"effect": -1.7140942765652671, "value": ""}, "1": {"effect": -1.0732301838956733, "value": ""}}}, {"outValue": 0.47391593437688073, "simIndex": 308.0, "features": {"0": {"effect": 0.46814847732206966, "value": ""}, "1": {"effect": 0.005767457054811076, "value": ""}}}, {"outValue": 0.6435004625765083, "simIndex": 245.0, "features": {"0": {"effect": 0.5257327236156284, "value": ""}, "1": {"effect": 0.11776773896087986, "value": ""}}}, {"outValue": 0.7640676145099001, "simIndex": 385.0, "features": {"0": {"effect": 0.8351142845312651, "value": ""}, "1": {"effect": -0.071046670021365, "value": ""}}}, {"outValue": 0.610158237926754, "simIndex": 389.0, "features": {"0": {"effect": 0.7663604110462907, "value": ""}, "1": {"effect": -0.15620217311953666, "value": ""}}}, {"outValue": 0.33272469806898003, "simIndex": 290.0, "features": {"0": {"effect": 0.42537627050135784, "value": ""}, "1": {"effect": -0.09265157243237782, "value": ""}}}, {"outValue": 0.40906312915010035, "simIndex": 317.0, "features": {"0": {"effect": 0.48757557796882345, "value": ""}, "1": {"effect": -0.07851244881872312, "value": ""}}}, {"outValue": 1.4730940746921821, "simIndex": 420.0, "features": {"0": {"effect": 1.3667346518933887, "value": ""}, "1": {"effect": 0.1063594227987934, "value": ""}}}, {"outValue": 1.2275749033907135, "simIndex": 391.0, "features": {"0": {"effect": 0.9289559996048219, "value": ""}, "1": {"effect": 0.2986189037858916, "value": ""}}}, {"outValue": 0.7651537395245402, "simIndex": 341.0, "features": {"0": {"effect": 0.7806639392279889, "value": ""}, "1": {"effect": -0.01551019970344869, "value": ""}}}, {"outValue": 0.22601505032834832, "simIndex": 271.0, "features": {"0": {"effect": 0.1159711187181535, "value": ""}, "1": {"effect": 0.11004393161019481, "value": ""}}}, {"outValue": -0.9035460635805518, "simIndex": 83.0, "features": {"0": {"effect": -1.0176755830103672, "value": ""}, "1": {"effect": 0.11412951942981542, "value": ""}}}, {"outValue": -0.5326859839580127, "simIndex": 163.0, "features": {"0": {"effect": -0.552609392384637, "value": ""}, "1": {"effect": 0.019923408426624323, "value": ""}}}, {"outValue": -1.6851204914214202, "simIndex": 59.0, "features": {"0": {"effect": -1.24740215402 ...

# %% [markdown]
# ### Hierarchically Clustered SHAP Values

# %% [markdown]
# #### Probability Space

# %%
plot_shap_values_hierarchically_clustered(shap_values_c1, 'Classifier 1')
plot_shap_values_hierarchically_clustered(shap_values_c2, 'Classifier 2')

# %%
plot_shap_values_hierarchically_clustered(shap_values_c_c1_positive_and_c2_negative, 'C1 predicts positive and C2 negative')
plot_shap_values_hierarchically_clustered(shap_values_c_c1_negative_and_c2_positive, 'C1 predicts negative and C2 positive')
plot_shap_values_hierarchically_clustered(shap_values_c_c1_and_c2_different, 'C1 and C2 predict different labels')

# %% [markdown]
# #### Margin Space

# %%
plot_shap_values_hierarchically_clustered(shap_values_f1, 'Classifier 1')
plot_shap_values_hierarchically_clustered(shap_values_f2, 'Classifier 2')

# %%
plot_shap_values_hierarchically_clustered(shap_values_f_c1_positive_and_c2_negative, 'C1 predicts positive and C2 negative')
plot_shap_values_hierarchically_clustered(shap_values_f_c1_negative_and_c2_positive, 'C1 predicts negative and C2 positive')
plot_shap_values_hierarchically_clustered(shap_values_f_c1_and_c2_different, 'C1 and C2 predict different labels')

# %%
plot_shap_values_hierarchically_clustered(shap_values_f_log_odds_ratio, 'Log odds ratio of C1 and C2')
