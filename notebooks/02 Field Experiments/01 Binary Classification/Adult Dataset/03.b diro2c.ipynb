# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
import shap
import pickle
import cloudpickle
import numpy as np
from comparers import ModelComparer
from explainers import generate_shap_explanations
from plots import plot_decision_boundary, plot_2d, plot_feature_importance_bar, plot_feature_importance_scatter,\
                  plot_feature_effects, plot_forces
from util import calc_feature_order, calc_class_order, calc_instance_order
import pandas as pd
import diro2c
from data_generation.helper import prepare_df
from data_generation.neighborhood_generation import neighbor_generator
from enums.diff_classifier_method_type import diff_classifier_method_type
from mlxtend.plotting import plot_decision_regions
from sklearn.tree import plot_tree
import rule_extractor
shap.initjs()
# %matplotlib inline
task_name = '03'
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open(task_name + '.dataset', 'rb') as f:
    X, display_data, y, feature_names = pickle.load(f)
with open(task_name + '.models', 'rb') as f:
    comparer = pickle.load(f)

# %% [markdown]
# # Explain using Interpretability Methods

# %% [markdown]
# Prepare dataset for diro2c

# %%
idx_explain = 0

# %%
y = y.astype(str)
d = dict([(feature_name, feature_data)
          for feature_name, feature_data
          in zip(feature_names, [x for x in X.T])])
d |= {'y': y}
df = pd.DataFrame(d)
dataset = prepare_df(df, 'test', 'y')

# %% [markdown]
# ## Binary difference explanations

# %%
# %%time
diff_classifiers_info = diro2c.recognize_diff(idx_explain, X, dataset, comparer.clf_a, comparer.clf_b,
                                              diff_classifier_method_type.binary_diff_classifier,
                                              data_generation_function=neighbor_generator.get_genetic_neighborhood)
# Out:
# CPU times: user 35.3 s, sys: 369 ms, total: 35.7 s
# Wall time: 37.5 s

# %%
dc_info = diff_classifiers_info['binary_diff_classifer']
dc_full = dc_info['dc_full']
dc_test = dc_info['dc_test']
evaluation_info = dc_info['evaluation_info']

X_diff = evaluation_info['X']
y_diff = evaluation_info['y']

print(np.unique(y_diff, return_counts=True))
# Out:
# (array([0, 1]), array([1505,   75]))

# %%
value = 0
width = X.shape[0]
filler_feature_values = {1: value, 3: value, 4: value, 5: value, 6: value, 7: value, 8: value, 9: value, 10: value, 11: value}
filler_feature_ranges = {1: width, 3: width, 4: width, 5: width, 6: width, 7: width, 8: width, 9: width, 10: width, 11: width}

# %%
y_pred_a = comparer.clf_a.predict(X)
y_pred_b = comparer.clf_b.predict(X)

fig, ax = plt.subplots(1, 3, figsize=(21, 7))

fig = plot_decision_regions(X=X, y=y_pred_a.astype(np.int64), clf=comparer.clf_a, ax=ax[0], legend=2, feature_index=[0, 2], 
                            filler_feature_values=filler_feature_values, filler_feature_ranges=filler_feature_ranges)
ax[0].set_xlabel(feature_names[0])
ax[0].set_ylabel(feature_names[2])
plt.title('blackbox 1')

fig = plot_decision_regions(X=X, y=y_pred_b.astype(np.int64), clf=comparer.clf_b, ax=ax[1], legend=2, feature_index=[0, 2], 
                            filler_feature_values=filler_feature_values, filler_feature_ranges=filler_feature_ranges)
ax[0].set_xlabel(feature_names[0])
ax[0].set_ylabel(feature_names[2])
plt.title('blackbox 2')

fig = plot_decision_regions(X=X_diff, y=y_diff.astype(np.integer), clf=dc_full, ax=ax[2], legend=2, feature_index=[0, 2], 
                            filler_feature_values=filler_feature_values, filler_feature_ranges=filler_feature_ranges)
ax[0].set_xlabel(feature_names[0])
ax[0].set_ylabel(feature_names[2])
plt.title('binary diff-classifier')

plt.show()
# Out:
# No contour levels were found within the data range.
# No contour levels were found within the data range.
# Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.
# No contour levels were found within the data range.

# %%
cn = ['no_diff', 'diff']
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(4, 4), dpi=300)
plot_tree(dc_full,
               feature_names=feature_names,
               class_names=cn,
               filled=True)
# Out:
# [Text(278.61937729498163, 888.5769230769231, 'Relationship <= 2.5\ngini = 0.09\nsamples = 1580\nvalue = [1505, 75]\nclass = no_diff'),
#  Text(72.85189718482252, 853.7307692307693, 'Capital Gain <= 7073.5\ngini = 0.009\nsamples = 921\nvalue = [917, 4]\nclass = no_diff'),
#  Text(36.42594859241126, 818.8846153846154, 'Relationship <= 1.5\ngini = 0.002\nsamples = 914\nvalue = [913, 1]\nclass = no_diff'),
#  Text(18.21297429620563, 784.0384615384615, 'gini = 0.0\nsamples = 891\nvalue = [891, 0]\nclass = no_diff'),
#  Text(54.63892288861689, 784.0384615384615, 'Marital Status <= 2.0\ngini = 0.083\nsamples = 23\nvalue = [22, 1]\nclass = no_diff'),
#  Text(36.42594859241126, 749.1923076923076, 'Workclass <= 6.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = no_diff'),
#  Text(18.21297429620563, 714.3461538461538, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(54.63892288861689, 714.3461538461538, 'Age <= 41.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(36.42594859241126, 679.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(72.85189718482252, 679.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(72.85189718482252, 749.1923076923076, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = no_diff'),
#  Text(109.27784577723378, 818.8846153846154, 'Sex <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = no_diff'),
#  Text(91.06487148102815, 784.0384615384615, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = no_diff'),
#  Text(127.49082007343941, 784.0384615384615, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = diff'),
#  Text(484.38685740514074, 853.7307692307693, 'Relationship <= 3.5\ngini = 0.192\nsamples = 659\nvalue = [588, 71]\nclass = no_diff'),
#  Text(243.66967564259485, 818.8846153846154, 'Education-Num <= 13.5\ngini = 0.364\nsamples = 205\nvalue = [156, 49]\nclass = no_diff'),
#  Text(207.2437270501836, 784.0384615384615, 'Age <= 41.5\ngini = 0.44\nsamples = 147\nvalue = [99, 48]\nclass = no_diff'),
#  Text(189.03075275397796, 749.1923076923076, 'Occupation <= 0.5\ngini = 0.469\nsamples = 128\nvalue = [80, 48]\nclass = no_diff'),
#  Text(127.49082007343941, 714.3461538461538, 'Hours per week <= 42.0\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = diff'),
#  Text(109.27784577723378, 679.5, 'Capital Loss <= 1412.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = diff'),
#  Text(91.06487148102815, 644.6538461538462, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = diff'),
#  Text(127.49082007343941, 644.6538461538462, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(145.70379436964504, 679.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(250.57068543451652, 714.3461538461538, 'Race <= 3.5\ngini = 0.452\nsamples = 119\nvalue = [78, 41]\nclass = no_diff'),
#  Text(182.1297429620563, 679.5, 'Race <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = diff'),
#  Text(163.91676866585067, 644.6538461538462, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(200.34271725826193, 644.6538461538462, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = diff'),
#  Text(319.01162790697674, 679.5, 'Age <= 38.5\ngini = 0.438\nsamples = 114\nvalue = [77, 37]\nclass = no_diff'),
#  Text(236.7686658506732, 644.6538461538462, 'Age <= 29.0\ngini = 0.463\nsamples = 11\nvalue = [4, 7]\nclass = diff'),
#  Text(218.55569155446756, 609.8076923076924, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(254.98164014687882, 609.8076923076924, 'Age <= 36.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = diff'),
#  Text(236.7686658506732, 574.9615384615385, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = diff'),
#  Text(273.19461444308445, 574.9615384615385, 'Marital Status <= 3.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = diff'),
#  Text(254.98164014687882, 540.1153846153845, 'Occupation <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = diff'),
#  Text(236.7686658506732, 505.2692307692308, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = diff'),
#  Text(273.19461444308445, 505.2692307692308, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(291.4075887392901, 540.1153846153845, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(401.2545899632803, 644.6538461538462, 'Capital Loss <= 386.5\ngini = 0.413\nsamples = 103\nvalue = [73, 30]\nclass = no_diff'),
#  Text(383.04161566707467, 609.8076923076924, 'Hours per week <= 39.0\ngini = 0.43\nsamples = 96\nvalue = [66, 30]\nclass = no_diff'),
#  Text(364.82864137086904, 574.9615384615385, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(401.2545899632803, 574.9615384615385, 'Education-Num <= 11.0\ngini = 0.418\nsamples = 94\nvalue = [66, 28]\nclass = no_diff'),
#  Text(383.04161566707467, 540.1153846153845, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = no_diff'),
#  Text(419.4675642594859, 540.1153846153845, 'Hours per week <= 43.0\ngini = 0.437\nsamples = 87\nvalue = [59, 28]\nclass = no_diff'),
#  Text(309.6205630354957, 505.2692307692308, 'Workclass <= 5.0\ngini = 0.458\nsamples = 76\nvalue = [49, 27]\nclass = no_diff'),
#  Text(196.92778457772337, 470.4230769230769, 'Marital Status <= 3.0\ngini = 0.308\nsamples = 21\nvalue = [17, 4]\nclass = no_diff'),
#  Text(178.71481028151774, 435.5769230769231, 'Education-Num <= 12.5\ngini = 0.426\nsamples = 13\nvalue = [9, 4]\nclass = no_diff'),
#  Text(160.5018359853121, 400.7307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(196.92778457772337, 400.7307692307692, 'Workclass <= 3.0\ngini = 0.375\nsamples = 12\nvalue = [9, 3]\nclass = no_diff'),
#  Text(178.71481028151774, 365.88461538461536, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = no_diff'),
#  Text(215.140758873929, 365.88461538461536, 'Marital Status <= 1.0\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = no_diff'),
#  Text(196.92778457772337, 331.03846153846155, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = no_diff'),
#  Text(233.35373317013463, 331.03846153846155, 'Occupation <= 5.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = no_diff'),
#  Text(215.140758873929, 296.19230769230774, 'Occupation <= 2.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = diff'),
#  Text(196.92778457772337, 261.3461538461538, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = diff'),
#  Text(233.35373317013463, 261.3461538461538, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(251.56670746634026, 296.19230769230774, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(215.140758873929, 435.5769230769231, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = no_diff'),
#  Text(422.313341493268, 470.4230769230769, 'Marital Status <= 1.5\ngini = 0.487\nsamples = 55\nvalue = [32, 23]\nclass = no_diff'),
#  Text(351.73806609547125, 435.5769230769231, 'Sex <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = no_diff'),
#  Text(333.5250917992656, 400.7307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(369.9510403916769, 400.7307692307692, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = no_diff'),
#  Text(492.8886168910649, 435.5769230769231, 'Occupation <= 9.0\ngini = 0.497\nsamples = 48\nvalue = [26, 22]\nclass = no_diff'),
#  Text(406.37698898408814, 400.7307692307692, 'Marital Status <= 3.0\ngini = 0.5\nsamples = 41\nvalue = [20, 21]\nclass = diff'),
#  Text(287.99265605875155, 365.88461538461536, 'Country <= 38.0\ngini = 0.455\nsamples = 20\nvalue = [7, 13]\nclass = diff'),
#  Text(269.7796817625459, 331.03846153846155, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(306.2056303549572, 331.03846153846155, 'Occupation <= 6.0\ngini = 0.475\nsamples = 18\nvalue = [7, 11]\nclass = diff'),
#  Text(287.99265605875155, 296.19230769230774, 'Workclass <= 6.5\ngini = 0.492\nsamples = 16\nvalue = [7, 9]\nclass = diff'),
#  Text(269.7796817625459, 261.3461538461538, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(306.2056303549572, 261.3461538461538, 'Hours per week <= 41.0\ngini = 0.5\nsamples = 14\nvalue = [7, 7]\nclass = no_diff'),
#  Text(287.99265605875155, 226.5, 'Education-Num <= 12.5\ngini = 0.497\nsamples = 13\nvalue = [7, 6]\nclass = no_diff'),
#  Text(269.7796817625459, 191.6538461538462, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(306.2056303549572, 191.6538461538462, 'Occupation <= 2.0\ngini = 0.486\nsamples = 12\nvalue = [7, 5]\nclass = no_diff'),
#  Text(269.7796817625459, 156.80769230769226, 'Sex <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = no_diff'),
#  Text(251.56670746634026, 121.96153846153845, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(287.99265605875155, 121.96153846153845, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = no_diff'),
#  Text(342.63157894736844, 156.80769230769226, 'Occupation <= 3.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = diff'),
#  Text(324.4186046511628, 121.96153846153845, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(360.84455324357407, 121.96153846153845, 'Sex <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = no_diff'),
#  Text(342.63157894736844, 87.11538461538464, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(379.0575275397797, 87.11538461538464, 'Occupation <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(360.84455324357407, 52.26923076923072, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(397.2705018359853, 52.26923076923072, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(324.4186046511628, 226.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(324.4186046511628, 296.19230769230774, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(524.7613219094247, 365.88461538461536, 'Marital Status <= 4.5\ngini = 0.472\nsamples = 21\nvalue = [13, 8]\nclass = no_diff'),
#  Text(506.5483476132191, 331.03846153846155, 'Age <= 40.0\ngini = 0.455\nsamples = 20\nvalue = [13, 7]\nclass = no_diff'),
#  Text(488.3353733170135, 296.19230769230774, 'Capital Loss <= 182.0\ngini = 0.432\nsamples = 19\nvalue = [13, 6]\nclass = no_diff'),
#  Text(470.12239902080785, 261.3461538461538, 'Country <= 32.5\ngini = 0.401\nsamples = 18\nvalue = [13, 5]\nclass = no_diff'),
#  Text(451.9094247246022, 226.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(488.3353733170135, 226.5, 'Occupation <= 4.5\ngini = 0.43\nsamples = 16\nvalue = [11, 5]\nclass = no_diff'),
#  Text(470.12239902080785, 191.6538461538462, 'Occupation <= 3.5\ngini = 0.459\nsamples = 14\nvalue = [9, 5]\nclass = no_diff'),
#  Text(451.9094247246022, 156.80769230769226, 'Occupation <= 2.0\ngini = 0.426\nsamples = 13\nvalue = [9, 4]\nclass = no_diff'),
#  Text(433.6964504283966, 121.96153846153845, 'Capital Gain <= 1087.0\ngini = 0.444\nsamples = 12\nvalue = [8, 4]\nclass = no_diff'),
#  Text(415.48347613219096, 87.11538461538464, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(451.9094247246022, 87.11538461538464, 'Sex <= 0.5\ngini = 0.463\nsamples = 11\nvalue = [7, 4]\nclass = no_diff'),
#  Text(433.6964504283966, 52.26923076923072, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(470.12239902080785, 52.26923076923072, 'Education-Num <= 12.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = no_diff'),
#  Text(451.9094247246022, 17.423076923076906, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(488.3353733170135, 17.423076923076906, 'gini = 0.494\nsamples = 9\nvalue = [5, 4]\nclass = no_diff'),
#  Text(470.12239902080785, 121.96153846153845, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(488.3353733170135, 156.80769230769226, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(506.5483476132191, 191.6538461538462, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(506.5483476132191, 261.3461538461538, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(524.7613219094247, 296.19230769230774, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(542.9742962056304, 331.03846153846155, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(579.4002447980416, 400.7307692307692, 'Occupation <= 13.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = no_diff'),
#  Text(561.187270501836, 365.88461538461536, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = no_diff'),
#  Text(597.6132190942473, 365.88461538461536, 'Marital Status <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(579.4002447980416, 331.03846153846155, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(615.8261933904529, 331.03846153846155, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(529.3145654834761, 505.2692307692308, 'Occupation <= 3.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = no_diff'),
#  Text(511.1015911872705, 470.4230769230769, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = no_diff'),
#  Text(547.5275397796818, 470.4230769230769, 'Hours per week <= 67.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(529.3145654834761, 435.5769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(565.7405140758874, 435.5769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(419.4675642594859, 609.8076923076924, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = no_diff'),
#  Text(225.45670134638922, 749.1923076923076, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = no_diff'),
#  Text(280.0956242350061, 784.0384615384615, 'Workclass <= 0.5\ngini = 0.034\nsamples = 58\nvalue = [57, 1]\nclass = no_diff'),
#  Text(261.88264993880045, 749.1923076923076, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(298.3085985312117, 749.1923076923076, 'gini = 0.0\nsamples = 57\nvalue = [57, 0]\nclass = no_diff'),
#  Text(725.1040391676867, 818.8846153846154, 'Sex <= 0.5\ngini = 0.092\nsamples = 454\nvalue = [432, 22]\nclass = no_diff'),
#  Text(620.3794369645043, 784.0384615384615, 'Marital Status <= 3.0\ngini = 0.414\nsamples = 41\nvalue = [29, 12]\nclass = no_diff'),
#  Text(583.953488372093, 749.1923076923076, 'Relationship <= 4.5\ngini = 0.444\nsamples = 15\nvalue = [5, 10]\nclass = diff'),
#  Text(565.7405140758874, 714.3461538461538, 'Education-Num <= 13.5\ngini = 0.355\nsamples = 13\nvalue = [3, 10]\nclass = diff'),
#  Text(547.5275397796818, 679.5, 'Marital Status <= 0.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = diff'),
#  Text(529.3145654834761, 644.6538461538462, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(565.7405140758874, 644.6538461538462, 'Workclass <= 6.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = diff'),
#  Text(547.5275397796818, 609.8076923076924, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = diff'),
#  Text(583.953488372093, 609.8076923076924, 'Occupation <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = diff'),
#  Text(565.7405140758874, 574.9615384615385, 'Race <= 3.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = diff'),
#  Text(547.5275397796818, 540.1153846153845, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(583.953488372093, 540.1153846153845, 'Marital Status <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = diff'),
#  Text(565.7405140758874, 505.2692307692308, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(602.1664626682987, 505.2692307692308, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(602.1664626682987, 574.9615384615385, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(583.953488372093, 679.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(602.1664626682987, 714.3461538461538, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(656.8053855569156, 749.1923076923076, 'Age <= 45.0\ngini = 0.142\nsamples = 26\nvalue = [24, 2]\nclass = no_diff'),
#  Text(638.5924112607099, 714.3461538461538, 'Occupation <= 2.0\ngini = 0.077\nsamples = 25\nvalue = [24, 1]\nclass = no_diff'),
#  Text(620.3794369645043, 679.5, 'Workclass <= 5.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]\nclass = no_diff'),
#  Text(602.1664626682987, 644.6538461538462, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = no_diff'),
#  Text(638.5924112607099, 644.6538461538462, 'Age <= 38.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = no_diff'),
#  Text(620.3794369645043, 609.8076923076924, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = no_diff'),
#  Text(656.8053855569156, 609.8076923076924, 'Relationship <= 4.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = no_diff'),
#  Text(638.5924112607099, 574.9615384615385, 'Country <= 32.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = no_diff'),
#  Text(620.3794369645043, 540.1153846153845, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(656.8053855569156, 540.1153846153845, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = no_diff'),
#  Text(675.0183598531212, 574.9615384615385, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(656.8053855569156, 679.5, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = no_diff'),
#  Text(675.0183598531212, 714.3461538461538, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(829.828641370869, 784.0384615384615, 'Marital Status <= 5.5\ngini = 0.047\nsamples = 413\nvalue = [403, 10]\nclass = no_diff'),
#  Text(784.296205630355, 749.1923076923076, 'Age <= 30.0\ngini = 0.034\nsamples = 406\nvalue = [399, 7]\nclass = no_diff'),
#  Text(747.8702570379437, 714.3461538461538, 'Age <= 27.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = no_diff'),
#  Text(729.6572827417381, 679.5, 'Age <= 23.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = no_diff'),
#  Text(711.4443084455324, 644.6538461538462, 'Marital Status <= 3.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = no_diff'),
#  Text(693.2313341493268, 609.8076923076924, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(729.6572827417381, 609.8076923076924, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(747.8702570379437, 644.6538461538462, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = no_diff'),
#  Text(766.0832313341493, 679.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(820.7221542227662, 714.3461538461538, 'Race <= 0.5\ngini = 0.02\nsamples = 398\nvalue = [394, 4]\nclass = no_diff'),
#  Text(802.5091799265606, 679.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(838.9351285189719, 679.5, 'Education-Num <= 12.5\ngini = 0.015\nsamples = 397\nvalue = [394, 3]\nclass = no_diff'),
#  Text(802.5091799265606, 644.6538461538462, 'Hours per week <= 41.0\ngini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = no_diff'),
#  Text(784.296205630355, 609.8076923076924, 'Workclass <= 5.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = no_diff'),
#  Text(766.0832313341493, 574.9615384615385, 'Education-Num <= 11.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = no_diff'),
#  Text(747.8702570379437, 540.1153846153845, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(784.296205630355, 540.1153846153845, 'Marital Status <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(766.0832313341493, 505.2692307692308, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(802.5091799265606, 505.2692307692308, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(802.5091799265606, 574.9615384615385, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = no_diff'),
#  Text(820.7221542227662, 609.8076923076924, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(875.3610771113831, 644.6538461538462, 'Capital Loss <= 46.0\ngini = 0.005\nsamples = 383\nvalue = [382, 1]\nclass = no_diff'),
#  Text(857.1481028151775, 609.8076923076924, 'gini = 0.0\nsamples = 379\nvalue = [379, 0]\nclass = no_diff'),
#  Text(893.5740514075887, 609.8076923076924, 'Capital Loss <= 98.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = no_diff'),
#  Text(875.3610771113831, 574.9615384615385, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(911.7870257037944, 574.9615384615385, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = no_diff'),
#  Text(875.3610771113831, 749.1923076923076, 'Workclass <= 5.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = no_diff'),
#  Text(857.1481028151775, 714.3461538461538, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = no_diff'),
#  Text(893.5740514075887, 714.3461538461538, 'Education-Num <= 13.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = diff'),
#  Text(875.3610771113831, 679.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = diff'),
#  Text(911.7870257037944, 679.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff')]

# %%
rule_extractor.print_rules_for_binary(
    dc_full, dataset['columns_for_decision_rules'], ['no_diff', 'diff'], 'diff')
# Out:
# {'diff': '{Relationship <= 2.5, Capital Gain <= 7073.5, Relationship > 1.5, Marital Status <= 2.0, Workclass > 6.5, Age <= 41.0}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 7073.5, Sex > 0.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation <= 0.5, Hours per week <= 42.0, Capital Loss <= 1412.0}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race <= 3.5, Race > 1.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age <= 38.5, Age > 29.0, Age <= 36.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age <= 38.5, Age > 29.0, Age > 36.5, Marital Status <= 3.0, Occupation <= 2.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week <= 39.0}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass <= 5.0, Marital Status <= 3.0, Education-Num <= 12.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass <= 5.0, Marital Status <= 3.0, Education-Num > 12.5, Workclass > 3.0, Marital Status > 1.0, Occupation <= 5.5, Occupation <= 2.0}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass <= 5.0, Marital Status <= 3.0, Education-Num > 12.5, Workclass > 3.0, Marital Status > 1.0, Occupation <= 5.5, Occupation > 2.0}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status <= 1.5, Sex <= 0.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status > 1.5, Occupation <= 9.0, Marital Status <= 3.0, Country <= 38.0}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status > 1.5, Occupation <= 9.0, Marital Status <= 3.0, Country > 38.0, Occupation <= 6.0, Workclass <= 6.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status > 1.5, Occupation <= 9.0, Marital Status <= 3.0, Country > 38.0, Occupation <= 6.0, Workclass > 6.5, Hours per week <= 41.0, Education-Num <= 12.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status > 1.5, Occupation <= 9.0, Marital Status <= 3.0, Country > 38.0, Occupation <= 6.0, Workclass > 6.5, Hours per week <= 41.0, Education-Num > 12.5, Occupation <= 2.0, Sex <= 0.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status > 1.5, Occupation <= 9.0, Marital Status <= 3.0, Country > 38.0, Occupation <= 6.0, Workclass > 6.5, Hours per week <= 41.0, Education-Num > 12.5, Occupation > 2.0, Occupation <= 3.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status > 1.5, Occupation <= 9.0, Marital Status <= 3.0, Country > 38.0, Occupation <= 6.0, Workclass > 6.5, Hours per week <= 41.0, Education-Num > 12.5, Occupation > 2.0, Occupation > 3.5, Sex > 0.5, Occupation <= 4.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status > 1.5, Occupation <= 9.0, Marital Status <= 3.0, Country > 38.0, Occupation <= 6.0, Workclass > 6.5, Hours per week > 41.0}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status > 1.5, Occupation <= 9.0, Marital Status <= 3.0, Country > 38.0, Occupation > 6.0}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status > 1.5, Occupation <= 9.0, Marital Status > 3.0, Marital Status <= 4.5, Age <= 40.0, Capital Loss <= 182.0, Country > 32.5, Occupation <= 4.5, Occupation > 3.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status > 1.5, Occupation <= 9.0, Marital Status > 3.0, Marital Status <= 4.5, Age <= 40.0, Capital Loss > 182.0}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status > 1.5, Occupation <= 9.0, Marital Status > 3.0, Marital Status <= 4.5, Age > 40.0}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status > 1.5, Occupation <= 9.0, Marital Status > 3.0, Marital Status > 4.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week <= 43.0, Workclass > 5.0, Marital Status > 1.5, Occupation > 9.0, Occupation > 13.5, Marital Status > 3.0}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num <= 13.5, Age <= 41.5, Occupation > 0.5, Race > 3.5, Age > 38.5, Capital Loss <= 386.5, Hours per week > 39.0, Education-Num > 11.0, Hours per week > 43.0, Occupation > 3.5, Hours per week <= 67.5}'}
# {'diff': '{Relationship > 2.5, Relationship <= 3.5, Education-Num > 13.5, Workclass <= 0.5}'}
# {'diff': '{Relationship > 2.5, Relationship > 3.5, Sex <= 0.5, Marital Status <= 3.0, Relationship <= 4.5, Education-Num <= 13.5, Marital Status > 0.5, Workclass <= 6.5}'}
# {'diff': '{Relationship > 2.5, Relationship > 3.5, Sex <= 0.5, Marital Status <= 3.0, Relationship <= 4.5, Education-Num <= 13.5, Marital Status > 0.5, Workclass > 6.5, Occupation <= 1.5, Race <= 3.0}'}
# {'diff': '{Relationship > 2.5, Relationship > 3.5, Sex <= 0.5, Marital Status <= 3.0, Relationship <= 4.5, Education-Num <= 13.5, Marital Status > 0.5, Workclass > 6.5, Occupation <= 1.5, Race > 3.0, Marital Status <= 1.5}'}
# {'diff': '{Relationship > 2.5, Relationship > 3.5, Sex <= 0.5, Marital Status <= 3.0, Relationship <= 4.5, Education-Num <= 13.5, Marital Status > 0.5, Workclass > 6.5, Occupation > 1.5}'}
# {'diff': '{Relationship > 2.5, Relationship > 3.5, Sex <= 0.5, Marital Status > 3.0, Age > 45.0}'}
# {'diff': '{Relationship > 2.5, Relationship > 3.5, Sex > 0.5, Marital Status <= 5.5, Age <= 30.0, Age <= 27.0, Age <= 23.5, Marital Status <= 3.0}'}
# {'diff': '{Relationship > 2.5, Relationship > 3.5, Sex > 0.5, Marital Status <= 5.5, Age <= 30.0, Age > 27.0}'}
# {'diff': '{Relationship > 2.5, Relationship > 3.5, Sex > 0.5, Marital Status <= 5.5, Age > 30.0, Race <= 0.5}'}
# {'diff': '{Relationship > 2.5, Relationship > 3.5, Sex > 0.5, Marital Status <= 5.5, Age > 30.0, Race > 0.5, Education-Num <= 12.5, Hours per week <= 41.0, Workclass <= 5.5, Education-Num > 11.0, Marital Status > 3.0}'}
# {'diff': '{Relationship > 2.5, Relationship > 3.5, Sex > 0.5, Marital Status <= 5.5, Age > 30.0, Race > 0.5, Education-Num <= 12.5, Hours per week > 41.0}'}
# {'diff': '{Relationship > 2.5, Relationship > 3.5, Sex > 0.5, Marital Status <= 5.5, Age > 30.0, Race > 0.5, Education-Num > 12.5, Capital Loss > 46.0, Capital Loss <= 98.5}'}
# {'diff': '{Relationship > 2.5, Relationship > 3.5, Sex > 0.5, Marital Status > 5.5, Workclass > 5.5, Education-Num <= 13.5}'}

# %% [markdown]
# ## Multiclass difference explanations

# %%
multiclass_diff_names = ['(0, 0)', '(1, 1)', '(1, 0)', '(0, 1)']

# %%
# %%time
diff_classifiers_info = diro2c.recognize_diff(idx_explain, X, dataset, comparer.clf_a, comparer.clf_b,
                                              diff_classifier_method_type.multiclass_diff_classifier,
                                              data_generation_function=neighbor_generator.get_genetic_neighborhood)

# %%
dc_info = diff_classifiers_info['multiclass_diff_classifer']
dc_full = dc_info['dc_full']
dc_test = dc_info['dc_test']
evaluation_info = dc_info['evaluation_info']

X_diff = evaluation_info['X']
y_diff = evaluation_info['y']

print(np.unique(y_diff, return_counts=True))
# Out:
# (array([1, 2, 3, 4]), array([1010,  572,   41,    9]))

# %%
fig, ax = plt.subplots(1, 3, figsize=(21, 7))

fig = plot_decision_regions(X=X, y=y_pred_a.astype(np.int64), clf=comparer.clf_a, ax=ax[0], legend=2,
                            hide_spines=False, feature_index=[0, 2], 
                            filler_feature_values=filler_feature_values, filler_feature_ranges=filler_feature_ranges)
ax[0].set_xlabel(feature_names[0])
ax[0].set_ylabel(feature_names[2])
ax[0].set_title('black box A')

fig = plot_decision_regions(X=X, y=y_pred_b.astype(np.int64), clf=comparer.clf_b, ax=ax[1], legend=2,
                            hide_spines=False, feature_index=[0, 2], 
                            filler_feature_values=filler_feature_values, filler_feature_ranges=filler_feature_ranges)
ax[1].set_xlabel(feature_names[0])
ax[1].set_ylabel(feature_names[2])
ax[1].set_title('black box B')

fig = plot_decision_regions(X=X_diff, y=y_diff.astype(np.int64), clf=dc_full, ax=ax[2], legend=2, feature_index=[0, 2], 
                            filler_feature_values=filler_feature_values, filler_feature_ranges=filler_feature_ranges)
ax[2].set_xlabel(feature_names[0])
ax[2].set_ylabel(feature_names[2])
ax[2].set_title('multiclass diff-classifier')

handles, labels = ax[2].get_legend_handles_labels()
ax[2].legend(handles,
             multiclass_diff_names,
             framealpha=0.3, scatterpoints=1)

plt.show()
# Out:
# No contour levels were found within the data range.
# No contour levels were found within the data range.
# No contour levels were found within the data range.
# You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(4, 4), dpi=300)
plot_tree(dc_full,
               feature_names=feature_names,
               class_names=multiclass_diff_names,
               filled=True)
# Out:
# [Text(183.04276315789474, 883.35, 'Relationship <= 2.5\ngini = 0.493\nsamples = 1632\nvalue = [1010, 572, 41, 9]\nclass = (0, 0)'),
#  Text(40.78947368421053, 838.05, 'Capital Gain <= 3449.0\ngini = 0.002\nsamples = 937\nvalue = [936, 1, 0, 0]\nclass = (0, 0)'),
#  Text(29.912280701754387, 792.75, 'gini = 0.0\nsamples = 929\nvalue = [929, 0, 0, 0]\nclass = (0, 0)'),
#  Text(51.666666666666664, 792.75, 'Capital Gain <= 3694.0\ngini = 0.219\nsamples = 8\nvalue = [7, 1, 0, 0]\nclass = (0, 0)'),
#  Text(40.78947368421053, 747.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(62.54385964912281, 747.45, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = (0, 0)'),
#  Text(325.29605263157896, 838.05, 'Sex <= 0.5\ngini = 0.31\nsamples = 695\nvalue = [74, 571, 41, 9]\nclass = (1, 1)'),
#  Text(95.17543859649123, 792.75, 'Relationship <= 3.5\ngini = 0.572\nsamples = 85\nvalue = [38, 40, 7, 0]\nclass = (1, 1)'),
#  Text(84.29824561403508, 747.45, 'gini = 0.0\nsamples = 15\nvalue = [15, 0, 0, 0]\nclass = (0, 0)'),
#  Text(106.05263157894737, 747.45, 'Capital Gain <= 1087.0\ngini = 0.556\nsamples = 70\nvalue = [23, 40, 7, 0]\nclass = (1, 1)'),
#  Text(95.17543859649123, 702.15, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = (0, 0)'),
#  Text(116.9298245614035, 702.15, 'Age <= 36.0\ngini = 0.52\nsamples = 63\nvalue = [16, 40, 7, 0]\nclass = (1, 1)'),
#  Text(106.05263157894737, 656.85, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = (0, 0)'),
#  Text(127.80701754385964, 656.85, 'Education-Num <= 11.0\ngini = 0.474\nsamples = 58\nvalue = [11, 40, 7, 0]\nclass = (1, 1)'),
#  Text(116.9298245614035, 611.55, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = (0, 0)'),
#  Text(138.68421052631578, 611.55, 'Race <= 3.5\ngini = 0.434\nsamples = 55\nvalue = [8, 40, 7, 0]\nclass = (1, 1)'),
#  Text(127.80701754385964, 566.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = (0, 0)'),
#  Text(149.56140350877192, 566.25, 'Relationship <= 4.5\ngini = 0.4\nsamples = 53\nvalue = [6, 40, 7, 0]\nclass = (1, 1)'),
#  Text(138.68421052631578, 520.95, 'Marital Status <= 5.0\ngini = 0.483\nsamples = 41\nvalue = [6, 28, 7, 0]\nclass = (1, 1)'),
#  Text(127.80701754385964, 475.65000000000003, 'Occupation <= 9.5\ngini = 0.464\nsamples = 40\nvalue = [5, 28, 7, 0]\nclass = (1, 1)'),
#  Text(116.9298245614035, 430.35, 'Workclass <= 6.0\ngini = 0.442\nsamples = 39\nvalue = [4, 28, 7, 0]\nclass = (1, 1)'),
#  Text(65.26315789473685, 385.05000000000007, 'Occupation <= 2.0\ngini = 0.625\nsamples = 8\nvalue = [2, 4, 2, 0]\nclass = (1, 1)'),
#  Text(54.3859649122807, 339.75, 'Education-Num <= 13.5\ngini = 0.571\nsamples = 7\nvalue = [2, 4, 1, 0]\nclass = (1, 1)'),
#  Text(43.50877192982456, 294.45000000000005, 'Workclass <= 4.5\ngini = 0.64\nsamples = 5\nvalue = [2, 2, 1, 0]\nclass = (0, 0)'),
#  Text(32.631578947368425, 249.1500000000001, 'Age <= 48.0\ngini = 0.625\nsamples = 4\nvalue = [1, 2, 1, 0]\nclass = (1, 1)'),
#  Text(21.75438596491228, 203.85000000000002, 'Marital Status <= 3.0\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 1, 0]\nclass = (0, 0)'),
#  Text(10.87719298245614, 158.55000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(32.631578947368425, 158.55000000000007, 'gini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0]\nclass = (0, 0)'),
#  Text(43.50877192982456, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(54.3859649122807, 249.1500000000001, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(65.26315789473685, 294.45000000000005, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(76.14035087719299, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(168.59649122807016, 385.05000000000007, 'Education-Num <= 13.5\ngini = 0.37\nsamples = 31\nvalue = [2, 24, 5, 0]\nclass = (1, 1)'),
#  Text(130.5263157894737, 339.75, 'Marital Status <= 3.0\ngini = 0.282\nsamples = 25\nvalue = [2, 21, 2, 0]\nclass = (1, 1)'),
#  Text(87.01754385964912, 294.45000000000005, 'Marital Status <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [1, 4, 1, 0]\nclass = (1, 1)'),
#  Text(76.14035087719299, 249.1500000000001, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = (1, 1)'),
#  Text(97.89473684210526, 249.1500000000001, 'Marital Status <= 1.5\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 1, 0]\nclass = (0, 0)'),
#  Text(87.01754385964912, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(108.7719298245614, 203.85000000000002, 'Age <= 38.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]\nclass = (0, 0)'),
#  Text(97.89473684210526, 158.55000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(119.64912280701755, 158.55000000000007, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(174.03508771929825, 294.45000000000005, 'Occupation <= 2.0\ngini = 0.194\nsamples = 19\nvalue = [1, 17, 1, 0]\nclass = (1, 1)'),
#  Text(163.1578947368421, 249.1500000000001, 'Hours per week <= 47.5\ngini = 0.255\nsamples = 14\nvalue = [1, 12, 1, 0]\nclass = (1, 1)'),
#  Text(152.28070175438597, 203.85000000000002, 'Age <= 38.5\ngini = 0.272\nsamples = 13\nvalue = [1, 11, 1, 0]\nclass = (1, 1)'),
#  Text(141.40350877192984, 158.55000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(163.1578947368421, 158.55000000000007, 'Age <= 45.5\ngini = 0.292\nsamples = 12\nvalue = [1, 10, 1, 0]\nclass = (1, 1)'),
#  Text(152.28070175438597, 113.25, 'gini = 0.314\nsamples = 11\nvalue = [1, 9, 1, 0]\nclass = (1, 1)'),
#  Text(174.03508771929825, 113.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(174.03508771929825, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(184.91228070175438, 249.1500000000001, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]\nclass = (1, 1)'),
#  Text(206.66666666666666, 339.75, 'Marital Status <= 3.0\ngini = 0.5\nsamples = 6\nvalue = [0, 3, 3, 0]\nclass = (1, 1)'),
#  Text(195.78947368421052, 294.45000000000005, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(217.5438596491228, 294.45000000000005, 'Occupation <= 2.0\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3, 0]\nclass = (1, 0)'),
#  Text(206.66666666666666, 249.1500000000001, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0]\nclass = (1, 0)'),
#  Text(228.42105263157896, 249.1500000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(138.68421052631578, 430.35, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(149.56140350877192, 475.65000000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(160.43859649122808, 520.95, 'gini = 0.0\nsamples = 12\nvalue = [0, 12, 0, 0]\nclass = (1, 1)'),
#  Text(555.4166666666666, 792.75, 'Education-Num <= 10.5\ngini = 0.235\nsamples = 610\nvalue = [36, 531, 34, 9]\nclass = (1, 1)'),
#  Text(469.75877192982455, 747.45, 'Capital Gain <= 4736.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1, 0, 0]\nclass = (0, 0)'),
#  Text(458.88157894736844, 702.15, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]\nclass = (0, 0)'),
#  Text(480.6359649122807, 702.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(641.0745614035088, 747.45, 'Relationship <= 3.5\ngini = 0.217\nsamples = 601\nvalue = [28, 530, 34, 9]\nclass = (1, 1)'),
#  Text(502.390350877193, 702.15, 'Education-Num <= 13.5\ngini = 0.475\nsamples = 176\nvalue = [17, 123, 28, 8]\nclass = (1, 1)'),
#  Text(390.219298245614, 656.85, 'Marital Status <= 3.0\ngini = 0.69\nsamples = 85\nvalue = [17, 35, 26, 7]\nclass = (1, 1)'),
#  Text(293.6842105263158, 611.55, 'Workclass <= 4.5\ngini = 0.518\nsamples = 43\nvalue = [1, 19, 23, 0]\nclass = (1, 0)'),
#  Text(239.2982456140351, 566.25, 'Country <= 38.0\ngini = 0.32\nsamples = 10\nvalue = [0, 8, 2, 0]\nclass = (1, 1)'),
#  Text(228.42105263157896, 520.95, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(250.17543859649123, 520.95, 'Workclass <= 3.5\ngini = 0.198\nsamples = 9\nvalue = [0, 8, 1, 0]\nclass = (1, 1)'),
#  Text(239.2982456140351, 475.65000000000003, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = (1, 1)'),
#  Text(261.0526315789474, 475.65000000000003, 'Marital Status <= 1.0\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1, 0]\nclass = (1, 1)'),
#  Text(250.17543859649123, 430.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(271.9298245614035, 430.35, 'Occupation <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1, 0]\nclass = (1, 1)'),
#  Text(261.0526315789474, 385.05000000000007, 'Hours per week <= 45.0\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]\nclass = (1, 1)'),
#  Text(250.17543859649123, 339.75, 'Age <= 40.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]\nclass = (1, 1)'),
#  Text(239.2982456140351, 294.45000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(261.0526315789474, 294.45000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(271.9298245614035, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(282.8070175438597, 385.05000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(348.0701754385965, 566.25, 'Capital Loss <= 325.0\ngini = 0.483\nsamples = 33\nvalue = [1, 11, 21, 0]\nclass = (1, 0)'),
#  Text(337.1929824561403, 520.95, 'Age <= 40.5\ngini = 0.438\nsamples = 30\nvalue = [1, 8, 21, 0]\nclass = (1, 0)'),
#  Text(304.56140350877195, 475.65000000000003, 'Education-Num <= 12.5\ngini = 0.299\nsamples = 23\nvalue = [1, 3, 19, 0]\nclass = (1, 0)'),
#  Text(293.6842105263158, 430.35, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(315.43859649122805, 430.35, 'Race <= 2.5\ngini = 0.236\nsamples = 22\nvalue = [0, 3, 19, 0]\nclass = (1, 0)'),
#  Text(304.56140350877195, 385.05000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(326.3157894736842, 385.05000000000007, 'Marital Status <= 1.0\ngini = 0.172\nsamples = 21\nvalue = [0, 2, 19, 0]\nclass = (1, 0)'),
#  Text(315.43859649122805, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(337.1929824561403, 339.75, 'Occupation <= 1.5\ngini = 0.095\nsamples = 20\nvalue = [0, 1, 19, 0]\nclass = (1, 0)'),
#  Text(326.3157894736842, 294.45000000000005, 'Age <= 38.5\ngini = 0.142\nsamples = 13\nvalue = [0, 1, 12, 0]\nclass = (1, 0)'),
#  Text(315.43859649122805, 249.1500000000001, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = (1, 0)'),
#  Text(337.1929824561403, 249.1500000000001, 'Workclass <= 6.5\ngini = 0.18\nsamples = 10\nvalue = [0, 1, 9, 0]\nclass = (1, 0)'),
#  Text(326.3157894736842, 203.85000000000002, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = (1, 0)'),
#  Text(348.0701754385965, 203.85000000000002, 'Hours per week <= 39.0\ngini = 0.219\nsamples = 8\nvalue = [0, 1, 7, 0]\nclass = (1, 0)'),
#  Text(337.1929824561403, 158.55000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(358.94736842105266, 158.55000000000007, 'Age <= 39.5\ngini = 0.245\nsamples = 7\nvalue = [0, 1, 6, 0]\nclass = (1, 0)'),
#  Text(348.0701754385965, 113.25, 'Race <= 3.5\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5, 0]\nclass = (1, 0)'),
#  Text(337.1929824561403, 67.95000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(358.94736842105266, 67.95000000000005, 'Occupation <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0]\nclass = (1, 0)'),
#  Text(348.0701754385965, 22.65000000000009, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(369.82456140350877, 22.65000000000009, 'gini = 0.375\nsamples = 4\nvalue = [0, 1, 3, 0]\nclass = (1, 0)'),
#  Text(369.82456140350877, 113.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(348.0701754385965, 294.45000000000005, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0]\nclass = (1, 0)'),
#  Text(369.82456140350877, 475.65000000000003, 'Education-Num <= 12.5\ngini = 0.408\nsamples = 7\nvalue = [0, 5, 2, 0]\nclass = (1, 1)'),
#  Text(358.94736842105266, 430.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(380.70175438596493, 430.35, 'Age <= 41.5\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1, 0]\nclass = (1, 1)'),
#  Text(369.82456140350877, 385.05000000000007, 'Hours per week <= 59.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]\nclass = (1, 1)'),
#  Text(358.94736842105266, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(380.70175438596493, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(391.57894736842104, 385.05000000000007, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = (1, 1)'),
#  Text(358.94736842105266, 520.95, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = (1, 1)'),
#  Text(486.7543859649123, 611.55, 'Race <= 3.5\ngini = 0.677\nsamples = 42\nvalue = [16, 16, 3, 7]\nclass = (0, 0)'),
#  Text(424.2105263157895, 566.25, 'Race <= 2.5\ngini = 0.314\nsamples = 11\nvalue = [9, 0, 1, 1]\nclass = (0, 0)'),
#  Text(402.4561403508772, 520.95, 'Occupation <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = (0, 0)'),
#  Text(391.57894736842104, 475.65000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(413.3333333333333, 475.65000000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(445.96491228070175, 520.95, 'Age <= 42.5\ngini = 0.198\nsamples = 9\nvalue = [8, 0, 1, 0]\nclass = (0, 0)'),
#  Text(435.0877192982456, 475.65000000000003, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = (0, 0)'),
#  Text(456.8421052631579, 475.65000000000003, 'Hours per week <= 36.0\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0]\nclass = (0, 0)'),
#  Text(445.96491228070175, 430.35, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(467.719298245614, 430.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(549.2982456140351, 566.25, 'Age <= 40.5\ngini = 0.641\nsamples = 31\nvalue = [7, 16, 2, 6]\nclass = (1, 1)'),
#  Text(522.1052631578948, 520.95, 'Workclass <= 5.0\ngini = 0.69\nsamples = 22\nvalue = [7, 8, 1, 6]\nclass = (1, 1)'),
#  Text(500.35087719298247, 475.65000000000003, 'Workclass <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1, 0]\nclass = (1, 1)'),
#  Text(489.4736842105263, 430.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(511.2280701754386, 430.35, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = (1, 1)'),
#  Text(543.859649122807, 475.65000000000003, 'Capital Gain <= 3412.0\ngini = 0.651\nsamples = 17\nvalue = [7, 4, 0, 6]\nclass = (0, 0)'),
#  Text(532.9824561403509, 430.35, 'Hours per week <= 44.0\ngini = 0.604\nsamples = 15\nvalue = [7, 2, 0, 6]\nclass = (0, 0)'),
#  Text(522.1052631578948, 385.05000000000007, 'Workclass <= 6.5\ngini = 0.497\nsamples = 13\nvalue = [7, 0, 0, 6]\nclass = (0, 0)'),
#  Text(511.2280701754386, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(532.9824561403509, 339.75, 'Country <= 34.5\ngini = 0.486\nsamples = 12\nvalue = [7, 0, 0, 5]\nclass = (0, 0)'),
#  Text(522.1052631578948, 294.45000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(543.859649122807, 294.45000000000005, 'Occupation <= 3.5\ngini = 0.463\nsamples = 11\nvalue = [7, 0, 0, 4]\nclass = (0, 0)'),
#  Text(532.9824561403509, 249.1500000000001, 'Age <= 37.5\ngini = 0.375\nsamples = 8\nvalue = [6, 0, 0, 2]\nclass = (0, 0)'),
#  Text(522.1052631578948, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(543.859649122807, 203.85000000000002, 'Occupation <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [5, 0, 0, 2]\nclass = (0, 0)'),
#  Text(532.9824561403509, 158.55000000000007, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(554.7368421052631, 158.55000000000007, 'Occupation <= 2.0\ngini = 0.444\nsamples = 6\nvalue = [4, 0, 0, 2]\nclass = (0, 0)'),
#  Text(543.859649122807, 113.25, 'Education-Num <= 12.5\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 0, 2]\nclass = (0, 0)'),
#  Text(532.9824561403509, 67.95000000000005, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(554.7368421052631, 67.95000000000005, 'gini = 0.5\nsamples = 4\nvalue = [2, 0, 0, 2]\nclass = (0, 0)'),
#  Text(565.6140350877193, 113.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(554.7368421052631, 249.1500000000001, 'gini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2]\nclass = (0, 1)'),
#  Text(543.859649122807, 385.05000000000007, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(554.7368421052631, 430.35, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(576.4912280701755, 520.95, 'Hours per week <= 25.5\ngini = 0.198\nsamples = 9\nvalue = [0, 8, 1, 0]\nclass = (1, 1)'),
#  Text(565.6140350877193, 475.65000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(587.3684210526316, 475.65000000000003, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0]\nclass = (1, 1)'),
#  Text(614.561403508772, 656.85, 'Race <= 1.5\ngini = 0.064\nsamples = 91\nvalue = [0, 88, 2, 1]\nclass = (1, 1)'),
#  Text(581.9298245614035, 611.55, 'Workclass <= 6.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = (1, 1)'),
#  Text(571.0526315789474, 566.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(592.8070175438596, 566.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(647.1929824561404, 611.55, 'Age <= 35.5\ngini = 0.044\nsamples = 89\nvalue = [0, 87, 2, 0]\nclass = (1, 1)'),
#  Text(614.561403508772, 566.25, 'Marital Status <= 3.0\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1, 0]\nclass = (1, 1)'),
#  Text(603.6842105263158, 520.95, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = (1, 1)'),
#  Text(625.438596491228, 520.95, 'Age <= 33.0\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]\nclass = (1, 1)'),
#  Text(614.561403508772, 475.65000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(636.3157894736842, 475.65000000000003, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]\nclass = (1, 1)'),
#  Text(679.8245614035088, 566.25, 'Age <= 40.0\ngini = 0.024\nsamples = 83\nvalue = [0, 82, 1, 0]\nclass = (1, 1)'),
#  Text(668.9473684210526, 520.95, 'Occupation <= 2.0\ngini = 0.034\nsamples = 58\nvalue = [0, 57, 1, 0]\nclass = (1, 1)'),
#  Text(658.0701754385965, 475.65000000000003, 'Workclass <= 6.5\ngini = 0.05\nsamples = 39\nvalue = [0, 38, 1, 0]\nclass = (1, 1)'),
#  Text(647.1929824561404, 430.35, 'gini = 0.0\nsamples = 14\nvalue = [0, 14, 0, 0]\nclass = (1, 1)'),
#  Text(668.9473684210526, 430.35, 'Marital Status <= 3.5\ngini = 0.077\nsamples = 25\nvalue = [0, 24, 1, 0]\nclass = (1, 1)'),
#  Text(658.0701754385965, 385.05000000000007, 'gini = 0.0\nsamples = 9\nvalue = [0, 9, 0, 0]\nclass = (1, 1)'),
#  Text(679.8245614035088, 385.05000000000007, 'Education-Num <= 14.5\ngini = 0.117\nsamples = 16\nvalue = [0, 15, 1, 0]\nclass = (1, 1)'),
#  Text(668.9473684210526, 339.75, 'Hours per week <= 42.0\ngini = 0.142\nsamples = 13\nvalue = [0, 12, 1, 0]\nclass = (1, 1)'),
#  Text(658.0701754385965, 294.45000000000005, 'Age <= 38.5\ngini = 0.165\nsamples = 11\nvalue = [0, 10, 1, 0]\nclass = (1, 1)'),
#  Text(647.1929824561404, 249.1500000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(668.9473684210526, 249.1500000000001, 'Capital Gain <= 8599.0\ngini = 0.198\nsamples = 9\nvalue = [0, 8, 1, 0]\nclass = (1, 1)'),
#  Text(658.0701754385965, 203.85000000000002, 'Country <= 37.0\ngini = 0.219\nsamples = 8\nvalue = [0, 7, 1, 0]\nclass = (1, 1)'),
#  Text(647.1929824561404, 158.55000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(668.9473684210526, 158.55000000000007, 'gini = 0.245\nsamples = 7\nvalue = [0, 6, 1, 0]\nclass = (1, 1)'),
#  Text(679.8245614035088, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(679.8245614035088, 294.45000000000005, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(690.7017543859649, 339.75, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = (1, 1)'),
#  Text(679.8245614035088, 475.65000000000003, 'gini = 0.0\nsamples = 19\nvalue = [0, 19, 0, 0]\nclass = (1, 1)'),
#  Text(690.7017543859649, 520.95, 'gini = 0.0\nsamples = 25\nvalue = [0, 25, 0, 0]\nclass = (1, 1)'),
#  Text(779.7587719298245, 702.15, 'Age <= 29.0\ngini = 0.082\nsamples = 425\nvalue = [11, 407, 6, 1]\nclass = (1, 1)'),
#  Text(723.3333333333334, 656.85, 'Occupation <= 2.5\ngini = 0.494\nsamples = 9\nvalue = [6, 2, 1, 0]\nclass = (0, 0)'),
#  Text(712.4561403508771, 611.55, 'Education-Num <= 12.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2, 0, 0]\nclass = (0, 0)'),
#  Text(701.578947368421, 566.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(723.3333333333334, 566.25, 'Marital Status <= 3.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1, 0, 0]\nclass = (0, 0)'),
#  Text(712.4561403508771, 520.95, 'Age <= 22.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]\nclass = (0, 0)'),
#  Text(701.578947368421, 475.65000000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(723.3333333333334, 475.65000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(734.2105263157895, 520.95, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = (0, 0)'),
#  Text(734.2105263157895, 611.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(836.1842105263158, 656.85, 'Marital Status <= 5.5\ngini = 0.052\nsamples = 416\nvalue = [5, 405, 5, 1]\nclass = (1, 1)'),
#  Text(802.1929824561404, 611.55, 'Capital Gain <= 1087.0\ngini = 0.043\nsamples = 413\nvalue = [5, 404, 3, 1]\nclass = (1, 1)'),
#  Text(766.8421052631579, 566.25, 'Race <= 3.5\ngini = 0.408\nsamples = 14\nvalue = [4, 10, 0, 0]\nclass = (1, 1)'),
#  Text(755.9649122807018, 520.95, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(777.719298245614, 520.95, 'Marital Status <= 4.5\ngini = 0.355\nsamples = 13\nvalue = [3, 10, 0, 0]\nclass = (1, 1)'),
#  Text(766.8421052631579, 475.65000000000003, 'Country <= 32.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10, 0, 0]\nclass = (1, 1)'),
#  Text(755.9649122807018, 430.35, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(777.719298245614, 430.35, 'Workclass <= 6.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10, 0, 0]\nclass = (1, 1)'),
#  Text(766.8421052631579, 385.05000000000007, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = (1, 1)'),
#  Text(788.5964912280701, 385.05000000000007, 'Education-Num <= 13.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6, 0, 0]\nclass = (1, 1)'),
#  Text(777.719298245614, 339.75, 'Age <= 54.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3, 0, 0]\nclass = (1, 1)'),
#  Text(766.8421052631579, 294.45000000000005, 'Hours per week <= 50.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0]\nclass = (1, 1)'),
#  Text(755.9649122807018, 249.1500000000001, 'Marital Status <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]\nclass = (0, 0)'),
#  Text(745.0877192982456, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(766.8421052631579, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(777.719298245614, 249.1500000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(788.5964912280701, 294.45000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(799.4736842105264, 339.75, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = (1, 1)'),
#  Text(788.5964912280701, 475.65000000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(837.5438596491229, 566.25, 'Hours per week <= 17.5\ngini = 0.025\nsamples = 399\nvalue = [1, 394, 3, 1]\nclass = (1, 1)'),
#  Text(826.6666666666666, 520.95, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(848.421052631579, 520.95, 'Education-Num <= 12.5\ngini = 0.02\nsamples = 398\nvalue = [0, 394, 3, 1]\nclass = (1, 1)'),
#  Text(810.3508771929825, 475.65000000000003, 'Country <= 21.5\ngini = 0.32\nsamples = 10\nvalue = [0, 8, 2, 0]\nclass = (1, 1)'),
#  Text(799.4736842105264, 430.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(821.2280701754386, 430.35, 'Education-Num <= 11.5\ngini = 0.198\nsamples = 9\nvalue = [0, 8, 1, 0]\nclass = (1, 1)'),
#  Text(810.3508771929825, 385.05000000000007, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = (1, 1)'),
#  Text(832.1052631578948, 385.05000000000007, 'Workclass <= 5.5\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1, 0]\nclass = (1, 1)'),
#  Text(821.2280701754386, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(842.9824561403509, 339.75, 'Occupation <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1, 0]\nclass = (1, 1)'),
#  Text(832.1052631578948, 294.45000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(853.859649122807, 294.45000000000005, 'Relationship <= 4.5\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1, 0]\nclass = (1, 1)'),
#  Text(842.9824561403509, 249.1500000000001, 'Hours per week <= 45.0\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]\nclass = (1, 1)'),
#  Text(832.1052631578948, 203.85000000000002, 'Capital Gain <= 2792.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]\nclass = (1, 1)'),
#  Text(821.2280701754386, 158.55000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(842.9824561403509, 158.55000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(853.859649122807, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(864.7368421052631, 249.1500000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(886.4912280701755, 475.65000000000003, 'Hours per week <= 32.5\ngini = 0.01\nsamples = 388\nvalue = [0, 386, 1, 1]\nclass = (1, 1)'),
#  Text(864.7368421052631, 430.35, 'Marital Status <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]\nclass = (1, 1)'),
#  Text(853.859649122807, 385.05000000000007, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(875.6140350877193, 385.05000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(908.2456140350877, 430.35, 'Race <= 1.5\ngini = 0.005\nsamples = 385\nvalue = [0, 384, 0, 1]\nclass = (1, 1)'),
#  Text(897.3684210526316, 385.05000000000007, 'Hours per week <= 39.0\ngini = 0.142\nsamples = 13\nvalue = [0, 12, 0, 1]\nclass = (1, 1)'),
#  Text(886.4912280701755, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(908.2456140350877, 339.75, 'gini = 0.0\nsamples = 12\nvalue = [0, 12, 0, 0]\nclass = (1, 1)'),
#  Text(919.1228070175439, 385.05000000000007, 'gini = 0.0\nsamples = 372\nvalue = [0, 372, 0, 0]\nclass = (1, 1)'),
#  Text(870.1754385964912, 611.55, 'Age <= 56.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0]\nclass = (1, 0)'),
#  Text(859.2982456140351, 566.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = (1, 0)'),
#  Text(881.0526315789474, 566.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)')]
