# %%
import pandas as pd
import numpy as np
import scipy as sp
import pickle
import cloudpickle
import matplotlib.pyplot as plt
from IPython.display import display
from comparers import ModelComparer, plot_decision_boundary
from tasks.cluster_example import make_task

# %%
clf_a, clf_b, X, y, feature_names = make_task()

# %%
comparer = ModelComparer(clf_a, clf_b, feature_names)

# %%
comparer.plot_individual_clf_decision_boundaries(X)

# %%
comparer.plot_decision_boundaries(X)

# %% [markdown]
# ground truth:
# - difference #1:
#     - 1.1: $-10 < x1, x1 ≤ 0, 0 < x2, x2 ≤ 10 \rightarrow (0,1)$
#     - 1.2: $-10 < x1, x1 ≤ 0, -10 < x2, x2 ≤ 0 \rightarrow (0,1)$
#     - 1.3: $-10 < x1, x1 ≤ 0, -20 < x2, x2 ≤ -10 \rightarrow (0,1)$
#     - 1.4: $-20 < x1, x1 ≤ -10, -10 < x2, x2 ≤ 0 \rightarrow (0,1)$
# - difference #2: $-60 < x1, x1 ≤ -50, 0 < x2, x2 ≤ 10 \rightarrow (0,1)$
# - difference #3: $0 < x1, x1 ≤ 10, 0 < x2, x2 ≤ 10 \rightarrow (1,0)$

# %% [markdown]
# I have split difference #1 into equally sized parts, although they could be described by only two rules. But there are multiple ways to do that. I will consider any of them correct. Selectiveness will be measured compared to the minimum number of rules possible.

# %%
comparer.plot_confusion_matrix(X)
