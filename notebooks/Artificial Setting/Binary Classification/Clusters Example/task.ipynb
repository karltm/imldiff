# %%
import pandas as pd
import numpy as np
import scipy as sp
import pickle
import cloudpickle
import matplotlib.pyplot as plt
from IPython.display import display
from comparers import ModelComparer, plot_decision_boundary
from tasks.cluster_example import make_task

# %%
clf_a, clf_b, X, y, feature_names = make_task()

# %%
comparer = ModelComparer(clf_a, clf_b, feature_names)

# %%
comparer.plot_individual_clf_decision_boundaries(X)

# %%
comparer.plot_decision_boundaries(X)

# %% [markdown]
# ground truth:
# - difference #1: $-10 < x1, x1 ≤ 0, -20 < x2, x2 ≤ 10 \rightarrow (0,1)$
# - difference #2: $-20 < x1, x1 ≤ -10, -10 < x2, x2 ≤ 0 \rightarrow (0,1)$
# - difference #3: $-60 < x1, x1 ≤ -50, 0 < x2, x2 ≤ 10 \rightarrow (0,1)$
# - difference #4: $0 < x1, x1 ≤ 10, 0 < x2, x2 ≤ 10 \rightarrow (1,0)$

# %%
comparer.plot_confusion_matrix(X)
