# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
import shap
import pickle
import cloudpickle
import numpy as np
from comparers import ModelComparer
from explainers import generate_shap_explanations
from plots import plot_decision_boundary, plot_2d, plot_feature_importance_bar, plot_feature_importance_scatter,\
                  plot_feature_effects, plot_forces
from util import calc_feature_order, calc_class_order, calc_instance_order
import pandas as pd
import diro2c
from data_generation.helper import prepare_df
from data_generation.neighborhood_generation import neighbor_generator
from enums.diff_classifier_method_type import diff_classifier_method_type
from mlxtend.plotting import plot_decision_regions
from sklearn.tree import plot_tree
import rule_extractor
shap.initjs()
# %matplotlib inline
task_name = '02'
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open(task_name + '.dataset', 'rb') as f:
    X, display_data, y, feature_names = pickle.load(f)
with open(task_name + '.models', 'rb') as f:
    comparer = pickle.load(f)

# %% [markdown]
# # Explain using Interpretability Methods

# %% [markdown]
# Prepare dataset for diro2c

# %%
idx_explain = 0

# %%
y = y.astype(str)
d = dict([(feature_name, feature_data)
          for feature_name, feature_data
          in zip(feature_names, [x for x in X.T])])
d |= {'y': y}
df = pd.DataFrame(d)
dataset = prepare_df(df, 'test', 'y')

# %% [markdown]
# ## Binary difference explanations

# %%
# %%time
diff_classifiers_info = diro2c.recognize_diff(idx_explain, X, dataset, comparer.clf_a, comparer.clf_b,
                                              diff_classifier_method_type.binary_diff_classifier,
                                              data_generation_function=neighbor_generator.get_genetic_neighborhood)
# Out:
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# CPU times: user 12min 26s, sys: 48.1 s, total: 13min 14s
# Wall time: 4min 20s

# %%
dc_info = diff_classifiers_info['binary_diff_classifer']
dc_full = dc_info['dc_full']
dc_test = dc_info['dc_test']
evaluation_info = dc_info['evaluation_info']

X_diff = evaluation_info['X']
y_diff = evaluation_info['y']

print(np.unique(y_diff, return_counts=True))
# Out:
# (array([0, 1]), array([1817,  659]))

# %%
value = 0
width = X.shape[0]
filler_feature_values = {1: value, 3: value, 4: value, 5: value, 6: value, 7: value, 8: value, 9: value, 10: value, 11: value}
filler_feature_ranges = {1: width, 3: width, 4: width, 5: width, 6: width, 7: width, 8: width, 9: width, 10: width, 11: width}

# %%
y_pred_a = comparer.clf_a.predict(X)
y_pred_b = comparer.clf_b.predict(X)

fig, ax = plt.subplots(1, 3, figsize=(21, 7))

fig = plot_decision_regions(X=X, y=y_pred_a.astype(np.int64), clf=comparer.clf_a, ax=ax[0], legend=2, feature_index=[0, 2], 
                            filler_feature_values=filler_feature_values, filler_feature_ranges=filler_feature_ranges)
ax[0].set_xlabel(feature_names[0])
ax[0].set_ylabel(feature_names[2])
plt.title('blackbox 1')

fig = plot_decision_regions(X=X, y=y_pred_b.astype(np.int64), clf=comparer.clf_b, ax=ax[1], legend=2, feature_index=[0, 2], 
                            filler_feature_values=filler_feature_values, filler_feature_ranges=filler_feature_ranges)
ax[0].set_xlabel(feature_names[0])
ax[0].set_ylabel(feature_names[2])
plt.title('blackbox 2')

fig = plot_decision_regions(X=X_diff, y=y_diff.astype(np.integer), clf=dc_full, ax=ax[2], legend=2, feature_index=[0, 2], 
                            filler_feature_values=filler_feature_values, filler_feature_ranges=filler_feature_ranges)
ax[0].set_xlabel(feature_names[0])
ax[0].set_ylabel(feature_names[2])
plt.title('binary diff-classifier')

plt.show()
# Out:
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# No contour levels were found within the data range.
# Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.

# %%
cn = ['no_diff', 'diff']
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(4, 4), dpi=300)
plot_tree(dc_full,
               feature_names=feature_names,
               class_names=cn,
               filled=True)
# Out:
# [Text(468.5403745229008, 886.304347826087, 'Relationship <= 2.5\ngini = 0.391\nsamples = 2476\nvalue = [1817, 659]\nclass = no_diff'),
#  Text(111.20288645038168, 846.9130434782609, 'Capital Gain <= 3880.0\ngini = 0.311\nsamples = 1529\nvalue = [1235, 294]\nclass = no_diff'),
#  Text(37.86259541984733, 807.5217391304348, 'Capital Loss <= 1881.5\ngini = 0.026\nsamples = 838\nvalue = [827, 11]\nclass = no_diff'),
#  Text(18.931297709923665, 768.1304347826087, 'Age <= 82.5\ngini = 0.002\nsamples = 826\nvalue = [825, 1]\nclass = no_diff'),
#  Text(9.465648854961833, 728.7391304347826, 'gini = 0.0\nsamples = 825\nvalue = [825, 0]\nclass = no_diff'),
#  Text(28.396946564885496, 728.7391304347826, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(56.79389312977099, 768.1304347826087, 'Capital Loss <= 2336.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = diff'),
#  Text(47.328244274809165, 728.7391304347826, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = diff'),
#  Text(66.25954198473283, 728.7391304347826, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(184.54317748091606, 807.5217391304348, 'Education-Num <= 10.5\ngini = 0.484\nsamples = 691\nvalue = [408, 283]\nclass = no_diff'),
#  Text(94.65648854961833, 768.1304347826087, 'Relationship <= 1.5\ngini = 0.032\nsamples = 122\nvalue = [2, 120]\nclass = diff'),
#  Text(85.19083969465649, 728.7391304347826, 'Capital Loss <= 1211.0\ngini = 0.016\nsamples = 121\nvalue = [1, 120]\nclass = diff'),
#  Text(75.72519083969466, 689.3478260869565, 'gini = 0.0\nsamples = 119\nvalue = [0, 119]\nclass = diff'),
#  Text(94.65648854961833, 689.3478260869565, 'Education-Num <= 7.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(85.19083969465649, 649.9565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(104.12213740458016, 649.9565217391305, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(104.12213740458016, 728.7391304347826, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(274.42986641221376, 768.1304347826087, 'Sex <= 0.5\ngini = 0.409\nsamples = 569\nvalue = [406, 163]\nclass = no_diff'),
#  Text(170.38167938931298, 728.7391304347826, 'Marital Status <= 3.5\ngini = 0.489\nsamples = 115\nvalue = [49, 66]\nclass = diff'),
#  Text(132.51908396946567, 689.3478260869565, 'Capital Loss <= 90.5\ngini = 0.245\nsamples = 21\nvalue = [18, 3]\nclass = no_diff'),
#  Text(123.05343511450383, 649.9565217391305, 'Age <= 46.5\ngini = 0.18\nsamples = 20\nvalue = [18, 2]\nclass = no_diff'),
#  Text(113.58778625954199, 610.5652173913044, 'Age <= 41.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = no_diff'),
#  Text(104.12213740458016, 571.1739130434783, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = no_diff'),
#  Text(123.05343511450383, 571.1739130434783, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(132.51908396946567, 610.5652173913044, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = no_diff'),
#  Text(141.98473282442748, 649.9565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(208.24427480916032, 689.3478260869565, 'Hours per week <= 52.5\ngini = 0.442\nsamples = 94\nvalue = [31, 63]\nclass = diff'),
#  Text(170.38167938931298, 649.9565217391305, 'Age <= 55.5\ngini = 0.355\nsamples = 78\nvalue = [18, 60]\nclass = diff'),
#  Text(151.45038167938932, 610.5652173913044, 'Capital Loss <= 1034.0\ngini = 0.23\nsamples = 68\nvalue = [9, 59]\nclass = diff'),
#  Text(141.98473282442748, 571.1739130434783, 'Relationship <= 0.5\ngini = 0.168\nsamples = 65\nvalue = [6, 59]\nclass = diff'),
#  Text(123.05343511450383, 531.7826086956522, 'Education-Num <= 15.0\ngini = 0.068\nsamples = 57\nvalue = [2, 55]\nclass = diff'),
#  Text(113.58778625954199, 492.3913043478261, 'Age <= 54.5\ngini = 0.035\nsamples = 56\nvalue = [1, 55]\nclass = diff'),
#  Text(104.12213740458016, 453.0, 'gini = 0.0\nsamples = 53\nvalue = [0, 53]\nclass = diff'),
#  Text(123.05343511450383, 453.0, 'Occupation <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = diff'),
#  Text(113.58778625954199, 413.60869565217394, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(132.51908396946567, 413.60869565217394, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(132.51908396946567, 492.3913043478261, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(160.91603053435117, 531.7826086956522, 'Age <= 40.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = no_diff'),
#  Text(151.45038167938932, 492.3913043478261, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = diff'),
#  Text(170.38167938931298, 492.3913043478261, 'Race <= 3.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = no_diff'),
#  Text(160.91603053435117, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(179.84732824427482, 453.0, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = no_diff'),
#  Text(160.91603053435117, 571.1739130434783, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = no_diff'),
#  Text(189.31297709923666, 610.5652173913044, 'Education-Num <= 12.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]\nclass = no_diff'),
#  Text(179.84732824427482, 571.1739130434783, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(198.77862595419847, 571.1739130434783, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = no_diff'),
#  Text(246.10687022900765, 649.9565217391305, 'Marital Status <= 5.5\ngini = 0.305\nsamples = 16\nvalue = [13, 3]\nclass = no_diff'),
#  Text(227.17557251908397, 610.5652173913044, 'Age <= 32.0\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = no_diff'),
#  Text(217.70992366412216, 571.1739130434783, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(236.6412213740458, 571.1739130434783, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = no_diff'),
#  Text(265.03816793893134, 610.5652173913044, 'Age <= 47.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = diff'),
#  Text(255.5725190839695, 571.1739130434783, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(274.5038167938931, 571.1739130434783, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(378.47805343511453, 728.7391304347826, 'Age <= 35.0\ngini = 0.336\nsamples = 454\nvalue = [357, 97]\nclass = no_diff'),
#  Text(302.90076335877865, 689.3478260869565, 'Hours per week <= 57.5\ngini = 0.287\nsamples = 23\nvalue = [4, 19]\nclass = diff'),
#  Text(293.4351145038168, 649.9565217391305, 'Age <= 27.5\ngini = 0.172\nsamples = 21\nvalue = [2, 19]\nclass = diff'),
#  Text(283.96946564885496, 610.5652173913044, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]\nclass = diff'),
#  Text(302.90076335877865, 610.5652173913044, 'Relationship <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = diff'),
#  Text(293.4351145038168, 571.1739130434783, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = diff'),
#  Text(312.3664122137405, 571.1739130434783, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(312.3664122137405, 649.9565217391305, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(454.0553435114504, 689.3478260869565, 'Age <= 40.5\ngini = 0.296\nsamples = 431\nvalue = [353, 78]\nclass = no_diff'),
#  Text(388.09160305343516, 649.9565217391305, 'Hours per week <= 44.5\ngini = 0.436\nsamples = 156\nvalue = [106, 50]\nclass = no_diff'),
#  Text(350.2290076335878, 610.5652173913044, 'Marital Status <= 2.5\ngini = 0.5\nsamples = 96\nvalue = [49, 47]\nclass = no_diff'),
#  Text(331.2977099236642, 571.1739130434783, 'Race <= 3.0\ngini = 0.087\nsamples = 22\nvalue = [21, 1]\nclass = no_diff'),
#  Text(321.83206106870233, 531.7826086956522, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(340.76335877862596, 531.7826086956522, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]\nclass = no_diff'),
#  Text(369.1603053435115, 571.1739130434783, 'Relationship <= 0.5\ngini = 0.47\nsamples = 74\nvalue = [28, 46]\nclass = diff'),
#  Text(359.69465648854964, 531.7826086956522, 'Capital Loss <= 943.5\ngini = 0.414\nsamples = 65\nvalue = [19, 46]\nclass = diff'),
#  Text(350.2290076335878, 492.3913043478261, 'Education-Num <= 13.5\ngini = 0.358\nsamples = 60\nvalue = [14, 46]\nclass = diff'),
#  Text(340.76335877862596, 453.0, 'Occupation <= 7.0\ngini = 0.293\nsamples = 56\nvalue = [10, 46]\nclass = diff'),
#  Text(317.0992366412214, 413.60869565217394, 'Capital Gain <= 4982.5\ngini = 0.059\nsamples = 33\nvalue = [1, 32]\nclass = diff'),
#  Text(307.63358778625957, 374.21739130434787, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(326.56488549618325, 374.21739130434787, 'gini = 0.0\nsamples = 32\nvalue = [0, 32]\nclass = diff'),
#  Text(364.42748091603056, 413.60869565217394, 'Workclass <= 6.5\ngini = 0.476\nsamples = 23\nvalue = [9, 14]\nclass = diff'),
#  Text(345.4961832061069, 374.21739130434787, 'Race <= 2.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = no_diff'),
#  Text(336.03053435114504, 334.82608695652175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(354.9618320610687, 334.82608695652175, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = no_diff'),
#  Text(383.35877862595424, 374.21739130434787, 'Occupation <= 12.5\ngini = 0.231\nsamples = 15\nvalue = [2, 13]\nclass = diff'),
#  Text(373.8931297709924, 334.82608695652175, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = diff'),
#  Text(392.8244274809161, 334.82608695652175, 'Hours per week <= 37.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = no_diff'),
#  Text(383.35877862595424, 295.4347826086956, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(402.29007633587787, 295.4347826086956, 'Capital Gain <= 7493.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = no_diff'),
#  Text(392.8244274809161, 256.0434782608696, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(411.7557251908397, 256.0434782608696, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(359.69465648854964, 453.0, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = no_diff'),
#  Text(369.1603053435115, 492.3913043478261, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = no_diff'),
#  Text(378.6259541984733, 531.7826086956522, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = no_diff'),
#  Text(425.9541984732825, 610.5652173913044, 'Capital Gain <= 7493.0\ngini = 0.095\nsamples = 60\nvalue = [57, 3]\nclass = no_diff'),
#  Text(407.0229007633588, 571.1739130434783, 'Hours per week <= 56.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = no_diff'),
#  Text(397.55725190839695, 531.7826086956522, 'Marital Status <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = diff'),
#  Text(388.09160305343516, 492.3913043478261, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(407.0229007633588, 492.3913043478261, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(416.48854961832063, 531.7826086956522, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(444.88549618320616, 571.1739130434783, 'Marital Status <= 5.5\ngini = 0.036\nsamples = 55\nvalue = [54, 1]\nclass = no_diff'),
#  Text(435.4198473282443, 531.7826086956522, 'gini = 0.0\nsamples = 47\nvalue = [47, 0]\nclass = no_diff'),
#  Text(454.35114503816794, 531.7826086956522, 'Hours per week <= 54.0\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = no_diff'),
#  Text(444.88549618320616, 492.3913043478261, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(463.8167938931298, 492.3913043478261, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = no_diff'),
#  Text(520.0190839694657, 649.9565217391305, 'Hours per week <= 32.5\ngini = 0.183\nsamples = 275\nvalue = [247, 28]\nclass = no_diff'),
#  Text(480.38167938931304, 610.5652173913044, 'Age <= 56.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = diff'),
#  Text(470.9160305343512, 571.1739130434783, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = diff'),
#  Text(489.8473282442748, 571.1739130434783, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(559.6564885496184, 610.5652173913044, 'Marital Status <= 4.5\ngini = 0.151\nsamples = 267\nvalue = [245, 22]\nclass = no_diff'),
#  Text(508.7786259541985, 571.1739130434783, 'Capital Gain <= 6238.0\ngini = 0.099\nsamples = 249\nvalue = [236, 13]\nclass = no_diff'),
#  Text(499.31297709923666, 531.7826086956522, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = diff'),
#  Text(518.2442748091603, 531.7826086956522, 'Education-Num <= 12.5\ngini = 0.078\nsamples = 246\nvalue = [236, 10]\nclass = no_diff'),
#  Text(482.74809160305347, 492.3913043478261, 'Age <= 46.0\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = no_diff'),
#  Text(473.2824427480916, 453.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(492.2137404580153, 453.0, 'Age <= 49.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = no_diff'),
#  Text(482.74809160305347, 413.60869565217394, 'Capital Loss <= 752.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = no_diff'),
#  Text(473.2824427480916, 374.21739130434787, 'Race <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(463.8167938931298, 334.82608695652175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(482.74809160305347, 334.82608695652175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(492.2137404580153, 374.21739130434787, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(501.67938931297715, 413.60869565217394, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = no_diff'),
#  Text(553.7404580152672, 492.3913043478261, 'Occupation <= 2.0\ngini = 0.058\nsamples = 236\nvalue = [229, 7]\nclass = no_diff'),
#  Text(544.2748091603054, 453.0, 'Age <= 46.5\ngini = 0.122\nsamples = 107\nvalue = [100, 7]\nclass = no_diff'),
#  Text(520.6106870229008, 413.60869565217394, 'Hours per week <= 42.0\ngini = 0.264\nsamples = 32\nvalue = [27, 5]\nclass = no_diff'),
#  Text(511.145038167939, 374.21739130434787, 'Marital Status <= 3.0\ngini = 0.351\nsamples = 22\nvalue = [17, 5]\nclass = no_diff'),
#  Text(501.67938931297715, 334.82608695652175, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = no_diff'),
#  Text(520.6106870229008, 334.82608695652175, 'Capital Loss <= 83.5\ngini = 0.43\nsamples = 16\nvalue = [11, 5]\nclass = no_diff'),
#  Text(511.145038167939, 295.4347826086956, 'Relationship <= 0.5\ngini = 0.486\nsamples = 12\nvalue = [7, 5]\nclass = no_diff'),
#  Text(501.67938931297715, 256.0434782608696, 'Capital Gain <= 7493.0\ngini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = no_diff'),
#  Text(492.2137404580153, 216.6521739130435, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(511.145038167939, 216.6521739130435, 'Occupation <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = no_diff'),
#  Text(501.67938931297715, 177.26086956521738, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(520.6106870229008, 177.26086956521738, 'Age <= 44.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = no_diff'),
#  Text(511.145038167939, 137.86956521739137, 'Workclass <= 5.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = no_diff'),
#  Text(501.67938931297715, 98.47826086956525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(520.6106870229008, 98.47826086956525, 'Education-Num <= 13.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = no_diff'),
#  Text(511.145038167939, 59.086956521739125, 'Age <= 41.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = diff'),
#  Text(501.67938931297715, 19.695652173913118, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(520.6106870229008, 19.695652173913118, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(530.0763358778627, 59.086956521739125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(530.0763358778627, 137.86956521739137, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(520.6106870229008, 256.0434782608696, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(530.0763358778627, 295.4347826086956, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = no_diff'),
#  Text(530.0763358778627, 374.21739130434787, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = no_diff'),
#  Text(567.9389312977099, 413.60869565217394, 'Race <= 1.5\ngini = 0.052\nsamples = 75\nvalue = [73, 2]\nclass = no_diff'),
#  Text(549.0076335877862, 374.21739130434787, 'Workclass <= 5.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = no_diff'),
#  Text(539.5419847328245, 334.82608695652175, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = no_diff'),
#  Text(558.4732824427481, 334.82608695652175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(586.8702290076336, 374.21739130434787, 'Capital Gain <= 7493.0\ngini = 0.028\nsamples = 71\nvalue = [70, 1]\nclass = no_diff'),
#  Text(577.4045801526718, 334.82608695652175, 'Workclass <= 6.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]\nclass = no_diff'),
#  Text(567.9389312977099, 295.4347826086956, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = no_diff'),
#  Text(586.8702290076336, 295.4347826086956, 'Age <= 50.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = no_diff'),
#  Text(577.4045801526718, 256.0434782608696, 'Marital Status <= 3.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = no_diff'),
#  Text(567.9389312977099, 216.6521739130435, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(586.8702290076336, 216.6521739130435, 'Relationship <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(577.4045801526718, 177.26086956521738, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(596.3358778625955, 177.26086956521738, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(596.3358778625955, 256.0434782608696, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = no_diff'),
#  Text(596.3358778625955, 334.82608695652175, 'gini = 0.0\nsamples = 53\nvalue = [53, 0]\nclass = no_diff'),
#  Text(563.2061068702291, 453.0, 'gini = 0.0\nsamples = 129\nvalue = [129, 0]\nclass = no_diff'),
#  Text(610.5343511450382, 571.1739130434783, 'Age <= 59.5\ngini = 0.5\nsamples = 18\nvalue = [9, 9]\nclass = no_diff'),
#  Text(601.0687022900764, 531.7826086956522, 'Education-Num <= 14.0\ngini = 0.375\nsamples = 12\nvalue = [3, 9]\nclass = diff'),
#  Text(591.6030534351146, 492.3913043478261, 'Relationship <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]\nclass = diff'),
#  Text(582.1374045801527, 453.0, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = diff'),
#  Text(601.0687022900764, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(610.5343511450382, 492.3913043478261, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(620.0, 531.7826086956522, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = no_diff'),
#  Text(825.8778625954199, 846.9130434782609, 'Capital Gain <= 7073.5\ngini = 0.474\nsamples = 947\nvalue = [582, 365]\nclass = no_diff'),
#  Text(759.6183206106871, 807.5217391304348, 'Capital Loss <= 1867.5\ngini = 0.477\nsamples = 582\nvalue = [228, 354]\nclass = diff'),
#  Text(674.4274809160306, 768.1304347826087, 'Capital Gain <= 2841.5\ngini = 0.288\nsamples = 424\nvalue = [74, 350]\nclass = diff'),
#  Text(643.6641221374047, 728.7391304347826, 'Education-Num <= 10.5\ngini = 0.24\nsamples = 395\nvalue = [55, 340]\nclass = diff'),
#  Text(620.0, 689.3478260869565, 'Capital Loss <= 924.0\ngini = 0.124\nsamples = 15\nvalue = [14, 1]\nclass = no_diff'),
#  Text(610.5343511450382, 649.9565217391305, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = no_diff'),
#  Text(629.4656488549618, 649.9565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(667.3282442748092, 689.3478260869565, 'Capital Gain <= 1263.0\ngini = 0.193\nsamples = 380\nvalue = [41, 339]\nclass = diff'),
#  Text(648.3969465648855, 649.9565217391305, 'Hours per week <= 70.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]\nclass = no_diff'),
#  Text(638.9312977099237, 610.5652173913044, 'Occupation <= 11.0\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = no_diff'),
#  Text(629.4656488549618, 571.1739130434783, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = no_diff'),
#  Text(648.3969465648855, 571.1739130434783, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(657.8625954198474, 610.5652173913044, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(686.2595419847329, 649.9565217391305, 'Hours per week <= 30.0\ngini = 0.154\nsamples = 368\nvalue = [31, 337]\nclass = diff'),
#  Text(676.793893129771, 610.5652173913044, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = no_diff'),
#  Text(695.7251908396947, 610.5652173913044, 'Age <= 28.5\ngini = 0.133\nsamples = 363\nvalue = [26, 337]\nclass = diff'),
#  Text(686.2595419847329, 571.1739130434783, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = no_diff'),
#  Text(705.1908396946566, 571.1739130434783, 'Sex <= 0.5\ngini = 0.11\nsamples = 358\nvalue = [21, 337]\nclass = diff'),
#  Text(664.9618320610688, 531.7826086956522, 'Relationship <= 3.5\ngini = 0.464\nsamples = 30\nvalue = [11, 19]\nclass = diff'),
#  Text(655.4961832061069, 492.3913043478261, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = no_diff'),
#  Text(674.4274809160306, 492.3913043478261, 'Marital Status <= 3.0\ngini = 0.417\nsamples = 27\nvalue = [8, 19]\nclass = diff'),
#  Text(664.9618320610688, 453.0, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = diff'),
#  Text(683.8931297709925, 453.0, 'Relationship <= 4.5\ngini = 0.488\nsamples = 19\nvalue = [8, 11]\nclass = diff'),
#  Text(674.4274809160306, 413.60869565217394, 'Education-Num <= 13.5\ngini = 0.473\nsamples = 13\nvalue = [8, 5]\nclass = no_diff'),
#  Text(664.9618320610688, 374.21739130434787, 'Education-Num <= 12.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = no_diff'),
#  Text(655.4961832061069, 334.82608695652175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(674.4274809160306, 334.82608695652175, 'Race <= 3.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = no_diff'),
#  Text(664.9618320610688, 295.4347826086956, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = no_diff'),
#  Text(683.8931297709925, 295.4347826086956, 'Age <= 40.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = no_diff'),
#  Text(674.4274809160306, 256.0434782608696, 'Age <= 38.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = no_diff'),
#  Text(664.9618320610688, 216.6521739130435, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(683.8931297709925, 216.6521739130435, 'Workclass <= 3.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = no_diff'),
#  Text(674.4274809160306, 177.26086956521738, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(693.3587786259543, 177.26086956521738, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = diff'),
#  Text(693.3587786259543, 256.0434782608696, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(683.8931297709925, 374.21739130434787, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(693.3587786259543, 413.60869565217394, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = diff'),
#  Text(745.4198473282444, 531.7826086956522, 'Race <= 0.5\ngini = 0.059\nsamples = 328\nvalue = [10, 318]\nclass = diff'),
#  Text(735.9541984732825, 492.3913043478261, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(754.8854961832062, 492.3913043478261, 'Relationship <= 3.5\ngini = 0.054\nsamples = 327\nvalue = [9, 318]\nclass = diff'),
#  Text(721.7557251908397, 453.0, 'Marital Status <= 2.5\ngini = 0.219\nsamples = 56\nvalue = [7, 49]\nclass = diff'),
#  Text(712.2900763358779, 413.60869565217394, 'gini = 0.0\nsamples = 43\nvalue = [0, 43]\nclass = diff'),
#  Text(731.2213740458016, 413.60869565217394, 'Education-Num <= 14.0\ngini = 0.497\nsamples = 13\nvalue = [7, 6]\nclass = no_diff'),
#  Text(721.7557251908397, 374.21739130434787, 'Age <= 49.0\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = no_diff'),
#  Text(712.2900763358779, 334.82608695652175, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = no_diff'),
#  Text(731.2213740458016, 334.82608695652175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(740.6870229007634, 374.21739130434787, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = diff'),
#  Text(788.0152671755726, 453.0, 'Hours per week <= 48.0\ngini = 0.015\nsamples = 271\nvalue = [2, 269]\nclass = diff'),
#  Text(769.0839694656489, 413.60869565217394, 'Education-Num <= 11.5\ngini = 0.007\nsamples = 268\nvalue = [1, 267]\nclass = diff'),
#  Text(759.6183206106871, 374.21739130434787, 'Race <= 3.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = diff'),
#  Text(750.1526717557252, 334.82608695652175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(769.0839694656489, 334.82608695652175, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = diff'),
#  Text(778.5496183206108, 374.21739130434787, 'gini = 0.0\nsamples = 264\nvalue = [0, 264]\nclass = diff'),
#  Text(806.9465648854963, 413.60869565217394, 'Age <= 42.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = diff'),
#  Text(797.4809160305344, 374.21739130434787, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(816.4122137404581, 374.21739130434787, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(705.1908396946566, 728.7391304347826, 'Education-Num <= 11.5\ngini = 0.452\nsamples = 29\nvalue = [19, 10]\nclass = no_diff'),
#  Text(695.7251908396947, 689.3478260869565, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = diff'),
#  Text(714.6564885496184, 689.3478260869565, 'Capital Gain <= 3214.0\ngini = 0.287\nsamples = 23\nvalue = [19, 4]\nclass = no_diff'),
#  Text(705.1908396946566, 649.9565217391305, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]\nclass = no_diff'),
#  Text(724.1221374045803, 649.9565217391305, 'Capital Gain <= 4601.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = diff'),
#  Text(714.6564885496184, 610.5652173913044, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = diff'),
#  Text(733.587786259542, 610.5652173913044, 'Marital Status <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = no_diff'),
#  Text(724.1221374045803, 571.1739130434783, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(743.0534351145038, 571.1739130434783, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(844.8091603053435, 768.1304347826087, 'Capital Loss <= 2298.5\ngini = 0.049\nsamples = 158\nvalue = [154, 4]\nclass = no_diff'),
#  Text(835.3435114503817, 728.7391304347826, 'Education-Num <= 11.0\ngini = 0.037\nsamples = 157\nvalue = [154, 3]\nclass = no_diff'),
#  Text(825.8778625954199, 689.3478260869565, 'Marital Status <= 5.0\ngini = 0.255\nsamples = 20\nvalue = [17, 3]\nclass = no_diff'),
#  Text(816.4122137404581, 649.9565217391305, 'Workclass <= 5.0\ngini = 0.188\nsamples = 19\nvalue = [17, 2]\nclass = no_diff'),
#  Text(806.9465648854963, 610.5652173913044, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = no_diff'),
#  Text(825.8778625954199, 610.5652173913044, 'Age <= 43.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = no_diff'),
#  Text(816.4122137404581, 571.1739130434783, 'Occupation <= 6.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = no_diff'),
#  Text(806.9465648854963, 531.7826086956522, 'Education-Num <= 9.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = diff'),
#  Text(797.4809160305344, 492.3913043478261, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(816.4122137404581, 492.3913043478261, 'Marital Status <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(806.9465648854963, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(825.8778625954199, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(825.8778625954199, 531.7826086956522, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(835.3435114503817, 571.1739130434783, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = no_diff'),
#  Text(835.3435114503817, 649.9565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(844.8091603053435, 689.3478260869565, 'gini = 0.0\nsamples = 137\nvalue = [137, 0]\nclass = no_diff'),
#  Text(854.2748091603054, 728.7391304347826, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(892.1374045801527, 807.5217391304348, 'Education-Num <= 9.5\ngini = 0.058\nsamples = 365\nvalue = [354, 11]\nclass = no_diff'),
#  Text(882.6717557251909, 768.1304347826087, 'Age <= 38.5\ngini = 0.471\nsamples = 29\nvalue = [18, 11]\nclass = no_diff'),
#  Text(873.2061068702291, 728.7391304347826, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = diff'),
#  Text(892.1374045801527, 728.7391304347826, 'Education-Num <= 5.0\ngini = 0.403\nsamples = 25\nvalue = [18, 7]\nclass = no_diff'),
#  Text(882.6717557251909, 689.3478260869565, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = diff'),
#  Text(901.6030534351146, 689.3478260869565, 'Occupation <= -0.5\ngini = 0.298\nsamples = 22\nvalue = [18, 4]\nclass = no_diff'),
#  Text(892.1374045801527, 649.9565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(911.0687022900764, 649.9565217391305, 'Capital Gain <= 7493.0\ngini = 0.245\nsamples = 21\nvalue = [18, 3]\nclass = no_diff'),
#  Text(901.6030534351146, 610.5652173913044, 'Education-Num <= 8.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = no_diff'),
#  Text(892.1374045801527, 571.1739130434783, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(911.0687022900764, 571.1739130434783, 'Age <= 43.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = no_diff'),
#  Text(901.6030534351146, 531.7826086956522, 'Marital Status <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(892.1374045801527, 492.3913043478261, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(911.0687022900764, 492.3913043478261, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(920.5343511450383, 531.7826086956522, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = no_diff'),
#  Text(920.5343511450383, 610.5652173913044, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = no_diff'),
#  Text(901.6030534351146, 768.1304347826087, 'gini = 0.0\nsamples = 336\nvalue = [336, 0]\nclass = no_diff')]

# %%
rule_extractor.print_rules_for_binary(
    dc_full, dataset['columns_for_decision_rules'], ['no_diff', 'diff'], 'diff')
# Out:
# {'diff': '{Relationship <= 2.5, Capital Gain <= 3880.0, Capital Loss <= 1881.5, Age > 82.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain <= 3880.0, Capital Loss > 1881.5, Capital Loss <= 2336.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num <= 10.5, Relationship <= 1.5, Capital Loss <= 1211.0}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num <= 10.5, Relationship <= 1.5, Capital Loss > 1211.0, Education-Num <= 7.0}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex <= 0.5, Marital Status <= 3.5, Capital Loss <= 90.5, Age <= 46.5, Age > 41.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex <= 0.5, Marital Status <= 3.5, Capital Loss > 90.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex <= 0.5, Marital Status > 3.5, Hours per week <= 52.5, Age <= 55.5, Capital Loss <= 1034.0, Relationship <= 0.5, Education-Num <= 15.0, Age <= 54.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex <= 0.5, Marital Status > 3.5, Hours per week <= 52.5, Age <= 55.5, Capital Loss <= 1034.0, Relationship <= 0.5, Education-Num <= 15.0, Age > 54.5, Occupation <= 3.0}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex <= 0.5, Marital Status > 3.5, Hours per week <= 52.5, Age <= 55.5, Capital Loss <= 1034.0, Relationship > 0.5, Age <= 40.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex <= 0.5, Marital Status > 3.5, Hours per week <= 52.5, Age <= 55.5, Capital Loss <= 1034.0, Relationship > 0.5, Age > 40.5, Race <= 3.0}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex <= 0.5, Marital Status > 3.5, Hours per week <= 52.5, Age > 55.5, Education-Num <= 12.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex <= 0.5, Marital Status > 3.5, Hours per week > 52.5, Marital Status <= 5.5, Age <= 32.0}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex <= 0.5, Marital Status > 3.5, Hours per week > 52.5, Marital Status > 5.5, Age <= 47.0}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age <= 35.0, Hours per week <= 57.5, Age <= 27.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age <= 35.0, Hours per week <= 57.5, Age > 27.5, Relationship <= 0.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age <= 40.5, Hours per week <= 44.5, Marital Status <= 2.5, Race <= 3.0}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age <= 40.5, Hours per week <= 44.5, Marital Status > 2.5, Relationship <= 0.5, Capital Loss <= 943.5, Education-Num <= 13.5, Occupation <= 7.0, Capital Gain > 4982.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age <= 40.5, Hours per week <= 44.5, Marital Status > 2.5, Relationship <= 0.5, Capital Loss <= 943.5, Education-Num <= 13.5, Occupation > 7.0, Workclass <= 6.5, Race <= 2.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age <= 40.5, Hours per week <= 44.5, Marital Status > 2.5, Relationship <= 0.5, Capital Loss <= 943.5, Education-Num <= 13.5, Occupation > 7.0, Workclass > 6.5, Occupation <= 12.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age <= 40.5, Hours per week <= 44.5, Marital Status > 2.5, Relationship <= 0.5, Capital Loss <= 943.5, Education-Num <= 13.5, Occupation > 7.0, Workclass > 6.5, Occupation > 12.5, Hours per week <= 37.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age <= 40.5, Hours per week > 44.5, Capital Gain <= 7493.0, Hours per week <= 56.5, Marital Status > 3.0}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age <= 40.5, Hours per week > 44.5, Capital Gain > 7493.0, Marital Status > 5.5, Hours per week <= 54.0}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age > 40.5, Hours per week <= 32.5, Age <= 56.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age > 40.5, Hours per week > 32.5, Marital Status <= 4.5, Capital Gain <= 6238.0}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age > 40.5, Hours per week > 32.5, Marital Status <= 4.5, Capital Gain > 6238.0, Education-Num <= 12.5, Age <= 46.0}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age > 40.5, Hours per week > 32.5, Marital Status <= 4.5, Capital Gain > 6238.0, Education-Num <= 12.5, Age > 46.0, Age <= 49.5, Capital Loss <= 752.0, Race > 2.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age > 40.5, Hours per week > 32.5, Marital Status <= 4.5, Capital Gain > 6238.0, Education-Num > 12.5, Occupation <= 2.0, Age <= 46.5, Hours per week <= 42.0, Marital Status > 3.0, Capital Loss <= 83.5, Relationship <= 0.5, Capital Gain <= 7493.0}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age > 40.5, Hours per week > 32.5, Marital Status <= 4.5, Capital Gain > 6238.0, Education-Num > 12.5, Occupation <= 2.0, Age <= 46.5, Hours per week <= 42.0, Marital Status > 3.0, Capital Loss <= 83.5, Relationship <= 0.5, Capital Gain > 7493.0, Occupation <= 0.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age > 40.5, Hours per week > 32.5, Marital Status <= 4.5, Capital Gain > 6238.0, Education-Num > 12.5, Occupation <= 2.0, Age <= 46.5, Hours per week <= 42.0, Marital Status > 3.0, Capital Loss <= 83.5, Relationship <= 0.5, Capital Gain > 7493.0, Occupation > 0.5, Age <= 44.5, Workclass > 5.5, Education-Num <= 13.5, Age > 41.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age > 40.5, Hours per week > 32.5, Marital Status <= 4.5, Capital Gain > 6238.0, Education-Num > 12.5, Occupation <= 2.0, Age > 46.5, Race <= 1.5, Workclass > 5.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age > 40.5, Hours per week > 32.5, Marital Status <= 4.5, Capital Gain > 6238.0, Education-Num > 12.5, Occupation <= 2.0, Age > 46.5, Race > 1.5, Capital Gain <= 7493.0, Workclass > 6.5, Age <= 50.5, Marital Status > 3.0, Relationship <= 0.5}'}
# {'diff': '{Relationship <= 2.5, Capital Gain > 3880.0, Education-Num > 10.5, Sex > 0.5, Age > 35.0, Age > 40.5, Hours per week > 32.5, Marital Status > 4.5, Age <= 59.5, Education-Num <= 14.0, Relationship <= 0.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num <= 10.5, Capital Loss > 924.0}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num > 10.5, Capital Gain <= 1263.0, Hours per week <= 70.0, Occupation > 11.0}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num > 10.5, Capital Gain <= 1263.0, Hours per week > 70.0}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num > 10.5, Capital Gain > 1263.0, Hours per week > 30.0, Age > 28.5, Sex <= 0.5, Relationship > 3.5, Marital Status <= 3.0}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num > 10.5, Capital Gain > 1263.0, Hours per week > 30.0, Age > 28.5, Sex <= 0.5, Relationship > 3.5, Marital Status > 3.0, Relationship <= 4.5, Education-Num <= 13.5, Education-Num <= 12.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num > 10.5, Capital Gain > 1263.0, Hours per week > 30.0, Age > 28.5, Sex <= 0.5, Relationship > 3.5, Marital Status > 3.0, Relationship <= 4.5, Education-Num <= 13.5, Education-Num > 12.5, Race > 3.5, Age <= 40.5, Age > 38.0, Workclass > 3.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num > 10.5, Capital Gain > 1263.0, Hours per week > 30.0, Age > 28.5, Sex <= 0.5, Relationship > 3.5, Marital Status > 3.0, Relationship <= 4.5, Education-Num > 13.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num > 10.5, Capital Gain > 1263.0, Hours per week > 30.0, Age > 28.5, Sex <= 0.5, Relationship > 3.5, Marital Status > 3.0, Relationship > 4.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num > 10.5, Capital Gain > 1263.0, Hours per week > 30.0, Age > 28.5, Sex > 0.5, Race > 0.5, Relationship <= 3.5, Marital Status <= 2.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num > 10.5, Capital Gain > 1263.0, Hours per week > 30.0, Age > 28.5, Sex > 0.5, Race > 0.5, Relationship <= 3.5, Marital Status > 2.5, Education-Num <= 14.0, Age > 49.0}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num > 10.5, Capital Gain > 1263.0, Hours per week > 30.0, Age > 28.5, Sex > 0.5, Race > 0.5, Relationship <= 3.5, Marital Status > 2.5, Education-Num > 14.0}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num > 10.5, Capital Gain > 1263.0, Hours per week > 30.0, Age > 28.5, Sex > 0.5, Race > 0.5, Relationship > 3.5, Hours per week <= 48.0, Education-Num <= 11.5, Race > 3.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num > 10.5, Capital Gain > 1263.0, Hours per week > 30.0, Age > 28.5, Sex > 0.5, Race > 0.5, Relationship > 3.5, Hours per week <= 48.0, Education-Num > 11.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain <= 2841.5, Education-Num > 10.5, Capital Gain > 1263.0, Hours per week > 30.0, Age > 28.5, Sex > 0.5, Race > 0.5, Relationship > 3.5, Hours per week > 48.0, Age <= 42.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain > 2841.5, Education-Num <= 11.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain > 2841.5, Education-Num > 11.5, Capital Gain > 3214.0, Capital Gain <= 4601.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss <= 1867.5, Capital Gain > 2841.5, Education-Num > 11.5, Capital Gain > 3214.0, Capital Gain > 4601.5, Marital Status <= 3.0}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss > 1867.5, Capital Loss <= 2298.5, Education-Num <= 11.0, Marital Status <= 5.0, Workclass > 5.0, Age <= 43.5, Occupation <= 6.5, Education-Num <= 9.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss > 1867.5, Capital Loss <= 2298.5, Education-Num <= 11.0, Marital Status <= 5.0, Workclass > 5.0, Age <= 43.5, Occupation <= 6.5, Education-Num > 9.5, Marital Status > 3.0}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss > 1867.5, Capital Loss <= 2298.5, Education-Num <= 11.0, Marital Status > 5.0}'}
# {'diff': '{Relationship > 2.5, Capital Gain <= 7073.5, Capital Loss > 1867.5, Capital Loss > 2298.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain > 7073.5, Education-Num <= 9.5, Age <= 38.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain > 7073.5, Education-Num <= 9.5, Age > 38.5, Education-Num <= 5.0}'}
# {'diff': '{Relationship > 2.5, Capital Gain > 7073.5, Education-Num <= 9.5, Age > 38.5, Education-Num > 5.0, Occupation <= -0.5}'}
# {'diff': '{Relationship > 2.5, Capital Gain > 7073.5, Education-Num <= 9.5, Age > 38.5, Education-Num > 5.0, Occupation > -0.5, Capital Gain <= 7493.0, Education-Num <= 8.0}'}
# {'diff': '{Relationship > 2.5, Capital Gain > 7073.5, Education-Num <= 9.5, Age > 38.5, Education-Num > 5.0, Occupation > -0.5, Capital Gain <= 7493.0, Education-Num > 8.0, Age <= 43.5, Marital Status > 2.0}'}

# %% [markdown]
# ## Multiclass difference explanations

# %%
multiclass_diff_names = ['(0, 0)', '(1, 1)', '(1, 0)', '(0, 1)']

# %%
# %%time
diff_classifiers_info = diro2c.recognize_diff(idx_explain, X, dataset, comparer.clf_a, comparer.clf_b,
                                              diff_classifier_method_type.multiclass_diff_classifier,
                                              data_generation_function=neighbor_generator.get_genetic_neighborhood)
# Out:
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption

# %%
dc_info = diff_classifiers_info['multiclass_diff_classifer']
dc_full = dc_info['dc_full']
dc_test = dc_info['dc_test']
evaluation_info = dc_info['evaluation_info']

X_diff = evaluation_info['X']
y_diff = evaluation_info['y']

print(np.unique(y_diff, return_counts=True))
# Out:
# (array([1, 2, 3, 4]), array([1024,  796,  377,  248]))

# %%
fig, ax = plt.subplots(1, 3, figsize=(21, 7))

fig = plot_decision_regions(X=X, y=y_pred_a.astype(np.int64), clf=comparer.clf_a, ax=ax[0], legend=2,
                            hide_spines=False, feature_index=[0, 2], 
                            filler_feature_values=filler_feature_values, filler_feature_ranges=filler_feature_ranges)
ax[0].set_xlabel(feature_names[0])
ax[0].set_ylabel(feature_names[2])
ax[0].set_title('black box A')

fig = plot_decision_regions(X=X, y=y_pred_b.astype(np.int64), clf=comparer.clf_b, ax=ax[1], legend=2,
                            hide_spines=False, feature_index=[0, 2], 
                            filler_feature_values=filler_feature_values, filler_feature_ranges=filler_feature_ranges)
ax[1].set_xlabel(feature_names[0])
ax[1].set_ylabel(feature_names[2])
ax[1].set_title('black box B')

fig = plot_decision_regions(X=X_diff, y=y_diff.astype(np.int64), clf=dc_full, ax=ax[2], legend=2, feature_index=[0, 2], 
                            filler_feature_values=filler_feature_values, filler_feature_ranges=filler_feature_ranges)
ax[2].set_xlabel(feature_names[0])
ax[2].set_ylabel(feature_names[2])
ax[2].set_title('multiclass diff-classifier')

handles, labels = ax[2].get_legend_handles_labels()
ax[2].legend(handles,
             multiclass_diff_names,
             framealpha=0.3, scatterpoints=1)

plt.show()
# Out:
# No contour levels were found within the data range.
# No contour levels were found within the data range.
# You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(4, 4), dpi=300)
plot_tree(dc_full,
               feature_names=feature_names,
               class_names=multiclass_diff_names,
               filled=True)
# Out:
# [Text(406.1343914762742, 875.8, 'Capital Gain <= 4250.5\ngini = 0.685\nsamples = 2445\nvalue = [1024, 796, 377, 248]\nclass = (0, 0)'),
#  Text(94.23605008787347, 815.4, 'Relationship <= 2.5\ngini = 0.412\nsamples = 1420\nvalue = [1022, 16, 375, 7]\nclass = (0, 0)'),
#  Text(26.151142355008787, 755.0, 'Education-Num <= 15.5\ngini = 0.008\nsamples = 966\nvalue = [962, 0, 2, 2]\nclass = (0, 0)'),
#  Text(13.075571177504393, 694.6, 'Capital Loss <= 1746.0\ngini = 0.002\nsamples = 961\nvalue = [960, 0, 0, 1]\nclass = (0, 0)'),
#  Text(6.537785588752197, 634.2, 'gini = 0.0\nsamples = 955\nvalue = [955, 0, 0, 0]\nclass = (0, 0)'),
#  Text(19.61335676625659, 634.2, 'Capital Gain <= 1087.0\ngini = 0.278\nsamples = 6\nvalue = [5, 0, 0, 1]\nclass = (0, 0)'),
#  Text(13.075571177504393, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(26.151142355008787, 573.8, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = (0, 0)'),
#  Text(39.22671353251318, 694.6, 'Sex <= 0.5\ngini = 0.64\nsamples = 5\nvalue = [2, 0, 2, 1]\nclass = (0, 0)'),
#  Text(32.68892794376099, 634.2, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = (0, 0)'),
#  Text(45.764499121265374, 634.2, 'Relationship <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1]\nclass = (1, 0)'),
#  Text(39.22671353251318, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(52.302284710017574, 573.8, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = (1, 0)'),
#  Text(162.32095782073813, 755.0, 'Capital Gain <= 1087.0\ngini = 0.306\nsamples = 454\nvalue = [60, 16, 373, 5]\nclass = (1, 0)'),
#  Text(101.33567662565905, 694.6, 'Workclass <= 6.5\ngini = 0.668\nsamples = 29\nvalue = [7, 14, 3, 5]\nclass = (1, 1)'),
#  Text(71.91564147627416, 634.2, 'Occupation <= -0.5\ngini = 0.379\nsamples = 13\nvalue = [0, 10, 1, 2]\nclass = (1, 1)'),
#  Text(65.37785588752197, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(78.45342706502636, 573.8, 'Age <= 38.5\ngini = 0.278\nsamples = 12\nvalue = [0, 10, 0, 2]\nclass = (1, 1)'),
#  Text(71.91564147627416, 513.4000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(84.99121265377856, 513.4000000000001, 'Marital Status <= 4.5\ngini = 0.165\nsamples = 11\nvalue = [0, 10, 0, 1]\nclass = (1, 1)'),
#  Text(78.45342706502636, 453.0, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0, 0]\nclass = (1, 1)'),
#  Text(91.52899824253075, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(130.75571177504395, 634.2, 'Marital Status <= 3.0\ngini = 0.695\nsamples = 16\nvalue = [7, 4, 2, 3]\nclass = (0, 0)'),
#  Text(117.68014059753955, 573.8, 'Capital Loss <= 870.0\ngini = 0.667\nsamples = 6\nvalue = [0, 2, 2, 2]\nclass = (1, 1)'),
#  Text(111.14235500878735, 513.4000000000001, 'Age <= 45.0\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 0, 2]\nclass = (1, 1)'),
#  Text(104.60456942003515, 453.0, 'Occupation <= 6.5\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2]\nclass = (0, 1)'),
#  Text(98.06678383128295, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = (0, 1)'),
#  Text(111.14235500878735, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(117.68014059753955, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(124.21792618629173, 513.4000000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = (1, 0)'),
#  Text(143.83128295254832, 573.8, 'Hours per week <= 50.0\ngini = 0.46\nsamples = 10\nvalue = [7, 2, 0, 1]\nclass = (0, 0)'),
#  Text(137.29349736379612, 513.4000000000001, 'Country <= 33.0\ngini = 0.219\nsamples = 8\nvalue = [7, 0, 0, 1]\nclass = (0, 0)'),
#  Text(130.75571177504395, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(143.83128295254832, 453.0, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = (0, 0)'),
#  Text(150.36906854130052, 513.4000000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(223.30623901581723, 694.6, 'Sex <= 0.5\ngini = 0.227\nsamples = 425\nvalue = [53, 2, 370, 0]\nclass = (1, 0)'),
#  Text(186.3268892794376, 634.2, 'Marital Status <= 3.0\ngini = 0.5\nsamples = 65\nvalue = [32, 0, 33, 0]\nclass = (1, 0)'),
#  Text(169.98242530755712, 573.8, 'Education-Num <= 12.5\ngini = 0.255\nsamples = 20\nvalue = [3, 0, 17, 0]\nclass = (1, 0)'),
#  Text(163.44463971880492, 513.4000000000001, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = (0, 0)'),
#  Text(176.52021089630932, 513.4000000000001, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 17, 0]\nclass = (1, 0)'),
#  Text(202.6713532513181, 573.8, 'Relationship <= 4.5\ngini = 0.458\nsamples = 45\nvalue = [29, 0, 16, 0]\nclass = (0, 0)'),
#  Text(189.5957820738137, 513.4000000000001, 'Education-Num <= 13.5\ngini = 0.346\nsamples = 36\nvalue = [28, 0, 8, 0]\nclass = (0, 0)'),
#  Text(183.0579964850615, 453.0, 'Hours per week <= 43.5\ngini = 0.219\nsamples = 32\nvalue = [28, 0, 4, 0]\nclass = (0, 0)'),
#  Text(176.52021089630932, 392.6, 'Workclass <= 2.5\ngini = 0.067\nsamples = 29\nvalue = [28, 0, 1, 0]\nclass = (0, 0)'),
#  Text(169.98242530755712, 332.20000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(183.0579964850615, 332.20000000000005, 'gini = 0.0\nsamples = 28\nvalue = [28, 0, 0, 0]\nclass = (0, 0)'),
#  Text(189.5957820738137, 392.6, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = (1, 0)'),
#  Text(196.1335676625659, 453.0, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = (1, 0)'),
#  Text(215.7469244288225, 513.4000000000001, 'Education-Num <= 11.0\ngini = 0.198\nsamples = 9\nvalue = [1, 0, 8, 0]\nclass = (1, 0)'),
#  Text(209.2091388400703, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(222.2847100175747, 453.0, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0]\nclass = (1, 0)'),
#  Text(260.2855887521968, 634.2, 'Education-Num <= 10.5\ngini = 0.12\nsamples = 360\nvalue = [21, 2, 337, 0]\nclass = (1, 0)'),
#  Text(235.3602811950791, 573.8, 'Marital Status <= 1.0\ngini = 0.198\nsamples = 9\nvalue = [8, 0, 1, 0]\nclass = (0, 0)'),
#  Text(228.8224956063269, 513.4000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(241.89806678383127, 513.4000000000001, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]\nclass = (0, 0)'),
#  Text(285.2108963093146, 573.8, 'Marital Status <= 4.5\ngini = 0.082\nsamples = 351\nvalue = [13, 2, 336, 0]\nclass = (1, 0)'),
#  Text(254.97363796133567, 513.4000000000001, 'Capital Loss <= 1676.0\ngini = 0.067\nsamples = 345\nvalue = [11, 1, 333, 0]\nclass = (1, 0)'),
#  Text(248.43585237258347, 453.0, 'Race <= 0.5\ngini = 0.062\nsamples = 344\nvalue = [11, 0, 333, 0]\nclass = (1, 0)'),
#  Text(241.89806678383127, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(254.97363796133567, 392.6, 'Education-Num <= 12.5\ngini = 0.057\nsamples = 343\nvalue = [10, 0, 333, 0]\nclass = (1, 0)'),
#  Text(227.18804920913882, 332.20000000000005, 'Marital Status <= 3.0\ngini = 0.346\nsamples = 9\nvalue = [2, 0, 7, 0]\nclass = (1, 0)'),
#  Text(220.65026362038665, 271.80000000000007, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0]\nclass = (1, 0)'),
#  Text(233.72583479789103, 271.80000000000007, 'Relationship <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0]\nclass = (0, 0)'),
#  Text(227.18804920913882, 211.39999999999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = (0, 0)'),
#  Text(240.26362038664323, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(282.7592267135325, 332.20000000000005, 'Relationship <= 3.5\ngini = 0.047\nsamples = 334\nvalue = [8, 0, 326, 0]\nclass = (1, 0)'),
#  Text(259.8769771528998, 271.80000000000007, 'Marital Status <= 3.0\ngini = 0.14\nsamples = 79\nvalue = [6, 0, 73, 0]\nclass = (1, 0)'),
#  Text(253.33919156414763, 211.39999999999998, 'gini = 0.0\nsamples = 70\nvalue = [0, 0, 70, 0]\nclass = (1, 0)'),
#  Text(266.414762741652, 211.39999999999998, 'Age <= 45.0\ngini = 0.444\nsamples = 9\nvalue = [6, 0, 3, 0]\nclass = (0, 0)'),
#  Text(259.8769771528998, 151.0, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]\nclass = (0, 0)'),
#  Text(272.9525483304042, 151.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = (1, 0)'),
#  Text(305.6414762741652, 271.80000000000007, 'Age <= 29.5\ngini = 0.016\nsamples = 255\nvalue = [2, 0, 253, 0]\nclass = (1, 0)'),
#  Text(292.5659050966608, 211.39999999999998, 'Age <= 28.0\ngini = 0.32\nsamples = 5\nvalue = [1, 0, 4, 0]\nclass = (1, 0)'),
#  Text(286.0281195079086, 151.0, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = (1, 0)'),
#  Text(299.103690685413, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(318.7170474516696, 211.39999999999998, 'Hours per week <= 32.5\ngini = 0.008\nsamples = 250\nvalue = [1, 0, 249, 0]\nclass = (1, 0)'),
#  Text(312.1792618629174, 151.0, 'Marital Status <= 3.0\ngini = 0.32\nsamples = 5\nvalue = [1, 0, 4, 0]\nclass = (1, 0)'),
#  Text(305.6414762741652, 90.60000000000002, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = (1, 0)'),
#  Text(318.7170474516696, 90.60000000000002, 'Age <= 49.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0]\nclass = (0, 0)'),
#  Text(312.1792618629174, 30.200000000000045, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(325.2548330404218, 30.200000000000045, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(325.2548330404218, 151.0, 'gini = 0.0\nsamples = 245\nvalue = [0, 0, 245, 0]\nclass = (1, 0)'),
#  Text(261.5114235500879, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(315.4481546572935, 513.4000000000001, 'Education-Num <= 14.5\ngini = 0.611\nsamples = 6\nvalue = [2, 1, 3, 0]\nclass = (1, 0)'),
#  Text(308.9103690685413, 453.0, 'Hours per week <= 40.5\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 3, 0]\nclass = (1, 0)'),
#  Text(302.3725834797891, 392.6, 'Relationship <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0]\nclass = (0, 0)'),
#  Text(295.8347978910369, 332.20000000000005, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = (0, 0)'),
#  Text(308.9103690685413, 332.20000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(315.4481546572935, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = (1, 0)'),
#  Text(321.9859402460457, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(718.0327328646748, 815.4, 'Relationship <= 0.5\ngini = 0.366\nsamples = 1025\nvalue = [2, 780, 2, 241]\nclass = (1, 1)'),
#  Text(598.4116871704745, 755.0, 'Age <= 50.5\ngini = 0.502\nsamples = 465\nvalue = [2, 248, 0, 215]\nclass = (1, 1)'),
#  Text(489.10808435852374, 694.6, 'Capital Gain <= 7559.0\ngini = 0.438\nsamples = 274\nvalue = [2, 85, 0, 187]\nclass = (0, 1)'),
#  Text(420.05272407732866, 634.2, 'Education-Num <= 15.0\ngini = 0.368\nsamples = 193\nvalue = [2, 44, 0, 147]\nclass = (0, 1)'),
#  Text(413.51493848857643, 573.8, 'Marital Status <= 3.5\ngini = 0.336\nsamples = 186\nvalue = [2, 37, 0, 147]\nclass = (0, 1)'),
#  Text(354.67486818980666, 513.4000000000001, 'Age <= 35.5\ngini = 0.494\nsamples = 56\nvalue = [0, 25, 0, 31]\nclass = (0, 1)'),
#  Text(348.1370826010545, 453.0, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14]\nclass = (0, 1)'),
#  Text(361.2126537785589, 453.0, 'Hours per week <= 50.0\ngini = 0.482\nsamples = 42\nvalue = [0, 25, 0, 17]\nclass = (1, 1)'),
#  Text(328.52372583479786, 392.6, 'Capital Gain <= 6238.0\ngini = 0.391\nsamples = 15\nvalue = [0, 4, 0, 11]\nclass = (0, 1)'),
#  Text(321.9859402460457, 332.20000000000005, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7]\nclass = (0, 1)'),
#  Text(335.0615114235501, 332.20000000000005, 'Education-Num <= 11.5\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 0, 4]\nclass = (1, 1)'),
#  Text(328.52372583479786, 271.80000000000007, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = (0, 1)'),
#  Text(341.59929701230226, 271.80000000000007, 'Sex <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [0, 4, 0, 2]\nclass = (1, 1)'),
#  Text(335.0615114235501, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(348.1370826010545, 211.39999999999998, 'Marital Status <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 0, 1]\nclass = (1, 1)'),
#  Text(341.59929701230226, 151.0, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = (1, 1)'),
#  Text(354.67486818980666, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(393.90158172231986, 392.6, 'Marital Status <= 2.5\ngini = 0.346\nsamples = 27\nvalue = [0, 21, 0, 6]\nclass = (1, 1)'),
#  Text(374.2882249560633, 332.20000000000005, 'Sex <= 0.5\ngini = 0.18\nsamples = 20\nvalue = [0, 18, 0, 2]\nclass = (1, 1)'),
#  Text(367.75043936731106, 271.80000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(380.82601054481546, 271.80000000000007, 'Age <= 38.5\ngini = 0.1\nsamples = 19\nvalue = [0, 18, 0, 1]\nclass = (1, 1)'),
#  Text(374.2882249560633, 211.39999999999998, 'Occupation <= 6.5\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1]\nclass = (1, 1)'),
#  Text(367.75043936731106, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(380.82601054481546, 151.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(387.36379613356763, 211.39999999999998, 'gini = 0.0\nsamples = 16\nvalue = [0, 16, 0, 0]\nclass = (1, 1)'),
#  Text(413.51493848857643, 332.20000000000005, 'Workclass <= 5.5\ngini = 0.49\nsamples = 7\nvalue = [0, 3, 0, 4]\nclass = (0, 1)'),
#  Text(406.97715289982426, 271.80000000000007, 'Occupation <= 5.5\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 0, 1]\nclass = (1, 1)'),
#  Text(400.43936731107203, 211.39999999999998, 'Workclass <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = (1, 1)'),
#  Text(393.90158172231986, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(406.97715289982426, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(413.51493848857643, 211.39999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(420.05272407732866, 271.80000000000007, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = (0, 1)'),
#  Text(472.3550087873462, 513.4000000000001, 'Capital Gain <= 7364.0\ngini = 0.195\nsamples = 130\nvalue = [2, 12, 0, 116]\nclass = (0, 1)'),
#  Text(446.2038664323374, 453.0, 'Capital Gain <= 4914.0\ngini = 0.106\nsamples = 108\nvalue = [2, 4, 0, 102]\nclass = (0, 1)'),
#  Text(433.128295254833, 392.6, 'Hours per week <= 50.0\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = (0, 0)'),
#  Text(426.59050966608083, 332.20000000000005, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = (0, 0)'),
#  Text(439.66608084358523, 332.20000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(459.2794376098418, 392.6, 'Workclass <= 0.5\ngini = 0.073\nsamples = 105\nvalue = [0, 4, 0, 101]\nclass = (0, 1)'),
#  Text(452.74165202108964, 332.20000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(465.81722319859404, 332.20000000000005, 'Capital Gain <= 6238.0\ngini = 0.056\nsamples = 104\nvalue = [0, 3, 0, 101]\nclass = (0, 1)'),
#  Text(459.2794376098418, 271.80000000000007, 'gini = 0.0\nsamples = 75\nvalue = [0, 0, 0, 75]\nclass = (0, 1)'),
#  Text(472.3550087873462, 271.80000000000007, 'Hours per week <= 50.0\ngini = 0.185\nsamples = 29\nvalue = [0, 3, 0, 26]\nclass = (0, 1)'),
#  Text(465.81722319859404, 211.39999999999998, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 0, 22]\nclass = (0, 1)'),
#  Text(478.89279437609844, 211.39999999999998, 'Sex <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [0, 3, 0, 4]\nclass = (0, 1)'),
#  Text(472.3550087873462, 151.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = (0, 1)'),
#  Text(485.4305799648506, 151.0, 'Education-Num <= 9.5\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 0, 1]\nclass = (1, 1)'),
#  Text(478.89279437609844, 90.60000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(491.9683655536028, 90.60000000000002, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = (1, 1)'),
#  Text(498.506151142355, 453.0, 'Hours per week <= 45.0\ngini = 0.463\nsamples = 22\nvalue = [0, 8, 0, 14]\nclass = (0, 1)'),
#  Text(485.4305799648506, 392.6, 'Education-Num <= 13.5\ngini = 0.245\nsamples = 14\nvalue = [0, 2, 0, 12]\nclass = (0, 1)'),
#  Text(478.89279437609844, 332.20000000000005, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12]\nclass = (0, 1)'),
#  Text(491.9683655536028, 332.20000000000005, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(511.5817223198594, 392.6, 'Education-Num <= 12.0\ngini = 0.375\nsamples = 8\nvalue = [0, 6, 0, 2]\nclass = (1, 1)'),
#  Text(505.0439367311072, 332.20000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(518.1195079086116, 332.20000000000005, 'Age <= 30.5\ngini = 0.245\nsamples = 7\nvalue = [0, 6, 0, 1]\nclass = (1, 1)'),
#  Text(511.5817223198594, 271.80000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(524.6572934973638, 271.80000000000007, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0]\nclass = (1, 1)'),
#  Text(426.59050966608083, 573.8, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0]\nclass = (1, 1)'),
#  Text(558.1634446397188, 634.2, 'Education-Num <= 12.5\ngini = 0.5\nsamples = 81\nvalue = [0, 41, 0, 40]\nclass = (1, 1)'),
#  Text(524.6572934973638, 573.8, 'Age <= 26.5\ngini = 0.165\nsamples = 22\nvalue = [0, 2, 0, 20]\nclass = (0, 1)'),
#  Text(518.1195079086116, 513.4000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(531.195079086116, 513.4000000000001, 'Age <= 45.5\ngini = 0.091\nsamples = 21\nvalue = [0, 1, 0, 20]\nclass = (0, 1)'),
#  Text(524.6572934973638, 453.0, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 0, 19]\nclass = (0, 1)'),
#  Text(537.7328646748682, 453.0, 'Occupation <= 5.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = (1, 1)'),
#  Text(531.195079086116, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(544.2706502636204, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(591.6695957820738, 573.8, 'Hours per week <= 46.5\ngini = 0.448\nsamples = 59\nvalue = [0, 39, 0, 20]\nclass = (1, 1)'),
#  Text(567.152899824253, 513.4000000000001, 'Age <= 32.0\ngini = 0.489\nsamples = 33\nvalue = [0, 14, 0, 19]\nclass = (0, 1)'),
#  Text(560.6151142355009, 453.0, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6]\nclass = (0, 1)'),
#  Text(573.6906854130052, 453.0, 'Occupation <= 11.0\ngini = 0.499\nsamples = 27\nvalue = [0, 14, 0, 13]\nclass = (1, 1)'),
#  Text(557.3462214411247, 392.6, 'Workclass <= 5.5\ngini = 0.49\nsamples = 21\nvalue = [0, 9, 0, 12]\nclass = (0, 1)'),
#  Text(544.2706502636204, 332.20000000000005, 'Occupation <= 2.5\ngini = 0.444\nsamples = 9\nvalue = [0, 6, 0, 3]\nclass = (1, 1)'),
#  Text(537.7328646748682, 271.80000000000007, 'Marital Status <= 2.0\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 0, 3]\nclass = (0, 1)'),
#  Text(531.195079086116, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(544.2706502636204, 211.39999999999998, 'Hours per week <= 42.5\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 0, 3]\nclass = (0, 1)'),
#  Text(537.7328646748682, 151.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = (0, 1)'),
#  Text(550.8084358523726, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(550.8084358523726, 271.80000000000007, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = (1, 1)'),
#  Text(570.4217926186292, 332.20000000000005, 'Marital Status <= 3.0\ngini = 0.375\nsamples = 12\nvalue = [0, 3, 0, 9]\nclass = (0, 1)'),
#  Text(563.884007029877, 271.80000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(576.9595782073814, 271.80000000000007, 'Age <= 44.5\ngini = 0.298\nsamples = 11\nvalue = [0, 2, 0, 9]\nclass = (0, 1)'),
#  Text(570.4217926186292, 211.39999999999998, 'Capital Loss <= 117.0\ngini = 0.18\nsamples = 10\nvalue = [0, 1, 0, 9]\nclass = (0, 1)'),
#  Text(563.884007029877, 151.0, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8]\nclass = (0, 1)'),
#  Text(576.9595782073814, 151.0, 'Hours per week <= 35.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = (1, 1)'),
#  Text(570.4217926186292, 90.60000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(583.4973637961335, 90.60000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(583.4973637961335, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(590.0351493848857, 392.6, 'Sex <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 0, 1]\nclass = (1, 1)'),
#  Text(583.4973637961335, 332.20000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(596.572934973638, 332.20000000000005, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]\nclass = (1, 1)'),
#  Text(616.1862917398945, 513.4000000000001, 'Sex <= 0.5\ngini = 0.074\nsamples = 26\nvalue = [0, 25, 0, 1]\nclass = (1, 1)'),
#  Text(609.6485061511423, 453.0, 'Occupation <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = (1, 1)'),
#  Text(603.1107205623902, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(616.1862917398945, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(622.7240773286468, 453.0, 'gini = 0.0\nsamples = 24\nvalue = [0, 24, 0, 0]\nclass = (1, 1)'),
#  Text(707.7152899824252, 694.6, 'Education-Num <= 12.0\ngini = 0.25\nsamples = 191\nvalue = [0, 163, 0, 28]\nclass = (1, 1)'),
#  Text(661.9507908611599, 634.2, 'Hours per week <= 55.0\ngini = 0.305\nsamples = 16\nvalue = [0, 3, 0, 13]\nclass = (0, 1)'),
#  Text(648.8752196836555, 573.8, 'Hours per week <= 39.0\ngini = 0.142\nsamples = 13\nvalue = [0, 1, 0, 12]\nclass = (0, 1)'),
#  Text(642.3374340949033, 513.4000000000001, 'Hours per week <= 34.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = (1, 1)'),
#  Text(635.7996485061511, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(648.8752196836555, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(655.4130052724078, 513.4000000000001, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11]\nclass = (0, 1)'),
#  Text(675.0263620386643, 573.8, 'Capital Gain <= 6433.0\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1]\nclass = (1, 1)'),
#  Text(668.4885764499121, 513.4000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(681.5641476274166, 513.4000000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(753.4797891036907, 634.2, 'Age <= 62.0\ngini = 0.157\nsamples = 175\nvalue = [0, 160, 0, 15]\nclass = (1, 1)'),
#  Text(720.7908611599297, 573.8, 'Hours per week <= 54.0\ngini = 0.31\nsamples = 73\nvalue = [0, 59, 0, 14]\nclass = (1, 1)'),
#  Text(694.6397188049209, 513.4000000000001, 'Capital Gain <= 6238.0\ngini = 0.426\nsamples = 39\nvalue = [0, 27, 0, 12]\nclass = (1, 1)'),
#  Text(681.5641476274166, 453.0, 'Occupation <= 7.0\ngini = 0.355\nsamples = 13\nvalue = [0, 3, 0, 10]\nclass = (0, 1)'),
#  Text(675.0263620386643, 392.6, 'Workclass <= 3.0\ngini = 0.165\nsamples = 11\nvalue = [0, 1, 0, 10]\nclass = (0, 1)'),
#  Text(668.4885764499121, 332.20000000000005, 'Occupation <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = (1, 1)'),
#  Text(661.9507908611599, 271.80000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(675.0263620386643, 271.80000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(681.5641476274166, 332.20000000000005, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9]\nclass = (0, 1)'),
#  Text(688.1019332161687, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(707.7152899824252, 453.0, 'Sex <= 0.5\ngini = 0.142\nsamples = 26\nvalue = [0, 24, 0, 2]\nclass = (1, 1)'),
#  Text(701.1775043936731, 392.6, 'Occupation <= 6.5\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 0, 2]\nclass = (1, 1)'),
#  Text(694.6397188049209, 332.20000000000005, 'Age <= 55.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2]\nclass = (0, 1)'),
#  Text(688.1019332161687, 271.80000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(701.1775043936731, 271.80000000000007, 'Capital Gain <= 7493.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = (1, 1)'),
#  Text(694.6397188049209, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(707.7152899824252, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(707.7152899824252, 332.20000000000005, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(714.2530755711775, 392.6, 'gini = 0.0\nsamples = 21\nvalue = [0, 21, 0, 0]\nclass = (1, 1)'),
#  Text(746.9420035149385, 513.4000000000001, 'Sex <= 0.5\ngini = 0.111\nsamples = 34\nvalue = [0, 32, 0, 2]\nclass = (1, 1)'),
#  Text(733.866432337434, 453.0, 'Occupation <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = (1, 1)'),
#  Text(727.3286467486819, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(740.4042179261863, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(760.0175746924428, 453.0, 'Race <= 2.5\ngini = 0.061\nsamples = 32\nvalue = [0, 31, 0, 1]\nclass = (1, 1)'),
#  Text(753.4797891036907, 392.6, 'Workclass <= 5.5\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1]\nclass = (1, 1)'),
#  Text(746.9420035149385, 332.20000000000005, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(760.0175746924428, 332.20000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(766.555360281195, 392.6, 'gini = 0.0\nsamples = 29\nvalue = [0, 29, 0, 0]\nclass = (1, 1)'),
#  Text(786.1687170474517, 573.8, 'Race <= 2.5\ngini = 0.019\nsamples = 102\nvalue = [0, 101, 0, 1]\nclass = (1, 1)'),
#  Text(779.6309314586995, 513.4000000000001, 'Workclass <= 2.5\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 0, 1]\nclass = (1, 1)'),
#  Text(773.0931458699473, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(786.1687170474517, 453.0, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]\nclass = (1, 1)'),
#  Text(792.7065026362038, 513.4000000000001, 'gini = 0.0\nsamples = 96\nvalue = [0, 96, 0, 0]\nclass = (1, 1)'),
#  Text(837.6537785588752, 755.0, 'Education-Num <= 6.5\ngini = 0.095\nsamples = 560\nvalue = [0, 532, 2, 26]\nclass = (1, 1)'),
#  Text(831.115992970123, 694.6, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8]\nclass = (0, 1)'),
#  Text(844.1915641476274, 694.6, 'Education-Num <= 9.5\ngini = 0.07\nsamples = 552\nvalue = [0, 532, 2, 18]\nclass = (1, 1)'),
#  Text(805.7820738137083, 634.2, 'Hours per week <= 31.5\ngini = 0.395\nsamples = 48\nvalue = [0, 35, 0, 13]\nclass = (1, 1)'),
#  Text(799.244288224956, 573.8, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5]\nclass = (0, 1)'),
#  Text(812.3198594024605, 573.8, 'Age <= 48.5\ngini = 0.303\nsamples = 43\nvalue = [0, 35, 0, 8]\nclass = (1, 1)'),
#  Text(805.7820738137083, 513.4000000000001, 'Marital Status <= 3.0\ngini = 0.408\nsamples = 28\nvalue = [0, 20, 0, 8]\nclass = (1, 1)'),
#  Text(799.244288224956, 453.0, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0]\nclass = (1, 1)'),
#  Text(812.3198594024605, 453.0, 'Relationship <= 4.5\ngini = 0.463\nsamples = 22\nvalue = [0, 14, 0, 8]\nclass = (1, 1)'),
#  Text(799.244288224956, 392.6, 'Workclass <= 3.0\ngini = 0.5\nsamples = 14\nvalue = [0, 7, 0, 7]\nclass = (1, 1)'),
#  Text(792.7065026362038, 332.20000000000005, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = (1, 1)'),
#  Text(805.7820738137083, 332.20000000000005, 'Sex <= 0.5\ngini = 0.463\nsamples = 11\nvalue = [0, 4, 0, 7]\nclass = (0, 1)'),
#  Text(799.244288224956, 271.80000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(812.3198594024605, 271.80000000000007, 'Occupation <= 2.0\ngini = 0.42\nsamples = 10\nvalue = [0, 3, 0, 7]\nclass = (0, 1)'),
#  Text(805.7820738137083, 211.39999999999998, 'Relationship <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [0, 3, 0, 3]\nclass = (1, 1)'),
#  Text(799.244288224956, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(812.3198594024605, 151.0, 'Hours per week <= 50.0\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 0, 2]\nclass = (1, 1)'),
#  Text(805.7820738137083, 90.60000000000002, 'Capital Gain <= 6238.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2]\nclass = (0, 1)'),
#  Text(799.244288224956, 30.200000000000045, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = (0, 1)'),
#  Text(812.3198594024605, 30.200000000000045, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(818.8576449912126, 90.60000000000002, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(818.8576449912126, 211.39999999999998, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]\nclass = (0, 1)'),
#  Text(825.3954305799648, 392.6, 'Workclass <= 3.0\ngini = 0.219\nsamples = 8\nvalue = [0, 7, 0, 1]\nclass = (1, 1)'),
#  Text(818.8576449912126, 332.20000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(831.9332161687171, 332.20000000000005, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0]\nclass = (1, 1)'),
#  Text(818.8576449912126, 513.4000000000001, 'gini = 0.0\nsamples = 15\nvalue = [0, 15, 0, 0]\nclass = (1, 1)'),
#  Text(882.6010544815466, 634.2, 'Marital Status <= 4.5\ngini = 0.027\nsamples = 504\nvalue = [0, 497, 2, 5]\nclass = (1, 1)'),
#  Text(854.8154657293497, 573.8, 'Hours per week <= 17.5\ngini = 0.012\nsamples = 486\nvalue = [0, 483, 2, 1]\nclass = (1, 1)'),
#  Text(838.4710017574693, 513.4000000000001, 'Relationship <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 0, 1]\nclass = (1, 1)'),
#  Text(831.9332161687171, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(845.0087873462214, 453.0, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = (1, 1)'),
#  Text(871.1599297012302, 513.4000000000001, 'Marital Status <= 0.5\ngini = 0.008\nsamples = 481\nvalue = [0, 479, 2, 0]\nclass = (1, 1)'),
#  Text(858.0843585237258, 453.0, 'Capital Gain <= 6433.0\ngini = 0.077\nsamples = 25\nvalue = [0, 24, 1, 0]\nclass = (1, 1)'),
#  Text(851.5465729349736, 392.6, 'Relationship <= 3.5\ngini = 0.219\nsamples = 8\nvalue = [0, 7, 1, 0]\nclass = (1, 1)'),
#  Text(845.0087873462214, 332.20000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(858.0843585237258, 332.20000000000005, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0]\nclass = (1, 1)'),
#  Text(864.622144112478, 392.6, 'gini = 0.0\nsamples = 17\nvalue = [0, 17, 0, 0]\nclass = (1, 1)'),
#  Text(884.2355008787346, 453.0, 'Capital Gain <= 5095.5\ngini = 0.004\nsamples = 456\nvalue = [0, 455, 1, 0]\nclass = (1, 1)'),
#  Text(877.6977152899824, 392.6, 'Capital Gain <= 4699.5\ngini = 0.054\nsamples = 36\nvalue = [0, 35, 1, 0]\nclass = (1, 1)'),
#  Text(871.1599297012302, 332.20000000000005, 'gini = 0.0\nsamples = 35\nvalue = [0, 35, 0, 0]\nclass = (1, 1)'),
#  Text(884.2355008787346, 332.20000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(890.7732864674869, 392.6, 'gini = 0.0\nsamples = 420\nvalue = [0, 420, 0, 0]\nclass = (1, 1)'),
#  Text(910.3866432337434, 573.8, 'Education-Num <= 11.5\ngini = 0.346\nsamples = 18\nvalue = [0, 14, 0, 4]\nclass = (1, 1)'),
#  Text(903.8488576449912, 513.4000000000001, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = (0, 1)'),
#  Text(916.9244288224955, 513.4000000000001, 'Relationship <= 2.5\ngini = 0.124\nsamples = 15\nvalue = [0, 14, 0, 1]\nclass = (1, 1)'),
#  Text(910.3866432337434, 453.0, 'Capital Gain <= 6433.0\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 0, 1]\nclass = (1, 1)'),
#  Text(903.8488576449912, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(916.9244288224955, 392.6, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = (1, 1)'),
#  Text(923.4622144112478, 453.0, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0, 0]\nclass = (1, 1)')]
