# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
import shap
import pickle
import cloudpickle
import numpy as np
from comparers import ModelComparer
from explainers import generate_shap_explanations
from plots import plot_decision_boundary, plot_2d, plot_feature_importance_bar, plot_feature_importance_scatter,\
                  plot_feature_effects, plot_forces
from util import calc_feature_order, calc_class_order, calc_instance_order
shap.initjs()
# %matplotlib inline
task_name = '02'
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
try:
    with open(task_name + '.dataset', 'rb') as f:
        X, y, feature_names = pickle.load(f)
    with open(task_name + '.models', 'rb') as f:
        comparer = pickle.load(f)
    with open(task_name + '.expl', 'rb') as f:
        explanations = pickle.load(f)
    print('loaded saved state')
except FileNotFoundError:
    pass
# Out:
# loaded saved state

# %% [markdown]
# # Setup Task

# %%
X, y = make_classification(n_samples=300, n_features=2, n_redundant=0, n_informative=1, n_clusters_per_class=1, class_sep=0.75, random_state=2)
X *= 100
feature_names = np.array(['x1', 'x2'])
with open(task_name + '.dataset', 'wb') as f:
    pickle.dump((X, y, feature_names), f, pickle.HIGHEST_PROTOCOL)

# %%
tree = DecisionTreeClassifier(max_depth=1)
tree.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
fig, ax = plt.subplots(figsize=(7, 7), constrained_layout=True)
plot_decision_boundary(X, y, 'Base classification task with vertical discrimination boundary', feature_names,
                       predict=tree.predict, class_names=tree.classes_,
                       fig=fig, ax=ax)

# %%
clf_a = tree

# %%
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils.validation import check_X_y, check_array, check_is_fitted
from sklearn.utils.multiclass import unique_labels

class ModifiedClassifier(BaseEstimator, ClassifierMixin):
    
    def  __init__(self, base_model):
         self.base_model = base_model
    
    def fit(self, X, y):
        X, y = check_X_y(X, y)
        self.classes_ = unique_labels(y)
        return self
    
    def predict(self, X):
        X2 = X.copy()
        X2[:, 0] -= 25
        return self.base_model.predict(X2)
    
clf_b = ModifiedClassifier(tree)
clf_b.fit(X, y)
# Out:
# ModifiedClassifier(base_model=DecisionTreeClassifier(max_depth=1))

# %%
comparer = ModelComparer(clf_a, clf_b, feature_names)
comparer.fit(X, y)
with open(task_name + '.models', 'wb') as f:
    cloudpickle.dump(comparer, f, pickle.HIGHEST_PROTOCOL)

# %%
comparer.plot_individual_clf_decision_boundaries(X, y_true=y, kind='label')

# %%
comparer.plot_decision_boundaries(X)

# %%
comparer.plot_confusion_matrix(X)

# %% [markdown]
# # Explain using Interpretability Methods

# %%
# %%time
explanations = generate_shap_explanations(comparer, X, space_types=['labels'])
with open(task_name + '.expl', 'wb') as f:
    pickle.dump(explanations, f, pickle.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 9.15 s, sys: 169 ms, total: 9.32 s
# Wall time: 11.5 s

# %% [markdown]
# ## Visualize SHAP values

# %% [markdown]
# ### Individual explanations

# %%
plot_2d(explanations.indiv.labels[:, :, 1].merged)

# %% [markdown]
# ### Simple subtraction explanation

# %%
plot_2d(explanations.indiv_diff.labels)

# %% [markdown]
# ### Multiclass difference classifier explanations

# %%
plot_2d(explanations.mclass_diff.labels)

# %% [markdown]
# ## Feature importance

# %% [markdown]
# ### Individual explanations

# %%
plot_feature_importance_bar(explanations.indiv.labels[:, :, 1].merged)

# %%
plot_feature_importance_scatter(explanations.indiv.labels[:, :, 1].merged)

# %% [markdown]
# ### Simple subtraction explanation

# %%
plot_feature_importance_bar(explanations.indiv_diff.labels[:, :, 1])

# %%
plot_feature_importance_scatter(explanations.indiv_diff.labels)

# %% [markdown]
# ### Multiclass difference classifier explanations

# %%
feature_order, feature_importance = calc_feature_order(explanations.mclass_diff.labels[:, :, comparer.difference_class_names])
plot_feature_importance_bar(feature_importance)

# %%
plot_feature_importance_bar(explanations.mclass_diff.labels)

# %%
plot_feature_importance_scatter(explanations.mclass_diff.labels)

# %% [markdown]
# ## Feature effects

# %% [markdown]
# ### Individual explanations

# %%
is_pred_diff = comparer.predict_bin_diff(explanations.data)
plot_feature_effects(explanations.indiv.labels[:, :, 1].merged, color=is_pred_diff)
# Out:
# Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.

# %% [markdown]
# ### Simple subtraction explanation

# %%
plot_feature_effects(explanations.indiv_diff.labels[:, :, 1], color=is_pred_diff)

# %% [markdown]
# ### Multiclass difference classifier explanations

# %%
plot_feature_effects(explanations.mclass_diff.labels, color=is_pred_diff)

# %% [markdown]
# ## Cluster instances

# %% [markdown]
# ### Individual explanations

# %%
instance_order = calc_instance_order(explanations.merged)
plot_forces(explanations.indiv.labels[:, :, 1].merged, instance_order=instance_order)
# Out:
# <div id='iTLZ0JM4UM4OKOTLM6MOJ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A.1"], "baseValue": 0.49, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 1.0, "simIndex": 226.0, "features": {"0": {"effect": 0.51, "value": 69.84845045985307}, "1": {"effect": 0.0, "value": 2.126084980942678}}}, {"outValue": 1.0, "simIndex": 227.0, "features": {"0": {"effect": 0.51, "value": 21.612426668253583}, "1": {"effect": 0.0, "value": 161.48732370632584}}}, {"outValue": 1.0, "simIndex": 228.0, "features": {"0": {"effect": 0.51, "value": 55.4405071527323}, "1": {"effect": 0.0, "value": -89.36092090801043}}}, {"outValue": 0.0, "simIndex": 78.0, "features": {"0": {"effect": -0.49, "value": -138.20994434837579}, "1": {"effect": 0.0, "value": 191.26006784907756}}}, {"outValue": 0.0, "simIndex": 77.0, "features": {"0": {"effect": -0.49, "value": -21.16418352656746}, "1": {"effect": 0.0, "value": 18.430173939835864}}}, {"outValue": 1.0, "simIndex": 225.0, "features": {"0": {"effect": 0.51, "value": 53.82780247765272}, "1": {"effect": 0.0, "value": 118.60486756863659}}}, {"outValue": 0.0, "simIndex": 76.0, "features": {"0": {"effect": -0.49, "value": -20.903200867579443}, "1": {"effect": 0.0, "value": -53.66853088375119}}}, {"outValue": 0.0, "simIndex": 79.0, "features": {"0": {"effect": -0.49, "value": -135.59841742607694}, "1": {"effect": 0.0, "value": 71.20612274258531}}}, {"outValue": 0.0, "simIndex": 75.0, "features": {"0": {"effect": -0.49, "value": -92.76988451693296}, "1": {"effect": 0.0, "value": -109.92973091284242}}}, {"outValue": 1.0, "simIndex": 229.0, "features": {"0": {"effect": 0.51, "value": 66.51404298157641}, "1": {"effect": 0.0, "value": -182.2231268440837}}}, {"outValue": 0.0, "simIndex": 80.0, "features": {"0": {"effect": -0.49, "value": -24.899837260985237}, "1": {"effect": 0.0, "value": -145.5359444978249}}}, {"outValue": 1.0, "simIndex": 224.0, "features": {"0": {"effect": 0.51, "value": 106.15692368042922}, "1": {"effect": 0.0, "value": 102.65979505650449}}}, {"outValue": 1.0, "simIndex": 230.0, "features": {"0": {"effect": 0.51, "value": 84.96472105471555}, "1": {"effect": 0.0, "value": 173.45163444050488}}}, {"outValue": 1.0, "simIndex": 223.0, "features": {"0": {"effect": 0.51, "value": 86.30021058884823}, "1": {"effect": 0.0, "value": 49.40358709352569}}}, {"outValue": 1.0, "simIndex": 231.0, "features": {"0": {"effect": 0.51, "value": 107.2183008097024}, "1": {"effect": 0.0, "value": 36.3433971879587}}}, {"outValue": 1.0, "simIndex": 222.0, "features": {"0": {"effect": 0.51, "value": 37.809321512286495}, "1": {"effect": 0.0, "value": 68.47599689489094}}}, {"outValue": 1.0, "simIndex": 232.0, "features": {"0": {"effect": 0.51, "value": 46.970181520396274}, "1": {"effect": 0.0, "value": -125.14484063143279}}}, {"outValue": 1.0, "simIndex": 221.0, "features": {"0": {"effect": 0.51, "value": 40.36526911137601}, "1": {"effect": 0.0, "value": -64.37449001568133}}}, {"outValue": 1.0, "simIndex": 233.0, "features": {"0": {"effect": 0.51, "value": 168.76358609624282}, "1": {"effect": 0.0, "value": 11.779654975533186}}}, {"outValue": 0.0, "simIndex": 74.0, "features": {"0": {"effect": -0.49, "value": -86.77584948620303}, "1": {"effect": 0.0, "value": 51.89249241623829}}}, {"outValue": 1.0, "simIndex": 220.0, "features": {"0": {"effect": 0.51, "value": 52.170362515411824}, "1": {"effect": 0.0, "value": -191.66305190091214}}}, {"outValue": 1.0, "simIndex": 234.0, "features": {"0": {"effect": 0.51, "value": 32.67901627270864}, "1": {"effect": 0.0, "value": -19.733094812472654}}}, {"outValue": 1.0, "simIndex": 219.0, "features": {"0": {"effect": 0.51, "value": 45.66450293302387}, "1": {"effect": 0.0, "value": 190.20172233005366}}}, {"outValue": 0.0, "simIndex": 81.0, "features": {"0": {"effect": -0.49, "value": -73.22882707289021}, "1": {"effect": 0.0, "value": -83.45152073854781}}}, {"outValue": 0.0, "simIndex": 73.0, "features": {"0": {"effect": -0.49, "value": -88.79693391027297}, "1": {"effect":  ...
# <div id='i3AVXNGHGZZYTCSAHMH5Q'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B.1"], "baseValue": 0.42, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 1.0, "simIndex": 238.0, "features": {"0": {"effect": 0.5800000000000001, "value": 69.84845045985307}, "1": {"effect": 0.0, "value": 2.126084980942678}}}, {"outValue": 1.0, "simIndex": 237.0, "features": {"0": {"effect": 0.5800000000000001, "value": 21.612426668253583}, "1": {"effect": 0.0, "value": 161.48732370632584}}}, {"outValue": 1.0, "simIndex": 236.0, "features": {"0": {"effect": 0.5800000000000001, "value": 55.4405071527323}, "1": {"effect": 0.0, "value": -89.36092090801043}}}, {"outValue": 0.0, "simIndex": 87.0, "features": {"0": {"effect": -0.42, "value": -138.20994434837579}, "1": {"effect": 0.0, "value": 191.26006784907756}}}, {"outValue": 0.0, "simIndex": 88.0, "features": {"0": {"effect": -0.42, "value": -21.16418352656746}, "1": {"effect": 0.0, "value": 18.430173939835864}}}, {"outValue": 1.0, "simIndex": 239.0, "features": {"0": {"effect": 0.5800000000000001, "value": 53.82780247765272}, "1": {"effect": 0.0, "value": 118.60486756863659}}}, {"outValue": 0.0, "simIndex": 89.0, "features": {"0": {"effect": -0.42, "value": -20.903200867579443}, "1": {"effect": 0.0, "value": -53.66853088375119}}}, {"outValue": 0.0, "simIndex": 86.0, "features": {"0": {"effect": -0.42, "value": -135.59841742607694}, "1": {"effect": 0.0, "value": 71.20612274258531}}}, {"outValue": 0.0, "simIndex": 90.0, "features": {"0": {"effect": -0.42, "value": -92.76988451693296}, "1": {"effect": 0.0, "value": -109.92973091284242}}}, {"outValue": 1.0, "simIndex": 235.0, "features": {"0": {"effect": 0.5800000000000001, "value": 66.51404298157641}, "1": {"effect": 0.0, "value": -182.2231268440837}}}, {"outValue": 0.0, "simIndex": 85.0, "features": {"0": {"effect": -0.42, "value": -24.899837260985237}, "1": {"effect": 0.0, "value": -145.5359444978249}}}, {"outValue": 1.0, "simIndex": 240.0, "features": {"0": {"effect": 0.5800000000000001, "value": 106.15692368042922}, "1": {"effect": 0.0, "value": 102.65979505650449}}}, {"outValue": 1.0, "simIndex": 234.0, "features": {"0": {"effect": 0.5800000000000001, "value": 84.96472105471555}, "1": {"effect": 0.0, "value": 173.45163444050488}}}, {"outValue": 1.0, "simIndex": 241.0, "features": {"0": {"effect": 0.5800000000000001, "value": 86.30021058884823}, "1": {"effect": 0.0, "value": 49.40358709352569}}}, {"outValue": 1.0, "simIndex": 233.0, "features": {"0": {"effect": 0.5800000000000001, "value": 107.2183008097024}, "1": {"effect": 0.0, "value": 36.3433971879587}}}, {"outValue": 1.0, "simIndex": 242.0, "features": {"0": {"effect": 0.5800000000000001, "value": 37.809321512286495}, "1": {"effect": 0.0, "value": 68.47599689489094}}}, {"outValue": 1.0, "simIndex": 232.0, "features": {"0": {"effect": 0.5800000000000001, "value": 46.970181520396274}, "1": {"effect": 0.0, "value": -125.14484063143279}}}, {"outValue": 1.0, "simIndex": 243.0, "features": {"0": {"effect": 0.5800000000000001, "value": 40.36526911137601}, "1": {"effect": 0.0, "value": -64.37449001568133}}}, {"outValue": 1.0, "simIndex": 231.0, "features": {"0": {"effect": 0.5800000000000001, "value": 168.76358609624282}, "1": {"effect": 0.0, "value": 11.779654975533186}}}, {"outValue": 0.0, "simIndex": 91.0, "features": {"0": {"effect": -0.42, "value": -86.77584948620303}, "1": {"effect": 0.0, "value": 51.89249241623829}}}, {"outValue": 1.0, "simIndex": 244.0, "features": {"0": {"effect": 0.5800000000000001, "value": 52.170362515411824}, "1": {"effect": 0.0, "value": -191.66305190091214}}}, {"outValue": 1.0, "simIndex": 230.0, "features": {"0": {"effect": 0.5800000000000001, "value": 32.67901627270864}, "1": {"effect": 0.0, "value": -19.733094812472654}}}, {"outValue": 1.0, "simIndex": 245.0, "features": {"0": {"effect": 0.5800000000000001, "value": 45.66450293302387}, "1": {"effect": 0.0, "value": 190.20172233005366}}}, {"outValue": 0.0, "simIndex": 84.0, "features": { ...

# %% [markdown]
# ### Simple subtraction explanation

# %%
plot_forces(explanations.indiv_diff.labels, instance_order=instance_order)
# Out:
# <div id='iZ3S2BGUNAB1Q30KFD293'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["0"], "baseValue": -0.06999999999999995, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 160.0, "features": {"0": {"effect": 0.06999999999999995, "value": 69.84845045985307}, "1": {"effect": 0.0, "value": 2.126084980942678}}}, {"outValue": 0.0, "simIndex": 161.0, "features": {"0": {"effect": 0.06999999999999995, "value": 21.612426668253583}, "1": {"effect": 0.0, "value": 161.48732370632584}}}, {"outValue": 0.0, "simIndex": 162.0, "features": {"0": {"effect": 0.06999999999999995, "value": 55.4405071527323}, "1": {"effect": 0.0, "value": -89.36092090801043}}}, {"outValue": 0.0, "simIndex": 159.0, "features": {"0": {"effect": 0.06999999999999995, "value": -138.20994434837579}, "1": {"effect": 0.0, "value": 191.26006784907756}}}, {"outValue": 0.0, "simIndex": 163.0, "features": {"0": {"effect": 0.06999999999999995, "value": -21.16418352656746}, "1": {"effect": 0.0, "value": 18.430173939835864}}}, {"outValue": 0.0, "simIndex": 158.0, "features": {"0": {"effect": 0.06999999999999995, "value": 53.82780247765272}, "1": {"effect": 0.0, "value": 118.60486756863659}}}, {"outValue": 0.0, "simIndex": 164.0, "features": {"0": {"effect": 0.06999999999999995, "value": -20.903200867579443}, "1": {"effect": 0.0, "value": -53.66853088375119}}}, {"outValue": 0.0, "simIndex": 157.0, "features": {"0": {"effect": 0.06999999999999995, "value": -135.59841742607694}, "1": {"effect": 0.0, "value": 71.20612274258531}}}, {"outValue": 0.0, "simIndex": 165.0, "features": {"0": {"effect": 0.06999999999999995, "value": -92.76988451693296}, "1": {"effect": 0.0, "value": -109.92973091284242}}}, {"outValue": 0.0, "simIndex": 156.0, "features": {"0": {"effect": 0.06999999999999995, "value": 66.51404298157641}, "1": {"effect": 0.0, "value": -182.2231268440837}}}, {"outValue": 0.0, "simIndex": 166.0, "features": {"0": {"effect": 0.06999999999999995, "value": -24.899837260985237}, "1": {"effect": 0.0, "value": -145.5359444978249}}}, {"outValue": 0.0, "simIndex": 155.0, "features": {"0": {"effect": 0.06999999999999995, "value": 106.15692368042922}, "1": {"effect": 0.0, "value": 102.65979505650449}}}, {"outValue": 0.0, "simIndex": 167.0, "features": {"0": {"effect": 0.06999999999999995, "value": 84.96472105471555}, "1": {"effect": 0.0, "value": 173.45163444050488}}}, {"outValue": 0.0, "simIndex": 154.0, "features": {"0": {"effect": 0.06999999999999995, "value": 86.30021058884823}, "1": {"effect": 0.0, "value": 49.40358709352569}}}, {"outValue": 0.0, "simIndex": 168.0, "features": {"0": {"effect": 0.06999999999999995, "value": 107.2183008097024}, "1": {"effect": 0.0, "value": 36.3433971879587}}}, {"outValue": 0.0, "simIndex": 153.0, "features": {"0": {"effect": 0.06999999999999995, "value": 37.809321512286495}, "1": {"effect": 0.0, "value": 68.47599689489094}}}, {"outValue": 0.0, "simIndex": 169.0, "features": {"0": {"effect": 0.06999999999999995, "value": 46.970181520396274}, "1": {"effect": 0.0, "value": -125.14484063143279}}}, {"outValue": 0.0, "simIndex": 152.0, "features": {"0": {"effect": 0.06999999999999995, "value": 40.36526911137601}, "1": {"effect": 0.0, "value": -64.37449001568133}}}, {"outValue": 0.0, "simIndex": 170.0, "features": {"0": {"effect": 0.06999999999999995, "value": 168.76358609624282}, "1": {"effect": 0.0, "value": 11.779654975533186}}}, {"outValue": 0.0, "simIndex": 151.0, "features": {"0": {"effect": 0.06999999999999995, "value": -86.77584948620303}, "1": {"effect": 0.0, "value": 51.89249241623829}}}, {"outValue": 0.0, "simIndex": 171.0, "features": {"0": {"effect": 0.06999999999999995, "value": 52.170362515411824}, "1": {"effect": 0.0, "value": -191.66305190091214}}}, {"outValue": 0.0, "simIndex": 150.0, "features": {"0": {"effect": 0.06999999999999995, "value": 32.67901627270864}, "1": {"effect": 0.0, "value": -19.733094812472654}}}, {"outValue": 0.0, "simIndex": 172.0, "features": {"0": {"effect": 0.069999999999999 ...
# <div id='iW64IF08PH3NY8NNKTXVZ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["1"], "baseValue": 0.07, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -5.551115123125783e-17, "simIndex": 84.0, "features": {"0": {"effect": -0.07000000000000006, "value": 69.84845045985307}, "1": {"effect": 0.0, "value": 2.126084980942678}}}, {"outValue": -5.551115123125783e-17, "simIndex": 85.0, "features": {"0": {"effect": -0.07000000000000006, "value": 21.612426668253583}, "1": {"effect": 0.0, "value": 161.48732370632584}}}, {"outValue": -5.551115123125783e-17, "simIndex": 86.0, "features": {"0": {"effect": -0.07000000000000006, "value": 55.4405071527323}, "1": {"effect": 0.0, "value": -89.36092090801043}}}, {"outValue": 0.0, "simIndex": 223.0, "features": {"0": {"effect": -0.07, "value": -138.20994434837579}, "1": {"effect": 0.0, "value": 191.26006784907756}}}, {"outValue": 0.0, "simIndex": 224.0, "features": {"0": {"effect": -0.07, "value": -21.16418352656746}, "1": {"effect": 0.0, "value": 18.430173939835864}}}, {"outValue": -5.551115123125783e-17, "simIndex": 83.0, "features": {"0": {"effect": -0.07000000000000006, "value": 53.82780247765272}, "1": {"effect": 0.0, "value": 118.60486756863659}}}, {"outValue": 0.0, "simIndex": 225.0, "features": {"0": {"effect": -0.07, "value": -20.903200867579443}, "1": {"effect": 0.0, "value": -53.66853088375119}}}, {"outValue": 0.0, "simIndex": 222.0, "features": {"0": {"effect": -0.07, "value": -135.59841742607694}, "1": {"effect": 0.0, "value": 71.20612274258531}}}, {"outValue": 0.0, "simIndex": 226.0, "features": {"0": {"effect": -0.07, "value": -92.76988451693296}, "1": {"effect": 0.0, "value": -109.92973091284242}}}, {"outValue": -5.551115123125783e-17, "simIndex": 87.0, "features": {"0": {"effect": -0.07000000000000006, "value": 66.51404298157641}, "1": {"effect": 0.0, "value": -182.2231268440837}}}, {"outValue": 0.0, "simIndex": 221.0, "features": {"0": {"effect": -0.07, "value": -24.899837260985237}, "1": {"effect": 0.0, "value": -145.5359444978249}}}, {"outValue": -5.551115123125783e-17, "simIndex": 82.0, "features": {"0": {"effect": -0.07000000000000006, "value": 106.15692368042922}, "1": {"effect": 0.0, "value": 102.65979505650449}}}, {"outValue": -5.551115123125783e-17, "simIndex": 88.0, "features": {"0": {"effect": -0.07000000000000006, "value": 84.96472105471555}, "1": {"effect": 0.0, "value": 173.45163444050488}}}, {"outValue": -5.551115123125783e-17, "simIndex": 81.0, "features": {"0": {"effect": -0.07000000000000006, "value": 86.30021058884823}, "1": {"effect": 0.0, "value": 49.40358709352569}}}, {"outValue": -5.551115123125783e-17, "simIndex": 89.0, "features": {"0": {"effect": -0.07000000000000006, "value": 107.2183008097024}, "1": {"effect": 0.0, "value": 36.3433971879587}}}, {"outValue": -5.551115123125783e-17, "simIndex": 80.0, "features": {"0": {"effect": -0.07000000000000006, "value": 37.809321512286495}, "1": {"effect": 0.0, "value": 68.47599689489094}}}, {"outValue": -5.551115123125783e-17, "simIndex": 90.0, "features": {"0": {"effect": -0.07000000000000006, "value": 46.970181520396274}, "1": {"effect": 0.0, "value": -125.14484063143279}}}, {"outValue": -5.551115123125783e-17, "simIndex": 79.0, "features": {"0": {"effect": -0.07000000000000006, "value": 40.36526911137601}, "1": {"effect": 0.0, "value": -64.37449001568133}}}, {"outValue": -5.551115123125783e-17, "simIndex": 91.0, "features": {"0": {"effect": -0.07000000000000006, "value": 168.76358609624282}, "1": {"effect": 0.0, "value": 11.779654975533186}}}, {"outValue": 0.0, "simIndex": 227.0, "features": {"0": {"effect": -0.07, "value": -86.77584948620303}, "1": {"effect": 0.0, "value": 51.89249241623829}}}, {"outValue": -5.551115123125783e-17, "simIndex": 78.0, "features": {"0": {"effect": -0.07000000000000006, "value": 52.170362515411824}, "1": {"effect": 0.0, "value": -191.66305190091214}}}, {"outValue": -5.551115123125783e-17, "simIndex": 92.0, "features": {"0": {"effect": -0.07000000000000 ...

# %% [markdown]
# ### Multiclass difference classifier explanations

# %%
plot_forces(explanations.mclass_diff.labels[:, :, comparer.difference_class_names], instance_order=instance_order)
# Out:
# <div id='i48S2TOTJP7070YAM9JUV'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(0, 1)"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 150.0, "features": {"0": {"effect": 0.0, "value": 69.84845045985307}, "1": {"effect": 0.0, "value": 2.126084980942678}}}, {"outValue": 0.0, "simIndex": 151.0, "features": {"0": {"effect": 0.0, "value": 21.612426668253583}, "1": {"effect": 0.0, "value": 161.48732370632584}}}, {"outValue": 0.0, "simIndex": 152.0, "features": {"0": {"effect": 0.0, "value": 55.4405071527323}, "1": {"effect": 0.0, "value": -89.36092090801043}}}, {"outValue": 0.0, "simIndex": 149.0, "features": {"0": {"effect": 0.0, "value": -138.20994434837579}, "1": {"effect": 0.0, "value": 191.26006784907756}}}, {"outValue": 0.0, "simIndex": 153.0, "features": {"0": {"effect": 0.0, "value": -21.16418352656746}, "1": {"effect": 0.0, "value": 18.430173939835864}}}, {"outValue": 0.0, "simIndex": 148.0, "features": {"0": {"effect": 0.0, "value": 53.82780247765272}, "1": {"effect": 0.0, "value": 118.60486756863659}}}, {"outValue": 0.0, "simIndex": 154.0, "features": {"0": {"effect": 0.0, "value": -20.903200867579443}, "1": {"effect": 0.0, "value": -53.66853088375119}}}, {"outValue": 0.0, "simIndex": 147.0, "features": {"0": {"effect": 0.0, "value": -135.59841742607694}, "1": {"effect": 0.0, "value": 71.20612274258531}}}, {"outValue": 0.0, "simIndex": 155.0, "features": {"0": {"effect": 0.0, "value": -92.76988451693296}, "1": {"effect": 0.0, "value": -109.92973091284242}}}, {"outValue": 0.0, "simIndex": 146.0, "features": {"0": {"effect": 0.0, "value": 66.51404298157641}, "1": {"effect": 0.0, "value": -182.2231268440837}}}, {"outValue": 0.0, "simIndex": 156.0, "features": {"0": {"effect": 0.0, "value": -24.899837260985237}, "1": {"effect": 0.0, "value": -145.5359444978249}}}, {"outValue": 0.0, "simIndex": 145.0, "features": {"0": {"effect": 0.0, "value": 106.15692368042922}, "1": {"effect": 0.0, "value": 102.65979505650449}}}, {"outValue": 0.0, "simIndex": 157.0, "features": {"0": {"effect": 0.0, "value": 84.96472105471555}, "1": {"effect": 0.0, "value": 173.45163444050488}}}, {"outValue": 0.0, "simIndex": 144.0, "features": {"0": {"effect": 0.0, "value": 86.30021058884823}, "1": {"effect": 0.0, "value": 49.40358709352569}}}, {"outValue": 0.0, "simIndex": 158.0, "features": {"0": {"effect": 0.0, "value": 107.2183008097024}, "1": {"effect": 0.0, "value": 36.3433971879587}}}, {"outValue": 0.0, "simIndex": 143.0, "features": {"0": {"effect": 0.0, "value": 37.809321512286495}, "1": {"effect": 0.0, "value": 68.47599689489094}}}, {"outValue": 0.0, "simIndex": 159.0, "features": {"0": {"effect": 0.0, "value": 46.970181520396274}, "1": {"effect": 0.0, "value": -125.14484063143279}}}, {"outValue": 0.0, "simIndex": 142.0, "features": {"0": {"effect": 0.0, "value": 40.36526911137601}, "1": {"effect": 0.0, "value": -64.37449001568133}}}, {"outValue": 0.0, "simIndex": 160.0, "features": {"0": {"effect": 0.0, "value": 168.76358609624282}, "1": {"effect": 0.0, "value": 11.779654975533186}}}, {"outValue": 0.0, "simIndex": 141.0, "features": {"0": {"effect": 0.0, "value": -86.77584948620303}, "1": {"effect": 0.0, "value": 51.89249241623829}}}, {"outValue": 0.0, "simIndex": 161.0, "features": {"0": {"effect": 0.0, "value": 52.170362515411824}, "1": {"effect": 0.0, "value": -191.66305190091214}}}, {"outValue": 0.0, "simIndex": 140.0, "features": {"0": {"effect": 0.0, "value": 32.67901627270864}, "1": {"effect": 0.0, "value": -19.733094812472654}}}, {"outValue": 0.0, "simIndex": 162.0, "features": {"0": {"effect": 0.0, "value": 45.66450293302387}, "1": {"effect": 0.0, "value": 190.20172233005366}}}, {"outValue": 0.0, "simIndex": 139.0, "features": {"0": {"effect": 0.0, "value": -73.22882707289021}, "1": {"effect": 0.0, "value": -83.45152073854781}}}, {"outValue": 0.0, "simIndex": 163.0, "features": {"0": {"effect": 0.0, "value": -88.79693391027297}, "1": {"effect": 0.0, "value": 78.075435 ...
# <div id='iAKG8QADVRANMIIEB47NW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(1, 0)"], "baseValue": 0.07, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 160.0, "features": {"0": {"effect": -0.07, "value": 69.84845045985307}, "1": {"effect": 0.0, "value": 2.126084980942678}}}, {"outValue": 0.0, "simIndex": 161.0, "features": {"0": {"effect": -0.07, "value": 21.612426668253583}, "1": {"effect": 0.0, "value": 161.48732370632584}}}, {"outValue": 0.0, "simIndex": 162.0, "features": {"0": {"effect": -0.07, "value": 55.4405071527323}, "1": {"effect": 0.0, "value": -89.36092090801043}}}, {"outValue": 0.0, "simIndex": 159.0, "features": {"0": {"effect": -0.07, "value": -138.20994434837579}, "1": {"effect": 0.0, "value": 191.26006784907756}}}, {"outValue": 0.0, "simIndex": 163.0, "features": {"0": {"effect": -0.07, "value": -21.16418352656746}, "1": {"effect": 0.0, "value": 18.430173939835864}}}, {"outValue": 0.0, "simIndex": 158.0, "features": {"0": {"effect": -0.07, "value": 53.82780247765272}, "1": {"effect": 0.0, "value": 118.60486756863659}}}, {"outValue": 0.0, "simIndex": 164.0, "features": {"0": {"effect": -0.07, "value": -20.903200867579443}, "1": {"effect": 0.0, "value": -53.66853088375119}}}, {"outValue": 0.0, "simIndex": 157.0, "features": {"0": {"effect": -0.07, "value": -135.59841742607694}, "1": {"effect": 0.0, "value": 71.20612274258531}}}, {"outValue": 0.0, "simIndex": 165.0, "features": {"0": {"effect": -0.07, "value": -92.76988451693296}, "1": {"effect": 0.0, "value": -109.92973091284242}}}, {"outValue": 0.0, "simIndex": 156.0, "features": {"0": {"effect": -0.07, "value": 66.51404298157641}, "1": {"effect": 0.0, "value": -182.2231268440837}}}, {"outValue": 0.0, "simIndex": 166.0, "features": {"0": {"effect": -0.07, "value": -24.899837260985237}, "1": {"effect": 0.0, "value": -145.5359444978249}}}, {"outValue": 0.0, "simIndex": 155.0, "features": {"0": {"effect": -0.07, "value": 106.15692368042922}, "1": {"effect": 0.0, "value": 102.65979505650449}}}, {"outValue": 0.0, "simIndex": 167.0, "features": {"0": {"effect": -0.07, "value": 84.96472105471555}, "1": {"effect": 0.0, "value": 173.45163444050488}}}, {"outValue": 0.0, "simIndex": 154.0, "features": {"0": {"effect": -0.07, "value": 86.30021058884823}, "1": {"effect": 0.0, "value": 49.40358709352569}}}, {"outValue": 0.0, "simIndex": 168.0, "features": {"0": {"effect": -0.07, "value": 107.2183008097024}, "1": {"effect": 0.0, "value": 36.3433971879587}}}, {"outValue": 0.0, "simIndex": 153.0, "features": {"0": {"effect": -0.07, "value": 37.809321512286495}, "1": {"effect": 0.0, "value": 68.47599689489094}}}, {"outValue": 0.0, "simIndex": 169.0, "features": {"0": {"effect": -0.07, "value": 46.970181520396274}, "1": {"effect": 0.0, "value": -125.14484063143279}}}, {"outValue": 0.0, "simIndex": 152.0, "features": {"0": {"effect": -0.07, "value": 40.36526911137601}, "1": {"effect": 0.0, "value": -64.37449001568133}}}, {"outValue": 0.0, "simIndex": 170.0, "features": {"0": {"effect": -0.07, "value": 168.76358609624282}, "1": {"effect": 0.0, "value": 11.779654975533186}}}, {"outValue": 0.0, "simIndex": 151.0, "features": {"0": {"effect": -0.07, "value": -86.77584948620303}, "1": {"effect": 0.0, "value": 51.89249241623829}}}, {"outValue": 0.0, "simIndex": 171.0, "features": {"0": {"effect": -0.07, "value": 52.170362515411824}, "1": {"effect": 0.0, "value": -191.66305190091214}}}, {"outValue": 0.0, "simIndex": 150.0, "features": {"0": {"effect": -0.07, "value": 32.67901627270864}, "1": {"effect": 0.0, "value": -19.733094812472654}}}, {"outValue": 0.0, "simIndex": 172.0, "features": {"0": {"effect": -0.07, "value": 45.66450293302387}, "1": {"effect": 0.0, "value": 190.20172233005366}}}, {"outValue": 0.0, "simIndex": 149.0, "features": {"0": {"effect": -0.07, "value": -73.22882707289021}, "1": {"effect": 0.0, "value": -83.45152073854781}}}, {"outValue": 0.0, "simIndex": 173.0, "features": {"0": {"effect": -0.07, "value": -88.79693 ...
