# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
import shap
import pickle
import cloudpickle
import numpy as np
from comparers import ModelComparer
from explainers import generate_shap_explanations
from plots import plot_decision_boundary, plot_2d, plot_feature_importance_bar, plot_feature_importance_scatter,\
                  plot_feature_effects, plot_forces
from util import calc_feature_order, calc_class_order, calc_instance_order
shap.initjs()
# %matplotlib inline
task_name = '03'
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
try:
    with open(task_name + '.dataset', 'rb') as f:
        X, y, feature_names = pickle.load(f)
    with open(task_name + '.models', 'rb') as f:
        comparer = pickle.load(f)
    with open(task_name + '.expl', 'rb') as f:
        explanations = pickle.load(f)
    print('loaded saved state')
except FileNotFoundError:
    pass

# %% [markdown]
# # Setup Task

# %%
X, y = make_classification(n_samples=300, n_features=2, n_redundant=0, n_informative=2,
                           n_clusters_per_class=1, class_sep=0.75, random_state=0)
X *= 100
feature_names = np.array(['x1', 'x2'])
with open(task_name + '.dataset', 'wb') as f:
    pickle.dump((X, y, feature_names), f, pickle.HIGHEST_PROTOCOL)

# %%
from sklearn.linear_model import LogisticRegression
lm = LogisticRegression()
lm.fit(X, y)
lm.intercept_, lm.coef_
# Out:
# (array([1.11018683]), array([[-0.02146303,  0.02909487]]))

# %%
fig, ax = plt.subplots(figsize=(7, 7), constrained_layout=True)
plot_decision_boundary(X, y, 'Base classification task with linear discrimination boundary', feature_names,
                       predict=lm.predict, class_names=lm.classes_,
                       fig=fig, ax=ax)

# %%
clf_a = lm

# %%
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils.validation import check_X_y, check_array, check_is_fitted
from sklearn.utils.multiclass import unique_labels

class ModifiedClassifier(BaseEstimator, ClassifierMixin):
    
    def  __init__(self, base_model):
         self.base_model = base_model
    
    def fit(self, X, y):
        X, y = check_X_y(X, y)
        self.classes_ = unique_labels(y)
        return self
    
    def predict(self, X):
        X2 = X.copy()
        X2[(50 < X[:, 0]) & (X[:, 0] <= 100), 0] += 50
        return self.base_model.predict(X2)
    
clf_b = ModifiedClassifier(lm)
clf_b.fit(X, y)
# Out:
# ModifiedClassifier(base_model=LogisticRegression())

# %%
comparer = ModelComparer(clf_a, clf_b, feature_names)
comparer.fit(X, y)
with open(task_name + '.models', 'wb') as f:
    cloudpickle.dump(comparer, f, pickle.HIGHEST_PROTOCOL)

# %%
comparer.plot_individual_clf_decision_boundaries(X, y_true=y, kind='label')

# %%
comparer.plot_decision_boundaries(X)

# %%
comparer.plot_confusion_matrix(X)

# %% [markdown]
# # Explain using Interpretability Methods

# %%
# %%time
explanations = generate_shap_explanations(comparer, X, space_types=['labels'])
with open(task_name + '.expl', 'wb') as f:
    pickle.dump(explanations, f, pickle.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 8.09 s, sys: 173 ms, total: 8.26 s
# Wall time: 10.4 s

# %% [markdown]
# ## Visualize SHAP values

# %% [markdown]
# ### Individual explanations

# %%
plot_2d(explanations.indiv.labels[:, :, 1].merged)

# %% [markdown]
# ### Simple subtraction explanation

# %%
plot_2d(explanations.indiv_diff.labels)

# %% [markdown]
# ### Multiclass difference classifier explanations

# %%
plot_2d(explanations.mclass_diff.labels)

# %% [markdown]
# ## Feature importance

# %% [markdown]
# ### Individual explanations

# %%
plot_feature_importance_bar(explanations.indiv.labels[:, :, 1].merged)

# %%
plot_feature_importance_scatter(explanations.indiv.labels[:, :, 1].merged)

# %% [markdown]
# ### Simple subtraction explanation

# %%
plot_feature_importance_bar(explanations.indiv_diff.labels[:, :, 1])

# %%
plot_feature_importance_scatter(explanations.indiv_diff.labels[:, :, 1])

# %% [markdown]
# ### Multiclass difference classifier explanations

# %%
feature_order, feature_importance = calc_feature_order(explanations.mclass_diff.labels[:, :, comparer.difference_class_names])
plot_feature_importance_bar(feature_importance)

# %%
plot_feature_importance_bar(explanations.mclass_diff.labels)

# %%
plot_feature_importance_scatter(explanations.mclass_diff.labels)

# %% [markdown]
# ## Feature effects

# %% [markdown]
# ### Individual explanations

# %%
is_pred_diff = comparer.predict_bin_diff(explanations.data)
plot_feature_effects(explanations.indiv.labels[:, :, 1].merged, color=is_pred_diff)

# %% [markdown]
# ### Simple subtraction explanation

# %%
plot_feature_effects(explanations.indiv_diff.labels[:, :, 1], color=is_pred_diff)

# %% [markdown]
# ### Multiclass difference classifier explanations

# %%
plot_feature_effects(explanations.mclass_diff.labels, color=is_pred_diff)

# %% [markdown]
# ## Cluster instances

# %% [markdown]
# ### Individual explanations

# %%
instance_order = calc_instance_order(explanations.merged)
plot_forces(explanations.indiv.labels[:, :, 1].merged, instance_order=instance_order)
# Out:
# <div id='iJ4GNMI6COWODN3DZ3P9D'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A.1"], "baseValue": 0.54, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 1.0, "simIndex": 183.0, "features": {"0": {"effect": 0.004999999999999921, "value": 111.53617498685358}, "1": {"effect": 0.45500000000000007, "value": 94.84660603958575}}}, {"outValue": 1.0, "simIndex": 134.0, "features": {"0": {"effect": 0.13999999999999996, "value": 49.276389908283484}, "1": {"effect": 0.32, "value": 70.80765024123922}}}, {"outValue": 1.0, "simIndex": 121.0, "features": {"0": {"effect": 0.1899999999999999, "value": 73.83951165108653}, "1": {"effect": 0.2700000000000001, "value": 46.48765384868598}}}, {"outValue": 0.0, "simIndex": 33.0, "features": {"0": {"effect": 0.044999999999999984, "value": 29.562844922404945}, "1": {"effect": -0.585, "value": -196.8648303615631}}}, {"outValue": 0.0, "simIndex": 13.0, "features": {"0": {"effect": 0.14499999999999996, "value": -62.23366635555217}, "1": {"effect": -0.685, "value": -243.52467212282912}}}, {"outValue": 1.0, "simIndex": 223.0, "features": {"0": {"effect": -0.06500000000000003, "value": 114.15225077889959}, "1": {"effect": 0.525, "value": 182.5957849905552}}}, {"outValue": 0.0, "simIndex": 61.0, "features": {"0": {"effect": -0.025000000000000022, "value": 93.51981243478768}, "1": {"effect": -0.515, "value": -107.4253836219851}}}, {"outValue": 0.0, "simIndex": 47.0, "features": {"0": {"effect": 0.014999999999999958, "value": 38.75757706557677}, "1": {"effect": -0.5549999999999999, "value": -71.52437324879315}}}, {"outValue": 1.0, "simIndex": 93.0, "features": {"0": {"effect": 0.345, "value": -15.775584358870287}, "1": {"effect": 0.11499999999999999, "value": 22.006794155309727}}}, {"outValue": 0.0, "simIndex": 275.0, "features": {"0": {"effect": -0.24000000000000002, "value": 252.99766006035816}, "1": {"effect": -0.3, "value": -94.01255096003749}}}, {"outValue": 1.0, "simIndex": 139.0, "features": {"0": {"effect": 0.11999999999999994, "value": 67.3057788151459}, "1": {"effect": 0.34, "value": 75.27414721973086}}}, {"outValue": 0.0, "simIndex": 276.0, "features": {"0": {"effect": -0.22500000000000003, "value": 243.9279128981836}, "1": {"effect": -0.315, "value": -124.85042803033653}}}, {"outValue": 0.0, "simIndex": 73.0, "features": {"0": {"effect": -0.06500000000000003, "value": 123.09571751718342}, "1": {"effect": -0.475, "value": -117.86713386848466}}}, {"outValue": 1.0, "simIndex": 200.0, "features": {"0": {"effect": -0.025000000000000022, "value": 95.5264767724994}, "1": {"effect": 0.485, "value": 165.01275476364737}}}, {"outValue": 1.0, "simIndex": 232.0, "features": {"0": {"effect": -0.09000000000000002, "value": 155.7603595119916}, "1": {"effect": 0.55, "value": 164.6433430927805}}}, {"outValue": 1.0, "simIndex": 133.0, "features": {"0": {"effect": 0.1499999999999999, "value": 4.4453170088412435}, "1": {"effect": 0.31000000000000005, "value": 82.4369884214837}}}, {"outValue": 0.0, "simIndex": 295.0, "features": {"0": {"effect": -0.12500000000000003, "value": 158.57459693663034}, "1": {"effect": -0.41500000000000004, "value": -102.42998575127005}}}, {"outValue": 1.0, "simIndex": 89.0, "features": {"0": {"effect": 0.44499999999999995, "value": 0.7026410828595231}, "1": {"effect": 0.015000000000000013, "value": -3.454652008977943}}}, {"outValue": 1.0, "simIndex": 160.0, "features": {"0": {"effect": 0.05999999999999997, "value": 118.50815541519346}, "1": {"effect": 0.4, "value": 63.83767951084997}}}, {"outValue": 1.0, "simIndex": 85.0, "features": {"0": {"effect": 0.48, "value": 11.198916778248002}, "1": {"effect": -0.020000000000000018, "value": -25.101326101672278}}}, {"outValue": 1.0, "simIndex": 242.0, "features": {"0": {"effect": -0.21500000000000002, "value": 227.76033534038848}, "1": {"effect": 0.6749999999999999, "value": 224.28686952174627}}}, {"outValue": 1.0, "simIndex": 210.0, "features": {"0": {"effect": -0.04500000000000001, "value": 115.84828036929716}, "1": {"e ...
# <div id='i1QCK829MZPYQ2V6ELES3'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B.1"], "baseValue": 0.5, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 1.0, "simIndex": 261.0, "features": {"0": {"effect": 0.02499999999999994, "value": 111.53617498685358}, "1": {"effect": 0.4750000000000001, "value": 94.84660603958575}}}, {"outValue": 1.0, "simIndex": 292.0, "features": {"0": {"effect": 0.15999999999999998, "value": 49.276389908283484}, "1": {"effect": 0.34, "value": 70.80765024123922}}}, {"outValue": 0.0, "simIndex": 160.0, "features": {"0": {"effect": -0.28, "value": 73.83951165108653}, "1": {"effect": -0.22, "value": 46.48765384868598}}}, {"outValue": 5.551115123125783e-17, "simIndex": 90.0, "features": {"0": {"effect": 0.065, "value": 29.562844922404945}, "1": {"effect": -0.565, "value": -196.8648303615631}}}, {"outValue": 0.0, "simIndex": 110.0, "features": {"0": {"effect": 0.16499999999999998, "value": -62.23366635555217}, "1": {"effect": -0.665, "value": -243.52467212282912}}}, {"outValue": 1.0, "simIndex": 207.0, "features": {"0": {"effect": -0.04500000000000001, "value": 114.15225077889959}, "1": {"effect": 0.545, "value": 182.5957849905552}}}, {"outValue": 0.0, "simIndex": 50.0, "features": {"0": {"effect": -0.07, "value": 93.51981243478768}, "1": {"effect": -0.43, "value": -107.4253836219851}}}, {"outValue": 0.0, "simIndex": 81.0, "features": {"0": {"effect": 0.034999999999999976, "value": 38.75757706557677}, "1": {"effect": -0.535, "value": -71.52437324879315}}}, {"outValue": 1.0, "simIndex": 7.0, "features": {"0": {"effect": 0.49, "value": -15.775584358870287}, "1": {"effect": 0.010000000000000009, "value": 22.006794155309727}}}, {"outValue": 0.0, "simIndex": 148.0, "features": {"0": {"effect": -0.22, "value": 252.99766006035816}, "1": {"effect": -0.27999999999999997, "value": -94.01255096003749}}}, {"outValue": 1.0, "simIndex": 273.0, "features": {"0": {"effect": 0.054999999999999966, "value": 67.3057788151459}, "1": {"effect": 0.44500000000000006, "value": 75.27414721973086}}}, {"outValue": 0.0, "simIndex": 144.0, "features": {"0": {"effect": -0.20500000000000002, "value": 243.9279128981836}, "1": {"effect": -0.295, "value": -124.85042803033653}}}, {"outValue": 0.0, "simIndex": 62.0, "features": {"0": {"effect": -0.04500000000000001, "value": 123.09571751718342}, "1": {"effect": -0.45499999999999996, "value": -117.86713386848466}}}, {"outValue": 1.0, "simIndex": 195.0, "features": {"0": {"effect": -0.07, "value": 95.5264767724994}, "1": {"effect": 0.5700000000000001, "value": 165.01275476364737}}}, {"outValue": 1.0, "simIndex": 194.0, "features": {"0": {"effect": -0.07, "value": 155.7603595119916}, "1": {"effect": 0.5700000000000001, "value": 164.6433430927805}}}, {"outValue": 1.0, "simIndex": 293.0, "features": {"0": {"effect": 0.16999999999999993, "value": 4.4453170088412435}, "1": {"effect": 0.33000000000000007, "value": 82.4369884214837}}}, {"outValue": 0.0, "simIndex": 42.0, "features": {"0": {"effect": -0.10500000000000001, "value": 158.57459693663034}, "1": {"effect": -0.395, "value": -102.42998575127005}}}, {"outValue": 1.0, "simIndex": 11.0, "features": {"0": {"effect": 0.46499999999999997, "value": 0.7026410828595231}, "1": {"effect": 0.03500000000000003, "value": -3.454652008977943}}}, {"outValue": 1.0, "simIndex": 281.0, "features": {"0": {"effect": 0.09, "value": 118.50815541519346}, "1": {"effect": 0.41000000000000003, "value": 63.83767951084997}}}, {"outValue": 1.0, "simIndex": 4.0, "features": {"0": {"effect": 0.5, "value": 11.198916778248002}, "1": {"effect": 0.0, "value": -25.101326101672278}}}, {"outValue": 1.0, "simIndex": 182.0, "features": {"0": {"effect": -0.195, "value": 227.76033534038848}, "1": {"effect": 0.695, "value": 224.28686952174627}}}, {"outValue": 1.0, "simIndex": 221.0, "features": {"0": {"effect": -0.024999999999999994, "value": 115.84828036929716}, "1": {"effect": 0.525, "value": 123.26900666309588}}}, {"outValue": 5.551115123125783e-17, "simIn ...

# %% [markdown]
# ### Simple subtraction explanation

# %%
plot_forces(explanations.indiv_diff.labels, instance_order=instance_order)
# Out:
# <div id='iRHMDLBNR2YAI4E3S32ZL'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["0"], "baseValue": -0.03999999999999998, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 96.0, "features": {"0": {"effect": 0.019999999999999962, "value": 111.53617498685358}, "1": {"effect": 0.020000000000000018, "value": 94.84660603958575}}}, {"outValue": -5.551115123125783e-17, "simIndex": 114.0, "features": {"0": {"effect": 0.019999999999999962, "value": 49.276389908283484}, "1": {"effect": 0.019999999999999962, "value": 70.80765024123922}}}, {"outValue": -1.0, "simIndex": 3.0, "features": {"0": {"effect": -0.47, "value": 73.83951165108653}, "1": {"effect": -0.49000000000000005, "value": 46.48765384868598}}}, {"outValue": 5.551115123125783e-17, "simIndex": 158.0, "features": {"0": {"effect": 0.020000000000000018, "value": 29.562844922404945}, "1": {"effect": 0.020000000000000018, "value": -196.8648303615631}}}, {"outValue": 5.551115123125783e-17, "simIndex": 157.0, "features": {"0": {"effect": 0.020000000000000018, "value": -62.23366635555217}, "1": {"effect": 0.020000000000000018, "value": -243.52467212282912}}}, {"outValue": -8.326672684688674e-17, "simIndex": 225.0, "features": {"0": {"effect": 0.01999999999999999, "value": 114.15225077889959}, "1": {"effect": 0.019999999999999907, "value": 182.5957849905552}}}, {"outValue": 5.551115123125783e-17, "simIndex": 257.0, "features": {"0": {"effect": -0.044999999999999984, "value": 93.51981243478768}, "1": {"effect": 0.08500000000000002, "value": -107.4253836219851}}}, {"outValue": 5.551115123125783e-17, "simIndex": 156.0, "features": {"0": {"effect": 0.020000000000000018, "value": 38.75757706557677}, "1": {"effect": 0.020000000000000018, "value": -71.52437324879315}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 33.0, "features": {"0": {"effect": 0.14500000000000002, "value": -15.775584358870287}, "1": {"effect": -0.10500000000000001, "value": 22.006794155309727}}}, {"outValue": 5.551115123125783e-17, "simIndex": 159.0, "features": {"0": {"effect": 0.020000000000000018, "value": 252.99766006035816}, "1": {"effect": 0.020000000000000018, "value": -94.01255096003749}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 298.0, "features": {"0": {"effect": -0.06500000000000003, "value": 67.3057788151459}, "1": {"effect": 0.10499999999999998, "value": 75.27414721973086}}}, {"outValue": 5.551115123125783e-17, "simIndex": 155.0, "features": {"0": {"effect": 0.020000000000000018, "value": 243.9279128981836}, "1": {"effect": 0.020000000000000018, "value": -124.85042803033653}}}, {"outValue": 5.551115123125783e-17, "simIndex": 160.0, "features": {"0": {"effect": 0.020000000000000018, "value": 123.09571751718342}, "1": {"effect": 0.020000000000000018, "value": -117.86713386848466}}}, {"outValue": 8.326672684688674e-17, "simIndex": 258.0, "features": {"0": {"effect": -0.04500000000000001, "value": 95.5264767724994}, "1": {"effect": 0.08500000000000008, "value": 165.01275476364737}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 76.0, "features": {"0": {"effect": 0.01999999999999999, "value": 155.7603595119916}, "1": {"effect": 0.020000000000000018, "value": 164.6433430927805}}}, {"outValue": -5.551115123125783e-17, "simIndex": 234.0, "features": {"0": {"effect": 0.020000000000000018, "value": 4.4453170088412435}, "1": {"effect": 0.019999999999999907, "value": 82.4369884214837}}}, {"outValue": 5.551115123125783e-17, "simIndex": 154.0, "features": {"0": {"effect": 0.020000000000000018, "value": 158.57459693663034}, "1": {"effect": 0.020000000000000018, "value": -102.42998575127005}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 203.0, "features": {"0": {"effect": 0.020000000000000018, "value": 0.7026410828595231}, "1": {"effect": 0.01999999999999999, "value": -3.454652008977943}}}, {"outValue": 0.0, "simIndex": 59.0, "features": {"0": {"effect": 0.030000000000000027, "value": 118.50815541519346}, "1": {"effect": 0.009999999999999953, "value": 63.8376 ...
# <div id='iG496XU43M9RBQZTWGXC6'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["1"], "baseValue": 0.040000000000000036, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 151.0, "features": {"0": {"effect": -0.020000000000000018, "value": 111.53617498685358}, "1": {"effect": -0.020000000000000018, "value": 94.84660603958575}}}, {"outValue": 0.0, "simIndex": 150.0, "features": {"0": {"effect": -0.020000000000000018, "value": 49.276389908283484}, "1": {"effect": -0.020000000000000018, "value": 70.80765024123922}}}, {"outValue": 1.0, "simIndex": 2.0, "features": {"0": {"effect": 0.4699999999999999, "value": 73.83951165108653}, "1": {"effect": 0.4900000000000001, "value": 46.48765384868598}}}, {"outValue": 0.0, "simIndex": 149.0, "features": {"0": {"effect": -0.020000000000000018, "value": 29.562844922404945}, "1": {"effect": -0.020000000000000018, "value": -196.8648303615631}}}, {"outValue": 0.0, "simIndex": 152.0, "features": {"0": {"effect": -0.020000000000000018, "value": -62.23366635555217}, "1": {"effect": -0.020000000000000018, "value": -243.52467212282912}}}, {"outValue": 0.0, "simIndex": 148.0, "features": {"0": {"effect": -0.020000000000000018, "value": 114.15225077889959}, "1": {"effect": -0.020000000000000018, "value": 182.5957849905552}}}, {"outValue": 0.0, "simIndex": 254.0, "features": {"0": {"effect": 0.044999999999999984, "value": 93.51981243478768}, "1": {"effect": -0.08500000000000002, "value": -107.4253836219851}}}, {"outValue": 1.1102230246251565e-16, "simIndex": 243.0, "features": {"0": {"effect": -0.020000000000000018, "value": 38.75757706557677}, "1": {"effect": -0.019999999999999907, "value": -71.52437324879315}}}, {"outValue": 0.0, "simIndex": 33.0, "features": {"0": {"effect": -0.14500000000000002, "value": -15.775584358870287}, "1": {"effect": 0.10499999999999998, "value": 22.006794155309727}}}, {"outValue": 0.0, "simIndex": 153.0, "features": {"0": {"effect": -0.020000000000000018, "value": 252.99766006035816}, "1": {"effect": -0.020000000000000018, "value": -94.01255096003749}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 295.0, "features": {"0": {"effect": 0.06499999999999997, "value": 67.3057788151459}, "1": {"effect": -0.10500000000000004, "value": 75.27414721973086}}}, {"outValue": 0.0, "simIndex": 147.0, "features": {"0": {"effect": -0.020000000000000018, "value": 243.9279128981836}, "1": {"effect": -0.020000000000000018, "value": -124.85042803033653}}}, {"outValue": 0.0, "simIndex": 154.0, "features": {"0": {"effect": -0.020000000000000018, "value": 123.09571751718342}, "1": {"effect": -0.020000000000000018, "value": -117.86713386848466}}}, {"outValue": -5.551115123125783e-17, "simIndex": 257.0, "features": {"0": {"effect": 0.044999999999999984, "value": 95.5264767724994}, "1": {"effect": -0.08500000000000008, "value": 165.01275476364737}}}, {"outValue": 0.0, "simIndex": 146.0, "features": {"0": {"effect": -0.020000000000000018, "value": 155.7603595119916}, "1": {"effect": -0.020000000000000018, "value": 164.6433430927805}}}, {"outValue": 0.0, "simIndex": 155.0, "features": {"0": {"effect": -0.020000000000000018, "value": 4.4453170088412435}, "1": {"effect": -0.020000000000000018, "value": 82.4369884214837}}}, {"outValue": 0.0, "simIndex": 145.0, "features": {"0": {"effect": -0.020000000000000018, "value": 158.57459693663034}, "1": {"effect": -0.020000000000000018, "value": -102.42998575127005}}}, {"outValue": 0.0, "simIndex": 156.0, "features": {"0": {"effect": -0.020000000000000018, "value": 0.7026410828595231}, "1": {"effect": -0.020000000000000018, "value": -3.454652008977943}}}, {"outValue": 0.0, "simIndex": 59.0, "features": {"0": {"effect": -0.030000000000000027, "value": 118.50815541519346}, "1": {"effect": -0.010000000000000009, "value": 63.83767951084997}}}, {"outValue": 0.0, "simIndex": 144.0, "features": {"0": {"effect": -0.020000000000000018, "value": 11.198916778248002}, "1": {"effect": -0.020000000000000018, "value": -25.10132610 ...

# %% [markdown]
# ### Multiclass difference classifier explanations

# %%
plot_forces(explanations.mclass_diff.labels[:, :, comparer.difference_class_names], instance_order=instance_order)
# Out:
# <div id='i2FI25C2EMR5RJS2ZXP5G'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(0, 1)"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 150.0, "features": {"0": {"effect": 0.0, "value": 111.53617498685358}, "1": {"effect": 0.0, "value": 94.84660603958575}}}, {"outValue": 0.0, "simIndex": 151.0, "features": {"0": {"effect": 0.0, "value": 49.276389908283484}, "1": {"effect": 0.0, "value": 70.80765024123922}}}, {"outValue": 0.0, "simIndex": 152.0, "features": {"0": {"effect": 0.0, "value": 73.83951165108653}, "1": {"effect": 0.0, "value": 46.48765384868598}}}, {"outValue": 0.0, "simIndex": 149.0, "features": {"0": {"effect": 0.0, "value": 29.562844922404945}, "1": {"effect": 0.0, "value": -196.8648303615631}}}, {"outValue": 0.0, "simIndex": 153.0, "features": {"0": {"effect": 0.0, "value": -62.23366635555217}, "1": {"effect": 0.0, "value": -243.52467212282912}}}, {"outValue": 0.0, "simIndex": 148.0, "features": {"0": {"effect": 0.0, "value": 114.15225077889959}, "1": {"effect": 0.0, "value": 182.5957849905552}}}, {"outValue": 0.0, "simIndex": 154.0, "features": {"0": {"effect": 0.0, "value": 93.51981243478768}, "1": {"effect": 0.0, "value": -107.4253836219851}}}, {"outValue": 0.0, "simIndex": 147.0, "features": {"0": {"effect": 0.0, "value": 38.75757706557677}, "1": {"effect": 0.0, "value": -71.52437324879315}}}, {"outValue": 0.0, "simIndex": 155.0, "features": {"0": {"effect": 0.0, "value": -15.775584358870287}, "1": {"effect": 0.0, "value": 22.006794155309727}}}, {"outValue": 0.0, "simIndex": 146.0, "features": {"0": {"effect": 0.0, "value": 252.99766006035816}, "1": {"effect": 0.0, "value": -94.01255096003749}}}, {"outValue": 0.0, "simIndex": 156.0, "features": {"0": {"effect": 0.0, "value": 67.3057788151459}, "1": {"effect": 0.0, "value": 75.27414721973086}}}, {"outValue": 0.0, "simIndex": 145.0, "features": {"0": {"effect": 0.0, "value": 243.9279128981836}, "1": {"effect": 0.0, "value": -124.85042803033653}}}, {"outValue": 0.0, "simIndex": 157.0, "features": {"0": {"effect": 0.0, "value": 123.09571751718342}, "1": {"effect": 0.0, "value": -117.86713386848466}}}, {"outValue": 0.0, "simIndex": 144.0, "features": {"0": {"effect": 0.0, "value": 95.5264767724994}, "1": {"effect": 0.0, "value": 165.01275476364737}}}, {"outValue": 0.0, "simIndex": 158.0, "features": {"0": {"effect": 0.0, "value": 155.7603595119916}, "1": {"effect": 0.0, "value": 164.6433430927805}}}, {"outValue": 0.0, "simIndex": 143.0, "features": {"0": {"effect": 0.0, "value": 4.4453170088412435}, "1": {"effect": 0.0, "value": 82.4369884214837}}}, {"outValue": 0.0, "simIndex": 159.0, "features": {"0": {"effect": 0.0, "value": 158.57459693663034}, "1": {"effect": 0.0, "value": -102.42998575127005}}}, {"outValue": 0.0, "simIndex": 142.0, "features": {"0": {"effect": 0.0, "value": 0.7026410828595231}, "1": {"effect": 0.0, "value": -3.454652008977943}}}, {"outValue": 0.0, "simIndex": 160.0, "features": {"0": {"effect": 0.0, "value": 118.50815541519346}, "1": {"effect": 0.0, "value": 63.83767951084997}}}, {"outValue": 0.0, "simIndex": 141.0, "features": {"0": {"effect": 0.0, "value": 11.198916778248002}, "1": {"effect": 0.0, "value": -25.101326101672278}}}, {"outValue": 0.0, "simIndex": 161.0, "features": {"0": {"effect": 0.0, "value": 227.76033534038848}, "1": {"effect": 0.0, "value": 224.28686952174627}}}, {"outValue": 0.0, "simIndex": 140.0, "features": {"0": {"effect": 0.0, "value": 115.84828036929716}, "1": {"effect": 0.0, "value": 123.26900666309588}}}, {"outValue": 0.0, "simIndex": 162.0, "features": {"0": {"effect": 0.0, "value": 18.545863833251662}, "1": {"effect": 0.0, "value": -342.9421556269003}}}, {"outValue": 0.0, "simIndex": 139.0, "features": {"0": {"effect": 0.0, "value": 75.06947913203324}, "1": {"effect": 0.0, "value": 93.28470105439504}}}, {"outValue": 0.0, "simIndex": 163.0, "features": {"0": {"effect": 0.0, "value": 35.54994509613969}, "1": {"effect": 0.0, "value": 131.4800071931 ...
# <div id='iW8F83TYPJEVXQFULUODX'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(1, 0)"], "baseValue": 0.04, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 154.0, "features": {"0": {"effect": -0.02, "value": 111.53617498685358}, "1": {"effect": -0.02, "value": 94.84660603958575}}}, {"outValue": 0.0, "simIndex": 153.0, "features": {"0": {"effect": -0.02, "value": 49.276389908283484}, "1": {"effect": -0.02, "value": 70.80765024123922}}}, {"outValue": 1.0, "simIndex": 2.0, "features": {"0": {"effect": 0.47000000000000003, "value": 73.83951165108653}, "1": {"effect": 0.48999999999999994, "value": 46.48765384868598}}}, {"outValue": 0.0, "simIndex": 152.0, "features": {"0": {"effect": -0.02, "value": 29.562844922404945}, "1": {"effect": -0.02, "value": -196.8648303615631}}}, {"outValue": 0.0, "simIndex": 155.0, "features": {"0": {"effect": -0.02, "value": -62.23366635555217}, "1": {"effect": -0.02, "value": -243.52467212282912}}}, {"outValue": 0.0, "simIndex": 151.0, "features": {"0": {"effect": -0.02, "value": 114.15225077889959}, "1": {"effect": -0.02, "value": 182.5957849905552}}}, {"outValue": -6.938893903907228e-18, "simIndex": 256.0, "features": {"0": {"effect": 0.045, "value": 93.51981243478768}, "1": {"effect": -0.085, "value": -107.4253836219851}}}, {"outValue": 0.0, "simIndex": 156.0, "features": {"0": {"effect": -0.02, "value": 38.75757706557677}, "1": {"effect": -0.02, "value": -71.52437324879315}}}, {"outValue": 6.938893903907228e-18, "simIndex": 34.0, "features": {"0": {"effect": -0.145, "value": -15.775584358870287}, "1": {"effect": 0.105, "value": 22.006794155309727}}}, {"outValue": 0.0, "simIndex": 150.0, "features": {"0": {"effect": -0.02, "value": 252.99766006035816}, "1": {"effect": -0.02, "value": -94.01255096003749}}}, {"outValue": -6.938893903907228e-18, "simIndex": 293.0, "features": {"0": {"effect": 0.065, "value": 67.3057788151459}, "1": {"effect": -0.10500000000000001, "value": 75.27414721973086}}}, {"outValue": 0.0, "simIndex": 157.0, "features": {"0": {"effect": -0.02, "value": 243.9279128981836}, "1": {"effect": -0.02, "value": -124.85042803033653}}}, {"outValue": 0.0, "simIndex": 149.0, "features": {"0": {"effect": -0.02, "value": 123.09571751718342}, "1": {"effect": -0.02, "value": -117.86713386848466}}}, {"outValue": -6.938893903907228e-18, "simIndex": 255.0, "features": {"0": {"effect": 0.045, "value": 95.5264767724994}, "1": {"effect": -0.085, "value": 165.01275476364737}}}, {"outValue": 0.0, "simIndex": 158.0, "features": {"0": {"effect": -0.02, "value": 155.7603595119916}, "1": {"effect": -0.02, "value": 164.6433430927805}}}, {"outValue": 0.0, "simIndex": 148.0, "features": {"0": {"effect": -0.02, "value": 4.4453170088412435}, "1": {"effect": -0.02, "value": 82.4369884214837}}}, {"outValue": 0.0, "simIndex": 159.0, "features": {"0": {"effect": -0.02, "value": 158.57459693663034}, "1": {"effect": -0.02, "value": -102.42998575127005}}}, {"outValue": 0.0, "simIndex": 147.0, "features": {"0": {"effect": -0.02, "value": 0.7026410828595231}, "1": {"effect": -0.02, "value": -3.454652008977943}}}, {"outValue": 0.0, "simIndex": 61.0, "features": {"0": {"effect": -0.03, "value": 118.50815541519346}, "1": {"effect": -0.01, "value": 63.83767951084997}}}, {"outValue": 0.0, "simIndex": 160.0, "features": {"0": {"effect": -0.02, "value": 11.198916778248002}, "1": {"effect": -0.02, "value": -25.101326101672278}}}, {"outValue": 0.0, "simIndex": 146.0, "features": {"0": {"effect": -0.02, "value": 227.76033534038848}, "1": {"effect": -0.02, "value": 224.28686952174627}}}, {"outValue": 0.0, "simIndex": 161.0, "features": {"0": {"effect": -0.02, "value": 115.84828036929716}, "1": {"effect": -0.02, "value": 123.26900666309588}}}, {"outValue": 0.0, "simIndex": 145.0, "features": {"0": {"effect": -0.02, "value": 18.545863833251662}, "1": {"effect": -0.02, "value": -342.9421556269003}}}, {"outValue": -6.938893903907228e-18, "simIndex": 282.0, "features": {"0": {"effect": 0 ...
