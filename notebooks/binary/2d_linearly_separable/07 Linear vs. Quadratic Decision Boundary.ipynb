# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
import shap
import pickle
import cloudpickle
import numpy as np
from comparers import ModelComparer
from explainers import generate_shap_explanations
from plots import plot_decision_boundary, plot_2d, plot_feature_importance_bar, plot_feature_importance_scatter,\
                  plot_feature_effects, plot_forces
from util import calc_feature_order, calc_class_order, calc_instance_order
shap.initjs()
# %matplotlib inline
task_name = '07'
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
try:
    with open(task_name + '.models', 'rb') as f:
        comparer = pickle.load(f)
    with open(task_name + '.expl', 'rb') as f:
        explanations = pickle.load(f)
    print('loaded saved state')
except FileNotFoundError:
    pass
# Out:
# loaded saved state

# %% [markdown]
# # Setup Task

# %%
X, y = make_classification(n_samples=300, n_features=2, n_redundant=0, n_informative=2,
                           n_clusters_per_class=1, class_sep=0.75, random_state=0)
feature_names = np.array(['x1', 'x2'])
n_features = len(feature_names)
n_samples = X.shape[0]

# %%
from sklearn.linear_model import LogisticRegression
lm = LogisticRegression()
lm.fit(X, y)
lm.intercept_, lm.coef_
# Out:
# (array([0.91535451]), array([[-1.76177855,  2.52385315]]))

# %%
fig, ax = plt.subplots(figsize=(7, 7), constrained_layout=True)
plot_decision_boundary(X, y, 'Base classification task with linear discrimination boundary', feature_names,
                       predict=lm.predict, class_names=lm.classes_,
                       fig=fig, ax=ax)

# %%
clf_a = lm

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
clf_b = QuadraticDiscriminantAnalysis(store_covariance=True)
clf_b.fit(X, y)
# Out:
# QuadraticDiscriminantAnalysis(store_covariance=True)

# %%
comparer = ModelComparer(clf_a, clf_b, feature_names)
comparer.fit(X, y)
with open(task_name + '.models', 'wb') as f:
    cloudpickle.dump(comparer, f, pickle.HIGHEST_PROTOCOL)

# %%
comparer.plot_individual_clf_decision_boundaries(X, y_true=y, kind='label')

# %%
comparer.plot_decision_boundaries(X)

# %%
comparer.plot_confusion_matrix(X)

# %% [markdown]
# # Explain using Interpretability Methods

# %%
# %%time
explanations = generate_shap_explanations(comparer, X, space_types=['labels'])
with open(task_name + '.expl', 'wb') as f:
    pickle.dump(explanations, f, pickle.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 6.45 s, sys: 110 ms, total: 6.56 s
# Wall time: 7.18 s

# %% [markdown]
# ## Visualize SHAP values

# %% [markdown]
# ### Individual explanations

# %%
plot_2d(explanations.indiv.labels[:, :, 1].merged)

# %% [markdown]
# ### Simple subtraction explanation

# %%
plot_2d(explanations.indiv_diff.labels)

# %% [markdown]
# ### Multiclass difference classifier explanations

# %%
plot_2d(explanations.mclass_diff.labels)

# %% [markdown]
# ## Feature importance

# %% [markdown]
# ### Individual explanations

# %%
plot_feature_importance_bar(explanations.indiv.labels[:, :, 1].merged)

# %%
plot_feature_importance_scatter(explanations.indiv.labels[:, :, 1].merged)

# %% [markdown]
# ### Simple subtraction explanation

# %%
plot_feature_importance_bar(explanations.indiv_diff.labels[:, :, 1])

# %%
plot_feature_importance_scatter(explanations.indiv_diff.labels[:, :, 1])

# %% [markdown]
# ### Multiclass difference classifier explanations

# %%
feature_order, feature_importance = calc_feature_order(explanations.mclass_diff.labels[:, :, comparer.difference_class_names])
plot_feature_importance_bar(feature_importance)

# %%
plot_feature_importance_bar(explanations.mclass_diff.labels)

# %%
plot_feature_importance_scatter(explanations.mclass_diff.labels)

# %% [markdown]
# ## Feature effects

# %% [markdown]
# ### Individual explanations

# %%
is_pred_diff = comparer.predict_bin_diff(explanations.data)
plot_feature_effects(explanations.indiv.labels[:, :, 1].merged, color=is_pred_diff)

# %% [markdown]
# ### Simple subtraction explanation

# %%
plot_feature_effects(explanations.indiv_diff.labels[:, :, 1], color=is_pred_diff)

# %% [markdown]
# ### Multiclass difference classifier explanations

# %%
plot_feature_effects(explanations.mclass_diff.labels, color=is_pred_diff)

# %% [markdown]
# ## Cluster instances

# %% [markdown]
# ### Individual explanations

# %%
instance_order = calc_instance_order(explanations.merged)
plot_forces(explanations.indiv.labels[:, :, 1].merged, instance_order=instance_order)
# Out:
# <div id='iI18KSE2SGN7W608H9EN3'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["A.1"], "baseValue": 0.54, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 1.0, "simIndex": 85.0, "features": {"0": {"effect": -8.326672684688674e-17, "value": 1.1153617498685358}, "1": {"effect": 0.4600000000000001, "value": 0.9484660603958575}}}, {"outValue": 1.0, "simIndex": 159.0, "features": {"0": {"effect": 0.12499999999999994, "value": 0.49276389908283486}, "1": {"effect": 0.335, "value": 0.7080765024123922}}}, {"outValue": 1.0, "simIndex": 144.0, "features": {"0": {"effect": 0.17999999999999988, "value": 0.7383951165108653}, "1": {"effect": 0.2800000000000001, "value": 0.4648765384868598}}}, {"outValue": 0.0, "simIndex": 268.0, "features": {"0": {"effect": 0.044999999999999984, "value": 0.29562844922404946}, "1": {"effect": -0.585, "value": -1.9686483036156308}}}, {"outValue": 0.0, "simIndex": 290.0, "features": {"0": {"effect": 0.14499999999999996, "value": -0.6223366635555216}, "1": {"effect": -0.685, "value": -2.435246721228291}}}, {"outValue": 1.0, "simIndex": 45.0, "features": {"0": {"effect": -0.05500000000000002, "value": 1.1415225077889959}, "1": {"effect": 0.515, "value": 1.825957849905552}}}, {"outValue": 0.0, "simIndex": 242.0, "features": {"0": {"effect": -0.020000000000000018, "value": 0.9351981243478769}, "1": {"effect": -0.52, "value": -1.074253836219851}}}, {"outValue": 0.0, "simIndex": 255.0, "features": {"0": {"effect": 0.014999999999999958, "value": 0.3875757706557677}, "1": {"effect": -0.5549999999999999, "value": -0.7152437324879316}}}, {"outValue": 1.0, "simIndex": 115.0, "features": {"0": {"effect": 0.33499999999999996, "value": -0.15775584358870287}, "1": {"effect": 0.125, "value": 0.22006794155309728}}}, {"outValue": 0.0, "simIndex": 194.0, "features": {"0": {"effect": -0.23500000000000004, "value": 2.5299766006035815}, "1": {"effect": -0.305, "value": -0.9401255096003749}}}, {"outValue": 1.0, "simIndex": 165.0, "features": {"0": {"effect": 0.09499999999999992, "value": 0.673057788151459}, "1": {"effect": 0.36500000000000005, "value": 0.7527414721973087}}}, {"outValue": 0.0, "simIndex": 195.0, "features": {"0": {"effect": -0.22000000000000003, "value": 2.439279128981836}, "1": {"effect": -0.32, "value": -1.2485042803033652}}}, {"outValue": 0.0, "simIndex": 227.0, "features": {"0": {"effect": -0.06500000000000003, "value": 1.2309571751718342}, "1": {"effect": -0.475, "value": -1.1786713386848466}}}, {"outValue": 1.0, "simIndex": 65.0, "features": {"0": {"effect": -0.025000000000000022, "value": 0.9552647677249939}, "1": {"effect": 0.485, "value": 1.6501275476364736}}}, {"outValue": 1.0, "simIndex": 35.0, "features": {"0": {"effect": -0.09000000000000002, "value": 1.5576035951199159}, "1": {"effect": 0.55, "value": 1.646433430927805}}}, {"outValue": 1.0, "simIndex": 154.0, "features": {"0": {"effect": 0.13999999999999996, "value": 0.04445317008841243}, "1": {"effect": 0.32, "value": 0.824369884214837}}}, {"outValue": 0.0, "simIndex": 220.0, "features": {"0": {"effect": -0.09000000000000002, "value": 1.5857459693663034}, "1": {"effect": -0.45, "value": -1.0242998575127005}}}, {"outValue": 1.0, "simIndex": 111.0, "features": {"0": {"effect": 0.44499999999999995, "value": 0.007026410828595231}, "1": {"effect": 0.015000000000000013, "value": -0.03454652008977943}}}, {"outValue": 1.0, "simIndex": 101.0, "features": {"0": {"effect": 0.04999999999999996, "value": 1.1850815541519346}, "1": {"effect": 0.41000000000000003, "value": 0.6383767951084998}}}, {"outValue": 1.0, "simIndex": 107.0, "features": {"0": {"effect": 0.485, "value": 0.11198916778248003}, "1": {"effect": -0.025000000000000022, "value": -0.2510132610167228}}}, {"outValue": 1.0, "simIndex": 23.0, "features": {"0": {"effect": -0.20500000000000002, "value": 2.277603353403885}, "1": {"effect": 0.665, "value": 2.242868695217463}}}, {"outValue": 1.0, "simIndex": 56.0, "features": {"0": {"effect": -0.04000000000000001, "value": 1.15848280 ...
# <div id='iX2A4LOWQ1VGNHJXNH43K'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["B.1"], "baseValue": 0.54, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 1.0, "simIndex": 21.0, "features": {"0": {"effect": 0.0749999999999999, "value": 1.1153617498685358}, "1": {"effect": 0.38500000000000006, "value": 0.9484660603958575}}}, {"outValue": 1.0, "simIndex": 150.0, "features": {"0": {"effect": 0.11999999999999994, "value": 0.49276389908283486}, "1": {"effect": 0.34, "value": 0.7080765024123922}}}, {"outValue": 1.0, "simIndex": 138.0, "features": {"0": {"effect": 0.14499999999999996, "value": 0.7383951165108653}, "1": {"effect": 0.315, "value": 0.4648765384868598}}}, {"outValue": 0.0, "simIndex": 277.0, "features": {"0": {"effect": 0.05499999999999999, "value": 0.29562844922404946}, "1": {"effect": -0.595, "value": -1.9686483036156308}}}, {"outValue": 0.0, "simIndex": 240.0, "features": {"0": {"effect": 0.010000000000000009, "value": -0.6223366635555216}, "1": {"effect": -0.55, "value": -2.435246721228291}}}, {"outValue": 1.0, "simIndex": 42.0, "features": {"0": {"effect": 0.06499999999999995, "value": 1.1415225077889959}, "1": {"effect": 0.395, "value": 1.825957849905552}}}, {"outValue": 0.0, "simIndex": 245.0, "features": {"0": {"effect": 0.019999999999999962, "value": 0.9351981243478769}, "1": {"effect": -0.56, "value": -1.074253836219851}}}, {"outValue": 0.0, "simIndex": 276.0, "features": {"0": {"effect": 0.05499999999999999, "value": 0.3875757706557677}, "1": {"effect": -0.595, "value": -0.7152437324879316}}}, {"outValue": 1.0, "simIndex": 108.0, "features": {"0": {"effect": 0.22499999999999992, "value": -0.15775584358870287}, "1": {"effect": 0.23500000000000004, "value": 0.22006794155309728}}}, {"outValue": 0.0, "simIndex": 200.0, "features": {"0": {"effect": -0.27, "value": 2.5299766006035815}, "1": {"effect": -0.27, "value": -0.9401255096003749}}}, {"outValue": 1.0, "simIndex": 168.0, "features": {"0": {"effect": 0.09999999999999992, "value": 0.673057788151459}, "1": {"effect": 0.36000000000000004, "value": 0.7527414721973087}}}, {"outValue": 0.0, "simIndex": 199.0, "features": {"0": {"effect": -0.27, "value": 2.439279128981836}, "1": {"effect": -0.27, "value": -1.2485042803033652}}}, {"outValue": 0.0, "simIndex": 230.0, "features": {"0": {"effect": -0.010000000000000009, "value": 1.2309571751718342}, "1": {"effect": -0.53, "value": -1.1786713386848466}}}, {"outValue": 1.0, "simIndex": 44.0, "features": {"0": {"effect": 0.06499999999999989, "value": 0.9552647677249939}, "1": {"effect": 0.3950000000000001, "value": 1.6501275476364736}}}, {"outValue": 1.0, "simIndex": 82.0, "features": {"0": {"effect": -0.0200000000000001, "value": 1.5576035951199159}, "1": {"effect": 0.4800000000000001, "value": 1.646433430927805}}}, {"outValue": 1.0, "simIndex": 145.0, "features": {"0": {"effect": 0.12499999999999994, "value": 0.04445317008841243}, "1": {"effect": 0.335, "value": 0.824369884214837}}}, {"outValue": 0.0, "simIndex": 216.0, "features": {"0": {"effect": -0.07, "value": 1.5857459693663034}, "1": {"effect": -0.47000000000000003, "value": -1.0242998575127005}}}, {"outValue": 1.0, "simIndex": 101.0, "features": {"0": {"effect": 0.315, "value": 0.007026410828595231}, "1": {"effect": 0.14499999999999996, "value": -0.03454652008977943}}}, {"outValue": 1.0, "simIndex": 23.0, "features": {"0": {"effect": 0.07499999999999996, "value": 1.1850815541519346}, "1": {"effect": 0.385, "value": 0.6383767951084998}}}, {"outValue": 1.0, "simIndex": 93.0, "features": {"0": {"effect": 0.48, "value": 0.11198916778248003}, "1": {"effect": -0.020000000000000018, "value": -0.2510132610167228}}}, {"outValue": 0.0, "simIndex": 11.0, "features": {"0": {"effect": -0.65, "value": 2.277603353403885}, "1": {"effect": 0.10999999999999999, "value": 2.242868695217463}}}, {"outValue": 1.0, "simIndex": 50.0, "features": {"0": {"effect": 0.050000000000000044, "value": 1.1584828036929715}, "1": {"effect": 0.4099999999999999, "value": 1.2 ...

# %% [markdown]
# ### Simple subtraction explanation

# %%
plot_forces(explanations.indiv_diff.labels, instance_order=instance_order)
# Out:
# <div id='i6455JJJO7S2XW0KY5VKO'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["0"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 2.7755575615628914e-17, "simIndex": 52.0, "features": {"0": {"effect": 0.07499999999999998, "value": 1.1153617498685358}, "1": {"effect": -0.07499999999999996, "value": 0.9484660603958575}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 191.0, "features": {"0": {"effect": -0.005000000000000032, "value": 0.49276389908283486}, "1": {"effect": 0.00500000000000006, "value": 0.7080765024123922}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 214.0, "features": {"0": {"effect": -0.035, "value": 0.7383951165108653}, "1": {"effect": 0.034999999999999976, "value": 0.4648765384868598}}}, {"outValue": 0.0, "simIndex": 168.0, "features": {"0": {"effect": 0.010000000000000009, "value": 0.29562844922404946}, "1": {"effect": -0.010000000000000009, "value": -1.9686483036156308}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 280.0, "features": {"0": {"effect": -0.13499999999999998, "value": -0.6223366635555216}, "1": {"effect": 0.135, "value": -2.435246721228291}}}, {"outValue": 0.0, "simIndex": 20.0, "features": {"0": {"effect": 0.12, "value": 1.1415225077889959}, "1": {"effect": -0.12, "value": 1.825957849905552}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 111.0, "features": {"0": {"effect": 0.04000000000000001, "value": 0.9351981243478769}, "1": {"effect": -0.040000000000000036, "value": -1.074253836219851}}}, {"outValue": 0.0, "simIndex": 113.0, "features": {"0": {"effect": 0.040000000000000036, "value": 0.3875757706557677}, "1": {"effect": -0.040000000000000036, "value": -0.7152437324879316}}}, {"outValue": 0.0, "simIndex": 276.0, "features": {"0": {"effect": -0.11000000000000001, "value": -0.15775584358870287}, "1": {"effect": 0.11000000000000001, "value": 0.22006794155309728}}}, {"outValue": 0.0, "simIndex": 217.0, "features": {"0": {"effect": -0.034999999999999976, "value": 2.5299766006035815}, "1": {"effect": 0.034999999999999976, "value": -0.9401255096003749}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 177.0, "features": {"0": {"effect": 0.005000000000000032, "value": 0.673057788151459}, "1": {"effect": -0.0050000000000000044, "value": 0.7527414721973087}}}, {"outValue": 0.0, "simIndex": 238.0, "features": {"0": {"effect": -0.04999999999999999, "value": 2.439279128981836}, "1": {"effect": 0.04999999999999999, "value": -1.2485042803033652}}}, {"outValue": 0.0, "simIndex": 84.0, "features": {"0": {"effect": 0.05499999999999999, "value": 1.2309571751718342}, "1": {"effect": -0.05499999999999999, "value": -1.1786713386848466}}}, {"outValue": 5.551115123125783e-17, "simIndex": 34.0, "features": {"0": {"effect": 0.09000000000000002, "value": 0.9552647677249939}, "1": {"effect": -0.08999999999999997, "value": 1.6501275476364736}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 62.0, "features": {"0": {"effect": 0.07000000000000003, "value": 1.5576035951199159}, "1": {"effect": -0.07000000000000006, "value": 1.646433430927805}}}, {"outValue": 0.0, "simIndex": 200.0, "features": {"0": {"effect": -0.014999999999999958, "value": 0.04445317008841243}, "1": {"effect": 0.014999999999999958, "value": 0.824369884214837}}}, {"outValue": 0.0, "simIndex": 149.0, "features": {"0": {"effect": 0.020000000000000018, "value": 1.5857459693663034}, "1": {"effect": -0.020000000000000018, "value": -1.0242998575127005}}}, {"outValue": 0.0, "simIndex": 279.0, "features": {"0": {"effect": -0.13, "value": 0.007026410828595231}, "1": {"effect": 0.13, "value": -0.03454652008977943}}}, {"outValue": -2.7755575615628914e-17, "simIndex": 134.0, "features": {"0": {"effect": 0.02499999999999994, "value": 1.1850815541519346}, "1": {"effect": -0.024999999999999967, "value": 0.6383767951084998}}}, {"outValue": 0.0, "simIndex": 189.0, "features": {"0": {"effect": -0.0050000000000000044, "value": 0.11198916778248003}, "1": {"effect": 0.0050000000000000044, "value": ...
# <div id='iO0M31348ZEJHAQAXG5O1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["1"], "baseValue": 0.0, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 2.7755575615628914e-17, "simIndex": 58.0, "features": {"0": {"effect": -0.07499999999999998, "value": 1.1153617498685358}, "1": {"effect": 0.07500000000000001, "value": 0.9484660603958575}}}, {"outValue": 0.0, "simIndex": 188.0, "features": {"0": {"effect": 0.0050000000000000044, "value": 0.49276389908283486}, "1": {"effect": -0.0050000000000000044, "value": 0.7080765024123922}}}, {"outValue": 0.0, "simIndex": 212.0, "features": {"0": {"effect": 0.03499999999999992, "value": 0.7383951165108653}, "1": {"effect": -0.03499999999999992, "value": 0.4648765384868598}}}, {"outValue": 0.0, "simIndex": 166.0, "features": {"0": {"effect": -0.010000000000000009, "value": 0.29562844922404946}, "1": {"effect": 0.010000000000000009, "value": -1.9686483036156308}}}, {"outValue": -5.551115123125783e-17, "simIndex": 282.0, "features": {"0": {"effect": 0.13499999999999995, "value": -0.6223366635555216}, "1": {"effect": -0.135, "value": -2.435246721228291}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 20.0, "features": {"0": {"effect": -0.11999999999999997, "value": 1.1415225077889959}, "1": {"effect": 0.12, "value": 1.825957849905552}}}, {"outValue": 5.551115123125783e-17, "simIndex": 110.0, "features": {"0": {"effect": -0.03999999999999998, "value": 0.9351981243478769}, "1": {"effect": 0.040000000000000036, "value": -1.074253836219851}}}, {"outValue": 0.0, "simIndex": 111.0, "features": {"0": {"effect": -0.040000000000000036, "value": 0.3875757706557677}, "1": {"effect": 0.040000000000000036, "value": -0.7152437324879316}}}, {"outValue": 0.0, "simIndex": 276.0, "features": {"0": {"effect": 0.11000000000000004, "value": -0.15775584358870287}, "1": {"effect": -0.11000000000000004, "value": 0.22006794155309728}}}, {"outValue": 0.0, "simIndex": 214.0, "features": {"0": {"effect": 0.034999999999999976, "value": 2.5299766006035815}, "1": {"effect": -0.034999999999999976, "value": -0.9401255096003749}}}, {"outValue": 0.0, "simIndex": 177.0, "features": {"0": {"effect": -0.0050000000000000044, "value": 0.673057788151459}, "1": {"effect": 0.0050000000000000044, "value": 0.7527414721973087}}}, {"outValue": 0.0, "simIndex": 236.0, "features": {"0": {"effect": 0.04999999999999999, "value": 2.439279128981836}, "1": {"effect": -0.04999999999999999, "value": -1.2485042803033652}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 83.0, "features": {"0": {"effect": -0.05500000000000002, "value": 1.2309571751718342}, "1": {"effect": 0.05500000000000005, "value": -1.1786713386848466}}}, {"outValue": 0.0, "simIndex": 34.0, "features": {"0": {"effect": -0.08999999999999991, "value": 0.9552647677249939}, "1": {"effect": 0.08999999999999991, "value": 1.6501275476364736}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 65.0, "features": {"0": {"effect": -0.06999999999999992, "value": 1.5576035951199159}, "1": {"effect": 0.06999999999999995, "value": 1.646433430927805}}}, {"outValue": 0.0, "simIndex": 200.0, "features": {"0": {"effect": 0.015000000000000013, "value": 0.04445317008841243}, "1": {"effect": -0.015000000000000013, "value": 0.824369884214837}}}, {"outValue": 0.0, "simIndex": 152.0, "features": {"0": {"effect": -0.020000000000000018, "value": 1.5857459693663034}, "1": {"effect": 0.020000000000000018, "value": -1.0242998575127005}}}, {"outValue": 0.0, "simIndex": 279.0, "features": {"0": {"effect": 0.12999999999999995, "value": 0.007026410828595231}, "1": {"effect": -0.12999999999999995, "value": -0.03454652008977943}}}, {"outValue": 2.7755575615628914e-17, "simIndex": 138.0, "features": {"0": {"effect": -0.024999999999999994, "value": 1.1850815541519346}, "1": {"effect": 0.025000000000000022, "value": 0.6383767951084998}}}, {"outValue": 0.0, "simIndex": 189.0, "features": {"0": {"effect": 0.0050000000000000044, "value": 0.11198916778248003}, "1": {"effect": -0.00500000 ...

# %% [markdown]
# ### Multiclass difference classifier explanations

# %%
plot_forces(explanations.mclass_diff.labels[:, :, comparer.difference_class_names], instance_order=instance_order)
# Out:
# <div id='iDSTSNHFDB170NLB37CTW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(0, 1)"], "baseValue": 0.03, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": -6.938893903907228e-18, "simIndex": 295.0, "features": {"0": {"effect": 0.049999999999999996, "value": 1.1153617498685358}, "1": {"effect": -0.08, "value": 0.9484660603958575}}}, {"outValue": 0.0, "simIndex": 84.0, "features": {"0": {"effect": -0.02, "value": 0.49276389908283486}, "1": {"effect": -0.009999999999999998, "value": 0.7080765024123922}}}, {"outValue": 0.0, "simIndex": 63.0, "features": {"0": {"effect": -0.049999999999999996, "value": 0.7383951165108653}, "1": {"effect": 0.019999999999999997, "value": 0.4648765384868598}}}, {"outValue": 0.0, "simIndex": 163.0, "features": {"0": {"effect": -0.004999999999999999, "value": 0.29562844922404946}, "1": {"effect": -0.025, "value": -1.9686483036156308}}}, {"outValue": 0.0, "simIndex": 112.0, "features": {"0": {"effect": -0.015, "value": -0.6223366635555216}, "1": {"effect": -0.015, "value": -2.435246721228291}}}, {"outValue": 0.0, "simIndex": 286.0, "features": {"0": {"effect": 0.05, "value": 1.1415225077889959}, "1": {"effect": -0.08, "value": 1.825957849905552}}}, {"outValue": 0.0, "simIndex": 257.0, "features": {"0": {"effect": 0.025, "value": 0.9351981243478769}, "1": {"effect": -0.055, "value": -1.074253836219851}}}, {"outValue": -3.469446951953614e-18, "simIndex": 194.0, "features": {"0": {"effect": 0.005000000000000001, "value": 0.3875757706557677}, "1": {"effect": -0.035, "value": -0.7152437324879316}}}, {"outValue": 0.0, "simIndex": 29.0, "features": {"0": {"effect": -0.085, "value": -0.15775584358870287}, "1": {"effect": 0.05500000000000001, "value": 0.22006794155309728}}}, {"outValue": 0.0, "simIndex": 113.0, "features": {"0": {"effect": -0.015, "value": 2.5299766006035815}, "1": {"effect": -0.015, "value": -0.9401255096003749}}}, {"outValue": 0.0, "simIndex": 143.0, "features": {"0": {"effect": -0.010000000000000002, "value": 0.673057788151459}, "1": {"effect": -0.019999999999999997, "value": 0.7527414721973087}}}, {"outValue": 0.0, "simIndex": 114.0, "features": {"0": {"effect": -0.015, "value": 2.439279128981836}, "1": {"effect": -0.015, "value": -1.2485042803033652}}}, {"outValue": -6.938893903907228e-18, "simIndex": 269.0, "features": {"0": {"effect": 0.04, "value": 1.2309571751718342}, "1": {"effect": -0.07, "value": -1.1786713386848466}}}, {"outValue": 0.0, "simIndex": 263.0, "features": {"0": {"effect": 0.03, "value": 0.9552647677249939}, "1": {"effect": -0.06, "value": 1.6501275476364736}}}, {"outValue": 0.0, "simIndex": 224.0, "features": {"0": {"effect": 0.010000000000000002, "value": 1.5576035951199159}, "1": {"effect": -0.04, "value": 1.646433430927805}}}, {"outValue": 0.0, "simIndex": 80.0, "features": {"0": {"effect": -0.025, "value": 0.04445317008841243}, "1": {"effect": -0.004999999999999999, "value": 0.824369884214837}}}, {"outValue": -3.469446951953614e-18, "simIndex": 195.0, "features": {"0": {"effect": 0.005000000000000001, "value": 1.5857459693663034}, "1": {"effect": -0.035, "value": -1.0242998575127005}}}, {"outValue": -1.3877787807814457e-17, "simIndex": 13.0, "features": {"0": {"effect": -0.14, "value": 0.007026410828595231}, "1": {"effect": 0.11, "value": -0.03454652008977943}}}, {"outValue": 0.0, "simIndex": 225.0, "features": {"0": {"effect": 0.010000000000000002, "value": 1.1850815541519346}, "1": {"effect": -0.04, "value": 0.6383767951084998}}}, {"outValue": 0.0, "simIndex": 73.0, "features": {"0": {"effect": -0.04, "value": 0.11198916778248003}, "1": {"effect": 0.010000000000000002, "value": -0.2510132610167228}}}, {"outValue": 0.0, "simIndex": 111.0, "features": {"0": {"effect": -0.015, "value": 2.277603353403885}, "1": {"effect": -0.015, "value": 2.242868695217463}}}, {"outValue": 0.0, "simIndex": 276.0, "features": {"0": {"effect": 0.045, "value": 1.1584828036929715}, "1": {"effect": -0.075, "value": 1.2326900666309588}}}, {"outValue": 0.0, "si ...
# <div id='iTKQPRGQF2BESMJV2UJUT'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["(1, 0)"], "baseValue": 0.03, "link": "identity", "featureNames": ["x1", "x2"], "explanations": [{"outValue": 0.0, "simIndex": 114.0, "features": {"0": {"effect": -0.025, "value": 1.1153617498685358}, "1": {"effect": -0.004999999999999999, "value": 0.9484660603958575}}}, {"outValue": 0.0, "simIndex": 195.0, "features": {"0": {"effect": -0.015, "value": 0.49276389908283486}, "1": {"effect": -0.015, "value": 0.7080765024123922}}}, {"outValue": 0.0, "simIndex": 194.0, "features": {"0": {"effect": -0.015, "value": 0.7383951165108653}, "1": {"effect": -0.015, "value": 0.4648765384868598}}}, {"outValue": 0.0, "simIndex": 193.0, "features": {"0": {"effect": -0.015, "value": 0.29562844922404946}, "1": {"effect": -0.015, "value": -1.9686483036156308}}}, {"outValue": -1.3877787807814457e-17, "simIndex": 287.0, "features": {"0": {"effect": 0.12000000000000001, "value": -0.6223366635555216}, "1": {"effect": -0.15000000000000002, "value": -2.435246721228291}}}, {"outValue": -6.938893903907228e-18, "simIndex": 28.0, "features": {"0": {"effect": -0.07, "value": 1.1415225077889959}, "1": {"effect": 0.04, "value": 1.825957849905552}}}, {"outValue": 0.0, "simIndex": 196.0, "features": {"0": {"effect": -0.015, "value": 0.9351981243478769}, "1": {"effect": -0.015, "value": -1.074253836219851}}}, {"outValue": -3.469446951953614e-18, "simIndex": 80.0, "features": {"0": {"effect": -0.035, "value": 0.3875757706557677}, "1": {"effect": 0.005000000000000001, "value": -0.7152437324879316}}}, {"outValue": 0.0, "simIndex": 272.0, "features": {"0": {"effect": 0.025, "value": -0.15775584358870287}, "1": {"effect": -0.055, "value": 0.22006794155309728}}}, {"outValue": 0.0, "simIndex": 269.0, "features": {"0": {"effect": 0.019999999999999997, "value": 2.5299766006035815}, "1": {"effect": -0.049999999999999996, "value": -0.9401255096003749}}}, {"outValue": 0.0, "simIndex": 192.0, "features": {"0": {"effect": -0.015, "value": 0.673057788151459}, "1": {"effect": -0.015, "value": 0.7527414721973087}}}, {"outValue": 0.0, "simIndex": 278.0, "features": {"0": {"effect": 0.035, "value": 2.439279128981836}, "1": {"effect": -0.065, "value": -1.2485042803033652}}}, {"outValue": 0.0, "simIndex": 197.0, "features": {"0": {"effect": -0.015, "value": 1.2309571751718342}, "1": {"effect": -0.015, "value": -1.1786713386848466}}}, {"outValue": 0.0, "simIndex": 38.0, "features": {"0": {"effect": -0.06, "value": 0.9552647677249939}, "1": {"effect": 0.03, "value": 1.6501275476364736}}}, {"outValue": 0.0, "simIndex": 37.0, "features": {"0": {"effect": -0.06, "value": 1.5576035951199159}, "1": {"effect": 0.03, "value": 1.646433430927805}}}, {"outValue": 0.0, "simIndex": 249.0, "features": {"0": {"effect": -0.009999999999999998, "value": 0.04445317008841243}, "1": {"effect": -0.02, "value": 0.824369884214837}}}, {"outValue": 0.0, "simIndex": 191.0, "features": {"0": {"effect": -0.015, "value": 1.5857459693663034}, "1": {"effect": -0.015, "value": -1.0242998575127005}}}, {"outValue": 0.0, "simIndex": 247.0, "features": {"0": {"effect": -0.010000000000000002, "value": 0.007026410828595231}, "1": {"effect": -0.019999999999999997, "value": -0.03454652008977943}}}, {"outValue": 0.0, "simIndex": 198.0, "features": {"0": {"effect": -0.015, "value": 1.1850815541519346}, "1": {"effect": -0.015, "value": 0.6383767951084998}}}, {"outValue": -3.469446951953614e-18, "simIndex": 79.0, "features": {"0": {"effect": -0.035, "value": 0.11198916778248003}, "1": {"effect": 0.005000000000000001, "value": -0.2510132610167228}}}, {"outValue": 1.0, "simIndex": 2.0, "features": {"0": {"effect": 0.43, "value": 2.277603353403885}, "1": {"effect": 0.54, "value": 2.242868695217463}}}, {"outValue": 0.0, "simIndex": 61.0, "features": {"0": {"effect": -0.045, "value": 1.1584828036929715}, "1": {"effect": 0.015, "value": 1.2326900666309588}}}, {"outValue": 0.0, "simIndex": 190.0, "features": {"0": {"effect": -0.015, "value": 0.185458638332 ...
