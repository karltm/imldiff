# %%
v

# %% [markdown]
# ### Feature effects

# %% [markdown]
# Let's check the decision plots for each group of their multiclass difference classifier classes' SHAP values:

# %%
shap_values = explanations_clustered.mclass_diff.log_odds.cohorts['(0, 1)'][:, :, '(0, 1)']
shap.decision_plot(shap_values.base_values[0], shap_values.values, xlim=(-3.0, -0.8))

# %%
shap_values = explanations_clustered.mclass_diff.log_odds.cohorts['(1, 2)'][:, :, '(1, 2)']
shap.decision_plot(shap_values.base_values[0], shap_values.values, xlim=(-3.0, -0.8))

# %%
shap_values = explanations_clustered.mclass_diff.log_odds.cohorts['(2, 1)'][:, :, '(2, 1)']
shap.decision_plot(shap_values.base_values[0], shap_values.values, xlim=(-3.0, -0.8))
