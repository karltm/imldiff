# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
import shap
import pickle
import cloudpickle
import numpy as np
from comparers import ModelComparer
from explainers import generate_shap_explanations
from plots import plot_decision_boundary, plot_2d, plot_feature_importance_bar, plot_feature_importance_scatter,\
                  plot_feature_effects, plot_forces
from util import calc_feature_order, calc_class_order, calc_instance_order
import pandas as pd
import diro2c
from data_generation.helper import prepare_df
from data_generation.neighborhood_generation import neighbor_generator
from enums.diff_classifier_method_type import diff_classifier_method_type
from mlxtend.plotting import plot_decision_regions
from sklearn.tree import plot_tree
import rule_extractor
shap.initjs()
# %matplotlib inline
task_name = '02'
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
with open(task_name + '.dataset', 'rb') as f:
    X, y, feature_names = pickle.load(f)
with open(task_name + '.models', 'rb') as f:
    comparer = pickle.load(f)

# %% [markdown]
# # Explain using Interpretability Methods

# %% [markdown]
# Prepare dataset for diro2c

# %%
idx_explain = 0

# %%
feature1 = []
feature2 = []
for x in X:
    feature1.append(x[0])
    feature2.append(x[1])

feature1 = np.asarray(feature1)
feature2 = np.asarray(feature2)

y = y.astype(str)

d = {'y': y, 'feature_1': feature1, 'feature_2': feature2}

df = pd.DataFrame(d)

dataset = prepare_df(df, 'test', 'y')

# %% [markdown]
# ## Binary difference explanations

# %%
diff_classifiers_info = diro2c.recognize_diff(idx_explain, X, dataset, comparer.clf_a, comparer.clf_b,
                                              diff_classifier_method_type.binary_diff_classifier,
                                              data_generation_function=neighbor_generator.get_genetic_neighborhood)

# %%
dc_info = diff_classifiers_info['binary_diff_classifer']
dc_full = dc_info['dc_full']
dc_test = dc_info['dc_test']
evaluation_info = dc_info['evaluation_info']

X_diff = evaluation_info['X']
y_diff = evaluation_info['y']

print(np.unique(y_diff, return_counts=True))
# Out:
# (array([0, 1]), array([1285,  257]))

# %%
y_pred_a = comparer.clf_a.predict(X)
y_pred_b = comparer.clf_b.predict(X)

fig, ax = plt.subplots(1, 3, figsize=(21, 7))

fig = plot_decision_regions(X=X, y=y_pred_a.astype(
    np.int64), clf=comparer.clf_a, ax=ax[0], legend=2)
ax[0].set_xlabel(feature_names[0])
ax[0].set_ylabel(feature_names[1])
plt.title('blackbox 1')

fig = plot_decision_regions(X=X, y=y_pred_b.astype(
    np.int64), clf=comparer.clf_b, ax=ax[1], legend=2)
ax[0].set_xlabel(feature_names[0])
ax[0].set_ylabel(feature_names[1])
plt.title('blackbox 2')

fig = plot_decision_regions(X=X_diff, y=y_diff.astype(
    np.integer), clf=dc_full, ax=ax[2], legend=2)
ax[0].set_xlabel(feature_names[0])
ax[0].set_ylabel(feature_names[1])
plt.title('binary diff-classifier')

plt.show()
# Out:
# Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.

# %%
cn = ['no_diff', 'diff']
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(4, 4), dpi=300)
plot_tree(dc_full,
               feature_names=feature_names,
               class_names=cn,
               filled=True)
# Out:
# [Text(497.15425531914894, 868.25, 'x1 <= 130.5\ngini = 0.278\nsamples = 1542\nvalue = [1285, 257]\nclass = no_diff'),
#  Text(286.9148936170213, 792.75, 'x1 <= 111.5\ngini = 0.123\nsamples = 1244\nvalue = [1162, 82]\nclass = no_diff'),
#  Text(98.93617021276596, 717.25, 'x1 <= -31.5\ngini = 0.032\nsamples = 853\nvalue = [839, 14]\nclass = no_diff'),
#  Text(79.14893617021276, 641.75, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = diff'),
#  Text(118.72340425531914, 641.75, 'x1 <= 73.5\ngini = 0.023\nsamples = 849\nvalue = [839, 10]\nclass = no_diff'),
#  Text(39.57446808510638, 566.25, 'x2 <= -7.5\ngini = 0.123\nsamples = 91\nvalue = [85, 6]\nclass = no_diff'),
#  Text(19.78723404255319, 490.75, 'gini = 0.0\nsamples = 77\nvalue = [77, 0]\nclass = no_diff'),
#  Text(59.36170212765957, 490.75, 'x2 <= 24.0\ngini = 0.49\nsamples = 14\nvalue = [8, 6]\nclass = no_diff'),
#  Text(39.57446808510638, 415.25, 'x1 <= 24.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]\nclass = diff'),
#  Text(19.78723404255319, 339.75, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(59.36170212765957, 339.75, 'x1 <= 47.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = diff'),
#  Text(39.57446808510638, 264.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(79.14893617021276, 264.25, 'x1 <= 51.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = diff'),
#  Text(59.36170212765957, 188.75, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(98.93617021276596, 188.75, 'x2 <= 14.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = diff'),
#  Text(79.14893617021276, 113.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = diff'),
#  Text(118.72340425531914, 113.25, 'x2 <= 19.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(98.93617021276596, 37.75, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = no_diff'),
#  Text(138.51063829787233, 37.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(79.14893617021276, 415.25, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = no_diff'),
#  Text(197.87234042553192, 566.25, 'x1 <= 109.5\ngini = 0.01\nsamples = 758\nvalue = [754, 4]\nclass = no_diff'),
#  Text(138.51063829787233, 490.75, 'x2 <= -3.5\ngini = 0.003\nsamples = 699\nvalue = [698, 1]\nclass = no_diff'),
#  Text(118.72340425531914, 415.25, 'gini = 0.0\nsamples = 466\nvalue = [466, 0]\nclass = no_diff'),
#  Text(158.29787234042553, 415.25, 'x2 <= -2.5\ngini = 0.009\nsamples = 233\nvalue = [232, 1]\nclass = no_diff'),
#  Text(138.51063829787233, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(178.08510638297872, 339.75, 'gini = 0.0\nsamples = 232\nvalue = [232, 0]\nclass = no_diff'),
#  Text(257.2340425531915, 490.75, 'x2 <= 0.5\ngini = 0.097\nsamples = 59\nvalue = [56, 3]\nclass = no_diff'),
#  Text(237.44680851063828, 415.25, 'x2 <= -29.5\ngini = 0.236\nsamples = 22\nvalue = [19, 3]\nclass = no_diff'),
#  Text(217.6595744680851, 339.75, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = no_diff'),
#  Text(257.2340425531915, 339.75, 'x2 <= -0.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = no_diff'),
#  Text(237.44680851063828, 264.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(277.02127659574467, 264.25, 'gini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = no_diff'),
#  Text(277.02127659574467, 415.25, 'gini = 0.0\nsamples = 37\nvalue = [37, 0]\nclass = no_diff'),
#  Text(474.89361702127655, 717.25, 'x2 <= 9.5\ngini = 0.287\nsamples = 391\nvalue = [323, 68]\nclass = no_diff'),
#  Text(415.531914893617, 641.75, 'x2 <= -6.5\ngini = 0.394\nsamples = 248\nvalue = [181, 67]\nclass = no_diff'),
#  Text(395.74468085106383, 566.25, 'gini = 0.0\nsamples = 102\nvalue = [102, 0]\nclass = no_diff'),
#  Text(435.3191489361702, 566.25, 'x2 <= 2.5\ngini = 0.497\nsamples = 146\nvalue = [79, 67]\nclass = no_diff'),
#  Text(375.9574468085106, 490.75, 'x1 <= 116.5\ngini = 0.382\nsamples = 66\nvalue = [17, 49]\nclass = diff'),
#  Text(356.17021276595744, 415.25, 'x2 <= 0.5\ngini = 0.5\nsamples = 33\nvalue = [17, 16]\nclass = no_diff'),
#  Text(336.3829787234042, 339.75, 'x1 <= 113.5\ngini = 0.363\nsamples = 21\nvalue = [5, 16]\nclass = diff'),
#  Text(316.59574468085106, 264.25, 'x2 <= -1.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = no_diff'),
#  Text(296.8085106382979, 188.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(336.3829787234042, 188.75, 'x1 <= 112.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = no_diff'),
#  Text(316.59574468085106, 113.25, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = no_diff'),
#  Text(356.17021276595744, 113.25, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = no_diff'),
#  Text(356.17021276595744, 264.25, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = diff'),
#  Text(375.9574468085106, 339.75, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = no_diff'),
#  Text(395.74468085106383, 415.25, 'gini = 0.0\nsamples = 33\nvalue = [0, 33]\nclass = diff'),
#  Text(494.6808510638298, 490.75, 'x1 <= 126.0\ngini = 0.349\nsamples = 80\nvalue = [62, 18]\nclass = no_diff'),
#  Text(474.89361702127655, 415.25, 'x2 <= 3.5\ngini = 0.114\nsamples = 66\nvalue = [62, 4]\nclass = no_diff'),
#  Text(415.531914893617, 339.75, 'x1 <= 117.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = no_diff'),
#  Text(395.74468085106383, 264.25, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = no_diff'),
#  Text(435.3191489361702, 264.25, 'x1 <= 119.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = diff'),
#  Text(415.531914893617, 188.75, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no_diff'),
#  Text(455.1063829787234, 188.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(534.2553191489361, 339.75, 'x2 <= 5.5\ngini = 0.036\nsamples = 55\nvalue = [54, 1]\nclass = no_diff'),
#  Text(514.468085106383, 264.25, 'x1 <= 122.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = no_diff'),
#  Text(494.6808510638298, 188.75, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = no_diff'),
#  Text(534.2553191489361, 188.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(554.0425531914893, 264.25, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]\nclass = no_diff'),
#  Text(514.468085106383, 415.25, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = diff'),
#  Text(534.2553191489361, 641.75, 'x1 <= 127.5\ngini = 0.014\nsamples = 143\nvalue = [142, 1]\nclass = no_diff'),
#  Text(514.468085106383, 566.25, 'gini = 0.0\nsamples = 131\nvalue = [131, 0]\nclass = no_diff'),
#  Text(554.0425531914893, 566.25, 'x2 <= 11.0\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = no_diff'),
#  Text(534.2553191489361, 490.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(573.8297872340426, 490.75, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = no_diff'),
#  Text(707.3936170212766, 792.75, 'x2 <= 4.5\ngini = 0.485\nsamples = 298\nvalue = [123, 175]\nclass = diff'),
#  Text(633.1914893617021, 717.25, 'x1 <= 131.5\ngini = 0.043\nsamples = 90\nvalue = [88, 2]\nclass = no_diff'),
#  Text(613.4042553191489, 641.75, 'x2 <= -23.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = no_diff'),
#  Text(593.6170212765958, 566.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(633.1914893617021, 566.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = diff'),
#  Text(652.9787234042553, 641.75, 'gini = 0.0\nsamples = 86\nvalue = [86, 0]\nclass = no_diff'),
#  Text(781.595744680851, 717.25, 'x1 <= 166.0\ngini = 0.28\nsamples = 208\nvalue = [35, 173]\nclass = diff'),
#  Text(761.8085106382979, 641.75, 'x1 <= 135.0\ngini = 0.234\nsamples = 200\nvalue = [27, 173]\nclass = diff'),
#  Text(672.7659574468084, 566.25, 'x2 <= 14.5\ngini = 0.5\nsamples = 39\nvalue = [20, 19]\nclass = no_diff'),
#  Text(652.9787234042553, 490.75, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]\nclass = diff'),
#  Text(692.5531914893617, 490.75, 'x2 <= 37.5\ngini = 0.091\nsamples = 21\nvalue = [20, 1]\nclass = no_diff'),
#  Text(672.7659574468084, 415.25, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = no_diff'),
#  Text(712.3404255319149, 415.25, 'x1 <= 133.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = no_diff'),
#  Text(692.5531914893617, 339.75, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(732.1276595744681, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(850.8510638297872, 566.25, 'x2 <= 41.0\ngini = 0.083\nsamples = 161\nvalue = [7, 154]\nclass = diff'),
#  Text(811.2765957446808, 490.75, 'x1 <= 136.5\ngini = 0.026\nsamples = 152\nvalue = [2, 150]\nclass = diff'),
#  Text(791.4893617021277, 415.25, 'x2 <= 24.5\ngini = 0.231\nsamples = 15\nvalue = [2, 13]\nclass = diff'),
#  Text(771.7021276595744, 339.75, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = diff'),
#  Text(811.2765957446808, 339.75, 'x2 <= 31.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = no_diff'),
#  Text(791.4893617021277, 264.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(831.063829787234, 264.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = diff'),
#  Text(831.063829787234, 415.25, 'gini = 0.0\nsamples = 137\nvalue = [0, 137]\nclass = diff'),
#  Text(890.4255319148936, 490.75, 'x1 <= 150.0\ngini = 0.494\nsamples = 9\nvalue = [5, 4]\nclass = no_diff'),
#  Text(870.6382978723404, 415.25, 'x1 <= 136.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = diff'),
#  Text(850.8510638297872, 339.75, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = no_diff'),
#  Text(890.4255319148936, 339.75, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = diff'),
#  Text(910.2127659574468, 415.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = no_diff'),
#  Text(801.3829787234042, 641.75, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = no_diff')]

# %%
rule_extractor.print_rules_for_binary(
    dc_full, dataset['columns_for_decision_rules'], ['no_diff', 'diff'], 'diff')
# Out:
# {'diff': '{feature_1 <= 130.5, feature_1 <= 111.5, feature_1 <= -31.5}'}
# {'diff': '{feature_1 <= 130.5, feature_1 <= 111.5, feature_1 > -31.5, feature_1 <= 73.5, feature_2 > -7.5, feature_2 <= 24.0, feature_1 > 24.5, feature_1 <= 47.0}'}
# {'diff': '{feature_1 <= 130.5, feature_1 <= 111.5, feature_1 > -31.5, feature_1 <= 73.5, feature_2 > -7.5, feature_2 <= 24.0, feature_1 > 24.5, feature_1 > 47.0, feature_1 > 51.0, feature_2 <= 14.0}'}
# {'diff': '{feature_1 <= 130.5, feature_1 <= 111.5, feature_1 > -31.5, feature_1 <= 73.5, feature_2 > -7.5, feature_2 <= 24.0, feature_1 > 24.5, feature_1 > 47.0, feature_1 > 51.0, feature_2 > 14.0, feature_2 > 19.5}'}
# {'diff': '{feature_1 <= 130.5, feature_1 <= 111.5, feature_1 > -31.5, feature_1 > 73.5, feature_1 <= 109.5, feature_2 > -3.5, feature_2 <= -2.5}'}
# {'diff': '{feature_1 <= 130.5, feature_1 <= 111.5, feature_1 > -31.5, feature_1 > 73.5, feature_1 > 109.5, feature_2 <= 0.5, feature_2 > -29.5, feature_2 <= -0.5}'}
# {'diff': '{feature_1 <= 130.5, feature_1 > 111.5, feature_2 <= 9.5, feature_2 > -6.5, feature_2 <= 2.5, feature_1 <= 116.5, feature_2 <= 0.5, feature_1 <= 113.5, feature_2 <= -1.5}'}
# {'diff': '{feature_1 <= 130.5, feature_1 > 111.5, feature_2 <= 9.5, feature_2 > -6.5, feature_2 <= 2.5, feature_1 <= 116.5, feature_2 <= 0.5, feature_1 > 113.5}'}
# {'diff': '{feature_1 <= 130.5, feature_1 > 111.5, feature_2 <= 9.5, feature_2 > -6.5, feature_2 <= 2.5, feature_1 > 116.5}'}
# {'diff': '{feature_1 <= 130.5, feature_1 > 111.5, feature_2 <= 9.5, feature_2 > -6.5, feature_2 > 2.5, feature_1 <= 126.0, feature_2 <= 3.5, feature_1 > 117.5, feature_1 > 119.5}'}
# {'diff': '{feature_1 <= 130.5, feature_1 > 111.5, feature_2 <= 9.5, feature_2 > -6.5, feature_2 > 2.5, feature_1 <= 126.0, feature_2 > 3.5, feature_2 <= 5.5, feature_1 > 122.5}'}
# {'diff': '{feature_1 <= 130.5, feature_1 > 111.5, feature_2 <= 9.5, feature_2 > -6.5, feature_2 > 2.5, feature_1 > 126.0}'}
# {'diff': '{feature_1 <= 130.5, feature_1 > 111.5, feature_2 > 9.5, feature_1 > 127.5, feature_2 <= 11.0}'}
# {'diff': '{feature_1 > 130.5, feature_2 <= 4.5, feature_1 <= 131.5, feature_2 > -23.0}'}
# {'diff': '{feature_1 > 130.5, feature_2 > 4.5, feature_1 <= 166.0, feature_1 <= 135.0, feature_2 <= 14.5}'}
# {'diff': '{feature_1 > 130.5, feature_2 > 4.5, feature_1 <= 166.0, feature_1 <= 135.0, feature_2 > 14.5, feature_2 > 37.5, feature_1 > 133.0}'}
# {'diff': '{feature_1 > 130.5, feature_2 > 4.5, feature_1 <= 166.0, feature_1 > 135.0, feature_2 <= 41.0, feature_1 <= 136.5, feature_2 <= 24.5}'}
# {'diff': '{feature_1 > 130.5, feature_2 > 4.5, feature_1 <= 166.0, feature_1 > 135.0, feature_2 <= 41.0, feature_1 <= 136.5, feature_2 > 24.5, feature_2 > 31.5}'}
# {'diff': '{feature_1 > 130.5, feature_2 > 4.5, feature_1 <= 166.0, feature_1 > 135.0, feature_2 <= 41.0, feature_1 > 136.5}'}
# {'diff': '{feature_1 > 130.5, feature_2 > 4.5, feature_1 <= 166.0, feature_1 > 135.0, feature_2 > 41.0, feature_1 <= 150.0, feature_1 > 136.5}'}

# %% [markdown]
# ## Multiclass difference explanations

# %%
multiclass_diff_names = ['(0, 0)', '(1, 1)', '(1, 0)', '(0, 1)']

# %%
diff_classifiers_info = diro2c.recognize_diff(idx_explain, X, dataset, comparer.clf_a, comparer.clf_b,
                                              diff_classifier_method_type.multiclass_diff_classifier,
                                              data_generation_function=neighbor_generator.get_genetic_neighborhood)

# %%
dc_info = diff_classifiers_info['multiclass_diff_classifer']
dc_full = dc_info['dc_full']
dc_test = dc_info['dc_test']
evaluation_info = dc_info['evaluation_info']

X_diff = evaluation_info['X']
y_diff = evaluation_info['y']

print(np.unique(y_diff, return_counts=True))
# Out:
# (array([1, 2, 3, 4]), array([644, 942, 283,  14]))

# %%
fig, ax = plt.subplots(1, 3, figsize=(21, 7))

fig = plot_decision_regions(X=X, y=y_pred_a.astype(
    np.int64), clf=comparer.clf_a, ax=ax[0], legend=2, hide_spines=False)
ax[0].set_xlabel(feature_names[0])
ax[0].set_ylabel(feature_names[1])
ax[0].set_title('black box A')

fig = plot_decision_regions(X=X, y=y_pred_b.astype(
    np.int64), clf=comparer.clf_b, ax=ax[1], legend=2, hide_spines=False)
ax[1].set_xlabel(feature_names[0])
ax[1].set_ylabel(feature_names[1])
ax[1].set_title('black box B')

fig = plot_decision_regions(X=X_diff, y=y_diff.astype(
    np.int64), clf=dc_full, ax=ax[2], legend=2)
ax[2].set_xlabel(feature_names[0])
ax[2].set_ylabel(feature_names[1])
ax[2].set_title('multiclass diff-classifier')

handles, labels = ax[2].get_legend_handles_labels()
ax[2].legend(handles,
             multiclass_diff_names,
             framealpha=0.3, scatterpoints=1)

plt.show()
# Out:
# You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(4, 4), dpi=300)
plot_tree(dc_full,
               feature_names=feature_names,
               class_names=multiclass_diff_names,
               filled=True)
# Out:
# [Text(303.8352272727273, 864.8181818181819, 'x2 <= -1.5\ngini = 0.61\nsamples = 1883\nvalue = [644, 942, 283, 14]\nclass = (1, 1)'),
#  Text(67.63636363636364, 782.4545454545455, 'x2 <= -2.5\ngini = 0.1\nsamples = 874\nvalue = [2, 828, 44, 0]\nclass = (1, 1)'),
#  Text(33.81818181818182, 700.0909090909091, 'x1 <= -33.0\ngini = 0.018\nsamples = 792\nvalue = [0, 785, 7, 0]\nclass = (1, 1)'),
#  Text(16.90909090909091, 617.7272727272727, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0]\nclass = (1, 0)'),
#  Text(50.727272727272734, 617.7272727272727, 'gini = 0.0\nsamples = 785\nvalue = [0, 785, 0, 0]\nclass = (1, 1)'),
#  Text(101.45454545454547, 700.0909090909091, 'x1 <= 121.5\ngini = 0.521\nsamples = 82\nvalue = [2, 43, 37, 0]\nclass = (1, 1)'),
#  Text(84.54545454545455, 617.7272727272727, 'x1 <= 62.5\ngini = 0.387\nsamples = 49\nvalue = [2, 10, 37, 0]\nclass = (1, 0)'),
#  Text(50.727272727272734, 535.3636363636364, 'x1 <= -32.5\ngini = 0.37\nsamples = 9\nvalue = [1, 7, 1, 0]\nclass = (1, 1)'),
#  Text(33.81818181818182, 453.0, 'x1 <= -52.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0]\nclass = (0, 0)'),
#  Text(16.90909090909091, 370.6363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(50.727272727272734, 370.6363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(67.63636363636364, 453.0, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0]\nclass = (1, 1)'),
#  Text(118.36363636363637, 535.3636363636364, 'x1 <= 120.5\ngini = 0.184\nsamples = 40\nvalue = [1, 3, 36, 0]\nclass = (1, 0)'),
#  Text(101.45454545454547, 453.0, 'x1 <= 119.5\ngini = 0.106\nsamples = 36\nvalue = [1, 1, 34, 0]\nclass = (1, 0)'),
#  Text(84.54545454545455, 370.6363636363636, 'x1 <= 101.0\ngini = 0.067\nsamples = 29\nvalue = [1, 0, 28, 0]\nclass = (1, 0)'),
#  Text(67.63636363636364, 288.27272727272725, 'x1 <= 97.5\ngini = 0.198\nsamples = 9\nvalue = [1, 0, 8, 0]\nclass = (1, 0)'),
#  Text(50.727272727272734, 205.909090909091, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]\nclass = (1, 0)'),
#  Text(84.54545454545455, 205.909090909091, 'gini = 0.375\nsamples = 4\nvalue = [1, 0, 3, 0]\nclass = (1, 0)'),
#  Text(101.45454545454547, 288.27272727272725, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 20, 0]\nclass = (1, 0)'),
#  Text(118.36363636363637, 370.6363636363636, 'gini = 0.245\nsamples = 7\nvalue = [0, 1, 6, 0]\nclass = (1, 0)'),
#  Text(135.27272727272728, 453.0, 'gini = 0.5\nsamples = 4\nvalue = [0, 2, 2, 0]\nclass = (1, 1)'),
#  Text(118.36363636363637, 617.7272727272727, 'gini = 0.0\nsamples = 33\nvalue = [0, 33, 0, 0]\nclass = (1, 1)'),
#  Text(540.034090909091, 782.4545454545455, 'x1 <= 132.5\ngini = 0.526\nsamples = 1009\nvalue = [642, 114, 239, 14]\nclass = (0, 0)'),
#  Text(302.25, 700.0909090909091, 'x1 <= 69.5\ngini = 0.283\nsamples = 763\nvalue = [640, 45, 77, 1]\nclass = (0, 0)'),
#  Text(186.0, 617.7272727272727, 'x1 <= -47.0\ngini = 0.618\nsamples = 58\nvalue = [18, 29, 11, 0]\nclass = (1, 1)'),
#  Text(169.0909090909091, 535.3636363636364, 'gini = 0.0\nsamples = 13\nvalue = [13, 0, 0, 0]\nclass = (0, 0)'),
#  Text(202.90909090909093, 535.3636363636364, 'x2 <= 39.5\ngini = 0.513\nsamples = 45\nvalue = [5, 29, 11, 0]\nclass = (1, 1)'),
#  Text(186.0, 453.0, 'x1 <= -25.0\ngini = 0.399\nsamples = 40\nvalue = [0, 29, 11, 0]\nclass = (1, 1)'),
#  Text(152.1818181818182, 370.6363636363636, 'x2 <= 5.0\ngini = 0.375\nsamples = 8\nvalue = [0, 2, 6, 0]\nclass = (1, 0)'),
#  Text(135.27272727272728, 288.27272727272725, 'x2 <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]\nclass = (1, 1)'),
#  Text(118.36363636363637, 205.909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(152.1818181818182, 205.909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(169.0909090909091, 288.27272727272725, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]\nclass = (1, 0)'),
#  Text(219.81818181818184, 370.6363636363636, 'x1 <= 43.0\ngini = 0.264\nsamples = 32\nvalue = [0, 27, 5, 0]\nclass = (1, 1)'),
#  Text(202.90909090909093, 288.27272727272725, 'gini = 0.0\nsamples = 25\nvalue = [0, 25, 0, 0]\nclass = (1, 1)'),
#  Text(236.72727272727275, 288.27272727272725, 'x2 <= 3.0\ngini = 0.408\nsamples = 7\nvalue = [0, 2, 5, 0]\nclass = (1, 0)'),
#  Text(219.81818181818184, 205.909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(253.63636363636365, 205.909090909091, 'x2 <= 14.0\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5, 0]\nclass = (1, 0)'),
#  Text(236.72727272727275, 123.54545454545462, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]\nclass = (1, 0)'),
#  Text(270.54545454545456, 123.54545454545462, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(219.81818181818184, 453.0, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = (0, 0)'),
#  Text(418.5, 617.7272727272727, 'x1 <= 119.5\ngini = 0.212\nsamples = 705\nvalue = [622, 16, 66, 1]\nclass = (0, 0)'),
#  Text(338.1818181818182, 535.3636363636364, 'x1 <= 115.5\ngini = 0.061\nsamples = 474\nvalue = [459, 0, 15, 0]\nclass = (0, 0)'),
#  Text(304.3636363636364, 453.0, 'x1 <= 84.0\ngini = 0.006\nsamples = 353\nvalue = [352, 0, 1, 0]\nclass = (0, 0)'),
#  Text(287.4545454545455, 370.6363636363636, 'x1 <= 80.5\ngini = 0.219\nsamples = 8\nvalue = [7, 0, 1, 0]\nclass = (0, 0)'),
#  Text(270.54545454545456, 288.27272727272725, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = (0, 0)'),
#  Text(304.3636363636364, 288.27272727272725, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(321.2727272727273, 370.6363636363636, 'gini = 0.0\nsamples = 345\nvalue = [345, 0, 0, 0]\nclass = (0, 0)'),
#  Text(372.0, 453.0, 'x2 <= 2.5\ngini = 0.205\nsamples = 121\nvalue = [107, 0, 14, 0]\nclass = (0, 0)'),
#  Text(355.0909090909091, 370.6363636363636, 'x1 <= 117.0\ngini = 0.388\nsamples = 19\nvalue = [5, 0, 14, 0]\nclass = (1, 0)'),
#  Text(338.1818181818182, 288.27272727272725, 'x2 <= 1.5\ngini = 0.469\nsamples = 8\nvalue = [5, 0, 3, 0]\nclass = (0, 0)'),
#  Text(321.2727272727273, 205.909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = (1, 0)'),
#  Text(355.0909090909091, 205.909090909091, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = (0, 0)'),
#  Text(372.0, 288.27272727272725, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0]\nclass = (1, 0)'),
#  Text(388.90909090909093, 370.6363636363636, 'gini = 0.0\nsamples = 102\nvalue = [102, 0, 0, 0]\nclass = (0, 0)'),
#  Text(498.81818181818187, 535.3636363636364, 'x2 <= 7.5\ngini = 0.449\nsamples = 231\nvalue = [163, 16, 51, 1]\nclass = (0, 0)'),
#  Text(456.54545454545456, 453.0, 'x2 <= 2.5\ngini = 0.57\nsamples = 75\nvalue = [15, 16, 44, 0]\nclass = (1, 0)'),
#  Text(422.72727272727275, 370.6363636363636, 'x1 <= 123.0\ngini = 0.496\nsamples = 35\nvalue = [0, 16, 19, 0]\nclass = (1, 0)'),
#  Text(405.81818181818187, 288.27272727272725, 'x1 <= 120.5\ngini = 0.172\nsamples = 21\nvalue = [0, 2, 19, 0]\nclass = (1, 0)'),
#  Text(388.90909090909093, 205.909090909091, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0]\nclass = (1, 0)'),
#  Text(422.72727272727275, 205.909090909091, 'x2 <= 1.5\ngini = 0.408\nsamples = 7\nvalue = [0, 2, 5, 0]\nclass = (1, 0)'),
#  Text(405.81818181818187, 123.54545454545462, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]\nclass = (1, 0)'),
#  Text(439.6363636363637, 123.54545454545462, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(439.6363636363637, 288.27272727272725, 'gini = 0.0\nsamples = 14\nvalue = [0, 14, 0, 0]\nclass = (1, 1)'),
#  Text(490.3636363636364, 370.6363636363636, 'x1 <= 124.5\ngini = 0.469\nsamples = 40\nvalue = [15, 0, 25, 0]\nclass = (1, 0)'),
#  Text(473.4545454545455, 288.27272727272725, 'x2 <= 3.5\ngini = 0.208\nsamples = 17\nvalue = [15, 0, 2, 0]\nclass = (0, 0)'),
#  Text(456.54545454545456, 205.909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(490.3636363636364, 205.909090909091, 'x1 <= 123.5\ngini = 0.117\nsamples = 16\nvalue = [15, 0, 1, 0]\nclass = (0, 0)'),
#  Text(473.4545454545455, 123.54545454545462, 'gini = 0.0\nsamples = 14\nvalue = [14, 0, 0, 0]\nclass = (0, 0)'),
#  Text(507.2727272727273, 123.54545454545462, 'x2 <= 5.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0]\nclass = (0, 0)'),
#  Text(490.3636363636364, 41.181818181818244, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = (1, 0)'),
#  Text(524.1818181818182, 41.181818181818244, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(507.2727272727273, 288.27272727272725, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 23, 0]\nclass = (1, 0)'),
#  Text(541.0909090909091, 453.0, 'x1 <= 129.5\ngini = 0.098\nsamples = 156\nvalue = [148, 0, 7, 1]\nclass = (0, 0)'),
#  Text(524.1818181818182, 370.6363636363636, 'gini = 0.0\nsamples = 118\nvalue = [118, 0, 0, 0]\nclass = (0, 0)'),
#  Text(558.0, 370.6363636363636, 'x2 <= 12.0\ngini = 0.342\nsamples = 38\nvalue = [30, 0, 7, 1]\nclass = (0, 0)'),
#  Text(541.0909090909091, 288.27272727272725, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0]\nclass = (1, 0)'),
#  Text(574.909090909091, 288.27272727272725, 'x2 <= 21.0\ngini = 0.062\nsamples = 31\nvalue = [30, 0, 0, 1]\nclass = (0, 0)'),
#  Text(558.0, 205.909090909091, 'gini = 0.0\nsamples = 22\nvalue = [22, 0, 0, 0]\nclass = (0, 0)'),
#  Text(591.8181818181819, 205.909090909091, 'x2 <= 25.0\ngini = 0.198\nsamples = 9\nvalue = [8, 0, 0, 1]\nclass = (0, 0)'),
#  Text(574.909090909091, 123.54545454545462, 'x1 <= 131.0\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = (0, 0)'),
#  Text(558.0, 41.181818181818244, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = (0, 0)'),
#  Text(591.8181818181819, 41.181818181818244, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = (0, 1)'),
#  Text(608.7272727272727, 123.54545454545462, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = (0, 0)'),
#  Text(777.8181818181819, 700.0909090909091, 'x2 <= 5.0\ngini = 0.485\nsamples = 246\nvalue = [2, 69, 162, 13]\nclass = (1, 0)'),
#  Text(760.909090909091, 617.7272727272727, 'gini = 0.0\nsamples = 46\nvalue = [0, 46, 0, 0]\nclass = (1, 1)'),
#  Text(794.7272727272727, 617.7272727272727, 'x1 <= 161.0\ngini = 0.326\nsamples = 200\nvalue = [2, 23, 162, 13]\nclass = (1, 0)'),
#  Text(777.8181818181819, 535.3636363636364, 'x2 <= 34.5\ngini = 0.242\nsamples = 187\nvalue = [2, 10, 162, 13]\nclass = (1, 0)'),
#  Text(693.2727272727274, 453.0, 'x1 <= 142.0\ngini = 0.152\nsamples = 174\nvalue = [2, 5, 160, 7]\nclass = (1, 0)'),
#  Text(625.6363636363636, 370.6363636363636, 'x2 <= 16.5\ngini = 0.493\nsamples = 34\nvalue = [2, 2, 23, 7]\nclass = (1, 0)'),
#  Text(608.7272727272727, 288.27272727272725, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 23, 0]\nclass = (1, 0)'),
#  Text(642.5454545454546, 288.27272727272725, 'x2 <= 18.0\ngini = 0.529\nsamples = 11\nvalue = [2, 2, 0, 7]\nclass = (0, 1)'),
#  Text(625.6363636363636, 205.909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(659.4545454545455, 205.909090909091, 'x2 <= 25.0\ngini = 0.346\nsamples = 9\nvalue = [2, 0, 0, 7]\nclass = (0, 1)'),
#  Text(642.5454545454546, 123.54545454545462, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]\nclass = (0, 1)'),
#  Text(676.3636363636364, 123.54545454545462, 'x1 <= 135.5\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]\nclass = (0, 1)'),
#  Text(659.4545454545455, 41.181818181818244, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = (0, 0)'),
#  Text(693.2727272727274, 41.181818181818244, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = (0, 1)'),
#  Text(760.909090909091, 370.6363636363636, 'x2 <= 21.5\ngini = 0.042\nsamples = 140\nvalue = [0, 3, 137, 0]\nclass = (1, 0)'),
#  Text(744.0, 288.27272727272725, 'gini = 0.0\nsamples = 114\nvalue = [0, 0, 114, 0]\nclass = (1, 0)'),
#  Text(777.8181818181819, 288.27272727272725, 'x1 <= 155.5\ngini = 0.204\nsamples = 26\nvalue = [0, 3, 23, 0]\nclass = (1, 0)'),
#  Text(760.909090909091, 205.909090909091, 'x2 <= 24.0\ngini = 0.147\nsamples = 25\nvalue = [0, 2, 23, 0]\nclass = (1, 0)'),
#  Text(744.0, 123.54545454545462, 'x1 <= 148.5\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4, 0]\nclass = (1, 0)'),
#  Text(727.0909090909091, 41.181818181818244, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = (1, 1)'),
#  Text(760.909090909091, 41.181818181818244, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = (1, 0)'),
#  Text(777.8181818181819, 123.54545454545462, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0]\nclass = (1, 0)'),
#  Text(794.7272727272727, 205.909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(862.3636363636364, 453.0, 'x1 <= 148.5\ngini = 0.615\nsamples = 13\nvalue = [0, 5, 2, 6]\nclass = (0, 1)'),
#  Text(828.5454545454546, 370.6363636363636, 'x2 <= 104.0\ngini = 0.245\nsamples = 7\nvalue = [0, 1, 0, 6]\nclass = (0, 1)'),
#  Text(811.6363636363637, 288.27272727272725, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6]\nclass = (0, 1)'),
#  Text(845.4545454545455, 288.27272727272725, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = (1, 1)'),
#  Text(896.1818181818182, 370.6363636363636, 'x2 <= 94.0\ngini = 0.444\nsamples = 6\nvalue = [0, 4, 2, 0]\nclass = (1, 1)'),
#  Text(879.2727272727274, 288.27272727272725, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = (1, 1)'),
#  Text(913.0909090909091, 288.27272727272725, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = (1, 0)'),
#  Text(811.6363636363637, 535.3636363636364, 'gini = 0.0\nsamples = 13\nvalue = [0, 13, 0, 0]\nclass = (1, 1)')]
